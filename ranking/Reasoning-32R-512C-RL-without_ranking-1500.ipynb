# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 0,  
    pin_memory: bool        = True,
    persistent_workers: bool = False, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth):
        out = self.conv[depth // (self.max_depth // self.num_module)](x, depth)
        x = 2 * torch.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        x = x + 2 * torch.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            x = checkpoint(self.step_forward, x, x_prev, d, use_reentrant=False)

        return x

# %%
class RecursionAmplifyConv(nn.Module):
    def __init__(self, channels, height, width):
        super(RecursionAmplifyConv, self).__init__()
        
        self.conv0 = nn.Conv2d(3, channels, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(channels, max_depth=32, num_module=1)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))


    def forward(self, x):
        
        x = self.conv0(x)

        x = self.amconv(x)

        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.reamconv= RecursionAmplifyConv(512, 32, 32)

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.reamconv(x)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        return x

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (1 - correct)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        rewards, correct = self.compute_positive_reward(outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        entropy_delta = (entropy - old_entropy)


        with torch.no_grad():

            metrics = {
                'targets': select,
                'entropy': entropy,
            }
    
        return select_delta, entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 1500,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    
    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=0,
        pin_memory=True,
        persistent_workers=False,
    )
    
    criterion = torch.nn.CrossEntropyLoss()
    all_params = list(net.parameters())
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=epochs, eta_min=1e-6
            )
        
        rl_metrics_accumulator = {
            'targets': 0.0, 'entropy': 0.0,
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs = net(inputs)
                
                select_delta, entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(outputs, targets)

                select_delta = torch.sigmoid(select_delta)
                select_loss = select_delta.mean()
                
                entropy_delta = torch.sigmoid(entropy_delta)
                entropy_loss = entropy_delta.mean()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value.sum().item()

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f}")
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
                    if use_bf16 else contextlib.nullcontext())

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = net(images)  
            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum    += batch_loss.item() * bs
            total_seen  += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 515,754

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.289 | Targets: 2.0294 | Entropy: -2.1589
# Epoch [2] 📊 acc: 0.470 | Targets: 1.6916 | Entropy: -2.0631
# Epoch [3] 📊 acc: 0.542 | Targets: 1.5684 | Entropy: -2.0285
# Epoch [4] 📊 acc: 0.593 | Targets: 1.4824 | Entropy: -2.0048
# Epoch [5] 📊 acc: 0.625 | Targets: 1.4292 | Entropy: -1.9925
# Epoch [6] 📊 acc: 0.652 | Targets: 1.3794 | Entropy: -1.9798
# Epoch [7] 📊 acc: 0.668 | Targets: 1.3479 | Entropy: -1.9738
# Epoch [8] 📊 acc: 0.690 | Targets: 1.3113 | Entropy: -1.9653
# Epoch [9] 📊 acc: 0.704 | Targets: 1.2925 | Entropy: -1.9618
# Epoch [10] 📊 acc: 0.717 | Targets: 1.2669 | Entropy: -1.9561
#
# Evaluating at epoch 10 …
# Train Accuracy: 72.82%
# Train Average Loss: 1.2766
# Test Accuracy: 78.21%
# Test Average Loss: 1.1692
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-03
# New best model saved with test accuracy: 78.21%
# Epoch [11] 📊 acc: 0.726 | Targets: 1.2476 | Entropy: -1.9528
# Epoch [12] 📊 acc: 0.735 | Targets: 1.2316 | Entropy: -1.9495
# Epoch [13] 📊 acc: 0.745 | Targets: 1.2170 | Entropy: -1.9470
# Epoch [14] 📊 acc: 0.750 | Targets: 1.2093 | Entropy: -1.9458
# Epoch [15] 📊 acc: 0.758 | Targets: 1.1961 | Entropy: -1.9434
# Epoch [16] 📊 acc: 0.761 | Targets: 1.1856 | Entropy: -1.9408
# Epoch [17] 📊 acc: 0.769 | Targets: 1.1734 | Entropy: -1.9392
# Epoch [18] 📊 acc: 0.775 | Targets: 1.1641 | Entropy: -1.9380
# Epoch [19] 📊 acc: 0.779 | Targets: 1.1551 | Entropy: -1.9360
# Epoch [20] 📊 acc: 0.782 | Targets: 1.1475 | Entropy: -1.9346
#
# Evaluating at epoch 20 …
# Train Accuracy: 76.38%
# Train Average Loss: 1.1756
# Test Accuracy: 82.17%
# Test Average Loss: 1.0790
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-03
# New best model saved with test accuracy: 82.17%
# Epoch [21] 📊 acc: 0.789 | Targets: 1.1377 | Entropy: -1.9327
# Epoch [22] 📊 acc: 0.791 | Targets: 1.1307 | Entropy: -1.9314
# Epoch [23] 📊 acc: 0.796 | Targets: 1.1243 | Entropy: -1.9300
# Epoch [24] 📊 acc: 0.798 | Targets: 1.1198 | Entropy: -1.9296
# Epoch [25] 📊 acc: 0.803 | Targets: 1.1116 | Entropy: -1.9287
# Epoch [26] 📊 acc: 0.805 | Targets: 1.1077 | Entropy: -1.9272
# Epoch [27] 📊 acc: 0.809 | Targets: 1.1016 | Entropy: -1.9260
# Epoch [28] 📊 acc: 0.809 | Targets: 1.1000 | Entropy: -1.9257
# Epoch [29] 📊 acc: 0.814 | Targets: 1.0905 | Entropy: -1.9242
# Epoch [30] 📊 acc: 0.818 | Targets: 1.0857 | Entropy: -1.9236
#
# Evaluating at epoch 30 …
# Train Accuracy: 82.30%
# Train Average Loss: 1.0529
# Test Accuracy: 86.30%
# Test Average Loss: 0.9749
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.99e-04
# New best model saved with test accuracy: 86.30%
# Epoch [31] 📊 acc: 0.819 | Targets: 1.0825 | Entropy: -1.9234
# Epoch [32] 📊 acc: 0.822 | Targets: 1.0756 | Entropy: -1.9214
# Epoch [33] 📊 acc: 0.824 | Targets: 1.0739 | Entropy: -1.9209
# Epoch [34] 📊 acc: 0.828 | Targets: 1.0670 | Entropy: -1.9206
# Epoch [35] 📊 acc: 0.829 | Targets: 1.0638 | Entropy: -1.9193
# Epoch [36] 📊 acc: 0.830 | Targets: 1.0632 | Entropy: -1.9194
# Epoch [37] 📊 acc: 0.834 | Targets: 1.0560 | Entropy: -1.9175
# Epoch [38] 📊 acc: 0.834 | Targets: 1.0557 | Entropy: -1.9179
# Epoch [39] 📊 acc: 0.837 | Targets: 1.0487 | Entropy: -1.9162
# Epoch [40] 📊 acc: 0.839 | Targets: 1.0462 | Entropy: -1.9155
#
# Evaluating at epoch 40 …
# Train Accuracy: 84.53%
# Train Average Loss: 1.0708
# Test Accuracy: 88.21%
# Test Average Loss: 1.0010
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.98e-04
# New best model saved with test accuracy: 88.21%
# Epoch [41] 📊 acc: 0.840 | Targets: 1.0445 | Entropy: -1.9158
# Epoch [42] 📊 acc: 0.841 | Targets: 1.0429 | Entropy: -1.9157
# Epoch [43] 📊 acc: 0.841 | Targets: 1.0389 | Entropy: -1.9147
# Epoch [44] 📊 acc: 0.847 | Targets: 1.0336 | Entropy: -1.9135
# Epoch [45] 📊 acc: 0.847 | Targets: 1.0338 | Entropy: -1.9142
# Epoch [46] 📊 acc: 0.845 | Targets: 1.0346 | Entropy: -1.9145
# Epoch [47] 📊 acc: 0.848 | Targets: 1.0308 | Entropy: -1.9135
# Epoch [48] 📊 acc: 0.851 | Targets: 1.0225 | Entropy: -1.9114
# Epoch [49] 📊 acc: 0.851 | Targets: 1.0259 | Entropy: -1.9132
# Epoch [50] 📊 acc: 0.852 | Targets: 1.0209 | Entropy: -1.9112
#
# Evaluating at epoch 50 …
# Train Accuracy: 85.84%
# Train Average Loss: 0.9959
# Test Accuracy: 88.61%
# Test Average Loss: 0.9366
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 88.61%
# Epoch [51] 📊 acc: 0.854 | Targets: 1.0172 | Entropy: -1.9108
# Epoch [52] 📊 acc: 0.854 | Targets: 1.0190 | Entropy: -1.9112
# Epoch [53] 📊 acc: 0.858 | Targets: 1.0112 | Entropy: -1.9092
# Epoch [54] 📊 acc: 0.857 | Targets: 1.0120 | Entropy: -1.9093
# Epoch [55] 📊 acc: 0.857 | Targets: 1.0102 | Entropy: -1.9094
# Epoch [56] 📊 acc: 0.860 | Targets: 1.0099 | Entropy: -1.9101
# Epoch [57] 📊 acc: 0.861 | Targets: 1.0045 | Entropy: -1.9081
# Epoch [58] 📊 acc: 0.862 | Targets: 1.0044 | Entropy: -1.9082
# Epoch [59] 📊 acc: 0.866 | Targets: 0.9985 | Entropy: -1.9070
# Epoch [60] 📊 acc: 0.865 | Targets: 0.9979 | Entropy: -1.9066
#
# Evaluating at epoch 60 …
# Train Accuracy: 86.64%
# Train Average Loss: 0.9822
# Test Accuracy: 89.47%
# Test Average Loss: 0.9241
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.96e-04
# New best model saved with test accuracy: 89.47%
# Epoch [61] 📊 acc: 0.866 | Targets: 0.9978 | Entropy: -1.9068
# Epoch [62] 📊 acc: 0.865 | Targets: 0.9963 | Entropy: -1.9065
# Epoch [63] 📊 acc: 0.866 | Targets: 0.9950 | Entropy: -1.9065
# Epoch [64] 📊 acc: 0.871 | Targets: 0.9903 | Entropy: -1.9054
# Epoch [65] 📊 acc: 0.872 | Targets: 0.9883 | Entropy: -1.9050
# Epoch [66] 📊 acc: 0.870 | Targets: 0.9888 | Entropy: -1.9049
# Epoch [67] 📊 acc: 0.869 | Targets: 0.9905 | Entropy: -1.9053
# Epoch [68] 📊 acc: 0.873 | Targets: 0.9848 | Entropy: -1.9042
# Epoch [69] 📊 acc: 0.870 | Targets: 0.9902 | Entropy: -1.9058
# Epoch [70] 📊 acc: 0.874 | Targets: 0.9850 | Entropy: -1.9044
#
# Evaluating at epoch 70 …
# Train Accuracy: 87.78%
# Train Average Loss: 0.9754
# Test Accuracy: 90.78%
# Test Average Loss: 0.9130
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.95e-04
# New best model saved with test accuracy: 90.78%
# Epoch [71] 📊 acc: 0.875 | Targets: 0.9801 | Entropy: -1.9028
# Epoch [72] 📊 acc: 0.875 | Targets: 0.9796 | Entropy: -1.9028
# Epoch [73] 📊 acc: 0.877 | Targets: 0.9765 | Entropy: -1.9021
# Epoch [74] 📊 acc: 0.874 | Targets: 0.9799 | Entropy: -1.9031
# Epoch [75] 📊 acc: 0.877 | Targets: 0.9772 | Entropy: -1.9024
# Epoch [76] 📊 acc: 0.878 | Targets: 0.9741 | Entropy: -1.9015
# Epoch [77] 📊 acc: 0.881 | Targets: 0.9707 | Entropy: -1.9011
# Epoch [78] 📊 acc: 0.879 | Targets: 0.9717 | Entropy: -1.9009
# Epoch [79] 📊 acc: 0.881 | Targets: 0.9713 | Entropy: -1.9013
# Epoch [80] 📊 acc: 0.882 | Targets: 0.9685 | Entropy: -1.9004
#
# Evaluating at epoch 80 …
# Train Accuracy: 88.69%
# Train Average Loss: 0.9631
# Test Accuracy: 90.88%
# Test Average Loss: 0.9098
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.93e-04
# New best model saved with test accuracy: 90.88%
# Epoch [81] 📊 acc: 0.878 | Targets: 0.9751 | Entropy: -1.9021
# Epoch [82] 📊 acc: 0.881 | Targets: 0.9697 | Entropy: -1.9010
# Epoch [83] 📊 acc: 0.881 | Targets: 0.9693 | Entropy: -1.9007
# Epoch [84] 📊 acc: 0.884 | Targets: 0.9634 | Entropy: -1.8992
# Epoch [85] 📊 acc: 0.883 | Targets: 0.9665 | Entropy: -1.9002
# Epoch [86] 📊 acc: 0.883 | Targets: 0.9663 | Entropy: -1.9001
# Epoch [87] 📊 acc: 0.885 | Targets: 0.9627 | Entropy: -1.8990
# Epoch [88] 📊 acc: 0.886 | Targets: 0.9590 | Entropy: -1.8982
# Epoch [89] 📊 acc: 0.887 | Targets: 0.9592 | Entropy: -1.8981
# Epoch [90] 📊 acc: 0.886 | Targets: 0.9594 | Entropy: -1.8981
#
# Evaluating at epoch 90 …
# Train Accuracy: 88.26%
# Train Average Loss: 0.9599
# Test Accuracy: 90.85%
# Test Average Loss: 0.9103
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.91e-04
# Epoch [91] 📊 acc: 0.887 | Targets: 0.9588 | Entropy: -1.8983
# Epoch [92] 📊 acc: 0.888 | Targets: 0.9530 | Entropy: -1.8967
# Epoch [93] 📊 acc: 0.890 | Targets: 0.9535 | Entropy: -1.8970
# Epoch [94] 📊 acc: 0.890 | Targets: 0.9538 | Entropy: -1.8969
# Epoch [95] 📊 acc: 0.888 | Targets: 0.9561 | Entropy: -1.8977
# Epoch [96] 📊 acc: 0.890 | Targets: 0.9517 | Entropy: -1.8965
# Epoch [97] 📊 acc: 0.890 | Targets: 0.9495 | Entropy: -1.8959
# Epoch [98] 📊 acc: 0.891 | Targets: 0.9504 | Entropy: -1.8964
# Epoch [99] 📊 acc: 0.891 | Targets: 0.9517 | Entropy: -1.8966
# Epoch [100] 📊 acc: 0.893 | Targets: 0.9473 | Entropy: -1.8953
#
# Evaluating at epoch 100 …
# Train Accuracy: 89.37%
# Train Average Loss: 0.9536
# Test Accuracy: 90.93%
# Test Average Loss: 0.9200
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 90.93%
# Epoch [101] 📊 acc: 0.890 | Targets: 0.9494 | Entropy: -1.8959
# Epoch [102] 📊 acc: 0.893 | Targets: 0.9456 | Entropy: -1.8950
# Epoch [103] 📊 acc: 0.892 | Targets: 0.9484 | Entropy: -1.8959
# Epoch [104] 📊 acc: 0.893 | Targets: 0.9455 | Entropy: -1.8950
# Epoch [105] 📊 acc: 0.894 | Targets: 0.9451 | Entropy: -1.8951
# Epoch [106] 📊 acc: 0.895 | Targets: 0.9423 | Entropy: -1.8943
# Epoch [107] 📊 acc: 0.896 | Targets: 0.9406 | Entropy: -1.8937
# Epoch [108] 📊 acc: 0.895 | Targets: 0.9431 | Entropy: -1.8948
# Epoch [109] 📊 acc: 0.896 | Targets: 0.9400 | Entropy: -1.8936
# Epoch [110] 📊 acc: 0.894 | Targets: 0.9436 | Entropy: -1.8946
#
# Evaluating at epoch 110 …
# Train Accuracy: 90.01%
# Train Average Loss: 0.9373
# Test Accuracy: 91.59%
# Test Average Loss: 0.9027
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.87e-04
# New best model saved with test accuracy: 91.59%
# Epoch [111] 📊 acc: 0.896 | Targets: 0.9393 | Entropy: -1.8935
# Epoch [112] 📊 acc: 0.895 | Targets: 0.9400 | Entropy: -1.8935
# Epoch [113] 📊 acc: 0.899 | Targets: 0.9376 | Entropy: -1.8932
# Epoch [114] 📊 acc: 0.897 | Targets: 0.9387 | Entropy: -1.8936
# Epoch [115] 📊 acc: 0.896 | Targets: 0.9383 | Entropy: -1.8933
# Epoch [116] 📊 acc: 0.900 | Targets: 0.9343 | Entropy: -1.8922
# Epoch [117] 📊 acc: 0.898 | Targets: 0.9372 | Entropy: -1.8932
# Epoch [118] 📊 acc: 0.897 | Targets: 0.9375 | Entropy: -1.8931
# Epoch [119] 📊 acc: 0.899 | Targets: 0.9361 | Entropy: -1.8925
# Epoch [120] 📊 acc: 0.899 | Targets: 0.9346 | Entropy: -1.8927
#
# Evaluating at epoch 120 …
# Train Accuracy: 90.34%
# Train Average Loss: 0.9089
# Test Accuracy: 91.66%
# Test Average Loss: 0.8788
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.84e-04
# New best model saved with test accuracy: 91.66%
# Epoch [121] 📊 acc: 0.898 | Targets: 0.9369 | Entropy: -1.8932
# Epoch [122] 📊 acc: 0.900 | Targets: 0.9353 | Entropy: -1.8927
# Epoch [123] 📊 acc: 0.902 | Targets: 0.9275 | Entropy: -1.8906
# Epoch [124] 📊 acc: 0.900 | Targets: 0.9331 | Entropy: -1.8923
# Epoch [125] 📊 acc: 0.900 | Targets: 0.9328 | Entropy: -1.8920
# Epoch [126] 📊 acc: 0.903 | Targets: 0.9297 | Entropy: -1.8915
# Epoch [127] 📊 acc: 0.901 | Targets: 0.9312 | Entropy: -1.8918
# Epoch [128] 📊 acc: 0.902 | Targets: 0.9288 | Entropy: -1.8911
# Epoch [129] 📊 acc: 0.903 | Targets: 0.9267 | Entropy: -1.8903
# Epoch [130] 📊 acc: 0.904 | Targets: 0.9262 | Entropy: -1.8905
#
# Evaluating at epoch 130 …
# Train Accuracy: 89.57%
# Train Average Loss: 0.9266
# Test Accuracy: 91.24%
# Test Average Loss: 0.9042
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.82e-04
# Epoch [131] 📊 acc: 0.904 | Targets: 0.9258 | Entropy: -1.8902
# Epoch [132] 📊 acc: 0.905 | Targets: 0.9223 | Entropy: -1.8892
# Epoch [133] 📊 acc: 0.904 | Targets: 0.9261 | Entropy: -1.8902
# Epoch [134] 📊 acc: 0.906 | Targets: 0.9225 | Entropy: -1.8894
# Epoch [135] 📊 acc: 0.905 | Targets: 0.9250 | Entropy: -1.8902
# Epoch [136] 📊 acc: 0.904 | Targets: 0.9253 | Entropy: -1.8902
# Epoch [137] 📊 acc: 0.905 | Targets: 0.9237 | Entropy: -1.8898
# Epoch [138] 📊 acc: 0.907 | Targets: 0.9195 | Entropy: -1.8886
# Epoch [139] 📊 acc: 0.906 | Targets: 0.9219 | Entropy: -1.8893
# Epoch [140] 📊 acc: 0.905 | Targets: 0.9237 | Entropy: -1.8898
#
# Evaluating at epoch 140 …
# Train Accuracy: 91.13%
# Train Average Loss: 0.9136
# Test Accuracy: 92.38%
# Test Average Loss: 0.8839
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.79e-04
# New best model saved with test accuracy: 92.38%
# Epoch [141] 📊 acc: 0.907 | Targets: 0.9190 | Entropy: -1.8884
# Epoch [142] 📊 acc: 0.907 | Targets: 0.9173 | Entropy: -1.8882
# Epoch [143] 📊 acc: 0.905 | Targets: 0.9228 | Entropy: -1.8898
# Epoch [144] 📊 acc: 0.907 | Targets: 0.9200 | Entropy: -1.8889
# Epoch [145] 📊 acc: 0.908 | Targets: 0.9195 | Entropy: -1.8890
# Epoch [146] 📊 acc: 0.906 | Targets: 0.9225 | Entropy: -1.8895
# Epoch [147] 📊 acc: 0.910 | Targets: 0.9157 | Entropy: -1.8876
# Epoch [148] 📊 acc: 0.907 | Targets: 0.9169 | Entropy: -1.8881
# Epoch [149] 📊 acc: 0.911 | Targets: 0.9134 | Entropy: -1.8872
# Epoch [150] 📊 acc: 0.907 | Targets: 0.9184 | Entropy: -1.8885
#
# Evaluating at epoch 150 …
# Train Accuracy: 90.78%
# Train Average Loss: 0.9144
# Test Accuracy: 91.87%
# Test Average Loss: 0.8850
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.76e-04
# Epoch [151] 📊 acc: 0.909 | Targets: 0.9161 | Entropy: -1.8879
# Epoch [152] 📊 acc: 0.910 | Targets: 0.9130 | Entropy: -1.8870
# Epoch [153] 📊 acc: 0.909 | Targets: 0.9166 | Entropy: -1.8882
# Epoch [154] 📊 acc: 0.910 | Targets: 0.9146 | Entropy: -1.8873
# Epoch [155] 📊 acc: 0.910 | Targets: 0.9145 | Entropy: -1.8877
# Epoch [156] 📊 acc: 0.910 | Targets: 0.9142 | Entropy: -1.8876
# Epoch [157] 📊 acc: 0.910 | Targets: 0.9150 | Entropy: -1.8881
# Epoch [158] 📊 acc: 0.914 | Targets: 0.9086 | Entropy: -1.8860
# Epoch [159] 📊 acc: 0.910 | Targets: 0.9138 | Entropy: -1.8874
# Epoch [160] 📊 acc: 0.910 | Targets: 0.9139 | Entropy: -1.8876
#
# Evaluating at epoch 160 …
# Train Accuracy: 91.19%
# Train Average Loss: 0.9097
# Test Accuracy: 91.99%
# Test Average Loss: 0.8902
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.72e-04
# Epoch [161] 📊 acc: 0.908 | Targets: 0.9144 | Entropy: -1.8877
# Epoch [162] 📊 acc: 0.910 | Targets: 0.9147 | Entropy: -1.8878
# Epoch [163] 📊 acc: 0.911 | Targets: 0.9116 | Entropy: -1.8869
# Epoch [164] 📊 acc: 0.912 | Targets: 0.9111 | Entropy: -1.8868
# Epoch [165] 📊 acc: 0.915 | Targets: 0.9048 | Entropy: -1.8851
# Epoch [166] 📊 acc: 0.913 | Targets: 0.9083 | Entropy: -1.8859
# Epoch [167] 📊 acc: 0.910 | Targets: 0.9117 | Entropy: -1.8867
# Epoch [168] 📊 acc: 0.913 | Targets: 0.9093 | Entropy: -1.8867
# Epoch [169] 📊 acc: 0.913 | Targets: 0.9090 | Entropy: -1.8862
# Epoch [170] 📊 acc: 0.913 | Targets: 0.9059 | Entropy: -1.8855
#
# Evaluating at epoch 170 …
# Train Accuracy: 91.06%
# Train Average Loss: 0.9191
# Test Accuracy: 91.94%
# Test Average Loss: 0.8964
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.69e-04
# Epoch [171] 📊 acc: 0.911 | Targets: 0.9106 | Entropy: -1.8864
# Epoch [172] 📊 acc: 0.913 | Targets: 0.9060 | Entropy: -1.8853
# Epoch [173] 📊 acc: 0.915 | Targets: 0.9046 | Entropy: -1.8850
# Epoch [174] 📊 acc: 0.912 | Targets: 0.9113 | Entropy: -1.8871
# Epoch [175] 📊 acc: 0.914 | Targets: 0.9049 | Entropy: -1.8850
# Epoch [176] 📊 acc: 0.915 | Targets: 0.9041 | Entropy: -1.8847
# Epoch [177] 📊 acc: 0.914 | Targets: 0.9048 | Entropy: -1.8852
# Epoch [178] 📊 acc: 0.914 | Targets: 0.9052 | Entropy: -1.8852
# Epoch [179] 📊 acc: 0.913 | Targets: 0.9087 | Entropy: -1.8864
# Epoch [180] 📊 acc: 0.916 | Targets: 0.9033 | Entropy: -1.8850
#
# Evaluating at epoch 180 …
# Train Accuracy: 91.52%
# Train Average Loss: 0.8992
# Test Accuracy: 92.57%
# Test Average Loss: 0.8769
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.65e-04
# New best model saved with test accuracy: 92.57%
# Epoch [181] 📊 acc: 0.915 | Targets: 0.9066 | Entropy: -1.8858
# Epoch [182] 📊 acc: 0.917 | Targets: 0.8999 | Entropy: -1.8836
# Epoch [183] 📊 acc: 0.916 | Targets: 0.9037 | Entropy: -1.8850
# Epoch [184] 📊 acc: 0.916 | Targets: 0.9032 | Entropy: -1.8848
# Epoch [185] 📊 acc: 0.918 | Targets: 0.9015 | Entropy: -1.8844
# Epoch [186] 📊 acc: 0.917 | Targets: 0.9016 | Entropy: -1.8845
# Epoch [187] 📊 acc: 0.917 | Targets: 0.9012 | Entropy: -1.8842
# Epoch [188] 📊 acc: 0.914 | Targets: 0.9076 | Entropy: -1.8862
# Epoch [189] 📊 acc: 0.916 | Targets: 0.9025 | Entropy: -1.8846
# Epoch [190] 📊 acc: 0.915 | Targets: 0.9032 | Entropy: -1.8847
#
# Evaluating at epoch 190 …
# Train Accuracy: 91.37%
# Train Average Loss: 0.9147
# Test Accuracy: 92.20%
# Test Average Loss: 0.8847
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.61e-04
# Epoch [191] 📊 acc: 0.917 | Targets: 0.8999 | Entropy: -1.8840
# Epoch [192] 📊 acc: 0.917 | Targets: 0.8995 | Entropy: -1.8838
# Epoch [193] 📊 acc: 0.917 | Targets: 0.9015 | Entropy: -1.8843
# Epoch [194] 📊 acc: 0.918 | Targets: 0.8982 | Entropy: -1.8835
# Epoch [195] 📊 acc: 0.917 | Targets: 0.9002 | Entropy: -1.8840
# Epoch [196] 📊 acc: 0.917 | Targets: 0.9006 | Entropy: -1.8842
# Epoch [197] 📊 acc: 0.918 | Targets: 0.8986 | Entropy: -1.8836
# Epoch [198] 📊 acc: 0.917 | Targets: 0.9017 | Entropy: -1.8844
# Epoch [199] 📊 acc: 0.919 | Targets: 0.8993 | Entropy: -1.8839
# Epoch [200] 📊 acc: 0.918 | Targets: 0.9006 | Entropy: -1.8844
#
# Evaluating at epoch 200 …
# Train Accuracy: 92.15%
# Train Average Loss: 0.8905
# Test Accuracy: 92.45%
# Test Average Loss: 0.8768
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.57e-04
# Epoch [201] 📊 acc: 0.920 | Targets: 0.8972 | Entropy: -1.8831
# Epoch [202] 📊 acc: 0.918 | Targets: 0.8984 | Entropy: -1.8836
# Epoch [203] 📊 acc: 0.919 | Targets: 0.8977 | Entropy: -1.8833
# Epoch [204] 📊 acc: 0.917 | Targets: 0.8987 | Entropy: -1.8833
# Epoch [205] 📊 acc: 0.919 | Targets: 0.8953 | Entropy: -1.8825
# Epoch [206] 📊 acc: 0.917 | Targets: 0.9003 | Entropy: -1.8841
# Epoch [207] 📊 acc: 0.919 | Targets: 0.8975 | Entropy: -1.8832
# Epoch [208] 📊 acc: 0.919 | Targets: 0.8987 | Entropy: -1.8839
# Epoch [209] 📊 acc: 0.920 | Targets: 0.8929 | Entropy: -1.8819
# Epoch [210] 📊 acc: 0.918 | Targets: 0.8996 | Entropy: -1.8839
#
# Evaluating at epoch 210 …
# Train Accuracy: 91.87%
# Train Average Loss: 0.8968
# Test Accuracy: 92.52%
# Test Average Loss: 0.8737
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.52e-04
# Epoch [211] 📊 acc: 0.918 | Targets: 0.8997 | Entropy: -1.8843
# Epoch [212] 📊 acc: 0.918 | Targets: 0.8995 | Entropy: -1.8843
# Epoch [213] 📊 acc: 0.920 | Targets: 0.8942 | Entropy: -1.8824
# Epoch [214] 📊 acc: 0.921 | Targets: 0.8935 | Entropy: -1.8824
# Epoch [215] 📊 acc: 0.918 | Targets: 0.8971 | Entropy: -1.8834
# Epoch [216] 📊 acc: 0.918 | Targets: 0.8981 | Entropy: -1.8836
# Epoch [217] 📊 acc: 0.917 | Targets: 0.8989 | Entropy: -1.8837
# Epoch [218] 📊 acc: 0.920 | Targets: 0.8963 | Entropy: -1.8832
# Epoch [219] 📊 acc: 0.920 | Targets: 0.8945 | Entropy: -1.8826
# Epoch [220] 📊 acc: 0.919 | Targets: 0.8981 | Entropy: -1.8834
#
# Evaluating at epoch 220 …
# Train Accuracy: 92.59%
# Train Average Loss: 0.9015
# Test Accuracy: 93.04%
# Test Average Loss: 0.8837
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.48e-04
# New best model saved with test accuracy: 93.04%
# Epoch [221] 📊 acc: 0.920 | Targets: 0.8958 | Entropy: -1.8830
# Epoch [222] 📊 acc: 0.920 | Targets: 0.8951 | Entropy: -1.8827
# Epoch [223] 📊 acc: 0.919 | Targets: 0.8975 | Entropy: -1.8836
# Epoch [224] 📊 acc: 0.921 | Targets: 0.8930 | Entropy: -1.8820
# Epoch [225] 📊 acc: 0.923 | Targets: 0.8907 | Entropy: -1.8817
# Epoch [226] 📊 acc: 0.919 | Targets: 0.8967 | Entropy: -1.8831
# Epoch [227] 📊 acc: 0.923 | Targets: 0.8918 | Entropy: -1.8820
# Epoch [228] 📊 acc: 0.920 | Targets: 0.8953 | Entropy: -1.8830
# Epoch [229] 📊 acc: 0.921 | Targets: 0.8942 | Entropy: -1.8825
# Epoch [230] 📊 acc: 0.920 | Targets: 0.8931 | Entropy: -1.8825
#
# Evaluating at epoch 230 …
# Train Accuracy: 92.71%
# Train Average Loss: 0.8920
# Test Accuracy: 92.91%
# Test Average Loss: 0.8766
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.43e-04
# Epoch [231] 📊 acc: 0.921 | Targets: 0.8951 | Entropy: -1.8829
# Epoch [232] 📊 acc: 0.919 | Targets: 0.8980 | Entropy: -1.8836
# Epoch [233] 📊 acc: 0.919 | Targets: 0.8964 | Entropy: -1.8832
# Epoch [234] 📊 acc: 0.920 | Targets: 0.8936 | Entropy: -1.8821
# Epoch [235] 📊 acc: 0.922 | Targets: 0.8925 | Entropy: -1.8821
# Epoch [236] 📊 acc: 0.922 | Targets: 0.8935 | Entropy: -1.8824
# Epoch [237] 📊 acc: 0.924 | Targets: 0.8870 | Entropy: -1.8804
# Epoch [238] 📊 acc: 0.919 | Targets: 0.8961 | Entropy: -1.8832
# Epoch [239] 📊 acc: 0.921 | Targets: 0.8924 | Entropy: -1.8819
# Epoch [240] 📊 acc: 0.922 | Targets: 0.8912 | Entropy: -1.8816
#
# Evaluating at epoch 240 …
# Train Accuracy: 92.11%
# Train Average Loss: 0.8941
# Test Accuracy: 92.17%
# Test Average Loss: 0.8779
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.38e-04
# Epoch [241] 📊 acc: 0.922 | Targets: 0.8897 | Entropy: -1.8814
# Epoch [242] 📊 acc: 0.924 | Targets: 0.8885 | Entropy: -1.8812
# Epoch [243] 📊 acc: 0.921 | Targets: 0.8926 | Entropy: -1.8823
# Epoch [244] 📊 acc: 0.925 | Targets: 0.8856 | Entropy: -1.8801
# Epoch [245] 📊 acc: 0.921 | Targets: 0.8913 | Entropy: -1.8816
# Epoch [246] 📊 acc: 0.922 | Targets: 0.8915 | Entropy: -1.8817
# Epoch [247] 📊 acc: 0.922 | Targets: 0.8922 | Entropy: -1.8822
# Epoch [248] 📊 acc: 0.921 | Targets: 0.8940 | Entropy: -1.8827
# Epoch [249] 📊 acc: 0.922 | Targets: 0.8919 | Entropy: -1.8818
# Epoch [250] 📊 acc: 0.922 | Targets: 0.8904 | Entropy: -1.8815
#
# Evaluating at epoch 250 …
# Train Accuracy: 92.71%
# Train Average Loss: 0.8870
# Test Accuracy: 93.04%
# Test Average Loss: 0.8741
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.33e-04
# Epoch [251] 📊 acc: 0.923 | Targets: 0.8895 | Entropy: -1.8815
# Epoch [252] 📊 acc: 0.923 | Targets: 0.8886 | Entropy: -1.8815
# Epoch [253] 📊 acc: 0.924 | Targets: 0.8881 | Entropy: -1.8813
# Epoch [254] 📊 acc: 0.923 | Targets: 0.8897 | Entropy: -1.8813
# Epoch [255] 📊 acc: 0.923 | Targets: 0.8897 | Entropy: -1.8814
# Epoch [256] 📊 acc: 0.922 | Targets: 0.8908 | Entropy: -1.8821
# Epoch [257] 📊 acc: 0.922 | Targets: 0.8880 | Entropy: -1.8809
# Epoch [258] 📊 acc: 0.922 | Targets: 0.8920 | Entropy: -1.8822
# Epoch [259] 📊 acc: 0.923 | Targets: 0.8904 | Entropy: -1.8814
# Epoch [260] 📊 acc: 0.923 | Targets: 0.8897 | Entropy: -1.8814
#
# Evaluating at epoch 260 …
# Train Accuracy: 92.35%
# Train Average Loss: 0.9066
# Test Accuracy: 92.49%
# Test Average Loss: 0.8943
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.28e-04
# Epoch [261] 📊 acc: 0.921 | Targets: 0.8911 | Entropy: -1.8820
# Epoch [262] 📊 acc: 0.923 | Targets: 0.8879 | Entropy: -1.8811
# Epoch [263] 📊 acc: 0.924 | Targets: 0.8865 | Entropy: -1.8806
# Epoch [264] 📊 acc: 0.923 | Targets: 0.8884 | Entropy: -1.8813
# Epoch [265] 📊 acc: 0.922 | Targets: 0.8919 | Entropy: -1.8820
# Epoch [266] 📊 acc: 0.924 | Targets: 0.8872 | Entropy: -1.8810
# Epoch [267] 📊 acc: 0.922 | Targets: 0.8903 | Entropy: -1.8816
# Epoch [268] 📊 acc: 0.924 | Targets: 0.8873 | Entropy: -1.8807
# Epoch [269] 📊 acc: 0.922 | Targets: 0.8917 | Entropy: -1.8822
# Epoch [270] 📊 acc: 0.922 | Targets: 0.8895 | Entropy: -1.8812
#
# Evaluating at epoch 270 …
# Train Accuracy: 92.35%
# Train Average Loss: 0.8928
# Test Accuracy: 92.73%
# Test Average Loss: 0.8772
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.22e-04
# Epoch [271] 📊 acc: 0.925 | Targets: 0.8871 | Entropy: -1.8810
# Epoch [272] 📊 acc: 0.925 | Targets: 0.8870 | Entropy: -1.8806
# Epoch [273] 📊 acc: 0.921 | Targets: 0.8905 | Entropy: -1.8816
# Epoch [274] 📊 acc: 0.924 | Targets: 0.8864 | Entropy: -1.8804
# Epoch [275] 📊 acc: 0.925 | Targets: 0.8835 | Entropy: -1.8798
# Epoch [276] 📊 acc: 0.922 | Targets: 0.8900 | Entropy: -1.8820
# Epoch [277] 📊 acc: 0.925 | Targets: 0.8857 | Entropy: -1.8801
# Epoch [278] 📊 acc: 0.923 | Targets: 0.8878 | Entropy: -1.8812
# Epoch [279] 📊 acc: 0.919 | Targets: 0.8962 | Entropy: -1.8833
# Epoch [280] 📊 acc: 0.925 | Targets: 0.8846 | Entropy: -1.8798
#
# Evaluating at epoch 280 …
# Train Accuracy: 92.82%
# Train Average Loss: 0.8812
# Test Accuracy: 93.02%
# Test Average Loss: 0.8652
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.17e-04
# Epoch [281] 📊 acc: 0.925 | Targets: 0.8865 | Entropy: -1.8809
# Epoch [282] 📊 acc: 0.924 | Targets: 0.8883 | Entropy: -1.8813
# Epoch [283] 📊 acc: 0.922 | Targets: 0.8909 | Entropy: -1.8818
# Epoch [284] 📊 acc: 0.925 | Targets: 0.8850 | Entropy: -1.8804
# Epoch [285] 📊 acc: 0.923 | Targets: 0.8909 | Entropy: -1.8820
# Epoch [286] 📊 acc: 0.922 | Targets: 0.8889 | Entropy: -1.8813
# Epoch [287] 📊 acc: 0.925 | Targets: 0.8845 | Entropy: -1.8798
# Epoch [288] 📊 acc: 0.925 | Targets: 0.8831 | Entropy: -1.8796
# Epoch [289] 📊 acc: 0.922 | Targets: 0.8885 | Entropy: -1.8806
# Epoch [290] 📊 acc: 0.923 | Targets: 0.8885 | Entropy: -1.8814
#
# Evaluating at epoch 290 …
# Train Accuracy: 92.52%
# Train Average Loss: 0.8865
# Test Accuracy: 92.94%
# Test Average Loss: 0.8685
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.11e-04
# Epoch [291] 📊 acc: 0.924 | Targets: 0.8873 | Entropy: -1.8809
# Epoch [292] 📊 acc: 0.925 | Targets: 0.8858 | Entropy: -1.8804
# Epoch [293] 📊 acc: 0.924 | Targets: 0.8876 | Entropy: -1.8812
# Epoch [294] 📊 acc: 0.924 | Targets: 0.8863 | Entropy: -1.8806
# Epoch [295] 📊 acc: 0.922 | Targets: 0.8905 | Entropy: -1.8817
# Epoch [296] 📊 acc: 0.924 | Targets: 0.8871 | Entropy: -1.8811
# Epoch [297] 📊 acc: 0.924 | Targets: 0.8871 | Entropy: -1.8803
# Epoch [298] 📊 acc: 0.925 | Targets: 0.8862 | Entropy: -1.8805
# Epoch [299] 📊 acc: 0.926 | Targets: 0.8853 | Entropy: -1.8805
# Epoch [300] 📊 acc: 0.926 | Targets: 0.8837 | Entropy: -1.8800
#
# Evaluating at epoch 300 …
# Train Accuracy: 92.91%
# Train Average Loss: 0.8837
# Test Accuracy: 92.73%
# Test Average Loss: 0.8781
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.05e-04
# Epoch [301] 📊 acc: 0.924 | Targets: 0.8864 | Entropy: -1.8809
# Epoch [302] 📊 acc: 0.925 | Targets: 0.8857 | Entropy: -1.8803
# Epoch [303] 📊 acc: 0.925 | Targets: 0.8850 | Entropy: -1.8804
# Epoch [304] 📊 acc: 0.925 | Targets: 0.8869 | Entropy: -1.8808
# Epoch [305] 📊 acc: 0.923 | Targets: 0.8904 | Entropy: -1.8816
# Epoch [306] 📊 acc: 0.925 | Targets: 0.8854 | Entropy: -1.8801
# Epoch [307] 📊 acc: 0.927 | Targets: 0.8824 | Entropy: -1.8795
# Epoch [308] 📊 acc: 0.925 | Targets: 0.8861 | Entropy: -1.8805
# Epoch [309] 📊 acc: 0.926 | Targets: 0.8826 | Entropy: -1.8792
# Epoch [310] 📊 acc: 0.921 | Targets: 0.8917 | Entropy: -1.8821
#
# Evaluating at epoch 310 …
# Train Accuracy: 92.89%
# Train Average Loss: 0.8790
# Test Accuracy: 93.23%
# Test Average Loss: 0.8656
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.98e-04
# New best model saved with test accuracy: 93.23%
# Epoch [311] 📊 acc: 0.923 | Targets: 0.8894 | Entropy: -1.8813
# Epoch [312] 📊 acc: 0.924 | Targets: 0.8876 | Entropy: -1.8810
# Epoch [313] 📊 acc: 0.922 | Targets: 0.8917 | Entropy: -1.8822
# Epoch [314] 📊 acc: 0.925 | Targets: 0.8832 | Entropy: -1.8796
# Epoch [315] 📊 acc: 0.924 | Targets: 0.8887 | Entropy: -1.8816
# Epoch [316] 📊 acc: 0.922 | Targets: 0.8896 | Entropy: -1.8812
# Epoch [317] 📊 acc: 0.925 | Targets: 0.8844 | Entropy: -1.8801
# Epoch [318] 📊 acc: 0.924 | Targets: 0.8864 | Entropy: -1.8810
# Epoch [319] 📊 acc: 0.924 | Targets: 0.8868 | Entropy: -1.8806
# Epoch [320] 📊 acc: 0.921 | Targets: 0.8915 | Entropy: -1.8816
#
# Evaluating at epoch 320 …
# Train Accuracy: 92.53%
# Train Average Loss: 0.8878
# Test Accuracy: 92.64%
# Test Average Loss: 0.8670
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.92e-04
# Epoch [321] 📊 acc: 0.925 | Targets: 0.8867 | Entropy: -1.8807
# Epoch [322] 📊 acc: 0.923 | Targets: 0.8883 | Entropy: -1.8812
# Epoch [323] 📊 acc: 0.923 | Targets: 0.8889 | Entropy: -1.8814
# Epoch [324] 📊 acc: 0.923 | Targets: 0.8896 | Entropy: -1.8816
# Epoch [325] 📊 acc: 0.922 | Targets: 0.8904 | Entropy: -1.8813
# Epoch [326] 📊 acc: 0.927 | Targets: 0.8824 | Entropy: -1.8798
# Epoch [327] 📊 acc: 0.924 | Targets: 0.8862 | Entropy: -1.8806
# Epoch [328] 📊 acc: 0.925 | Targets: 0.8856 | Entropy: -1.8803
# Epoch [329] 📊 acc: 0.925 | Targets: 0.8830 | Entropy: -1.8797
# Epoch [330] 📊 acc: 0.927 | Targets: 0.8831 | Entropy: -1.8798
#
# Evaluating at epoch 330 …
# Train Accuracy: 92.48%
# Train Average Loss: 0.8812
# Test Accuracy: 92.50%
# Test Average Loss: 0.8744
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.85e-04
# Epoch [331] 📊 acc: 0.925 | Targets: 0.8842 | Entropy: -1.8802
# Epoch [332] 📊 acc: 0.925 | Targets: 0.8835 | Entropy: -1.8797
# Epoch [333] 📊 acc: 0.921 | Targets: 0.8911 | Entropy: -1.8819
# Epoch [334] 📊 acc: 0.922 | Targets: 0.8884 | Entropy: -1.8811
# Epoch [335] 📊 acc: 0.926 | Targets: 0.8832 | Entropy: -1.8798
# Epoch [336] 📊 acc: 0.923 | Targets: 0.8876 | Entropy: -1.8809
# Epoch [337] 📊 acc: 0.924 | Targets: 0.8888 | Entropy: -1.8813
# Epoch [338] 📊 acc: 0.922 | Targets: 0.8899 | Entropy: -1.8816
# Epoch [339] 📊 acc: 0.919 | Targets: 0.8957 | Entropy: -1.8830
# Epoch [340] 📊 acc: 0.921 | Targets: 0.8914 | Entropy: -1.8817
#
# Evaluating at epoch 340 …
# Train Accuracy: 92.67%
# Train Average Loss: 0.8829
# Test Accuracy: 93.32%
# Test Average Loss: 0.8677
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.79e-04
# New best model saved with test accuracy: 93.32%
# Epoch [341] 📊 acc: 0.923 | Targets: 0.8894 | Entropy: -1.8814
# Epoch [342] 📊 acc: 0.923 | Targets: 0.8896 | Entropy: -1.8816
# Epoch [343] 📊 acc: 0.925 | Targets: 0.8853 | Entropy: -1.8803
# Epoch [344] 📊 acc: 0.927 | Targets: 0.8846 | Entropy: -1.8803
# Epoch [345] 📊 acc: 0.924 | Targets: 0.8874 | Entropy: -1.8810
# Epoch [346] 📊 acc: 0.924 | Targets: 0.8861 | Entropy: -1.8806
# Epoch [347] 📊 acc: 0.921 | Targets: 0.8898 | Entropy: -1.8816
# Epoch [348] 📊 acc: 0.924 | Targets: 0.8881 | Entropy: -1.8810
# Epoch [349] 📊 acc: 0.927 | Targets: 0.8815 | Entropy: -1.8793
# Epoch [350] 📊 acc: 0.924 | Targets: 0.8857 | Entropy: -1.8807
#
# Evaluating at epoch 350 …
# Train Accuracy: 92.87%
# Train Average Loss: 0.8722
# Test Accuracy: 92.88%
# Test Average Loss: 0.8591
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.72e-04
# Epoch [351] 📊 acc: 0.925 | Targets: 0.8854 | Entropy: -1.8804
# Epoch [352] 📊 acc: 0.925 | Targets: 0.8868 | Entropy: -1.8809
# Epoch [353] 📊 acc: 0.924 | Targets: 0.8883 | Entropy: -1.8813
# Epoch [354] 📊 acc: 0.920 | Targets: 0.8924 | Entropy: -1.8819
# Epoch [355] 📊 acc: 0.924 | Targets: 0.8861 | Entropy: -1.8808
# Epoch [356] 📊 acc: 0.927 | Targets: 0.8833 | Entropy: -1.8799
# Epoch [357] 📊 acc: 0.923 | Targets: 0.8879 | Entropy: -1.8809
# Epoch [358] 📊 acc: 0.924 | Targets: 0.8871 | Entropy: -1.8806
# Epoch [359] 📊 acc: 0.924 | Targets: 0.8882 | Entropy: -1.8814
# Epoch [360] 📊 acc: 0.925 | Targets: 0.8824 | Entropy: -1.8795
#
# Evaluating at epoch 360 …
# Train Accuracy: 92.48%
# Train Average Loss: 0.8798
# Test Accuracy: 93.47%
# Test Average Loss: 0.8563
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.65e-04
# New best model saved with test accuracy: 93.47%
# Epoch [361] 📊 acc: 0.923 | Targets: 0.8918 | Entropy: -1.8823
# Epoch [362] 📊 acc: 0.922 | Targets: 0.8919 | Entropy: -1.8820
# Epoch [363] 📊 acc: 0.926 | Targets: 0.8836 | Entropy: -1.8797
# Epoch [364] 📊 acc: 0.924 | Targets: 0.8901 | Entropy: -1.8822
# Epoch [365] 📊 acc: 0.923 | Targets: 0.8899 | Entropy: -1.8816
# Epoch [366] 📊 acc: 0.924 | Targets: 0.8883 | Entropy: -1.8811
# Epoch [367] 📊 acc: 0.921 | Targets: 0.8925 | Entropy: -1.8819
# Epoch [368] 📊 acc: 0.922 | Targets: 0.8910 | Entropy: -1.8818
# Epoch [369] 📊 acc: 0.922 | Targets: 0.8902 | Entropy: -1.8817
# Epoch [370] 📊 acc: 0.925 | Targets: 0.8866 | Entropy: -1.8806
#
# Evaluating at epoch 370 …
# Train Accuracy: 92.50%
# Train Average Loss: 0.8878
# Test Accuracy: 92.66%
# Test Average Loss: 0.8753
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.57e-04
# Epoch [371] 📊 acc: 0.925 | Targets: 0.8869 | Entropy: -1.8807
# Epoch [372] 📊 acc: 0.922 | Targets: 0.8917 | Entropy: -1.8822
# Epoch [373] 📊 acc: 0.922 | Targets: 0.8905 | Entropy: -1.8817
# Epoch [374] 📊 acc: 0.921 | Targets: 0.8912 | Entropy: -1.8817
# Epoch [375] 📊 acc: 0.924 | Targets: 0.8882 | Entropy: -1.8810
# Epoch [376] 📊 acc: 0.921 | Targets: 0.8934 | Entropy: -1.8829
# Epoch [377] 📊 acc: 0.921 | Targets: 0.8932 | Entropy: -1.8825
# Epoch [378] 📊 acc: 0.923 | Targets: 0.8887 | Entropy: -1.8810
# Epoch [379] 📊 acc: 0.921 | Targets: 0.8938 | Entropy: -1.8827
# Epoch [380] 📊 acc: 0.923 | Targets: 0.8854 | Entropy: -1.8800
#
# Evaluating at epoch 380 …
# Train Accuracy: 92.26%
# Train Average Loss: 0.8838
# Test Accuracy: 92.66%
# Test Average Loss: 0.8670
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.50e-04
# Epoch [381] 📊 acc: 0.923 | Targets: 0.8906 | Entropy: -1.8813
# Epoch [382] 📊 acc: 0.918 | Targets: 0.8978 | Entropy: -1.8835
# Epoch [383] 📊 acc: 0.919 | Targets: 0.8978 | Entropy: -1.8839
# Epoch [384] 📊 acc: 0.921 | Targets: 0.8957 | Entropy: -1.8830
# Epoch [385] 📊 acc: 0.923 | Targets: 0.8889 | Entropy: -1.8810
# Epoch [386] 📊 acc: 0.924 | Targets: 0.8883 | Entropy: -1.8812
# Epoch [387] 📊 acc: 0.921 | Targets: 0.8939 | Entropy: -1.8828
# Epoch [388] 📊 acc: 0.919 | Targets: 0.8964 | Entropy: -1.8830
# Epoch [389] 📊 acc: 0.920 | Targets: 0.8961 | Entropy: -1.8828
# Epoch [390] 📊 acc: 0.923 | Targets: 0.8899 | Entropy: -1.8816
#
# Evaluating at epoch 390 …
# Train Accuracy: 92.58%
# Train Average Loss: 0.8875
# Test Accuracy: 92.69%
# Test Average Loss: 0.8766
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.42e-04
# Epoch [391] 📊 acc: 0.918 | Targets: 0.8970 | Entropy: -1.8832
# Epoch [392] 📊 acc: 0.919 | Targets: 0.8982 | Entropy: -1.8840
# Epoch [393] 📊 acc: 0.920 | Targets: 0.8944 | Entropy: -1.8826
# Epoch [394] 📊 acc: 0.917 | Targets: 0.9005 | Entropy: -1.8844
# Epoch [395] 📊 acc: 0.916 | Targets: 0.9014 | Entropy: -1.8853
# Epoch [396] 📊 acc: 0.921 | Targets: 0.8945 | Entropy: -1.8828
# Epoch [397] 📊 acc: 0.923 | Targets: 0.8893 | Entropy: -1.8813
# Epoch [398] 📊 acc: 0.920 | Targets: 0.8954 | Entropy: -1.8831
# Epoch [399] 📊 acc: 0.914 | Targets: 0.9050 | Entropy: -1.8855
# Epoch [400] 📊 acc: 0.919 | Targets: 0.8942 | Entropy: -1.8822
#
# Evaluating at epoch 400 …
# Train Accuracy: 91.91%
# Train Average Loss: 0.8974
# Test Accuracy: 92.71%
# Test Average Loss: 0.8749
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.35e-04
# Epoch [401] 📊 acc: 0.918 | Targets: 0.8992 | Entropy: -1.8841
# Epoch [402] 📊 acc: 0.920 | Targets: 0.8925 | Entropy: -1.8822
# Epoch [403] 📊 acc: 0.921 | Targets: 0.8924 | Entropy: -1.8817
# Epoch [404] 📊 acc: 0.919 | Targets: 0.8969 | Entropy: -1.8840
# Epoch [405] 📊 acc: 0.920 | Targets: 0.8946 | Entropy: -1.8830
# Epoch [406] 📊 acc: 0.914 | Targets: 0.9059 | Entropy: -1.8855
# Epoch [407] 📊 acc: 0.916 | Targets: 0.9004 | Entropy: -1.8842
# Epoch [408] 📊 acc: 0.919 | Targets: 0.8944 | Entropy: -1.8826
# Epoch [409] 📊 acc: 0.916 | Targets: 0.9014 | Entropy: -1.8843
# Epoch [410] 📊 acc: 0.916 | Targets: 0.8998 | Entropy: -1.8838
#
# Evaluating at epoch 410 …
# Train Accuracy: 92.29%
# Train Average Loss: 0.8896
# Test Accuracy: 92.84%
# Test Average Loss: 0.8753
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.27e-04
# Epoch [411] 📊 acc: 0.920 | Targets: 0.8963 | Entropy: -1.8827
# Epoch [412] 📊 acc: 0.919 | Targets: 0.8953 | Entropy: -1.8825
# Epoch [413] 📊 acc: 0.921 | Targets: 0.8927 | Entropy: -1.8823
# Epoch [414] 📊 acc: 0.918 | Targets: 0.8965 | Entropy: -1.8831
# Epoch [415] 📊 acc: 0.921 | Targets: 0.8904 | Entropy: -1.8812
# Epoch [416] 📊 acc: 0.918 | Targets: 0.8957 | Entropy: -1.8827
# Epoch [417] 📊 acc: 0.913 | Targets: 0.9068 | Entropy: -1.8860
# Epoch [418] 📊 acc: 0.916 | Targets: 0.9034 | Entropy: -1.8849
# Epoch [419] 📊 acc: 0.921 | Targets: 0.8929 | Entropy: -1.8821
# Epoch [420] 📊 acc: 0.919 | Targets: 0.8981 | Entropy: -1.8838
#
# Evaluating at epoch 420 …
# Train Accuracy: 91.10%
# Train Average Loss: 0.9107
# Test Accuracy: 92.14%
# Test Average Loss: 0.8826
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.19e-04
# Epoch [421] 📊 acc: 0.918 | Targets: 0.8968 | Entropy: -1.8836
# Epoch [422] 📊 acc: 0.921 | Targets: 0.8939 | Entropy: -1.8824
# Epoch [423] 📊 acc: 0.921 | Targets: 0.8930 | Entropy: -1.8822
# Epoch [424] 📊 acc: 0.922 | Targets: 0.8902 | Entropy: -1.8814
# Epoch [425] 📊 acc: 0.921 | Targets: 0.8928 | Entropy: -1.8819
# Epoch [426] 📊 acc: 0.917 | Targets: 0.8995 | Entropy: -1.8838
# Epoch [427] 📊 acc: 0.911 | Targets: 0.9080 | Entropy: -1.8860
# Epoch [428] 📊 acc: 0.919 | Targets: 0.8957 | Entropy: -1.8829
# Epoch [429] 📊 acc: 0.916 | Targets: 0.9028 | Entropy: -1.8853
# Epoch [430] 📊 acc: 0.913 | Targets: 0.9092 | Entropy: -1.8863
#
# Evaluating at epoch 430 …
# Train Accuracy: 90.11%
# Train Average Loss: 0.9238
# Test Accuracy: 91.43%
# Test Average Loss: 0.8885
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.11e-04
# Epoch [431] 📊 acc: 0.914 | Targets: 0.9059 | Entropy: -1.8858
# Epoch [432] 📊 acc: 0.920 | Targets: 0.8928 | Entropy: -1.8819
# Epoch [433] 📊 acc: 0.918 | Targets: 0.8997 | Entropy: -1.8839
# Epoch [434] 📊 acc: 0.916 | Targets: 0.9025 | Entropy: -1.8848
# Epoch [435] 📊 acc: 0.919 | Targets: 0.8991 | Entropy: -1.8841
# Epoch [436] 📊 acc: 0.911 | Targets: 0.9098 | Entropy: -1.8869
# Epoch [437] 📊 acc: 0.922 | Targets: 0.8918 | Entropy: -1.8818
# Epoch [438] 📊 acc: 0.917 | Targets: 0.8989 | Entropy: -1.8835
# Epoch [439] 📊 acc: 0.916 | Targets: 0.9017 | Entropy: -1.8847
# Epoch [440] 📊 acc: 0.918 | Targets: 0.8988 | Entropy: -1.8844
#
# Evaluating at epoch 440 …
# Train Accuracy: 92.28%
# Train Average Loss: 0.8850
# Test Accuracy: 92.62%
# Test Average Loss: 0.8659
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.02e-04
# Epoch [441] 📊 acc: 0.919 | Targets: 0.8957 | Entropy: -1.8830
# Epoch [442] 📊 acc: 0.914 | Targets: 0.9045 | Entropy: -1.8846
# Epoch [443] 📊 acc: 0.912 | Targets: 0.9095 | Entropy: -1.8863
# Epoch [444] 📊 acc: 0.911 | Targets: 0.9114 | Entropy: -1.8874
# Epoch [445] 📊 acc: 0.920 | Targets: 0.8956 | Entropy: -1.8828
# Epoch [446] 📊 acc: 0.919 | Targets: 0.8975 | Entropy: -1.8831
# Epoch [447] 📊 acc: 0.911 | Targets: 0.9114 | Entropy: -1.8878
# Epoch [448] 📊 acc: 0.918 | Targets: 0.8986 | Entropy: -1.8839
# Epoch [449] 📊 acc: 0.918 | Targets: 0.8995 | Entropy: -1.8842
# Epoch [450] 📊 acc: 0.912 | Targets: 0.9106 | Entropy: -1.8868
#
# Evaluating at epoch 450 …
# Train Accuracy: 91.37%
# Train Average Loss: 0.9159
# Test Accuracy: 92.30%
# Test Average Loss: 0.8850
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.94e-04
# Epoch [451] 📊 acc: 0.918 | Targets: 0.8975 | Entropy: -1.8836
# Epoch [452] 📊 acc: 0.914 | Targets: 0.9025 | Entropy: -1.8846
# Epoch [453] 📊 acc: 0.908 | Targets: 0.9140 | Entropy: -1.8872
# Epoch [454] 📊 acc: 0.909 | Targets: 0.9146 | Entropy: -1.8880
# Epoch [455] 📊 acc: 0.918 | Targets: 0.8971 | Entropy: -1.8834
# Epoch [456] 📊 acc: 0.919 | Targets: 0.8961 | Entropy: -1.8831
# Epoch [457] 📊 acc: 0.916 | Targets: 0.9020 | Entropy: -1.8846
# Epoch [458] 📊 acc: 0.917 | Targets: 0.9006 | Entropy: -1.8844
# Epoch [459] 📊 acc: 0.917 | Targets: 0.9009 | Entropy: -1.8842
# Epoch [460] 📊 acc: 0.914 | Targets: 0.9067 | Entropy: -1.8856
#
# Evaluating at epoch 460 …
# Train Accuracy: 91.64%
# Train Average Loss: 0.9049
# Test Accuracy: 92.86%
# Test Average Loss: 0.8713
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.86e-04
# Epoch [461] 📊 acc: 0.915 | Targets: 0.9034 | Entropy: -1.8847
# Epoch [462] 📊 acc: 0.914 | Targets: 0.9059 | Entropy: -1.8853
# Epoch [463] 📊 acc: 0.914 | Targets: 0.9061 | Entropy: -1.8853
# Epoch [464] 📊 acc: 0.913 | Targets: 0.9059 | Entropy: -1.8855
# Epoch [465] 📊 acc: 0.915 | Targets: 0.9052 | Entropy: -1.8856
# Epoch [466] 📊 acc: 0.914 | Targets: 0.9056 | Entropy: -1.8853
# Epoch [467] 📊 acc: 0.912 | Targets: 0.9096 | Entropy: -1.8864
# Epoch [468] 📊 acc: 0.911 | Targets: 0.9098 | Entropy: -1.8864
# Epoch [469] 📊 acc: 0.911 | Targets: 0.9125 | Entropy: -1.8877
# Epoch [470] 📊 acc: 0.913 | Targets: 0.9093 | Entropy: -1.8872
#
# Evaluating at epoch 470 …
# Train Accuracy: 91.09%
# Train Average Loss: 0.9090
# Test Accuracy: 91.93%
# Test Average Loss: 0.8871
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.77e-04
# Epoch [471] 📊 acc: 0.911 | Targets: 0.9116 | Entropy: -1.8870
# Epoch [472] 📊 acc: 0.915 | Targets: 0.9023 | Entropy: -1.8848
# Epoch [473] 📊 acc: 0.916 | Targets: 0.9040 | Entropy: -1.8850
# Epoch [474] 📊 acc: 0.915 | Targets: 0.9039 | Entropy: -1.8846
# Epoch [475] 📊 acc: 0.919 | Targets: 0.8983 | Entropy: -1.8835
# Epoch [476] 📊 acc: 0.915 | Targets: 0.9033 | Entropy: -1.8842
# Epoch [477] 📊 acc: 0.914 | Targets: 0.9074 | Entropy: -1.8863
# Epoch [478] 📊 acc: 0.907 | Targets: 0.9204 | Entropy: -1.8895
# Epoch [479] 📊 acc: 0.911 | Targets: 0.9101 | Entropy: -1.8860
# Epoch [480] 📊 acc: 0.914 | Targets: 0.9050 | Entropy: -1.8853
#
# Evaluating at epoch 480 …
# Train Accuracy: 91.19%
# Train Average Loss: 0.9055
# Test Accuracy: 92.44%
# Test Average Loss: 0.8730
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.68e-04
# Epoch [481] 📊 acc: 0.914 | Targets: 0.9043 | Entropy: -1.8853
# Epoch [482] 📊 acc: 0.915 | Targets: 0.9028 | Entropy: -1.8845
# Epoch [483] 📊 acc: 0.914 | Targets: 0.9093 | Entropy: -1.8870
# Epoch [484] 📊 acc: 0.912 | Targets: 0.9082 | Entropy: -1.8861
# Epoch [485] 📊 acc: 0.911 | Targets: 0.9119 | Entropy: -1.8871
# Epoch [486] 📊 acc: 0.915 | Targets: 0.9049 | Entropy: -1.8856
# Epoch [487] 📊 acc: 0.916 | Targets: 0.8995 | Entropy: -1.8832
# Epoch [488] 📊 acc: 0.911 | Targets: 0.9106 | Entropy: -1.8864
# Epoch [489] 📊 acc: 0.912 | Targets: 0.9085 | Entropy: -1.8860
# Epoch [490] 📊 acc: 0.916 | Targets: 0.9027 | Entropy: -1.8846
#
# Evaluating at epoch 490 …
# Train Accuracy: 91.45%
# Train Average Loss: 0.9071
# Test Accuracy: 92.15%
# Test Average Loss: 0.8818
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.59e-04
# Epoch [491] 📊 acc: 0.907 | Targets: 0.9182 | Entropy: -1.8880
# Epoch [492] 📊 acc: 0.910 | Targets: 0.9141 | Entropy: -1.8876
# Epoch [493] 📊 acc: 0.912 | Targets: 0.9081 | Entropy: -1.8860
# Epoch [494] 📊 acc: 0.914 | Targets: 0.9060 | Entropy: -1.8860
# Epoch [495] 📊 acc: 0.913 | Targets: 0.9052 | Entropy: -1.8851
# Epoch [496] 📊 acc: 0.910 | Targets: 0.9111 | Entropy: -1.8864
# Epoch [497] 📊 acc: 0.912 | Targets: 0.9082 | Entropy: -1.8860
# Epoch [498] 📊 acc: 0.913 | Targets: 0.9070 | Entropy: -1.8858
# Epoch [499] 📊 acc: 0.910 | Targets: 0.9147 | Entropy: -1.8881
# Epoch [500] 📊 acc: 0.914 | Targets: 0.9056 | Entropy: -1.8851
#
# Evaluating at epoch 500 …
# Train Accuracy: 91.88%
# Train Average Loss: 0.8944
# Test Accuracy: 92.59%
# Test Average Loss: 0.8686
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.50e-04
# Epoch [501] 📊 acc: 0.912 | Targets: 0.9058 | Entropy: -1.8854
# Epoch [502] 📊 acc: 0.912 | Targets: 0.9122 | Entropy: -1.8876
# Epoch [503] 📊 acc: 0.916 | Targets: 0.9011 | Entropy: -1.8839
# Epoch [504] 📊 acc: 0.911 | Targets: 0.9119 | Entropy: -1.8873
# Epoch [505] 📊 acc: 0.912 | Targets: 0.9085 | Entropy: -1.8867
# Epoch [506] 📊 acc: 0.915 | Targets: 0.9027 | Entropy: -1.8845
# Epoch [507] 📊 acc: 0.912 | Targets: 0.9075 | Entropy: -1.8853
# Epoch [508] 📊 acc: 0.914 | Targets: 0.9074 | Entropy: -1.8863
# Epoch [509] 📊 acc: 0.909 | Targets: 0.9145 | Entropy: -1.8880
# Epoch [510] 📊 acc: 0.913 | Targets: 0.9058 | Entropy: -1.8848
#
# Evaluating at epoch 510 …
# Train Accuracy: 91.78%
# Train Average Loss: 0.8908
# Test Accuracy: 92.56%
# Test Average Loss: 0.8666
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.41e-04
# Epoch [511] 📊 acc: 0.918 | Targets: 0.9011 | Entropy: -1.8844
# Epoch [512] 📊 acc: 0.916 | Targets: 0.9032 | Entropy: -1.8853
# Epoch [513] 📊 acc: 0.912 | Targets: 0.9068 | Entropy: -1.8854
# Epoch [514] 📊 acc: 0.913 | Targets: 0.9076 | Entropy: -1.8859
# Epoch [515] 📊 acc: 0.909 | Targets: 0.9129 | Entropy: -1.8877
# Epoch [516] 📊 acc: 0.914 | Targets: 0.9048 | Entropy: -1.8855
# Epoch [517] 📊 acc: 0.916 | Targets: 0.9004 | Entropy: -1.8839
# Epoch [518] 📊 acc: 0.917 | Targets: 0.9014 | Entropy: -1.8848
# Epoch [519] 📊 acc: 0.919 | Targets: 0.8957 | Entropy: -1.8833
# Epoch [520] 📊 acc: 0.919 | Targets: 0.8959 | Entropy: -1.8830
#
# Evaluating at epoch 520 …
# Train Accuracy: 92.22%
# Train Average Loss: 0.8952
# Test Accuracy: 93.05%
# Test Average Loss: 0.8717
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.32e-04
# Epoch [521] 📊 acc: 0.915 | Targets: 0.9025 | Entropy: -1.8847
# Epoch [522] 📊 acc: 0.918 | Targets: 0.8968 | Entropy: -1.8829
# Epoch [523] 📊 acc: 0.918 | Targets: 0.8994 | Entropy: -1.8839
# Epoch [524] 📊 acc: 0.912 | Targets: 0.9092 | Entropy: -1.8864
# Epoch [525] 📊 acc: 0.912 | Targets: 0.9109 | Entropy: -1.8869
# Epoch [526] 📊 acc: 0.916 | Targets: 0.9009 | Entropy: -1.8842
# Epoch [527] 📊 acc: 0.910 | Targets: 0.9124 | Entropy: -1.8875
# Epoch [528] 📊 acc: 0.910 | Targets: 0.9152 | Entropy: -1.8884
# Epoch [529] 📊 acc: 0.908 | Targets: 0.9155 | Entropy: -1.8888
# Epoch [530] 📊 acc: 0.910 | Targets: 0.9126 | Entropy: -1.8874
#
# Evaluating at epoch 530 …
# Train Accuracy: 91.13%
# Train Average Loss: 0.9070
# Test Accuracy: 92.10%
# Test Average Loss: 0.8781
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.23e-04
# Epoch [531] 📊 acc: 0.910 | Targets: 0.9130 | Entropy: -1.8872
# Epoch [532] 📊 acc: 0.912 | Targets: 0.9080 | Entropy: -1.8862
# Epoch [533] 📊 acc: 0.912 | Targets: 0.9096 | Entropy: -1.8866
# Epoch [534] 📊 acc: 0.910 | Targets: 0.9101 | Entropy: -1.8860
# Epoch [535] 📊 acc: 0.907 | Targets: 0.9181 | Entropy: -1.8883
# Epoch [536] 📊 acc: 0.912 | Targets: 0.9112 | Entropy: -1.8871
# Epoch [537] 📊 acc: 0.913 | Targets: 0.9105 | Entropy: -1.8867
# Epoch [538] 📊 acc: 0.913 | Targets: 0.9072 | Entropy: -1.8859
# Epoch [539] 📊 acc: 0.910 | Targets: 0.9156 | Entropy: -1.8881
# Epoch [540] 📊 acc: 0.908 | Targets: 0.9195 | Entropy: -1.8892
#
# Evaluating at epoch 540 …
# Train Accuracy: 91.54%
# Train Average Loss: 0.9010
# Test Accuracy: 92.37%
# Test Average Loss: 0.8787
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.13e-04
# Epoch [541] 📊 acc: 0.908 | Targets: 0.9176 | Entropy: -1.8892
# Epoch [542] 📊 acc: 0.908 | Targets: 0.9128 | Entropy: -1.8872
# Epoch [543] 📊 acc: 0.910 | Targets: 0.9147 | Entropy: -1.8876
# Epoch [544] 📊 acc: 0.908 | Targets: 0.9158 | Entropy: -1.8877
# Epoch [545] 📊 acc: 0.906 | Targets: 0.9181 | Entropy: -1.8881
# Epoch [546] 📊 acc: 0.906 | Targets: 0.9169 | Entropy: -1.8878
# Epoch [547] 📊 acc: 0.913 | Targets: 0.9089 | Entropy: -1.8865
# Epoch [548] 📊 acc: 0.908 | Targets: 0.9151 | Entropy: -1.8877
# Epoch [549] 📊 acc: 0.908 | Targets: 0.9160 | Entropy: -1.8875
# Epoch [550] 📊 acc: 0.904 | Targets: 0.9207 | Entropy: -1.8888
#
# Evaluating at epoch 550 …
# Train Accuracy: 89.65%
# Train Average Loss: 0.9413
# Test Accuracy: 91.76%
# Test Average Loss: 0.8979
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.04e-04
# Epoch [551] 📊 acc: 0.902 | Targets: 0.9286 | Entropy: -1.8917
# Epoch [552] 📊 acc: 0.903 | Targets: 0.9285 | Entropy: -1.8912
# Epoch [553] 📊 acc: 0.900 | Targets: 0.9321 | Entropy: -1.8927
# Epoch [554] 📊 acc: 0.910 | Targets: 0.9118 | Entropy: -1.8873
# Epoch [555] 📊 acc: 0.913 | Targets: 0.9051 | Entropy: -1.8847
# Epoch [556] 📊 acc: 0.915 | Targets: 0.9035 | Entropy: -1.8848
# Epoch [557] 📊 acc: 0.910 | Targets: 0.9127 | Entropy: -1.8871
# Epoch [558] 📊 acc: 0.911 | Targets: 0.9110 | Entropy: -1.8865
# Epoch [559] 📊 acc: 0.908 | Targets: 0.9157 | Entropy: -1.8881
# Epoch [560] 📊 acc: 0.912 | Targets: 0.9092 | Entropy: -1.8862
#
# Evaluating at epoch 560 …
# Train Accuracy: 91.86%
# Train Average Loss: 0.9051
# Test Accuracy: 92.87%
# Test Average Loss: 0.8777
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.94e-04
# Epoch [561] 📊 acc: 0.911 | Targets: 0.9089 | Entropy: -1.8858
# Epoch [562] 📊 acc: 0.913 | Targets: 0.9073 | Entropy: -1.8858
# Epoch [563] 📊 acc: 0.911 | Targets: 0.9108 | Entropy: -1.8870
# Epoch [564] 📊 acc: 0.912 | Targets: 0.9092 | Entropy: -1.8858
# Epoch [565] 📊 acc: 0.910 | Targets: 0.9125 | Entropy: -1.8868
# Epoch [566] 📊 acc: 0.913 | Targets: 0.9085 | Entropy: -1.8861
# Epoch [567] 📊 acc: 0.909 | Targets: 0.9145 | Entropy: -1.8878
# Epoch [568] 📊 acc: 0.903 | Targets: 0.9275 | Entropy: -1.8912
# Epoch [569] 📊 acc: 0.893 | Targets: 0.9442 | Entropy: -1.8950
# Epoch [570] 📊 acc: 0.898 | Targets: 0.9343 | Entropy: -1.8923
#
# Evaluating at epoch 570 …
# Train Accuracy: 90.46%
# Train Average Loss: 0.9273
# Test Accuracy: 92.23%
# Test Average Loss: 0.8907
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.84e-04
# Epoch [571] 📊 acc: 0.888 | Targets: 0.9525 | Entropy: -1.8970
# Epoch [572] 📊 acc: 0.900 | Targets: 0.9337 | Entropy: -1.8936
# Epoch [573] 📊 acc: 0.904 | Targets: 0.9252 | Entropy: -1.8896
# Epoch [574] 📊 acc: 0.908 | Targets: 0.9175 | Entropy: -1.8882
# Epoch [575] 📊 acc: 0.912 | Targets: 0.9087 | Entropy: -1.8853
# Epoch [576] 📊 acc: 0.911 | Targets: 0.9117 | Entropy: -1.8870
# Epoch [577] 📊 acc: 0.907 | Targets: 0.9210 | Entropy: -1.8890
# Epoch [578] 📊 acc: 0.910 | Targets: 0.9135 | Entropy: -1.8873
# Epoch [579] 📊 acc: 0.908 | Targets: 0.9162 | Entropy: -1.8882
# Epoch [580] 📊 acc: 0.901 | Targets: 0.9287 | Entropy: -1.8910
#
# Evaluating at epoch 580 …
# Train Accuracy: 90.30%
# Train Average Loss: 0.9265
# Test Accuracy: 91.62%
# Test Average Loss: 0.8926
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.75e-04
# ...
#
# Evaluating at epoch 1310 …
# Train Accuracy: 95.16%
# Train Average Loss: 0.8331
# Test Accuracy: 94.31%
# Test Average Loss: 0.8415
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.00e-05
# Epoch [1311] 📊 acc: 0.951 | Targets: 0.8357 | Entropy: -1.8678
# Epoch [1312] 📊 acc: 0.951 | Targets: 0.8353 | Entropy: -1.8677
# Epoch [1313] 📊 acc: 0.952 | Targets: 0.8343 | Entropy: -1.8679
# Epoch [1314] 📊 acc: 0.952 | Targets: 0.8344 | Entropy: -1.8678
# Epoch [1315] 📊 acc: 0.952 | Targets: 0.8344 | Entropy: -1.8678
# Epoch [1316] 📊 acc: 0.951 | Targets: 0.8354 | Entropy: -1.8677
# Epoch [1317] 📊 acc: 0.950 | Targets: 0.8382 | Entropy: -1.8685
# Epoch [1318] 📊 acc: 0.952 | Targets: 0.8341 | Entropy: -1.8677
# Epoch [1319] 📊 acc: 0.951 | Targets: 0.8356 | Entropy: -1.8677
# Epoch [1320] 📊 acc: 0.953 | Targets: 0.8319 | Entropy: -1.8660
#
# Evaluating at epoch 1320 …
# Train Accuracy: 95.13%
# Train Average Loss: 0.8350
# Test Accuracy: 94.23%
# Test Average Loss: 0.8428
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.61e-05
# Epoch [1321] 📊 acc: 0.952 | Targets: 0.8335 | Entropy: -1.8673
# Epoch [1322] 📊 acc: 0.952 | Targets: 0.8348 | Entropy: -1.8679
# Epoch [1323] 📊 acc: 0.952 | Targets: 0.8355 | Entropy: -1.8679
# Epoch [1324] 📊 acc: 0.951 | Targets: 0.8353 | Entropy: -1.8674
# Epoch [1325] 📊 acc: 0.951 | Targets: 0.8358 | Entropy: -1.8682
# Epoch [1326] 📊 acc: 0.953 | Targets: 0.8346 | Entropy: -1.8684
# Epoch [1327] 📊 acc: 0.952 | Targets: 0.8339 | Entropy: -1.8676
# Epoch [1328] 📊 acc: 0.951 | Targets: 0.8353 | Entropy: -1.8683
# Epoch [1329] 📊 acc: 0.953 | Targets: 0.8326 | Entropy: -1.8670
# Epoch [1330] 📊 acc: 0.952 | Targets: 0.8351 | Entropy: -1.8680
#
# Evaluating at epoch 1330 …
# Train Accuracy: 95.35%
# Train Average Loss: 0.8329
# Test Accuracy: 94.16%
# Test Average Loss: 0.8452
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.23e-05
# Epoch [1331] 📊 acc: 0.951 | Targets: 0.8362 | Entropy: -1.8682
# Epoch [1332] 📊 acc: 0.951 | Targets: 0.8357 | Entropy: -1.8681
# Epoch [1333] 📊 acc: 0.951 | Targets: 0.8353 | Entropy: -1.8681
# Epoch [1334] 📊 acc: 0.952 | Targets: 0.8322 | Entropy: -1.8669
# Epoch [1335] 📊 acc: 0.952 | Targets: 0.8346 | Entropy: -1.8675
# Epoch [1336] 📊 acc: 0.951 | Targets: 0.8351 | Entropy: -1.8681
# Epoch [1337] 📊 acc: 0.953 | Targets: 0.8318 | Entropy: -1.8666
# Epoch [1338] 📊 acc: 0.954 | Targets: 0.8301 | Entropy: -1.8665
# Epoch [1339] 📊 acc: 0.951 | Targets: 0.8358 | Entropy: -1.8682
# Epoch [1340] 📊 acc: 0.952 | Targets: 0.8356 | Entropy: -1.8682
#
# Evaluating at epoch 1340 …
# Train Accuracy: 95.14%
# Train Average Loss: 0.8363
# Test Accuracy: 94.18%
# Test Average Loss: 0.8434
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.88e-05
# Epoch [1341] 📊 acc: 0.951 | Targets: 0.8360 | Entropy: -1.8683
# Epoch [1342] 📊 acc: 0.951 | Targets: 0.8353 | Entropy: -1.8676
# Epoch [1343] 📊 acc: 0.951 | Targets: 0.8368 | Entropy: -1.8683
# Epoch [1344] 📊 acc: 0.952 | Targets: 0.8337 | Entropy: -1.8679
# Epoch [1345] 📊 acc: 0.953 | Targets: 0.8328 | Entropy: -1.8674
# Epoch [1346] 📊 acc: 0.953 | Targets: 0.8332 | Entropy: -1.8675
# Epoch [1347] 📊 acc: 0.953 | Targets: 0.8335 | Entropy: -1.8677
# Epoch [1348] 📊 acc: 0.952 | Targets: 0.8338 | Entropy: -1.8671
# Epoch [1349] 📊 acc: 0.952 | Targets: 0.8339 | Entropy: -1.8675
# Epoch [1350] 📊 acc: 0.952 | Targets: 0.8335 | Entropy: -1.8676
#
# Evaluating at epoch 1350 …
# Train Accuracy: 95.23%
# Train Average Loss: 0.8350
# Test Accuracy: 94.14%
# Test Average Loss: 0.8456
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-05
# Epoch [1351] 📊 acc: 0.951 | Targets: 0.8349 | Entropy: -1.8681
# Epoch [1352] 📊 acc: 0.953 | Targets: 0.8332 | Entropy: -1.8675
# Epoch [1353] 📊 acc: 0.952 | Targets: 0.8336 | Entropy: -1.8672
# Epoch [1354] 📊 acc: 0.952 | Targets: 0.8324 | Entropy: -1.8670
# Epoch [1355] 📊 acc: 0.953 | Targets: 0.8318 | Entropy: -1.8667
# Epoch [1356] 📊 acc: 0.954 | Targets: 0.8326 | Entropy: -1.8671
# Epoch [1357] 📊 acc: 0.954 | Targets: 0.8326 | Entropy: -1.8673
# Epoch [1358] 📊 acc: 0.953 | Targets: 0.8329 | Entropy: -1.8674
# Epoch [1359] 📊 acc: 0.951 | Targets: 0.8348 | Entropy: -1.8678
# Epoch [1360] 📊 acc: 0.953 | Targets: 0.8323 | Entropy: -1.8671
#
# Evaluating at epoch 1360 …
# Train Accuracy: 95.41%
# Train Average Loss: 0.8296
# Test Accuracy: 94.22%
# Test Average Loss: 0.8429
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.23e-05
# Epoch [1361] 📊 acc: 0.952 | Targets: 0.8331 | Entropy: -1.8669
# Epoch [1362] 📊 acc: 0.952 | Targets: 0.8346 | Entropy: -1.8678
# Epoch [1363] 📊 acc: 0.953 | Targets: 0.8313 | Entropy: -1.8666
# Epoch [1364] 📊 acc: 0.951 | Targets: 0.8345 | Entropy: -1.8677
# Epoch [1365] 📊 acc: 0.953 | Targets: 0.8316 | Entropy: -1.8668
# Epoch [1366] 📊 acc: 0.953 | Targets: 0.8329 | Entropy: -1.8678
# Epoch [1367] 📊 acc: 0.951 | Targets: 0.8358 | Entropy: -1.8680
# Epoch [1368] 📊 acc: 0.954 | Targets: 0.8321 | Entropy: -1.8673
# Epoch [1369] 📊 acc: 0.952 | Targets: 0.8339 | Entropy: -1.8676
# Epoch [1370] 📊 acc: 0.953 | Targets: 0.8332 | Entropy: -1.8675
#
# Evaluating at epoch 1370 …
# Train Accuracy: 95.24%
# Train Average Loss: 0.8338
# Test Accuracy: 94.02%
# Test Average Loss: 0.8452
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.94e-05
# Epoch [1371] 📊 acc: 0.954 | Targets: 0.8297 | Entropy: -1.8666
# Epoch [1372] 📊 acc: 0.951 | Targets: 0.8338 | Entropy: -1.8673
# Epoch [1373] 📊 acc: 0.953 | Targets: 0.8325 | Entropy: -1.8675
# Epoch [1374] 📊 acc: 0.951 | Targets: 0.8335 | Entropy: -1.8672
# Epoch [1375] 📊 acc: 0.952 | Targets: 0.8354 | Entropy: -1.8679
# Epoch [1376] 📊 acc: 0.953 | Targets: 0.8323 | Entropy: -1.8671
# Epoch [1377] 📊 acc: 0.952 | Targets: 0.8333 | Entropy: -1.8671
# Epoch [1378] 📊 acc: 0.953 | Targets: 0.8306 | Entropy: -1.8667
# Epoch [1379] 📊 acc: 0.954 | Targets: 0.8315 | Entropy: -1.8669
# Epoch [1380] 📊 acc: 0.951 | Targets: 0.8359 | Entropy: -1.8680
#
# Evaluating at epoch 1380 …
# Train Accuracy: 95.13%
# Train Average Loss: 0.8361
# Test Accuracy: 94.23%
# Test Average Loss: 0.8442
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.67e-05
# Epoch [1381] 📊 acc: 0.953 | Targets: 0.8330 | Entropy: -1.8670
# Epoch [1382] 📊 acc: 0.953 | Targets: 0.8327 | Entropy: -1.8671
# Epoch [1383] 📊 acc: 0.953 | Targets: 0.8323 | Entropy: -1.8671
# Epoch [1384] 📊 acc: 0.953 | Targets: 0.8320 | Entropy: -1.8672
# Epoch [1385] 📊 acc: 0.952 | Targets: 0.8336 | Entropy: -1.8673
# Epoch [1386] 📊 acc: 0.954 | Targets: 0.8320 | Entropy: -1.8668
# Epoch [1387] 📊 acc: 0.953 | Targets: 0.8334 | Entropy: -1.8676
# Epoch [1388] 📊 acc: 0.954 | Targets: 0.8303 | Entropy: -1.8665
# Epoch [1389] 📊 acc: 0.953 | Targets: 0.8314 | Entropy: -1.8665
# Epoch [1390] 📊 acc: 0.953 | Targets: 0.8326 | Entropy: -1.8669
#
# Evaluating at epoch 1390 …
# Train Accuracy: 95.31%
# Train Average Loss: 0.8322
# Test Accuracy: 94.19%
# Test Average Loss: 0.8437
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.42e-05
# Epoch [1391] 📊 acc: 0.954 | Targets: 0.8300 | Entropy: -1.8663
# Epoch [1392] 📊 acc: 0.952 | Targets: 0.8329 | Entropy: -1.8668
# Epoch [1393] 📊 acc: 0.953 | Targets: 0.8333 | Entropy: -1.8674
# Epoch [1394] 📊 acc: 0.954 | Targets: 0.8301 | Entropy: -1.8664
# Epoch [1395] 📊 acc: 0.954 | Targets: 0.8317 | Entropy: -1.8670
# Epoch [1396] 📊 acc: 0.953 | Targets: 0.8313 | Entropy: -1.8665
# Epoch [1397] 📊 acc: 0.953 | Targets: 0.8315 | Entropy: -1.8670
# Epoch [1398] 📊 acc: 0.954 | Targets: 0.8313 | Entropy: -1.8667
# Epoch [1399] 📊 acc: 0.954 | Targets: 0.8327 | Entropy: -1.8669
# Epoch [1400] 📊 acc: 0.954 | Targets: 0.8304 | Entropy: -1.8667
#
# Evaluating at epoch 1400 …
# Train Accuracy: 95.30%
# Train Average Loss: 0.8317
# Test Accuracy: 94.19%
# Test Average Loss: 0.8431
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.19e-05
# Epoch [1401] 📊 acc: 0.952 | Targets: 0.8320 | Entropy: -1.8668
# Epoch [1402] 📊 acc: 0.954 | Targets: 0.8311 | Entropy: -1.8666
# Epoch [1403] 📊 acc: 0.954 | Targets: 0.8298 | Entropy: -1.8664
# Epoch [1404] 📊 acc: 0.952 | Targets: 0.8333 | Entropy: -1.8676
# Epoch [1405] 📊 acc: 0.955 | Targets: 0.8298 | Entropy: -1.8668
# Epoch [1406] 📊 acc: 0.954 | Targets: 0.8301 | Entropy: -1.8658
# Epoch [1407] 📊 acc: 0.955 | Targets: 0.8283 | Entropy: -1.8657
# Epoch [1408] 📊 acc: 0.954 | Targets: 0.8300 | Entropy: -1.8659
# Epoch [1409] 📊 acc: 0.953 | Targets: 0.8317 | Entropy: -1.8664
# Epoch [1410] 📊 acc: 0.954 | Targets: 0.8304 | Entropy: -1.8666
#
# Evaluating at epoch 1410 …
# Train Accuracy: 95.35%
# Train Average Loss: 0.8307
# Test Accuracy: 94.20%
# Test Average Loss: 0.8437
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.85e-06
# Epoch [1411] 📊 acc: 0.952 | Targets: 0.8339 | Entropy: -1.8671
# Epoch [1412] 📊 acc: 0.953 | Targets: 0.8341 | Entropy: -1.8681
# Epoch [1413] 📊 acc: 0.955 | Targets: 0.8293 | Entropy: -1.8665
# Epoch [1414] 📊 acc: 0.954 | Targets: 0.8299 | Entropy: -1.8666
# Epoch [1415] 📊 acc: 0.951 | Targets: 0.8344 | Entropy: -1.8675
# Epoch [1416] 📊 acc: 0.952 | Targets: 0.8349 | Entropy: -1.8678
# Epoch [1417] 📊 acc: 0.954 | Targets: 0.8286 | Entropy: -1.8661
# Epoch [1418] 📊 acc: 0.954 | Targets: 0.8309 | Entropy: -1.8665
# Epoch [1419] 📊 acc: 0.952 | Targets: 0.8336 | Entropy: -1.8673
# Epoch [1420] 📊 acc: 0.954 | Targets: 0.8303 | Entropy: -1.8673
#
# Evaluating at epoch 1420 …
# Train Accuracy: 95.46%
# Train Average Loss: 0.8311
# Test Accuracy: 94.28%
# Test Average Loss: 0.8433
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.99e-06
# Epoch [1421] 📊 acc: 0.953 | Targets: 0.8336 | Entropy: -1.8672
# Epoch [1422] 📊 acc: 0.951 | Targets: 0.8342 | Entropy: -1.8678
# Epoch [1423] 📊 acc: 0.954 | Targets: 0.8315 | Entropy: -1.8670
# Epoch [1424] 📊 acc: 0.954 | Targets: 0.8303 | Entropy: -1.8659
# Epoch [1425] 📊 acc: 0.956 | Targets: 0.8280 | Entropy: -1.8664
# Epoch [1426] 📊 acc: 0.953 | Targets: 0.8307 | Entropy: -1.8663
# Epoch [1427] 📊 acc: 0.953 | Targets: 0.8310 | Entropy: -1.8664
# Epoch [1428] 📊 acc: 0.954 | Targets: 0.8308 | Entropy: -1.8668
# Epoch [1429] 📊 acc: 0.954 | Targets: 0.8310 | Entropy: -1.8671
# Epoch [1430] 📊 acc: 0.953 | Targets: 0.8314 | Entropy: -1.8666
#
# Evaluating at epoch 1430 …
# Train Accuracy: 95.32%
# Train Average Loss: 0.8314
# Test Accuracy: 94.13%
# Test Average Loss: 0.8433
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.36e-06
# Epoch [1431] 📊 acc: 0.953 | Targets: 0.8314 | Entropy: -1.8667
# Epoch [1432] 📊 acc: 0.952 | Targets: 0.8332 | Entropy: -1.8674
# Epoch [1433] 📊 acc: 0.955 | Targets: 0.8303 | Entropy: -1.8670
# Epoch [1434] 📊 acc: 0.952 | Targets: 0.8343 | Entropy: -1.8670
# Epoch [1435] 📊 acc: 0.953 | Targets: 0.8327 | Entropy: -1.8673
# Epoch [1436] 📊 acc: 0.954 | Targets: 0.8300 | Entropy: -1.8667
# Epoch [1437] 📊 acc: 0.954 | Targets: 0.8313 | Entropy: -1.8669
# Epoch [1438] 📊 acc: 0.955 | Targets: 0.8297 | Entropy: -1.8665
# Epoch [1439] 📊 acc: 0.954 | Targets: 0.8294 | Entropy: -1.8661
# Epoch [1440] 📊 acc: 0.953 | Targets: 0.8318 | Entropy: -1.8667
#
# Evaluating at epoch 1440 …
# Train Accuracy: 95.35%
# Train Average Loss: 0.8309
# Test Accuracy: 94.26%
# Test Average Loss: 0.8424
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.94e-06
# Epoch [1441] 📊 acc: 0.953 | Targets: 0.8314 | Entropy: -1.8667
# Epoch [1442] 📊 acc: 0.953 | Targets: 0.8317 | Entropy: -1.8669
# Epoch [1443] 📊 acc: 0.953 | Targets: 0.8308 | Entropy: -1.8666
# Epoch [1444] 📊 acc: 0.954 | Targets: 0.8313 | Entropy: -1.8669
# Epoch [1445] 📊 acc: 0.953 | Targets: 0.8316 | Entropy: -1.8671
# Epoch [1446] 📊 acc: 0.954 | Targets: 0.8301 | Entropy: -1.8667
# Epoch [1447] 📊 acc: 0.953 | Targets: 0.8326 | Entropy: -1.8671
# Epoch [1448] 📊 acc: 0.954 | Targets: 0.8311 | Entropy: -1.8668
# Epoch [1449] 📊 acc: 0.954 | Targets: 0.8301 | Entropy: -1.8666
# Epoch [1450] 📊 acc: 0.954 | Targets: 0.8307 | Entropy: -1.8666
#
# Evaluating at epoch 1450 …
# Train Accuracy: 95.35%
# Train Average Loss: 0.8316
# Test Accuracy: 94.16%
# Test Average Loss: 0.8433
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.74e-06
# Epoch [1451] 📊 acc: 0.953 | Targets: 0.8317 | Entropy: -1.8666
# Epoch [1452] 📊 acc: 0.954 | Targets: 0.8313 | Entropy: -1.8667
# Epoch [1453] 📊 acc: 0.953 | Targets: 0.8307 | Entropy: -1.8665
# Epoch [1454] 📊 acc: 0.955 | Targets: 0.8290 | Entropy: -1.8664
# Epoch [1455] 📊 acc: 0.955 | Targets: 0.8296 | Entropy: -1.8668
# Epoch [1456] 📊 acc: 0.953 | Targets: 0.8316 | Entropy: -1.8669
# Epoch [1457] 📊 acc: 0.952 | Targets: 0.8327 | Entropy: -1.8669
# Epoch [1458] 📊 acc: 0.953 | Targets: 0.8299 | Entropy: -1.8663
# Epoch [1459] 📊 acc: 0.952 | Targets: 0.8326 | Entropy: -1.8671
# Epoch [1460] 📊 acc: 0.955 | Targets: 0.8279 | Entropy: -1.8663
#
# Evaluating at epoch 1460 …
# Train Accuracy: 95.41%
# Train Average Loss: 0.8322
# Test Accuracy: 94.15%
# Test Average Loss: 0.8438
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.75e-06
# Epoch [1461] 📊 acc: 0.953 | Targets: 0.8314 | Entropy: -1.8667
# Epoch [1462] 📊 acc: 0.952 | Targets: 0.8326 | Entropy: -1.8668
# Epoch [1463] 📊 acc: 0.953 | Targets: 0.8316 | Entropy: -1.8671
# Epoch [1464] 📊 acc: 0.954 | Targets: 0.8303 | Entropy: -1.8665
# Epoch [1465] 📊 acc: 0.954 | Targets: 0.8304 | Entropy: -1.8669
# Epoch [1466] 📊 acc: 0.953 | Targets: 0.8307 | Entropy: -1.8668
# Epoch [1467] 📊 acc: 0.952 | Targets: 0.8314 | Entropy: -1.8667
# Epoch [1468] 📊 acc: 0.954 | Targets: 0.8308 | Entropy: -1.8669
# Epoch [1469] 📊 acc: 0.954 | Targets: 0.8304 | Entropy: -1.8663
# Epoch [1470] 📊 acc: 0.953 | Targets: 0.8316 | Entropy: -1.8668
#
# Evaluating at epoch 1470 …
# Train Accuracy: 95.45%
# Train Average Loss: 0.8302
# Test Accuracy: 94.24%
# Test Average Loss: 0.8432
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.99e-06
# Epoch [1471] 📊 acc: 0.953 | Targets: 0.8329 | Entropy: -1.8672
# Epoch [1472] 📊 acc: 0.953 | Targets: 0.8309 | Entropy: -1.8668
# Epoch [1473] 📊 acc: 0.954 | Targets: 0.8303 | Entropy: -1.8666
# Epoch [1474] 📊 acc: 0.956 | Targets: 0.8283 | Entropy: -1.8666
# Epoch [1475] 📊 acc: 0.953 | Targets: 0.8314 | Entropy: -1.8667
# Epoch [1476] 📊 acc: 0.954 | Targets: 0.8305 | Entropy: -1.8668
# Epoch [1477] 📊 acc: 0.953 | Targets: 0.8323 | Entropy: -1.8670
# Epoch [1478] 📊 acc: 0.954 | Targets: 0.8316 | Entropy: -1.8668
# Epoch [1479] 📊 acc: 0.955 | Targets: 0.8286 | Entropy: -1.8663
# Epoch [1480] 📊 acc: 0.953 | Targets: 0.8328 | Entropy: -1.8674
#
# Evaluating at epoch 1480 …
# Train Accuracy: 95.29%
# Train Average Loss: 0.8322
# Test Accuracy: 94.24%
# Test Average Loss: 0.8430
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.44e-06
# Epoch [1481] 📊 acc: 0.953 | Targets: 0.8318 | Entropy: -1.8673
# Epoch [1482] 📊 acc: 0.953 | Targets: 0.8314 | Entropy: -1.8668
# Epoch [1483] 📊 acc: 0.954 | Targets: 0.8307 | Entropy: -1.8666
# Epoch [1484] 📊 acc: 0.952 | Targets: 0.8327 | Entropy: -1.8667
# Epoch [1485] 📊 acc: 0.953 | Targets: 0.8326 | Entropy: -1.8673
# Epoch [1486] 📊 acc: 0.954 | Targets: 0.8303 | Entropy: -1.8662
# Epoch [1487] 📊 acc: 0.953 | Targets: 0.8321 | Entropy: -1.8671
# Epoch [1488] 📊 acc: 0.955 | Targets: 0.8301 | Entropy: -1.8668
# Epoch [1489] 📊 acc: 0.953 | Targets: 0.8309 | Entropy: -1.8666
# Epoch [1490] 📊 acc: 0.953 | Targets: 0.8322 | Entropy: -1.8672
#
# Evaluating at epoch 1490 …
# Train Accuracy: 95.32%
# Train Average Loss: 0.8324
# Test Accuracy: 94.21%
# Test Average Loss: 0.8428
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.11e-06
# Epoch [1491] 📊 acc: 0.953 | Targets: 0.8329 | Entropy: -1.8669
# Epoch [1492] 📊 acc: 0.952 | Targets: 0.8331 | Entropy: -1.8673
# Epoch [1493] 📊 acc: 0.953 | Targets: 0.8327 | Entropy: -1.8673
# Epoch [1494] 📊 acc: 0.953 | Targets: 0.8332 | Entropy: -1.8669
# Epoch [1495] 📊 acc: 0.954 | Targets: 0.8311 | Entropy: -1.8668
# Epoch [1496] 📊 acc: 0.954 | Targets: 0.8305 | Entropy: -1.8666
# Epoch [1497] 📊 acc: 0.953 | Targets: 0.8310 | Entropy: -1.8668
# Epoch [1498] 📊 acc: 0.953 | Targets: 0.8308 | Entropy: -1.8667
# Epoch [1499] 📊 acc: 0.954 | Targets: 0.8308 | Entropy: -1.8667
# Epoch [1500] 📊 acc: 0.953 | Targets: 0.8323 | Entropy: -1.8670
#
# Evaluating at epoch 1500 …
# Train Accuracy: 95.34%
# Train Average Loss: 0.8317
# Test Accuracy: 94.24%
# Test Average Loss: 0.8427
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-06
# Finished Training
# Best test accuracy achieved: 94.33%
# Total Trainable Parameters: 515,754
