# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth):
        out = self.conv[depth // (self.max_depth // self.num_module)](x, depth)
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        if depth < self.max_depth - 1:
            x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            x = checkpoint(self.step_forward, x, x_prev, d, use_reentrant=False)

        return x

# %%
class RecursionAmplifyConv(nn.Module):
    def __init__(self, channels, height, width):
        super(RecursionAmplifyConv, self).__init__()
        
        self.conv0 = nn.Conv2d(3, channels, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(channels, max_depth=32, num_module=1)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))


    def forward(self, x):
        
        x = self.conv0(x)

        x = self.amconv(x)

        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.reamconv= RecursionAmplifyConv(512, 32, 32)

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.reamconv(x)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        return x

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 1)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        pre_entropy = torch.sum(pre_probs * torch.log(pre_probs), dim=1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_pre_entropy = torch.sum(old_pre_probs * torch.log(old_pre_probs), dim=1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        ref_entropy = torch.sum(ref_probs * torch.log(ref_probs), dim=1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_ref_entropy = torch.sum(old_ref_probs * torch.log(old_ref_probs), dim=1)

        rewards, correct = self.compute_reconstruct_reward(outputs, targets)
        p_rewards, _ = self.compute_positive_reward(outputs, targets)
        n_rewards, _ = self.compute_negative_reward(outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        entropy_delta = (entropy - old_entropy)
        pre_entropy_delta = (pre_entropy - old_pre_entropy)
        ref_entropy_delta = (ref_entropy - old_ref_entropy)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
                'entropy': entropy.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)

    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()

    all_params = list(net.parameters()) + list(pre_net.parameters())
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    ref_accuracy = 0.0
    pre_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    ref_count = 32
    d = 0
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=300, eta_min=1e-6
            )

        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
            'rewards_mean': 0.0, 'rewards_std': 0.0, 
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs = net(inputs)
                ref_outputs = ref_net(inputs)
                pre_outputs = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_ratio = F.relu(pre_select_delta) + F.sigmoid(select_delta) - F.sigmoid(ref_select_delta)
                select_loss = select_ratio.sum()
                
                entropy_ratio = F.relu(pre_entropy_delta) +  F.sigmoid(entropy_delta) - F.sigmoid(ref_entropy_delta)
                entropy_loss = entropy_ratio.sum()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(all_params, max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f}")

        if running_cor > ref_accuracy:
            ref_accuracy = running_cor
            ref = copy.deepcopy(net).to(device)
            if d % 2 == 0:
                prev_ref.append(ref)
                prev_ref = prev_ref[-ref_count:]
            ref_net = prev_ref[((d % ref_count + 1) - ((d % ref_count + 1) & -(d % ref_count + 1))) // 2]
            d += 1
            print(f"New ref model saved")

        if running_cor > pre_accuracy:
            pre_accuracy = running_cor
            pre_net = copy.deepcopy(net).to(device)
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
                    if use_bf16 else contextlib.nullcontext())

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = net(images)  
            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum    += batch_loss.item() * bs
            total_seen  += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 515,754

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.319 | Targets: 1.9788 | Entropy: -2.1682
# New ref model saved
# Epoch [2] 📊 acc: 0.491 | Targets: 1.6767 | Entropy: -2.0808
# New ref model saved
# Epoch [3] 📊 acc: 0.568 | Targets: 1.5484 | Entropy: -2.0411
# New ref model saved
# Epoch [4] 📊 acc: 0.614 | Targets: 1.4653 | Entropy: -2.0169
# New ref model saved
# Epoch [5] 📊 acc: 0.651 | Targets: 1.4032 | Entropy: -1.9991
# New ref model saved
# Epoch [6] 📊 acc: 0.679 | Targets: 1.3545 | Entropy: -1.9853
# New ref model saved
# Epoch [7] 📊 acc: 0.700 | Targets: 1.3185 | Entropy: -1.9762
# New ref model saved
# Epoch [8] 📊 acc: 0.715 | Targets: 1.2898 | Entropy: -1.9686
# New ref model saved
# Epoch [9] 📊 acc: 0.727 | Targets: 1.2645 | Entropy: -1.9623
# New ref model saved
# Epoch [10] 📊 acc: 0.738 | Targets: 1.2433 | Entropy: -1.9581
# New ref model saved
#
# Evaluating at epoch 10 …
# Train Accuracy: 73.44%
# Train Average Loss: 1.2811
# Test Accuracy: 79.05%
# Test Average Loss: 1.1899
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 79.05%
# Epoch [11] 📊 acc: 0.745 | Targets: 1.2296 | Entropy: -1.9538
# New ref model saved
# Epoch [12] 📊 acc: 0.750 | Targets: 1.2154 | Entropy: -1.9511
# New ref model saved
# Epoch [13] 📊 acc: 0.765 | Targets: 1.1953 | Entropy: -1.9461
# New ref model saved
# Epoch [14] 📊 acc: 0.770 | Targets: 1.1821 | Entropy: -1.9435
# New ref model saved
# Epoch [15] 📊 acc: 0.772 | Targets: 1.1749 | Entropy: -1.9419
# New ref model saved
# Epoch [16] 📊 acc: 0.780 | Targets: 1.1620 | Entropy: -1.9393
# New ref model saved
# Epoch [17] 📊 acc: 0.783 | Targets: 1.1545 | Entropy: -1.9370
# New ref model saved
# Epoch [18] 📊 acc: 0.789 | Targets: 1.1445 | Entropy: -1.9350
# New ref model saved
# Epoch [19] 📊 acc: 0.794 | Targets: 1.1354 | Entropy: -1.9328
# New ref model saved
# Epoch [20] 📊 acc: 0.797 | Targets: 1.1284 | Entropy: -1.9309
# New ref model saved
#
# Evaluating at epoch 20 …
# Train Accuracy: 79.85%
# Train Average Loss: 1.1455
# Test Accuracy: 84.58%
# Test Average Loss: 1.0552
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 84.58%
# Epoch [21] 📊 acc: 0.803 | Targets: 1.1182 | Entropy: -1.9287
# New ref model saved
# Epoch [22] 📊 acc: 0.801 | Targets: 1.1159 | Entropy: -1.9290
# Epoch [23] 📊 acc: 0.808 | Targets: 1.1066 | Entropy: -1.9262
# New ref model saved
# Epoch [24] 📊 acc: 0.809 | Targets: 1.1025 | Entropy: -1.9249
# New ref model saved
# Epoch [25] 📊 acc: 0.810 | Targets: 1.1019 | Entropy: -1.9262
# New ref model saved
# Epoch [26] 📊 acc: 0.815 | Targets: 1.0910 | Entropy: -1.9231
# New ref model saved
# Epoch [27] 📊 acc: 0.819 | Targets: 1.0869 | Entropy: -1.9229
# New ref model saved
# Epoch [28] 📊 acc: 0.821 | Targets: 1.0811 | Entropy: -1.9213
# New ref model saved
# Epoch [29] 📊 acc: 0.823 | Targets: 1.0757 | Entropy: -1.9199
# New ref model saved
# Epoch [30] 📊 acc: 0.825 | Targets: 1.0737 | Entropy: -1.9191
# New ref model saved
#
# Evaluating at epoch 30 …
# Train Accuracy: 82.86%
# Train Average Loss: 1.0812
# Test Accuracy: 86.93%
# Test Average Loss: 0.9978
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 86.93%
# Epoch [31] 📊 acc: 0.826 | Targets: 1.0731 | Entropy: -1.9202
# New ref model saved
# Epoch [32] 📊 acc: 0.828 | Targets: 1.0657 | Entropy: -1.9179
# New ref model saved
# Epoch [33] 📊 acc: 0.835 | Targets: 1.0571 | Entropy: -1.9156
# New ref model saved
# Epoch [34] 📊 acc: 0.835 | Targets: 1.0554 | Entropy: -1.9157
# New ref model saved
# Epoch [35] 📊 acc: 0.836 | Targets: 1.0538 | Entropy: -1.9156
# New ref model saved
# Epoch [36] 📊 acc: 0.837 | Targets: 1.0512 | Entropy: -1.9154
# New ref model saved
# Epoch [37] 📊 acc: 0.839 | Targets: 1.0456 | Entropy: -1.9136
# New ref model saved
# Epoch [38] 📊 acc: 0.840 | Targets: 1.0410 | Entropy: -1.9119
# New ref model saved
# Epoch [39] 📊 acc: 0.843 | Targets: 1.0398 | Entropy: -1.9124
# New ref model saved
# Epoch [40] 📊 acc: 0.844 | Targets: 1.0373 | Entropy: -1.9118
# New ref model saved
#
# Evaluating at epoch 40 …
# Train Accuracy: 84.44%
# Train Average Loss: 1.0352
# Test Accuracy: 88.20%
# Test Average Loss: 0.9581
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 88.20%
# Epoch [41] 📊 acc: 0.847 | Targets: 1.0305 | Entropy: -1.9100
# New ref model saved
# Epoch [42] 📊 acc: 0.848 | Targets: 1.0293 | Entropy: -1.9096
# New ref model saved
# Epoch [43] 📊 acc: 0.849 | Targets: 1.0264 | Entropy: -1.9093
# New ref model saved
# Epoch [44] 📊 acc: 0.850 | Targets: 1.0253 | Entropy: -1.9093
# New ref model saved
# Epoch [45] 📊 acc: 0.851 | Targets: 1.0256 | Entropy: -1.9092
# New ref model saved
# Epoch [46] 📊 acc: 0.852 | Targets: 1.0227 | Entropy: -1.9094
# New ref model saved
# Epoch [47] 📊 acc: 0.855 | Targets: 1.0185 | Entropy: -1.9078
# New ref model saved
# Epoch [48] 📊 acc: 0.855 | Targets: 1.0155 | Entropy: -1.9072
# Epoch [49] 📊 acc: 0.857 | Targets: 1.0145 | Entropy: -1.9071
# New ref model saved
# Epoch [50] 📊 acc: 0.860 | Targets: 1.0064 | Entropy: -1.9044
# New ref model saved
#
# Evaluating at epoch 50 …
# Train Accuracy: 85.82%
# Train Average Loss: 1.0231
# Test Accuracy: 88.91%
# Test Average Loss: 0.9610
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.33e-04
# New best model saved with test accuracy: 88.91%
# Epoch [51] 📊 acc: 0.858 | Targets: 1.0069 | Entropy: -1.9051
# Epoch [52] 📊 acc: 0.862 | Targets: 1.0061 | Entropy: -1.9055
# New ref model saved
# Epoch [53] 📊 acc: 0.861 | Targets: 1.0038 | Entropy: -1.9047
# Epoch [54] 📊 acc: 0.865 | Targets: 0.9965 | Entropy: -1.9024
# New ref model saved
# Epoch [55] 📊 acc: 0.865 | Targets: 0.9987 | Entropy: -1.9038
# Epoch [56] 📊 acc: 0.863 | Targets: 1.0007 | Entropy: -1.9043
# Epoch [57] 📊 acc: 0.866 | Targets: 0.9938 | Entropy: -1.9021
# New ref model saved
# Epoch [58] 📊 acc: 0.866 | Targets: 0.9952 | Entropy: -1.9031
# Epoch [59] 📊 acc: 0.866 | Targets: 0.9911 | Entropy: -1.9018
# New ref model saved
# Epoch [60] 📊 acc: 0.870 | Targets: 0.9892 | Entropy: -1.9019
# New ref model saved
#
# Evaluating at epoch 60 …
# Train Accuracy: 87.49%
# Train Average Loss: 0.9715
# Test Accuracy: 89.78%
# Test Average Loss: 0.9122
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 89.78%
# Epoch [61] 📊 acc: 0.872 | Targets: 0.9861 | Entropy: -1.9004
# New ref model saved
# Epoch [62] 📊 acc: 0.872 | Targets: 0.9845 | Entropy: -1.9005
# Epoch [63] 📊 acc: 0.874 | Targets: 0.9820 | Entropy: -1.8999
# New ref model saved
# Epoch [64] 📊 acc: 0.872 | Targets: 0.9852 | Entropy: -1.9010
# Epoch [65] 📊 acc: 0.873 | Targets: 0.9831 | Entropy: -1.9008
# Epoch [66] 📊 acc: 0.875 | Targets: 0.9761 | Entropy: -1.8989
# New ref model saved
# Epoch [67] 📊 acc: 0.876 | Targets: 0.9761 | Entropy: -1.8988
# New ref model saved
# Epoch [68] 📊 acc: 0.878 | Targets: 0.9746 | Entropy: -1.8988
# New ref model saved
# Epoch [69] 📊 acc: 0.877 | Targets: 0.9759 | Entropy: -1.8987
# Epoch [70] 📊 acc: 0.878 | Targets: 0.9725 | Entropy: -1.8981
#
# Evaluating at epoch 70 …
# Train Accuracy: 87.72%
# Train Average Loss: 0.9790
# Test Accuracy: 89.95%
# Test Average Loss: 0.9196
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.72e-04
# New best model saved with test accuracy: 89.95%
# Epoch [71] 📊 acc: 0.877 | Targets: 0.9728 | Entropy: -1.8981
# Epoch [72] 📊 acc: 0.879 | Targets: 0.9704 | Entropy: -1.8979
# New ref model saved
# Epoch [73] 📊 acc: 0.881 | Targets: 0.9683 | Entropy: -1.8974
# New ref model saved
# Epoch [74] 📊 acc: 0.881 | Targets: 0.9666 | Entropy: -1.8968
# New ref model saved
# Epoch [75] 📊 acc: 0.881 | Targets: 0.9663 | Entropy: -1.8970
# Epoch [76] 📊 acc: 0.885 | Targets: 0.9609 | Entropy: -1.8953
# New ref model saved
# Epoch [77] 📊 acc: 0.885 | Targets: 0.9601 | Entropy: -1.8953
# Epoch [78] 📊 acc: 0.886 | Targets: 0.9579 | Entropy: -1.8949
# New ref model saved
# Epoch [79] 📊 acc: 0.888 | Targets: 0.9582 | Entropy: -1.8949
# New ref model saved
# Epoch [80] 📊 acc: 0.887 | Targets: 0.9573 | Entropy: -1.8950
#
# Evaluating at epoch 80 …
# Train Accuracy: 88.77%
# Train Average Loss: 0.9626
# Test Accuracy: 90.99%
# Test Average Loss: 0.9025
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.35e-04
# New best model saved with test accuracy: 90.99%
# Epoch [81] 📊 acc: 0.889 | Targets: 0.9543 | Entropy: -1.8939
# New ref model saved
# Epoch [82] 📊 acc: 0.888 | Targets: 0.9549 | Entropy: -1.8942
# Epoch [83] 📊 acc: 0.888 | Targets: 0.9540 | Entropy: -1.8944
# Epoch [84] 📊 acc: 0.891 | Targets: 0.9465 | Entropy: -1.8918
# New ref model saved
# Epoch [85] 📊 acc: 0.889 | Targets: 0.9519 | Entropy: -1.8936
# Epoch [86] 📊 acc: 0.890 | Targets: 0.9488 | Entropy: -1.8934
# Epoch [87] 📊 acc: 0.891 | Targets: 0.9484 | Entropy: -1.8932
# Epoch [88] 📊 acc: 0.892 | Targets: 0.9443 | Entropy: -1.8912
# New ref model saved
# Epoch [89] 📊 acc: 0.893 | Targets: 0.9470 | Entropy: -1.8927
# New ref model saved
# Epoch [90] 📊 acc: 0.896 | Targets: 0.9417 | Entropy: -1.8912
# New ref model saved
#
# Evaluating at epoch 90 …
# Train Accuracy: 90.03%
# Train Average Loss: 0.9492
# Test Accuracy: 91.40%
# Test Average Loss: 0.9076
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.94e-04
# New best model saved with test accuracy: 91.40%
# Epoch [91] 📊 acc: 0.895 | Targets: 0.9418 | Entropy: -1.8914
# Epoch [92] 📊 acc: 0.894 | Targets: 0.9438 | Entropy: -1.8921
# Epoch [93] 📊 acc: 0.895 | Targets: 0.9395 | Entropy: -1.8904
# Epoch [94] 📊 acc: 0.897 | Targets: 0.9397 | Entropy: -1.8907
# New ref model saved
# Epoch [95] 📊 acc: 0.898 | Targets: 0.9351 | Entropy: -1.8897
# New ref model saved
# Epoch [96] 📊 acc: 0.898 | Targets: 0.9334 | Entropy: -1.8891
# Epoch [97] 📊 acc: 0.899 | Targets: 0.9350 | Entropy: -1.8897
# New ref model saved
# Epoch [98] 📊 acc: 0.899 | Targets: 0.9333 | Entropy: -1.8893
# New ref model saved
# Epoch [99] 📊 acc: 0.898 | Targets: 0.9345 | Entropy: -1.8899
# Epoch [100] 📊 acc: 0.900 | Targets: 0.9300 | Entropy: -1.8882
# New ref model saved
#
# Evaluating at epoch 100 …
# Train Accuracy: 90.58%
# Train Average Loss: 0.9263
# Test Accuracy: 92.03%
# Test Average Loss: 0.8918
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.50e-04
# New best model saved with test accuracy: 92.03%
# Epoch [101] 📊 acc: 0.899 | Targets: 0.9324 | Entropy: -1.8896
# Epoch [102] 📊 acc: 0.901 | Targets: 0.9316 | Entropy: -1.8888
# New ref model saved
# Epoch [103] 📊 acc: 0.901 | Targets: 0.9291 | Entropy: -1.8884
# Epoch [104] 📊 acc: 0.901 | Targets: 0.9289 | Entropy: -1.8883
# New ref model saved
# Epoch [105] 📊 acc: 0.902 | Targets: 0.9262 | Entropy: -1.8875
# New ref model saved
# Epoch [106] 📊 acc: 0.903 | Targets: 0.9250 | Entropy: -1.8873
# New ref model saved
# Epoch [107] 📊 acc: 0.904 | Targets: 0.9244 | Entropy: -1.8875
# New ref model saved
# Epoch [108] 📊 acc: 0.906 | Targets: 0.9200 | Entropy: -1.8863
# New ref model saved
# Epoch [109] 📊 acc: 0.905 | Targets: 0.9221 | Entropy: -1.8867
# Epoch [110] 📊 acc: 0.905 | Targets: 0.9231 | Entropy: -1.8870
#
# Evaluating at epoch 110 …
# Train Accuracy: 90.85%
# Train Average Loss: 0.9160
# Test Accuracy: 92.21%
# Test Average Loss: 0.8794
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.04e-04
# New best model saved with test accuracy: 92.21%
# Epoch [111] 📊 acc: 0.907 | Targets: 0.9181 | Entropy: -1.8859
# New ref model saved
# Epoch [112] 📊 acc: 0.908 | Targets: 0.9158 | Entropy: -1.8849
# New ref model saved
# Epoch [113] 📊 acc: 0.905 | Targets: 0.9212 | Entropy: -1.8864
# Epoch [114] 📊 acc: 0.909 | Targets: 0.9154 | Entropy: -1.8851
# New ref model saved
# Epoch [115] 📊 acc: 0.907 | Targets: 0.9177 | Entropy: -1.8858
# Epoch [116] 📊 acc: 0.910 | Targets: 0.9138 | Entropy: -1.8850
# New ref model saved
# Epoch [117] 📊 acc: 0.910 | Targets: 0.9131 | Entropy: -1.8848
# Epoch [118] 📊 acc: 0.909 | Targets: 0.9136 | Entropy: -1.8844
# Epoch [119] 📊 acc: 0.909 | Targets: 0.9147 | Entropy: -1.8851
# Epoch [120] 📊 acc: 0.910 | Targets: 0.9123 | Entropy: -1.8848
#
# Evaluating at epoch 120 …
# Train Accuracy: 91.64%
# Train Average Loss: 0.8891
# Test Accuracy: 92.71%
# Test Average Loss: 0.8631
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.55e-04
# New best model saved with test accuracy: 92.71%
# Epoch [121] 📊 acc: 0.911 | Targets: 0.9124 | Entropy: -1.8849
# New ref model saved
# Epoch [122] 📊 acc: 0.912 | Targets: 0.9082 | Entropy: -1.8836
# New ref model saved
# Epoch [123] 📊 acc: 0.913 | Targets: 0.9091 | Entropy: -1.8837
# New ref model saved
# Epoch [124] 📊 acc: 0.914 | Targets: 0.9046 | Entropy: -1.8825
# New ref model saved
# Epoch [125] 📊 acc: 0.915 | Targets: 0.9040 | Entropy: -1.8822
# New ref model saved
# Epoch [126] 📊 acc: 0.916 | Targets: 0.9028 | Entropy: -1.8822
# New ref model saved
# Epoch [127] 📊 acc: 0.917 | Targets: 0.9016 | Entropy: -1.8819
# New ref model saved
# Epoch [128] 📊 acc: 0.914 | Targets: 0.9052 | Entropy: -1.8828
# Epoch [129] 📊 acc: 0.916 | Targets: 0.9025 | Entropy: -1.8821
# Epoch [130] 📊 acc: 0.918 | Targets: 0.8995 | Entropy: -1.8814
# New ref model saved
#
# Evaluating at epoch 130 …
# Train Accuracy: 91.91%
# Train Average Loss: 0.8996
# Test Accuracy: 92.61%
# Test Average Loss: 0.8752
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.04e-04
# Epoch [131] 📊 acc: 0.916 | Targets: 0.8993 | Entropy: -1.8812
# Epoch [132] 📊 acc: 0.918 | Targets: 0.8992 | Entropy: -1.8814
# New ref model saved
# Epoch [133] 📊 acc: 0.917 | Targets: 0.8999 | Entropy: -1.8821
# Epoch [134] 📊 acc: 0.917 | Targets: 0.8985 | Entropy: -1.8809
# Epoch [135] 📊 acc: 0.920 | Targets: 0.8956 | Entropy: -1.8805
# New ref model saved
# Epoch [136] 📊 acc: 0.920 | Targets: 0.8946 | Entropy: -1.8806
# New ref model saved
# Epoch [137] 📊 acc: 0.918 | Targets: 0.8966 | Entropy: -1.8808
# Epoch [138] 📊 acc: 0.919 | Targets: 0.8969 | Entropy: -1.8810
# Epoch [139] 📊 acc: 0.921 | Targets: 0.8945 | Entropy: -1.8804
# New ref model saved
# Epoch [140] 📊 acc: 0.919 | Targets: 0.8942 | Entropy: -1.8802
#
# Evaluating at epoch 140 …
# Train Accuracy: 92.18%
# Train Average Loss: 0.8803
# Test Accuracy: 92.57%
# Test Average Loss: 0.8673
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.53e-04
# Epoch [141] 📊 acc: 0.921 | Targets: 0.8917 | Entropy: -1.8793
# New ref model saved
# Epoch [142] 📊 acc: 0.921 | Targets: 0.8926 | Entropy: -1.8803
# Epoch [143] 📊 acc: 0.923 | Targets: 0.8901 | Entropy: -1.8791
# New ref model saved
# Epoch [144] 📊 acc: 0.921 | Targets: 0.8913 | Entropy: -1.8802
# Epoch [145] 📊 acc: 0.923 | Targets: 0.8898 | Entropy: -1.8793
# New ref model saved
# Epoch [146] 📊 acc: 0.924 | Targets: 0.8882 | Entropy: -1.8790
# New ref model saved
# Epoch [147] 📊 acc: 0.924 | Targets: 0.8851 | Entropy: -1.8782
# New ref model saved
# Epoch [148] 📊 acc: 0.923 | Targets: 0.8896 | Entropy: -1.8793
# Epoch [149] 📊 acc: 0.925 | Targets: 0.8856 | Entropy: -1.8781
# New ref model saved
# Epoch [150] 📊 acc: 0.926 | Targets: 0.8836 | Entropy: -1.8778
# New ref model saved
#
# Evaluating at epoch 150 …
# Train Accuracy: 92.66%
# Train Average Loss: 0.8785
# Test Accuracy: 92.85%
# Test Average Loss: 0.8667
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.01e-04
# New best model saved with test accuracy: 92.85%
# Epoch [151] 📊 acc: 0.927 | Targets: 0.8836 | Entropy: -1.8777
# New ref model saved
# Epoch [152] 📊 acc: 0.926 | Targets: 0.8835 | Entropy: -1.8777
# Epoch [153] 📊 acc: 0.928 | Targets: 0.8817 | Entropy: -1.8774
# New ref model saved
# Epoch [154] 📊 acc: 0.928 | Targets: 0.8800 | Entropy: -1.8768
# Epoch [155] 📊 acc: 0.928 | Targets: 0.8800 | Entropy: -1.8769
# Epoch [156] 📊 acc: 0.929 | Targets: 0.8783 | Entropy: -1.8764
# New ref model saved
# Epoch [157] 📊 acc: 0.929 | Targets: 0.8786 | Entropy: -1.8768
# Epoch [158] 📊 acc: 0.926 | Targets: 0.8806 | Entropy: -1.8771
# Epoch [159] 📊 acc: 0.929 | Targets: 0.8781 | Entropy: -1.8762
# Epoch [160] 📊 acc: 0.931 | Targets: 0.8746 | Entropy: -1.8756
# New ref model saved
#
# Evaluating at epoch 160 …
# Train Accuracy: 93.07%
# Train Average Loss: 0.8781
# Test Accuracy: 92.71%
# Test Average Loss: 0.8685
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.48e-04
# Epoch [161] 📊 acc: 0.929 | Targets: 0.8777 | Entropy: -1.8766
# Epoch [162] 📊 acc: 0.931 | Targets: 0.8719 | Entropy: -1.8749
# New ref model saved
# Epoch [163] 📊 acc: 0.929 | Targets: 0.8772 | Entropy: -1.8764
# Epoch [164] 📊 acc: 0.931 | Targets: 0.8767 | Entropy: -1.8763
# Epoch [165] 📊 acc: 0.929 | Targets: 0.8755 | Entropy: -1.8760
# Epoch [166] 📊 acc: 0.930 | Targets: 0.8731 | Entropy: -1.8754
# Epoch [167] 📊 acc: 0.933 | Targets: 0.8707 | Entropy: -1.8749
# New ref model saved
# Epoch [168] 📊 acc: 0.935 | Targets: 0.8673 | Entropy: -1.8737
# New ref model saved
# Epoch [169] 📊 acc: 0.931 | Targets: 0.8743 | Entropy: -1.8760
# Epoch [170] 📊 acc: 0.933 | Targets: 0.8694 | Entropy: -1.8746
#
# Evaluating at epoch 170 …
# Train Accuracy: 93.03%
# Train Average Loss: 0.8674
# Test Accuracy: 93.20%
# Test Average Loss: 0.8565
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.97e-04
# New best model saved with test accuracy: 93.20%
# Epoch [171] 📊 acc: 0.933 | Targets: 0.8715 | Entropy: -1.8750
# Epoch [172] 📊 acc: 0.934 | Targets: 0.8674 | Entropy: -1.8740
# Epoch [173] 📊 acc: 0.935 | Targets: 0.8674 | Entropy: -1.8742
# Epoch [174] 📊 acc: 0.933 | Targets: 0.8700 | Entropy: -1.8746
# Epoch [175] 📊 acc: 0.935 | Targets: 0.8675 | Entropy: -1.8743
# New ref model saved
# Epoch [176] 📊 acc: 0.936 | Targets: 0.8648 | Entropy: -1.8734
# New ref model saved
# Epoch [177] 📊 acc: 0.936 | Targets: 0.8633 | Entropy: -1.8729
# New ref model saved
# Epoch [178] 📊 acc: 0.936 | Targets: 0.8658 | Entropy: -1.8737
# Epoch [179] 📊 acc: 0.936 | Targets: 0.8634 | Entropy: -1.8731
# Epoch [180] 📊 acc: 0.936 | Targets: 0.8641 | Entropy: -1.8732
# New ref model saved
#
# Evaluating at epoch 180 …
# Train Accuracy: 93.94%
# Train Average Loss: 0.8604
# Test Accuracy: 93.32%
# Test Average Loss: 0.8590
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.46e-04
# New best model saved with test accuracy: 93.32%
# Epoch [181] 📊 acc: 0.938 | Targets: 0.8605 | Entropy: -1.8723
# New ref model saved
# Epoch [182] 📊 acc: 0.938 | Targets: 0.8626 | Entropy: -1.8728
# New ref model saved
# Epoch [183] 📊 acc: 0.939 | Targets: 0.8602 | Entropy: -1.8725
# New ref model saved
# Epoch [184] 📊 acc: 0.938 | Targets: 0.8618 | Entropy: -1.8726
# Epoch [185] 📊 acc: 0.938 | Targets: 0.8608 | Entropy: -1.8731
# Epoch [186] 📊 acc: 0.940 | Targets: 0.8567 | Entropy: -1.8714
# New ref model saved
# Epoch [187] 📊 acc: 0.940 | Targets: 0.8591 | Entropy: -1.8719
# Epoch [188] 📊 acc: 0.940 | Targets: 0.8577 | Entropy: -1.8720
# New ref model saved
# Epoch [189] 📊 acc: 0.939 | Targets: 0.8582 | Entropy: -1.8722
# Epoch [190] 📊 acc: 0.939 | Targets: 0.8573 | Entropy: -1.8716
#
# Evaluating at epoch 190 …
# Train Accuracy: 94.12%
# Train Average Loss: 0.8552
# Test Accuracy: 93.42%
# Test Average Loss: 0.8548
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.97e-04
# New best model saved with test accuracy: 93.42%
# Epoch [191] 📊 acc: 0.941 | Targets: 0.8560 | Entropy: -1.8716
# New ref model saved
# Epoch [192] 📊 acc: 0.940 | Targets: 0.8575 | Entropy: -1.8721
# Epoch [193] 📊 acc: 0.942 | Targets: 0.8520 | Entropy: -1.8703
# New ref model saved
# Epoch [194] 📊 acc: 0.941 | Targets: 0.8560 | Entropy: -1.8717
# Epoch [195] 📊 acc: 0.943 | Targets: 0.8539 | Entropy: -1.8708
# New ref model saved
# Epoch [196] 📊 acc: 0.942 | Targets: 0.8529 | Entropy: -1.8704
# Epoch [197] 📊 acc: 0.942 | Targets: 0.8532 | Entropy: -1.8706
# Epoch [198] 📊 acc: 0.945 | Targets: 0.8493 | Entropy: -1.8697
# New ref model saved
# Epoch [199] 📊 acc: 0.943 | Targets: 0.8513 | Entropy: -1.8700
# Epoch [200] 📊 acc: 0.943 | Targets: 0.8516 | Entropy: -1.8706
#
# Evaluating at epoch 200 …
# Train Accuracy: 94.35%
# Train Average Loss: 0.8485
# Test Accuracy: 93.54%
# Test Average Loss: 0.8500
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.51e-04
# New best model saved with test accuracy: 93.54%
# Epoch [201] 📊 acc: 0.944 | Targets: 0.8490 | Entropy: -1.8696
# Epoch [202] 📊 acc: 0.943 | Targets: 0.8513 | Entropy: -1.8706
# Epoch [203] 📊 acc: 0.945 | Targets: 0.8473 | Entropy: -1.8689
# New ref model saved
# Epoch [204] 📊 acc: 0.944 | Targets: 0.8496 | Entropy: -1.8700
# Epoch [205] 📊 acc: 0.944 | Targets: 0.8480 | Entropy: -1.8692
# Epoch [206] 📊 acc: 0.944 | Targets: 0.8481 | Entropy: -1.8698
# Epoch [207] 📊 acc: 0.945 | Targets: 0.8492 | Entropy: -1.8698
# Epoch [208] 📊 acc: 0.945 | Targets: 0.8459 | Entropy: -1.8688
# Epoch [209] 📊 acc: 0.946 | Targets: 0.8464 | Entropy: -1.8691
# New ref model saved
# Epoch [210] 📊 acc: 0.946 | Targets: 0.8456 | Entropy: -1.8690
# New ref model saved
#
# Evaluating at epoch 210 …
# Train Accuracy: 94.66%
# Train Average Loss: 0.8421
# Test Accuracy: 94.05%
# Test Average Loss: 0.8453
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.07e-04
# New best model saved with test accuracy: 94.05%
# Epoch [211] 📊 acc: 0.946 | Targets: 0.8456 | Entropy: -1.8690
# Epoch [212] 📊 acc: 0.947 | Targets: 0.8452 | Entropy: -1.8687
# New ref model saved
# Epoch [213] 📊 acc: 0.946 | Targets: 0.8458 | Entropy: -1.8691
# Epoch [214] 📊 acc: 0.947 | Targets: 0.8424 | Entropy: -1.8679
# New ref model saved
# Epoch [215] 📊 acc: 0.948 | Targets: 0.8423 | Entropy: -1.8682
# New ref model saved
# Epoch [216] 📊 acc: 0.948 | Targets: 0.8416 | Entropy: -1.8679
# New ref model saved
# Epoch [217] 📊 acc: 0.950 | Targets: 0.8389 | Entropy: -1.8672
# New ref model saved
# Epoch [218] 📊 acc: 0.946 | Targets: 0.8449 | Entropy: -1.8685
# Epoch [219] 📊 acc: 0.949 | Targets: 0.8405 | Entropy: -1.8680
# Epoch [220] 📊 acc: 0.948 | Targets: 0.8411 | Entropy: -1.8677
#
# Evaluating at epoch 220 …
# Train Accuracy: 94.86%
# Train Average Loss: 0.8429
# Test Accuracy: 93.94%
# Test Average Loss: 0.8526
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.66e-04
# Epoch [221] 📊 acc: 0.950 | Targets: 0.8378 | Entropy: -1.8670
# New ref model saved
# Epoch [222] 📊 acc: 0.949 | Targets: 0.8410 | Entropy: -1.8679
# Epoch [223] 📊 acc: 0.947 | Targets: 0.8432 | Entropy: -1.8686
# Epoch [224] 📊 acc: 0.951 | Targets: 0.8350 | Entropy: -1.8659
# New ref model saved
# Epoch [225] 📊 acc: 0.949 | Targets: 0.8394 | Entropy: -1.8672
# Epoch [226] 📊 acc: 0.949 | Targets: 0.8397 | Entropy: -1.8677
# Epoch [227] 📊 acc: 0.950 | Targets: 0.8376 | Entropy: -1.8670
# Epoch [228] 📊 acc: 0.951 | Targets: 0.8377 | Entropy: -1.8670
# New ref model saved
# Epoch [229] 📊 acc: 0.950 | Targets: 0.8388 | Entropy: -1.8672
# Epoch [230] 📊 acc: 0.951 | Targets: 0.8358 | Entropy: -1.8667
#
# Evaluating at epoch 230 …
# Train Accuracy: 95.10%
# Train Average Loss: 0.8382
# Test Accuracy: 93.90%
# Test Average Loss: 0.8512
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.29e-04
# Epoch [231] 📊 acc: 0.951 | Targets: 0.8385 | Entropy: -1.8675
# Epoch [232] 📊 acc: 0.951 | Targets: 0.8347 | Entropy: -1.8660
# New ref model saved
# Epoch [233] 📊 acc: 0.951 | Targets: 0.8350 | Entropy: -1.8663
# Epoch [234] 📊 acc: 0.953 | Targets: 0.8318 | Entropy: -1.8653
# New ref model saved
# Epoch [235] 📊 acc: 0.949 | Targets: 0.8395 | Entropy: -1.8676
# Epoch [236] 📊 acc: 0.951 | Targets: 0.8345 | Entropy: -1.8664
# Epoch [237] 📊 acc: 0.952 | Targets: 0.8339 | Entropy: -1.8659
# Epoch [238] 📊 acc: 0.951 | Targets: 0.8353 | Entropy: -1.8663
# Epoch [239] 📊 acc: 0.953 | Targets: 0.8307 | Entropy: -1.8650
# New ref model saved
# Epoch [240] 📊 acc: 0.953 | Targets: 0.8328 | Entropy: -1.8658
#
# Evaluating at epoch 240 …
# Train Accuracy: 95.32%
# Train Average Loss: 0.8313
# Test Accuracy: 94.16%
# Test Average Loss: 0.8447
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.64e-05
# New best model saved with test accuracy: 94.16%
# Epoch [241] 📊 acc: 0.952 | Targets: 0.8340 | Entropy: -1.8664
# Epoch [242] 📊 acc: 0.952 | Targets: 0.8333 | Entropy: -1.8657
# Epoch [243] 📊 acc: 0.953 | Targets: 0.8330 | Entropy: -1.8659
# Epoch [244] 📊 acc: 0.953 | Targets: 0.8332 | Entropy: -1.8660
# Epoch [245] 📊 acc: 0.955 | Targets: 0.8299 | Entropy: -1.8650
# New ref model saved
# Epoch [246] 📊 acc: 0.953 | Targets: 0.8301 | Entropy: -1.8649
# Epoch [247] 📊 acc: 0.954 | Targets: 0.8313 | Entropy: -1.8656
# Epoch [248] 📊 acc: 0.954 | Targets: 0.8305 | Entropy: -1.8653
# Epoch [249] 📊 acc: 0.955 | Targets: 0.8296 | Entropy: -1.8652
# Epoch [250] 📊 acc: 0.954 | Targets: 0.8295 | Entropy: -1.8649
#
# Evaluating at epoch 250 …
# Train Accuracy: 95.41%
# Train Average Loss: 0.8288
# Test Accuracy: 94.15%
# Test Average Loss: 0.8430
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.79e-05
# Epoch [251] 📊 acc: 0.954 | Targets: 0.8319 | Entropy: -1.8658
# Epoch [252] 📊 acc: 0.955 | Targets: 0.8283 | Entropy: -1.8648
# Epoch [253] 📊 acc: 0.955 | Targets: 0.8287 | Entropy: -1.8649
# New ref model saved
# Epoch [254] 📊 acc: 0.953 | Targets: 0.8300 | Entropy: -1.8649
# Epoch [255] 📊 acc: 0.954 | Targets: 0.8297 | Entropy: -1.8653
# Epoch [256] 📊 acc: 0.955 | Targets: 0.8284 | Entropy: -1.8648
# Epoch [257] 📊 acc: 0.955 | Targets: 0.8304 | Entropy: -1.8655
# Epoch [258] 📊 acc: 0.954 | Targets: 0.8307 | Entropy: -1.8655
# Epoch [259] 📊 acc: 0.954 | Targets: 0.8295 | Entropy: -1.8651
# Epoch [260] 📊 acc: 0.955 | Targets: 0.8282 | Entropy: -1.8646
#
# Evaluating at epoch 260 …
# Train Accuracy: 95.37%
# Train Average Loss: 0.8322
# Test Accuracy: 94.31%
# Test Average Loss: 0.8456
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.42e-05
# New best model saved with test accuracy: 94.31%
# Epoch [261] 📊 acc: 0.956 | Targets: 0.8271 | Entropy: -1.8646
# New ref model saved
# Epoch [262] 📊 acc: 0.955 | Targets: 0.8272 | Entropy: -1.8641
# Epoch [263] 📊 acc: 0.955 | Targets: 0.8267 | Entropy: -1.8643
# Epoch [264] 📊 acc: 0.956 | Targets: 0.8278 | Entropy: -1.8646
# Epoch [265] 📊 acc: 0.955 | Targets: 0.8275 | Entropy: -1.8645
# Epoch [266] 📊 acc: 0.956 | Targets: 0.8261 | Entropy: -1.8641
# New ref model saved
# Epoch [267] 📊 acc: 0.956 | Targets: 0.8260 | Entropy: -1.8641
# Epoch [268] 📊 acc: 0.955 | Targets: 0.8282 | Entropy: -1.8646
# Epoch [269] 📊 acc: 0.955 | Targets: 0.8279 | Entropy: -1.8647
# Epoch [270] 📊 acc: 0.956 | Targets: 0.8264 | Entropy: -1.8641
#
# Evaluating at epoch 270 …
# Train Accuracy: 95.51%
# Train Average Loss: 0.8281
# Test Accuracy: 94.18%
# Test Average Loss: 0.8442
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-05
# Epoch [271] 📊 acc: 0.956 | Targets: 0.8247 | Entropy: -1.8640
# Epoch [272] 📊 acc: 0.956 | Targets: 0.8248 | Entropy: -1.8636
# Epoch [273] 📊 acc: 0.956 | Targets: 0.8261 | Entropy: -1.8640
# Epoch [274] 📊 acc: 0.955 | Targets: 0.8283 | Entropy: -1.8648
# Epoch [275] 📊 acc: 0.958 | Targets: 0.8240 | Entropy: -1.8636
# New ref model saved
# Epoch [276] 📊 acc: 0.956 | Targets: 0.8273 | Entropy: -1.8645
# Epoch [277] 📊 acc: 0.957 | Targets: 0.8247 | Entropy: -1.8641
# Epoch [278] 📊 acc: 0.955 | Targets: 0.8262 | Entropy: -1.8644
# Epoch [279] 📊 acc: 0.958 | Targets: 0.8252 | Entropy: -1.8639
# Epoch [280] 📊 acc: 0.958 | Targets: 0.8244 | Entropy: -1.8638
#
# Evaluating at epoch 280 …
# Train Accuracy: 95.65%
# Train Average Loss: 0.8245
# Test Accuracy: 94.22%
# Test Average Loss: 0.8428
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.19e-05
# Epoch [281] 📊 acc: 0.956 | Targets: 0.8263 | Entropy: -1.8642
# Epoch [282] 📊 acc: 0.956 | Targets: 0.8256 | Entropy: -1.8640
# Epoch [283] 📊 acc: 0.957 | Targets: 0.8249 | Entropy: -1.8639
# Epoch [284] 📊 acc: 0.956 | Targets: 0.8251 | Entropy: -1.8639
# Epoch [285] 📊 acc: 0.956 | Targets: 0.8269 | Entropy: -1.8646
# Epoch [286] 📊 acc: 0.957 | Targets: 0.8250 | Entropy: -1.8641
# Epoch [287] 📊 acc: 0.957 | Targets: 0.8239 | Entropy: -1.8640
# Epoch [288] 📊 acc: 0.958 | Targets: 0.8227 | Entropy: -1.8634
# Epoch [289] 📊 acc: 0.956 | Targets: 0.8260 | Entropy: -1.8639
# Epoch [290] 📊 acc: 0.959 | Targets: 0.8219 | Entropy: -1.8632
# New ref model saved
#
# Evaluating at epoch 290 …
# Train Accuracy: 95.81%
# Train Average Loss: 0.8235
# Test Accuracy: 94.18%
# Test Average Loss: 0.8441
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.74e-06
# Epoch [291] 📊 acc: 0.957 | Targets: 0.8244 | Entropy: -1.8636
# Epoch [292] 📊 acc: 0.958 | Targets: 0.8238 | Entropy: -1.8639
# Epoch [293] 📊 acc: 0.958 | Targets: 0.8231 | Entropy: -1.8632
# Epoch [294] 📊 acc: 0.958 | Targets: 0.8233 | Entropy: -1.8639
# Epoch [295] 📊 acc: 0.958 | Targets: 0.8227 | Entropy: -1.8633
# Epoch [296] 📊 acc: 0.958 | Targets: 0.8228 | Entropy: -1.8633
# Epoch [297] 📊 acc: 0.957 | Targets: 0.8240 | Entropy: -1.8635
# Epoch [298] 📊 acc: 0.957 | Targets: 0.8248 | Entropy: -1.8636
# Epoch [299] 📊 acc: 0.956 | Targets: 0.8251 | Entropy: -1.8640
# Epoch [300] 📊 acc: 0.959 | Targets: 0.8225 | Entropy: -1.8633
#
# Evaluating at epoch 300 …
# Train Accuracy: 95.68%
# Train Average Loss: 0.8246
# Test Accuracy: 94.18%
# Test Average Loss: 0.8436
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-06
# Finished Training
# Best test accuracy achieved: 94.31%
# Total Trainable Parameters: 515,754
