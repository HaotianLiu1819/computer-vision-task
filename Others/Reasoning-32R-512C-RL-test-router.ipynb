# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class Router(nn.Module):
    def __init__(self, channels, num_module, tau=1.0, reduction_factor=4):
        super().__init__()
        self.num_module = num_module
        self.tau = tau
        reduced_channels = channels // reduction_factor
        self.conv = nn.Sequential(
            nn.ReLU(),
            nn.GroupNorm(1, channels),
            nn.Conv2d(channels, reduced_channels, kernel_size=1, bias=False),
            nn.ReLU(),
            nn.GroupNorm(1, reduced_channels),
            nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels),
            nn.ReLU(),
            nn.GroupNorm(1, reduced_channels),
            nn.Conv2d(reduced_channels, channels, kernel_size=1, bias=False),
            nn.AdaptiveAvgPool2d((1, 1)),
        )
        self.fc = nn.Linear(channels, num_module)

    def forward(self, x):
        h = self.conv(x).flatten(1)
        logits = self.fc(h)
        r = F.gumbel_softmax(logits, tau=self.tau, hard=True, dim=1)
        return r, logits

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)
        self.router = Router(channels, num_module)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth, group_ids):
        out = torch.empty_like(x)

        for i in range(self.num_module):
            idx = (group_ids == i).nonzero(as_tuple=True)[0]
            if idx.numel() == 0:
                continue
            out_i = self.conv[i](x[idx], depth).to(x.dtype)
            out[idx] = out_i
        
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        usage_per_depth = []
        
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            
            r, logits = self.router(x)
            group_ids = torch.argmax(r, dim=1)
            usage = torch.bincount(group_ids, minlength=self.num_module).detach()
            usage_per_depth.append(usage)
            
            x = checkpoint(self.step_forward, x, x_prev, d, group_ids, use_reentrant=False)

        return x, usage_per_depth

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv0 = nn.Conv2d(3, 512, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(512, max_depth=32, num_module=4)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.conv0(x)
        x, usage_per_depth = self.amconv(x)
        
        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        
        return x, usage_per_depth

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 1)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        pre_entropy = torch.sum(pre_probs * torch.log(pre_probs), dim=1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_pre_entropy = torch.sum(old_pre_probs * torch.log(old_pre_probs), dim=1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        ref_entropy = torch.sum(ref_probs * torch.log(ref_probs), dim=1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_ref_entropy = torch.sum(old_ref_probs * torch.log(old_ref_probs), dim=1)

        rewards, correct = self.compute_reconstruct_reward(outputs, targets)
        p_rewards, _ = self.compute_positive_reward(outputs, targets)
        n_rewards, _ = self.compute_negative_reward(outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        entropy_delta = (entropy - old_entropy)
        pre_entropy_delta = (pre_entropy - old_pre_entropy)
        ref_entropy_delta = (ref_entropy - old_ref_entropy)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
                'entropy': entropy.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_16R_256C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)
    
    ref_count = 16

    select_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    select_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))

    entropy_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    entropy_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    
    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()
    all_params = list(net.parameters()) + list(pre_net.parameters()) + list(ref_net.parameters()) + [
        select_embeddings1, select_embeddings2,
        entropy_embeddings1, entropy_embeddings2,
    ]
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    rl_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    d = 0
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=300, eta_min=1e-6
            )
        
        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
            'rewards_mean': 0.0, 'rewards_std': 0.0, 
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs, _ = net(inputs)
                ref_outputs, _ = ref_net(inputs)
                pre_outputs, _ = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_delta = F.tanh(select_delta) - 2 * F.sigmoid(select_embeddings1[d % ref_count]) * F.relu(F.tanh(pre_select_delta))
                select_delta = F.tanh(select_delta)
                select_delta = select_delta - 2 * F.sigmoid(select_embeddings2[d % ref_count]) * F.relu(F.tanh(ref_select_delta))
                
                select_loss = select_delta.sum()
                
                entropy_delta = F.tanh(entropy_delta) - 2 * F.sigmoid(entropy_embeddings1[d % ref_count]) * F.relu(F.tanh(pre_entropy_delta))
                entropy_delta = F.tanh(entropy_delta)         
                entropy_delta = entropy_delta - 2 * F.sigmoid(entropy_embeddings2[d % ref_count]) * F.relu(F.tanh(ref_entropy_delta))  

                entropy_loss = entropy_delta.sum()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f}")

        if running_cor > rl_accuracy:
            rl_accuracy = running_cor
            ref = copy.deepcopy(net).to(device)
            if d % 2 == 0:
                prev_ref.append(ref)
                prev_ref = prev_ref[-ref_count:]
            ref_net = prev_ref[((d % ref_count + 1) - ((d % ref_count + 1) & -(d % ref_count + 1))) // 2]
            pre_net = prev_ref[0]
            d += 1
            print(f"New ref model saved")
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
            
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (
        torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
        if use_bf16 else contextlib.nullcontext()
    )

    total_usage_per_depth = None

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

        
            outputs, usage_per_depth = net(images)

            if total_usage_per_depth is None:
                total_usage_per_depth = [
                    u.clone().to(torch.long) for u in usage_per_depth
                ]
            else:
                for d in range(len(usage_per_depth)):
                    total_usage_per_depth[d] += usage_per_depth[d].to(torch.long)

            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum += batch_loss.item() * bs
            total_seen += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if total_usage_per_depth is not None:

        max_depth_to_sum = min(16, len(total_usage_per_depth))
        summed_usage = sum(total_usage_per_depth[:max_depth_to_sum])
        summed_usage = summed_usage.cpu()

        total = summed_usage.sum().item()
        print(f"{dataset_name} Module Usage Summed Over Depth 0 to {max_depth_to_sum - 1}:")

        if total > 0:
            ratio = summed_usage.float() / total
            for i in range(len(summed_usage)):
                print(f"  module{i}: {summed_usage[i].item()} ({ratio[i].item() * 100:.2f}%)")
        else:
            for i in range(len(summed_usage)):
                print(f"  module{i}: 0 (0.00%)")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 1,942,286

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.265 | Targets: 2.0838 | Entropy: -2.1529
# New ref model saved
# Epoch [2] 📊 acc: 0.431 | Targets: 1.7591 | Entropy: -2.0834
# New ref model saved
# Epoch [3] 📊 acc: 0.504 | Targets: 1.6297 | Entropy: -2.0426
# New ref model saved
# Epoch [4] 📊 acc: 0.559 | Targets: 1.5435 | Entropy: -2.0192
# New ref model saved
# Epoch [5] 📊 acc: 0.597 | Targets: 1.4755 | Entropy: -1.9998
# New ref model saved
# Epoch [6] 📊 acc: 0.629 | Targets: 1.4252 | Entropy: -1.9859
# New ref model saved
# Epoch [7] 📊 acc: 0.654 | Targets: 1.3833 | Entropy: -1.9762
# New ref model saved
# Epoch [8] 📊 acc: 0.673 | Targets: 1.3489 | Entropy: -1.9692
# New ref model saved
# Epoch [9] 📊 acc: 0.693 | Targets: 1.3176 | Entropy: -1.9630
# New ref model saved
# Epoch [10] 📊 acc: 0.703 | Targets: 1.2973 | Entropy: -1.9581
# New ref model saved
#
# Evaluating at epoch 10 …
# Train Accuracy: 71.54%
# Train Average Loss: 1.2942
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 207410 (25.93%)
#   module1: 185979 (23.25%)
#   module2: 206898 (25.87%)
#   module3: 199457 (24.94%)
# Test Accuracy: 76.72%
# Test Average Loss: 1.2328
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 41646 (26.03%)
#   module1: 37278 (23.30%)
#   module2: 39773 (24.86%)
#   module3: 41303 (25.81%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 76.72%
# Epoch [11] 📊 acc: 0.715 | Targets: 1.2792 | Entropy: -1.9553
# New ref model saved
# Epoch [12] 📊 acc: 0.722 | Targets: 1.2616 | Entropy: -1.9523
# New ref model saved
# Epoch [13] 📊 acc: 0.730 | Targets: 1.2485 | Entropy: -1.9501
# New ref model saved
# Epoch [14] 📊 acc: 0.739 | Targets: 1.2350 | Entropy: -1.9480
# New ref model saved
# Epoch [15] 📊 acc: 0.745 | Targets: 1.2210 | Entropy: -1.9464
# New ref model saved
# Epoch [16] 📊 acc: 0.754 | Targets: 1.2053 | Entropy: -1.9430
# New ref model saved
# Epoch [17] 📊 acc: 0.759 | Targets: 1.1949 | Entropy: -1.9405
# New ref model saved
# Epoch [18] 📊 acc: 0.764 | Targets: 1.1868 | Entropy: -1.9387
# New ref model saved
# Epoch [19] 📊 acc: 0.769 | Targets: 1.1775 | Entropy: -1.9383
# New ref model saved
# Epoch [20] 📊 acc: 0.770 | Targets: 1.1730 | Entropy: -1.9375
# New ref model saved
#
# Evaluating at epoch 20 …
# Train Accuracy: 77.44%
# Train Average Loss: 1.1537
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 212901 (26.62%)
#   module1: 193559 (24.20%)
#   module2: 198669 (24.84%)
#   module3: 194615 (24.33%)
# Test Accuracy: 82.77%
# Test Average Loss: 1.0661
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42132 (26.33%)
#   module1: 38591 (24.12%)
#   module2: 39121 (24.45%)
#   module3: 40156 (25.10%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 82.77%
# Epoch [21] 📊 acc: 0.778 | Targets: 1.1599 | Entropy: -1.9344
# New ref model saved
# Epoch [22] 📊 acc: 0.784 | Targets: 1.1511 | Entropy: -1.9333
# New ref model saved
# Epoch [23] 📊 acc: 0.786 | Targets: 1.1452 | Entropy: -1.9325
# New ref model saved
# Epoch [24] 📊 acc: 0.790 | Targets: 1.1412 | Entropy: -1.9322
# New ref model saved
# Epoch [25] 📊 acc: 0.794 | Targets: 1.1327 | Entropy: -1.9305
# New ref model saved
# Epoch [26] 📊 acc: 0.798 | Targets: 1.1249 | Entropy: -1.9287
# New ref model saved
# Epoch [27] 📊 acc: 0.802 | Targets: 1.1167 | Entropy: -1.9281
# New ref model saved
# Epoch [28] 📊 acc: 0.804 | Targets: 1.1135 | Entropy: -1.9266
# New ref model saved
# Epoch [29] 📊 acc: 0.806 | Targets: 1.1085 | Entropy: -1.9254
# New ref model saved
# Epoch [30] 📊 acc: 0.809 | Targets: 1.1011 | Entropy: -1.9241
# New ref model saved
#
# Evaluating at epoch 30 …
# Train Accuracy: 80.30%
# Train Average Loss: 1.1105
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 214291 (26.79%)
#   module1: 185727 (23.22%)
#   module2: 207943 (26.00%)
#   module3: 191783 (23.98%)
# Test Accuracy: 84.78%
# Test Average Loss: 1.0379
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42124 (26.33%)
#   module1: 37024 (23.14%)
#   module2: 40807 (25.50%)
#   module3: 40045 (25.03%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 84.78%
# Epoch [31] 📊 acc: 0.811 | Targets: 1.0974 | Entropy: -1.9246
# New ref model saved
# Epoch [32] 📊 acc: 0.811 | Targets: 1.0969 | Entropy: -1.9242
# Epoch [33] 📊 acc: 0.815 | Targets: 1.0897 | Entropy: -1.9223
# New ref model saved
# Epoch [34] 📊 acc: 0.816 | Targets: 1.0884 | Entropy: -1.9224
# New ref model saved
# Epoch [35] 📊 acc: 0.821 | Targets: 1.0799 | Entropy: -1.9208
# New ref model saved
# Epoch [36] 📊 acc: 0.823 | Targets: 1.0760 | Entropy: -1.9197
# New ref model saved
# Epoch [37] 📊 acc: 0.825 | Targets: 1.0746 | Entropy: -1.9197
# New ref model saved
# Epoch [38] 📊 acc: 0.826 | Targets: 1.0689 | Entropy: -1.9188
# New ref model saved
# Epoch [39] 📊 acc: 0.829 | Targets: 1.0663 | Entropy: -1.9182
# New ref model saved
# Epoch [40] 📊 acc: 0.832 | Targets: 1.0630 | Entropy: -1.9175
# New ref model saved
#
# Evaluating at epoch 40 …
# Train Accuracy: 83.40%
# Train Average Loss: 1.0517
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 213963 (26.75%)
#   module1: 194374 (24.30%)
#   module2: 199090 (24.89%)
#   module3: 192317 (24.05%)
# Test Accuracy: 87.43%
# Test Average Loss: 0.9657
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42469 (26.54%)
#   module1: 38355 (23.97%)
#   module2: 39667 (24.79%)
#   module3: 39509 (24.69%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 87.43%
# Epoch [41] 📊 acc: 0.831 | Targets: 1.0618 | Entropy: -1.9174
# Epoch [42] 📊 acc: 0.832 | Targets: 1.0583 | Entropy: -1.9168
# New ref model saved
# Epoch [43] 📊 acc: 0.835 | Targets: 1.0538 | Entropy: -1.9160
# New ref model saved
# Epoch [44] 📊 acc: 0.836 | Targets: 1.0563 | Entropy: -1.9167
# New ref model saved
# Epoch [45] 📊 acc: 0.839 | Targets: 1.0495 | Entropy: -1.9153
# New ref model saved
# Epoch [46] 📊 acc: 0.840 | Targets: 1.0449 | Entropy: -1.9146
# New ref model saved
# Epoch [47] 📊 acc: 0.842 | Targets: 1.0419 | Entropy: -1.9139
# New ref model saved
# Epoch [48] 📊 acc: 0.840 | Targets: 1.0439 | Entropy: -1.9151
# Epoch [49] 📊 acc: 0.844 | Targets: 1.0372 | Entropy: -1.9135
# New ref model saved
# Epoch [50] 📊 acc: 0.846 | Targets: 1.0340 | Entropy: -1.9128
# New ref model saved
#
# Evaluating at epoch 50 …
# Train Accuracy: 85.04%
# Train Average Loss: 1.0152
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 214715 (26.85%)
#   module1: 191170 (23.90%)
#   module2: 205441 (25.69%)
#   module3: 188418 (23.56%)
# Test Accuracy: 88.86%
# Test Average Loss: 0.9378
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42291 (26.43%)
#   module1: 38192 (23.87%)
#   module2: 40748 (25.47%)
#   module3: 38769 (24.23%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.33e-04
# New best model saved with test accuracy: 88.86%
# Epoch [51] 📊 acc: 0.847 | Targets: 1.0324 | Entropy: -1.9127
# New ref model saved
# Epoch [52] 📊 acc: 0.849 | Targets: 1.0285 | Entropy: -1.9121
# New ref model saved
# Epoch [53] 📊 acc: 0.849 | Targets: 1.0274 | Entropy: -1.9118
# New ref model saved
# Epoch [54] 📊 acc: 0.849 | Targets: 1.0276 | Entropy: -1.9123
# Epoch [55] 📊 acc: 0.852 | Targets: 1.0206 | Entropy: -1.9107
# New ref model saved
# Epoch [56] 📊 acc: 0.852 | Targets: 1.0212 | Entropy: -1.9110
# Epoch [57] 📊 acc: 0.856 | Targets: 1.0173 | Entropy: -1.9098
# New ref model saved
# Epoch [58] 📊 acc: 0.858 | Targets: 1.0124 | Entropy: -1.9089
# New ref model saved
# Epoch [59] 📊 acc: 0.854 | Targets: 1.0157 | Entropy: -1.9099
# Epoch [60] 📊 acc: 0.859 | Targets: 1.0088 | Entropy: -1.9081
# New ref model saved
#
# Evaluating at epoch 60 …
# Train Accuracy: 86.55%
# Train Average Loss: 1.0107
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 209665 (26.22%)
#   module1: 188988 (23.63%)
#   module2: 203416 (25.44%)
#   module3: 197675 (24.72%)
# Test Accuracy: 89.62%
# Test Average Loss: 0.9453
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 41785 (26.12%)
#   module1: 38169 (23.86%)
#   module2: 39853 (24.91%)
#   module3: 40193 (25.12%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 89.62%
# Epoch [61] 📊 acc: 0.861 | Targets: 1.0058 | Entropy: -1.9077
# New ref model saved
# Epoch [62] 📊 acc: 0.860 | Targets: 1.0057 | Entropy: -1.9076
# Epoch [63] 📊 acc: 0.862 | Targets: 1.0031 | Entropy: -1.9071
# New ref model saved
# Epoch [64] 📊 acc: 0.865 | Targets: 0.9997 | Entropy: -1.9066
# New ref model saved
# Epoch [65] 📊 acc: 0.866 | Targets: 0.9992 | Entropy: -1.9063
# New ref model saved
# Epoch [66] 📊 acc: 0.868 | Targets: 0.9930 | Entropy: -1.9048
# New ref model saved
# Epoch [67] 📊 acc: 0.866 | Targets: 0.9965 | Entropy: -1.9059
# Epoch [68] 📊 acc: 0.868 | Targets: 0.9925 | Entropy: -1.9049
# New ref model saved
# Epoch [69] 📊 acc: 0.869 | Targets: 0.9892 | Entropy: -1.9041
# New ref model saved
# Epoch [70] 📊 acc: 0.871 | Targets: 0.9874 | Entropy: -1.9033
# New ref model saved
#
# Evaluating at epoch 70 …
# Train Accuracy: 87.39%
# Train Average Loss: 0.9839
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 213217 (26.66%)
#   module1: 192665 (24.09%)
#   module2: 203788 (25.48%)
#   module3: 190074 (23.77%)
# Test Accuracy: 90.92%
# Test Average Loss: 0.9213
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42297 (26.44%)
#   module1: 38473 (24.05%)
#   module2: 39736 (24.83%)
#   module3: 39494 (24.68%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 8.72e-04
# New best model saved with test accuracy: 90.92%
# Epoch [71] 📊 acc: 0.872 | Targets: 0.9854 | Entropy: -1.9033
# New ref model saved
# Epoch [72] 📊 acc: 0.873 | Targets: 0.9837 | Entropy: -1.9029
# New ref model saved
# Epoch [73] 📊 acc: 0.874 | Targets: 0.9827 | Entropy: -1.9026
# New ref model saved
# Epoch [74] 📊 acc: 0.875 | Targets: 0.9806 | Entropy: -1.9021
# New ref model saved
# Epoch [75] 📊 acc: 0.875 | Targets: 0.9799 | Entropy: -1.9019
# New ref model saved
# Epoch [76] 📊 acc: 0.875 | Targets: 0.9776 | Entropy: -1.9017
# Epoch [77] 📊 acc: 0.878 | Targets: 0.9735 | Entropy: -1.9004
# New ref model saved
# Epoch [78] 📊 acc: 0.878 | Targets: 0.9743 | Entropy: -1.9011
# Epoch [79] 📊 acc: 0.879 | Targets: 0.9727 | Entropy: -1.9006
# New ref model saved
# Epoch [80] 📊 acc: 0.880 | Targets: 0.9700 | Entropy: -1.8997
# New ref model saved
#
# Evaluating at epoch 80 …
# Train Accuracy: 87.89%
# Train Average Loss: 0.9752
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 213936 (26.75%)
#   module1: 186315 (23.30%)
#   module2: 204792 (25.61%)
#   module3: 194701 (24.35%)
# Test Accuracy: 90.39%
# Test Average Loss: 0.9328
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42397 (26.50%)
#   module1: 37890 (23.68%)
#   module2: 40757 (25.47%)
#   module3: 38956 (24.35%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 8.35e-04
# Epoch [81] 📊 acc: 0.881 | Targets: 0.9700 | Entropy: -1.9003
# New ref model saved
# Epoch [82] 📊 acc: 0.881 | Targets: 0.9686 | Entropy: -1.8995
# Epoch [83] 📊 acc: 0.883 | Targets: 0.9642 | Entropy: -1.8983
# New ref model saved
# Epoch [84] 📊 acc: 0.885 | Targets: 0.9612 | Entropy: -1.8977
# New ref model saved
# Epoch [85] 📊 acc: 0.887 | Targets: 0.9589 | Entropy: -1.8972
# New ref model saved
# Epoch [86] 📊 acc: 0.885 | Targets: 0.9603 | Entropy: -1.8977
# Epoch [87] 📊 acc: 0.886 | Targets: 0.9590 | Entropy: -1.8975
# Epoch [88] 📊 acc: 0.887 | Targets: 0.9601 | Entropy: -1.8978
# Epoch [89] 📊 acc: 0.888 | Targets: 0.9568 | Entropy: -1.8967
# New ref model saved
# Epoch [90] 📊 acc: 0.889 | Targets: 0.9525 | Entropy: -1.8957
# New ref model saved
#
# Evaluating at epoch 90 …
# Train Accuracy: 88.74%
# Train Average Loss: 0.9574
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 209743 (26.23%)
#   module1: 189943 (23.75%)
#   module2: 204511 (25.57%)
#   module3: 195547 (24.45%)
# Test Accuracy: 90.56%
# Test Average Loss: 0.9177
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 41991 (26.24%)
#   module1: 38404 (24.00%)
#   module2: 40270 (25.17%)
#   module3: 39335 (24.58%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 7.94e-04
# Epoch [91] 📊 acc: 0.890 | Targets: 0.9531 | Entropy: -1.8962
# New ref model saved
# Epoch [92] 📊 acc: 0.888 | Targets: 0.9543 | Entropy: -1.8958
# Epoch [93] 📊 acc: 0.890 | Targets: 0.9528 | Entropy: -1.8959
# Epoch [94] 📊 acc: 0.889 | Targets: 0.9521 | Entropy: -1.8958
# Epoch [95] 📊 acc: 0.890 | Targets: 0.9498 | Entropy: -1.8954
# New ref model saved
# Epoch [96] 📊 acc: 0.892 | Targets: 0.9495 | Entropy: -1.8951
# New ref model saved
# Epoch [97] 📊 acc: 0.892 | Targets: 0.9469 | Entropy: -1.8946
# New ref model saved
# Epoch [98] 📊 acc: 0.894 | Targets: 0.9442 | Entropy: -1.8938
# New ref model saved
# Epoch [99] 📊 acc: 0.894 | Targets: 0.9453 | Entropy: -1.8942
# New ref model saved
# Epoch [100] 📊 acc: 0.894 | Targets: 0.9414 | Entropy: -1.8930
# New ref model saved
#
# Evaluating at epoch 100 …
# Train Accuracy: 89.66%
# Train Average Loss: 0.9463
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 213768 (26.73%)
#   module1: 193223 (24.16%)
#   module2: 203918 (25.50%)
#   module3: 188835 (23.61%)
# Test Accuracy: 91.37%
# Test Average Loss: 0.9060
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42388 (26.49%)
#   module1: 39049 (24.41%)
#   module2: 40498 (25.31%)
#   module3: 38065 (23.79%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 7.50e-04
# New best model saved with test accuracy: 91.37%
# Epoch [101] 📊 acc: 0.896 | Targets: 0.9394 | Entropy: -1.8926
# New ref model saved
# Epoch [102] 📊 acc: 0.895 | Targets: 0.9409 | Entropy: -1.8931
# Epoch [103] 📊 acc: 0.896 | Targets: 0.9424 | Entropy: -1.8935
# Epoch [104] 📊 acc: 0.895 | Targets: 0.9414 | Entropy: -1.8937
# Epoch [105] 📊 acc: 0.897 | Targets: 0.9375 | Entropy: -1.8920
# New ref model saved
# Epoch [106] 📊 acc: 0.899 | Targets: 0.9350 | Entropy: -1.8916
# New ref model saved
# Epoch [107] 📊 acc: 0.897 | Targets: 0.9374 | Entropy: -1.8921
# Epoch [108] 📊 acc: 0.898 | Targets: 0.9385 | Entropy: -1.8931
# Epoch [109] 📊 acc: 0.899 | Targets: 0.9331 | Entropy: -1.8911
# Epoch [110] 📊 acc: 0.902 | Targets: 0.9297 | Entropy: -1.8902
# New ref model saved
#
# Evaluating at epoch 110 …
# Train Accuracy: 90.06%
# Train Average Loss: 0.9364
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 214389 (26.81%)
#   module1: 191048 (23.89%)
#   module2: 204472 (25.57%)
#   module3: 189835 (23.74%)
# Test Accuracy: 92.17%
# Test Average Loss: 0.8935
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42485 (26.55%)
#   module1: 38418 (24.01%)
#   module2: 40638 (25.40%)
#   module3: 38459 (24.04%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 7.04e-04
# New best model saved with test accuracy: 92.17%
# Epoch [111] 📊 acc: 0.901 | Targets: 0.9297 | Entropy: -1.8904
# Epoch [112] 📊 acc: 0.901 | Targets: 0.9296 | Entropy: -1.8903
# Epoch [113] 📊 acc: 0.904 | Targets: 0.9265 | Entropy: -1.8897
# New ref model saved
# Epoch [114] 📊 acc: 0.903 | Targets: 0.9262 | Entropy: -1.8897
# Epoch [115] 📊 acc: 0.905 | Targets: 0.9240 | Entropy: -1.8889
# New ref model saved
# Epoch [116] 📊 acc: 0.905 | Targets: 0.9253 | Entropy: -1.8896
# New ref model saved
# Epoch [117] 📊 acc: 0.903 | Targets: 0.9250 | Entropy: -1.8894
# Epoch [118] 📊 acc: 0.905 | Targets: 0.9228 | Entropy: -1.8886
# New ref model saved
# Epoch [119] 📊 acc: 0.904 | Targets: 0.9245 | Entropy: -1.8894
# Epoch [120] 📊 acc: 0.905 | Targets: 0.9223 | Entropy: -1.8887
#
# Evaluating at epoch 120 …
# Train Accuracy: 90.41%
# Train Average Loss: 0.9168
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 211406 (26.43%)
#   module1: 190761 (23.85%)
#   module2: 208282 (26.04%)
#   module3: 189295 (23.67%)
# Test Accuracy: 91.76%
# Test Average Loss: 0.8843
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42569 (26.61%)
#   module1: 38258 (23.91%)
#   module2: 40464 (25.29%)
#   module3: 38709 (24.19%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 6.55e-04
# Epoch [121] 📊 acc: 0.908 | Targets: 0.9179 | Entropy: -1.8875
# New ref model saved
# Epoch [122] 📊 acc: 0.906 | Targets: 0.9212 | Entropy: -1.8884
# Epoch [123] 📊 acc: 0.908 | Targets: 0.9154 | Entropy: -1.8866
# Epoch [124] 📊 acc: 0.907 | Targets: 0.9184 | Entropy: -1.8876
# Epoch [125] 📊 acc: 0.908 | Targets: 0.9173 | Entropy: -1.8873
# Epoch [126] 📊 acc: 0.907 | Targets: 0.9178 | Entropy: -1.8878
# Epoch [127] 📊 acc: 0.911 | Targets: 0.9138 | Entropy: -1.8866
# New ref model saved
# Epoch [128] 📊 acc: 0.910 | Targets: 0.9143 | Entropy: -1.8867
# Epoch [129] 📊 acc: 0.909 | Targets: 0.9135 | Entropy: -1.8864
# Epoch [130] 📊 acc: 0.911 | Targets: 0.9117 | Entropy: -1.8862
# New ref model saved
#
# Evaluating at epoch 130 …
# Train Accuracy: 91.41%
# Train Average Loss: 0.9069
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 214637 (26.84%)
#   module1: 190646 (23.84%)
#   module2: 204108 (25.52%)
#   module3: 190353 (23.80%)
# Test Accuracy: 92.49%
# Test Average Loss: 0.8857
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42644 (26.65%)
#   module1: 38135 (23.83%)
#   module2: 40154 (25.10%)
#   module3: 39067 (24.42%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 6.04e-04
# New best model saved with test accuracy: 92.49%
# Epoch [131] 📊 acc: 0.911 | Targets: 0.9095 | Entropy: -1.8853
# New ref model saved
# Epoch [132] 📊 acc: 0.914 | Targets: 0.9074 | Entropy: -1.8846
# New ref model saved
# Epoch [133] 📊 acc: 0.913 | Targets: 0.9070 | Entropy: -1.8850
# Epoch [134] 📊 acc: 0.914 | Targets: 0.9071 | Entropy: -1.8851
# Epoch [135] 📊 acc: 0.914 | Targets: 0.9055 | Entropy: -1.8847
# New ref model saved
# Epoch [136] 📊 acc: 0.916 | Targets: 0.9034 | Entropy: -1.8838
# New ref model saved
# Epoch [137] 📊 acc: 0.913 | Targets: 0.9055 | Entropy: -1.8842
# Epoch [138] 📊 acc: 0.918 | Targets: 0.9017 | Entropy: -1.8833
# New ref model saved
# Epoch [139] 📊 acc: 0.915 | Targets: 0.9032 | Entropy: -1.8842
# Epoch [140] 📊 acc: 0.918 | Targets: 0.8978 | Entropy: -1.8823
# New ref model saved
#
# Evaluating at epoch 140 …
# Train Accuracy: 91.69%
# Train Average Loss: 0.8991
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 212974 (26.63%)
#   module1: 191611 (23.96%)
#   module2: 203558 (25.45%)
#   module3: 191601 (23.96%)
# Test Accuracy: 92.49%
# Test Average Loss: 0.8807
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42182 (26.36%)
#   module1: 38918 (24.32%)
#   module2: 40354 (25.22%)
#   module3: 38546 (24.09%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 5.53e-04
# Epoch [141] 📊 acc: 0.918 | Targets: 0.9005 | Entropy: -1.8833
# Epoch [142] 📊 acc: 0.918 | Targets: 0.9010 | Entropy: -1.8836
# Epoch [143] 📊 acc: 0.918 | Targets: 0.8975 | Entropy: -1.8821
# New ref model saved
# Epoch [144] 📊 acc: 0.918 | Targets: 0.8983 | Entropy: -1.8825
# Epoch [145] 📊 acc: 0.919 | Targets: 0.8958 | Entropy: -1.8822
# New ref model saved
# Epoch [146] 📊 acc: 0.919 | Targets: 0.8979 | Entropy: -1.8823
# Epoch [147] 📊 acc: 0.918 | Targets: 0.8987 | Entropy: -1.8829
# Epoch [148] 📊 acc: 0.920 | Targets: 0.8962 | Entropy: -1.8821
# New ref model saved
# Epoch [149] 📊 acc: 0.920 | Targets: 0.8955 | Entropy: -1.8823
# Epoch [150] 📊 acc: 0.922 | Targets: 0.8917 | Entropy: -1.8812
# New ref model saved
#
# Evaluating at epoch 150 …
# Train Accuracy: 92.14%
# Train Average Loss: 0.8800
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 213884 (26.74%)
#   module1: 193539 (24.20%)
#   module2: 202381 (25.31%)
#   module3: 189940 (23.75%)
# Test Accuracy: 92.71%
# Test Average Loss: 0.8654
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42869 (26.79%)
#   module1: 38453 (24.03%)
#   module2: 40462 (25.29%)
#   module3: 38216 (23.88%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 5.00e-04
# New best model saved with test accuracy: 92.71%
# Epoch [151] 📊 acc: 0.921 | Targets: 0.8939 | Entropy: -1.8819
# Epoch [152] 📊 acc: 0.922 | Targets: 0.8912 | Entropy: -1.8812
# Epoch [153] 📊 acc: 0.922 | Targets: 0.8918 | Entropy: -1.8810
# Epoch [154] 📊 acc: 0.923 | Targets: 0.8886 | Entropy: -1.8805
# New ref model saved
# Epoch [155] 📊 acc: 0.923 | Targets: 0.8878 | Entropy: -1.8798
# Epoch [156] 📊 acc: 0.923 | Targets: 0.8874 | Entropy: -1.8799
# New ref model saved
# Epoch [157] 📊 acc: 0.923 | Targets: 0.8882 | Entropy: -1.8805
# Epoch [158] 📊 acc: 0.923 | Targets: 0.8878 | Entropy: -1.8798
# Epoch [159] 📊 acc: 0.925 | Targets: 0.8866 | Entropy: -1.8798
# New ref model saved
# Epoch [160] 📊 acc: 0.924 | Targets: 0.8876 | Entropy: -1.8800
#
# Evaluating at epoch 160 …
# Train Accuracy: 92.47%
# Train Average Loss: 0.8914
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 214129 (26.77%)
#   module1: 186185 (23.28%)
#   module2: 205609 (25.71%)
#   module3: 193821 (24.24%)
# Test Accuracy: 93.07%
# Test Average Loss: 0.8744
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 43105 (26.94%)
#   module1: 37774 (23.61%)
#   module2: 40691 (25.43%)
#   module3: 38430 (24.02%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 4.48e-04
# New best model saved with test accuracy: 93.07%
# Epoch [161] 📊 acc: 0.924 | Targets: 0.8854 | Entropy: -1.8794
# Epoch [162] 📊 acc: 0.925 | Targets: 0.8849 | Entropy: -1.8794
# Epoch [163] 📊 acc: 0.926 | Targets: 0.8836 | Entropy: -1.8792
# New ref model saved
# Epoch [164] 📊 acc: 0.926 | Targets: 0.8821 | Entropy: -1.8787
# New ref model saved
# Epoch [165] 📊 acc: 0.930 | Targets: 0.8785 | Entropy: -1.8781
# New ref model saved
# Epoch [166] 📊 acc: 0.926 | Targets: 0.8825 | Entropy: -1.8789
# Epoch [167] 📊 acc: 0.928 | Targets: 0.8791 | Entropy: -1.8781
# Epoch [168] 📊 acc: 0.925 | Targets: 0.8832 | Entropy: -1.8790
# Epoch [169] 📊 acc: 0.928 | Targets: 0.8798 | Entropy: -1.8782
# Epoch [170] 📊 acc: 0.928 | Targets: 0.8790 | Entropy: -1.8779
#
# Evaluating at epoch 170 …
# Train Accuracy: 93.15%
# Train Average Loss: 0.8762
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 213647 (26.71%)
#   module1: 189638 (23.71%)
#   module2: 204433 (25.56%)
#   module3: 192026 (24.01%)
# Test Accuracy: 93.06%
# Test Average Loss: 0.8678
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42583 (26.61%)
#   module1: 38155 (23.85%)
#   module2: 40237 (25.15%)
#   module3: 39025 (24.39%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 3.97e-04
# Epoch [171] 📊 acc: 0.929 | Targets: 0.8780 | Entropy: -1.8777
# Epoch [172] 📊 acc: 0.930 | Targets: 0.8767 | Entropy: -1.8773
# New ref model saved
# Epoch [173] 📊 acc: 0.929 | Targets: 0.8769 | Entropy: -1.8774
# Epoch [174] 📊 acc: 0.930 | Targets: 0.8738 | Entropy: -1.8766
# Epoch [175] 📊 acc: 0.930 | Targets: 0.8762 | Entropy: -1.8775
# Epoch [176] 📊 acc: 0.929 | Targets: 0.8763 | Entropy: -1.8776
# Epoch [177] 📊 acc: 0.933 | Targets: 0.8707 | Entropy: -1.8759
# New ref model saved
# Epoch [178] 📊 acc: 0.931 | Targets: 0.8749 | Entropy: -1.8770
# Epoch [179] 📊 acc: 0.933 | Targets: 0.8698 | Entropy: -1.8757
# New ref model saved
# Epoch [180] 📊 acc: 0.932 | Targets: 0.8713 | Entropy: -1.8762
#
# Evaluating at epoch 180 …
# Train Accuracy: 93.16%
# Train Average Loss: 0.8753
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 213551 (26.70%)
#   module1: 191640 (23.96%)
#   module2: 202119 (25.27%)
#   module3: 192434 (24.06%)
# Test Accuracy: 93.24%
# Test Average Loss: 0.8667
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42863 (26.79%)
#   module1: 38200 (23.87%)
#   module2: 40456 (25.28%)
#   module3: 38481 (24.05%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 3.46e-04
# New best model saved with test accuracy: 93.24%
# Epoch [181] 📊 acc: 0.931 | Targets: 0.8720 | Entropy: -1.8763
# Epoch [182] 📊 acc: 0.933 | Targets: 0.8711 | Entropy: -1.8761
# New ref model saved
# Epoch [183] 📊 acc: 0.935 | Targets: 0.8671 | Entropy: -1.8750
# New ref model saved
# Epoch [184] 📊 acc: 0.934 | Targets: 0.8679 | Entropy: -1.8749
# Epoch [185] 📊 acc: 0.933 | Targets: 0.8688 | Entropy: -1.8755
# Epoch [186] 📊 acc: 0.933 | Targets: 0.8678 | Entropy: -1.8748
# Epoch [187] 📊 acc: 0.936 | Targets: 0.8641 | Entropy: -1.8739
# New ref model saved
# Epoch [188] 📊 acc: 0.933 | Targets: 0.8680 | Entropy: -1.8750
# Epoch [189] 📊 acc: 0.935 | Targets: 0.8653 | Entropy: -1.8745
# Epoch [190] 📊 acc: 0.936 | Targets: 0.8641 | Entropy: -1.8743
# New ref model saved
#
# Evaluating at epoch 190 …
# Train Accuracy: 93.99%
# Train Average Loss: 0.8637
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 216065 (27.02%)
#   module1: 187796 (23.48%)
#   module2: 204210 (25.53%)
#   module3: 191673 (23.97%)
# Test Accuracy: 93.69%
# Test Average Loss: 0.8625
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 43056 (26.91%)
#   module1: 37876 (23.67%)
#   module2: 40524 (25.33%)
#   module3: 38544 (24.09%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 2.97e-04
# New best model saved with test accuracy: 93.69%
# Epoch [191] 📊 acc: 0.937 | Targets: 0.8629 | Entropy: -1.8741
# New ref model saved
# Epoch [192] 📊 acc: 0.936 | Targets: 0.8641 | Entropy: -1.8744
# Epoch [193] 📊 acc: 0.937 | Targets: 0.8628 | Entropy: -1.8740
# New ref model saved
# Epoch [194] 📊 acc: 0.937 | Targets: 0.8604 | Entropy: -1.8731
# New ref model saved
# Epoch [195] 📊 acc: 0.938 | Targets: 0.8604 | Entropy: -1.8732
# New ref model saved
# Epoch [196] 📊 acc: 0.936 | Targets: 0.8621 | Entropy: -1.8738
# Epoch [197] 📊 acc: 0.939 | Targets: 0.8591 | Entropy: -1.8730
# New ref model saved
# Epoch [198] 📊 acc: 0.939 | Targets: 0.8576 | Entropy: -1.8724
# New ref model saved
# Epoch [199] 📊 acc: 0.938 | Targets: 0.8598 | Entropy: -1.8736
# Epoch [200] 📊 acc: 0.940 | Targets: 0.8576 | Entropy: -1.8726
# New ref model saved
#
# Evaluating at epoch 200 …
# Train Accuracy: 93.80%
# Train Average Loss: 0.8585
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 214564 (26.83%)
#   module1: 192591 (24.08%)
#   module2: 204430 (25.56%)
#   module3: 188159 (23.53%)
# Test Accuracy: 93.95%
# Test Average Loss: 0.8491
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42862 (26.79%)
#   module1: 38542 (24.09%)
#   module2: 40553 (25.35%)
#   module3: 38043 (23.78%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 2.51e-04
# New best model saved with test accuracy: 93.95%
# Epoch [201] 📊 acc: 0.940 | Targets: 0.8571 | Entropy: -1.8724
# New ref model saved
# Epoch [202] 📊 acc: 0.938 | Targets: 0.8594 | Entropy: -1.8735
# Epoch [203] 📊 acc: 0.940 | Targets: 0.8578 | Entropy: -1.8727
# Epoch [204] 📊 acc: 0.940 | Targets: 0.8570 | Entropy: -1.8727
# New ref model saved
# Epoch [205] 📊 acc: 0.940 | Targets: 0.8564 | Entropy: -1.8723
# Epoch [206] 📊 acc: 0.940 | Targets: 0.8569 | Entropy: -1.8725
# New ref model saved
# Epoch [207] 📊 acc: 0.941 | Targets: 0.8551 | Entropy: -1.8721
# New ref model saved
# Epoch [208] 📊 acc: 0.940 | Targets: 0.8552 | Entropy: -1.8722
# Epoch [209] 📊 acc: 0.942 | Targets: 0.8538 | Entropy: -1.8715
# New ref model saved
# Epoch [210] 📊 acc: 0.942 | Targets: 0.8524 | Entropy: -1.8715
#
# Evaluating at epoch 210 …
# Train Accuracy: 94.26%
# Train Average Loss: 0.8500
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 215043 (26.89%)
#   module1: 191679 (23.97%)
#   module2: 206084 (25.77%)
#   module3: 186938 (23.37%)
# Test Accuracy: 93.96%
# Test Average Loss: 0.8502
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42951 (26.84%)
#   module1: 38418 (24.01%)
#   module2: 40923 (25.58%)
#   module3: 37708 (23.57%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 2.07e-04
# New best model saved with test accuracy: 93.96%
# Epoch [211] 📊 acc: 0.943 | Targets: 0.8512 | Entropy: -1.8709
# New ref model saved
# Epoch [212] 📊 acc: 0.943 | Targets: 0.8522 | Entropy: -1.8716
# Epoch [213] 📊 acc: 0.942 | Targets: 0.8531 | Entropy: -1.8720
# Epoch [214] 📊 acc: 0.943 | Targets: 0.8520 | Entropy: -1.8712
# Epoch [215] 📊 acc: 0.942 | Targets: 0.8510 | Entropy: -1.8713
# Epoch [216] 📊 acc: 0.943 | Targets: 0.8511 | Entropy: -1.8711
# New ref model saved
# Epoch [217] 📊 acc: 0.945 | Targets: 0.8475 | Entropy: -1.8700
# New ref model saved
# Epoch [218] 📊 acc: 0.943 | Targets: 0.8498 | Entropy: -1.8709
# Epoch [219] 📊 acc: 0.944 | Targets: 0.8478 | Entropy: -1.8703
# Epoch [220] 📊 acc: 0.945 | Targets: 0.8460 | Entropy: -1.8693
# New ref model saved
#
# Evaluating at epoch 220 …
# Train Accuracy: 94.57%
# Train Average Loss: 0.8463
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 214649 (26.84%)
#   module1: 189396 (23.68%)
#   module2: 204470 (25.57%)
#   module3: 191229 (23.91%)
# Test Accuracy: 94.17%
# Test Average Loss: 0.8476
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42933 (26.83%)
#   module1: 37618 (23.51%)
#   module2: 40803 (25.50%)
#   module3: 38646 (24.15%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 1.66e-04
# New best model saved with test accuracy: 94.17%
# Epoch [221] 📊 acc: 0.945 | Targets: 0.8493 | Entropy: -1.8707
# Epoch [222] 📊 acc: 0.944 | Targets: 0.8479 | Entropy: -1.8704
# Epoch [223] 📊 acc: 0.944 | Targets: 0.8483 | Entropy: -1.8706
# Epoch [224] 📊 acc: 0.947 | Targets: 0.8419 | Entropy: -1.8687
# New ref model saved
# Epoch [225] 📊 acc: 0.946 | Targets: 0.8457 | Entropy: -1.8696
# Epoch [226] 📊 acc: 0.947 | Targets: 0.8451 | Entropy: -1.8694
# Epoch [227] 📊 acc: 0.947 | Targets: 0.8419 | Entropy: -1.8686
# Epoch [228] 📊 acc: 0.946 | Targets: 0.8469 | Entropy: -1.8700
# Epoch [229] 📊 acc: 0.948 | Targets: 0.8432 | Entropy: -1.8690
# New ref model saved
# Epoch [230] 📊 acc: 0.946 | Targets: 0.8447 | Entropy: -1.8693
#
# Evaluating at epoch 230 …
# Train Accuracy: 94.67%
# Train Average Loss: 0.8465
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 215725 (26.97%)
#   module1: 191639 (23.96%)
#   module2: 203107 (25.40%)
#   module3: 189273 (23.67%)
# Test Accuracy: 94.09%
# Test Average Loss: 0.8501
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42946 (26.84%)
#   module1: 38311 (23.94%)
#   module2: 40390 (25.24%)
#   module3: 38353 (23.97%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 1.29e-04
# Epoch [231] 📊 acc: 0.946 | Targets: 0.8452 | Entropy: -1.8697
# Epoch [232] 📊 acc: 0.946 | Targets: 0.8455 | Entropy: -1.8697
# Epoch [233] 📊 acc: 0.949 | Targets: 0.8409 | Entropy: -1.8683
# New ref model saved
# Epoch [234] 📊 acc: 0.947 | Targets: 0.8419 | Entropy: -1.8686
# Epoch [235] 📊 acc: 0.945 | Targets: 0.8470 | Entropy: -1.8702
# Epoch [236] 📊 acc: 0.947 | Targets: 0.8421 | Entropy: -1.8688
# Epoch [237] 📊 acc: 0.948 | Targets: 0.8405 | Entropy: -1.8684
# Epoch [238] 📊 acc: 0.948 | Targets: 0.8416 | Entropy: -1.8687
# Epoch [239] 📊 acc: 0.950 | Targets: 0.8386 | Entropy: -1.8679
# New ref model saved
# Epoch [240] 📊 acc: 0.949 | Targets: 0.8404 | Entropy: -1.8686
#
# Evaluating at epoch 240 …
# Train Accuracy: 94.81%
# Train Average Loss: 0.8383
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 215838 (26.99%)
#   module1: 189458 (23.69%)
#   module2: 201928 (25.25%)
#   module3: 192520 (24.07%)
# Test Accuracy: 94.11%
# Test Average Loss: 0.8445
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42963 (26.85%)
#   module1: 38119 (23.82%)
#   module2: 40055 (25.03%)
#   module3: 38863 (24.29%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.64e-05
# Epoch [241] 📊 acc: 0.947 | Targets: 0.8436 | Entropy: -1.8691
# Epoch [242] 📊 acc: 0.949 | Targets: 0.8404 | Entropy: -1.8684
# Epoch [243] 📊 acc: 0.949 | Targets: 0.8389 | Entropy: -1.8681
# Epoch [244] 📊 acc: 0.949 | Targets: 0.8398 | Entropy: -1.8680
# Epoch [245] 📊 acc: 0.948 | Targets: 0.8403 | Entropy: -1.8683
# Epoch [246] 📊 acc: 0.950 | Targets: 0.8392 | Entropy: -1.8679
# Epoch [247] 📊 acc: 0.951 | Targets: 0.8356 | Entropy: -1.8671
# New ref model saved
# Epoch [248] 📊 acc: 0.950 | Targets: 0.8380 | Entropy: -1.8678
# Epoch [249] 📊 acc: 0.951 | Targets: 0.8355 | Entropy: -1.8670
# Epoch [250] 📊 acc: 0.950 | Targets: 0.8384 | Entropy: -1.8679
#
# Evaluating at epoch 250 …
# Train Accuracy: 95.08%
# Train Average Loss: 0.8375
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 215774 (26.98%)
#   module1: 189670 (23.72%)
#   module2: 203874 (25.49%)
#   module3: 190426 (23.81%)
# Test Accuracy: 94.51%
# Test Average Loss: 0.8447
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 42664 (26.66%)
#   module1: 38450 (24.03%)
#   module2: 40343 (25.21%)
#   module3: 38543 (24.09%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 6.79e-05
# New best model saved with test accuracy: 94.51%
# Epoch [251] 📊 acc: 0.949 | Targets: 0.8386 | Entropy: -1.8680
# Epoch [252] 📊 acc: 0.950 | Targets: 0.8384 | Entropy: -1.8681
# Epoch [253] 📊 acc: 0.950 | Targets: 0.8370 | Entropy: -1.8677
# Epoch [254] 📊 acc: 0.950 | Targets: 0.8365 | Entropy: -1.8672
# Epoch [255] 📊 acc: 0.949 | Targets: 0.8378 | Entropy: -1.8680
# Epoch [256] 📊 acc: 0.950 | Targets: 0.8359 | Entropy: -1.8671
# Epoch [257] 📊 acc: 0.949 | Targets: 0.8376 | Entropy: -1.8675
# Epoch [258] 📊 acc: 0.951 | Targets: 0.8366 | Entropy: -1.8675
# Epoch [259] 📊 acc: 0.952 | Targets: 0.8342 | Entropy: -1.8665
# New ref model saved
# Epoch [260] 📊 acc: 0.952 | Targets: 0.8333 | Entropy: -1.8665
# New ref model saved
#
# Evaluating at epoch 260 …
# Train Accuracy: 95.21%
# Train Average Loss: 0.8353
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 215398 (26.93%)
#   module1: 190143 (23.78%)
#   module2: 203532 (25.45%)
#   module3: 190671 (23.84%)
# Test Accuracy: 94.26%
# Test Average Loss: 0.8438
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 43040 (26.90%)
#   module1: 38354 (23.97%)
#   module2: 40267 (25.17%)
#   module3: 38339 (23.96%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 4.42e-05
# Epoch [261] 📊 acc: 0.949 | Targets: 0.8379 | Entropy: -1.8673
# Epoch [262] 📊 acc: 0.952 | Targets: 0.8339 | Entropy: -1.8667
# Epoch [263] 📊 acc: 0.952 | Targets: 0.8325 | Entropy: -1.8665
# New ref model saved
# Epoch [264] 📊 acc: 0.952 | Targets: 0.8324 | Entropy: -1.8660
# Epoch [265] 📊 acc: 0.952 | Targets: 0.8341 | Entropy: -1.8669
# New ref model saved
# Epoch [266] 📊 acc: 0.952 | Targets: 0.8340 | Entropy: -1.8668
# Epoch [267] 📊 acc: 0.952 | Targets: 0.8316 | Entropy: -1.8661
# Epoch [268] 📊 acc: 0.952 | Targets: 0.8335 | Entropy: -1.8664
# Epoch [269] 📊 acc: 0.952 | Targets: 0.8346 | Entropy: -1.8670
# Epoch [270] 📊 acc: 0.952 | Targets: 0.8332 | Entropy: -1.8663
#
# Evaluating at epoch 270 …
# Train Accuracy: 95.41%
# Train Average Loss: 0.8311
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 216738 (27.10%)
#   module1: 189889 (23.74%)
#   module2: 202877 (25.37%)
#   module3: 190240 (23.79%)
# Test Accuracy: 94.26%
# Test Average Loss: 0.8451
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 43094 (26.93%)
#   module1: 38587 (24.12%)
#   module2: 40272 (25.17%)
#   module3: 38047 (23.78%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 2.54e-05
# Epoch [271] 📊 acc: 0.951 | Targets: 0.8346 | Entropy: -1.8665
# Epoch [272] 📊 acc: 0.953 | Targets: 0.8311 | Entropy: -1.8660
# New ref model saved
# Epoch [273] 📊 acc: 0.953 | Targets: 0.8316 | Entropy: -1.8658
# New ref model saved
# Epoch [274] 📊 acc: 0.953 | Targets: 0.8305 | Entropy: -1.8658
# Epoch [275] 📊 acc: 0.952 | Targets: 0.8320 | Entropy: -1.8659
# Epoch [276] 📊 acc: 0.954 | Targets: 0.8304 | Entropy: -1.8659
# New ref model saved
# Epoch [277] 📊 acc: 0.952 | Targets: 0.8332 | Entropy: -1.8667
# Epoch [278] 📊 acc: 0.953 | Targets: 0.8319 | Entropy: -1.8661
# Epoch [279] 📊 acc: 0.951 | Targets: 0.8330 | Entropy: -1.8662
# Epoch [280] 📊 acc: 0.953 | Targets: 0.8312 | Entropy: -1.8662
#
# Evaluating at epoch 280 …
# Train Accuracy: 95.35%
# Train Average Loss: 0.8312
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 216992 (27.13%)
#   module1: 189146 (23.65%)
#   module2: 203203 (25.41%)
#   module3: 190403 (23.81%)
# Test Accuracy: 94.35%
# Test Average Loss: 0.8446
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 43207 (27.00%)
#   module1: 38126 (23.83%)
#   module2: 40686 (25.43%)
#   module3: 37981 (23.74%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 1.19e-05
# Epoch [281] 📊 acc: 0.954 | Targets: 0.8315 | Entropy: -1.8662
# Epoch [282] 📊 acc: 0.952 | Targets: 0.8321 | Entropy: -1.8661
# Epoch [283] 📊 acc: 0.953 | Targets: 0.8306 | Entropy: -1.8657
# Epoch [284] 📊 acc: 0.954 | Targets: 0.8312 | Entropy: -1.8663
# Epoch [285] 📊 acc: 0.952 | Targets: 0.8321 | Entropy: -1.8661
# Epoch [286] 📊 acc: 0.953 | Targets: 0.8298 | Entropy: -1.8653
# Epoch [287] 📊 acc: 0.951 | Targets: 0.8342 | Entropy: -1.8668
# Epoch [288] 📊 acc: 0.953 | Targets: 0.8315 | Entropy: -1.8666
# Epoch [289] 📊 acc: 0.955 | Targets: 0.8298 | Entropy: -1.8658
# New ref model saved
# Epoch [290] 📊 acc: 0.953 | Targets: 0.8300 | Entropy: -1.8655
#
# Evaluating at epoch 290 …
# Train Accuracy: 95.31%
# Train Average Loss: 0.8314
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 216040 (27.01%)
#   module1: 190354 (23.80%)
#   module2: 204267 (25.54%)
#   module3: 189083 (23.64%)
# Test Accuracy: 94.28%
# Test Average Loss: 0.8447
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 43206 (27.00%)
#   module1: 38452 (24.03%)
#   module2: 40708 (25.44%)
#   module3: 37634 (23.52%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 3.74e-06
# Epoch [291] 📊 acc: 0.954 | Targets: 0.8298 | Entropy: -1.8658
# Epoch [292] 📊 acc: 0.954 | Targets: 0.8297 | Entropy: -1.8654
# Epoch [293] 📊 acc: 0.954 | Targets: 0.8311 | Entropy: -1.8660
# Epoch [294] 📊 acc: 0.953 | Targets: 0.8312 | Entropy: -1.8659
# Epoch [295] 📊 acc: 0.953 | Targets: 0.8330 | Entropy: -1.8666
# Epoch [296] 📊 acc: 0.953 | Targets: 0.8312 | Entropy: -1.8659
# Epoch [297] 📊 acc: 0.954 | Targets: 0.8301 | Entropy: -1.8658
# Epoch [298] 📊 acc: 0.953 | Targets: 0.8313 | Entropy: -1.8659
# Epoch [299] 📊 acc: 0.954 | Targets: 0.8309 | Entropy: -1.8659
# Epoch [300] 📊 acc: 0.952 | Targets: 0.8324 | Entropy: -1.8664
#
# Evaluating at epoch 300 …
# Train Accuracy: 95.36%
# Train Average Loss: 0.8309
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 216489 (27.07%)
#   module1: 189113 (23.65%)
#   module2: 203807 (25.48%)
#   module3: 190335 (23.80%)
# Test Accuracy: 94.39%
# Test Average Loss: 0.8448
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 43124 (26.95%)
#   module1: 37904 (23.69%)
#   module2: 40790 (25.49%)
#   module3: 38182 (23.86%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 1.00e-06
# Finished Training
# Best test accuracy achieved: 94.51%
# Total Trainable Parameters: 1,942,286
