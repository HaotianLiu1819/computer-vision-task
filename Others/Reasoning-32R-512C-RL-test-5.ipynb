# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth):
        out = self.conv[depth // (self.max_depth // self.num_module)](x, depth)
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            x = checkpoint(self.step_forward, x, x_prev, d, use_reentrant=False)

        return x

# %%
class RecursionAmplifyConv(nn.Module):
    def __init__(self, channels, height, width):
        super(RecursionAmplifyConv, self).__init__()
        
        self.conv0 = nn.Conv2d(3, channels, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(channels, max_depth=32, num_module=1)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))


    def forward(self, x):
        
        x = self.conv0(x)

        x = self.amconv(x)

        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.reamconv= RecursionAmplifyConv(512, 32, 32)

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.reamconv(x)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        return x

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 1)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        pre_entropy = torch.sum(pre_probs * torch.log(pre_probs), dim=1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_pre_entropy = torch.sum(old_pre_probs * torch.log(old_pre_probs), dim=1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        ref_entropy = torch.sum(ref_probs * torch.log(ref_probs), dim=1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_ref_entropy = torch.sum(old_ref_probs * torch.log(old_ref_probs), dim=1)

        rewards, correct = self.compute_reconstruct_reward(outputs, targets)
        p_rewards, _ = self.compute_positive_reward(outputs, targets)
        n_rewards, _ = self.compute_negative_reward(outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        entropy_delta = (entropy - old_entropy)
        pre_entropy_delta = (pre_entropy - old_pre_entropy)
        ref_entropy_delta = (ref_entropy - old_ref_entropy)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
                'entropy': entropy.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)
    
    ref_count = 32
    
    select_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    select_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))

    entropy_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    entropy_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    
    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()
    all_params = list(net.parameters()) + list(pre_net.parameters()) + list(ref_net.parameters()) + [
        select_embeddings1, select_embeddings2,
        entropy_embeddings1, entropy_embeddings2,
    ]
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    rl_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    d = 0
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=300, eta_min=1e-6
            )
        
        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
            'rewards_mean': 0.0, 'rewards_std': 0.0, 
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs = net(inputs)
                ref_outputs = ref_net(inputs)
                pre_outputs = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_delta = F.tanh(select_delta) - 2 * F.sigmoid(select_embeddings1[d % ref_count]) * F.relu(F.tanh(pre_select_delta))
                select_delta = F.tanh(select_delta)
                select_delta = select_delta - 2 * F.sigmoid(select_embeddings2[d % ref_count]) * F.relu(F.tanh(ref_select_delta))
                
                select_loss = select_delta.sum()
                
                entropy_delta = F.tanh(entropy_delta) - 2 * F.sigmoid(entropy_embeddings1[d % ref_count]) * F.relu(F.tanh(pre_entropy_delta))
                entropy_delta = F.tanh(entropy_delta)           
                entropy_delta = entropy_delta - 2 * F.sigmoid(entropy_embeddings2[d % ref_count]) * F.relu(F.tanh(ref_entropy_delta))  

                entropy_loss = entropy_delta.sum()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f}")

        if running_cor > rl_accuracy:
            rl_accuracy = running_cor
            ref = copy.deepcopy(net).to(device)
            if d % 2 == 0:
                prev_ref.append(ref)
                prev_ref = prev_ref[-ref_count:]
            ref_net = prev_ref[((d % ref_count + 1) - ((d % ref_count + 1) & -(d % ref_count + 1))) // 2]
            pre_net = prev_ref[0]
            d += 1
            print(f"New ref model saved")
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
                    if use_bf16 else contextlib.nullcontext())

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = net(images)  
            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum    += batch_loss.item() * bs
            total_seen  += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 515,754

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.293 | Targets: 2.0238 | Entropy: -2.1400
# New ref model saved
# Epoch [2] 📊 acc: 0.465 | Targets: 1.6992 | Entropy: -2.0646
# New ref model saved
# Epoch [3] 📊 acc: 0.549 | Targets: 1.5592 | Entropy: -2.0258
# New ref model saved
# Epoch [4] 📊 acc: 0.595 | Targets: 1.4786 | Entropy: -2.0016
# New ref model saved
# Epoch [5] 📊 acc: 0.635 | Targets: 1.4139 | Entropy: -1.9872
# New ref model saved
# Epoch [6] 📊 acc: 0.663 | Targets: 1.3640 | Entropy: -1.9739
# New ref model saved
# Epoch [7] 📊 acc: 0.684 | Targets: 1.3314 | Entropy: -1.9660
# New ref model saved
# Epoch [8] 📊 acc: 0.700 | Targets: 1.3005 | Entropy: -1.9586
# New ref model saved
# Epoch [9] 📊 acc: 0.711 | Targets: 1.2799 | Entropy: -1.9542
# New ref model saved
# Epoch [10] 📊 acc: 0.723 | Targets: 1.2605 | Entropy: -1.9519
# New ref model saved
#
# Evaluating at epoch 10 …
# Train Accuracy: 72.72%
# Train Average Loss: 1.2798
# Test Accuracy: 78.82%
# Test Average Loss: 1.1784
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 78.82%
# Epoch [11] 📊 acc: 0.734 | Targets: 1.2375 | Entropy: -1.9457
# New ref model saved
# Epoch [12] 📊 acc: 0.743 | Targets: 1.2227 | Entropy: -1.9440
# New ref model saved
# Epoch [13] 📊 acc: 0.747 | Targets: 1.2124 | Entropy: -1.9427
# New ref model saved
# Epoch [14] 📊 acc: 0.758 | Targets: 1.1965 | Entropy: -1.9405
# New ref model saved
# Epoch [15] 📊 acc: 0.763 | Targets: 1.1874 | Entropy: -1.9376
# New ref model saved
# Epoch [16] 📊 acc: 0.770 | Targets: 1.1753 | Entropy: -1.9373
# New ref model saved
# Epoch [17] 📊 acc: 0.772 | Targets: 1.1656 | Entropy: -1.9336
# New ref model saved
# Epoch [18] 📊 acc: 0.780 | Targets: 1.1510 | Entropy: -1.9317
# New ref model saved
# Epoch [19] 📊 acc: 0.782 | Targets: 1.1488 | Entropy: -1.9320
# New ref model saved
# Epoch [20] 📊 acc: 0.786 | Targets: 1.1409 | Entropy: -1.9312
# New ref model saved
#
# Evaluating at epoch 20 …
# Train Accuracy: 79.72%
# Train Average Loss: 1.0950
# Test Accuracy: 84.84%
# Test Average Loss: 0.9960
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 84.84%
# Epoch [21] 📊 acc: 0.792 | Targets: 1.1326 | Entropy: -1.9299
# New ref model saved
# Epoch [22] 📊 acc: 0.796 | Targets: 1.1234 | Entropy: -1.9276
# New ref model saved
# Epoch [23] 📊 acc: 0.799 | Targets: 1.1197 | Entropy: -1.9278
# New ref model saved
# Epoch [24] 📊 acc: 0.806 | Targets: 1.1081 | Entropy: -1.9241
# New ref model saved
# Epoch [25] 📊 acc: 0.808 | Targets: 1.1010 | Entropy: -1.9236
# New ref model saved
# Epoch [26] 📊 acc: 0.809 | Targets: 1.0989 | Entropy: -1.9237
# New ref model saved
# Epoch [27] 📊 acc: 0.813 | Targets: 1.0936 | Entropy: -1.9231
# New ref model saved
# Epoch [28] 📊 acc: 0.815 | Targets: 1.0874 | Entropy: -1.9214
# New ref model saved
# Epoch [29] 📊 acc: 0.820 | Targets: 1.0826 | Entropy: -1.9207
# New ref model saved
# Epoch [30] 📊 acc: 0.820 | Targets: 1.0805 | Entropy: -1.9207
#
# Evaluating at epoch 30 …
# Train Accuracy: 81.74%
# Train Average Loss: 1.1039
# Test Accuracy: 85.76%
# Test Average Loss: 1.0235
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 85.76%
# Epoch [31] 📊 acc: 0.824 | Targets: 1.0732 | Entropy: -1.9189
# New ref model saved
# Epoch [32] 📊 acc: 0.823 | Targets: 1.0763 | Entropy: -1.9201
# Epoch [33] 📊 acc: 0.828 | Targets: 1.0658 | Entropy: -1.9178
# New ref model saved
# Epoch [34] 📊 acc: 0.829 | Targets: 1.0654 | Entropy: -1.9178
# New ref model saved
# Epoch [35] 📊 acc: 0.832 | Targets: 1.0586 | Entropy: -1.9161
# New ref model saved
# Epoch [36] 📊 acc: 0.833 | Targets: 1.0579 | Entropy: -1.9164
# New ref model saved
# Epoch [37] 📊 acc: 0.836 | Targets: 1.0502 | Entropy: -1.9142
# New ref model saved
# Epoch [38] 📊 acc: 0.838 | Targets: 1.0481 | Entropy: -1.9142
# New ref model saved
# Epoch [39] 📊 acc: 0.840 | Targets: 1.0456 | Entropy: -1.9139
# New ref model saved
# Epoch [40] 📊 acc: 0.838 | Targets: 1.0447 | Entropy: -1.9141
#
# Evaluating at epoch 40 …
# Train Accuracy: 85.08%
# Train Average Loss: 1.0150
# Test Accuracy: 88.14%
# Test Average Loss: 0.9536
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 88.14%
# Epoch [41] 📊 acc: 0.839 | Targets: 1.0431 | Entropy: -1.9134
# Epoch [42] 📊 acc: 0.840 | Targets: 1.0395 | Entropy: -1.9130
# Epoch [43] 📊 acc: 0.844 | Targets: 1.0346 | Entropy: -1.9114
# New ref model saved
# Epoch [44] 📊 acc: 0.845 | Targets: 1.0328 | Entropy: -1.9116
# New ref model saved
# Epoch [45] 📊 acc: 0.849 | Targets: 1.0259 | Entropy: -1.9094
# New ref model saved
# Epoch [46] 📊 acc: 0.852 | Targets: 1.0247 | Entropy: -1.9101
# New ref model saved
# Epoch [47] 📊 acc: 0.851 | Targets: 1.0230 | Entropy: -1.9094
# Epoch [48] 📊 acc: 0.853 | Targets: 1.0212 | Entropy: -1.9095
# New ref model saved
# Epoch [49] 📊 acc: 0.854 | Targets: 1.0191 | Entropy: -1.9086
# New ref model saved
# Epoch [50] 📊 acc: 0.852 | Targets: 1.0190 | Entropy: -1.9096
#
# Evaluating at epoch 50 …
# Train Accuracy: 84.45%
# Train Average Loss: 1.0216
# Test Accuracy: 88.73%
# Test Average Loss: 0.9441
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.33e-04
# New best model saved with test accuracy: 88.73%
# Epoch [51] 📊 acc: 0.856 | Targets: 1.0141 | Entropy: -1.9079
# New ref model saved
# Epoch [52] 📊 acc: 0.857 | Targets: 1.0138 | Entropy: -1.9080
# New ref model saved
# Epoch [53] 📊 acc: 0.857 | Targets: 1.0110 | Entropy: -1.9074
# Epoch [54] 📊 acc: 0.860 | Targets: 1.0062 | Entropy: -1.9062
# New ref model saved
# Epoch [55] 📊 acc: 0.861 | Targets: 1.0028 | Entropy: -1.9049
# New ref model saved
# Epoch [56] 📊 acc: 0.859 | Targets: 1.0083 | Entropy: -1.9072
# Epoch [57] 📊 acc: 0.863 | Targets: 1.0013 | Entropy: -1.9055
# New ref model saved
# Epoch [58] 📊 acc: 0.863 | Targets: 1.0005 | Entropy: -1.9054
# Epoch [59] 📊 acc: 0.867 | Targets: 0.9944 | Entropy: -1.9038
# New ref model saved
# Epoch [60] 📊 acc: 0.868 | Targets: 0.9923 | Entropy: -1.9033
# New ref model saved
#
# Evaluating at epoch 60 …
# Train Accuracy: 87.09%
# Train Average Loss: 0.9879
# Test Accuracy: 89.82%
# Test Average Loss: 0.9266
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 89.82%
# Epoch [61] 📊 acc: 0.867 | Targets: 0.9914 | Entropy: -1.9028
# Epoch [62] 📊 acc: 0.871 | Targets: 0.9866 | Entropy: -1.9020
# New ref model saved
# Epoch [63] 📊 acc: 0.869 | Targets: 0.9875 | Entropy: -1.9022
# Epoch [64] 📊 acc: 0.872 | Targets: 0.9842 | Entropy: -1.9011
# New ref model saved
# Epoch [65] 📊 acc: 0.873 | Targets: 0.9847 | Entropy: -1.9017
# New ref model saved
# Epoch [66] 📊 acc: 0.874 | Targets: 0.9808 | Entropy: -1.9011
# New ref model saved
# Epoch [67] 📊 acc: 0.875 | Targets: 0.9779 | Entropy: -1.9003
# New ref model saved
# Epoch [68] 📊 acc: 0.877 | Targets: 0.9765 | Entropy: -1.8994
# New ref model saved
# Epoch [69] 📊 acc: 0.876 | Targets: 0.9755 | Entropy: -1.8998
# Epoch [70] 📊 acc: 0.879 | Targets: 0.9721 | Entropy: -1.8989
# New ref model saved
#
# Evaluating at epoch 70 …
# Train Accuracy: 88.77%
# Train Average Loss: 0.9562
# Test Accuracy: 90.81%
# Test Average Loss: 0.9111
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.72e-04
# New best model saved with test accuracy: 90.81%
# Epoch [71] 📊 acc: 0.879 | Targets: 0.9716 | Entropy: -1.8988
# New ref model saved
# Epoch [72] 📊 acc: 0.879 | Targets: 0.9714 | Entropy: -1.8991
# New ref model saved
# Epoch [73] 📊 acc: 0.881 | Targets: 0.9677 | Entropy: -1.8979
# New ref model saved
# Epoch [74] 📊 acc: 0.882 | Targets: 0.9641 | Entropy: -1.8971
# New ref model saved
# Epoch [75] 📊 acc: 0.881 | Targets: 0.9662 | Entropy: -1.8976
# Epoch [76] 📊 acc: 0.880 | Targets: 0.9678 | Entropy: -1.8983
# Epoch [77] 📊 acc: 0.883 | Targets: 0.9635 | Entropy: -1.8968
# New ref model saved
# Epoch [78] 📊 acc: 0.883 | Targets: 0.9645 | Entropy: -1.8976
# Epoch [79] 📊 acc: 0.886 | Targets: 0.9577 | Entropy: -1.8959
# New ref model saved
# Epoch [80] 📊 acc: 0.884 | Targets: 0.9618 | Entropy: -1.8968
#
# Evaluating at epoch 80 …
# Train Accuracy: 89.19%
# Train Average Loss: 0.9408
# Test Accuracy: 90.50%
# Test Average Loss: 0.9090
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.35e-04
# Epoch [81] 📊 acc: 0.886 | Targets: 0.9584 | Entropy: -1.8959
# Epoch [82] 📊 acc: 0.887 | Targets: 0.9563 | Entropy: -1.8956
# New ref model saved
# Epoch [83] 📊 acc: 0.887 | Targets: 0.9560 | Entropy: -1.8960
# Epoch [84] 📊 acc: 0.888 | Targets: 0.9547 | Entropy: -1.8953
# New ref model saved
# Epoch [85] 📊 acc: 0.891 | Targets: 0.9496 | Entropy: -1.8940
# New ref model saved
# Epoch [86] 📊 acc: 0.889 | Targets: 0.9517 | Entropy: -1.8950
# Epoch [87] 📊 acc: 0.892 | Targets: 0.9464 | Entropy: -1.8932
# New ref model saved
# Epoch [88] 📊 acc: 0.891 | Targets: 0.9493 | Entropy: -1.8943
# Epoch [89] 📊 acc: 0.892 | Targets: 0.9479 | Entropy: -1.8939
# New ref model saved
# Epoch [90] 📊 acc: 0.892 | Targets: 0.9476 | Entropy: -1.8941
#
# Evaluating at epoch 90 …
# Train Accuracy: 87.75%
# Train Average Loss: 0.9793
# Test Accuracy: 89.62%
# Test Average Loss: 0.9379
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.94e-04
# Epoch [91] 📊 acc: 0.893 | Targets: 0.9434 | Entropy: -1.8925
# New ref model saved
# Epoch [92] 📊 acc: 0.893 | Targets: 0.9468 | Entropy: -1.8938
# Epoch [93] 📊 acc: 0.894 | Targets: 0.9424 | Entropy: -1.8927
# New ref model saved
# Epoch [94] 📊 acc: 0.894 | Targets: 0.9409 | Entropy: -1.8922
# Epoch [95] 📊 acc: 0.896 | Targets: 0.9381 | Entropy: -1.8917
# New ref model saved
# Epoch [96] 📊 acc: 0.897 | Targets: 0.9368 | Entropy: -1.8914
# New ref model saved
# Epoch [97] 📊 acc: 0.898 | Targets: 0.9368 | Entropy: -1.8917
# New ref model saved
# Epoch [98] 📊 acc: 0.898 | Targets: 0.9363 | Entropy: -1.8915
# New ref model saved
# Epoch [99] 📊 acc: 0.899 | Targets: 0.9352 | Entropy: -1.8915
# New ref model saved
# Epoch [100] 📊 acc: 0.898 | Targets: 0.9360 | Entropy: -1.8916
#
# Evaluating at epoch 100 …
# Train Accuracy: 90.22%
# Train Average Loss: 0.9205
# Test Accuracy: 91.41%
# Test Average Loss: 0.8861
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.50e-04
# New best model saved with test accuracy: 91.41%
# Epoch [101] 📊 acc: 0.899 | Targets: 0.9353 | Entropy: -1.8912
# New ref model saved
# Epoch [102] 📊 acc: 0.901 | Targets: 0.9301 | Entropy: -1.8904
# New ref model saved
# Epoch [103] 📊 acc: 0.902 | Targets: 0.9297 | Entropy: -1.8896
# New ref model saved
# Epoch [104] 📊 acc: 0.903 | Targets: 0.9290 | Entropy: -1.8897
# New ref model saved
# Epoch [105] 📊 acc: 0.903 | Targets: 0.9273 | Entropy: -1.8894
# New ref model saved
# Epoch [106] 📊 acc: 0.906 | Targets: 0.9241 | Entropy: -1.8885
# New ref model saved
# Epoch [107] 📊 acc: 0.904 | Targets: 0.9251 | Entropy: -1.8886
# Epoch [108] 📊 acc: 0.904 | Targets: 0.9240 | Entropy: -1.8884
# Epoch [109] 📊 acc: 0.907 | Targets: 0.9210 | Entropy: -1.8877
# New ref model saved
# Epoch [110] 📊 acc: 0.907 | Targets: 0.9191 | Entropy: -1.8875
#
# Evaluating at epoch 110 …
# Train Accuracy: 90.47%
# Train Average Loss: 0.9201
# Test Accuracy: 91.64%
# Test Average Loss: 0.8876
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.04e-04
# New best model saved with test accuracy: 91.64%
# Epoch [111] 📊 acc: 0.904 | Targets: 0.9222 | Entropy: -1.8877
# Epoch [112] 📊 acc: 0.908 | Targets: 0.9185 | Entropy: -1.8874
# New ref model saved
# Epoch [113] 📊 acc: 0.907 | Targets: 0.9196 | Entropy: -1.8877
# Epoch [114] 📊 acc: 0.909 | Targets: 0.9163 | Entropy: -1.8869
# New ref model saved
# Epoch [115] 📊 acc: 0.909 | Targets: 0.9154 | Entropy: -1.8865
# New ref model saved
# Epoch [116] 📊 acc: 0.909 | Targets: 0.9131 | Entropy: -1.8857
# Epoch [117] 📊 acc: 0.909 | Targets: 0.9147 | Entropy: -1.8862
# New ref model saved
# Epoch [118] 📊 acc: 0.908 | Targets: 0.9176 | Entropy: -1.8876
# Epoch [119] 📊 acc: 0.911 | Targets: 0.9127 | Entropy: -1.8859
# New ref model saved
# Epoch [120] 📊 acc: 0.911 | Targets: 0.9128 | Entropy: -1.8863
# New ref model saved
#
# Evaluating at epoch 120 …
# Train Accuracy: 91.18%
# Train Average Loss: 0.9124
# Test Accuracy: 91.95%
# Test Average Loss: 0.8847
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.55e-04
# New best model saved with test accuracy: 91.95%
# Epoch [121] 📊 acc: 0.911 | Targets: 0.9118 | Entropy: -1.8860
# New ref model saved
# Epoch [122] 📊 acc: 0.911 | Targets: 0.9092 | Entropy: -1.8853
# Epoch [123] 📊 acc: 0.913 | Targets: 0.9089 | Entropy: -1.8849
# New ref model saved
# Epoch [124] 📊 acc: 0.912 | Targets: 0.9091 | Entropy: -1.8853
# Epoch [125] 📊 acc: 0.914 | Targets: 0.9064 | Entropy: -1.8843
# New ref model saved
# Epoch [126] 📊 acc: 0.916 | Targets: 0.9030 | Entropy: -1.8835
# New ref model saved
# Epoch [127] 📊 acc: 0.916 | Targets: 0.9013 | Entropy: -1.8830
# New ref model saved
# Epoch [128] 📊 acc: 0.917 | Targets: 0.9005 | Entropy: -1.8829
# New ref model saved
# Epoch [129] 📊 acc: 0.917 | Targets: 0.9000 | Entropy: -1.8828
# New ref model saved
# Epoch [130] 📊 acc: 0.916 | Targets: 0.9001 | Entropy: -1.8829
#
# Evaluating at epoch 130 …
# Train Accuracy: 92.08%
# Train Average Loss: 0.8920
# Test Accuracy: 92.82%
# Test Average Loss: 0.8676
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.04e-04
# New best model saved with test accuracy: 92.82%
# Epoch [131] 📊 acc: 0.917 | Targets: 0.9015 | Entropy: -1.8833
# Epoch [132] 📊 acc: 0.917 | Targets: 0.8997 | Entropy: -1.8826
# Epoch [133] 📊 acc: 0.918 | Targets: 0.8986 | Entropy: -1.8825
# New ref model saved
# Epoch [134] 📊 acc: 0.918 | Targets: 0.8967 | Entropy: -1.8819
# New ref model saved
# Epoch [135] 📊 acc: 0.920 | Targets: 0.8957 | Entropy: -1.8819
# New ref model saved
# Epoch [136] 📊 acc: 0.919 | Targets: 0.8951 | Entropy: -1.8816
# Epoch [137] 📊 acc: 0.919 | Targets: 0.8948 | Entropy: -1.8815
# Epoch [138] 📊 acc: 0.921 | Targets: 0.8948 | Entropy: -1.8817
# New ref model saved
# Epoch [139] 📊 acc: 0.920 | Targets: 0.8928 | Entropy: -1.8807
# Epoch [140] 📊 acc: 0.919 | Targets: 0.8952 | Entropy: -1.8817
#
# Evaluating at epoch 140 …
# Train Accuracy: 92.18%
# Train Average Loss: 0.8921
# Test Accuracy: 92.48%
# Test Average Loss: 0.8769
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.53e-04
# Epoch [141] 📊 acc: 0.922 | Targets: 0.8912 | Entropy: -1.8808
# New ref model saved
# Epoch [142] 📊 acc: 0.921 | Targets: 0.8926 | Entropy: -1.8812
# Epoch [143] 📊 acc: 0.921 | Targets: 0.8927 | Entropy: -1.8812
# Epoch [144] 📊 acc: 0.921 | Targets: 0.8926 | Entropy: -1.8813
# Epoch [145] 📊 acc: 0.923 | Targets: 0.8877 | Entropy: -1.8799
# New ref model saved
# Epoch [146] 📊 acc: 0.925 | Targets: 0.8866 | Entropy: -1.8796
# New ref model saved
# Epoch [147] 📊 acc: 0.925 | Targets: 0.8851 | Entropy: -1.8793
# New ref model saved
# Epoch [148] 📊 acc: 0.924 | Targets: 0.8858 | Entropy: -1.8797
# Epoch [149] 📊 acc: 0.927 | Targets: 0.8837 | Entropy: -1.8789
# New ref model saved
# Epoch [150] 📊 acc: 0.925 | Targets: 0.8852 | Entropy: -1.8795
#
# Evaluating at epoch 150 …
# Train Accuracy: 92.74%
# Train Average Loss: 0.8757
# Test Accuracy: 92.85%
# Test Average Loss: 0.8619
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.01e-04
# New best model saved with test accuracy: 92.85%
# Epoch [151] 📊 acc: 0.924 | Targets: 0.8857 | Entropy: -1.8792
# Epoch [152] 📊 acc: 0.926 | Targets: 0.8824 | Entropy: -1.8789
# Epoch [153] 📊 acc: 0.924 | Targets: 0.8867 | Entropy: -1.8799
# Epoch [154] 📊 acc: 0.926 | Targets: 0.8821 | Entropy: -1.8789
# Epoch [155] 📊 acc: 0.929 | Targets: 0.8777 | Entropy: -1.8774
# New ref model saved
# Epoch [156] 📊 acc: 0.926 | Targets: 0.8812 | Entropy: -1.8784
# Epoch [157] 📊 acc: 0.930 | Targets: 0.8747 | Entropy: -1.8767
# New ref model saved
# Epoch [158] 📊 acc: 0.928 | Targets: 0.8788 | Entropy: -1.8778
# Epoch [159] 📊 acc: 0.927 | Targets: 0.8802 | Entropy: -1.8783
# Epoch [160] 📊 acc: 0.928 | Targets: 0.8787 | Entropy: -1.8778
#
# Evaluating at epoch 160 …
# Train Accuracy: 92.80%
# Train Average Loss: 0.8834
# Test Accuracy: 92.71%
# Test Average Loss: 0.8781
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.48e-04
# Epoch [161] 📊 acc: 0.929 | Targets: 0.8759 | Entropy: -1.8770
# Epoch [162] 📊 acc: 0.929 | Targets: 0.8797 | Entropy: -1.8783
# Epoch [163] 📊 acc: 0.931 | Targets: 0.8729 | Entropy: -1.8763
# New ref model saved
# Epoch [164] 📊 acc: 0.931 | Targets: 0.8723 | Entropy: -1.8760
# Epoch [165] 📊 acc: 0.930 | Targets: 0.8722 | Entropy: -1.8760
# Epoch [166] 📊 acc: 0.932 | Targets: 0.8711 | Entropy: -1.8759
# New ref model saved
# Epoch [167] 📊 acc: 0.930 | Targets: 0.8755 | Entropy: -1.8774
# Epoch [168] 📊 acc: 0.932 | Targets: 0.8702 | Entropy: -1.8755
# New ref model saved
# Epoch [169] 📊 acc: 0.933 | Targets: 0.8704 | Entropy: -1.8758
# New ref model saved
# Epoch [170] 📊 acc: 0.933 | Targets: 0.8697 | Entropy: -1.8757
# New ref model saved
#
# Evaluating at epoch 170 …
# Train Accuracy: 93.37%
# Train Average Loss: 0.8713
# Test Accuracy: 92.79%
# Test Average Loss: 0.8707
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.97e-04
# Epoch [171] 📊 acc: 0.933 | Targets: 0.8700 | Entropy: -1.8757
# New ref model saved
# Epoch [172] 📊 acc: 0.935 | Targets: 0.8662 | Entropy: -1.8750
# New ref model saved
# Epoch [173] 📊 acc: 0.934 | Targets: 0.8680 | Entropy: -1.8754
# Epoch [174] 📊 acc: 0.933 | Targets: 0.8695 | Entropy: -1.8755
# Epoch [175] 📊 acc: 0.936 | Targets: 0.8652 | Entropy: -1.8743
# New ref model saved
# Epoch [176] 📊 acc: 0.935 | Targets: 0.8650 | Entropy: -1.8746
# Epoch [177] 📊 acc: 0.935 | Targets: 0.8667 | Entropy: -1.8751
# Epoch [178] 📊 acc: 0.937 | Targets: 0.8615 | Entropy: -1.8733
# New ref model saved
# Epoch [179] 📊 acc: 0.938 | Targets: 0.8631 | Entropy: -1.8741
# New ref model saved
# Epoch [180] 📊 acc: 0.935 | Targets: 0.8657 | Entropy: -1.8743
#
# Evaluating at epoch 180 …
# Train Accuracy: 94.20%
# Train Average Loss: 0.8592
# Test Accuracy: 93.61%
# Test Average Loss: 0.8569
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.46e-04
# New best model saved with test accuracy: 93.61%
# Epoch [181] 📊 acc: 0.938 | Targets: 0.8603 | Entropy: -1.8731
# New ref model saved
# Epoch [182] 📊 acc: 0.934 | Targets: 0.8672 | Entropy: -1.8752
# Epoch [183] 📊 acc: 0.940 | Targets: 0.8576 | Entropy: -1.8728
# New ref model saved
# Epoch [184] 📊 acc: 0.937 | Targets: 0.8645 | Entropy: -1.8748
# Epoch [185] 📊 acc: 0.938 | Targets: 0.8602 | Entropy: -1.8734
# Epoch [186] 📊 acc: 0.939 | Targets: 0.8578 | Entropy: -1.8726
# Epoch [187] 📊 acc: 0.940 | Targets: 0.8558 | Entropy: -1.8722
# New ref model saved
# Epoch [188] 📊 acc: 0.939 | Targets: 0.8585 | Entropy: -1.8731
# Epoch [189] 📊 acc: 0.941 | Targets: 0.8549 | Entropy: -1.8716
# New ref model saved
# Epoch [190] 📊 acc: 0.940 | Targets: 0.8570 | Entropy: -1.8726
#
# Evaluating at epoch 190 …
# Train Accuracy: 94.17%
# Train Average Loss: 0.8576
# Test Accuracy: 93.30%
# Test Average Loss: 0.8631
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.97e-04
# Epoch [191] 📊 acc: 0.940 | Targets: 0.8566 | Entropy: -1.8724
# Epoch [192] 📊 acc: 0.940 | Targets: 0.8570 | Entropy: -1.8728
# Epoch [193] 📊 acc: 0.940 | Targets: 0.8575 | Entropy: -1.8727
# Epoch [194] 📊 acc: 0.942 | Targets: 0.8515 | Entropy: -1.8709
# New ref model saved
# Epoch [195] 📊 acc: 0.942 | Targets: 0.8540 | Entropy: -1.8719
# Epoch [196] 📊 acc: 0.941 | Targets: 0.8532 | Entropy: -1.8715
# Epoch [197] 📊 acc: 0.942 | Targets: 0.8531 | Entropy: -1.8714
# Epoch [198] 📊 acc: 0.942 | Targets: 0.8550 | Entropy: -1.8723
# Epoch [199] 📊 acc: 0.944 | Targets: 0.8489 | Entropy: -1.8703
# New ref model saved
# Epoch [200] 📊 acc: 0.943 | Targets: 0.8519 | Entropy: -1.8717
#
# Evaluating at epoch 200 …
# Train Accuracy: 94.19%
# Train Average Loss: 0.8505
# Test Accuracy: 93.60%
# Test Average Loss: 0.8547
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.51e-04
# Epoch [201] 📊 acc: 0.944 | Targets: 0.8490 | Entropy: -1.8703
# Epoch [202] 📊 acc: 0.944 | Targets: 0.8497 | Entropy: -1.8707
# Epoch [203] 📊 acc: 0.944 | Targets: 0.8489 | Entropy: -1.8706
# New ref model saved
# Epoch [204] 📊 acc: 0.944 | Targets: 0.8484 | Entropy: -1.8704
# Epoch [205] 📊 acc: 0.946 | Targets: 0.8458 | Entropy: -1.8695
# New ref model saved
# Epoch [206] 📊 acc: 0.946 | Targets: 0.8470 | Entropy: -1.8697
# Epoch [207] 📊 acc: 0.947 | Targets: 0.8448 | Entropy: -1.8697
# New ref model saved
# Epoch [208] 📊 acc: 0.947 | Targets: 0.8447 | Entropy: -1.8695
# Epoch [209] 📊 acc: 0.944 | Targets: 0.8483 | Entropy: -1.8705
# Epoch [210] 📊 acc: 0.946 | Targets: 0.8438 | Entropy: -1.8690
#
# Evaluating at epoch 210 …
# Train Accuracy: 94.65%
# Train Average Loss: 0.8463
# Test Accuracy: 93.92%
# Test Average Loss: 0.8513
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.07e-04
# New best model saved with test accuracy: 93.92%
# Epoch [211] 📊 acc: 0.945 | Targets: 0.8475 | Entropy: -1.8704
# Epoch [212] 📊 acc: 0.947 | Targets: 0.8425 | Entropy: -1.8687
# New ref model saved
# Epoch [213] 📊 acc: 0.946 | Targets: 0.8447 | Entropy: -1.8693
# Epoch [214] 📊 acc: 0.947 | Targets: 0.8448 | Entropy: -1.8698
# Epoch [215] 📊 acc: 0.948 | Targets: 0.8426 | Entropy: -1.8688
# New ref model saved
# Epoch [216] 📊 acc: 0.949 | Targets: 0.8407 | Entropy: -1.8686
# New ref model saved
# Epoch [217] 📊 acc: 0.947 | Targets: 0.8442 | Entropy: -1.8693
# Epoch [218] 📊 acc: 0.947 | Targets: 0.8438 | Entropy: -1.8688
# Epoch [219] 📊 acc: 0.948 | Targets: 0.8406 | Entropy: -1.8683
# Epoch [220] 📊 acc: 0.947 | Targets: 0.8422 | Entropy: -1.8690
#
# Evaluating at epoch 220 …
# Train Accuracy: 94.82%
# Train Average Loss: 0.8410
# Test Accuracy: 94.11%
# Test Average Loss: 0.8474
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.66e-04
# New best model saved with test accuracy: 94.11%
# Epoch [221] 📊 acc: 0.948 | Targets: 0.8410 | Entropy: -1.8685
# Epoch [222] 📊 acc: 0.950 | Targets: 0.8381 | Entropy: -1.8678
# New ref model saved
# Epoch [223] 📊 acc: 0.951 | Targets: 0.8373 | Entropy: -1.8675
# New ref model saved
# Epoch [224] 📊 acc: 0.950 | Targets: 0.8364 | Entropy: -1.8671
# Epoch [225] 📊 acc: 0.950 | Targets: 0.8368 | Entropy: -1.8674
# Epoch [226] 📊 acc: 0.951 | Targets: 0.8359 | Entropy: -1.8671
# New ref model saved
# Epoch [227] 📊 acc: 0.949 | Targets: 0.8402 | Entropy: -1.8687
# Epoch [228] 📊 acc: 0.952 | Targets: 0.8346 | Entropy: -1.8665
# New ref model saved
# Epoch [229] 📊 acc: 0.949 | Targets: 0.8388 | Entropy: -1.8681
# Epoch [230] 📊 acc: 0.952 | Targets: 0.8346 | Entropy: -1.8669
# New ref model saved
#
# Evaluating at epoch 230 …
# Train Accuracy: 94.97%
# Train Average Loss: 0.8401
# Test Accuracy: 93.95%
# Test Average Loss: 0.8492
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.29e-04
# Epoch [231] 📊 acc: 0.953 | Targets: 0.8342 | Entropy: -1.8669
# New ref model saved
# Epoch [232] 📊 acc: 0.950 | Targets: 0.8369 | Entropy: -1.8675
# Epoch [233] 📊 acc: 0.951 | Targets: 0.8353 | Entropy: -1.8669
# Epoch [234] 📊 acc: 0.953 | Targets: 0.8317 | Entropy: -1.8659
# New ref model saved
# Epoch [235] 📊 acc: 0.951 | Targets: 0.8358 | Entropy: -1.8671
# Epoch [236] 📊 acc: 0.952 | Targets: 0.8329 | Entropy: -1.8663
# Epoch [237] 📊 acc: 0.952 | Targets: 0.8336 | Entropy: -1.8667
# Epoch [238] 📊 acc: 0.953 | Targets: 0.8330 | Entropy: -1.8664
# Epoch [239] 📊 acc: 0.953 | Targets: 0.8322 | Entropy: -1.8659
# Epoch [240] 📊 acc: 0.953 | Targets: 0.8318 | Entropy: -1.8663
# New ref model saved
#
# Evaluating at epoch 240 …
# Train Accuracy: 95.37%
# Train Average Loss: 0.8296
# Test Accuracy: 94.20%
# Test Average Loss: 0.8447
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.64e-05
# New best model saved with test accuracy: 94.20%
# Epoch [241] 📊 acc: 0.952 | Targets: 0.8354 | Entropy: -1.8671
# Epoch [242] 📊 acc: 0.955 | Targets: 0.8290 | Entropy: -1.8656
# New ref model saved
# Epoch [243] 📊 acc: 0.954 | Targets: 0.8310 | Entropy: -1.8662
# Epoch [244] 📊 acc: 0.955 | Targets: 0.8291 | Entropy: -1.8654
# Epoch [245] 📊 acc: 0.953 | Targets: 0.8329 | Entropy: -1.8664
# Epoch [246] 📊 acc: 0.954 | Targets: 0.8311 | Entropy: -1.8658
# Epoch [247] 📊 acc: 0.953 | Targets: 0.8316 | Entropy: -1.8662
# Epoch [248] 📊 acc: 0.953 | Targets: 0.8313 | Entropy: -1.8661
# Epoch [249] 📊 acc: 0.954 | Targets: 0.8310 | Entropy: -1.8657
# Epoch [250] 📊 acc: 0.953 | Targets: 0.8313 | Entropy: -1.8660
#
# Evaluating at epoch 250 …
# Train Accuracy: 95.36%
# Train Average Loss: 0.8287
# Test Accuracy: 94.15%
# Test Average Loss: 0.8445
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.79e-05
# Epoch [251] 📊 acc: 0.955 | Targets: 0.8288 | Entropy: -1.8651
# Epoch [252] 📊 acc: 0.955 | Targets: 0.8297 | Entropy: -1.8657
# Epoch [253] 📊 acc: 0.954 | Targets: 0.8303 | Entropy: -1.8659
# Epoch [254] 📊 acc: 0.955 | Targets: 0.8294 | Entropy: -1.8659
# Epoch [255] 📊 acc: 0.957 | Targets: 0.8259 | Entropy: -1.8647
# New ref model saved
# Epoch [256] 📊 acc: 0.956 | Targets: 0.8273 | Entropy: -1.8655
# Epoch [257] 📊 acc: 0.955 | Targets: 0.8273 | Entropy: -1.8650
# Epoch [258] 📊 acc: 0.955 | Targets: 0.8279 | Entropy: -1.8653
# Epoch [259] 📊 acc: 0.956 | Targets: 0.8257 | Entropy: -1.8644
# Epoch [260] 📊 acc: 0.954 | Targets: 0.8287 | Entropy: -1.8652
#
# Evaluating at epoch 260 …
# Train Accuracy: 95.52%
# Train Average Loss: 0.8263
# Test Accuracy: 94.23%
# Test Average Loss: 0.8435
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.42e-05
# New best model saved with test accuracy: 94.23%
# Epoch [261] 📊 acc: 0.955 | Targets: 0.8280 | Entropy: -1.8654
# Epoch [262] 📊 acc: 0.956 | Targets: 0.8268 | Entropy: -1.8647
# Epoch [263] 📊 acc: 0.956 | Targets: 0.8268 | Entropy: -1.8652
# Epoch [264] 📊 acc: 0.956 | Targets: 0.8258 | Entropy: -1.8646
# Epoch [265] 📊 acc: 0.957 | Targets: 0.8248 | Entropy: -1.8645
# New ref model saved
# Epoch [266] 📊 acc: 0.956 | Targets: 0.8268 | Entropy: -1.8648
# Epoch [267] 📊 acc: 0.956 | Targets: 0.8258 | Entropy: -1.8645
# Epoch [268] 📊 acc: 0.957 | Targets: 0.8240 | Entropy: -1.8639
# Epoch [269] 📊 acc: 0.956 | Targets: 0.8260 | Entropy: -1.8646
# Epoch [270] 📊 acc: 0.957 | Targets: 0.8267 | Entropy: -1.8651
#
# Evaluating at epoch 270 …
# Train Accuracy: 95.69%
# Train Average Loss: 0.8243
# Test Accuracy: 94.21%
# Test Average Loss: 0.8442
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-05
# Epoch [271] 📊 acc: 0.957 | Targets: 0.8262 | Entropy: -1.8649
# Epoch [272] 📊 acc: 0.956 | Targets: 0.8270 | Entropy: -1.8652
# Epoch [273] 📊 acc: 0.957 | Targets: 0.8233 | Entropy: -1.8638
# New ref model saved
# Epoch [274] 📊 acc: 0.958 | Targets: 0.8236 | Entropy: -1.8642
# New ref model saved
# Epoch [275] 📊 acc: 0.957 | Targets: 0.8245 | Entropy: -1.8642
# Epoch [276] 📊 acc: 0.958 | Targets: 0.8248 | Entropy: -1.8645
# New ref model saved
# Epoch [277] 📊 acc: 0.958 | Targets: 0.8226 | Entropy: -1.8637
# Epoch [278] 📊 acc: 0.958 | Targets: 0.8242 | Entropy: -1.8647
# New ref model saved
# Epoch [279] 📊 acc: 0.955 | Targets: 0.8275 | Entropy: -1.8650
# Epoch [280] 📊 acc: 0.957 | Targets: 0.8255 | Entropy: -1.8644
#
# Evaluating at epoch 280 …
# Train Accuracy: 95.62%
# Train Average Loss: 0.8261
# Test Accuracy: 94.38%
# Test Average Loss: 0.8444
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.19e-05
# New best model saved with test accuracy: 94.38%
# Epoch [281] 📊 acc: 0.957 | Targets: 0.8240 | Entropy: -1.8644
# Epoch [282] 📊 acc: 0.957 | Targets: 0.8245 | Entropy: -1.8640
# Epoch [283] 📊 acc: 0.956 | Targets: 0.8261 | Entropy: -1.8648
# Epoch [284] 📊 acc: 0.958 | Targets: 0.8229 | Entropy: -1.8642
# New ref model saved
# Epoch [285] 📊 acc: 0.957 | Targets: 0.8236 | Entropy: -1.8641
# Epoch [286] 📊 acc: 0.958 | Targets: 0.8231 | Entropy: -1.8635
# Epoch [287] 📊 acc: 0.957 | Targets: 0.8242 | Entropy: -1.8644
# Epoch [288] 📊 acc: 0.957 | Targets: 0.8244 | Entropy: -1.8643
# Epoch [289] 📊 acc: 0.958 | Targets: 0.8235 | Entropy: -1.8644
# Epoch [290] 📊 acc: 0.957 | Targets: 0.8236 | Entropy: -1.8640
#
# Evaluating at epoch 290 …
# Train Accuracy: 95.73%
# Train Average Loss: 0.8239
# Test Accuracy: 94.39%
# Test Average Loss: 0.8421
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.74e-06
# New best model saved with test accuracy: 94.39%
# Epoch [291] 📊 acc: 0.957 | Targets: 0.8231 | Entropy: -1.8639
# Epoch [292] 📊 acc: 0.959 | Targets: 0.8203 | Entropy: -1.8632
# New ref model saved
# Epoch [293] 📊 acc: 0.958 | Targets: 0.8230 | Entropy: -1.8637
# Epoch [294] 📊 acc: 0.957 | Targets: 0.8246 | Entropy: -1.8644
# Epoch [295] 📊 acc: 0.957 | Targets: 0.8245 | Entropy: -1.8643
# Epoch [296] 📊 acc: 0.957 | Targets: 0.8243 | Entropy: -1.8646
# Epoch [297] 📊 acc: 0.959 | Targets: 0.8219 | Entropy: -1.8641
# Epoch [298] 📊 acc: 0.958 | Targets: 0.8241 | Entropy: -1.8644
# Epoch [299] 📊 acc: 0.957 | Targets: 0.8233 | Entropy: -1.8637
# Epoch [300] 📊 acc: 0.956 | Targets: 0.8253 | Entropy: -1.8642
#
# Evaluating at epoch 300 …
# Train Accuracy: 95.81%
# Train Average Loss: 0.8229
# Test Accuracy: 94.46%
# Test Average Loss: 0.8427
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-06
# New best model saved with test accuracy: 94.46%
# Finished Training
# Best test accuracy achieved: 94.46%
# Total Trainable Parameters: 515,754
