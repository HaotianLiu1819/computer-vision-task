# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth):
        out = self.conv[depth // (self.max_depth // self.num_module)](x, depth)
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            x = checkpoint(self.step_forward, x, x_prev, d, use_reentrant=False)

        return x

# %%
class RecursionAmplifyConv(nn.Module):
    def __init__(self, channels, height, width):
        super(RecursionAmplifyConv, self).__init__()
        
        self.conv0 = nn.Conv2d(3, channels, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(channels, max_depth=32, num_module=1)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))


    def forward(self, x):
        
        x = self.conv0(x)

        x = self.amconv(x)

        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.reamconv= RecursionAmplifyConv(512, 32, 32)

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.reamconv(x)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        return x

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 1)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        pre_entropy = torch.sum(pre_probs * torch.log(pre_probs), dim=1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_pre_entropy = torch.sum(old_pre_probs * torch.log(old_pre_probs), dim=1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        ref_entropy = torch.sum(ref_probs * torch.log(ref_probs), dim=1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_ref_entropy = torch.sum(old_ref_probs * torch.log(old_ref_probs), dim=1)

        rewards, correct = self.compute_reconstruct_reward(outputs, targets)
        p_rewards, _ = self.compute_positive_reward(outputs, targets)
        n_rewards, _ = self.compute_negative_reward(outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        entropy_delta = (entropy - old_entropy)
        pre_entropy_delta = (pre_entropy - old_pre_entropy)
        ref_entropy_delta = (ref_entropy - old_ref_entropy)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
                'entropy': entropy.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)
    
    ref_count = 32
    
    select_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    select_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))

    entropy_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    entropy_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    
    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()
    all_params = list(net.parameters()) + [
        select_embeddings1, select_embeddings2,
        entropy_embeddings1, entropy_embeddings2,
    ]
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    rl_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    d = 0
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=300, eta_min=1e-6
            )
        
        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
            'rewards_mean': 0.0, 'rewards_std': 0.0, 
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs = net(inputs)
                ref_outputs = ref_net(inputs)
                pre_outputs = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_delta = F.tanh(select_delta) - 2 * F.sigmoid(select_embeddings1[d % ref_count]) * F.relu(F.tanh(pre_select_delta))
                select_delta = F.tanh(select_delta)
                select_delta = select_delta - 2 * F.sigmoid(select_embeddings2[d % ref_count]) * F.relu(F.tanh(ref_select_delta))
                
                select_loss = select_delta.sum()
                
                entropy_delta = F.tanh(entropy_delta) - 2 * F.sigmoid(entropy_embeddings1[d % ref_count]) * F.relu(F.tanh(pre_entropy_delta))
                entropy_delta = F.tanh(entropy_delta)           
                entropy_delta = entropy_delta - 2 * F.sigmoid(entropy_embeddings2[d % ref_count]) * F.relu(F.tanh(ref_entropy_delta))  

                entropy_loss = entropy_delta.sum()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f}")

        if running_cor > rl_accuracy:
            rl_accuracy = running_cor
            ref = copy.deepcopy(net).to(device)
            if d % 2 == 0:
                prev_ref.append(ref)
                prev_ref = prev_ref[-ref_count:]
            ref_net = prev_ref[((d % ref_count + 1) - ((d % ref_count + 1) & -(d % ref_count + 1))) // 2]
            pre_net = prev_ref[0]
            d += 1
            print(f"New ref model saved")
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
                    if use_bf16 else contextlib.nullcontext())

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = net(images)  
            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum    += batch_loss.item() * bs
            total_seen  += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 515,754

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.281 | Targets: 2.0502 | Entropy: -2.1507
# New ref model saved
# Epoch [2] 📊 acc: 0.462 | Targets: 1.7070 | Entropy: -2.0656
# New ref model saved
# Epoch [3] 📊 acc: 0.542 | Targets: 1.5711 | Entropy: -2.0265
# New ref model saved
# Epoch [4] 📊 acc: 0.588 | Targets: 1.4907 | Entropy: -2.0046
# New ref model saved
# Epoch [5] 📊 acc: 0.626 | Targets: 1.4299 | Entropy: -1.9903
# New ref model saved
# Epoch [6] 📊 acc: 0.654 | Targets: 1.3786 | Entropy: -1.9772
# New ref model saved
# Epoch [7] 📊 acc: 0.677 | Targets: 1.3425 | Entropy: -1.9694
# New ref model saved
# Epoch [8] 📊 acc: 0.698 | Targets: 1.3047 | Entropy: -1.9609
# New ref model saved
# Epoch [9] 📊 acc: 0.704 | Targets: 1.2863 | Entropy: -1.9577
# New ref model saved
# Epoch [10] 📊 acc: 0.718 | Targets: 1.2642 | Entropy: -1.9536
# New ref model saved
#
# Evaluating at epoch 10 …
# Train Accuracy: 73.24%
# Train Average Loss: 1.2266
# Test Accuracy: 79.01%
# Test Average Loss: 1.1293
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 79.01%
# Epoch [11] 📊 acc: 0.728 | Targets: 1.2466 | Entropy: -1.9506
# New ref model saved
# Epoch [12] 📊 acc: 0.735 | Targets: 1.2337 | Entropy: -1.9495
# New ref model saved
# Epoch [13] 📊 acc: 0.748 | Targets: 1.2109 | Entropy: -1.9452
# New ref model saved
# Epoch [14] 📊 acc: 0.755 | Targets: 1.2007 | Entropy: -1.9430
# New ref model saved
# Epoch [15] 📊 acc: 0.762 | Targets: 1.1875 | Entropy: -1.9405
# New ref model saved
# Epoch [16] 📊 acc: 0.768 | Targets: 1.1757 | Entropy: -1.9378
# New ref model saved
# Epoch [17] 📊 acc: 0.774 | Targets: 1.1653 | Entropy: -1.9365
# New ref model saved
# Epoch [18] 📊 acc: 0.778 | Targets: 1.1567 | Entropy: -1.9350
# New ref model saved
# Epoch [19] 📊 acc: 0.784 | Targets: 1.1474 | Entropy: -1.9333
# New ref model saved
# Epoch [20] 📊 acc: 0.789 | Targets: 1.1393 | Entropy: -1.9320
# New ref model saved
#
# Evaluating at epoch 20 …
# Train Accuracy: 79.76%
# Train Average Loss: 1.1386
# Test Accuracy: 84.53%
# Test Average Loss: 1.0459
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 84.53%
# Epoch [21] 📊 acc: 0.792 | Targets: 1.1312 | Entropy: -1.9303
# New ref model saved
# Epoch [22] 📊 acc: 0.796 | Targets: 1.1237 | Entropy: -1.9297
# New ref model saved
# Epoch [23] 📊 acc: 0.797 | Targets: 1.1204 | Entropy: -1.9291
# New ref model saved
# Epoch [24] 📊 acc: 0.803 | Targets: 1.1109 | Entropy: -1.9263
# New ref model saved
# Epoch [25] 📊 acc: 0.804 | Targets: 1.1101 | Entropy: -1.9269
# New ref model saved
# Epoch [26] 📊 acc: 0.808 | Targets: 1.1014 | Entropy: -1.9259
# New ref model saved
# Epoch [27] 📊 acc: 0.811 | Targets: 1.0975 | Entropy: -1.9259
# New ref model saved
# Epoch [28] 📊 acc: 0.812 | Targets: 1.0958 | Entropy: -1.9259
# New ref model saved
# Epoch [29] 📊 acc: 0.813 | Targets: 1.0943 | Entropy: -1.9262
# New ref model saved
# Epoch [30] 📊 acc: 0.815 | Targets: 1.0885 | Entropy: -1.9248
# New ref model saved
#
# Evaluating at epoch 30 …
# Train Accuracy: 82.80%
# Train Average Loss: 1.0795
# Test Accuracy: 86.02%
# Test Average Loss: 1.0072
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 86.02%
# Epoch [31] 📊 acc: 0.816 | Targets: 1.0863 | Entropy: -1.9249
# New ref model saved
# Epoch [32] 📊 acc: 0.822 | Targets: 1.0780 | Entropy: -1.9239
# New ref model saved
# Epoch [33] 📊 acc: 0.825 | Targets: 1.0687 | Entropy: -1.9211
# New ref model saved
# Epoch [34] 📊 acc: 0.828 | Targets: 1.0644 | Entropy: -1.9207
# New ref model saved
# Epoch [35] 📊 acc: 0.831 | Targets: 1.0599 | Entropy: -1.9203
# New ref model saved
# Epoch [36] 📊 acc: 0.835 | Targets: 1.0532 | Entropy: -1.9184
# New ref model saved
# Epoch [37] 📊 acc: 0.838 | Targets: 1.0500 | Entropy: -1.9183
# New ref model saved
# Epoch [38] 📊 acc: 0.837 | Targets: 1.0489 | Entropy: -1.9181
# Epoch [39] 📊 acc: 0.842 | Targets: 1.0409 | Entropy: -1.9163
# New ref model saved
# Epoch [40] 📊 acc: 0.843 | Targets: 1.0388 | Entropy: -1.9161
# New ref model saved
#
# Evaluating at epoch 40 …
# Train Accuracy: 85.21%
# Train Average Loss: 1.0408
# Test Accuracy: 88.76%
# Test Average Loss: 0.9701
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 88.76%
# Epoch [41] 📊 acc: 0.845 | Targets: 1.0342 | Entropy: -1.9149
# New ref model saved
# Epoch [42] 📊 acc: 0.846 | Targets: 1.0320 | Entropy: -1.9148
# New ref model saved
# Epoch [43] 📊 acc: 0.849 | Targets: 1.0269 | Entropy: -1.9136
# New ref model saved
# Epoch [44] 📊 acc: 0.852 | Targets: 1.0242 | Entropy: -1.9130
# New ref model saved
# Epoch [45] 📊 acc: 0.852 | Targets: 1.0237 | Entropy: -1.9129
# New ref model saved
# Epoch [46] 📊 acc: 0.851 | Targets: 1.0242 | Entropy: -1.9134
# Epoch [47] 📊 acc: 0.856 | Targets: 1.0152 | Entropy: -1.9107
# New ref model saved
# Epoch [48] 📊 acc: 0.857 | Targets: 1.0120 | Entropy: -1.9104
# New ref model saved
# Epoch [49] 📊 acc: 0.857 | Targets: 1.0119 | Entropy: -1.9101
# New ref model saved
# Epoch [50] 📊 acc: 0.860 | Targets: 1.0073 | Entropy: -1.9093
# New ref model saved
#
# Evaluating at epoch 50 …
# Train Accuracy: 86.80%
# Train Average Loss: 0.9976
# Test Accuracy: 89.46%
# Test Average Loss: 0.9334
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.33e-04
# New best model saved with test accuracy: 89.46%
# Epoch [51] 📊 acc: 0.858 | Targets: 1.0103 | Entropy: -1.9103
# Epoch [52] 📊 acc: 0.863 | Targets: 1.0014 | Entropy: -1.9075
# New ref model saved
# Epoch [53] 📊 acc: 0.864 | Targets: 0.9980 | Entropy: -1.9066
# New ref model saved
# Epoch [54] 📊 acc: 0.865 | Targets: 0.9965 | Entropy: -1.9061
# New ref model saved
# Epoch [55] 📊 acc: 0.865 | Targets: 0.9993 | Entropy: -1.9073
# Epoch [56] 📊 acc: 0.867 | Targets: 0.9938 | Entropy: -1.9063
# New ref model saved
# Epoch [57] 📊 acc: 0.866 | Targets: 0.9945 | Entropy: -1.9058
# Epoch [58] 📊 acc: 0.867 | Targets: 0.9934 | Entropy: -1.9060
# New ref model saved
# Epoch [59] 📊 acc: 0.870 | Targets: 0.9905 | Entropy: -1.9055
# New ref model saved
# Epoch [60] 📊 acc: 0.872 | Targets: 0.9846 | Entropy: -1.9037
# New ref model saved
#
# Evaluating at epoch 60 …
# Train Accuracy: 87.27%
# Train Average Loss: 0.9680
# Test Accuracy: 90.42%
# Test Average Loss: 0.9157
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 90.42%
# Epoch [61] 📊 acc: 0.872 | Targets: 0.9855 | Entropy: -1.9041
# Epoch [62] 📊 acc: 0.872 | Targets: 0.9816 | Entropy: -1.9027
# New ref model saved
# Epoch [63] 📊 acc: 0.872 | Targets: 0.9832 | Entropy: -1.9032
# Epoch [64] 📊 acc: 0.875 | Targets: 0.9797 | Entropy: -1.9022
# New ref model saved
# Epoch [65] 📊 acc: 0.877 | Targets: 0.9771 | Entropy: -1.9020
# New ref model saved
# Epoch [66] 📊 acc: 0.876 | Targets: 0.9781 | Entropy: -1.9022
# Epoch [67] 📊 acc: 0.877 | Targets: 0.9766 | Entropy: -1.9023
# Epoch [68] 📊 acc: 0.879 | Targets: 0.9725 | Entropy: -1.9012
# New ref model saved
# Epoch [69] 📊 acc: 0.878 | Targets: 0.9747 | Entropy: -1.9017
# Epoch [70] 📊 acc: 0.879 | Targets: 0.9726 | Entropy: -1.9014
# New ref model saved
#
# Evaluating at epoch 70 …
# Train Accuracy: 88.56%
# Train Average Loss: 0.9554
# Test Accuracy: 91.29%
# Test Average Loss: 0.9089
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.72e-04
# New best model saved with test accuracy: 91.29%
# Epoch [71] 📊 acc: 0.880 | Targets: 0.9691 | Entropy: -1.9005
# New ref model saved
# Epoch [72] 📊 acc: 0.881 | Targets: 0.9663 | Entropy: -1.8993
# New ref model saved
# Epoch [73] 📊 acc: 0.882 | Targets: 0.9645 | Entropy: -1.8989
# New ref model saved
# Epoch [74] 📊 acc: 0.884 | Targets: 0.9629 | Entropy: -1.8984
# New ref model saved
# Epoch [75] 📊 acc: 0.886 | Targets: 0.9614 | Entropy: -1.8986
# New ref model saved
# Epoch [76] 📊 acc: 0.885 | Targets: 0.9595 | Entropy: -1.8979
# Epoch [77] 📊 acc: 0.886 | Targets: 0.9599 | Entropy: -1.8984
# Epoch [78] 📊 acc: 0.885 | Targets: 0.9588 | Entropy: -1.8979
# Epoch [79] 📊 acc: 0.887 | Targets: 0.9567 | Entropy: -1.8974
# New ref model saved
# Epoch [80] 📊 acc: 0.887 | Targets: 0.9563 | Entropy: -1.8970
#
# Evaluating at epoch 80 …
# Train Accuracy: 88.79%
# Train Average Loss: 0.9728
# Test Accuracy: 90.52%
# Test Average Loss: 0.9372
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.35e-04
# Epoch [81] 📊 acc: 0.891 | Targets: 0.9508 | Entropy: -1.8959
# New ref model saved
# Epoch [82] 📊 acc: 0.889 | Targets: 0.9535 | Entropy: -1.8963
# Epoch [83] 📊 acc: 0.891 | Targets: 0.9481 | Entropy: -1.8954
# New ref model saved
# Epoch [84] 📊 acc: 0.891 | Targets: 0.9475 | Entropy: -1.8950
# Epoch [85] 📊 acc: 0.892 | Targets: 0.9451 | Entropy: -1.8943
# New ref model saved
# Epoch [86] 📊 acc: 0.892 | Targets: 0.9483 | Entropy: -1.8951
# Epoch [87] 📊 acc: 0.893 | Targets: 0.9449 | Entropy: -1.8946
# New ref model saved
# Epoch [88] 📊 acc: 0.893 | Targets: 0.9449 | Entropy: -1.8942
# New ref model saved
# Epoch [89] 📊 acc: 0.896 | Targets: 0.9380 | Entropy: -1.8926
# New ref model saved
# Epoch [90] 📊 acc: 0.895 | Targets: 0.9416 | Entropy: -1.8934
#
# Evaluating at epoch 90 …
# Train Accuracy: 90.27%
# Train Average Loss: 0.9548
# Test Accuracy: 91.81%
# Test Average Loss: 0.9195
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.94e-04
# New best model saved with test accuracy: 91.81%
# Epoch [91] 📊 acc: 0.898 | Targets: 0.9356 | Entropy: -1.8920
# New ref model saved
# Epoch [92] 📊 acc: 0.896 | Targets: 0.9401 | Entropy: -1.8932
# Epoch [93] 📊 acc: 0.897 | Targets: 0.9395 | Entropy: -1.8931
# Epoch [94] 📊 acc: 0.897 | Targets: 0.9386 | Entropy: -1.8928
# Epoch [95] 📊 acc: 0.901 | Targets: 0.9317 | Entropy: -1.8912
# New ref model saved
# Epoch [96] 📊 acc: 0.898 | Targets: 0.9355 | Entropy: -1.8921
# Epoch [97] 📊 acc: 0.899 | Targets: 0.9357 | Entropy: -1.8923
# Epoch [98] 📊 acc: 0.901 | Targets: 0.9319 | Entropy: -1.8913
# Epoch [99] 📊 acc: 0.902 | Targets: 0.9280 | Entropy: -1.8899
# New ref model saved
# Epoch [100] 📊 acc: 0.904 | Targets: 0.9275 | Entropy: -1.8903
# New ref model saved
#
# Evaluating at epoch 100 …
# Train Accuracy: 90.50%
# Train Average Loss: 0.9210
# Test Accuracy: 92.10%
# Test Average Loss: 0.8927
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.50e-04
# New best model saved with test accuracy: 92.10%
# Epoch [101] 📊 acc: 0.902 | Targets: 0.9273 | Entropy: -1.8898
# Epoch [102] 📊 acc: 0.905 | Targets: 0.9258 | Entropy: -1.8899
# New ref model saved
# Epoch [103] 📊 acc: 0.904 | Targets: 0.9260 | Entropy: -1.8897
# Epoch [104] 📊 acc: 0.904 | Targets: 0.9253 | Entropy: -1.8899
# Epoch [105] 📊 acc: 0.904 | Targets: 0.9243 | Entropy: -1.8892
# Epoch [106] 📊 acc: 0.905 | Targets: 0.9222 | Entropy: -1.8887
# New ref model saved
# Epoch [107] 📊 acc: 0.905 | Targets: 0.9240 | Entropy: -1.8895
# New ref model saved
# Epoch [108] 📊 acc: 0.908 | Targets: 0.9167 | Entropy: -1.8874
# New ref model saved
# Epoch [109] 📊 acc: 0.906 | Targets: 0.9214 | Entropy: -1.8887
# Epoch [110] 📊 acc: 0.907 | Targets: 0.9189 | Entropy: -1.8880
#
# Evaluating at epoch 110 …
# Train Accuracy: 90.65%
# Train Average Loss: 0.9209
# Test Accuracy: 92.06%
# Test Average Loss: 0.8875
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.04e-04
# Epoch [111] 📊 acc: 0.906 | Targets: 0.9200 | Entropy: -1.8883
# Epoch [112] 📊 acc: 0.909 | Targets: 0.9133 | Entropy: -1.8864
# New ref model saved
# Epoch [113] 📊 acc: 0.908 | Targets: 0.9165 | Entropy: -1.8873
# Epoch [114] 📊 acc: 0.908 | Targets: 0.9146 | Entropy: -1.8871
# Epoch [115] 📊 acc: 0.908 | Targets: 0.9171 | Entropy: -1.8876
# Epoch [116] 📊 acc: 0.911 | Targets: 0.9117 | Entropy: -1.8865
# New ref model saved
# Epoch [117] 📊 acc: 0.910 | Targets: 0.9123 | Entropy: -1.8862
# Epoch [118] 📊 acc: 0.912 | Targets: 0.9110 | Entropy: -1.8864
# New ref model saved
# Epoch [119] 📊 acc: 0.913 | Targets: 0.9051 | Entropy: -1.8845
# New ref model saved
# Epoch [120] 📊 acc: 0.914 | Targets: 0.9050 | Entropy: -1.8846
# New ref model saved
#
# Evaluating at epoch 120 …
# Train Accuracy: 91.44%
# Train Average Loss: 0.9026
# Test Accuracy: 92.51%
# Test Average Loss: 0.8779
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.55e-04
# New best model saved with test accuracy: 92.51%
# Epoch [121] 📊 acc: 0.912 | Targets: 0.9113 | Entropy: -1.8867
# Epoch [122] 📊 acc: 0.913 | Targets: 0.9077 | Entropy: -1.8853
# Epoch [123] 📊 acc: 0.914 | Targets: 0.9063 | Entropy: -1.8850
# New ref model saved
# Epoch [124] 📊 acc: 0.917 | Targets: 0.9028 | Entropy: -1.8840
# New ref model saved
# Epoch [125] 📊 acc: 0.914 | Targets: 0.9054 | Entropy: -1.8847
# Epoch [126] 📊 acc: 0.915 | Targets: 0.9040 | Entropy: -1.8844
# Epoch [127] 📊 acc: 0.918 | Targets: 0.9002 | Entropy: -1.8837
# New ref model saved
# Epoch [128] 📊 acc: 0.918 | Targets: 0.8989 | Entropy: -1.8829
# Epoch [129] 📊 acc: 0.917 | Targets: 0.9006 | Entropy: -1.8839
# Epoch [130] 📊 acc: 0.918 | Targets: 0.9003 | Entropy: -1.8837
#
# Evaluating at epoch 130 …
# Train Accuracy: 91.92%
# Train Average Loss: 0.8983
# Test Accuracy: 92.52%
# Test Average Loss: 0.8830
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.04e-04
# New best model saved with test accuracy: 92.52%
# Epoch [131] 📊 acc: 0.918 | Targets: 0.8984 | Entropy: -1.8829
# Epoch [132] 📊 acc: 0.921 | Targets: 0.8937 | Entropy: -1.8819
# New ref model saved
# Epoch [133] 📊 acc: 0.920 | Targets: 0.8958 | Entropy: -1.8824
# Epoch [134] 📊 acc: 0.920 | Targets: 0.8943 | Entropy: -1.8818
# Epoch [135] 📊 acc: 0.920 | Targets: 0.8937 | Entropy: -1.8816
# Epoch [136] 📊 acc: 0.922 | Targets: 0.8918 | Entropy: -1.8816
# New ref model saved
# Epoch [137] 📊 acc: 0.920 | Targets: 0.8931 | Entropy: -1.8813
# Epoch [138] 📊 acc: 0.922 | Targets: 0.8918 | Entropy: -1.8816
# New ref model saved
# Epoch [139] 📊 acc: 0.920 | Targets: 0.8936 | Entropy: -1.8823
# Epoch [140] 📊 acc: 0.924 | Targets: 0.8882 | Entropy: -1.8805
# New ref model saved
#
# Evaluating at epoch 140 …
# Train Accuracy: 91.99%
# Train Average Loss: 0.8924
# Test Accuracy: 92.54%
# Test Average Loss: 0.8823
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.53e-04
# New best model saved with test accuracy: 92.54%
# Epoch [141] 📊 acc: 0.924 | Targets: 0.8880 | Entropy: -1.8802
# Epoch [142] 📊 acc: 0.924 | Targets: 0.8871 | Entropy: -1.8803
# Epoch [143] 📊 acc: 0.924 | Targets: 0.8864 | Entropy: -1.8798
# Epoch [144] 📊 acc: 0.925 | Targets: 0.8848 | Entropy: -1.8794
# New ref model saved
# Epoch [145] 📊 acc: 0.925 | Targets: 0.8850 | Entropy: -1.8797
# Epoch [146] 📊 acc: 0.924 | Targets: 0.8868 | Entropy: -1.8800
# Epoch [147] 📊 acc: 0.925 | Targets: 0.8862 | Entropy: -1.8802
# Epoch [148] 📊 acc: 0.925 | Targets: 0.8841 | Entropy: -1.8794
# Epoch [149] 📊 acc: 0.924 | Targets: 0.8847 | Entropy: -1.8795
# Epoch [150] 📊 acc: 0.927 | Targets: 0.8819 | Entropy: -1.8787
# New ref model saved
#
# Evaluating at epoch 150 …
# Train Accuracy: 92.71%
# Train Average Loss: 0.8828
# Test Accuracy: 92.89%
# Test Average Loss: 0.8750
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.01e-04
# New best model saved with test accuracy: 92.89%
# Epoch [151] 📊 acc: 0.927 | Targets: 0.8820 | Entropy: -1.8791
# New ref model saved
# Epoch [152] 📊 acc: 0.927 | Targets: 0.8817 | Entropy: -1.8787
# Epoch [153] 📊 acc: 0.927 | Targets: 0.8823 | Entropy: -1.8792
# Epoch [154] 📊 acc: 0.928 | Targets: 0.8793 | Entropy: -1.8782
# New ref model saved
# Epoch [155] 📊 acc: 0.929 | Targets: 0.8772 | Entropy: -1.8775
# New ref model saved
# Epoch [156] 📊 acc: 0.928 | Targets: 0.8803 | Entropy: -1.8784
# Epoch [157] 📊 acc: 0.930 | Targets: 0.8767 | Entropy: -1.8777
# New ref model saved
# Epoch [158] 📊 acc: 0.929 | Targets: 0.8767 | Entropy: -1.8772
# Epoch [159] 📊 acc: 0.929 | Targets: 0.8764 | Entropy: -1.8774
# Epoch [160] 📊 acc: 0.930 | Targets: 0.8744 | Entropy: -1.8769
#
# Evaluating at epoch 160 …
# Train Accuracy: 93.45%
# Train Average Loss: 0.8613
# Test Accuracy: 93.15%
# Test Average Loss: 0.8566
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.48e-04
# New best model saved with test accuracy: 93.15%
# Epoch [161] 📊 acc: 0.930 | Targets: 0.8732 | Entropy: -1.8766
# New ref model saved
# Epoch [162] 📊 acc: 0.932 | Targets: 0.8735 | Entropy: -1.8769
# New ref model saved
# Epoch [163] 📊 acc: 0.931 | Targets: 0.8738 | Entropy: -1.8766
# Epoch [164] 📊 acc: 0.933 | Targets: 0.8703 | Entropy: -1.8759
# New ref model saved
# Epoch [165] 📊 acc: 0.932 | Targets: 0.8719 | Entropy: -1.8765
# Epoch [166] 📊 acc: 0.931 | Targets: 0.8737 | Entropy: -1.8770
# Epoch [167] 📊 acc: 0.933 | Targets: 0.8706 | Entropy: -1.8758
# Epoch [168] 📊 acc: 0.933 | Targets: 0.8689 | Entropy: -1.8754
# Epoch [169] 📊 acc: 0.933 | Targets: 0.8703 | Entropy: -1.8763
# New ref model saved
# Epoch [170] 📊 acc: 0.935 | Targets: 0.8663 | Entropy: -1.8751
# New ref model saved
#
# Evaluating at epoch 170 …
# Train Accuracy: 93.36%
# Train Average Loss: 0.8724
# Test Accuracy: 92.97%
# Test Average Loss: 0.8749
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.97e-04
# Epoch [171] 📊 acc: 0.933 | Targets: 0.8685 | Entropy: -1.8755
# Epoch [172] 📊 acc: 0.935 | Targets: 0.8648 | Entropy: -1.8742
# New ref model saved
# Epoch [173] 📊 acc: 0.936 | Targets: 0.8655 | Entropy: -1.8750
# New ref model saved
# Epoch [174] 📊 acc: 0.935 | Targets: 0.8673 | Entropy: -1.8754
# Epoch [175] 📊 acc: 0.935 | Targets: 0.8659 | Entropy: -1.8751
# Epoch [176] 📊 acc: 0.937 | Targets: 0.8621 | Entropy: -1.8737
# New ref model saved
# Epoch [177] 📊 acc: 0.938 | Targets: 0.8607 | Entropy: -1.8736
# New ref model saved
# Epoch [178] 📊 acc: 0.937 | Targets: 0.8623 | Entropy: -1.8736
# Epoch [179] 📊 acc: 0.938 | Targets: 0.8595 | Entropy: -1.8732
# New ref model saved
# Epoch [180] 📊 acc: 0.939 | Targets: 0.8596 | Entropy: -1.8732
# New ref model saved
#
# Evaluating at epoch 180 …
# Train Accuracy: 93.66%
# Train Average Loss: 0.8621
# Test Accuracy: 93.17%
# Test Average Loss: 0.8633
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.46e-04
# New best model saved with test accuracy: 93.17%
# Epoch [181] 📊 acc: 0.939 | Targets: 0.8594 | Entropy: -1.8732
# Epoch [182] 📊 acc: 0.939 | Targets: 0.8574 | Entropy: -1.8727
# New ref model saved
# Epoch [183] 📊 acc: 0.939 | Targets: 0.8579 | Entropy: -1.8725
# Epoch [184] 📊 acc: 0.937 | Targets: 0.8607 | Entropy: -1.8736
# Epoch [185] 📊 acc: 0.939 | Targets: 0.8593 | Entropy: -1.8733
# Epoch [186] 📊 acc: 0.941 | Targets: 0.8559 | Entropy: -1.8726
# New ref model saved
# Epoch [187] 📊 acc: 0.941 | Targets: 0.8565 | Entropy: -1.8725
# Epoch [188] 📊 acc: 0.941 | Targets: 0.8545 | Entropy: -1.8720
# New ref model saved
# Epoch [189] 📊 acc: 0.942 | Targets: 0.8529 | Entropy: -1.8715
# New ref model saved
# Epoch [190] 📊 acc: 0.940 | Targets: 0.8552 | Entropy: -1.8721
#
# Evaluating at epoch 190 …
# Train Accuracy: 94.43%
# Train Average Loss: 0.8468
# Test Accuracy: 93.48%
# Test Average Loss: 0.8575
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.97e-04
# New best model saved with test accuracy: 93.48%
# Epoch [191] 📊 acc: 0.940 | Targets: 0.8568 | Entropy: -1.8729
# Epoch [192] 📊 acc: 0.941 | Targets: 0.8547 | Entropy: -1.8719
# Epoch [193] 📊 acc: 0.942 | Targets: 0.8526 | Entropy: -1.8718
# New ref model saved
# Epoch [194] 📊 acc: 0.943 | Targets: 0.8519 | Entropy: -1.8711
# New ref model saved
# Epoch [195] 📊 acc: 0.943 | Targets: 0.8521 | Entropy: -1.8713
# New ref model saved
# Epoch [196] 📊 acc: 0.943 | Targets: 0.8526 | Entropy: -1.8717
# Epoch [197] 📊 acc: 0.943 | Targets: 0.8501 | Entropy: -1.8709
# New ref model saved
# Epoch [198] 📊 acc: 0.943 | Targets: 0.8505 | Entropy: -1.8712
# Epoch [199] 📊 acc: 0.942 | Targets: 0.8531 | Entropy: -1.8721
# Epoch [200] 📊 acc: 0.947 | Targets: 0.8439 | Entropy: -1.8692
# New ref model saved
#
# Evaluating at epoch 200 …
# Train Accuracy: 94.55%
# Train Average Loss: 0.8452
# Test Accuracy: 93.52%
# Test Average Loss: 0.8595
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.51e-04
# New best model saved with test accuracy: 93.52%
# Epoch [201] 📊 acc: 0.945 | Targets: 0.8478 | Entropy: -1.8704
# Epoch [202] 📊 acc: 0.944 | Targets: 0.8492 | Entropy: -1.8707
# Epoch [203] 📊 acc: 0.945 | Targets: 0.8482 | Entropy: -1.8707
# Epoch [204] 📊 acc: 0.945 | Targets: 0.8469 | Entropy: -1.8702
# Epoch [205] 📊 acc: 0.946 | Targets: 0.8465 | Entropy: -1.8701
# Epoch [206] 📊 acc: 0.946 | Targets: 0.8451 | Entropy: -1.8694
# Epoch [207] 📊 acc: 0.947 | Targets: 0.8431 | Entropy: -1.8692
# New ref model saved
# Epoch [208] 📊 acc: 0.946 | Targets: 0.8450 | Entropy: -1.8692
# Epoch [209] 📊 acc: 0.945 | Targets: 0.8475 | Entropy: -1.8703
# Epoch [210] 📊 acc: 0.947 | Targets: 0.8422 | Entropy: -1.8691
# New ref model saved
#
# Evaluating at epoch 210 …
# Train Accuracy: 95.05%
# Train Average Loss: 0.8382
# Test Accuracy: 93.68%
# Test Average Loss: 0.8573
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.07e-04
# New best model saved with test accuracy: 93.68%
# Epoch [211] 📊 acc: 0.946 | Targets: 0.8460 | Entropy: -1.8701
# Epoch [212] 📊 acc: 0.948 | Targets: 0.8406 | Entropy: -1.8685
# New ref model saved
# Epoch [213] 📊 acc: 0.947 | Targets: 0.8417 | Entropy: -1.8683
# Epoch [214] 📊 acc: 0.949 | Targets: 0.8397 | Entropy: -1.8683
# New ref model saved
# Epoch [215] 📊 acc: 0.948 | Targets: 0.8420 | Entropy: -1.8690
# Epoch [216] 📊 acc: 0.949 | Targets: 0.8391 | Entropy: -1.8684
# Epoch [217] 📊 acc: 0.949 | Targets: 0.8407 | Entropy: -1.8685
# New ref model saved
# Epoch [218] 📊 acc: 0.949 | Targets: 0.8403 | Entropy: -1.8685
# New ref model saved
# Epoch [219] 📊 acc: 0.951 | Targets: 0.8369 | Entropy: -1.8674
# New ref model saved
# Epoch [220] 📊 acc: 0.949 | Targets: 0.8395 | Entropy: -1.8681
#
# Evaluating at epoch 220 …
# Train Accuracy: 94.83%
# Train Average Loss: 0.8403
# Test Accuracy: 93.89%
# Test Average Loss: 0.8542
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.66e-04
# New best model saved with test accuracy: 93.89%
# Epoch [221] 📊 acc: 0.950 | Targets: 0.8376 | Entropy: -1.8678
# Epoch [222] 📊 acc: 0.949 | Targets: 0.8384 | Entropy: -1.8680
# Epoch [223] 📊 acc: 0.950 | Targets: 0.8388 | Entropy: -1.8680
# Epoch [224] 📊 acc: 0.950 | Targets: 0.8377 | Entropy: -1.8679
# Epoch [225] 📊 acc: 0.950 | Targets: 0.8365 | Entropy: -1.8674
# Epoch [226] 📊 acc: 0.951 | Targets: 0.8369 | Entropy: -1.8673
# New ref model saved
# Epoch [227] 📊 acc: 0.949 | Targets: 0.8378 | Entropy: -1.8680
# Epoch [228] 📊 acc: 0.950 | Targets: 0.8373 | Entropy: -1.8681
# Epoch [229] 📊 acc: 0.953 | Targets: 0.8325 | Entropy: -1.8665
# New ref model saved
# Epoch [230] 📊 acc: 0.951 | Targets: 0.8343 | Entropy: -1.8669
#
# Evaluating at epoch 230 …
# Train Accuracy: 95.32%
# Train Average Loss: 0.8335
# Test Accuracy: 94.01%
# Test Average Loss: 0.8522
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.29e-04
# New best model saved with test accuracy: 94.01%
# Epoch [231] 📊 acc: 0.952 | Targets: 0.8326 | Entropy: -1.8668
# Epoch [232] 📊 acc: 0.950 | Targets: 0.8358 | Entropy: -1.8671
# Epoch [233] 📊 acc: 0.951 | Targets: 0.8351 | Entropy: -1.8671
# Epoch [234] 📊 acc: 0.954 | Targets: 0.8296 | Entropy: -1.8654
# New ref model saved
# Epoch [235] 📊 acc: 0.952 | Targets: 0.8342 | Entropy: -1.8667
# Epoch [236] 📊 acc: 0.953 | Targets: 0.8334 | Entropy: -1.8667
# Epoch [237] 📊 acc: 0.953 | Targets: 0.8313 | Entropy: -1.8660
# Epoch [238] 📊 acc: 0.953 | Targets: 0.8320 | Entropy: -1.8663
# Epoch [239] 📊 acc: 0.954 | Targets: 0.8298 | Entropy: -1.8654
# New ref model saved
# Epoch [240] 📊 acc: 0.954 | Targets: 0.8309 | Entropy: -1.8660
#
# Evaluating at epoch 240 …
# Train Accuracy: 95.45%
# Train Average Loss: 0.8325
# Test Accuracy: 93.96%
# Test Average Loss: 0.8537
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.64e-05
# Epoch [241] 📊 acc: 0.952 | Targets: 0.8348 | Entropy: -1.8672
# Epoch [242] 📊 acc: 0.954 | Targets: 0.8312 | Entropy: -1.8662
# New ref model saved
# Epoch [243] 📊 acc: 0.955 | Targets: 0.8285 | Entropy: -1.8655
# New ref model saved
# Epoch [244] 📊 acc: 0.953 | Targets: 0.8316 | Entropy: -1.8663
# Epoch [245] 📊 acc: 0.956 | Targets: 0.8273 | Entropy: -1.8648
# New ref model saved
# Epoch [246] 📊 acc: 0.954 | Targets: 0.8307 | Entropy: -1.8662
# Epoch [247] 📊 acc: 0.954 | Targets: 0.8295 | Entropy: -1.8654
# Epoch [248] 📊 acc: 0.955 | Targets: 0.8288 | Entropy: -1.8660
# Epoch [249] 📊 acc: 0.956 | Targets: 0.8275 | Entropy: -1.8654
# Epoch [250] 📊 acc: 0.956 | Targets: 0.8273 | Entropy: -1.8650
#
# Evaluating at epoch 250 …
# Train Accuracy: 95.66%
# Train Average Loss: 0.8254
# Test Accuracy: 93.97%
# Test Average Loss: 0.8518
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.79e-05
# Epoch [251] 📊 acc: 0.957 | Targets: 0.8261 | Entropy: -1.8647
# New ref model saved
# Epoch [252] 📊 acc: 0.956 | Targets: 0.8271 | Entropy: -1.8650
# Epoch [253] 📊 acc: 0.955 | Targets: 0.8274 | Entropy: -1.8650
# Epoch [254] 📊 acc: 0.956 | Targets: 0.8266 | Entropy: -1.8650
# Epoch [255] 📊 acc: 0.957 | Targets: 0.8249 | Entropy: -1.8642
# New ref model saved
# Epoch [256] 📊 acc: 0.956 | Targets: 0.8258 | Entropy: -1.8648
# Epoch [257] 📊 acc: 0.956 | Targets: 0.8273 | Entropy: -1.8652
# Epoch [258] 📊 acc: 0.955 | Targets: 0.8266 | Entropy: -1.8648
# Epoch [259] 📊 acc: 0.956 | Targets: 0.8252 | Entropy: -1.8647
# Epoch [260] 📊 acc: 0.956 | Targets: 0.8256 | Entropy: -1.8642
#
# Evaluating at epoch 260 …
# Train Accuracy: 95.77%
# Train Average Loss: 0.8221
# Test Accuracy: 94.07%
# Test Average Loss: 0.8505
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.42e-05
# New best model saved with test accuracy: 94.07%
# Epoch [261] 📊 acc: 0.955 | Targets: 0.8281 | Entropy: -1.8651
# Epoch [262] 📊 acc: 0.957 | Targets: 0.8255 | Entropy: -1.8649
# Epoch [263] 📊 acc: 0.958 | Targets: 0.8231 | Entropy: -1.8639
# New ref model saved
# Epoch [264] 📊 acc: 0.955 | Targets: 0.8283 | Entropy: -1.8655
# Epoch [265] 📊 acc: 0.957 | Targets: 0.8241 | Entropy: -1.8643
# Epoch [266] 📊 acc: 0.957 | Targets: 0.8265 | Entropy: -1.8651
# Epoch [267] 📊 acc: 0.957 | Targets: 0.8241 | Entropy: -1.8647
# Epoch [268] 📊 acc: 0.958 | Targets: 0.8225 | Entropy: -1.8637
# Epoch [269] 📊 acc: 0.957 | Targets: 0.8252 | Entropy: -1.8646
# Epoch [270] 📊 acc: 0.958 | Targets: 0.8239 | Entropy: -1.8647
# New ref model saved
#
# Evaluating at epoch 270 …
# Train Accuracy: 95.70%
# Train Average Loss: 0.8219
# Test Accuracy: 94.19%
# Test Average Loss: 0.8474
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-05
# New best model saved with test accuracy: 94.19%
# Epoch [271] 📊 acc: 0.957 | Targets: 0.8234 | Entropy: -1.8638
# Epoch [272] 📊 acc: 0.957 | Targets: 0.8246 | Entropy: -1.8644
# Epoch [273] 📊 acc: 0.958 | Targets: 0.8238 | Entropy: -1.8640
# New ref model saved
# Epoch [274] 📊 acc: 0.957 | Targets: 0.8230 | Entropy: -1.8637
# Epoch [275] 📊 acc: 0.957 | Targets: 0.8233 | Entropy: -1.8641
# Epoch [276] 📊 acc: 0.958 | Targets: 0.8233 | Entropy: -1.8641
# Epoch [277] 📊 acc: 0.957 | Targets: 0.8230 | Entropy: -1.8643
# Epoch [278] 📊 acc: 0.956 | Targets: 0.8270 | Entropy: -1.8650
# Epoch [279] 📊 acc: 0.958 | Targets: 0.8237 | Entropy: -1.8644
# Epoch [280] 📊 acc: 0.959 | Targets: 0.8218 | Entropy: -1.8639
# New ref model saved
#
# Evaluating at epoch 280 …
# Train Accuracy: 95.70%
# Train Average Loss: 0.8222
# Test Accuracy: 94.31%
# Test Average Loss: 0.8468
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.19e-05
# New best model saved with test accuracy: 94.31%
# Epoch [281] 📊 acc: 0.958 | Targets: 0.8223 | Entropy: -1.8639
# Epoch [282] 📊 acc: 0.959 | Targets: 0.8216 | Entropy: -1.8635
# Epoch [283] 📊 acc: 0.959 | Targets: 0.8212 | Entropy: -1.8633
# Epoch [284] 📊 acc: 0.959 | Targets: 0.8204 | Entropy: -1.8630
# New ref model saved
# Epoch [285] 📊 acc: 0.958 | Targets: 0.8228 | Entropy: -1.8640
# Epoch [286] 📊 acc: 0.957 | Targets: 0.8237 | Entropy: -1.8638
# Epoch [287] 📊 acc: 0.958 | Targets: 0.8218 | Entropy: -1.8635
# Epoch [288] 📊 acc: 0.957 | Targets: 0.8240 | Entropy: -1.8644
# Epoch [289] 📊 acc: 0.957 | Targets: 0.8237 | Entropy: -1.8641
# Epoch [290] 📊 acc: 0.957 | Targets: 0.8245 | Entropy: -1.8646
#
# Evaluating at epoch 290 …
# Train Accuracy: 95.77%
# Train Average Loss: 0.8224
# Test Accuracy: 94.24%
# Test Average Loss: 0.8482
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.74e-06
# Epoch [291] 📊 acc: 0.958 | Targets: 0.8225 | Entropy: -1.8640
# Epoch [292] 📊 acc: 0.957 | Targets: 0.8228 | Entropy: -1.8640
# Epoch [293] 📊 acc: 0.959 | Targets: 0.8217 | Entropy: -1.8635
# Epoch [294] 📊 acc: 0.960 | Targets: 0.8196 | Entropy: -1.8632
# New ref model saved
# Epoch [295] 📊 acc: 0.959 | Targets: 0.8212 | Entropy: -1.8634
# Epoch [296] 📊 acc: 0.959 | Targets: 0.8220 | Entropy: -1.8639
# Epoch [297] 📊 acc: 0.957 | Targets: 0.8219 | Entropy: -1.8633
# Epoch [298] 📊 acc: 0.958 | Targets: 0.8225 | Entropy: -1.8635
# Epoch [299] 📊 acc: 0.958 | Targets: 0.8229 | Entropy: -1.8638
# Epoch [300] 📊 acc: 0.959 | Targets: 0.8216 | Entropy: -1.8638
#
# Evaluating at epoch 300 …
# Train Accuracy: 95.76%
# Train Average Loss: 0.8226
# Test Accuracy: 94.21%
# Test Average Loss: 0.8481
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-06
# Finished Training
# Best test accuracy achieved: 94.31%
# Total Trainable Parameters: 515,754
