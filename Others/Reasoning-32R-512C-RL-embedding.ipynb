# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth):
        out = self.conv[depth // (self.max_depth // self.num_module)](x, depth)
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        if depth < self.max_depth - 1:
            x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            x = checkpoint(self.step_forward, x, x_prev, d, use_reentrant=False)

        return x

# %%
class RecursionAmplifyConv(nn.Module):
    def __init__(self, channels, height, width):
        super(RecursionAmplifyConv, self).__init__()
        
        self.conv0 = nn.Conv2d(3, channels, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(channels, max_depth=32, num_module=1)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))


    def forward(self, x):
        
        x = self.conv0(x)

        x = self.amconv(x)

        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.reamconv= RecursionAmplifyConv(512, 32, 32)

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.reamconv(x)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        return x

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 1)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        pre_entropy = torch.sum(pre_probs * torch.log(pre_probs), dim=1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_pre_entropy = torch.sum(old_pre_probs * torch.log(old_pre_probs), dim=1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        ref_entropy = torch.sum(ref_probs * torch.log(ref_probs), dim=1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_ref_entropy = torch.sum(old_ref_probs * torch.log(old_ref_probs), dim=1)

        rewards, correct = self.compute_reconstruct_reward(outputs, targets)
        p_rewards, _ = self.compute_positive_reward(outputs, targets)
        n_rewards, _ = self.compute_negative_reward(outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        entropy_delta = (entropy - old_entropy)
        pre_entropy_delta = (pre_entropy - old_pre_entropy)
        ref_entropy_delta = (ref_entropy - old_ref_entropy)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
                'entropy': entropy.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)
    
    ref_count = 32
    
    select_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    select_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))

    entropy_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    entropy_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    
    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()
    all_params = list(net.parameters()) + [
        select_embeddings1, select_embeddings2,
        entropy_embeddings1, entropy_embeddings2,
    ]
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    rl_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    d = 0
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=300, eta_min=1e-6
            )
        
        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
            'rewards_mean': 0.0, 'rewards_std': 0.0, 
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs = net(inputs)
                ref_outputs = ref_net(inputs)
                pre_outputs = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_delta = F.sigmoid(select_delta) - 2 * F.sigmoid(select_embeddings1[d % ref_count]) * F.sigmoid(pre_select_delta)
                select_delta = F.tanh(select_delta)
                select_delta = select_delta - 2 * F.sigmoid(select_embeddings2[d % ref_count]) * F.sigmoid(ref_select_delta)
                
                select_loss = select_delta.sum()
                
                entropy_delta = F.sigmoid(entropy_delta) - 2 * F.sigmoid(entropy_embeddings1[d % ref_count]) * F.sigmoid(pre_entropy_delta)
                entropy_delta = F.tanh(entropy_delta)           
                entropy_delta = entropy_delta - 2 * F.sigmoid(entropy_embeddings2[d % ref_count]) * F.sigmoid(ref_entropy_delta)  

                entropy_loss = entropy_delta.sum()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f}")

        if running_cor > rl_accuracy:
            rl_accuracy = running_cor
            ref = copy.deepcopy(net).to(device)
            if d % 2 == 0:
                prev_ref.append(ref)
                prev_ref = prev_ref[-ref_count:]
            ref_net = prev_ref[((d % ref_count + 1) - ((d % ref_count + 1) & -(d % ref_count + 1))) // 2]
            pre_net = prev_ref[0]
            d += 1
            print(f"New ref model saved")
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
                    if use_bf16 else contextlib.nullcontext())

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = net(images)  
            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum    += batch_loss.item() * bs
            total_seen  += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 515,754

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.308 | Targets: 1.9917 | Entropy: -2.1479
# New ref model saved
# Epoch [2] 📊 acc: 0.489 | Targets: 1.6799 | Entropy: -2.0813
# New ref model saved
# Epoch [3] 📊 acc: 0.568 | Targets: 1.5573 | Entropy: -2.0500
# New ref model saved
# Epoch [4] 📊 acc: 0.619 | Targets: 1.5122 | Entropy: -2.0627
# New ref model saved
# Epoch [5] 📊 acc: 0.651 | Targets: 1.4116 | Entropy: -2.0038
# New ref model saved
# Epoch [6] 📊 acc: 0.676 | Targets: 1.3464 | Entropy: -1.9713
# New ref model saved
# Epoch [7] 📊 acc: 0.699 | Targets: 1.3284 | Entropy: -1.9823
# New ref model saved
# Epoch [8] 📊 acc: 0.715 | Targets: 1.3492 | Entropy: -2.0231
# New ref model saved
# Epoch [9] 📊 acc: 0.725 | Targets: 1.3197 | Entropy: -2.0108
# New ref model saved
# Epoch [10] 📊 acc: 0.735 | Targets: 1.2545 | Entropy: -1.9597
# New ref model saved
#
# Evaluating at epoch 10 …
# Train Accuracy: 74.40%
# Train Average Loss: 1.2060
# Test Accuracy: 80.55%
# Test Average Loss: 1.0889
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 80.55%
# Epoch [11] 📊 acc: 0.747 | Targets: 1.2309 | Entropy: -1.9542
# New ref model saved
# Epoch [12] 📊 acc: 0.753 | Targets: 1.2181 | Entropy: -1.9508
# New ref model saved
# Epoch [13] 📊 acc: 0.761 | Targets: 1.1863 | Entropy: -1.9272
# New ref model saved
# Epoch [14] 📊 acc: 0.769 | Targets: 1.1914 | Entropy: -1.9440
# New ref model saved
# Epoch [15] 📊 acc: 0.775 | Targets: 1.2094 | Entropy: -1.9707
# New ref model saved
# Epoch [16] 📊 acc: 0.778 | Targets: 1.2310 | Entropy: -1.9982
# New ref model saved
# Epoch [17] 📊 acc: 0.783 | Targets: 1.1538 | Entropy: -1.9288
# New ref model saved
# Epoch [18] 📊 acc: 0.789 | Targets: 1.1983 | Entropy: -1.9818
# New ref model saved
# Epoch [19] 📊 acc: 0.789 | Targets: 1.1592 | Entropy: -1.9460
# Epoch [20] 📊 acc: 0.791 | Targets: 1.1584 | Entropy: -1.9484
# New ref model saved
#
# Evaluating at epoch 20 …
# Train Accuracy: 80.24%
# Train Average Loss: 1.1682
# Test Accuracy: 85.20%
# Test Average Loss: 1.0801
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 85.20%
# Epoch [21] 📊 acc: 0.797 | Targets: 1.1329 | Entropy: -1.9315
# New ref model saved
# Epoch [22] 📊 acc: 0.803 | Targets: 1.1306 | Entropy: -1.9373
# New ref model saved
# Epoch [23] 📊 acc: 0.802 | Targets: 1.1042 | Entropy: -1.9103
# Epoch [24] 📊 acc: 0.809 | Targets: 1.0858 | Entropy: -1.9002
# New ref model saved
# Epoch [25] 📊 acc: 0.812 | Targets: 1.1003 | Entropy: -1.9216
# New ref model saved
# Epoch [26] 📊 acc: 0.817 | Targets: 1.0960 | Entropy: -1.9229
# New ref model saved
# Epoch [27] 📊 acc: 0.817 | Targets: 1.0158 | Entropy: -1.8337
# Epoch [28] 📊 acc: 0.818 | Targets: 1.0287 | Entropy: -1.8539
# New ref model saved
# Epoch [29] 📊 acc: 0.824 | Targets: 1.0768 | Entropy: -1.9149
# New ref model saved
# Epoch [30] 📊 acc: 0.825 | Targets: 1.1144 | Entropy: -1.9562
# New ref model saved
#
# Evaluating at epoch 30 …
# Train Accuracy: 83.44%
# Train Average Loss: 1.0868
# Test Accuracy: 87.48%
# Test Average Loss: 1.0026
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 87.48%
# Epoch [31] 📊 acc: 0.825 | Targets: 1.0480 | Entropy: -1.8884
# New ref model saved
# Epoch [32] 📊 acc: 0.826 | Targets: 1.0230 | Entropy: -1.8648
# New ref model saved
# Epoch [33] 📊 acc: 0.831 | Targets: 1.0537 | Entropy: -1.9026
# New ref model saved
# Epoch [34] 📊 acc: 0.833 | Targets: 1.0923 | Entropy: -1.9453
# New ref model saved
# Epoch [35] 📊 acc: 0.835 | Targets: 1.0563 | Entropy: -1.9137
# New ref model saved
# Epoch [36] 📊 acc: 0.834 | Targets: 1.0166 | Entropy: -1.8721
# Epoch [37] 📊 acc: 0.840 | Targets: 1.0246 | Entropy: -1.8875
# New ref model saved
# Epoch [38] 📊 acc: 0.841 | Targets: 1.0488 | Entropy: -1.9157
# New ref model saved
# Epoch [39] 📊 acc: 0.839 | Targets: 1.0573 | Entropy: -1.9242
# Epoch [40] 📊 acc: 0.843 | Targets: 1.0464 | Entropy: -1.9180
# New ref model saved
#
# Evaluating at epoch 40 …
# Train Accuracy: 84.87%
# Train Average Loss: 1.0444
# Test Accuracy: 88.72%
# Test Average Loss: 0.9675
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 88.72%
# Epoch [41] 📊 acc: 0.845 | Targets: 1.0650 | Entropy: -1.9384
# New ref model saved
# Epoch [42] 📊 acc: 0.847 | Targets: 1.0390 | Entropy: -1.9147
# New ref model saved
# Epoch [43] 📊 acc: 0.847 | Targets: 0.9955 | Entropy: -1.8701
# Epoch [44] 📊 acc: 0.849 | Targets: 1.0014 | Entropy: -1.8820
# New ref model saved
# Epoch [45] 📊 acc: 0.850 | Targets: 1.0326 | Entropy: -1.9149
# New ref model saved
# Epoch [46] 📊 acc: 0.853 | Targets: 1.0605 | Entropy: -1.9455
# New ref model saved
# Epoch [47] 📊 acc: 0.853 | Targets: 1.0565 | Entropy: -1.9411
# Epoch [48] 📊 acc: 0.852 | Targets: 1.0381 | Entropy: -1.9254
# Epoch [49] 📊 acc: 0.857 | Targets: 1.0292 | Entropy: -1.9193
# New ref model saved
# Epoch [50] 📊 acc: 0.858 | Targets: 0.9835 | Entropy: -1.8734
# New ref model saved
#
# Evaluating at epoch 50 …
# Train Accuracy: 86.23%
# Train Average Loss: 0.9822
# Test Accuracy: 89.35%
# Test Average Loss: 0.9166
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.33e-04
# New best model saved with test accuracy: 89.35%
# Epoch [51] 📊 acc: 0.858 | Targets: 1.0231 | Entropy: -1.9175
# New ref model saved
# Epoch [52] 📊 acc: 0.860 | Targets: 1.0131 | Entropy: -1.9081
# New ref model saved
# Epoch [53] 📊 acc: 0.862 | Targets: 1.0340 | Entropy: -1.9335
# New ref model saved
# Epoch [54] 📊 acc: 0.861 | Targets: 1.0248 | Entropy: -1.9236
# Epoch [55] 📊 acc: 0.861 | Targets: 1.0184 | Entropy: -1.9171
# Epoch [56] 📊 acc: 0.863 | Targets: 1.0099 | Entropy: -1.9119
# New ref model saved
# Epoch [57] 📊 acc: 0.867 | Targets: 1.0501 | Entropy: -1.9542
# New ref model saved
# Epoch [58] 📊 acc: 0.864 | Targets: 1.0314 | Entropy: -1.9337
# Epoch [59] 📊 acc: 0.870 | Targets: 1.0059 | Entropy: -1.9168
# New ref model saved
# Epoch [60] 📊 acc: 0.869 | Targets: 0.9568 | Entropy: -1.8637
#
# Evaluating at epoch 60 …
# Train Accuracy: 87.39%
# Train Average Loss: 0.9675
# Test Accuracy: 89.95%
# Test Average Loss: 0.9073
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 89.95%
# Epoch [61] 📊 acc: 0.869 | Targets: 0.9650 | Entropy: -1.8755
# Epoch [62] 📊 acc: 0.870 | Targets: 0.9714 | Entropy: -1.8832
# New ref model saved
# Epoch [63] 📊 acc: 0.875 | Targets: 1.0502 | Entropy: -1.9632
# New ref model saved
# Epoch [64] 📊 acc: 0.872 | Targets: 0.9909 | Entropy: -1.9079
# Epoch [65] 📊 acc: 0.873 | Targets: 0.9875 | Entropy: -1.9044
# Epoch [66] 📊 acc: 0.874 | Targets: 0.9833 | Entropy: -1.9023
# Epoch [67] 📊 acc: 0.876 | Targets: 0.9826 | Entropy: -1.9018
# New ref model saved
# Epoch [68] 📊 acc: 0.876 | Targets: 0.9735 | Entropy: -1.8934
# New ref model saved
# Epoch [69] 📊 acc: 0.880 | Targets: 0.9781 | Entropy: -1.9029
# New ref model saved
# Epoch [70] 📊 acc: 0.876 | Targets: 0.9651 | Entropy: -1.8856
#
# Evaluating at epoch 70 …
# Train Accuracy: 87.89%
# Train Average Loss: 0.9629
# Test Accuracy: 90.69%
# Test Average Loss: 0.9045
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.72e-04
# New best model saved with test accuracy: 90.69%
# Epoch [71] 📊 acc: 0.878 | Targets: 0.9646 | Entropy: -1.8898
# Epoch [72] 📊 acc: 0.881 | Targets: 0.9656 | Entropy: -1.8921
# New ref model saved
# Epoch [73] 📊 acc: 0.881 | Targets: 0.9786 | Entropy: -1.9072
# New ref model saved
# Epoch [74] 📊 acc: 0.883 | Targets: 0.9695 | Entropy: -1.9006
# New ref model saved
# Epoch [75] 📊 acc: 0.885 | Targets: 0.9341 | Entropy: -1.8642
# New ref model saved
# Epoch [76] 📊 acc: 0.884 | Targets: 0.9589 | Entropy: -1.8927
# Epoch [77] 📊 acc: 0.884 | Targets: 0.9617 | Entropy: -1.8946
# Epoch [78] 📊 acc: 0.884 | Targets: 0.9614 | Entropy: -1.8947
# Epoch [79] 📊 acc: 0.886 | Targets: 0.9583 | Entropy: -1.8942
# New ref model saved
# Epoch [80] 📊 acc: 0.886 | Targets: 1.0011 | Entropy: -1.9353
#
# Evaluating at epoch 80 …
# Train Accuracy: 88.86%
# Train Average Loss: 0.9816
# Test Accuracy: 91.08%
# Test Average Loss: 0.9332
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.35e-04
# New best model saved with test accuracy: 91.08%
# Epoch [81] 📊 acc: 0.887 | Targets: 0.9821 | Entropy: -1.9198
# New ref model saved
# Epoch [82] 📊 acc: 0.887 | Targets: 0.9274 | Entropy: -1.8628
# Epoch [83] 📊 acc: 0.888 | Targets: 0.9359 | Entropy: -1.8741
# New ref model saved
# Epoch [84] 📊 acc: 0.890 | Targets: 0.9249 | Entropy: -1.8654
# New ref model saved
# Epoch [85] 📊 acc: 0.891 | Targets: 0.8675 | Entropy: -1.8007
# New ref model saved
# Epoch [86] 📊 acc: 0.891 | Targets: 0.9846 | Entropy: -1.9284
# New ref model saved
# Epoch [87] 📊 acc: 0.893 | Targets: 0.9456 | Entropy: -1.8913
# New ref model saved
# Epoch [88] 📊 acc: 0.893 | Targets: 0.9364 | Entropy: -1.8812
# New ref model saved
# Epoch [89] 📊 acc: 0.894 | Targets: 0.9463 | Entropy: -1.8933
# New ref model saved
# Epoch [90] 📊 acc: 0.893 | Targets: 0.9492 | Entropy: -1.8948
#
# Evaluating at epoch 90 …
# Train Accuracy: 89.85%
# Train Average Loss: 0.9311
# Test Accuracy: 91.41%
# Test Average Loss: 0.8922
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.94e-04
# New best model saved with test accuracy: 91.41%
# Epoch [91] 📊 acc: 0.892 | Targets: 0.9463 | Entropy: -1.8930
# Epoch [92] 📊 acc: 0.895 | Targets: 0.9440 | Entropy: -1.8917
# New ref model saved
# Epoch [93] 📊 acc: 0.896 | Targets: 0.9503 | Entropy: -1.9007
# New ref model saved
# Epoch [94] 📊 acc: 0.897 | Targets: 0.9416 | Entropy: -1.8925
# New ref model saved
# Epoch [95] 📊 acc: 0.897 | Targets: 0.9274 | Entropy: -1.8787
# New ref model saved
# Epoch [96] 📊 acc: 0.897 | Targets: 0.9407 | Entropy: -1.8932
# Epoch [97] 📊 acc: 0.898 | Targets: 0.9362 | Entropy: -1.8906
# New ref model saved
# Epoch [98] 📊 acc: 0.899 | Targets: 0.9517 | Entropy: -1.9059
# New ref model saved
# Epoch [99] 📊 acc: 0.900 | Targets: 0.9398 | Entropy: -1.8946
# New ref model saved
# Epoch [100] 📊 acc: 0.900 | Targets: 0.9147 | Entropy: -1.8711
# New ref model saved
#
# Evaluating at epoch 100 …
# Train Accuracy: 90.54%
# Train Average Loss: 0.9236
# Test Accuracy: 92.00%
# Test Average Loss: 0.8915
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.50e-04
# New best model saved with test accuracy: 92.00%
# Epoch [101] 📊 acc: 0.903 | Targets: 0.9364 | Entropy: -1.8949
# New ref model saved
# Epoch [102] 📊 acc: 0.901 | Targets: 0.9323 | Entropy: -1.8901
# Epoch [103] 📊 acc: 0.901 | Targets: 0.9310 | Entropy: -1.8889
# Epoch [104] 📊 acc: 0.903 | Targets: 0.9285 | Entropy: -1.8884
# New ref model saved
# Epoch [105] 📊 acc: 0.905 | Targets: 0.9457 | Entropy: -1.9082
# New ref model saved
# Epoch [106] 📊 acc: 0.903 | Targets: 0.9322 | Entropy: -1.8919
# Epoch [107] 📊 acc: 0.904 | Targets: 0.9281 | Entropy: -1.8896
# Epoch [108] 📊 acc: 0.904 | Targets: 0.9269 | Entropy: -1.8889
# Epoch [109] 📊 acc: 0.905 | Targets: 0.9238 | Entropy: -1.8877
# Epoch [110] 📊 acc: 0.908 | Targets: 0.9179 | Entropy: -1.8858
# New ref model saved
#
# Evaluating at epoch 110 …
# Train Accuracy: 90.71%
# Train Average Loss: 0.9236
# Test Accuracy: 92.37%
# Test Average Loss: 0.8891
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.04e-04
# New best model saved with test accuracy: 92.37%
# Epoch [111] 📊 acc: 0.906 | Targets: 0.9495 | Entropy: -1.9140
# Epoch [112] 📊 acc: 0.907 | Targets: 0.9348 | Entropy: -1.9023
# Epoch [113] 📊 acc: 0.907 | Targets: 0.9319 | Entropy: -1.8981
# Epoch [114] 📊 acc: 0.906 | Targets: 0.9287 | Entropy: -1.8948
# Epoch [115] 📊 acc: 0.909 | Targets: 0.9234 | Entropy: -1.8918
# New ref model saved
# Epoch [116] 📊 acc: 0.909 | Targets: 0.9237 | Entropy: -1.8925
# New ref model saved
# Epoch [117] 📊 acc: 0.910 | Targets: 0.9054 | Entropy: -1.8762
# New ref model saved
# Epoch [118] 📊 acc: 0.911 | Targets: 0.9478 | Entropy: -1.9189
# New ref model saved
# Epoch [119] 📊 acc: 0.912 | Targets: 0.9101 | Entropy: -1.8844
# New ref model saved
# Epoch [120] 📊 acc: 0.912 | Targets: 0.9068 | Entropy: -1.8803
# New ref model saved
#
# Evaluating at epoch 120 …
# Train Accuracy: 91.29%
# Train Average Loss: 0.9024
# Test Accuracy: 92.37%
# Test Average Loss: 0.8828
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.55e-04
# Epoch [121] 📊 acc: 0.912 | Targets: 0.9152 | Entropy: -1.8870
# Epoch [122] 📊 acc: 0.913 | Targets: 0.9078 | Entropy: -1.8843
# New ref model saved
# Epoch [123] 📊 acc: 0.912 | Targets: 0.9060 | Entropy: -1.8807
# Epoch [124] 📊 acc: 0.914 | Targets: 0.9059 | Entropy: -1.8817
# New ref model saved
# Epoch [125] 📊 acc: 0.914 | Targets: 0.9135 | Entropy: -1.8898
# Epoch [126] 📊 acc: 0.914 | Targets: 0.9114 | Entropy: -1.8877
# New ref model saved
# Epoch [127] 📊 acc: 0.915 | Targets: 0.9063 | Entropy: -1.8847
# New ref model saved
# Epoch [128] 📊 acc: 0.915 | Targets: 0.8920 | Entropy: -1.8699
# Epoch [129] 📊 acc: 0.915 | Targets: 0.8971 | Entropy: -1.8750
# Epoch [130] 📊 acc: 0.916 | Targets: 0.8970 | Entropy: -1.8769
# New ref model saved
#
# Evaluating at epoch 130 …
# Train Accuracy: 91.93%
# Train Average Loss: 0.8858
# Test Accuracy: 92.30%
# Test Average Loss: 0.8684
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.04e-04
# Epoch [131] 📊 acc: 0.917 | Targets: 0.9011 | Entropy: -1.8811
# New ref model saved
# Epoch [132] 📊 acc: 0.915 | Targets: 0.9162 | Entropy: -1.8953
# Epoch [133] 📊 acc: 0.918 | Targets: 0.9069 | Entropy: -1.8895
# New ref model saved
# Epoch [134] 📊 acc: 0.918 | Targets: 0.8898 | Entropy: -1.8715
# Epoch [135] 📊 acc: 0.919 | Targets: 0.8918 | Entropy: -1.8751
# New ref model saved
# Epoch [136] 📊 acc: 0.919 | Targets: 0.8844 | Entropy: -1.8679
# Epoch [137] 📊 acc: 0.920 | Targets: 0.8867 | Entropy: -1.8726
# New ref model saved
# Epoch [138] 📊 acc: 0.921 | Targets: 0.8322 | Entropy: -1.8130
# New ref model saved
# Epoch [139] 📊 acc: 0.922 | Targets: 0.9136 | Entropy: -1.9003
# New ref model saved
# Epoch [140] 📊 acc: 0.922 | Targets: 0.8926 | Entropy: -1.8795
#
# Evaluating at epoch 140 …
# Train Accuracy: 92.45%
# Train Average Loss: 0.8828
# Test Accuracy: 93.01%
# Test Average Loss: 0.8698
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.53e-04
# New best model saved with test accuracy: 93.01%
# Epoch [141] 📊 acc: 0.922 | Targets: 0.8909 | Entropy: -1.8790
# New ref model saved
# Epoch [142] 📊 acc: 0.922 | Targets: 0.8866 | Entropy: -1.8750
# Epoch [143] 📊 acc: 0.920 | Targets: 0.8909 | Entropy: -1.8774
# Epoch [144] 📊 acc: 0.922 | Targets: 0.8899 | Entropy: -1.8775
# Epoch [145] 📊 acc: 0.925 | Targets: 0.8836 | Entropy: -1.8760
# New ref model saved
# Epoch [146] 📊 acc: 0.924 | Targets: 0.8879 | Entropy: -1.8791
# Epoch [147] 📊 acc: 0.923 | Targets: 0.8900 | Entropy: -1.8800
# Epoch [148] 📊 acc: 0.925 | Targets: 0.8856 | Entropy: -1.8782
# Epoch [149] 📊 acc: 0.928 | Targets: 0.8842 | Entropy: -1.8780
# New ref model saved
# Epoch [150] 📊 acc: 0.926 | Targets: 0.8848 | Entropy: -1.8782
#
# Evaluating at epoch 150 …
# Train Accuracy: 92.75%
# Train Average Loss: 0.8750
# Test Accuracy: 92.89%
# Test Average Loss: 0.8738
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.01e-04
# Epoch [151] 📊 acc: 0.926 | Targets: 0.8835 | Entropy: -1.8781
# Epoch [152] 📊 acc: 0.925 | Targets: 0.8859 | Entropy: -1.8784
# Epoch [153] 📊 acc: 0.926 | Targets: 0.8829 | Entropy: -1.8775
# Epoch [154] 📊 acc: 0.926 | Targets: 0.8836 | Entropy: -1.8780
# Epoch [155] 📊 acc: 0.926 | Targets: 0.8828 | Entropy: -1.8776
# Epoch [156] 📊 acc: 0.928 | Targets: 0.8816 | Entropy: -1.8772
# New ref model saved
# Epoch [157] 📊 acc: 0.929 | Targets: 0.8840 | Entropy: -1.8809
# New ref model saved
# Epoch [158] 📊 acc: 0.929 | Targets: 0.8789 | Entropy: -1.8770
# New ref model saved
# Epoch [159] 📊 acc: 0.930 | Targets: 0.8712 | Entropy: -1.8705
# New ref model saved
# Epoch [160] 📊 acc: 0.931 | Targets: 0.8756 | Entropy: -1.8763
# New ref model saved
#
# Evaluating at epoch 160 …
# Train Accuracy: 93.19%
# Train Average Loss: 0.8690
# Test Accuracy: 92.87%
# Test Average Loss: 0.8703
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.48e-04
# Epoch [161] 📊 acc: 0.931 | Targets: 0.8835 | Entropy: -1.8835
# New ref model saved
# Epoch [162] 📊 acc: 0.929 | Targets: 0.8798 | Entropy: -1.8789
# Epoch [163] 📊 acc: 0.931 | Targets: 0.8767 | Entropy: -1.8773
# Epoch [164] 📊 acc: 0.932 | Targets: 0.8745 | Entropy: -1.8764
# New ref model saved
# Epoch [165] 📊 acc: 0.933 | Targets: 0.8624 | Entropy: -1.8659
# New ref model saved
# Epoch [166] 📊 acc: 0.932 | Targets: 0.8762 | Entropy: -1.8784
# Epoch [167] 📊 acc: 0.933 | Targets: 0.8761 | Entropy: -1.8782
# Epoch [168] 📊 acc: 0.932 | Targets: 0.8738 | Entropy: -1.8767
# Epoch [169] 📊 acc: 0.932 | Targets: 0.8751 | Entropy: -1.8773
# Epoch [170] 📊 acc: 0.934 | Targets: 0.8701 | Entropy: -1.8754
# New ref model saved
#
# Evaluating at epoch 170 …
# Train Accuracy: 93.77%
# Train Average Loss: 0.8626
# Test Accuracy: 93.58%
# Test Average Loss: 0.8660
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.97e-04
# New best model saved with test accuracy: 93.58%
# Epoch [171] 📊 acc: 0.933 | Targets: 0.8688 | Entropy: -1.8744
# Epoch [172] 📊 acc: 0.933 | Targets: 0.8701 | Entropy: -1.8749
# Epoch [173] 📊 acc: 0.934 | Targets: 0.8683 | Entropy: -1.8741
# Epoch [174] 📊 acc: 0.934 | Targets: 0.8680 | Entropy: -1.8739
# Epoch [175] 📊 acc: 0.935 | Targets: 0.8667 | Entropy: -1.8739
# New ref model saved
# Epoch [176] 📊 acc: 0.937 | Targets: 0.8761 | Entropy: -1.8851
# New ref model saved
# Epoch [177] 📊 acc: 0.938 | Targets: 0.8641 | Entropy: -1.8734
# New ref model saved
# Epoch [178] 📊 acc: 0.937 | Targets: 0.8662 | Entropy: -1.8764
# Epoch [179] 📊 acc: 0.937 | Targets: 0.8666 | Entropy: -1.8756
# Epoch [180] 📊 acc: 0.935 | Targets: 0.8673 | Entropy: -1.8754
#
# Evaluating at epoch 180 …
# Train Accuracy: 93.86%
# Train Average Loss: 0.8639
# Test Accuracy: 93.42%
# Test Average Loss: 0.8646
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.46e-04
# Epoch [181] 📊 acc: 0.938 | Targets: 0.8643 | Entropy: -1.8746
# Epoch [182] 📊 acc: 0.936 | Targets: 0.8657 | Entropy: -1.8747
# Epoch [183] 📊 acc: 0.939 | Targets: 0.8613 | Entropy: -1.8732
# New ref model saved
# Epoch [184] 📊 acc: 0.938 | Targets: 0.8652 | Entropy: -1.8762
# Epoch [185] 📊 acc: 0.938 | Targets: 0.8645 | Entropy: -1.8753
# Epoch [186] 📊 acc: 0.939 | Targets: 0.8605 | Entropy: -1.8735
# Epoch [187] 📊 acc: 0.940 | Targets: 0.8595 | Entropy: -1.8734
# New ref model saved
# Epoch [188] 📊 acc: 0.939 | Targets: 0.8549 | Entropy: -1.8678
# Epoch [189] 📊 acc: 0.940 | Targets: 0.8555 | Entropy: -1.8688
# Epoch [190] 📊 acc: 0.939 | Targets: 0.8557 | Entropy: -1.8692
#
# Evaluating at epoch 190 …
# Train Accuracy: 94.29%
# Train Average Loss: 0.8501
# Test Accuracy: 93.45%
# Test Average Loss: 0.8583
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.97e-04
# Epoch [191] 📊 acc: 0.941 | Targets: 0.8531 | Entropy: -1.8685
# New ref model saved
# Epoch [192] 📊 acc: 0.940 | Targets: 0.8781 | Entropy: -1.8925
# Epoch [193] 📊 acc: 0.941 | Targets: 0.8728 | Entropy: -1.8875
# Epoch [194] 📊 acc: 0.941 | Targets: 0.8700 | Entropy: -1.8851
# Epoch [195] 📊 acc: 0.942 | Targets: 0.8662 | Entropy: -1.8822
# New ref model saved
# Epoch [196] 📊 acc: 0.944 | Targets: 0.8522 | Entropy: -1.8708
# New ref model saved
# Epoch [197] 📊 acc: 0.942 | Targets: 0.8503 | Entropy: -1.8682
# Epoch [198] 📊 acc: 0.942 | Targets: 0.8514 | Entropy: -1.8691
# Epoch [199] 📊 acc: 0.942 | Targets: 0.8502 | Entropy: -1.8689
# Epoch [200] 📊 acc: 0.943 | Targets: 0.8503 | Entropy: -1.8688
#
# Evaluating at epoch 200 …
# Train Accuracy: 94.17%
# Train Average Loss: 0.8503
# Test Accuracy: 93.64%
# Test Average Loss: 0.8556
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.51e-04
# New best model saved with test accuracy: 93.64%
# Epoch [201] 📊 acc: 0.943 | Targets: 0.8525 | Entropy: -1.8701
# Epoch [202] 📊 acc: 0.945 | Targets: 0.8461 | Entropy: -1.8683
# New ref model saved
# Epoch [203] 📊 acc: 0.943 | Targets: 0.8516 | Entropy: -1.8711
# Epoch [204] 📊 acc: 0.945 | Targets: 0.8487 | Entropy: -1.8702
# New ref model saved
# Epoch [205] 📊 acc: 0.944 | Targets: 0.8480 | Entropy: -1.8686
# Epoch [206] 📊 acc: 0.946 | Targets: 0.8472 | Entropy: -1.8687
# New ref model saved
# Epoch [207] 📊 acc: 0.945 | Targets: 0.8524 | Entropy: -1.8729
# Epoch [208] 📊 acc: 0.944 | Targets: 0.8502 | Entropy: -1.8721
# Epoch [209] 📊 acc: 0.946 | Targets: 0.8481 | Entropy: -1.8710
# New ref model saved
# Epoch [210] 📊 acc: 0.947 | Targets: 0.8457 | Entropy: -1.8699
# New ref model saved
#
# Evaluating at epoch 210 …
# Train Accuracy: 94.61%
# Train Average Loss: 0.8447
# Test Accuracy: 93.67%
# Test Average Loss: 0.8585
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.07e-04
# New best model saved with test accuracy: 93.67%
# Epoch [211] 📊 acc: 0.947 | Targets: 0.8406 | Entropy: -1.8652
# New ref model saved
# Epoch [212] 📊 acc: 0.944 | Targets: 0.8479 | Entropy: -1.8693
# Epoch [213] 📊 acc: 0.948 | Targets: 0.8429 | Entropy: -1.8680
# New ref model saved
# Epoch [214] 📊 acc: 0.948 | Targets: 0.8494 | Entropy: -1.8743
# Epoch [215] 📊 acc: 0.947 | Targets: 0.8476 | Entropy: -1.8729
# Epoch [216] 📊 acc: 0.948 | Targets: 0.8465 | Entropy: -1.8723
# New ref model saved
# Epoch [217] 📊 acc: 0.947 | Targets: 0.8395 | Entropy: -1.8639
# Epoch [218] 📊 acc: 0.948 | Targets: 0.8384 | Entropy: -1.8638
# Epoch [219] 📊 acc: 0.947 | Targets: 0.8402 | Entropy: -1.8647
# Epoch [220] 📊 acc: 0.948 | Targets: 0.8389 | Entropy: -1.8650
#
# Evaluating at epoch 220 …
# Train Accuracy: 94.88%
# Train Average Loss: 0.8397
# Test Accuracy: 93.80%
# Test Average Loss: 0.8570
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.66e-04
# New best model saved with test accuracy: 93.80%
# Epoch [221] 📊 acc: 0.949 | Targets: 0.8381 | Entropy: -1.8648
# New ref model saved
# Epoch [222] 📊 acc: 0.948 | Targets: 0.8354 | Entropy: -1.8623
# Epoch [223] 📊 acc: 0.951 | Targets: 0.8345 | Entropy: -1.8626
# New ref model saved
# Epoch [224] 📊 acc: 0.951 | Targets: 0.7913 | Entropy: -1.8177
# Epoch [225] 📊 acc: 0.951 | Targets: 0.7945 | Entropy: -1.8228
# New ref model saved
# Epoch [226] 📊 acc: 0.950 | Targets: 0.8506 | Entropy: -1.8799
# Epoch [227] 📊 acc: 0.951 | Targets: 0.8505 | Entropy: -1.8799
# Epoch [228] 📊 acc: 0.949 | Targets: 0.8513 | Entropy: -1.8788
# Epoch [229] 📊 acc: 0.949 | Targets: 0.8499 | Entropy: -1.8778
# Epoch [230] 📊 acc: 0.952 | Targets: 0.8460 | Entropy: -1.8766
# New ref model saved
#
# Evaluating at epoch 230 …
# Train Accuracy: 95.05%
# Train Average Loss: 0.8496
# Test Accuracy: 93.82%
# Test Average Loss: 0.8664
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.29e-04
# New best model saved with test accuracy: 93.82%
# Epoch [231] 📊 acc: 0.950 | Targets: 0.8382 | Entropy: -1.8673
# Epoch [232] 📊 acc: 0.950 | Targets: 0.8374 | Entropy: -1.8669
# Epoch [233] 📊 acc: 0.952 | Targets: 0.8342 | Entropy: -1.8660
# New ref model saved
# Epoch [234] 📊 acc: 0.952 | Targets: 0.8354 | Entropy: -1.8661
# Epoch [235] 📊 acc: 0.952 | Targets: 0.8336 | Entropy: -1.8653
# New ref model saved
# Epoch [236] 📊 acc: 0.952 | Targets: 0.8337 | Entropy: -1.8660
# New ref model saved
# Epoch [237] 📊 acc: 0.952 | Targets: 0.8340 | Entropy: -1.8660
# Epoch [238] 📊 acc: 0.952 | Targets: 0.8337 | Entropy: -1.8661
# New ref model saved
# Epoch [239] 📊 acc: 0.951 | Targets: 0.8381 | Entropy: -1.8698
# Epoch [240] 📊 acc: 0.952 | Targets: 0.8347 | Entropy: -1.8680
#
# Evaluating at epoch 240 …
# Train Accuracy: 95.46%
# Train Average Loss: 0.8354
# Test Accuracy: 93.92%
# Test Average Loss: 0.8565
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.64e-05
# New best model saved with test accuracy: 93.92%
# Epoch [241] 📊 acc: 0.952 | Targets: 0.8381 | Entropy: -1.8691
# Epoch [242] 📊 acc: 0.954 | Targets: 0.8344 | Entropy: -1.8680
# New ref model saved
# Epoch [243] 📊 acc: 0.954 | Targets: 0.8309 | Entropy: -1.8657
# New ref model saved
# Epoch [244] 📊 acc: 0.953 | Targets: 0.8291 | Entropy: -1.8621
# Epoch [245] 📊 acc: 0.953 | Targets: 0.8278 | Entropy: -1.8619
# Epoch [246] 📊 acc: 0.954 | Targets: 0.8268 | Entropy: -1.8616
# Epoch [247] 📊 acc: 0.954 | Targets: 0.8288 | Entropy: -1.8630
# Epoch [248] 📊 acc: 0.955 | Targets: 0.8273 | Entropy: -1.8620
# New ref model saved
# Epoch [249] 📊 acc: 0.956 | Targets: 0.8297 | Entropy: -1.8656
# New ref model saved
# Epoch [250] 📊 acc: 0.954 | Targets: 0.8368 | Entropy: -1.8712
#
# Evaluating at epoch 250 …
# Train Accuracy: 95.54%
# Train Average Loss: 0.8336
# Test Accuracy: 93.93%
# Test Average Loss: 0.8581
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.79e-05
# New best model saved with test accuracy: 93.93%
# Epoch [251] 📊 acc: 0.955 | Targets: 0.8348 | Entropy: -1.8700
# Epoch [252] 📊 acc: 0.955 | Targets: 0.8349 | Entropy: -1.8701
# Epoch [253] 📊 acc: 0.955 | Targets: 0.8336 | Entropy: -1.8696
# Epoch [254] 📊 acc: 0.953 | Targets: 0.8370 | Entropy: -1.8706
# Epoch [255] 📊 acc: 0.954 | Targets: 0.8327 | Entropy: -1.8687
# Epoch [256] 📊 acc: 0.956 | Targets: 0.8317 | Entropy: -1.8690
# New ref model saved
# Epoch [257] 📊 acc: 0.956 | Targets: 0.8290 | Entropy: -1.8657
# Epoch [258] 📊 acc: 0.956 | Targets: 0.8285 | Entropy: -1.8658
# Epoch [259] 📊 acc: 0.956 | Targets: 0.8285 | Entropy: -1.8654
# Epoch [260] 📊 acc: 0.956 | Targets: 0.8287 | Entropy: -1.8656
#
# Evaluating at epoch 260 …
# Train Accuracy: 95.58%
# Train Average Loss: 0.8277
# Test Accuracy: 94.03%
# Test Average Loss: 0.8519
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.42e-05
# New best model saved with test accuracy: 94.03%
# Epoch [261] 📊 acc: 0.955 | Targets: 0.8309 | Entropy: -1.8664
# Epoch [262] 📊 acc: 0.956 | Targets: 0.8268 | Entropy: -1.8649
# Epoch [263] 📊 acc: 0.958 | Targets: 0.8261 | Entropy: -1.8649
# New ref model saved
# Epoch [264] 📊 acc: 0.955 | Targets: 0.8240 | Entropy: -1.8587
# Epoch [265] 📊 acc: 0.956 | Targets: 0.8202 | Entropy: -1.8574
# Epoch [266] 📊 acc: 0.956 | Targets: 0.8204 | Entropy: -1.8580
# Epoch [267] 📊 acc: 0.956 | Targets: 0.8206 | Entropy: -1.8578
# Epoch [268] 📊 acc: 0.958 | Targets: 0.8179 | Entropy: -1.8576
# New ref model saved
# Epoch [269] 📊 acc: 0.956 | Targets: 0.8283 | Entropy: -1.8649
# Epoch [270] 📊 acc: 0.957 | Targets: 0.8275 | Entropy: -1.8653
#
# Evaluating at epoch 270 …
# Train Accuracy: 95.62%
# Train Average Loss: 0.8275
# Test Accuracy: 94.03%
# Test Average Loss: 0.8534
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-05
# Epoch [271] 📊 acc: 0.956 | Targets: 0.8269 | Entropy: -1.8648
# Epoch [272] 📊 acc: 0.956 | Targets: 0.8281 | Entropy: -1.8661
# Epoch [273] 📊 acc: 0.957 | Targets: 0.8254 | Entropy: -1.8643
# Epoch [274] 📊 acc: 0.956 | Targets: 0.8271 | Entropy: -1.8650
# Epoch [275] 📊 acc: 0.958 | Targets: 0.8255 | Entropy: -1.8649
# Epoch [276] 📊 acc: 0.958 | Targets: 0.8247 | Entropy: -1.8644
# Epoch [277] 📊 acc: 0.959 | Targets: 0.8215 | Entropy: -1.8631
# New ref model saved
# Epoch [278] 📊 acc: 0.956 | Targets: 0.8260 | Entropy: -1.8640
# Epoch [279] 📊 acc: 0.958 | Targets: 0.8251 | Entropy: -1.8638
# Epoch [280] 📊 acc: 0.957 | Targets: 0.8253 | Entropy: -1.8642
#
# Evaluating at epoch 280 …
# Train Accuracy: 95.70%
# Train Average Loss: 0.8243
# Test Accuracy: 94.03%
# Test Average Loss: 0.8509
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.19e-05
# Epoch [281] 📊 acc: 0.959 | Targets: 0.8227 | Entropy: -1.8634
# Epoch [282] 📊 acc: 0.957 | Targets: 0.8257 | Entropy: -1.8640
# Epoch [283] 📊 acc: 0.959 | Targets: 0.8225 | Entropy: -1.8636
# Epoch [284] 📊 acc: 0.958 | Targets: 0.8235 | Entropy: -1.8636
# Epoch [285] 📊 acc: 0.957 | Targets: 0.8244 | Entropy: -1.8635
# Epoch [286] 📊 acc: 0.958 | Targets: 0.8242 | Entropy: -1.8637
# Epoch [287] 📊 acc: 0.958 | Targets: 0.8234 | Entropy: -1.8634
# Epoch [288] 📊 acc: 0.958 | Targets: 0.8244 | Entropy: -1.8637
# Epoch [289] 📊 acc: 0.957 | Targets: 0.8246 | Entropy: -1.8634
# Epoch [290] 📊 acc: 0.957 | Targets: 0.8238 | Entropy: -1.8638
#
# Evaluating at epoch 290 …
# Train Accuracy: 95.72%
# Train Average Loss: 0.8269
# Test Accuracy: 94.17%
# Test Average Loss: 0.8509
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.74e-06
# New best model saved with test accuracy: 94.17%
# Epoch [291] 📊 acc: 0.958 | Targets: 0.8228 | Entropy: -1.8635
# Epoch [292] 📊 acc: 0.957 | Targets: 0.8243 | Entropy: -1.8633
# Epoch [293] 📊 acc: 0.958 | Targets: 0.8239 | Entropy: -1.8639
# Epoch [294] 📊 acc: 0.959 | Targets: 0.8216 | Entropy: -1.8629
# Epoch [295] 📊 acc: 0.957 | Targets: 0.8244 | Entropy: -1.8633
# Epoch [296] 📊 acc: 0.957 | Targets: 0.8266 | Entropy: -1.8644
# Epoch [297] 📊 acc: 0.956 | Targets: 0.8249 | Entropy: -1.8638
# Epoch [298] 📊 acc: 0.958 | Targets: 0.8233 | Entropy: -1.8634
# Epoch [299] 📊 acc: 0.958 | Targets: 0.8242 | Entropy: -1.8639
# Epoch [300] 📊 acc: 0.958 | Targets: 0.8239 | Entropy: -1.8636
#
# Evaluating at epoch 300 …
# Train Accuracy: 95.78%
# Train Average Loss: 0.8229
# Test Accuracy: 94.14%
# Test Average Loss: 0.8503
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-06
# Finished Training
# Best test accuracy achieved: 94.17%
# Total Trainable Parameters: 515,754
