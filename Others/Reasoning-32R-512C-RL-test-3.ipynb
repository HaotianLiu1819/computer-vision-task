# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth):
        out = self.conv[depth // (self.max_depth // self.num_module)](x, depth)
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            x = checkpoint(self.step_forward, x, x_prev, d, use_reentrant=False)

        return x

# %%
class RecursionAmplifyConv(nn.Module):
    def __init__(self, channels, height, width):
        super(RecursionAmplifyConv, self).__init__()
        
        self.conv0 = nn.Conv2d(3, channels, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(channels, max_depth=32, num_module=1)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))


    def forward(self, x):
        
        x = self.conv0(x)

        x = self.amconv(x)

        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.reamconv= RecursionAmplifyConv(512, 32, 32)

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.reamconv(x)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        return x

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 1)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        pre_entropy = torch.sum(pre_probs * torch.log(pre_probs), dim=1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_pre_entropy = torch.sum(old_pre_probs * torch.log(old_pre_probs), dim=1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        ref_entropy = torch.sum(ref_probs * torch.log(ref_probs), dim=1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_ref_entropy = torch.sum(old_ref_probs * torch.log(old_ref_probs), dim=1)

        rewards, correct = self.compute_reconstruct_reward(outputs, targets)
        p_rewards, _ = self.compute_positive_reward(outputs, targets)
        n_rewards, _ = self.compute_negative_reward(outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        entropy_delta = (entropy - old_entropy)
        pre_entropy_delta = (pre_entropy - old_pre_entropy)
        ref_entropy_delta = (ref_entropy - old_ref_entropy)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
                'entropy': entropy.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)

    ref_count = 32
   
    select_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    select_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))

    entropy_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    entropy_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))

    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()

    all_params = list(net.parameters()) + list(pre_net.parameters()) + [
        select_embeddings1, select_embeddings2,
        entropy_embeddings1, entropy_embeddings2,
    ]
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    ref_accuracy = 0.0
    pre_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    d = 0
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=300, eta_min=1e-6
            )

        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
            'rewards_mean': 0.0, 'rewards_std': 0.0, 
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs = net(inputs)
                ref_outputs = ref_net(inputs)
                pre_outputs = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_ratio = 2 * F.sigmoid(select_embeddings1[d % ref_count]) * F.tanh(pre_select_delta) + F.tanh(select_delta)
                select_ratio = F.tanh(select_ratio) - 2 * F.sigmoid(select_embeddings2[d % ref_count]) * F.tanh(ref_select_delta)
                select_loss = select_ratio.sum()
                
                entropy_ratio = 2 * F.sigmoid(entropy_embeddings1[d % ref_count]) * F.tanh(pre_entropy_delta) + F.tanh(entropy_delta) 
                entropy_ratio = F.tanh(entropy_ratio) - 2 * F.sigmoid(entropy_embeddings2[d % ref_count]) * F.tanh(ref_entropy_delta)
                entropy_loss = entropy_ratio.sum()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(all_params, max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f}")

        if running_cor > ref_accuracy:
            ref_accuracy = running_cor
            ref = copy.deepcopy(net).to(device)
            if d % 2 == 0:
                prev_ref.append(ref)
                prev_ref = prev_ref[-ref_count:]
            ref_net = prev_ref[((d % ref_count + 1) - ((d % ref_count + 1) & -(d % ref_count + 1))) // 2]
            d += 1
            print(f"New ref model saved")

        if running_cor > pre_accuracy:
            pre_accuracy = running_cor
            pre_net = copy.deepcopy(net).to(device)
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
                    if use_bf16 else contextlib.nullcontext())

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = net(images)  
            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum    += batch_loss.item() * bs
            total_seen  += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 515,754

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.284 | Targets: 2.0576 | Entropy: -2.1488
# New ref model saved
# Epoch [2] 📊 acc: 0.441 | Targets: 1.7328 | Entropy: -2.0702
# New ref model saved
# Epoch [3] 📊 acc: 0.529 | Targets: 1.5921 | Entropy: -2.0325
# New ref model saved
# Epoch [4] 📊 acc: 0.585 | Targets: 1.4985 | Entropy: -2.0058
# New ref model saved
# Epoch [5] 📊 acc: 0.631 | Targets: 1.4288 | Entropy: -1.9887
# New ref model saved
# Epoch [6] 📊 acc: 0.656 | Targets: 1.3768 | Entropy: -1.9761
# New ref model saved
# Epoch [7] 📊 acc: 0.676 | Targets: 1.3418 | Entropy: -1.9689
# New ref model saved
# Epoch [8] 📊 acc: 0.697 | Targets: 1.3068 | Entropy: -1.9615
# New ref model saved
# Epoch [9] 📊 acc: 0.713 | Targets: 1.2758 | Entropy: -1.9545
# New ref model saved
# Epoch [10] 📊 acc: 0.726 | Targets: 1.2541 | Entropy: -1.9507
# New ref model saved
#
# Evaluating at epoch 10 …
# Train Accuracy: 73.36%
# Train Average Loss: 1.2581
# Test Accuracy: 78.64%
# Test Average Loss: 1.1704
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 78.64%
# Epoch [11] 📊 acc: 0.734 | Targets: 1.2375 | Entropy: -1.9470
# New ref model saved
# Epoch [12] 📊 acc: 0.745 | Targets: 1.2193 | Entropy: -1.9436
# New ref model saved
# Epoch [13] 📊 acc: 0.752 | Targets: 1.2055 | Entropy: -1.9421
# New ref model saved
# Epoch [14] 📊 acc: 0.760 | Targets: 1.1919 | Entropy: -1.9391
# New ref model saved
# Epoch [15] 📊 acc: 0.765 | Targets: 1.1812 | Entropy: -1.9371
# New ref model saved
# Epoch [16] 📊 acc: 0.771 | Targets: 1.1699 | Entropy: -1.9353
# New ref model saved
# Epoch [17] 📊 acc: 0.774 | Targets: 1.1631 | Entropy: -1.9343
# New ref model saved
# Epoch [18] 📊 acc: 0.781 | Targets: 1.1524 | Entropy: -1.9331
# New ref model saved
# Epoch [19] 📊 acc: 0.785 | Targets: 1.1452 | Entropy: -1.9318
# New ref model saved
# Epoch [20] 📊 acc: 0.788 | Targets: 1.1380 | Entropy: -1.9313
# New ref model saved
#
# Evaluating at epoch 20 …
# Train Accuracy: 79.79%
# Train Average Loss: 1.1049
# Test Accuracy: 84.84%
# Test Average Loss: 1.0159
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 84.84%
# Epoch [21] 📊 acc: 0.795 | Targets: 1.1251 | Entropy: -1.9287
# New ref model saved
# Epoch [22] 📊 acc: 0.797 | Targets: 1.1197 | Entropy: -1.9273
# New ref model saved
# Epoch [23] 📊 acc: 0.800 | Targets: 1.1159 | Entropy: -1.9269
# New ref model saved
# Epoch [24] 📊 acc: 0.805 | Targets: 1.1040 | Entropy: -1.9241
# New ref model saved
# Epoch [25] 📊 acc: 0.809 | Targets: 1.1021 | Entropy: -1.9247
# New ref model saved
# Epoch [26] 📊 acc: 0.812 | Targets: 1.0948 | Entropy: -1.9235
# New ref model saved
# Epoch [27] 📊 acc: 0.815 | Targets: 1.0899 | Entropy: -1.9223
# New ref model saved
# Epoch [28] 📊 acc: 0.816 | Targets: 1.0859 | Entropy: -1.9220
# New ref model saved
# Epoch [29] 📊 acc: 0.819 | Targets: 1.0823 | Entropy: -1.9210
# New ref model saved
# Epoch [30] 📊 acc: 0.820 | Targets: 1.0796 | Entropy: -1.9209
# New ref model saved
#
# Evaluating at epoch 30 …
# Train Accuracy: 79.87%
# Train Average Loss: 1.1358
# Test Accuracy: 84.41%
# Test Average Loss: 1.0480
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.76e-04
# Epoch [31] 📊 acc: 0.824 | Targets: 1.0735 | Entropy: -1.9189
# New ref model saved
# Epoch [32] 📊 acc: 0.828 | Targets: 1.0659 | Entropy: -1.9183
# New ref model saved
# Epoch [33] 📊 acc: 0.829 | Targets: 1.0647 | Entropy: -1.9182
# New ref model saved
# Epoch [34] 📊 acc: 0.829 | Targets: 1.0639 | Entropy: -1.9181
# New ref model saved
# Epoch [35] 📊 acc: 0.832 | Targets: 1.0568 | Entropy: -1.9159
# New ref model saved
# Epoch [36] 📊 acc: 0.832 | Targets: 1.0579 | Entropy: -1.9175
# Epoch [37] 📊 acc: 0.835 | Targets: 1.0513 | Entropy: -1.9161
# New ref model saved
# Epoch [38] 📊 acc: 0.839 | Targets: 1.0454 | Entropy: -1.9145
# New ref model saved
# Epoch [39] 📊 acc: 0.842 | Targets: 1.0386 | Entropy: -1.9129
# New ref model saved
# Epoch [40] 📊 acc: 0.841 | Targets: 1.0407 | Entropy: -1.9133
#
# Evaluating at epoch 40 …
# Train Accuracy: 84.74%
# Train Average Loss: 1.0407
# Test Accuracy: 88.24%
# Test Average Loss: 0.9696
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 88.24%
# Epoch [41] 📊 acc: 0.845 | Targets: 1.0344 | Entropy: -1.9124
# New ref model saved
# Epoch [42] 📊 acc: 0.849 | Targets: 1.0306 | Entropy: -1.9113
# New ref model saved
# Epoch [43] 📊 acc: 0.848 | Targets: 1.0303 | Entropy: -1.9116
# Epoch [44] 📊 acc: 0.849 | Targets: 1.0286 | Entropy: -1.9115
# Epoch [45] 📊 acc: 0.851 | Targets: 1.0258 | Entropy: -1.9111
# New ref model saved
# Epoch [46] 📊 acc: 0.851 | Targets: 1.0213 | Entropy: -1.9089
# Epoch [47] 📊 acc: 0.853 | Targets: 1.0206 | Entropy: -1.9100
# New ref model saved
# Epoch [48] 📊 acc: 0.855 | Targets: 1.0177 | Entropy: -1.9093
# New ref model saved
# Epoch [49] 📊 acc: 0.854 | Targets: 1.0181 | Entropy: -1.9096
# Epoch [50] 📊 acc: 0.855 | Targets: 1.0145 | Entropy: -1.9090
# New ref model saved
#
# Evaluating at epoch 50 …
# Train Accuracy: 86.30%
# Train Average Loss: 1.0000
# Test Accuracy: 88.52%
# Test Average Loss: 0.9550
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.33e-04
# New best model saved with test accuracy: 88.52%
# Epoch [51] 📊 acc: 0.857 | Targets: 1.0108 | Entropy: -1.9079
# New ref model saved
# Epoch [52] 📊 acc: 0.860 | Targets: 1.0067 | Entropy: -1.9071
# New ref model saved
# Epoch [53] 📊 acc: 0.861 | Targets: 1.0010 | Entropy: -1.9055
# New ref model saved
# Epoch [54] 📊 acc: 0.864 | Targets: 1.0007 | Entropy: -1.9058
# New ref model saved
# Epoch [55] 📊 acc: 0.864 | Targets: 0.9993 | Entropy: -1.9056
# New ref model saved
# Epoch [56] 📊 acc: 0.867 | Targets: 0.9942 | Entropy: -1.9046
# New ref model saved
# Epoch [57] 📊 acc: 0.867 | Targets: 0.9952 | Entropy: -1.9047
# Epoch [58] 📊 acc: 0.866 | Targets: 0.9941 | Entropy: -1.9048
# Epoch [59] 📊 acc: 0.871 | Targets: 0.9905 | Entropy: -1.9043
# New ref model saved
# Epoch [60] 📊 acc: 0.871 | Targets: 0.9865 | Entropy: -1.9026
# New ref model saved
#
# Evaluating at epoch 60 …
# Train Accuracy: 87.31%
# Train Average Loss: 0.9831
# Test Accuracy: 89.51%
# Test Average Loss: 0.9377
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 89.51%
# Epoch [61] 📊 acc: 0.871 | Targets: 0.9862 | Entropy: -1.9027
# Epoch [62] 📊 acc: 0.871 | Targets: 0.9875 | Entropy: -1.9035
# New ref model saved
# Epoch [63] 📊 acc: 0.873 | Targets: 0.9833 | Entropy: -1.9024
# New ref model saved
# Epoch [64] 📊 acc: 0.873 | Targets: 0.9824 | Entropy: -1.9027
# New ref model saved
# Epoch [65] 📊 acc: 0.873 | Targets: 0.9816 | Entropy: -1.9021
# New ref model saved
# Epoch [66] 📊 acc: 0.877 | Targets: 0.9755 | Entropy: -1.9011
# New ref model saved
# Epoch [67] 📊 acc: 0.878 | Targets: 0.9736 | Entropy: -1.9004
# New ref model saved
# Epoch [68] 📊 acc: 0.877 | Targets: 0.9751 | Entropy: -1.9009
# Epoch [69] 📊 acc: 0.878 | Targets: 0.9733 | Entropy: -1.9005
# Epoch [70] 📊 acc: 0.880 | Targets: 0.9678 | Entropy: -1.8991
# New ref model saved
#
# Evaluating at epoch 70 …
# Train Accuracy: 88.16%
# Train Average Loss: 0.9634
# Test Accuracy: 90.30%
# Test Average Loss: 0.9276
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.72e-04
# New best model saved with test accuracy: 90.30%
# Epoch [71] 📊 acc: 0.879 | Targets: 0.9711 | Entropy: -1.9000
# Epoch [72] 📊 acc: 0.881 | Targets: 0.9673 | Entropy: -1.8991
# New ref model saved
# Epoch [73] 📊 acc: 0.880 | Targets: 0.9677 | Entropy: -1.8991
# Epoch [74] 📊 acc: 0.883 | Targets: 0.9636 | Entropy: -1.8980
# New ref model saved
# Epoch [75] 📊 acc: 0.883 | Targets: 0.9636 | Entropy: -1.8986
# Epoch [76] 📊 acc: 0.884 | Targets: 0.9632 | Entropy: -1.8985
# New ref model saved
# Epoch [77] 📊 acc: 0.885 | Targets: 0.9606 | Entropy: -1.8980
# New ref model saved
# Epoch [78] 📊 acc: 0.886 | Targets: 0.9598 | Entropy: -1.8976
# New ref model saved
# Epoch [79] 📊 acc: 0.885 | Targets: 0.9590 | Entropy: -1.8975
# Epoch [80] 📊 acc: 0.889 | Targets: 0.9536 | Entropy: -1.8963
# New ref model saved
#
# Evaluating at epoch 80 …
# Train Accuracy: 89.26%
# Train Average Loss: 0.9498
# Test Accuracy: 90.95%
# Test Average Loss: 0.9184
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.35e-04
# New best model saved with test accuracy: 90.95%
# Epoch [81] 📊 acc: 0.890 | Targets: 0.9520 | Entropy: -1.8960
# New ref model saved
# Epoch [82] 📊 acc: 0.889 | Targets: 0.9515 | Entropy: -1.8956
# Epoch [83] 📊 acc: 0.889 | Targets: 0.9535 | Entropy: -1.8961
# Epoch [84] 📊 acc: 0.890 | Targets: 0.9518 | Entropy: -1.8960
# Epoch [85] 📊 acc: 0.892 | Targets: 0.9465 | Entropy: -1.8940
# New ref model saved
# Epoch [86] 📊 acc: 0.891 | Targets: 0.9475 | Entropy: -1.8947
# Epoch [87] 📊 acc: 0.894 | Targets: 0.9440 | Entropy: -1.8938
# New ref model saved
# Epoch [88] 📊 acc: 0.895 | Targets: 0.9429 | Entropy: -1.8936
# New ref model saved
# Epoch [89] 📊 acc: 0.896 | Targets: 0.9408 | Entropy: -1.8930
# New ref model saved
# Epoch [90] 📊 acc: 0.896 | Targets: 0.9406 | Entropy: -1.8930
# New ref model saved
#
# Evaluating at epoch 90 …
# Train Accuracy: 89.86%
# Train Average Loss: 0.9449
# Test Accuracy: 91.74%
# Test Average Loss: 0.9154
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.94e-04
# New best model saved with test accuracy: 91.74%
# Epoch [91] 📊 acc: 0.895 | Targets: 0.9418 | Entropy: -1.8934
# Epoch [92] 📊 acc: 0.895 | Targets: 0.9375 | Entropy: -1.8923
# Epoch [93] 📊 acc: 0.896 | Targets: 0.9398 | Entropy: -1.8932
# Epoch [94] 📊 acc: 0.897 | Targets: 0.9370 | Entropy: -1.8924
# New ref model saved
# Epoch [95] 📊 acc: 0.898 | Targets: 0.9358 | Entropy: -1.8921
# New ref model saved
# Epoch [96] 📊 acc: 0.900 | Targets: 0.9339 | Entropy: -1.8913
# New ref model saved
# Epoch [97] 📊 acc: 0.902 | Targets: 0.9318 | Entropy: -1.8914
# New ref model saved
# Epoch [98] 📊 acc: 0.899 | Targets: 0.9327 | Entropy: -1.8914
# Epoch [99] 📊 acc: 0.899 | Targets: 0.9327 | Entropy: -1.8910
# Epoch [100] 📊 acc: 0.903 | Targets: 0.9268 | Entropy: -1.8898
# New ref model saved
#
# Evaluating at epoch 100 …
# Train Accuracy: 90.99%
# Train Average Loss: 0.9008
# Test Accuracy: 92.13%
# Test Average Loss: 0.8771
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.50e-04
# New best model saved with test accuracy: 92.13%
# Epoch [101] 📊 acc: 0.902 | Targets: 0.9276 | Entropy: -1.8896
# Epoch [102] 📊 acc: 0.904 | Targets: 0.9259 | Entropy: -1.8898
# New ref model saved
# Epoch [103] 📊 acc: 0.904 | Targets: 0.9257 | Entropy: -1.8896
# Epoch [104] 📊 acc: 0.905 | Targets: 0.9244 | Entropy: -1.8892
# New ref model saved
# Epoch [105] 📊 acc: 0.907 | Targets: 0.9198 | Entropy: -1.8876
# New ref model saved
# Epoch [106] 📊 acc: 0.905 | Targets: 0.9235 | Entropy: -1.8893
# Epoch [107] 📊 acc: 0.907 | Targets: 0.9179 | Entropy: -1.8875
# New ref model saved
# Epoch [108] 📊 acc: 0.907 | Targets: 0.9205 | Entropy: -1.8885
# Epoch [109] 📊 acc: 0.907 | Targets: 0.9221 | Entropy: -1.8891
# Epoch [110] 📊 acc: 0.908 | Targets: 0.9174 | Entropy: -1.8874
# New ref model saved
#
# Evaluating at epoch 110 …
# Train Accuracy: 90.92%
# Train Average Loss: 0.9350
# Test Accuracy: 91.86%
# Test Average Loss: 0.9152
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.04e-04
# Epoch [111] 📊 acc: 0.908 | Targets: 0.9187 | Entropy: -1.8883
# New ref model saved
# Epoch [112] 📊 acc: 0.908 | Targets: 0.9187 | Entropy: -1.8879
# New ref model saved
# Epoch [113] 📊 acc: 0.913 | Targets: 0.9087 | Entropy: -1.8853
# New ref model saved
# Epoch [114] 📊 acc: 0.907 | Targets: 0.9173 | Entropy: -1.8875
# Epoch [115] 📊 acc: 0.910 | Targets: 0.9137 | Entropy: -1.8865
# Epoch [116] 📊 acc: 0.910 | Targets: 0.9153 | Entropy: -1.8874
# Epoch [117] 📊 acc: 0.910 | Targets: 0.9136 | Entropy: -1.8866
# Epoch [118] 📊 acc: 0.911 | Targets: 0.9124 | Entropy: -1.8865
# Epoch [119] 📊 acc: 0.911 | Targets: 0.9113 | Entropy: -1.8864
# Epoch [120] 📊 acc: 0.912 | Targets: 0.9085 | Entropy: -1.8850
#
# Evaluating at epoch 120 …
# Train Accuracy: 91.73%
# Train Average Loss: 0.9054
# Test Accuracy: 92.53%
# Test Average Loss: 0.8948
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.55e-04
# New best model saved with test accuracy: 92.53%
# Epoch [121] 📊 acc: 0.913 | Targets: 0.9057 | Entropy: -1.8848
# Epoch [122] 📊 acc: 0.914 | Targets: 0.9067 | Entropy: -1.8851
# New ref model saved
# Epoch [123] 📊 acc: 0.914 | Targets: 0.9053 | Entropy: -1.8849
# New ref model saved
# Epoch [124] 📊 acc: 0.916 | Targets: 0.9039 | Entropy: -1.8843
# New ref model saved
# Epoch [125] 📊 acc: 0.917 | Targets: 0.9009 | Entropy: -1.8834
# New ref model saved
# Epoch [126] 📊 acc: 0.916 | Targets: 0.9030 | Entropy: -1.8843
# Epoch [127] 📊 acc: 0.915 | Targets: 0.9032 | Entropy: -1.8841
# Epoch [128] 📊 acc: 0.917 | Targets: 0.8996 | Entropy: -1.8833
# New ref model saved
# Epoch [129] 📊 acc: 0.917 | Targets: 0.9007 | Entropy: -1.8837
# Epoch [130] 📊 acc: 0.916 | Targets: 0.9005 | Entropy: -1.8833
#
# Evaluating at epoch 130 …
# Train Accuracy: 92.22%
# Train Average Loss: 0.8888
# Test Accuracy: 92.42%
# Test Average Loss: 0.8825
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.04e-04
# Epoch [131] 📊 acc: 0.919 | Targets: 0.8956 | Entropy: -1.8818
# New ref model saved
# Epoch [132] 📊 acc: 0.919 | Targets: 0.8940 | Entropy: -1.8817
# Epoch [133] 📊 acc: 0.919 | Targets: 0.8957 | Entropy: -1.8823
# New ref model saved
# Epoch [134] 📊 acc: 0.920 | Targets: 0.8935 | Entropy: -1.8815
# New ref model saved
# Epoch [135] 📊 acc: 0.919 | Targets: 0.8965 | Entropy: -1.8827
# Epoch [136] 📊 acc: 0.922 | Targets: 0.8929 | Entropy: -1.8818
# New ref model saved
# Epoch [137] 📊 acc: 0.921 | Targets: 0.8929 | Entropy: -1.8818
# Epoch [138] 📊 acc: 0.921 | Targets: 0.8919 | Entropy: -1.8812
# Epoch [139] 📊 acc: 0.923 | Targets: 0.8895 | Entropy: -1.8807
# New ref model saved
# Epoch [140] 📊 acc: 0.922 | Targets: 0.8906 | Entropy: -1.8811
#
# Evaluating at epoch 140 …
# Train Accuracy: 92.20%
# Train Average Loss: 0.8857
# Test Accuracy: 92.63%
# Test Average Loss: 0.8773
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.53e-04
# New best model saved with test accuracy: 92.63%
# Epoch [141] 📊 acc: 0.924 | Targets: 0.8860 | Entropy: -1.8794
# New ref model saved
# Epoch [142] 📊 acc: 0.923 | Targets: 0.8894 | Entropy: -1.8810
# Epoch [143] 📊 acc: 0.924 | Targets: 0.8874 | Entropy: -1.8801
# New ref model saved
# Epoch [144] 📊 acc: 0.925 | Targets: 0.8873 | Entropy: -1.8801
# New ref model saved
# Epoch [145] 📊 acc: 0.923 | Targets: 0.8875 | Entropy: -1.8803
# Epoch [146] 📊 acc: 0.925 | Targets: 0.8858 | Entropy: -1.8799
# Epoch [147] 📊 acc: 0.926 | Targets: 0.8835 | Entropy: -1.8793
# New ref model saved
# Epoch [148] 📊 acc: 0.926 | Targets: 0.8841 | Entropy: -1.8795
# New ref model saved
# Epoch [149] 📊 acc: 0.924 | Targets: 0.8865 | Entropy: -1.8805
# Epoch [150] 📊 acc: 0.927 | Targets: 0.8813 | Entropy: -1.8789
# New ref model saved
#
# Evaluating at epoch 150 …
# Train Accuracy: 92.95%
# Train Average Loss: 0.8771
# Test Accuracy: 92.84%
# Test Average Loss: 0.8826
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.00e-04
# New best model saved with test accuracy: 92.84%
# Epoch [151] 📊 acc: 0.928 | Targets: 0.8791 | Entropy: -1.8780
# New ref model saved
# Epoch [152] 📊 acc: 0.926 | Targets: 0.8824 | Entropy: -1.8791
# Epoch [153] 📊 acc: 0.928 | Targets: 0.8790 | Entropy: -1.8783
# New ref model saved
# Epoch [154] 📊 acc: 0.931 | Targets: 0.8747 | Entropy: -1.8767
# New ref model saved
# Epoch [155] 📊 acc: 0.928 | Targets: 0.8778 | Entropy: -1.8779
# Epoch [156] 📊 acc: 0.928 | Targets: 0.8797 | Entropy: -1.8785
# Epoch [157] 📊 acc: 0.931 | Targets: 0.8737 | Entropy: -1.8769
# New ref model saved
# Epoch [158] 📊 acc: 0.930 | Targets: 0.8767 | Entropy: -1.8777
# Epoch [159] 📊 acc: 0.931 | Targets: 0.8744 | Entropy: -1.8770
# Epoch [160] 📊 acc: 0.930 | Targets: 0.8737 | Entropy: -1.8767
#
# Evaluating at epoch 160 …
# Train Accuracy: 93.50%
# Train Average Loss: 0.8687
# Test Accuracy: 93.22%
# Test Average Loss: 0.8736
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.48e-04
# New best model saved with test accuracy: 93.22%
# Epoch [161] 📊 acc: 0.931 | Targets: 0.8747 | Entropy: -1.8770
# Epoch [162] 📊 acc: 0.932 | Targets: 0.8723 | Entropy: -1.8762
# New ref model saved
# Epoch [163] 📊 acc: 0.931 | Targets: 0.8711 | Entropy: -1.8761
# Epoch [164] 📊 acc: 0.933 | Targets: 0.8709 | Entropy: -1.8762
# New ref model saved
# Epoch [165] 📊 acc: 0.933 | Targets: 0.8695 | Entropy: -1.8756
# New ref model saved
# Epoch [166] 📊 acc: 0.933 | Targets: 0.8698 | Entropy: -1.8758
# Epoch [167] 📊 acc: 0.932 | Targets: 0.8691 | Entropy: -1.8755
# Epoch [168] 📊 acc: 0.935 | Targets: 0.8665 | Entropy: -1.8751
# New ref model saved
# Epoch [169] 📊 acc: 0.935 | Targets: 0.8667 | Entropy: -1.8754
# Epoch [170] 📊 acc: 0.935 | Targets: 0.8666 | Entropy: -1.8752
#
# Evaluating at epoch 170 …
# Train Accuracy: 93.72%
# Train Average Loss: 0.8574
# Test Accuracy: 93.39%
# Test Average Loss: 0.8622
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.97e-04
# New best model saved with test accuracy: 93.39%
# Epoch [171] 📊 acc: 0.935 | Targets: 0.8663 | Entropy: -1.8750
# New ref model saved
# Epoch [172] 📊 acc: 0.936 | Targets: 0.8656 | Entropy: -1.8751
# New ref model saved
# Epoch [173] 📊 acc: 0.938 | Targets: 0.8605 | Entropy: -1.8735
# New ref model saved
# Epoch [174] 📊 acc: 0.937 | Targets: 0.8636 | Entropy: -1.8741
# Epoch [175] 📊 acc: 0.935 | Targets: 0.8658 | Entropy: -1.8747
# Epoch [176] 📊 acc: 0.937 | Targets: 0.8611 | Entropy: -1.8732
# Epoch [177] 📊 acc: 0.936 | Targets: 0.8630 | Entropy: -1.8741
# Epoch [178] 📊 acc: 0.936 | Targets: 0.8638 | Entropy: -1.8747
# Epoch [179] 📊 acc: 0.939 | Targets: 0.8592 | Entropy: -1.8732
# New ref model saved
# Epoch [180] 📊 acc: 0.937 | Targets: 0.8623 | Entropy: -1.8742
#
# Evaluating at epoch 180 …
# Train Accuracy: 93.97%
# Train Average Loss: 0.8605
# Test Accuracy: 93.46%
# Test Average Loss: 0.8664
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.46e-04
# New best model saved with test accuracy: 93.46%
# Epoch [181] 📊 acc: 0.939 | Targets: 0.8583 | Entropy: -1.8730
# Epoch [182] 📊 acc: 0.938 | Targets: 0.8582 | Entropy: -1.8728
# Epoch [183] 📊 acc: 0.941 | Targets: 0.8547 | Entropy: -1.8718
# New ref model saved
# Epoch [184] 📊 acc: 0.940 | Targets: 0.8579 | Entropy: -1.8731
# Epoch [185] 📊 acc: 0.941 | Targets: 0.8558 | Entropy: -1.8724
# New ref model saved
# Epoch [186] 📊 acc: 0.940 | Targets: 0.8567 | Entropy: -1.8727
# Epoch [187] 📊 acc: 0.941 | Targets: 0.8541 | Entropy: -1.8718
# New ref model saved
# Epoch [188] 📊 acc: 0.942 | Targets: 0.8531 | Entropy: -1.8722
# New ref model saved
# Epoch [189] 📊 acc: 0.941 | Targets: 0.8536 | Entropy: -1.8717
# Epoch [190] 📊 acc: 0.942 | Targets: 0.8518 | Entropy: -1.8712
# New ref model saved
#
# Evaluating at epoch 190 …
# Train Accuracy: 94.14%
# Train Average Loss: 0.8503
# Test Accuracy: 93.23%
# Test Average Loss: 0.8611
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.97e-04
# Epoch [191] 📊 acc: 0.942 | Targets: 0.8506 | Entropy: -1.8706
# Epoch [192] 📊 acc: 0.942 | Targets: 0.8524 | Entropy: -1.8717
# Epoch [193] 📊 acc: 0.943 | Targets: 0.8498 | Entropy: -1.8704
# New ref model saved
# Epoch [194] 📊 acc: 0.942 | Targets: 0.8518 | Entropy: -1.8712
# Epoch [195] 📊 acc: 0.943 | Targets: 0.8507 | Entropy: -1.8710
# New ref model saved
# Epoch [196] 📊 acc: 0.942 | Targets: 0.8524 | Entropy: -1.8717
# Epoch [197] 📊 acc: 0.942 | Targets: 0.8503 | Entropy: -1.8709
# Epoch [198] 📊 acc: 0.945 | Targets: 0.8469 | Entropy: -1.8696
# New ref model saved
# Epoch [199] 📊 acc: 0.941 | Targets: 0.8534 | Entropy: -1.8720
# Epoch [200] 📊 acc: 0.945 | Targets: 0.8459 | Entropy: -1.8697
# New ref model saved
#
# Evaluating at epoch 200 …
# Train Accuracy: 94.42%
# Train Average Loss: 0.8470
# Test Accuracy: 93.48%
# Test Average Loss: 0.8611
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.51e-04
# New best model saved with test accuracy: 93.48%
# Epoch [201] 📊 acc: 0.945 | Targets: 0.8465 | Entropy: -1.8699
# Epoch [202] 📊 acc: 0.946 | Targets: 0.8449 | Entropy: -1.8696
# New ref model saved
# Epoch [203] 📊 acc: 0.947 | Targets: 0.8456 | Entropy: -1.8699
# New ref model saved
# Epoch [204] 📊 acc: 0.944 | Targets: 0.8470 | Entropy: -1.8701
# Epoch [205] 📊 acc: 0.946 | Targets: 0.8436 | Entropy: -1.8691
# Epoch [206] 📊 acc: 0.946 | Targets: 0.8454 | Entropy: -1.8698
# Epoch [207] 📊 acc: 0.947 | Targets: 0.8452 | Entropy: -1.8697
# New ref model saved
# Epoch [208] 📊 acc: 0.948 | Targets: 0.8416 | Entropy: -1.8686
# New ref model saved
# Epoch [209] 📊 acc: 0.947 | Targets: 0.8436 | Entropy: -1.8694
# Epoch [210] 📊 acc: 0.948 | Targets: 0.8414 | Entropy: -1.8691
# New ref model saved
#
# Evaluating at epoch 210 …
# Train Accuracy: 94.84%
# Train Average Loss: 0.8447
# Test Accuracy: 93.78%
# Test Average Loss: 0.8613
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.07e-04
# New best model saved with test accuracy: 93.78%
# Epoch [211] 📊 acc: 0.948 | Targets: 0.8405 | Entropy: -1.8684
# New ref model saved
# Epoch [212] 📊 acc: 0.950 | Targets: 0.8386 | Entropy: -1.8680
# New ref model saved
# Epoch [213] 📊 acc: 0.947 | Targets: 0.8414 | Entropy: -1.8685
# Epoch [214] 📊 acc: 0.950 | Targets: 0.8378 | Entropy: -1.8676
# Epoch [215] 📊 acc: 0.949 | Targets: 0.8412 | Entropy: -1.8687
# Epoch [216] 📊 acc: 0.950 | Targets: 0.8377 | Entropy: -1.8679
# New ref model saved
# Epoch [217] 📊 acc: 0.947 | Targets: 0.8430 | Entropy: -1.8689
# Epoch [218] 📊 acc: 0.949 | Targets: 0.8397 | Entropy: -1.8684
# Epoch [219] 📊 acc: 0.950 | Targets: 0.8376 | Entropy: -1.8678
# New ref model saved
# Epoch [220] 📊 acc: 0.951 | Targets: 0.8381 | Entropy: -1.8683
# New ref model saved
#
# Evaluating at epoch 220 …
# Train Accuracy: 95.11%
# Train Average Loss: 0.8348
# Test Accuracy: 93.58%
# Test Average Loss: 0.8578
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.66e-04
# Epoch [221] 📊 acc: 0.950 | Targets: 0.8371 | Entropy: -1.8679
# Epoch [222] 📊 acc: 0.948 | Targets: 0.8380 | Entropy: -1.8679
# Epoch [223] 📊 acc: 0.952 | Targets: 0.8345 | Entropy: -1.8669
# New ref model saved
# Epoch [224] 📊 acc: 0.952 | Targets: 0.8346 | Entropy: -1.8669
# Epoch [225] 📊 acc: 0.951 | Targets: 0.8366 | Entropy: -1.8679
# Epoch [226] 📊 acc: 0.952 | Targets: 0.8350 | Entropy: -1.8672
# New ref model saved
# Epoch [227] 📊 acc: 0.953 | Targets: 0.8325 | Entropy: -1.8666
# New ref model saved
# Epoch [228] 📊 acc: 0.951 | Targets: 0.8342 | Entropy: -1.8667
# Epoch [229] 📊 acc: 0.953 | Targets: 0.8341 | Entropy: -1.8671
# Epoch [230] 📊 acc: 0.952 | Targets: 0.8348 | Entropy: -1.8673
#
# Evaluating at epoch 230 …
# Train Accuracy: 95.03%
# Train Average Loss: 0.8365
# Test Accuracy: 93.60%
# Test Average Loss: 0.8612
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.29e-04
# Epoch [231] 📊 acc: 0.952 | Targets: 0.8336 | Entropy: -1.8665
# Epoch [232] 📊 acc: 0.951 | Targets: 0.8357 | Entropy: -1.8676
# Epoch [233] 📊 acc: 0.953 | Targets: 0.8312 | Entropy: -1.8658
# New ref model saved
# Epoch [234] 📊 acc: 0.953 | Targets: 0.8313 | Entropy: -1.8661
# New ref model saved
# Epoch [235] 📊 acc: 0.954 | Targets: 0.8312 | Entropy: -1.8660
# New ref model saved
# Epoch [236] 📊 acc: 0.953 | Targets: 0.8326 | Entropy: -1.8666
# Epoch [237] 📊 acc: 0.952 | Targets: 0.8332 | Entropy: -1.8666
# Epoch [238] 📊 acc: 0.954 | Targets: 0.8315 | Entropy: -1.8658
# New ref model saved
# Epoch [239] 📊 acc: 0.952 | Targets: 0.8318 | Entropy: -1.8662
# Epoch [240] 📊 acc: 0.953 | Targets: 0.8310 | Entropy: -1.8662
#
# Evaluating at epoch 240 …
# Train Accuracy: 95.39%
# Train Average Loss: 0.8296
# Test Accuracy: 94.01%
# Test Average Loss: 0.8536
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.64e-05
# New best model saved with test accuracy: 94.01%
# Epoch [241] 📊 acc: 0.952 | Targets: 0.8324 | Entropy: -1.8666
# Epoch [242] 📊 acc: 0.955 | Targets: 0.8278 | Entropy: -1.8654
# New ref model saved
# Epoch [243] 📊 acc: 0.954 | Targets: 0.8288 | Entropy: -1.8652
# Epoch [244] 📊 acc: 0.955 | Targets: 0.8289 | Entropy: -1.8654
# Epoch [245] 📊 acc: 0.955 | Targets: 0.8295 | Entropy: -1.8658
# Epoch [246] 📊 acc: 0.956 | Targets: 0.8273 | Entropy: -1.8649
# New ref model saved
# Epoch [247] 📊 acc: 0.957 | Targets: 0.8255 | Entropy: -1.8644
# New ref model saved
# Epoch [248] 📊 acc: 0.956 | Targets: 0.8267 | Entropy: -1.8649
# Epoch [249] 📊 acc: 0.957 | Targets: 0.8250 | Entropy: -1.8646
# Epoch [250] 📊 acc: 0.956 | Targets: 0.8277 | Entropy: -1.8656
#
# Evaluating at epoch 250 …
# Train Accuracy: 95.68%
# Train Average Loss: 0.8261
# Test Accuracy: 94.15%
# Test Average Loss: 0.8536
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.79e-05
# New best model saved with test accuracy: 94.15%
# Epoch [251] 📊 acc: 0.958 | Targets: 0.8236 | Entropy: -1.8641
# New ref model saved
# Epoch [252] 📊 acc: 0.958 | Targets: 0.8234 | Entropy: -1.8643
# New ref model saved
# Epoch [253] 📊 acc: 0.955 | Targets: 0.8279 | Entropy: -1.8654
# Epoch [254] 📊 acc: 0.957 | Targets: 0.8245 | Entropy: -1.8643
# Epoch [255] 📊 acc: 0.957 | Targets: 0.8235 | Entropy: -1.8642
# Epoch [256] 📊 acc: 0.957 | Targets: 0.8237 | Entropy: -1.8639
# Epoch [257] 📊 acc: 0.956 | Targets: 0.8263 | Entropy: -1.8646
# Epoch [258] 📊 acc: 0.956 | Targets: 0.8256 | Entropy: -1.8647
# Epoch [259] 📊 acc: 0.957 | Targets: 0.8249 | Entropy: -1.8644
# Epoch [260] 📊 acc: 0.957 | Targets: 0.8248 | Entropy: -1.8648
#
# Evaluating at epoch 260 …
# Train Accuracy: 95.71%
# Train Average Loss: 0.8231
# Test Accuracy: 94.12%
# Test Average Loss: 0.8517
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.42e-05
# Epoch [261] 📊 acc: 0.956 | Targets: 0.8254 | Entropy: -1.8647
# Epoch [262] 📊 acc: 0.957 | Targets: 0.8247 | Entropy: -1.8646
# Epoch [263] 📊 acc: 0.958 | Targets: 0.8233 | Entropy: -1.8643
# Epoch [264] 📊 acc: 0.957 | Targets: 0.8247 | Entropy: -1.8644
# Epoch [265] 📊 acc: 0.958 | Targets: 0.8233 | Entropy: -1.8642
# Epoch [266] 📊 acc: 0.957 | Targets: 0.8246 | Entropy: -1.8645
# Epoch [267] 📊 acc: 0.958 | Targets: 0.8224 | Entropy: -1.8637
# Epoch [268] 📊 acc: 0.958 | Targets: 0.8237 | Entropy: -1.8647
# Epoch [269] 📊 acc: 0.958 | Targets: 0.8224 | Entropy: -1.8635
# Epoch [270] 📊 acc: 0.958 | Targets: 0.8219 | Entropy: -1.8640
#
# Evaluating at epoch 270 …
# Train Accuracy: 95.74%
# Train Average Loss: 0.8215
# Test Accuracy: 94.11%
# Test Average Loss: 0.8494
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-05
# Epoch [271] 📊 acc: 0.959 | Targets: 0.8216 | Entropy: -1.8632
# New ref model saved
# Epoch [272] 📊 acc: 0.958 | Targets: 0.8212 | Entropy: -1.8636
# Epoch [273] 📊 acc: 0.959 | Targets: 0.8215 | Entropy: -1.8635
# Epoch [274] 📊 acc: 0.956 | Targets: 0.8251 | Entropy: -1.8646
# Epoch [275] 📊 acc: 0.959 | Targets: 0.8209 | Entropy: -1.8637
# Epoch [276] 📊 acc: 0.958 | Targets: 0.8230 | Entropy: -1.8641
# Epoch [277] 📊 acc: 0.958 | Targets: 0.8220 | Entropy: -1.8636
# Epoch [278] 📊 acc: 0.957 | Targets: 0.8240 | Entropy: -1.8643
# Epoch [279] 📊 acc: 0.958 | Targets: 0.8216 | Entropy: -1.8639
# Epoch [280] 📊 acc: 0.958 | Targets: 0.8215 | Entropy: -1.8639
#
# Evaluating at epoch 280 …
# Train Accuracy: 95.75%
# Train Average Loss: 0.8214
# Test Accuracy: 94.08%
# Test Average Loss: 0.8500
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.19e-05
# Epoch [281] 📊 acc: 0.959 | Targets: 0.8214 | Entropy: -1.8634
# New ref model saved
# Epoch [282] 📊 acc: 0.959 | Targets: 0.8210 | Entropy: -1.8631
# Epoch [283] 📊 acc: 0.959 | Targets: 0.8209 | Entropy: -1.8635
# Epoch [284] 📊 acc: 0.959 | Targets: 0.8206 | Entropy: -1.8630
# Epoch [285] 📊 acc: 0.959 | Targets: 0.8206 | Entropy: -1.8634
# New ref model saved
# Epoch [286] 📊 acc: 0.958 | Targets: 0.8217 | Entropy: -1.8635
# Epoch [287] 📊 acc: 0.958 | Targets: 0.8229 | Entropy: -1.8641
# Epoch [288] 📊 acc: 0.959 | Targets: 0.8222 | Entropy: -1.8642
# New ref model saved
# Epoch [289] 📊 acc: 0.959 | Targets: 0.8200 | Entropy: -1.8635
# New ref model saved
# Epoch [290] 📊 acc: 0.960 | Targets: 0.8192 | Entropy: -1.8630
# New ref model saved
#
# Evaluating at epoch 290 …
# Train Accuracy: 95.97%
# Train Average Loss: 0.8193
# Test Accuracy: 94.29%
# Test Average Loss: 0.8495
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.74e-06
# New best model saved with test accuracy: 94.29%
# Epoch [291] 📊 acc: 0.959 | Targets: 0.8215 | Entropy: -1.8638
# Epoch [292] 📊 acc: 0.962 | Targets: 0.8166 | Entropy: -1.8627
# New ref model saved
# Epoch [293] 📊 acc: 0.958 | Targets: 0.8214 | Entropy: -1.8633
# Epoch [294] 📊 acc: 0.959 | Targets: 0.8202 | Entropy: -1.8631
# Epoch [295] 📊 acc: 0.960 | Targets: 0.8182 | Entropy: -1.8629
# Epoch [296] 📊 acc: 0.958 | Targets: 0.8219 | Entropy: -1.8633
# Epoch [297] 📊 acc: 0.958 | Targets: 0.8215 | Entropy: -1.8632
# Epoch [298] 📊 acc: 0.958 | Targets: 0.8229 | Entropy: -1.8633
# Epoch [299] 📊 acc: 0.959 | Targets: 0.8193 | Entropy: -1.8632
# Epoch [300] 📊 acc: 0.959 | Targets: 0.8212 | Entropy: -1.8629
#
# Evaluating at epoch 300 …
# Train Accuracy: 95.98%
# Train Average Loss: 0.8186
# Test Accuracy: 94.20%
# Test Average Loss: 0.8493
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-06
# Finished Training
# Best test accuracy achieved: 94.29%
# Total Trainable Parameters: 515,754
