# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth):
        out = self.conv[depth // (self.max_depth // self.num_module)](x, depth)
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            x = checkpoint(self.step_forward, x, x_prev, d, use_reentrant=False)

        return x

# %%
class RecursionAmplifyConv(nn.Module):
    def __init__(self, channels, height, width):
        super(RecursionAmplifyConv, self).__init__()
        
        self.conv0 = nn.Conv2d(3, channels, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(channels, max_depth=32, num_module=1)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))


    def forward(self, x):
        
        x = self.conv0(x)

        x = self.amconv(x)

        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.reamconv= RecursionAmplifyConv(512, 32, 32)

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.reamconv(x)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        return x

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 1)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        pre_entropy = torch.sum(pre_probs * torch.log(pre_probs), dim=1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_pre_entropy = torch.sum(old_pre_probs * torch.log(old_pre_probs), dim=1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        ref_entropy = torch.sum(ref_probs * torch.log(ref_probs), dim=1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_ref_entropy = torch.sum(old_ref_probs * torch.log(old_ref_probs), dim=1)

        rewards, correct = self.compute_reconstruct_reward(outputs, targets)
        p_rewards, _ = self.compute_positive_reward(outputs, targets)
        n_rewards, _ = self.compute_negative_reward(outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        entropy_delta = (entropy - old_entropy)
        pre_entropy_delta = (pre_entropy - old_pre_entropy)
        ref_entropy_delta = (ref_entropy - old_ref_entropy)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
                'entropy': entropy.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)

    ref_count = 32
   
    select_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    select_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))

    entropy_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    entropy_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))

    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()

    all_params = list(net.parameters()) + list(pre_net.parameters()) + [
        select_embeddings1, select_embeddings2,
        entropy_embeddings1, entropy_embeddings2,
    ]
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    ref_accuracy = 0.0
    pre_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    d = 0
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=300, eta_min=1e-6
            )

        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
            'rewards_mean': 0.0, 'rewards_std': 0.0, 
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs = net(inputs)
                ref_outputs = ref_net(inputs)
                pre_outputs = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_ratio = 2 * F.sigmoid(select_embeddings1[d % ref_count]) * F.relu(F.tanh(pre_select_delta)) + F.tanh(select_delta)
                select_ratio = F.tanh(select_ratio) - 2 * F.sigmoid(select_embeddings2[d % ref_count]) * F.tanh(ref_select_delta)
                select_loss = select_ratio.sum()
                
                entropy_ratio = 2 * F.sigmoid(entropy_embeddings1[d % ref_count]) * F.relu(F.tanh(pre_entropy_delta)) + F.tanh(entropy_delta) 
                entropy_ratio = F.tanh(entropy_ratio) - 2 * F.sigmoid(entropy_embeddings2[d % ref_count]) * F.tanh(ref_entropy_delta)
                entropy_loss = entropy_ratio.sum()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(all_params, max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f}")

        if running_cor > ref_accuracy:
            ref_accuracy = running_cor
            ref = copy.deepcopy(net).to(device)
            if d % 2 == 0:
                prev_ref.append(ref)
                prev_ref = prev_ref[-ref_count:]
            ref_net = prev_ref[((d % ref_count + 1) - ((d % ref_count + 1) & -(d % ref_count + 1))) // 2]
            d += 1
            print(f"New ref model saved")

        if running_cor > pre_accuracy:
            pre_accuracy = running_cor
            pre_net = copy.deepcopy(net).to(device)
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
                    if use_bf16 else contextlib.nullcontext())

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = net(images)  
            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum    += batch_loss.item() * bs
            total_seen  += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 515,754

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.280 | Targets: 2.0520 | Entropy: -2.1493
# New ref model saved
# Epoch [2] 📊 acc: 0.449 | Targets: 1.7243 | Entropy: -2.0721
# New ref model saved
# Epoch [3] 📊 acc: 0.528 | Targets: 1.5908 | Entropy: -2.0336
# New ref model saved
# Epoch [4] 📊 acc: 0.583 | Targets: 1.5003 | Entropy: -2.0092
# New ref model saved
# Epoch [5] 📊 acc: 0.622 | Targets: 1.4356 | Entropy: -1.9925
# New ref model saved
# Epoch [6] 📊 acc: 0.649 | Targets: 1.3868 | Entropy: -1.9790
# New ref model saved
# Epoch [7] 📊 acc: 0.674 | Targets: 1.3431 | Entropy: -1.9691
# New ref model saved
# Epoch [8] 📊 acc: 0.692 | Targets: 1.3106 | Entropy: -1.9619
# New ref model saved
# Epoch [9] 📊 acc: 0.706 | Targets: 1.2872 | Entropy: -1.9576
# New ref model saved
# Epoch [10] 📊 acc: 0.720 | Targets: 1.2628 | Entropy: -1.9529
# New ref model saved
#
# Evaluating at epoch 10 …
# Train Accuracy: 71.88%
# Train Average Loss: 1.2727
# Test Accuracy: 78.20%
# Test Average Loss: 1.1639
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 78.20%
# Epoch [11] 📊 acc: 0.726 | Targets: 1.2469 | Entropy: -1.9493
# New ref model saved
# Epoch [12] 📊 acc: 0.736 | Targets: 1.2336 | Entropy: -1.9473
# New ref model saved
# Epoch [13] 📊 acc: 0.749 | Targets: 1.2129 | Entropy: -1.9429
# New ref model saved
# Epoch [14] 📊 acc: 0.754 | Targets: 1.2013 | Entropy: -1.9417
# New ref model saved
# Epoch [15] 📊 acc: 0.763 | Targets: 1.1850 | Entropy: -1.9388
# New ref model saved
# Epoch [16] 📊 acc: 0.765 | Targets: 1.1812 | Entropy: -1.9387
# New ref model saved
# Epoch [17] 📊 acc: 0.771 | Targets: 1.1709 | Entropy: -1.9366
# New ref model saved
# Epoch [18] 📊 acc: 0.778 | Targets: 1.1596 | Entropy: -1.9350
# New ref model saved
# Epoch [19] 📊 acc: 0.781 | Targets: 1.1518 | Entropy: -1.9335
# New ref model saved
# Epoch [20] 📊 acc: 0.786 | Targets: 1.1429 | Entropy: -1.9323
# New ref model saved
#
# Evaluating at epoch 20 …
# Train Accuracy: 79.79%
# Train Average Loss: 1.1212
# Test Accuracy: 84.84%
# Test Average Loss: 1.0266
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 84.84%
# Epoch [21] 📊 acc: 0.791 | Targets: 1.1333 | Entropy: -1.9305
# New ref model saved
# Epoch [22] 📊 acc: 0.794 | Targets: 1.1274 | Entropy: -1.9294
# New ref model saved
# Epoch [23] 📊 acc: 0.796 | Targets: 1.1239 | Entropy: -1.9293
# New ref model saved
# Epoch [24] 📊 acc: 0.803 | Targets: 1.1153 | Entropy: -1.9277
# New ref model saved
# Epoch [25] 📊 acc: 0.804 | Targets: 1.1115 | Entropy: -1.9275
# New ref model saved
# Epoch [26] 📊 acc: 0.806 | Targets: 1.1048 | Entropy: -1.9260
# New ref model saved
# Epoch [27] 📊 acc: 0.810 | Targets: 1.0960 | Entropy: -1.9238
# New ref model saved
# Epoch [28] 📊 acc: 0.815 | Targets: 1.0913 | Entropy: -1.9224
# New ref model saved
# Epoch [29] 📊 acc: 0.814 | Targets: 1.0893 | Entropy: -1.9232
# Epoch [30] 📊 acc: 0.817 | Targets: 1.0861 | Entropy: -1.9224
# New ref model saved
#
# Evaluating at epoch 30 …
# Train Accuracy: 81.76%
# Train Average Loss: 1.0932
# Test Accuracy: 85.96%
# Test Average Loss: 1.0099
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 85.96%
# Epoch [31] 📊 acc: 0.823 | Targets: 1.0772 | Entropy: -1.9205
# New ref model saved
# Epoch [32] 📊 acc: 0.821 | Targets: 1.0758 | Entropy: -1.9207
# Epoch [33] 📊 acc: 0.824 | Targets: 1.0708 | Entropy: -1.9198
# New ref model saved
# Epoch [34] 📊 acc: 0.826 | Targets: 1.0687 | Entropy: -1.9195
# New ref model saved
# Epoch [35] 📊 acc: 0.830 | Targets: 1.0617 | Entropy: -1.9175
# New ref model saved
# Epoch [36] 📊 acc: 0.831 | Targets: 1.0586 | Entropy: -1.9175
# New ref model saved
# Epoch [37] 📊 acc: 0.834 | Targets: 1.0538 | Entropy: -1.9156
# New ref model saved
# Epoch [38] 📊 acc: 0.832 | Targets: 1.0580 | Entropy: -1.9173
# Epoch [39] 📊 acc: 0.835 | Targets: 1.0505 | Entropy: -1.9158
# New ref model saved
# Epoch [40] 📊 acc: 0.838 | Targets: 1.0512 | Entropy: -1.9162
# New ref model saved
#
# Evaluating at epoch 40 …
# Train Accuracy: 84.49%
# Train Average Loss: 1.0414
# Test Accuracy: 87.91%
# Test Average Loss: 0.9790
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 87.91%
# Epoch [41] 📊 acc: 0.841 | Targets: 1.0408 | Entropy: -1.9134
# New ref model saved
# Epoch [42] 📊 acc: 0.841 | Targets: 1.0419 | Entropy: -1.9143
# Epoch [43] 📊 acc: 0.843 | Targets: 1.0351 | Entropy: -1.9122
# New ref model saved
# Epoch [44] 📊 acc: 0.847 | Targets: 1.0319 | Entropy: -1.9122
# New ref model saved
# Epoch [45] 📊 acc: 0.845 | Targets: 1.0318 | Entropy: -1.9120
# Epoch [46] 📊 acc: 0.848 | Targets: 1.0283 | Entropy: -1.9113
# New ref model saved
# Epoch [47] 📊 acc: 0.849 | Targets: 1.0273 | Entropy: -1.9110
# New ref model saved
# Epoch [48] 📊 acc: 0.851 | Targets: 1.0249 | Entropy: -1.9106
# New ref model saved
# Epoch [49] 📊 acc: 0.852 | Targets: 1.0206 | Entropy: -1.9096
# New ref model saved
# Epoch [50] 📊 acc: 0.851 | Targets: 1.0225 | Entropy: -1.9105
#
# Evaluating at epoch 50 …
# Train Accuracy: 85.90%
# Train Average Loss: 0.9905
# Test Accuracy: 88.82%
# Test Average Loss: 0.9315
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.33e-04
# New best model saved with test accuracy: 88.82%
# Epoch [51] 📊 acc: 0.854 | Targets: 1.0153 | Entropy: -1.9087
# New ref model saved
# Epoch [52] 📊 acc: 0.856 | Targets: 1.0118 | Entropy: -1.9081
# New ref model saved
# Epoch [53] 📊 acc: 0.856 | Targets: 1.0118 | Entropy: -1.9083
# New ref model saved
# Epoch [54] 📊 acc: 0.858 | Targets: 1.0092 | Entropy: -1.9073
# New ref model saved
# Epoch [55] 📊 acc: 0.860 | Targets: 1.0070 | Entropy: -1.9069
# New ref model saved
# Epoch [56] 📊 acc: 0.861 | Targets: 1.0029 | Entropy: -1.9061
# New ref model saved
# Epoch [57] 📊 acc: 0.861 | Targets: 1.0035 | Entropy: -1.9061
# Epoch [58] 📊 acc: 0.864 | Targets: 0.9978 | Entropy: -1.9045
# New ref model saved
# Epoch [59] 📊 acc: 0.863 | Targets: 1.0025 | Entropy: -1.9063
# Epoch [60] 📊 acc: 0.865 | Targets: 0.9940 | Entropy: -1.9043
# New ref model saved
#
# Evaluating at epoch 60 …
# Train Accuracy: 87.67%
# Train Average Loss: 0.9566
# Test Accuracy: 90.31%
# Test Average Loss: 0.9051
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 90.31%
# Epoch [61] 📊 acc: 0.868 | Targets: 0.9925 | Entropy: -1.9039
# New ref model saved
# Epoch [62] 📊 acc: 0.868 | Targets: 0.9910 | Entropy: -1.9038
# New ref model saved
# Epoch [63] 📊 acc: 0.871 | Targets: 0.9860 | Entropy: -1.9027
# New ref model saved
# Epoch [64] 📊 acc: 0.873 | Targets: 0.9854 | Entropy: -1.9023
# New ref model saved
# Epoch [65] 📊 acc: 0.872 | Targets: 0.9831 | Entropy: -1.9013
# Epoch [66] 📊 acc: 0.874 | Targets: 0.9809 | Entropy: -1.9013
# New ref model saved
# Epoch [67] 📊 acc: 0.874 | Targets: 0.9801 | Entropy: -1.9017
# Epoch [68] 📊 acc: 0.875 | Targets: 0.9787 | Entropy: -1.9007
# New ref model saved
# Epoch [69] 📊 acc: 0.875 | Targets: 0.9787 | Entropy: -1.9013
# Epoch [70] 📊 acc: 0.878 | Targets: 0.9733 | Entropy: -1.8996
# New ref model saved
#
# Evaluating at epoch 70 …
# Train Accuracy: 87.68%
# Train Average Loss: 0.9815
# Test Accuracy: 90.15%
# Test Average Loss: 0.9282
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.72e-04
# Epoch [71] 📊 acc: 0.879 | Targets: 0.9727 | Entropy: -1.9000
# New ref model saved
# Epoch [72] 📊 acc: 0.877 | Targets: 0.9752 | Entropy: -1.9007
# Epoch [73] 📊 acc: 0.878 | Targets: 0.9714 | Entropy: -1.8996
# Epoch [74] 📊 acc: 0.881 | Targets: 0.9676 | Entropy: -1.8989
# New ref model saved
# Epoch [75] 📊 acc: 0.882 | Targets: 0.9678 | Entropy: -1.8988
# New ref model saved
# Epoch [76] 📊 acc: 0.881 | Targets: 0.9660 | Entropy: -1.8986
# Epoch [77] 📊 acc: 0.883 | Targets: 0.9627 | Entropy: -1.8974
# New ref model saved
# Epoch [78] 📊 acc: 0.883 | Targets: 0.9622 | Entropy: -1.8976
# New ref model saved
# Epoch [79] 📊 acc: 0.881 | Targets: 0.9661 | Entropy: -1.8986
# Epoch [80] 📊 acc: 0.884 | Targets: 0.9618 | Entropy: -1.8975
# New ref model saved
#
# Evaluating at epoch 80 …
# Train Accuracy: 88.33%
# Train Average Loss: 0.9771
# Test Accuracy: 90.57%
# Test Average Loss: 0.9180
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.35e-04
# New best model saved with test accuracy: 90.57%
# Epoch [81] 📊 acc: 0.887 | Targets: 0.9589 | Entropy: -1.8972
# New ref model saved
# Epoch [82] 📊 acc: 0.887 | Targets: 0.9559 | Entropy: -1.8960
# New ref model saved
# Epoch [83] 📊 acc: 0.886 | Targets: 0.9566 | Entropy: -1.8961
# Epoch [84] 📊 acc: 0.888 | Targets: 0.9554 | Entropy: -1.8963
# New ref model saved
# Epoch [85] 📊 acc: 0.889 | Targets: 0.9529 | Entropy: -1.8956
# New ref model saved
# Epoch [86] 📊 acc: 0.890 | Targets: 0.9499 | Entropy: -1.8948
# New ref model saved
# Epoch [87] 📊 acc: 0.893 | Targets: 0.9459 | Entropy: -1.8940
# New ref model saved
# Epoch [88] 📊 acc: 0.890 | Targets: 0.9520 | Entropy: -1.8953
# Epoch [89] 📊 acc: 0.892 | Targets: 0.9468 | Entropy: -1.8943
# Epoch [90] 📊 acc: 0.892 | Targets: 0.9474 | Entropy: -1.8943
#
# Evaluating at epoch 90 …
# Train Accuracy: 89.02%
# Train Average Loss: 0.9712
# Test Accuracy: 91.05%
# Test Average Loss: 0.9237
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.94e-04
# New best model saved with test accuracy: 91.05%
# Epoch [91] 📊 acc: 0.894 | Targets: 0.9448 | Entropy: -1.8940
# New ref model saved
# Epoch [92] 📊 acc: 0.896 | Targets: 0.9416 | Entropy: -1.8930
# New ref model saved
# Epoch [93] 📊 acc: 0.894 | Targets: 0.9421 | Entropy: -1.8931
# Epoch [94] 📊 acc: 0.896 | Targets: 0.9398 | Entropy: -1.8924
# New ref model saved
# Epoch [95] 📊 acc: 0.894 | Targets: 0.9432 | Entropy: -1.8937
# Epoch [96] 📊 acc: 0.896 | Targets: 0.9391 | Entropy: -1.8927
# Epoch [97] 📊 acc: 0.896 | Targets: 0.9377 | Entropy: -1.8921
# New ref model saved
# Epoch [98] 📊 acc: 0.900 | Targets: 0.9339 | Entropy: -1.8912
# New ref model saved
# Epoch [99] 📊 acc: 0.901 | Targets: 0.9327 | Entropy: -1.8912
# New ref model saved
# Epoch [100] 📊 acc: 0.899 | Targets: 0.9345 | Entropy: -1.8917
#
# Evaluating at epoch 100 …
# Train Accuracy: 90.41%
# Train Average Loss: 0.9287
# Test Accuracy: 91.63%
# Test Average Loss: 0.8938
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.50e-04
# New best model saved with test accuracy: 91.63%
# Epoch [101] 📊 acc: 0.899 | Targets: 0.9330 | Entropy: -1.8910
# Epoch [102] 📊 acc: 0.899 | Targets: 0.9319 | Entropy: -1.8904
# Epoch [103] 📊 acc: 0.901 | Targets: 0.9292 | Entropy: -1.8904
# New ref model saved
# Epoch [104] 📊 acc: 0.900 | Targets: 0.9333 | Entropy: -1.8914
# Epoch [105] 📊 acc: 0.903 | Targets: 0.9285 | Entropy: -1.8902
# New ref model saved
# Epoch [106] 📊 acc: 0.902 | Targets: 0.9261 | Entropy: -1.8893
# Epoch [107] 📊 acc: 0.906 | Targets: 0.9205 | Entropy: -1.8882
# New ref model saved
# Epoch [108] 📊 acc: 0.904 | Targets: 0.9247 | Entropy: -1.8895
# Epoch [109] 📊 acc: 0.904 | Targets: 0.9239 | Entropy: -1.8892
# Epoch [110] 📊 acc: 0.904 | Targets: 0.9210 | Entropy: -1.8880
#
# Evaluating at epoch 110 …
# Train Accuracy: 91.22%
# Train Average Loss: 0.9088
# Test Accuracy: 91.85%
# Test Average Loss: 0.8842
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.04e-04
# New best model saved with test accuracy: 91.85%
# Epoch [111] 📊 acc: 0.905 | Targets: 0.9225 | Entropy: -1.8887
# Epoch [112] 📊 acc: 0.907 | Targets: 0.9202 | Entropy: -1.8886
# New ref model saved
# Epoch [113] 📊 acc: 0.909 | Targets: 0.9182 | Entropy: -1.8874
# New ref model saved
# Epoch [114] 📊 acc: 0.909 | Targets: 0.9139 | Entropy: -1.8865
# New ref model saved
# Epoch [115] 📊 acc: 0.907 | Targets: 0.9191 | Entropy: -1.8880
# Epoch [116] 📊 acc: 0.909 | Targets: 0.9132 | Entropy: -1.8865
# New ref model saved
# Epoch [117] 📊 acc: 0.909 | Targets: 0.9132 | Entropy: -1.8859
# Epoch [118] 📊 acc: 0.909 | Targets: 0.9156 | Entropy: -1.8872
# New ref model saved
# Epoch [119] 📊 acc: 0.911 | Targets: 0.9109 | Entropy: -1.8862
# New ref model saved
# Epoch [120] 📊 acc: 0.910 | Targets: 0.9131 | Entropy: -1.8865
#
# Evaluating at epoch 120 …
# Train Accuracy: 91.10%
# Train Average Loss: 0.9054
# Test Accuracy: 91.78%
# Test Average Loss: 0.8812
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.55e-04
# Epoch [121] 📊 acc: 0.910 | Targets: 0.9125 | Entropy: -1.8861
# Epoch [122] 📊 acc: 0.912 | Targets: 0.9079 | Entropy: -1.8850
# New ref model saved
# Epoch [123] 📊 acc: 0.913 | Targets: 0.9060 | Entropy: -1.8845
# New ref model saved
# Epoch [124] 📊 acc: 0.914 | Targets: 0.9062 | Entropy: -1.8845
# New ref model saved
# Epoch [125] 📊 acc: 0.913 | Targets: 0.9085 | Entropy: -1.8858
# Epoch [126] 📊 acc: 0.914 | Targets: 0.9051 | Entropy: -1.8843
# Epoch [127] 📊 acc: 0.913 | Targets: 0.9055 | Entropy: -1.8842
# Epoch [128] 📊 acc: 0.915 | Targets: 0.9047 | Entropy: -1.8845
# New ref model saved
# Epoch [129] 📊 acc: 0.917 | Targets: 0.9014 | Entropy: -1.8838
# New ref model saved
# Epoch [130] 📊 acc: 0.914 | Targets: 0.9058 | Entropy: -1.8850
#
# Evaluating at epoch 130 …
# Train Accuracy: 92.04%
# Train Average Loss: 0.8918
# Test Accuracy: 92.56%
# Test Average Loss: 0.8677
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.04e-04
# New best model saved with test accuracy: 92.56%
# Epoch [131] 📊 acc: 0.916 | Targets: 0.9009 | Entropy: -1.8833
# Epoch [132] 📊 acc: 0.917 | Targets: 0.8992 | Entropy: -1.8828
# New ref model saved
# Epoch [133] 📊 acc: 0.919 | Targets: 0.8985 | Entropy: -1.8830
# New ref model saved
# Epoch [134] 📊 acc: 0.917 | Targets: 0.8993 | Entropy: -1.8833
# Epoch [135] 📊 acc: 0.917 | Targets: 0.8985 | Entropy: -1.8830
# Epoch [136] 📊 acc: 0.919 | Targets: 0.8968 | Entropy: -1.8825
# Epoch [137] 📊 acc: 0.919 | Targets: 0.8969 | Entropy: -1.8827
# Epoch [138] 📊 acc: 0.920 | Targets: 0.8956 | Entropy: -1.8822
# New ref model saved
# Epoch [139] 📊 acc: 0.921 | Targets: 0.8925 | Entropy: -1.8815
# New ref model saved
# Epoch [140] 📊 acc: 0.922 | Targets: 0.8903 | Entropy: -1.8808
# New ref model saved
#
# Evaluating at epoch 140 …
# Train Accuracy: 92.24%
# Train Average Loss: 0.8906
# Test Accuracy: 92.66%
# Test Average Loss: 0.8732
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.53e-04
# New best model saved with test accuracy: 92.66%
# Epoch [141] 📊 acc: 0.920 | Targets: 0.8944 | Entropy: -1.8821
# Epoch [142] 📊 acc: 0.920 | Targets: 0.8926 | Entropy: -1.8817
# Epoch [143] 📊 acc: 0.921 | Targets: 0.8932 | Entropy: -1.8816
# Epoch [144] 📊 acc: 0.922 | Targets: 0.8907 | Entropy: -1.8811
# New ref model saved
# Epoch [145] 📊 acc: 0.923 | Targets: 0.8900 | Entropy: -1.8807
# New ref model saved
# Epoch [146] 📊 acc: 0.925 | Targets: 0.8860 | Entropy: -1.8798
# New ref model saved
# Epoch [147] 📊 acc: 0.925 | Targets: 0.8866 | Entropy: -1.8803
# Epoch [148] 📊 acc: 0.924 | Targets: 0.8861 | Entropy: -1.8798
# Epoch [149] 📊 acc: 0.925 | Targets: 0.8854 | Entropy: -1.8797
# New ref model saved
# Epoch [150] 📊 acc: 0.926 | Targets: 0.8848 | Entropy: -1.8800
# New ref model saved
#
# Evaluating at epoch 150 …
# Train Accuracy: 92.80%
# Train Average Loss: 0.8827
# Test Accuracy: 93.12%
# Test Average Loss: 0.8682
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.00e-04
# New best model saved with test accuracy: 93.12%
# Epoch [151] 📊 acc: 0.923 | Targets: 0.8871 | Entropy: -1.8802
# Epoch [152] 📊 acc: 0.925 | Targets: 0.8857 | Entropy: -1.8802
# Epoch [153] 📊 acc: 0.926 | Targets: 0.8815 | Entropy: -1.8786
# New ref model saved
# Epoch [154] 📊 acc: 0.927 | Targets: 0.8815 | Entropy: -1.8791
# New ref model saved
# Epoch [155] 📊 acc: 0.927 | Targets: 0.8805 | Entropy: -1.8783
# Epoch [156] 📊 acc: 0.928 | Targets: 0.8804 | Entropy: -1.8783
# New ref model saved
# Epoch [157] 📊 acc: 0.928 | Targets: 0.8795 | Entropy: -1.8784
# Epoch [158] 📊 acc: 0.927 | Targets: 0.8798 | Entropy: -1.8783
# Epoch [159] 📊 acc: 0.931 | Targets: 0.8737 | Entropy: -1.8767
# New ref model saved
# Epoch [160] 📊 acc: 0.929 | Targets: 0.8765 | Entropy: -1.8772
#
# Evaluating at epoch 160 …
# Train Accuracy: 92.54%
# Train Average Loss: 0.8855
# Test Accuracy: 92.69%
# Test Average Loss: 0.8785
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.48e-04
# Epoch [161] 📊 acc: 0.930 | Targets: 0.8736 | Entropy: -1.8767
# Epoch [162] 📊 acc: 0.930 | Targets: 0.8727 | Entropy: -1.8765
# Epoch [163] 📊 acc: 0.932 | Targets: 0.8724 | Entropy: -1.8760
# New ref model saved
# Epoch [164] 📊 acc: 0.929 | Targets: 0.8765 | Entropy: -1.8776
# Epoch [165] 📊 acc: 0.932 | Targets: 0.8727 | Entropy: -1.8766
# New ref model saved
# Epoch [166] 📊 acc: 0.932 | Targets: 0.8720 | Entropy: -1.8766
# Epoch [167] 📊 acc: 0.932 | Targets: 0.8720 | Entropy: -1.8762
# Epoch [168] 📊 acc: 0.933 | Targets: 0.8724 | Entropy: -1.8765
# New ref model saved
# Epoch [169] 📊 acc: 0.932 | Targets: 0.8720 | Entropy: -1.8765
# Epoch [170] 📊 acc: 0.934 | Targets: 0.8676 | Entropy: -1.8751
# New ref model saved
#
# Evaluating at epoch 170 …
# Train Accuracy: 93.34%
# Train Average Loss: 0.8682
# Test Accuracy: 93.23%
# Test Average Loss: 0.8602
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.97e-04
# New best model saved with test accuracy: 93.23%
# Epoch [171] 📊 acc: 0.933 | Targets: 0.8713 | Entropy: -1.8765
# Epoch [172] 📊 acc: 0.933 | Targets: 0.8709 | Entropy: -1.8764
# Epoch [173] 📊 acc: 0.935 | Targets: 0.8658 | Entropy: -1.8747
# New ref model saved
# Epoch [174] 📊 acc: 0.934 | Targets: 0.8672 | Entropy: -1.8751
# Epoch [175] 📊 acc: 0.934 | Targets: 0.8691 | Entropy: -1.8758
# Epoch [176] 📊 acc: 0.935 | Targets: 0.8675 | Entropy: -1.8752
# New ref model saved
# Epoch [177] 📊 acc: 0.937 | Targets: 0.8637 | Entropy: -1.8743
# New ref model saved
# Epoch [178] 📊 acc: 0.936 | Targets: 0.8650 | Entropy: -1.8747
# Epoch [179] 📊 acc: 0.937 | Targets: 0.8624 | Entropy: -1.8739
# New ref model saved
# Epoch [180] 📊 acc: 0.936 | Targets: 0.8641 | Entropy: -1.8749
#
# Evaluating at epoch 180 …
# Train Accuracy: 93.69%
# Train Average Loss: 0.8704
# Test Accuracy: 93.32%
# Test Average Loss: 0.8704
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.46e-04
# New best model saved with test accuracy: 93.32%
# Epoch [181] 📊 acc: 0.937 | Targets: 0.8630 | Entropy: -1.8742
# Epoch [182] 📊 acc: 0.937 | Targets: 0.8622 | Entropy: -1.8743
# New ref model saved
# Epoch [183] 📊 acc: 0.937 | Targets: 0.8629 | Entropy: -1.8742
# Epoch [184] 📊 acc: 0.938 | Targets: 0.8601 | Entropy: -1.8737
# New ref model saved
# Epoch [185] 📊 acc: 0.939 | Targets: 0.8594 | Entropy: -1.8732
# New ref model saved
# Epoch [186] 📊 acc: 0.939 | Targets: 0.8590 | Entropy: -1.8732
# Epoch [187] 📊 acc: 0.938 | Targets: 0.8592 | Entropy: -1.8731
# Epoch [188] 📊 acc: 0.941 | Targets: 0.8563 | Entropy: -1.8726
# New ref model saved
# Epoch [189] 📊 acc: 0.941 | Targets: 0.8552 | Entropy: -1.8721
# New ref model saved
# Epoch [190] 📊 acc: 0.941 | Targets: 0.8550 | Entropy: -1.8721
#
# Evaluating at epoch 190 …
# Train Accuracy: 93.89%
# Train Average Loss: 0.8551
# Test Accuracy: 93.64%
# Test Average Loss: 0.8499
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.97e-04
# New best model saved with test accuracy: 93.64%
# Epoch [191] 📊 acc: 0.941 | Targets: 0.8559 | Entropy: -1.8724
# Epoch [192] 📊 acc: 0.940 | Targets: 0.8581 | Entropy: -1.8731
# Epoch [193] 📊 acc: 0.940 | Targets: 0.8557 | Entropy: -1.8722
# Epoch [194] 📊 acc: 0.941 | Targets: 0.8539 | Entropy: -1.8720
# New ref model saved
# Epoch [195] 📊 acc: 0.940 | Targets: 0.8555 | Entropy: -1.8723
# Epoch [196] 📊 acc: 0.940 | Targets: 0.8561 | Entropy: -1.8724
# Epoch [197] 📊 acc: 0.942 | Targets: 0.8519 | Entropy: -1.8715
# New ref model saved
# Epoch [198] 📊 acc: 0.941 | Targets: 0.8535 | Entropy: -1.8719
# Epoch [199] 📊 acc: 0.943 | Targets: 0.8515 | Entropy: -1.8713
# New ref model saved
# Epoch [200] 📊 acc: 0.945 | Targets: 0.8499 | Entropy: -1.8712
# New ref model saved
#
# Evaluating at epoch 200 …
# Train Accuracy: 94.65%
# Train Average Loss: 0.8425
# Test Accuracy: 93.59%
# Test Average Loss: 0.8548
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.51e-04
# Epoch [201] 📊 acc: 0.944 | Targets: 0.8496 | Entropy: -1.8706
# Epoch [202] 📊 acc: 0.943 | Targets: 0.8519 | Entropy: -1.8718
# Epoch [203] 📊 acc: 0.942 | Targets: 0.8522 | Entropy: -1.8713
# Epoch [204] 📊 acc: 0.943 | Targets: 0.8506 | Entropy: -1.8713
# Epoch [205] 📊 acc: 0.943 | Targets: 0.8504 | Entropy: -1.8709
# Epoch [206] 📊 acc: 0.944 | Targets: 0.8484 | Entropy: -1.8703
# Epoch [207] 📊 acc: 0.945 | Targets: 0.8469 | Entropy: -1.8702
# New ref model saved
# Epoch [208] 📊 acc: 0.945 | Targets: 0.8466 | Entropy: -1.8700
# New ref model saved
# Epoch [209] 📊 acc: 0.947 | Targets: 0.8438 | Entropy: -1.8696
# New ref model saved
# Epoch [210] 📊 acc: 0.949 | Targets: 0.8403 | Entropy: -1.8681
# New ref model saved
#
# Evaluating at epoch 210 …
# Train Accuracy: 94.48%
# Train Average Loss: 0.8453
# Test Accuracy: 93.61%
# Test Average Loss: 0.8525
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.07e-04
# Epoch [211] 📊 acc: 0.946 | Targets: 0.8458 | Entropy: -1.8700
# Epoch [212] 📊 acc: 0.946 | Targets: 0.8445 | Entropy: -1.8694
# Epoch [213] 📊 acc: 0.947 | Targets: 0.8428 | Entropy: -1.8687
# Epoch [214] 📊 acc: 0.948 | Targets: 0.8410 | Entropy: -1.8684
# Epoch [215] 📊 acc: 0.948 | Targets: 0.8427 | Entropy: -1.8693
# Epoch [216] 📊 acc: 0.948 | Targets: 0.8416 | Entropy: -1.8686
# Epoch [217] 📊 acc: 0.947 | Targets: 0.8423 | Entropy: -1.8691
# Epoch [218] 📊 acc: 0.949 | Targets: 0.8403 | Entropy: -1.8685
# New ref model saved
# Epoch [219] 📊 acc: 0.948 | Targets: 0.8410 | Entropy: -1.8686
# Epoch [220] 📊 acc: 0.947 | Targets: 0.8429 | Entropy: -1.8691
#
# Evaluating at epoch 220 …
# Train Accuracy: 95.02%
# Train Average Loss: 0.8380
# Test Accuracy: 93.72%
# Test Average Loss: 0.8526
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.66e-04
# New best model saved with test accuracy: 93.72%
# Epoch [221] 📊 acc: 0.950 | Targets: 0.8391 | Entropy: -1.8683
# New ref model saved
# Epoch [222] 📊 acc: 0.949 | Targets: 0.8404 | Entropy: -1.8685
# Epoch [223] 📊 acc: 0.948 | Targets: 0.8412 | Entropy: -1.8689
# Epoch [224] 📊 acc: 0.948 | Targets: 0.8404 | Entropy: -1.8685
# Epoch [225] 📊 acc: 0.950 | Targets: 0.8388 | Entropy: -1.8681
# Epoch [226] 📊 acc: 0.948 | Targets: 0.8414 | Entropy: -1.8687
# Epoch [227] 📊 acc: 0.949 | Targets: 0.8387 | Entropy: -1.8685
# Epoch [228] 📊 acc: 0.951 | Targets: 0.8370 | Entropy: -1.8678
# New ref model saved
# Epoch [229] 📊 acc: 0.951 | Targets: 0.8378 | Entropy: -1.8680
# New ref model saved
# Epoch [230] 📊 acc: 0.951 | Targets: 0.8361 | Entropy: -1.8674
# New ref model saved
#
# Evaluating at epoch 230 …
# Train Accuracy: 95.20%
# Train Average Loss: 0.8292
# Test Accuracy: 93.88%
# Test Average Loss: 0.8462
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.29e-04
# New best model saved with test accuracy: 93.88%
# Epoch [231] 📊 acc: 0.952 | Targets: 0.8326 | Entropy: -1.8663
# New ref model saved
# Epoch [232] 📊 acc: 0.951 | Targets: 0.8349 | Entropy: -1.8670
# Epoch [233] 📊 acc: 0.951 | Targets: 0.8356 | Entropy: -1.8672
# Epoch [234] 📊 acc: 0.952 | Targets: 0.8323 | Entropy: -1.8661
# New ref model saved
# Epoch [235] 📊 acc: 0.951 | Targets: 0.8360 | Entropy: -1.8677
# Epoch [236] 📊 acc: 0.951 | Targets: 0.8351 | Entropy: -1.8670
# Epoch [237] 📊 acc: 0.954 | Targets: 0.8318 | Entropy: -1.8665
# New ref model saved
# Epoch [238] 📊 acc: 0.953 | Targets: 0.8315 | Entropy: -1.8659
# Epoch [239] 📊 acc: 0.954 | Targets: 0.8302 | Entropy: -1.8657
# Epoch [240] 📊 acc: 0.953 | Targets: 0.8307 | Entropy: -1.8656
#
# Evaluating at epoch 240 …
# Train Accuracy: 95.51%
# Train Average Loss: 0.8324
# Test Accuracy: 94.05%
# Test Average Loss: 0.8508
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.64e-05
# New best model saved with test accuracy: 94.05%
# Epoch [241] 📊 acc: 0.952 | Targets: 0.8323 | Entropy: -1.8662
# Epoch [242] 📊 acc: 0.953 | Targets: 0.8330 | Entropy: -1.8665
# Epoch [243] 📊 acc: 0.953 | Targets: 0.8319 | Entropy: -1.8660
# Epoch [244] 📊 acc: 0.954 | Targets: 0.8295 | Entropy: -1.8657
# New ref model saved
# Epoch [245] 📊 acc: 0.953 | Targets: 0.8323 | Entropy: -1.8666
# Epoch [246] 📊 acc: 0.953 | Targets: 0.8332 | Entropy: -1.8670
# Epoch [247] 📊 acc: 0.955 | Targets: 0.8296 | Entropy: -1.8658
# New ref model saved
# Epoch [248] 📊 acc: 0.953 | Targets: 0.8334 | Entropy: -1.8669
# Epoch [249] 📊 acc: 0.953 | Targets: 0.8326 | Entropy: -1.8665
# Epoch [250] 📊 acc: 0.954 | Targets: 0.8316 | Entropy: -1.8663
#
# Evaluating at epoch 250 …
# Train Accuracy: 95.47%
# Train Average Loss: 0.8310
# Test Accuracy: 94.12%
# Test Average Loss: 0.8477
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.79e-05
# New best model saved with test accuracy: 94.12%
# Epoch [251] 📊 acc: 0.955 | Targets: 0.8292 | Entropy: -1.8658
# New ref model saved
# Epoch [252] 📊 acc: 0.955 | Targets: 0.8283 | Entropy: -1.8655
# New ref model saved
# Epoch [253] 📊 acc: 0.955 | Targets: 0.8287 | Entropy: -1.8656
# New ref model saved
# Epoch [254] 📊 acc: 0.953 | Targets: 0.8319 | Entropy: -1.8665
# Epoch [255] 📊 acc: 0.955 | Targets: 0.8278 | Entropy: -1.8652
# Epoch [256] 📊 acc: 0.956 | Targets: 0.8273 | Entropy: -1.8650
# New ref model saved
# Epoch [257] 📊 acc: 0.955 | Targets: 0.8280 | Entropy: -1.8651
# Epoch [258] 📊 acc: 0.956 | Targets: 0.8282 | Entropy: -1.8653
# Epoch [259] 📊 acc: 0.955 | Targets: 0.8287 | Entropy: -1.8659
# Epoch [260] 📊 acc: 0.956 | Targets: 0.8277 | Entropy: -1.8654
#
# Evaluating at epoch 260 …
# Train Accuracy: 95.50%
# Train Average Loss: 0.8278
# Test Accuracy: 94.37%
# Test Average Loss: 0.8454
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.42e-05
# New best model saved with test accuracy: 94.37%
# Epoch [261] 📊 acc: 0.955 | Targets: 0.8260 | Entropy: -1.8646
# Epoch [262] 📊 acc: 0.955 | Targets: 0.8283 | Entropy: -1.8659
# Epoch [263] 📊 acc: 0.955 | Targets: 0.8280 | Entropy: -1.8653
# Epoch [264] 📊 acc: 0.957 | Targets: 0.8257 | Entropy: -1.8648
# New ref model saved
# Epoch [265] 📊 acc: 0.956 | Targets: 0.8261 | Entropy: -1.8649
# Epoch [266] 📊 acc: 0.957 | Targets: 0.8244 | Entropy: -1.8641
# New ref model saved
# Epoch [267] 📊 acc: 0.958 | Targets: 0.8239 | Entropy: -1.8646
# New ref model saved
# Epoch [268] 📊 acc: 0.956 | Targets: 0.8252 | Entropy: -1.8646
# Epoch [269] 📊 acc: 0.957 | Targets: 0.8244 | Entropy: -1.8644
# Epoch [270] 📊 acc: 0.955 | Targets: 0.8274 | Entropy: -1.8653
#
# Evaluating at epoch 270 …
# Train Accuracy: 95.56%
# Train Average Loss: 0.8249
# Test Accuracy: 94.11%
# Test Average Loss: 0.8444
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-05
# Epoch [271] 📊 acc: 0.958 | Targets: 0.8235 | Entropy: -1.8639
# New ref model saved
# Epoch [272] 📊 acc: 0.956 | Targets: 0.8255 | Entropy: -1.8648
# Epoch [273] 📊 acc: 0.957 | Targets: 0.8243 | Entropy: -1.8640
# Epoch [274] 📊 acc: 0.956 | Targets: 0.8263 | Entropy: -1.8646
# Epoch [275] 📊 acc: 0.958 | Targets: 0.8237 | Entropy: -1.8646
# New ref model saved
# Epoch [276] 📊 acc: 0.956 | Targets: 0.8251 | Entropy: -1.8644
# Epoch [277] 📊 acc: 0.956 | Targets: 0.8257 | Entropy: -1.8650
# Epoch [278] 📊 acc: 0.956 | Targets: 0.8260 | Entropy: -1.8646
# Epoch [279] 📊 acc: 0.957 | Targets: 0.8249 | Entropy: -1.8646
# Epoch [280] 📊 acc: 0.955 | Targets: 0.8269 | Entropy: -1.8650
#
# Evaluating at epoch 280 …
# Train Accuracy: 95.70%
# Train Average Loss: 0.8255
# Test Accuracy: 94.40%
# Test Average Loss: 0.8450
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.19e-05
# New best model saved with test accuracy: 94.40%
# Epoch [281] 📊 acc: 0.957 | Targets: 0.8255 | Entropy: -1.8650
# Epoch [282] 📊 acc: 0.958 | Targets: 0.8220 | Entropy: -1.8634
# New ref model saved
# Epoch [283] 📊 acc: 0.959 | Targets: 0.8218 | Entropy: -1.8635
# New ref model saved
# Epoch [284] 📊 acc: 0.958 | Targets: 0.8230 | Entropy: -1.8641
# Epoch [285] 📊 acc: 0.958 | Targets: 0.8241 | Entropy: -1.8644
# Epoch [286] 📊 acc: 0.957 | Targets: 0.8244 | Entropy: -1.8643
# Epoch [287] 📊 acc: 0.957 | Targets: 0.8258 | Entropy: -1.8654
# Epoch [288] 📊 acc: 0.958 | Targets: 0.8221 | Entropy: -1.8638
# Epoch [289] 📊 acc: 0.957 | Targets: 0.8233 | Entropy: -1.8639
# Epoch [290] 📊 acc: 0.958 | Targets: 0.8219 | Entropy: -1.8636
#
# Evaluating at epoch 290 …
# Train Accuracy: 95.77%
# Train Average Loss: 0.8229
# Test Accuracy: 94.39%
# Test Average Loss: 0.8441
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.74e-06
# Epoch [291] 📊 acc: 0.958 | Targets: 0.8224 | Entropy: -1.8637
# Epoch [292] 📊 acc: 0.957 | Targets: 0.8245 | Entropy: -1.8642
# Epoch [293] 📊 acc: 0.958 | Targets: 0.8227 | Entropy: -1.8640
# Epoch [294] 📊 acc: 0.957 | Targets: 0.8252 | Entropy: -1.8643
# Epoch [295] 📊 acc: 0.959 | Targets: 0.8210 | Entropy: -1.8638
# New ref model saved
# Epoch [296] 📊 acc: 0.957 | Targets: 0.8237 | Entropy: -1.8638
# Epoch [297] 📊 acc: 0.957 | Targets: 0.8238 | Entropy: -1.8645
# Epoch [298] 📊 acc: 0.957 | Targets: 0.8233 | Entropy: -1.8640
# Epoch [299] 📊 acc: 0.957 | Targets: 0.8242 | Entropy: -1.8640
# Epoch [300] 📊 acc: 0.957 | Targets: 0.8252 | Entropy: -1.8646
#
# Evaluating at epoch 300 …
# Train Accuracy: 95.70%
# Train Average Loss: 0.8229
# Test Accuracy: 94.41%
# Test Average Loss: 0.8441
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-06
# New best model saved with test accuracy: 94.41%
# Finished Training
# Best test accuracy achieved: 94.41%
# Total Trainable Parameters: 515,754
