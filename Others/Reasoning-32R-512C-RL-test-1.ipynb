# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth):
        out = self.conv[depth // (self.max_depth // self.num_module)](x, depth)
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        if depth < self.max_depth - 1:
            x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            x = checkpoint(self.step_forward, x, x_prev, d, use_reentrant=False)

        return x

# %%
class RecursionAmplifyConv(nn.Module):
    def __init__(self, channels, height, width):
        super(RecursionAmplifyConv, self).__init__()
        
        self.conv0 = nn.Conv2d(3, channels, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(channels, max_depth=32, num_module=1)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))


    def forward(self, x):
        
        x = self.conv0(x)

        x = self.amconv(x)

        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.reamconv= RecursionAmplifyConv(512, 32, 32)

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.reamconv(x)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        return x

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 1)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        pre_entropy = torch.sum(pre_probs * torch.log(pre_probs), dim=1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_pre_entropy = torch.sum(old_pre_probs * torch.log(old_pre_probs), dim=1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        ref_entropy = torch.sum(ref_probs * torch.log(ref_probs), dim=1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_ref_entropy = torch.sum(old_ref_probs * torch.log(old_ref_probs), dim=1)

        rewards, correct = self.compute_reconstruct_reward(outputs, targets)
        p_rewards, _ = self.compute_positive_reward(outputs, targets)
        n_rewards, _ = self.compute_negative_reward(outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        entropy_delta = (entropy - old_entropy)
        pre_entropy_delta = (pre_entropy - old_pre_entropy)
        ref_entropy_delta = (ref_entropy - old_ref_entropy)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
                'entropy': entropy.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)

    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()

    all_params = list(net.parameters()) + list(pre_net.parameters())
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    ref_accuracy = 0.0
    pre_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    ref_count = 32
    d = 0
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=300, eta_min=1e-6
            )

        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
            'rewards_mean': 0.0, 'rewards_std': 0.0, 
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs = net(inputs)
                ref_outputs = ref_net(inputs)
                pre_outputs = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_ratio = F.sigmoid(pre_select_delta) + F.sigmoid(select_delta) - F.sigmoid(ref_select_delta)
                select_loss = select_ratio.sum()
                
                entropy_ratio = F.sigmoid(pre_entropy_delta) +  F.sigmoid(entropy_delta) - F.sigmoid(ref_entropy_delta)
                entropy_loss = entropy_ratio.sum()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(all_params, max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f}")

        if running_cor > ref_accuracy:
            ref_accuracy = running_cor
            ref = copy.deepcopy(net).to(device)
            if d % 2 == 0:
                prev_ref.append(ref)
                prev_ref = prev_ref[-ref_count:]
            ref_net = prev_ref[((d % ref_count + 1) - ((d % ref_count + 1) & -(d % ref_count + 1))) // 2]
            d += 1
            print(f"New ref model saved")

        if running_cor > pre_accuracy:
            pre_accuracy = running_cor
            pre_net = copy.deepcopy(net).to(device)
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
                    if use_bf16 else contextlib.nullcontext())

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = net(images)  
            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum    += batch_loss.item() * bs
            total_seen  += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 515,754

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.331 | Targets: 1.9578 | Entropy: -2.1616
# New ref model saved
# Epoch [2] 📊 acc: 0.494 | Targets: 1.6710 | Entropy: -2.0768
# New ref model saved
# Epoch [3] 📊 acc: 0.576 | Targets: 1.5308 | Entropy: -2.0346
# New ref model saved
# Epoch [4] 📊 acc: 0.627 | Targets: 1.4436 | Entropy: -2.0092
# New ref model saved
# Epoch [5] 📊 acc: 0.660 | Targets: 1.3873 | Entropy: -1.9941
# New ref model saved
# Epoch [6] 📊 acc: 0.685 | Targets: 1.3409 | Entropy: -1.9816
# New ref model saved
# Epoch [7] 📊 acc: 0.703 | Targets: 1.3098 | Entropy: -1.9747
# New ref model saved
# Epoch [8] 📊 acc: 0.717 | Targets: 1.2838 | Entropy: -1.9677
# New ref model saved
# Epoch [9] 📊 acc: 0.731 | Targets: 1.2551 | Entropy: -1.9599
# New ref model saved
# Epoch [10] 📊 acc: 0.736 | Targets: 1.2436 | Entropy: -1.9583
# New ref model saved
#
# Evaluating at epoch 10 …
# Train Accuracy: 75.49%
# Train Average Loss: 1.2400
# Test Accuracy: 80.41%
# Test Average Loss: 1.1501
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 80.41%
# Epoch [11] 📊 acc: 0.745 | Targets: 1.2259 | Entropy: -1.9541
# New ref model saved
# Epoch [12] 📊 acc: 0.756 | Targets: 1.2074 | Entropy: -1.9490
# New ref model saved
# Epoch [13] 📊 acc: 0.762 | Targets: 1.1935 | Entropy: -1.9458
# New ref model saved
# Epoch [14] 📊 acc: 0.768 | Targets: 1.1836 | Entropy: -1.9435
# New ref model saved
# Epoch [15] 📊 acc: 0.775 | Targets: 1.1701 | Entropy: -1.9403
# New ref model saved
# Epoch [16] 📊 acc: 0.778 | Targets: 1.1659 | Entropy: -1.9402
# New ref model saved
# Epoch [17] 📊 acc: 0.781 | Targets: 1.1558 | Entropy: -1.9376
# New ref model saved
# Epoch [18] 📊 acc: 0.789 | Targets: 1.1431 | Entropy: -1.9356
# New ref model saved
# Epoch [19] 📊 acc: 0.792 | Targets: 1.1381 | Entropy: -1.9347
# New ref model saved
# Epoch [20] 📊 acc: 0.796 | Targets: 1.1292 | Entropy: -1.9324
# New ref model saved
#
# Evaluating at epoch 20 …
# Train Accuracy: 79.99%
# Train Average Loss: 1.1090
# Test Accuracy: 84.25%
# Test Average Loss: 1.0377
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 84.25%
# Epoch [21] 📊 acc: 0.799 | Targets: 1.1255 | Entropy: -1.9313
# New ref model saved
# Epoch [22] 📊 acc: 0.803 | Targets: 1.1159 | Entropy: -1.9290
# New ref model saved
# Epoch [23] 📊 acc: 0.805 | Targets: 1.1117 | Entropy: -1.9288
# New ref model saved
# Epoch [24] 📊 acc: 0.808 | Targets: 1.1043 | Entropy: -1.9263
# New ref model saved
# Epoch [25] 📊 acc: 0.812 | Targets: 1.0976 | Entropy: -1.9251
# New ref model saved
# Epoch [26] 📊 acc: 0.813 | Targets: 1.0963 | Entropy: -1.9255
# New ref model saved
# Epoch [27] 📊 acc: 0.816 | Targets: 1.0898 | Entropy: -1.9237
# New ref model saved
# Epoch [28] 📊 acc: 0.818 | Targets: 1.0866 | Entropy: -1.9227
# New ref model saved
# Epoch [29] 📊 acc: 0.822 | Targets: 1.0788 | Entropy: -1.9206
# New ref model saved
# Epoch [30] 📊 acc: 0.823 | Targets: 1.0770 | Entropy: -1.9205
# New ref model saved
#
# Evaluating at epoch 30 …
# Train Accuracy: 82.78%
# Train Average Loss: 1.0694
# Test Accuracy: 87.02%
# Test Average Loss: 0.9892
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 87.02%
# Epoch [31] 📊 acc: 0.826 | Targets: 1.0712 | Entropy: -1.9199
# New ref model saved
# Epoch [32] 📊 acc: 0.826 | Targets: 1.0694 | Entropy: -1.9197
# New ref model saved
# Epoch [33] 📊 acc: 0.831 | Targets: 1.0632 | Entropy: -1.9177
# New ref model saved
# Epoch [34] 📊 acc: 0.830 | Targets: 1.0619 | Entropy: -1.9172
# Epoch [35] 📊 acc: 0.834 | Targets: 1.0550 | Entropy: -1.9155
# New ref model saved
# Epoch [36] 📊 acc: 0.837 | Targets: 1.0512 | Entropy: -1.9151
# New ref model saved
# Epoch [37] 📊 acc: 0.837 | Targets: 1.0496 | Entropy: -1.9151
# New ref model saved
# Epoch [38] 📊 acc: 0.839 | Targets: 1.0463 | Entropy: -1.9142
# New ref model saved
# Epoch [39] 📊 acc: 0.841 | Targets: 1.0428 | Entropy: -1.9133
# New ref model saved
# Epoch [40] 📊 acc: 0.839 | Targets: 1.0441 | Entropy: -1.9140
#
# Evaluating at epoch 40 …
# Train Accuracy: 85.15%
# Train Average Loss: 1.0225
# Test Accuracy: 88.71%
# Test Average Loss: 0.9432
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 88.71%
# Epoch [41] 📊 acc: 0.843 | Targets: 1.0367 | Entropy: -1.9118
# New ref model saved
# Epoch [42] 📊 acc: 0.845 | Targets: 1.0332 | Entropy: -1.9110
# New ref model saved
# Epoch [43] 📊 acc: 0.848 | Targets: 1.0315 | Entropy: -1.9109
# New ref model saved
# Epoch [44] 📊 acc: 0.849 | Targets: 1.0285 | Entropy: -1.9095
# New ref model saved
# Epoch [45] 📊 acc: 0.852 | Targets: 1.0222 | Entropy: -1.9086
# New ref model saved
# Epoch [46] 📊 acc: 0.852 | Targets: 1.0231 | Entropy: -1.9092
# Epoch [47] 📊 acc: 0.852 | Targets: 1.0218 | Entropy: -1.9084
# Epoch [48] 📊 acc: 0.852 | Targets: 1.0200 | Entropy: -1.9087
# Epoch [49] 📊 acc: 0.853 | Targets: 1.0186 | Entropy: -1.9078
# New ref model saved
# Epoch [50] 📊 acc: 0.855 | Targets: 1.0149 | Entropy: -1.9074
# New ref model saved
#
# Evaluating at epoch 50 …
# Train Accuracy: 86.46%
# Train Average Loss: 0.9962
# Test Accuracy: 89.45%
# Test Average Loss: 0.9349
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.33e-04
# New best model saved with test accuracy: 89.45%
# Epoch [51] 📊 acc: 0.856 | Targets: 1.0132 | Entropy: -1.9070
# New ref model saved
# Epoch [52] 📊 acc: 0.856 | Targets: 1.0142 | Entropy: -1.9077
# Epoch [53] 📊 acc: 0.859 | Targets: 1.0084 | Entropy: -1.9057
# New ref model saved
# Epoch [54] 📊 acc: 0.861 | Targets: 1.0056 | Entropy: -1.9059
# New ref model saved
# Epoch [55] 📊 acc: 0.861 | Targets: 1.0044 | Entropy: -1.9051
# New ref model saved
# Epoch [56] 📊 acc: 0.865 | Targets: 0.9981 | Entropy: -1.9036
# New ref model saved
# Epoch [57] 📊 acc: 0.863 | Targets: 1.0003 | Entropy: -1.9046
# Epoch [58] 📊 acc: 0.864 | Targets: 0.9978 | Entropy: -1.9035
# Epoch [59] 📊 acc: 0.865 | Targets: 0.9982 | Entropy: -1.9039
# Epoch [60] 📊 acc: 0.867 | Targets: 0.9934 | Entropy: -1.9031
# New ref model saved
#
# Evaluating at epoch 60 …
# Train Accuracy: 87.00%
# Train Average Loss: 0.9977
# Test Accuracy: 89.21%
# Test Average Loss: 0.9507
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.05e-04
# Epoch [61] 📊 acc: 0.870 | Targets: 0.9877 | Entropy: -1.9005
# New ref model saved
# Epoch [62] 📊 acc: 0.870 | Targets: 0.9884 | Entropy: -1.9017
# Epoch [63] 📊 acc: 0.869 | Targets: 0.9889 | Entropy: -1.9020
# Epoch [64] 📊 acc: 0.871 | Targets: 0.9880 | Entropy: -1.9020
# New ref model saved
# Epoch [65] 📊 acc: 0.873 | Targets: 0.9817 | Entropy: -1.9001
# New ref model saved
# Epoch [66] 📊 acc: 0.873 | Targets: 0.9834 | Entropy: -1.9007
# Epoch [67] 📊 acc: 0.874 | Targets: 0.9817 | Entropy: -1.9002
# New ref model saved
# Epoch [68] 📊 acc: 0.873 | Targets: 0.9815 | Entropy: -1.9007
# Epoch [69] 📊 acc: 0.874 | Targets: 0.9782 | Entropy: -1.8999
# Epoch [70] 📊 acc: 0.878 | Targets: 0.9742 | Entropy: -1.8988
# New ref model saved
#
# Evaluating at epoch 70 …
# Train Accuracy: 88.55%
# Train Average Loss: 0.9653
# Test Accuracy: 90.57%
# Test Average Loss: 0.9142
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.72e-04
# New best model saved with test accuracy: 90.57%
# Epoch [71] 📊 acc: 0.879 | Targets: 0.9741 | Entropy: -1.8994
# New ref model saved
# Epoch [72] 📊 acc: 0.876 | Targets: 0.9742 | Entropy: -1.8990
# Epoch [73] 📊 acc: 0.880 | Targets: 0.9702 | Entropy: -1.8980
# New ref model saved
# Epoch [74] 📊 acc: 0.880 | Targets: 0.9693 | Entropy: -1.8981
# New ref model saved
# Epoch [75] 📊 acc: 0.880 | Targets: 0.9699 | Entropy: -1.8982
# Epoch [76] 📊 acc: 0.881 | Targets: 0.9676 | Entropy: -1.8974
# New ref model saved
# Epoch [77] 📊 acc: 0.884 | Targets: 0.9634 | Entropy: -1.8966
# New ref model saved
# Epoch [78] 📊 acc: 0.881 | Targets: 0.9672 | Entropy: -1.8976
# Epoch [79] 📊 acc: 0.881 | Targets: 0.9663 | Entropy: -1.8979
# Epoch [80] 📊 acc: 0.886 | Targets: 0.9607 | Entropy: -1.8958
# New ref model saved
#
# Evaluating at epoch 80 …
# Train Accuracy: 88.99%
# Train Average Loss: 0.9335
# Test Accuracy: 90.50%
# Test Average Loss: 0.8986
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.35e-04
# Epoch [81] 📊 acc: 0.886 | Targets: 0.9584 | Entropy: -1.8952
# New ref model saved
# Epoch [82] 📊 acc: 0.887 | Targets: 0.9589 | Entropy: -1.8954
# New ref model saved
# Epoch [83] 📊 acc: 0.887 | Targets: 0.9588 | Entropy: -1.8957
# New ref model saved
# Epoch [84] 📊 acc: 0.885 | Targets: 0.9591 | Entropy: -1.8960
# Epoch [85] 📊 acc: 0.888 | Targets: 0.9534 | Entropy: -1.8942
# New ref model saved
# Epoch [86] 📊 acc: 0.890 | Targets: 0.9519 | Entropy: -1.8938
# New ref model saved
# Epoch [87] 📊 acc: 0.889 | Targets: 0.9556 | Entropy: -1.8953
# Epoch [88] 📊 acc: 0.892 | Targets: 0.9467 | Entropy: -1.8928
# New ref model saved
# Epoch [89] 📊 acc: 0.889 | Targets: 0.9525 | Entropy: -1.8947
# Epoch [90] 📊 acc: 0.893 | Targets: 0.9464 | Entropy: -1.8928
# New ref model saved
#
# Evaluating at epoch 90 …
# Train Accuracy: 89.54%
# Train Average Loss: 0.9435
# Test Accuracy: 91.26%
# Test Average Loss: 0.9032
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.94e-04
# New best model saved with test accuracy: 91.26%
# Epoch [91] 📊 acc: 0.893 | Targets: 0.9454 | Entropy: -1.8921
# New ref model saved
# Epoch [92] 📊 acc: 0.893 | Targets: 0.9471 | Entropy: -1.8930
# Epoch [93] 📊 acc: 0.895 | Targets: 0.9403 | Entropy: -1.8908
# New ref model saved
# Epoch [94] 📊 acc: 0.896 | Targets: 0.9416 | Entropy: -1.8916
# New ref model saved
# Epoch [95] 📊 acc: 0.895 | Targets: 0.9421 | Entropy: -1.8916
# Epoch [96] 📊 acc: 0.896 | Targets: 0.9398 | Entropy: -1.8912
# New ref model saved
# Epoch [97] 📊 acc: 0.897 | Targets: 0.9383 | Entropy: -1.8910
# New ref model saved
# Epoch [98] 📊 acc: 0.898 | Targets: 0.9372 | Entropy: -1.8910
# New ref model saved
# Epoch [99] 📊 acc: 0.896 | Targets: 0.9397 | Entropy: -1.8913
# Epoch [100] 📊 acc: 0.897 | Targets: 0.9380 | Entropy: -1.8908
#
# Evaluating at epoch 100 …
# Train Accuracy: 90.09%
# Train Average Loss: 0.9426
# Test Accuracy: 90.88%
# Test Average Loss: 0.9173
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.50e-04
# Epoch [101] 📊 acc: 0.900 | Targets: 0.9314 | Entropy: -1.8894
# New ref model saved
# Epoch [102] 📊 acc: 0.898 | Targets: 0.9360 | Entropy: -1.8910
# Epoch [103] 📊 acc: 0.900 | Targets: 0.9340 | Entropy: -1.8901
# Epoch [104] 📊 acc: 0.901 | Targets: 0.9292 | Entropy: -1.8890
# New ref model saved
# Epoch [105] 📊 acc: 0.901 | Targets: 0.9301 | Entropy: -1.8888
# Epoch [106] 📊 acc: 0.901 | Targets: 0.9293 | Entropy: -1.8887
# Epoch [107] 📊 acc: 0.903 | Targets: 0.9262 | Entropy: -1.8877
# New ref model saved
# Epoch [108] 📊 acc: 0.902 | Targets: 0.9280 | Entropy: -1.8888
# Epoch [109] 📊 acc: 0.904 | Targets: 0.9239 | Entropy: -1.8876
# New ref model saved
# Epoch [110] 📊 acc: 0.903 | Targets: 0.9270 | Entropy: -1.8884
#
# Evaluating at epoch 110 …
# Train Accuracy: 90.80%
# Train Average Loss: 0.9156
# Test Accuracy: 91.78%
# Test Average Loss: 0.8934
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.04e-04
# New best model saved with test accuracy: 91.78%
# Epoch [111] 📊 acc: 0.905 | Targets: 0.9234 | Entropy: -1.8876
# New ref model saved
# Epoch [112] 📊 acc: 0.905 | Targets: 0.9212 | Entropy: -1.8867
# New ref model saved
# Epoch [113] 📊 acc: 0.905 | Targets: 0.9210 | Entropy: -1.8866
# Epoch [114] 📊 acc: 0.906 | Targets: 0.9229 | Entropy: -1.8874
# New ref model saved
# Epoch [115] 📊 acc: 0.906 | Targets: 0.9214 | Entropy: -1.8874
# New ref model saved
# Epoch [116] 📊 acc: 0.907 | Targets: 0.9185 | Entropy: -1.8865
# New ref model saved
# Epoch [117] 📊 acc: 0.907 | Targets: 0.9203 | Entropy: -1.8868
# Epoch [118] 📊 acc: 0.907 | Targets: 0.9177 | Entropy: -1.8861
# New ref model saved
# Epoch [119] 📊 acc: 0.908 | Targets: 0.9174 | Entropy: -1.8864
# New ref model saved
# Epoch [120] 📊 acc: 0.910 | Targets: 0.9123 | Entropy: -1.8850
# New ref model saved
#
# Evaluating at epoch 120 …
# Train Accuracy: 91.70%
# Train Average Loss: 0.9015
# Test Accuracy: 92.09%
# Test Average Loss: 0.8885
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.55e-04
# New best model saved with test accuracy: 92.09%
# Epoch [121] 📊 acc: 0.911 | Targets: 0.9120 | Entropy: -1.8848
# New ref model saved
# Epoch [122] 📊 acc: 0.911 | Targets: 0.9121 | Entropy: -1.8849
# New ref model saved
# Epoch [123] 📊 acc: 0.911 | Targets: 0.9124 | Entropy: -1.8845
# Epoch [124] 📊 acc: 0.913 | Targets: 0.9099 | Entropy: -1.8846
# New ref model saved
# Epoch [125] 📊 acc: 0.913 | Targets: 0.9075 | Entropy: -1.8838
# New ref model saved
# Epoch [126] 📊 acc: 0.913 | Targets: 0.9090 | Entropy: -1.8839
# Epoch [127] 📊 acc: 0.915 | Targets: 0.9058 | Entropy: -1.8832
# New ref model saved
# Epoch [128] 📊 acc: 0.914 | Targets: 0.9061 | Entropy: -1.8838
# Epoch [129] 📊 acc: 0.913 | Targets: 0.9064 | Entropy: -1.8835
# Epoch [130] 📊 acc: 0.914 | Targets: 0.9053 | Entropy: -1.8829
#
# Evaluating at epoch 130 …
# Train Accuracy: 91.16%
# Train Average Loss: 0.9003
# Test Accuracy: 91.71%
# Test Average Loss: 0.8928
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.04e-04
# Epoch [131] 📊 acc: 0.915 | Targets: 0.9045 | Entropy: -1.8836
# New ref model saved
# Epoch [132] 📊 acc: 0.916 | Targets: 0.9023 | Entropy: -1.8825
# New ref model saved
# Epoch [133] 📊 acc: 0.916 | Targets: 0.9024 | Entropy: -1.8827
# New ref model saved
# Epoch [134] 📊 acc: 0.914 | Targets: 0.9044 | Entropy: -1.8833
# Epoch [135] 📊 acc: 0.915 | Targets: 0.9020 | Entropy: -1.8828
# Epoch [136] 📊 acc: 0.918 | Targets: 0.8993 | Entropy: -1.8819
# New ref model saved
# Epoch [137] 📊 acc: 0.917 | Targets: 0.9007 | Entropy: -1.8828
# Epoch [138] 📊 acc: 0.919 | Targets: 0.8972 | Entropy: -1.8812
# New ref model saved
# Epoch [139] 📊 acc: 0.920 | Targets: 0.8949 | Entropy: -1.8806
# New ref model saved
# Epoch [140] 📊 acc: 0.919 | Targets: 0.8965 | Entropy: -1.8814
#
# Evaluating at epoch 140 …
# Train Accuracy: 91.89%
# Train Average Loss: 0.9066
# Test Accuracy: 92.27%
# Test Average Loss: 0.8921
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.53e-04
# New best model saved with test accuracy: 92.27%
# Epoch [141] 📊 acc: 0.920 | Targets: 0.8946 | Entropy: -1.8804
# New ref model saved
# Epoch [142] 📊 acc: 0.919 | Targets: 0.8943 | Entropy: -1.8808
# Epoch [143] 📊 acc: 0.920 | Targets: 0.8939 | Entropy: -1.8805
# Epoch [144] 📊 acc: 0.922 | Targets: 0.8920 | Entropy: -1.8804
# New ref model saved
# Epoch [145] 📊 acc: 0.921 | Targets: 0.8929 | Entropy: -1.8804
# Epoch [146] 📊 acc: 0.921 | Targets: 0.8924 | Entropy: -1.8802
# Epoch [147] 📊 acc: 0.923 | Targets: 0.8892 | Entropy: -1.8793
# New ref model saved
# Epoch [148] 📊 acc: 0.924 | Targets: 0.8862 | Entropy: -1.8783
# New ref model saved
# Epoch [149] 📊 acc: 0.922 | Targets: 0.8904 | Entropy: -1.8799
# Epoch [150] 📊 acc: 0.921 | Targets: 0.8924 | Entropy: -1.8803
#
# Evaluating at epoch 150 …
# Train Accuracy: 92.61%
# Train Average Loss: 0.8847
# Test Accuracy: 92.51%
# Test Average Loss: 0.8797
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.01e-04
# New best model saved with test accuracy: 92.51%
# Epoch [151] 📊 acc: 0.923 | Targets: 0.8897 | Entropy: -1.8795
# Epoch [152] 📊 acc: 0.925 | Targets: 0.8852 | Entropy: -1.8786
# New ref model saved
# Epoch [153] 📊 acc: 0.926 | Targets: 0.8841 | Entropy: -1.8779
# New ref model saved
# Epoch [154] 📊 acc: 0.925 | Targets: 0.8858 | Entropy: -1.8786
# Epoch [155] 📊 acc: 0.926 | Targets: 0.8850 | Entropy: -1.8785
# Epoch [156] 📊 acc: 0.924 | Targets: 0.8845 | Entropy: -1.8784
# Epoch [157] 📊 acc: 0.926 | Targets: 0.8843 | Entropy: -1.8785
# Epoch [158] 📊 acc: 0.925 | Targets: 0.8837 | Entropy: -1.8779
# Epoch [159] 📊 acc: 0.928 | Targets: 0.8796 | Entropy: -1.8773
# New ref model saved
# Epoch [160] 📊 acc: 0.928 | Targets: 0.8798 | Entropy: -1.8773
# New ref model saved
#
# Evaluating at epoch 160 …
# Train Accuracy: 92.99%
# Train Average Loss: 0.8748
# Test Accuracy: 92.74%
# Test Average Loss: 0.8746
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.48e-04
# New best model saved with test accuracy: 92.74%
# Epoch [161] 📊 acc: 0.929 | Targets: 0.8793 | Entropy: -1.8774
# New ref model saved
# Epoch [162] 📊 acc: 0.928 | Targets: 0.8804 | Entropy: -1.8775
# Epoch [163] 📊 acc: 0.929 | Targets: 0.8771 | Entropy: -1.8766
# New ref model saved
# Epoch [164] 📊 acc: 0.928 | Targets: 0.8784 | Entropy: -1.8768
# Epoch [165] 📊 acc: 0.929 | Targets: 0.8763 | Entropy: -1.8764
# New ref model saved
# Epoch [166] 📊 acc: 0.931 | Targets: 0.8738 | Entropy: -1.8757
# New ref model saved
# Epoch [167] 📊 acc: 0.932 | Targets: 0.8729 | Entropy: -1.8762
# New ref model saved
# Epoch [168] 📊 acc: 0.932 | Targets: 0.8736 | Entropy: -1.8751
# Epoch [169] 📊 acc: 0.933 | Targets: 0.8714 | Entropy: -1.8751
# New ref model saved
# Epoch [170] 📊 acc: 0.932 | Targets: 0.8732 | Entropy: -1.8759
#
# Evaluating at epoch 170 …
# Train Accuracy: 93.43%
# Train Average Loss: 0.8665
# Test Accuracy: 92.75%
# Test Average Loss: 0.8739
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.97e-04
# New best model saved with test accuracy: 92.75%
# Epoch [171] 📊 acc: 0.932 | Targets: 0.8725 | Entropy: -1.8753
# Epoch [172] 📊 acc: 0.933 | Targets: 0.8712 | Entropy: -1.8753
# Epoch [173] 📊 acc: 0.932 | Targets: 0.8719 | Entropy: -1.8755
# Epoch [174] 📊 acc: 0.932 | Targets: 0.8729 | Entropy: -1.8756
# Epoch [175] 📊 acc: 0.933 | Targets: 0.8714 | Entropy: -1.8754
# New ref model saved
# Epoch [176] 📊 acc: 0.933 | Targets: 0.8716 | Entropy: -1.8756
# Epoch [177] 📊 acc: 0.935 | Targets: 0.8676 | Entropy: -1.8746
# New ref model saved
# Epoch [178] 📊 acc: 0.934 | Targets: 0.8697 | Entropy: -1.8748
# Epoch [179] 📊 acc: 0.935 | Targets: 0.8684 | Entropy: -1.8748
# New ref model saved
# Epoch [180] 📊 acc: 0.934 | Targets: 0.8674 | Entropy: -1.8741
#
# Evaluating at epoch 180 …
# Train Accuracy: 93.66%
# Train Average Loss: 0.8611
# Test Accuracy: 93.12%
# Test Average Loss: 0.8663
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.46e-04
# New best model saved with test accuracy: 93.12%
# Epoch [181] 📊 acc: 0.936 | Targets: 0.8657 | Entropy: -1.8741
# New ref model saved
# Epoch [182] 📊 acc: 0.937 | Targets: 0.8639 | Entropy: -1.8733
# New ref model saved
# Epoch [183] 📊 acc: 0.936 | Targets: 0.8645 | Entropy: -1.8734
# Epoch [184] 📊 acc: 0.938 | Targets: 0.8619 | Entropy: -1.8729
# New ref model saved
# Epoch [185] 📊 acc: 0.935 | Targets: 0.8661 | Entropy: -1.8741
# Epoch [186] 📊 acc: 0.936 | Targets: 0.8626 | Entropy: -1.8731
# Epoch [187] 📊 acc: 0.938 | Targets: 0.8611 | Entropy: -1.8732
# New ref model saved
# Epoch [188] 📊 acc: 0.939 | Targets: 0.8601 | Entropy: -1.8728
# New ref model saved
# Epoch [189] 📊 acc: 0.938 | Targets: 0.8607 | Entropy: -1.8725
# Epoch [190] 📊 acc: 0.938 | Targets: 0.8615 | Entropy: -1.8732
#
# Evaluating at epoch 190 …
# Train Accuracy: 93.73%
# Train Average Loss: 0.8579
# Test Accuracy: 93.21%
# Test Average Loss: 0.8639
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.97e-04
# New best model saved with test accuracy: 93.21%
# Epoch [191] 📊 acc: 0.940 | Targets: 0.8577 | Entropy: -1.8722
# New ref model saved
# Epoch [192] 📊 acc: 0.939 | Targets: 0.8599 | Entropy: -1.8726
# Epoch [193] 📊 acc: 0.940 | Targets: 0.8568 | Entropy: -1.8714
# Epoch [194] 📊 acc: 0.940 | Targets: 0.8590 | Entropy: -1.8726
# Epoch [195] 📊 acc: 0.940 | Targets: 0.8566 | Entropy: -1.8717
# New ref model saved
# Epoch [196] 📊 acc: 0.940 | Targets: 0.8564 | Entropy: -1.8714
# Epoch [197] 📊 acc: 0.940 | Targets: 0.8576 | Entropy: -1.8720
# Epoch [198] 📊 acc: 0.940 | Targets: 0.8574 | Entropy: -1.8720
# Epoch [199] 📊 acc: 0.942 | Targets: 0.8529 | Entropy: -1.8711
# New ref model saved
# Epoch [200] 📊 acc: 0.941 | Targets: 0.8547 | Entropy: -1.8712
#
# Evaluating at epoch 200 …
# Train Accuracy: 94.49%
# Train Average Loss: 0.8507
# Test Accuracy: 93.45%
# Test Average Loss: 0.8629
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.51e-04
# New best model saved with test accuracy: 93.45%
# Epoch [201] 📊 acc: 0.943 | Targets: 0.8529 | Entropy: -1.8709
# New ref model saved
# Epoch [202] 📊 acc: 0.941 | Targets: 0.8542 | Entropy: -1.8713
# Epoch [203] 📊 acc: 0.942 | Targets: 0.8516 | Entropy: -1.8703
# Epoch [204] 📊 acc: 0.943 | Targets: 0.8505 | Entropy: -1.8702
# Epoch [205] 📊 acc: 0.943 | Targets: 0.8501 | Entropy: -1.8703
# New ref model saved
# Epoch [206] 📊 acc: 0.944 | Targets: 0.8504 | Entropy: -1.8703
# New ref model saved
# Epoch [207] 📊 acc: 0.944 | Targets: 0.8504 | Entropy: -1.8702
# Epoch [208] 📊 acc: 0.943 | Targets: 0.8513 | Entropy: -1.8708
# Epoch [209] 📊 acc: 0.946 | Targets: 0.8475 | Entropy: -1.8696
# New ref model saved
# Epoch [210] 📊 acc: 0.944 | Targets: 0.8483 | Entropy: -1.8696
#
# Evaluating at epoch 210 …
# Train Accuracy: 94.65%
# Train Average Loss: 0.8461
# Test Accuracy: 93.59%
# Test Average Loss: 0.8599
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.07e-04
# New best model saved with test accuracy: 93.59%
# Epoch [211] 📊 acc: 0.945 | Targets: 0.8479 | Entropy: -1.8698
# Epoch [212] 📊 acc: 0.944 | Targets: 0.8485 | Entropy: -1.8695
# Epoch [213] 📊 acc: 0.945 | Targets: 0.8477 | Entropy: -1.8694
# Epoch [214] 📊 acc: 0.945 | Targets: 0.8461 | Entropy: -1.8691
# Epoch [215] 📊 acc: 0.946 | Targets: 0.8448 | Entropy: -1.8688
# New ref model saved
# Epoch [216] 📊 acc: 0.946 | Targets: 0.8440 | Entropy: -1.8687
# New ref model saved
# Epoch [217] 📊 acc: 0.947 | Targets: 0.8438 | Entropy: -1.8689
# New ref model saved
# Epoch [218] 📊 acc: 0.946 | Targets: 0.8451 | Entropy: -1.8691
# Epoch [219] 📊 acc: 0.947 | Targets: 0.8436 | Entropy: -1.8685
# New ref model saved
# Epoch [220] 📊 acc: 0.947 | Targets: 0.8435 | Entropy: -1.8685
#
# Evaluating at epoch 220 …
# Train Accuracy: 94.77%
# Train Average Loss: 0.8404
# Test Accuracy: 93.52%
# Test Average Loss: 0.8615
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.66e-04
# Epoch [221] 📊 acc: 0.948 | Targets: 0.8431 | Entropy: -1.8685
# New ref model saved
# Epoch [222] 📊 acc: 0.947 | Targets: 0.8435 | Entropy: -1.8687
# Epoch [223] 📊 acc: 0.948 | Targets: 0.8425 | Entropy: -1.8684
# New ref model saved
# Epoch [224] 📊 acc: 0.949 | Targets: 0.8404 | Entropy: -1.8680
# New ref model saved
# Epoch [225] 📊 acc: 0.950 | Targets: 0.8405 | Entropy: -1.8679
# New ref model saved
# Epoch [226] 📊 acc: 0.950 | Targets: 0.8394 | Entropy: -1.8677
# New ref model saved
# Epoch [227] 📊 acc: 0.948 | Targets: 0.8408 | Entropy: -1.8678
# Epoch [228] 📊 acc: 0.950 | Targets: 0.8405 | Entropy: -1.8679
# Epoch [229] 📊 acc: 0.948 | Targets: 0.8397 | Entropy: -1.8676
# Epoch [230] 📊 acc: 0.948 | Targets: 0.8423 | Entropy: -1.8686
#
# Evaluating at epoch 230 …
# Train Accuracy: 95.01%
# Train Average Loss: 0.8386
# Test Accuracy: 93.62%
# Test Average Loss: 0.8561
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.29e-04
# New best model saved with test accuracy: 93.62%
# Epoch [231] 📊 acc: 0.950 | Targets: 0.8362 | Entropy: -1.8666
# New ref model saved
# Epoch [232] 📊 acc: 0.949 | Targets: 0.8388 | Entropy: -1.8673
# Epoch [233] 📊 acc: 0.949 | Targets: 0.8400 | Entropy: -1.8683
# Epoch [234] 📊 acc: 0.952 | Targets: 0.8369 | Entropy: -1.8672
# New ref model saved
# Epoch [235] 📊 acc: 0.949 | Targets: 0.8385 | Entropy: -1.8675
# Epoch [236] 📊 acc: 0.950 | Targets: 0.8374 | Entropy: -1.8671
# Epoch [237] 📊 acc: 0.951 | Targets: 0.8359 | Entropy: -1.8670
# Epoch [238] 📊 acc: 0.951 | Targets: 0.8367 | Entropy: -1.8671
# Epoch [239] 📊 acc: 0.952 | Targets: 0.8349 | Entropy: -1.8663
# New ref model saved
# Epoch [240] 📊 acc: 0.952 | Targets: 0.8348 | Entropy: -1.8666
# New ref model saved
#
# Evaluating at epoch 240 …
# Train Accuracy: 95.25%
# Train Average Loss: 0.8343
# Test Accuracy: 93.82%
# Test Average Loss: 0.8562
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.64e-05
# New best model saved with test accuracy: 93.82%
# Epoch [241] 📊 acc: 0.952 | Targets: 0.8345 | Entropy: -1.8663
# Epoch [242] 📊 acc: 0.953 | Targets: 0.8331 | Entropy: -1.8661
# New ref model saved
# Epoch [243] 📊 acc: 0.951 | Targets: 0.8346 | Entropy: -1.8663
# Epoch [244] 📊 acc: 0.953 | Targets: 0.8329 | Entropy: -1.8659
# Epoch [245] 📊 acc: 0.951 | Targets: 0.8358 | Entropy: -1.8669
# Epoch [246] 📊 acc: 0.952 | Targets: 0.8339 | Entropy: -1.8666
# Epoch [247] 📊 acc: 0.952 | Targets: 0.8346 | Entropy: -1.8667
# Epoch [248] 📊 acc: 0.954 | Targets: 0.8321 | Entropy: -1.8660
# New ref model saved
# Epoch [249] 📊 acc: 0.953 | Targets: 0.8322 | Entropy: -1.8660
# Epoch [250] 📊 acc: 0.951 | Targets: 0.8382 | Entropy: -1.8678
#
# Evaluating at epoch 250 …
# Train Accuracy: 95.48%
# Train Average Loss: 0.8316
# Test Accuracy: 93.94%
# Test Average Loss: 0.8563
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.79e-05
# New best model saved with test accuracy: 93.94%
# Epoch [251] 📊 acc: 0.952 | Targets: 0.8317 | Entropy: -1.8653
# Epoch [252] 📊 acc: 0.954 | Targets: 0.8313 | Entropy: -1.8656
# Epoch [253] 📊 acc: 0.952 | Targets: 0.8333 | Entropy: -1.8664
# Epoch [254] 📊 acc: 0.954 | Targets: 0.8313 | Entropy: -1.8650
# Epoch [255] 📊 acc: 0.954 | Targets: 0.8302 | Entropy: -1.8653
# Epoch [256] 📊 acc: 0.954 | Targets: 0.8297 | Entropy: -1.8652
# New ref model saved
# Epoch [257] 📊 acc: 0.954 | Targets: 0.8320 | Entropy: -1.8659
# Epoch [258] 📊 acc: 0.953 | Targets: 0.8336 | Entropy: -1.8668
# Epoch [259] 📊 acc: 0.956 | Targets: 0.8275 | Entropy: -1.8647
# New ref model saved
# Epoch [260] 📊 acc: 0.954 | Targets: 0.8314 | Entropy: -1.8656
#
# Evaluating at epoch 260 …
# Train Accuracy: 95.44%
# Train Average Loss: 0.8311
# Test Accuracy: 94.04%
# Test Average Loss: 0.8555
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.42e-05
# New best model saved with test accuracy: 94.04%
# Epoch [261] 📊 acc: 0.955 | Targets: 0.8301 | Entropy: -1.8654
# Epoch [262] 📊 acc: 0.956 | Targets: 0.8287 | Entropy: -1.8651
# Epoch [263] 📊 acc: 0.956 | Targets: 0.8275 | Entropy: -1.8645
# Epoch [264] 📊 acc: 0.955 | Targets: 0.8288 | Entropy: -1.8651
# Epoch [265] 📊 acc: 0.955 | Targets: 0.8282 | Entropy: -1.8651
# Epoch [266] 📊 acc: 0.955 | Targets: 0.8298 | Entropy: -1.8653
# Epoch [267] 📊 acc: 0.955 | Targets: 0.8281 | Entropy: -1.8647
# Epoch [268] 📊 acc: 0.954 | Targets: 0.8300 | Entropy: -1.8654
# Epoch [269] 📊 acc: 0.955 | Targets: 0.8302 | Entropy: -1.8658
# Epoch [270] 📊 acc: 0.956 | Targets: 0.8286 | Entropy: -1.8648
#
# Evaluating at epoch 270 …
# Train Accuracy: 95.61%
# Train Average Loss: 0.8276
# Test Accuracy: 94.07%
# Test Average Loss: 0.8533
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-05
# New best model saved with test accuracy: 94.07%
# Epoch [271] 📊 acc: 0.955 | Targets: 0.8294 | Entropy: -1.8652
# Epoch [272] 📊 acc: 0.956 | Targets: 0.8262 | Entropy: -1.8647
# New ref model saved
# Epoch [273] 📊 acc: 0.954 | Targets: 0.8302 | Entropy: -1.8655
# Epoch [274] 📊 acc: 0.956 | Targets: 0.8268 | Entropy: -1.8645
# Epoch [275] 📊 acc: 0.955 | Targets: 0.8280 | Entropy: -1.8650
# Epoch [276] 📊 acc: 0.955 | Targets: 0.8283 | Entropy: -1.8653
# Epoch [277] 📊 acc: 0.956 | Targets: 0.8265 | Entropy: -1.8644
# Epoch [278] 📊 acc: 0.955 | Targets: 0.8281 | Entropy: -1.8648
# Epoch [279] 📊 acc: 0.955 | Targets: 0.8281 | Entropy: -1.8651
# Epoch [280] 📊 acc: 0.956 | Targets: 0.8264 | Entropy: -1.8646
# New ref model saved
#
# Evaluating at epoch 280 …
# Train Accuracy: 95.55%
# Train Average Loss: 0.8291
# Test Accuracy: 94.11%
# Test Average Loss: 0.8534
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.19e-05
# New best model saved with test accuracy: 94.11%
# Epoch [281] 📊 acc: 0.955 | Targets: 0.8290 | Entropy: -1.8650
# Epoch [282] 📊 acc: 0.954 | Targets: 0.8281 | Entropy: -1.8648
# Epoch [283] 📊 acc: 0.956 | Targets: 0.8275 | Entropy: -1.8653
# Epoch [284] 📊 acc: 0.955 | Targets: 0.8267 | Entropy: -1.8645
# Epoch [285] 📊 acc: 0.956 | Targets: 0.8253 | Entropy: -1.8643
# Epoch [286] 📊 acc: 0.955 | Targets: 0.8275 | Entropy: -1.8644
# Epoch [287] 📊 acc: 0.956 | Targets: 0.8277 | Entropy: -1.8652
# Epoch [288] 📊 acc: 0.956 | Targets: 0.8258 | Entropy: -1.8645
# Epoch [289] 📊 acc: 0.958 | Targets: 0.8239 | Entropy: -1.8634
# New ref model saved
# Epoch [290] 📊 acc: 0.957 | Targets: 0.8255 | Entropy: -1.8641
#
# Evaluating at epoch 290 …
# Train Accuracy: 95.65%
# Train Average Loss: 0.8252
# Test Accuracy: 94.02%
# Test Average Loss: 0.8539
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.74e-06
# Epoch [291] 📊 acc: 0.956 | Targets: 0.8252 | Entropy: -1.8642
# Epoch [292] 📊 acc: 0.957 | Targets: 0.8262 | Entropy: -1.8643
# Epoch [293] 📊 acc: 0.957 | Targets: 0.8253 | Entropy: -1.8638
# Epoch [294] 📊 acc: 0.957 | Targets: 0.8257 | Entropy: -1.8643
# Epoch [295] 📊 acc: 0.956 | Targets: 0.8263 | Entropy: -1.8646
# Epoch [296] 📊 acc: 0.957 | Targets: 0.8267 | Entropy: -1.8645
# Epoch [297] 📊 acc: 0.956 | Targets: 0.8267 | Entropy: -1.8643
# Epoch [298] 📊 acc: 0.957 | Targets: 0.8248 | Entropy: -1.8643
# Epoch [299] 📊 acc: 0.957 | Targets: 0.8251 | Entropy: -1.8643
# Epoch [300] 📊 acc: 0.956 | Targets: 0.8265 | Entropy: -1.8648
#
# Evaluating at epoch 300 …
# Train Accuracy: 95.41%
# Train Average Loss: 0.8301
# Test Accuracy: 94.11%
# Test Average Loss: 0.8533
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-06
# Finished Training
# Best test accuracy achieved: 94.11%
# Total Trainable Parameters: 515,754
