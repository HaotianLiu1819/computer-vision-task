# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth):
        out = self.conv[depth // (self.max_depth // self.num_module)](x, depth)
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        if depth < self.max_depth - 1:
            x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            x = checkpoint(self.step_forward, x, x_prev, d, use_reentrant=False)

        return x

# %%
class RecursionAmplifyConv(nn.Module):
    def __init__(self, channels, height, width):
        super(RecursionAmplifyConv, self).__init__()
        
        self.conv0 = nn.Conv2d(3, channels, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(channels, max_depth=32, num_module=1)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))


    def forward(self, x):
        
        x = self.conv0(x)

        x = self.amconv(x)

        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.reamconv= RecursionAmplifyConv(512, 32, 32)

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.reamconv(x)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        return x

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 1)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        pre_entropy = torch.sum(pre_probs * torch.log(pre_probs), dim=1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_pre_entropy = torch.sum(old_pre_probs * torch.log(old_pre_probs), dim=1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        ref_entropy = torch.sum(ref_probs * torch.log(ref_probs), dim=1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_ref_entropy = torch.sum(old_ref_probs * torch.log(old_ref_probs), dim=1)

        rewards, correct = self.compute_reconstruct_reward(outputs, targets)
        p_rewards, _ = self.compute_positive_reward(outputs, targets)
        n_rewards, _ = self.compute_negative_reward(outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        entropy_delta = (entropy - old_entropy)
        pre_entropy_delta = (pre_entropy - old_pre_entropy)
        ref_entropy_delta = (ref_entropy - old_ref_entropy)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
                'entropy': entropy.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 400,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)

    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    rl_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    ref_count = 16
    d = 0
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=400, eta_min=1e-6
            )
        
        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
            'rewards_mean': 0.0, 'rewards_std': 0.0, 
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs = net(inputs)
                ref_outputs = ref_net(inputs)
                pre_outputs = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_ratio = F.sigmoid(select_delta) - F.sigmoid(ref_select_delta)
                select_loss = select_ratio.sum()
                
                entropy_ratio = F.sigmoid(entropy_delta) - F.sigmoid(ref_entropy_delta)
                entropy_loss = entropy_ratio.sum()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f}")

        if running_cor > rl_accuracy:
            rl_accuracy = running_cor
            ref = copy.deepcopy(net).to(device)
            if d % 2 == 0:
                prev_ref.append(ref)
                prev_ref = prev_ref[-ref_count:]
            ref_net = prev_ref[((d % ref_count + 1) - ((d % ref_count + 1) & -(d % ref_count + 1))) // 2]
            d += 1
            print(f"New ref model saved")
            
        pre_net = copy.deepcopy(net).to(device)
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
                    if use_bf16 else contextlib.nullcontext())

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = net(images)  
            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum    += batch_loss.item() * bs
            total_seen  += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 515,754

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.322 | Targets: 1.9702 | Entropy: -2.1619
# New ref model saved
# Epoch [2] 📊 acc: 0.481 | Targets: 1.6887 | Entropy: -2.0808
# New ref model saved
# Epoch [3] 📊 acc: 0.557 | Targets: 1.5632 | Entropy: -2.0424
# New ref model saved
# Epoch [4] 📊 acc: 0.608 | Targets: 1.4794 | Entropy: -2.0182
# New ref model saved
# Epoch [5] 📊 acc: 0.642 | Targets: 1.4183 | Entropy: -2.0007
# New ref model saved
# Epoch [6] 📊 acc: 0.670 | Targets: 1.3719 | Entropy: -1.9882
# New ref model saved
# Epoch [7] 📊 acc: 0.691 | Targets: 1.3303 | Entropy: -1.9772
# New ref model saved
# Epoch [8] 📊 acc: 0.708 | Targets: 1.2995 | Entropy: -1.9684
# New ref model saved
# Epoch [9] 📊 acc: 0.721 | Targets: 1.2753 | Entropy: -1.9639
# New ref model saved
# Epoch [10] 📊 acc: 0.733 | Targets: 1.2555 | Entropy: -1.9577
# New ref model saved
#
# Evaluating at epoch 10 …
# Train Accuracy: 72.44%
# Train Average Loss: 1.2676
# Test Accuracy: 76.71%
# Test Average Loss: 1.1991
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.98e-04
# New best model saved with test accuracy: 76.71%
# Epoch [11] 📊 acc: 0.743 | Targets: 1.2350 | Entropy: -1.9535
# New ref model saved
# Epoch [12] 📊 acc: 0.751 | Targets: 1.2202 | Entropy: -1.9496
# New ref model saved
# Epoch [13] 📊 acc: 0.760 | Targets: 1.2045 | Entropy: -1.9459
# New ref model saved
# Epoch [14] 📊 acc: 0.767 | Targets: 1.1909 | Entropy: -1.9425
# New ref model saved
# Epoch [15] 📊 acc: 0.771 | Targets: 1.1832 | Entropy: -1.9406
# New ref model saved
# Epoch [16] 📊 acc: 0.776 | Targets: 1.1740 | Entropy: -1.9397
# New ref model saved
# Epoch [17] 📊 acc: 0.782 | Targets: 1.1578 | Entropy: -1.9350
# New ref model saved
# Epoch [18] 📊 acc: 0.787 | Targets: 1.1502 | Entropy: -1.9345
# New ref model saved
# Epoch [19] 📊 acc: 0.792 | Targets: 1.1401 | Entropy: -1.9316
# New ref model saved
# Epoch [20] 📊 acc: 0.797 | Targets: 1.1346 | Entropy: -1.9312
# New ref model saved
#
# Evaluating at epoch 20 …
# Train Accuracy: 79.90%
# Train Average Loss: 1.1059
# Test Accuracy: 83.38%
# Test Average Loss: 1.0511
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.94e-04
# New best model saved with test accuracy: 83.38%
# Epoch [21] 📊 acc: 0.799 | Targets: 1.1247 | Entropy: -1.9282
# New ref model saved
# Epoch [22] 📊 acc: 0.802 | Targets: 1.1187 | Entropy: -1.9276
# New ref model saved
# Epoch [23] 📊 acc: 0.805 | Targets: 1.1138 | Entropy: -1.9267
# New ref model saved
# Epoch [24] 📊 acc: 0.809 | Targets: 1.1061 | Entropy: -1.9247
# New ref model saved
# Epoch [25] 📊 acc: 0.811 | Targets: 1.1006 | Entropy: -1.9236
# New ref model saved
# Epoch [26] 📊 acc: 0.813 | Targets: 1.0947 | Entropy: -1.9225
# New ref model saved
# Epoch [27] 📊 acc: 0.819 | Targets: 1.0891 | Entropy: -1.9219
# New ref model saved
# Epoch [28] 📊 acc: 0.818 | Targets: 1.0862 | Entropy: -1.9213
# Epoch [29] 📊 acc: 0.822 | Targets: 1.0804 | Entropy: -1.9199
# New ref model saved
# Epoch [30] 📊 acc: 0.822 | Targets: 1.0758 | Entropy: -1.9186
# New ref model saved
#
# Evaluating at epoch 30 …
# Train Accuracy: 84.05%
# Train Average Loss: 1.0574
# Test Accuracy: 87.89%
# Test Average Loss: 0.9847
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.86e-04
# New best model saved with test accuracy: 87.89%
# Epoch [31] 📊 acc: 0.825 | Targets: 1.0721 | Entropy: -1.9178
# New ref model saved
# Epoch [32] 📊 acc: 0.827 | Targets: 1.0685 | Entropy: -1.9171
# New ref model saved
# Epoch [33] 📊 acc: 0.831 | Targets: 1.0617 | Entropy: -1.9165
# New ref model saved
# Epoch [34] 📊 acc: 0.832 | Targets: 1.0589 | Entropy: -1.9157
# New ref model saved
# Epoch [35] 📊 acc: 0.836 | Targets: 1.0539 | Entropy: -1.9144
# New ref model saved
# Epoch [36] 📊 acc: 0.841 | Targets: 1.0477 | Entropy: -1.9132
# New ref model saved
# Epoch [37] 📊 acc: 0.839 | Targets: 1.0470 | Entropy: -1.9133
# Epoch [38] 📊 acc: 0.844 | Targets: 1.0417 | Entropy: -1.9118
# New ref model saved
# Epoch [39] 📊 acc: 0.841 | Targets: 1.0422 | Entropy: -1.9118
# Epoch [40] 📊 acc: 0.842 | Targets: 1.0390 | Entropy: -1.9122
#
# Evaluating at epoch 40 …
# Train Accuracy: 84.44%
# Train Average Loss: 1.0164
# Test Accuracy: 88.03%
# Test Average Loss: 0.9492
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 88.03%
# Epoch [41] 📊 acc: 0.846 | Targets: 1.0320 | Entropy: -1.9098
# New ref model saved
# Epoch [42] 📊 acc: 0.847 | Targets: 1.0301 | Entropy: -1.9094
# New ref model saved
# Epoch [43] 📊 acc: 0.848 | Targets: 1.0310 | Entropy: -1.9098
# New ref model saved
# Epoch [44] 📊 acc: 0.849 | Targets: 1.0277 | Entropy: -1.9086
# New ref model saved
# Epoch [45] 📊 acc: 0.851 | Targets: 1.0250 | Entropy: -1.9087
# New ref model saved
# Epoch [46] 📊 acc: 0.851 | Targets: 1.0217 | Entropy: -1.9079
# New ref model saved
# Epoch [47] 📊 acc: 0.853 | Targets: 1.0201 | Entropy: -1.9081
# New ref model saved
# Epoch [48] 📊 acc: 0.854 | Targets: 1.0174 | Entropy: -1.9075
# New ref model saved
# Epoch [49] 📊 acc: 0.854 | Targets: 1.0161 | Entropy: -1.9068
# New ref model saved
# Epoch [50] 📊 acc: 0.856 | Targets: 1.0139 | Entropy: -1.9069
# New ref model saved
#
# Evaluating at epoch 50 …
# Train Accuracy: 85.87%
# Train Average Loss: 1.0114
# Test Accuracy: 88.38%
# Test Average Loss: 0.9551
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.62e-04
# New best model saved with test accuracy: 88.38%
# Epoch [51] 📊 acc: 0.860 | Targets: 1.0089 | Entropy: -1.9052
# New ref model saved
# Epoch [52] 📊 acc: 0.862 | Targets: 1.0051 | Entropy: -1.9048
# New ref model saved
# Epoch [53] 📊 acc: 0.860 | Targets: 1.0055 | Entropy: -1.9051
# Epoch [54] 📊 acc: 0.864 | Targets: 1.0012 | Entropy: -1.9040
# New ref model saved
# Epoch [55] 📊 acc: 0.864 | Targets: 0.9995 | Entropy: -1.9034
# New ref model saved
# Epoch [56] 📊 acc: 0.865 | Targets: 0.9990 | Entropy: -1.9031
# New ref model saved
# Epoch [57] 📊 acc: 0.863 | Targets: 1.0016 | Entropy: -1.9043
# Epoch [58] 📊 acc: 0.864 | Targets: 0.9972 | Entropy: -1.9035
# Epoch [59] 📊 acc: 0.866 | Targets: 0.9923 | Entropy: -1.9019
# New ref model saved
# Epoch [60] 📊 acc: 0.870 | Targets: 0.9883 | Entropy: -1.9011
# New ref model saved
#
# Evaluating at epoch 60 …
# Train Accuracy: 87.60%
# Train Average Loss: 0.9895
# Test Accuracy: 90.21%
# Test Average Loss: 0.9339
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.46e-04
# New best model saved with test accuracy: 90.21%
# Epoch [61] 📊 acc: 0.869 | Targets: 0.9893 | Entropy: -1.9018
# Epoch [62] 📊 acc: 0.869 | Targets: 0.9884 | Entropy: -1.9012
# Epoch [63] 📊 acc: 0.873 | Targets: 0.9837 | Entropy: -1.9003
# New ref model saved
# Epoch [64] 📊 acc: 0.873 | Targets: 0.9840 | Entropy: -1.9002
# Epoch [65] 📊 acc: 0.875 | Targets: 0.9787 | Entropy: -1.8988
# New ref model saved
# Epoch [66] 📊 acc: 0.875 | Targets: 0.9795 | Entropy: -1.8994
# Epoch [67] 📊 acc: 0.874 | Targets: 0.9802 | Entropy: -1.8999
# Epoch [68] 📊 acc: 0.877 | Targets: 0.9741 | Entropy: -1.8981
# New ref model saved
# Epoch [69] 📊 acc: 0.879 | Targets: 0.9731 | Entropy: -1.8982
# New ref model saved
# Epoch [70] 📊 acc: 0.878 | Targets: 0.9751 | Entropy: -1.8987
#
# Evaluating at epoch 70 …
# Train Accuracy: 88.27%
# Train Average Loss: 0.9729
# Test Accuracy: 90.35%
# Test Average Loss: 0.9371
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.26e-04
# New best model saved with test accuracy: 90.35%
# Epoch [71] 📊 acc: 0.878 | Targets: 0.9750 | Entropy: -1.8989
# Epoch [72] 📊 acc: 0.879 | Targets: 0.9697 | Entropy: -1.8972
# New ref model saved
# Epoch [73] 📊 acc: 0.880 | Targets: 0.9682 | Entropy: -1.8976
# New ref model saved
# Epoch [74] 📊 acc: 0.881 | Targets: 0.9683 | Entropy: -1.8973
# New ref model saved
# Epoch [75] 📊 acc: 0.882 | Targets: 0.9655 | Entropy: -1.8964
# New ref model saved
# Epoch [76] 📊 acc: 0.883 | Targets: 0.9641 | Entropy: -1.8965
# New ref model saved
# Epoch [77] 📊 acc: 0.885 | Targets: 0.9604 | Entropy: -1.8952
# New ref model saved
# Epoch [78] 📊 acc: 0.885 | Targets: 0.9634 | Entropy: -1.8965
# Epoch [79] 📊 acc: 0.884 | Targets: 0.9606 | Entropy: -1.8954
# Epoch [80] 📊 acc: 0.887 | Targets: 0.9568 | Entropy: -1.8949
# New ref model saved
#
# Evaluating at epoch 80 …
# Train Accuracy: 88.26%
# Train Average Loss: 0.9632
# Test Accuracy: 90.39%
# Test Average Loss: 0.9277
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 90.39%
# Epoch [81] 📊 acc: 0.887 | Targets: 0.9572 | Entropy: -1.8949
# Epoch [82] 📊 acc: 0.885 | Targets: 0.9593 | Entropy: -1.8956
# Epoch [83] 📊 acc: 0.884 | Targets: 0.9583 | Entropy: -1.8952
# Epoch [84] 📊 acc: 0.889 | Targets: 0.9543 | Entropy: -1.8943
# New ref model saved
# Epoch [85] 📊 acc: 0.889 | Targets: 0.9532 | Entropy: -1.8936
# New ref model saved
# Epoch [86] 📊 acc: 0.892 | Targets: 0.9489 | Entropy: -1.8930
# New ref model saved
# Epoch [87] 📊 acc: 0.891 | Targets: 0.9496 | Entropy: -1.8933
# Epoch [88] 📊 acc: 0.892 | Targets: 0.9476 | Entropy: -1.8926
# New ref model saved
# Epoch [89] 📊 acc: 0.891 | Targets: 0.9479 | Entropy: -1.8927
# Epoch [90] 📊 acc: 0.893 | Targets: 0.9453 | Entropy: -1.8923
# New ref model saved
#
# Evaluating at epoch 90 …
# Train Accuracy: 89.50%
# Train Average Loss: 0.9258
# Test Accuracy: 91.11%
# Test Average Loss: 0.9032
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.80e-04
# New best model saved with test accuracy: 91.11%
# Epoch [91] 📊 acc: 0.893 | Targets: 0.9478 | Entropy: -1.8932
# Epoch [92] 📊 acc: 0.892 | Targets: 0.9444 | Entropy: -1.8915
# Epoch [93] 📊 acc: 0.892 | Targets: 0.9469 | Entropy: -1.8932
# Epoch [94] 📊 acc: 0.894 | Targets: 0.9430 | Entropy: -1.8920
# New ref model saved
# Epoch [95] 📊 acc: 0.894 | Targets: 0.9435 | Entropy: -1.8922
# Epoch [96] 📊 acc: 0.894 | Targets: 0.9424 | Entropy: -1.8916
# Epoch [97] 📊 acc: 0.897 | Targets: 0.9404 | Entropy: -1.8914
# New ref model saved
# Epoch [98] 📊 acc: 0.898 | Targets: 0.9393 | Entropy: -1.8914
# New ref model saved
# Epoch [99] 📊 acc: 0.898 | Targets: 0.9378 | Entropy: -1.8908
# New ref model saved
# Epoch [100] 📊 acc: 0.898 | Targets: 0.9366 | Entropy: -1.8905
#
# Evaluating at epoch 100 …
# Train Accuracy: 90.01%
# Train Average Loss: 0.9362
# Test Accuracy: 91.46%
# Test Average Loss: 0.9142
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.54e-04
# New best model saved with test accuracy: 91.46%
# Epoch [101] 📊 acc: 0.898 | Targets: 0.9375 | Entropy: -1.8910
# New ref model saved
# Epoch [102] 📊 acc: 0.901 | Targets: 0.9317 | Entropy: -1.8891
# New ref model saved
# Epoch [103] 📊 acc: 0.899 | Targets: 0.9327 | Entropy: -1.8894
# Epoch [104] 📊 acc: 0.902 | Targets: 0.9319 | Entropy: -1.8892
# New ref model saved
# Epoch [105] 📊 acc: 0.902 | Targets: 0.9325 | Entropy: -1.8894
# New ref model saved
# Epoch [106] 📊 acc: 0.899 | Targets: 0.9338 | Entropy: -1.8901
# Epoch [107] 📊 acc: 0.904 | Targets: 0.9267 | Entropy: -1.8881
# New ref model saved
# Epoch [108] 📊 acc: 0.904 | Targets: 0.9270 | Entropy: -1.8882
# New ref model saved
# Epoch [109] 📊 acc: 0.902 | Targets: 0.9277 | Entropy: -1.8881
# Epoch [110] 📊 acc: 0.901 | Targets: 0.9288 | Entropy: -1.8891
#
# Evaluating at epoch 110 …
# Train Accuracy: 90.85%
# Train Average Loss: 0.9189
# Test Accuracy: 91.74%
# Test Average Loss: 0.8994
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.25e-04
# New best model saved with test accuracy: 91.74%
# Epoch [111] 📊 acc: 0.903 | Targets: 0.9245 | Entropy: -1.8875
# Epoch [112] 📊 acc: 0.903 | Targets: 0.9276 | Entropy: -1.8887
# Epoch [113] 📊 acc: 0.906 | Targets: 0.9246 | Entropy: -1.8882
# New ref model saved
# Epoch [114] 📊 acc: 0.905 | Targets: 0.9233 | Entropy: -1.8875
# Epoch [115] 📊 acc: 0.907 | Targets: 0.9189 | Entropy: -1.8864
# New ref model saved
# Epoch [116] 📊 acc: 0.906 | Targets: 0.9208 | Entropy: -1.8866
# Epoch [117] 📊 acc: 0.908 | Targets: 0.9193 | Entropy: -1.8864
# New ref model saved
# Epoch [118] 📊 acc: 0.907 | Targets: 0.9189 | Entropy: -1.8865
# Epoch [119] 📊 acc: 0.908 | Targets: 0.9168 | Entropy: -1.8855
# New ref model saved
# Epoch [120] 📊 acc: 0.908 | Targets: 0.9170 | Entropy: -1.8857
#
# Evaluating at epoch 120 …
# Train Accuracy: 91.09%
# Train Average Loss: 0.9123
# Test Accuracy: 91.68%
# Test Average Loss: 0.8946
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.94e-04
# Epoch [121] 📊 acc: 0.908 | Targets: 0.9153 | Entropy: -1.8853
# Epoch [122] 📊 acc: 0.909 | Targets: 0.9152 | Entropy: -1.8852
# New ref model saved
# Epoch [123] 📊 acc: 0.911 | Targets: 0.9133 | Entropy: -1.8850
# New ref model saved
# Epoch [124] 📊 acc: 0.910 | Targets: 0.9131 | Entropy: -1.8852
# Epoch [125] 📊 acc: 0.909 | Targets: 0.9130 | Entropy: -1.8849
# Epoch [126] 📊 acc: 0.910 | Targets: 0.9135 | Entropy: -1.8856
# Epoch [127] 📊 acc: 0.913 | Targets: 0.9121 | Entropy: -1.8852
# New ref model saved
# Epoch [128] 📊 acc: 0.910 | Targets: 0.9106 | Entropy: -1.8839
# Epoch [129] 📊 acc: 0.912 | Targets: 0.9109 | Entropy: -1.8847
# Epoch [130] 📊 acc: 0.913 | Targets: 0.9084 | Entropy: -1.8842
#
# Evaluating at epoch 130 …
# Train Accuracy: 91.54%
# Train Average Loss: 0.9013
# Test Accuracy: 92.02%
# Test Average Loss: 0.8944
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.61e-04
# New best model saved with test accuracy: 92.02%
# Epoch [131] 📊 acc: 0.913 | Targets: 0.9080 | Entropy: -1.8838
# New ref model saved
# Epoch [132] 📊 acc: 0.912 | Targets: 0.9084 | Entropy: -1.8841
# Epoch [133] 📊 acc: 0.914 | Targets: 0.9060 | Entropy: -1.8834
# New ref model saved
# Epoch [134] 📊 acc: 0.914 | Targets: 0.9065 | Entropy: -1.8835
# Epoch [135] 📊 acc: 0.915 | Targets: 0.9041 | Entropy: -1.8826
# New ref model saved
# Epoch [136] 📊 acc: 0.916 | Targets: 0.9025 | Entropy: -1.8824
# New ref model saved
# Epoch [137] 📊 acc: 0.914 | Targets: 0.9046 | Entropy: -1.8830
# Epoch [138] 📊 acc: 0.917 | Targets: 0.9032 | Entropy: -1.8824
# New ref model saved
# Epoch [139] 📊 acc: 0.915 | Targets: 0.9051 | Entropy: -1.8831
# Epoch [140] 📊 acc: 0.916 | Targets: 0.9023 | Entropy: -1.8826
#
# Evaluating at epoch 140 …
# Train Accuracy: 91.25%
# Train Average Loss: 0.9180
# Test Accuracy: 92.23%
# Test Average Loss: 0.9039
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.27e-04
# New best model saved with test accuracy: 92.23%
# Epoch [141] 📊 acc: 0.918 | Targets: 0.8993 | Entropy: -1.8817
# New ref model saved
# Epoch [142] 📊 acc: 0.916 | Targets: 0.9023 | Entropy: -1.8828
# Epoch [143] 📊 acc: 0.917 | Targets: 0.9000 | Entropy: -1.8822
# Epoch [144] 📊 acc: 0.916 | Targets: 0.9006 | Entropy: -1.8820
# Epoch [145] 📊 acc: 0.917 | Targets: 0.9006 | Entropy: -1.8820
# Epoch [146] 📊 acc: 0.918 | Targets: 0.8991 | Entropy: -1.8819
# New ref model saved
# Epoch [147] 📊 acc: 0.918 | Targets: 0.8982 | Entropy: -1.8813
# Epoch [148] 📊 acc: 0.919 | Targets: 0.8980 | Entropy: -1.8815
# New ref model saved
# Epoch [149] 📊 acc: 0.920 | Targets: 0.8961 | Entropy: -1.8813
# New ref model saved
# Epoch [150] 📊 acc: 0.918 | Targets: 0.8971 | Entropy: -1.8812
#
# Evaluating at epoch 150 …
# Train Accuracy: 92.39%
# Train Average Loss: 0.8825
# Test Accuracy: 92.59%
# Test Average Loss: 0.8795
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.92e-04
# New best model saved with test accuracy: 92.59%
# Epoch [151] 📊 acc: 0.920 | Targets: 0.8961 | Entropy: -1.8813
# New ref model saved
# Epoch [152] 📊 acc: 0.921 | Targets: 0.8926 | Entropy: -1.8803
# New ref model saved
# Epoch [153] 📊 acc: 0.919 | Targets: 0.8959 | Entropy: -1.8813
# Epoch [154] 📊 acc: 0.922 | Targets: 0.8935 | Entropy: -1.8809
# New ref model saved
# Epoch [155] 📊 acc: 0.922 | Targets: 0.8903 | Entropy: -1.8793
# Epoch [156] 📊 acc: 0.921 | Targets: 0.8917 | Entropy: -1.8800
# Epoch [157] 📊 acc: 0.922 | Targets: 0.8905 | Entropy: -1.8798
# Epoch [158] 📊 acc: 0.924 | Targets: 0.8910 | Entropy: -1.8803
# New ref model saved
# Epoch [159] 📊 acc: 0.923 | Targets: 0.8898 | Entropy: -1.8799
# Epoch [160] 📊 acc: 0.922 | Targets: 0.8908 | Entropy: -1.8799
#
# Evaluating at epoch 160 …
# Train Accuracy: 92.54%
# Train Average Loss: 0.8883
# Test Accuracy: 92.87%
# Test Average Loss: 0.8816
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.55e-04
# New best model saved with test accuracy: 92.87%
# Epoch [161] 📊 acc: 0.924 | Targets: 0.8896 | Entropy: -1.8800
# New ref model saved
# Epoch [162] 📊 acc: 0.923 | Targets: 0.8876 | Entropy: -1.8792
# Epoch [163] 📊 acc: 0.923 | Targets: 0.8878 | Entropy: -1.8793
# Epoch [164] 📊 acc: 0.923 | Targets: 0.8890 | Entropy: -1.8794
# Epoch [165] 📊 acc: 0.925 | Targets: 0.8834 | Entropy: -1.8780
# New ref model saved
# Epoch [166] 📊 acc: 0.924 | Targets: 0.8878 | Entropy: -1.8795
# Epoch [167] 📊 acc: 0.927 | Targets: 0.8840 | Entropy: -1.8783
# New ref model saved
# Epoch [168] 📊 acc: 0.926 | Targets: 0.8826 | Entropy: -1.8780
# Epoch [169] 📊 acc: 0.925 | Targets: 0.8832 | Entropy: -1.8778
# Epoch [170] 📊 acc: 0.926 | Targets: 0.8846 | Entropy: -1.8785
#
# Evaluating at epoch 170 …
# Train Accuracy: 93.01%
# Train Average Loss: 0.8762
# Test Accuracy: 92.47%
# Test Average Loss: 0.8799
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.17e-04
# Epoch [171] 📊 acc: 0.928 | Targets: 0.8790 | Entropy: -1.8768
# New ref model saved
# Epoch [172] 📊 acc: 0.928 | Targets: 0.8797 | Entropy: -1.8768
# Epoch [173] 📊 acc: 0.927 | Targets: 0.8808 | Entropy: -1.8777
# Epoch [174] 📊 acc: 0.929 | Targets: 0.8774 | Entropy: -1.8762
# New ref model saved
# Epoch [175] 📊 acc: 0.927 | Targets: 0.8813 | Entropy: -1.8778
# Epoch [176] 📊 acc: 0.927 | Targets: 0.8814 | Entropy: -1.8777
# Epoch [177] 📊 acc: 0.928 | Targets: 0.8794 | Entropy: -1.8774
# Epoch [178] 📊 acc: 0.931 | Targets: 0.8762 | Entropy: -1.8761
# New ref model saved
# Epoch [179] 📊 acc: 0.929 | Targets: 0.8772 | Entropy: -1.8761
# Epoch [180] 📊 acc: 0.930 | Targets: 0.8766 | Entropy: -1.8763
#
# Evaluating at epoch 180 …
# Train Accuracy: 93.13%
# Train Average Loss: 0.8886
# Test Accuracy: 92.77%
# Test Average Loss: 0.8892
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.79e-04
# Epoch [181] 📊 acc: 0.929 | Targets: 0.8774 | Entropy: -1.8767
# Epoch [182] 📊 acc: 0.930 | Targets: 0.8760 | Entropy: -1.8765
# Epoch [183] 📊 acc: 0.930 | Targets: 0.8742 | Entropy: -1.8758
# Epoch [184] 📊 acc: 0.931 | Targets: 0.8743 | Entropy: -1.8758
# New ref model saved
# Epoch [185] 📊 acc: 0.932 | Targets: 0.8721 | Entropy: -1.8752
# New ref model saved
# Epoch [186] 📊 acc: 0.934 | Targets: 0.8704 | Entropy: -1.8750
# New ref model saved
# Epoch [187] 📊 acc: 0.933 | Targets: 0.8715 | Entropy: -1.8753
# Epoch [188] 📊 acc: 0.932 | Targets: 0.8713 | Entropy: -1.8749
# Epoch [189] 📊 acc: 0.933 | Targets: 0.8702 | Entropy: -1.8747
# Epoch [190] 📊 acc: 0.933 | Targets: 0.8703 | Entropy: -1.8749
#
# Evaluating at epoch 190 …
# Train Accuracy: 93.61%
# Train Average Loss: 0.8615
# Test Accuracy: 93.28%
# Test Average Loss: 0.8620
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.40e-04
# New best model saved with test accuracy: 93.28%
# Epoch [191] 📊 acc: 0.933 | Targets: 0.8705 | Entropy: -1.8748
# Epoch [192] 📊 acc: 0.934 | Targets: 0.8678 | Entropy: -1.8743
# New ref model saved
# Epoch [193] 📊 acc: 0.934 | Targets: 0.8689 | Entropy: -1.8746
# New ref model saved
# Epoch [194] 📊 acc: 0.933 | Targets: 0.8709 | Entropy: -1.8750
# Epoch [195] 📊 acc: 0.934 | Targets: 0.8677 | Entropy: -1.8741
# Epoch [196] 📊 acc: 0.934 | Targets: 0.8677 | Entropy: -1.8743
# Epoch [197] 📊 acc: 0.935 | Targets: 0.8662 | Entropy: -1.8743
# New ref model saved
# Epoch [198] 📊 acc: 0.936 | Targets: 0.8661 | Entropy: -1.8735
# New ref model saved
# Epoch [199] 📊 acc: 0.936 | Targets: 0.8650 | Entropy: -1.8736
# New ref model saved
# Epoch [200] 📊 acc: 0.936 | Targets: 0.8644 | Entropy: -1.8736
# New ref model saved
#
# Evaluating at epoch 200 …
# Train Accuracy: 93.70%
# Train Average Loss: 0.8631
# Test Accuracy: 93.03%
# Test Average Loss: 0.8697
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.01e-04
# Epoch [201] 📊 acc: 0.937 | Targets: 0.8621 | Entropy: -1.8729
# New ref model saved
# Epoch [202] 📊 acc: 0.935 | Targets: 0.8646 | Entropy: -1.8736
# Epoch [203] 📊 acc: 0.937 | Targets: 0.8633 | Entropy: -1.8733
# Epoch [204] 📊 acc: 0.937 | Targets: 0.8638 | Entropy: -1.8737
# Epoch [205] 📊 acc: 0.935 | Targets: 0.8629 | Entropy: -1.8726
# Epoch [206] 📊 acc: 0.938 | Targets: 0.8600 | Entropy: -1.8726
# New ref model saved
# Epoch [207] 📊 acc: 0.937 | Targets: 0.8619 | Entropy: -1.8729
# Epoch [208] 📊 acc: 0.938 | Targets: 0.8607 | Entropy: -1.8727
# Epoch [209] 📊 acc: 0.938 | Targets: 0.8608 | Entropy: -1.8729
# Epoch [210] 📊 acc: 0.938 | Targets: 0.8606 | Entropy: -1.8725
#
# Evaluating at epoch 210 …
# Train Accuracy: 93.76%
# Train Average Loss: 0.8662
# Test Accuracy: 93.25%
# Test Average Loss: 0.8713
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.61e-04
# Epoch [211] 📊 acc: 0.938 | Targets: 0.8605 | Entropy: -1.8723
# Epoch [212] 📊 acc: 0.939 | Targets: 0.8587 | Entropy: -1.8721
# New ref model saved
# Epoch [213] 📊 acc: 0.937 | Targets: 0.8629 | Entropy: -1.8732
# Epoch [214] 📊 acc: 0.939 | Targets: 0.8581 | Entropy: -1.8722
# New ref model saved
# Epoch [215] 📊 acc: 0.938 | Targets: 0.8600 | Entropy: -1.8723
# Epoch [216] 📊 acc: 0.940 | Targets: 0.8567 | Entropy: -1.8718
# New ref model saved
# Epoch [217] 📊 acc: 0.941 | Targets: 0.8562 | Entropy: -1.8717
# New ref model saved
# Epoch [218] 📊 acc: 0.940 | Targets: 0.8566 | Entropy: -1.8715
# Epoch [219] 📊 acc: 0.941 | Targets: 0.8554 | Entropy: -1.8713
# Epoch [220] 📊 acc: 0.941 | Targets: 0.8541 | Entropy: -1.8708
#
# Evaluating at epoch 220 …
# Train Accuracy: 94.27%
# Train Average Loss: 0.8453
# Test Accuracy: 93.36%
# Test Average Loss: 0.8585
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.22e-04
# New best model saved with test accuracy: 93.36%
# Epoch [221] 📊 acc: 0.941 | Targets: 0.8555 | Entropy: -1.8717
# Epoch [222] 📊 acc: 0.942 | Targets: 0.8532 | Entropy: -1.8710
# New ref model saved
# Epoch [223] 📊 acc: 0.943 | Targets: 0.8507 | Entropy: -1.8702
# New ref model saved
# Epoch [224] 📊 acc: 0.944 | Targets: 0.8506 | Entropy: -1.8699
# New ref model saved
# Epoch [225] 📊 acc: 0.942 | Targets: 0.8542 | Entropy: -1.8714
# Epoch [226] 📊 acc: 0.943 | Targets: 0.8538 | Entropy: -1.8715
# Epoch [227] 📊 acc: 0.941 | Targets: 0.8547 | Entropy: -1.8714
# Epoch [228] 📊 acc: 0.943 | Targets: 0.8530 | Entropy: -1.8714
# Epoch [229] 📊 acc: 0.944 | Targets: 0.8497 | Entropy: -1.8701
# Epoch [230] 📊 acc: 0.943 | Targets: 0.8495 | Entropy: -1.8700
#
# Evaluating at epoch 230 …
# Train Accuracy: 94.54%
# Train Average Loss: 0.8460
# Test Accuracy: 93.33%
# Test Average Loss: 0.8629
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.84e-04
# Epoch [231] 📊 acc: 0.944 | Targets: 0.8487 | Entropy: -1.8697
# New ref model saved
# Epoch [232] 📊 acc: 0.944 | Targets: 0.8505 | Entropy: -1.8701
# Epoch [233] 📊 acc: 0.943 | Targets: 0.8500 | Entropy: -1.8703
# Epoch [234] 📊 acc: 0.944 | Targets: 0.8507 | Entropy: -1.8706
# Epoch [235] 📊 acc: 0.945 | Targets: 0.8482 | Entropy: -1.8697
# New ref model saved
# Epoch [236] 📊 acc: 0.944 | Targets: 0.8493 | Entropy: -1.8699
# Epoch [237] 📊 acc: 0.945 | Targets: 0.8468 | Entropy: -1.8691
# New ref model saved
# Epoch [238] 📊 acc: 0.944 | Targets: 0.8470 | Entropy: -1.8691
# Epoch [239] 📊 acc: 0.948 | Targets: 0.8439 | Entropy: -1.8686
# New ref model saved
# Epoch [240] 📊 acc: 0.946 | Targets: 0.8455 | Entropy: -1.8692
#
# Evaluating at epoch 240 …
# Train Accuracy: 94.73%
# Train Average Loss: 0.8451
# Test Accuracy: 93.49%
# Test Average Loss: 0.8590
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.46e-04
# New best model saved with test accuracy: 93.49%
# Epoch [241] 📊 acc: 0.944 | Targets: 0.8484 | Entropy: -1.8699
# Epoch [242] 📊 acc: 0.947 | Targets: 0.8441 | Entropy: -1.8687
# Epoch [243] 📊 acc: 0.946 | Targets: 0.8450 | Entropy: -1.8688
# Epoch [244] 📊 acc: 0.946 | Targets: 0.8457 | Entropy: -1.8691
# Epoch [245] 📊 acc: 0.947 | Targets: 0.8427 | Entropy: -1.8682
# Epoch [246] 📊 acc: 0.948 | Targets: 0.8437 | Entropy: -1.8685
# New ref model saved
# Epoch [247] 📊 acc: 0.947 | Targets: 0.8435 | Entropy: -1.8685
# Epoch [248] 📊 acc: 0.947 | Targets: 0.8426 | Entropy: -1.8682
# Epoch [249] 📊 acc: 0.945 | Targets: 0.8465 | Entropy: -1.8698
# Epoch [250] 📊 acc: 0.949 | Targets: 0.8391 | Entropy: -1.8673
# New ref model saved
#
# Evaluating at epoch 250 …
# Train Accuracy: 95.04%
# Train Average Loss: 0.8352
# Test Accuracy: 93.55%
# Test Average Loss: 0.8581
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.09e-04
# New best model saved with test accuracy: 93.55%
# Epoch [251] 📊 acc: 0.946 | Targets: 0.8434 | Entropy: -1.8685
# Epoch [252] 📊 acc: 0.949 | Targets: 0.8392 | Entropy: -1.8677
# New ref model saved
# Epoch [253] 📊 acc: 0.948 | Targets: 0.8436 | Entropy: -1.8690
# Epoch [254] 📊 acc: 0.948 | Targets: 0.8411 | Entropy: -1.8681
# Epoch [255] 📊 acc: 0.948 | Targets: 0.8416 | Entropy: -1.8684
# Epoch [256] 📊 acc: 0.948 | Targets: 0.8398 | Entropy: -1.8675
# Epoch [257] 📊 acc: 0.949 | Targets: 0.8392 | Entropy: -1.8678
# Epoch [258] 📊 acc: 0.947 | Targets: 0.8424 | Entropy: -1.8685
# Epoch [259] 📊 acc: 0.948 | Targets: 0.8414 | Entropy: -1.8682
# Epoch [260] 📊 acc: 0.950 | Targets: 0.8375 | Entropy: -1.8673
# New ref model saved
#
# Evaluating at epoch 260 …
# Train Accuracy: 95.05%
# Train Average Loss: 0.8352
# Test Accuracy: 93.58%
# Test Average Loss: 0.8542
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.74e-04
# New best model saved with test accuracy: 93.58%
# Epoch [261] 📊 acc: 0.949 | Targets: 0.8386 | Entropy: -1.8675
# Epoch [262] 📊 acc: 0.949 | Targets: 0.8405 | Entropy: -1.8679
# Epoch [263] 📊 acc: 0.952 | Targets: 0.8346 | Entropy: -1.8665
# New ref model saved
# Epoch [264] 📊 acc: 0.951 | Targets: 0.8363 | Entropy: -1.8672
# Epoch [265] 📊 acc: 0.951 | Targets: 0.8348 | Entropy: -1.8661
# Epoch [266] 📊 acc: 0.950 | Targets: 0.8373 | Entropy: -1.8674
# Epoch [267] 📊 acc: 0.950 | Targets: 0.8372 | Entropy: -1.8672
# Epoch [268] 📊 acc: 0.952 | Targets: 0.8343 | Entropy: -1.8661
# New ref model saved
# Epoch [269] 📊 acc: 0.952 | Targets: 0.8350 | Entropy: -1.8666
# Epoch [270] 📊 acc: 0.950 | Targets: 0.8385 | Entropy: -1.8674
#
# Evaluating at epoch 270 …
# Train Accuracy: 95.22%
# Train Average Loss: 0.8344
# Test Accuracy: 93.80%
# Test Average Loss: 0.8571
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.40e-04
# New best model saved with test accuracy: 93.80%
# Epoch [271] 📊 acc: 0.952 | Targets: 0.8347 | Entropy: -1.8664
# Epoch [272] 📊 acc: 0.951 | Targets: 0.8351 | Entropy: -1.8663
# Epoch [273] 📊 acc: 0.952 | Targets: 0.8344 | Entropy: -1.8667
# New ref model saved
# Epoch [274] 📊 acc: 0.953 | Targets: 0.8323 | Entropy: -1.8655
# New ref model saved
# Epoch [275] 📊 acc: 0.952 | Targets: 0.8344 | Entropy: -1.8664
# Epoch [276] 📊 acc: 0.952 | Targets: 0.8330 | Entropy: -1.8659
# Epoch [277] 📊 acc: 0.954 | Targets: 0.8299 | Entropy: -1.8651
# New ref model saved
# Epoch [278] 📊 acc: 0.953 | Targets: 0.8308 | Entropy: -1.8653
# Epoch [279] 📊 acc: 0.954 | Targets: 0.8309 | Entropy: -1.8655
# Epoch [280] 📊 acc: 0.952 | Targets: 0.8335 | Entropy: -1.8660
#
# Evaluating at epoch 280 …
# Train Accuracy: 95.49%
# Train Average Loss: 0.8315
# Test Accuracy: 93.78%
# Test Average Loss: 0.8581
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.07e-04
# Epoch [281] 📊 acc: 0.954 | Targets: 0.8304 | Entropy: -1.8651
# Epoch [282] 📊 acc: 0.953 | Targets: 0.8328 | Entropy: -1.8661
# Epoch [283] 📊 acc: 0.955 | Targets: 0.8293 | Entropy: -1.8652
# New ref model saved
# Epoch [284] 📊 acc: 0.954 | Targets: 0.8305 | Entropy: -1.8655
# Epoch [285] 📊 acc: 0.954 | Targets: 0.8305 | Entropy: -1.8655
# Epoch [286] 📊 acc: 0.954 | Targets: 0.8297 | Entropy: -1.8651
# Epoch [287] 📊 acc: 0.954 | Targets: 0.8315 | Entropy: -1.8661
# Epoch [288] 📊 acc: 0.954 | Targets: 0.8303 | Entropy: -1.8653
# Epoch [289] 📊 acc: 0.955 | Targets: 0.8280 | Entropy: -1.8646
# Epoch [290] 📊 acc: 0.956 | Targets: 0.8271 | Entropy: -1.8645
# New ref model saved
#
# Evaluating at epoch 290 …
# Train Accuracy: 95.41%
# Train Average Loss: 0.8290
# Test Accuracy: 93.61%
# Test Average Loss: 0.8584
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.76e-04
# Epoch [291] 📊 acc: 0.954 | Targets: 0.8303 | Entropy: -1.8653
# Epoch [292] 📊 acc: 0.956 | Targets: 0.8266 | Entropy: -1.8641
# New ref model saved
# Epoch [293] 📊 acc: 0.956 | Targets: 0.8275 | Entropy: -1.8642
# Epoch [294] 📊 acc: 0.957 | Targets: 0.8243 | Entropy: -1.8638
# New ref model saved
# Epoch [295] 📊 acc: 0.956 | Targets: 0.8261 | Entropy: -1.8641
# Epoch [296] 📊 acc: 0.956 | Targets: 0.8272 | Entropy: -1.8647
# Epoch [297] 📊 acc: 0.956 | Targets: 0.8268 | Entropy: -1.8644
# Epoch [298] 📊 acc: 0.957 | Targets: 0.8269 | Entropy: -1.8646
# Epoch [299] 📊 acc: 0.956 | Targets: 0.8273 | Entropy: -1.8647
# Epoch [300] 📊 acc: 0.956 | Targets: 0.8255 | Entropy: -1.8639
#
# Evaluating at epoch 300 …
# Train Accuracy: 95.73%
# Train Average Loss: 0.8222
# Test Accuracy: 94.01%
# Test Average Loss: 0.8530
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.47e-04
# New best model saved with test accuracy: 94.01%
# Epoch [301] 📊 acc: 0.958 | Targets: 0.8228 | Entropy: -1.8633
# New ref model saved
# Epoch [302] 📊 acc: 0.957 | Targets: 0.8228 | Entropy: -1.8634
# Epoch [303] 📊 acc: 0.957 | Targets: 0.8239 | Entropy: -1.8636
# Epoch [304] 📊 acc: 0.957 | Targets: 0.8234 | Entropy: -1.8636
# Epoch [305] 📊 acc: 0.957 | Targets: 0.8230 | Entropy: -1.8635
# Epoch [306] 📊 acc: 0.958 | Targets: 0.8235 | Entropy: -1.8636
# New ref model saved
# Epoch [307] 📊 acc: 0.957 | Targets: 0.8236 | Entropy: -1.8635
# Epoch [308] 📊 acc: 0.957 | Targets: 0.8229 | Entropy: -1.8633
# Epoch [309] 📊 acc: 0.956 | Targets: 0.8260 | Entropy: -1.8648
# Epoch [310] 📊 acc: 0.956 | Targets: 0.8252 | Entropy: -1.8642
#
# Evaluating at epoch 310 …
# Train Accuracy: 95.69%
# Train Average Loss: 0.8235
# Test Accuracy: 93.74%
# Test Average Loss: 0.8539
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.21e-04
# Epoch [311] 📊 acc: 0.957 | Targets: 0.8265 | Entropy: -1.8649
# Epoch [312] 📊 acc: 0.958 | Targets: 0.8218 | Entropy: -1.8632
# Epoch [313] 📊 acc: 0.958 | Targets: 0.8227 | Entropy: -1.8632
# Epoch [314] 📊 acc: 0.959 | Targets: 0.8207 | Entropy: -1.8632
# New ref model saved
# Epoch [315] 📊 acc: 0.959 | Targets: 0.8191 | Entropy: -1.8623
# New ref model saved
# Epoch [316] 📊 acc: 0.959 | Targets: 0.8204 | Entropy: -1.8630
# Epoch [317] 📊 acc: 0.958 | Targets: 0.8232 | Entropy: -1.8636
# Epoch [318] 📊 acc: 0.959 | Targets: 0.8201 | Entropy: -1.8629
# Epoch [319] 📊 acc: 0.960 | Targets: 0.8200 | Entropy: -1.8629
# New ref model saved
# Epoch [320] 📊 acc: 0.960 | Targets: 0.8199 | Entropy: -1.8630
#
# Evaluating at epoch 320 …
# Train Accuracy: 95.94%
# Train Average Loss: 0.8235
# Test Accuracy: 94.02%
# Test Average Loss: 0.8556
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.64e-05
# New best model saved with test accuracy: 94.02%
# Epoch [321] 📊 acc: 0.959 | Targets: 0.8198 | Entropy: -1.8629
# Epoch [322] 📊 acc: 0.960 | Targets: 0.8202 | Entropy: -1.8627
# Epoch [323] 📊 acc: 0.958 | Targets: 0.8206 | Entropy: -1.8629
# Epoch [324] 📊 acc: 0.959 | Targets: 0.8221 | Entropy: -1.8637
# Epoch [325] 📊 acc: 0.961 | Targets: 0.8173 | Entropy: -1.8620
# New ref model saved
# Epoch [326] 📊 acc: 0.960 | Targets: 0.8179 | Entropy: -1.8622
# Epoch [327] 📊 acc: 0.959 | Targets: 0.8188 | Entropy: -1.8626
# Epoch [328] 📊 acc: 0.961 | Targets: 0.8167 | Entropy: -1.8619
# New ref model saved
# Epoch [329] 📊 acc: 0.961 | Targets: 0.8183 | Entropy: -1.8625
# Epoch [330] 📊 acc: 0.960 | Targets: 0.8190 | Entropy: -1.8628
#
# Evaluating at epoch 330 …
# Train Accuracy: 96.12%
# Train Average Loss: 0.8161
# Test Accuracy: 93.91%
# Test Average Loss: 0.8541
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.46e-05
# Epoch [331] 📊 acc: 0.961 | Targets: 0.8172 | Entropy: -1.8622
# Epoch [332] 📊 acc: 0.959 | Targets: 0.8202 | Entropy: -1.8630
# Epoch [333] 📊 acc: 0.960 | Targets: 0.8199 | Entropy: -1.8626
# Epoch [334] 📊 acc: 0.960 | Targets: 0.8182 | Entropy: -1.8624
# Epoch [335] 📊 acc: 0.960 | Targets: 0.8170 | Entropy: -1.8620
# Epoch [336] 📊 acc: 0.960 | Targets: 0.8175 | Entropy: -1.8622
# Epoch [337] 📊 acc: 0.959 | Targets: 0.8216 | Entropy: -1.8632
# Epoch [338] 📊 acc: 0.961 | Targets: 0.8178 | Entropy: -1.8625
# Epoch [339] 📊 acc: 0.959 | Targets: 0.8185 | Entropy: -1.8623
# Epoch [340] 📊 acc: 0.960 | Targets: 0.8180 | Entropy: -1.8622
#
# Evaluating at epoch 340 …
# Train Accuracy: 95.98%
# Train Average Loss: 0.8163
# Test Accuracy: 93.94%
# Test Average Loss: 0.8529
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.54e-05
# Epoch [341] 📊 acc: 0.961 | Targets: 0.8182 | Entropy: -1.8627
# Epoch [342] 📊 acc: 0.962 | Targets: 0.8150 | Entropy: -1.8615
# New ref model saved
# Epoch [343] 📊 acc: 0.961 | Targets: 0.8178 | Entropy: -1.8624
# Epoch [344] 📊 acc: 0.962 | Targets: 0.8155 | Entropy: -1.8618
# New ref model saved
# Epoch [345] 📊 acc: 0.961 | Targets: 0.8164 | Entropy: -1.8617
# Epoch [346] 📊 acc: 0.961 | Targets: 0.8161 | Entropy: -1.8617
# Epoch [347] 📊 acc: 0.962 | Targets: 0.8154 | Entropy: -1.8615
# Epoch [348] 📊 acc: 0.963 | Targets: 0.8137 | Entropy: -1.8609
# New ref model saved
# Epoch [349] 📊 acc: 0.960 | Targets: 0.8179 | Entropy: -1.8622
# Epoch [350] 📊 acc: 0.962 | Targets: 0.8141 | Entropy: -1.8613
#
# Evaluating at epoch 350 …
# Train Accuracy: 96.29%
# Train Average Loss: 0.8136
# Test Accuracy: 94.08%
# Test Average Loss: 0.8524
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.90e-05
# New best model saved with test accuracy: 94.08%
# Epoch [351] 📊 acc: 0.961 | Targets: 0.8157 | Entropy: -1.8615
# Epoch [352] 📊 acc: 0.962 | Targets: 0.8144 | Entropy: -1.8612
# Epoch [353] 📊 acc: 0.962 | Targets: 0.8159 | Entropy: -1.8619
# Epoch [354] 📊 acc: 0.962 | Targets: 0.8154 | Entropy: -1.8616
# Epoch [355] 📊 acc: 0.962 | Targets: 0.8157 | Entropy: -1.8618
# Epoch [356] 📊 acc: 0.962 | Targets: 0.8166 | Entropy: -1.8619
# Epoch [357] 📊 acc: 0.963 | Targets: 0.8155 | Entropy: -1.8620
# Epoch [358] 📊 acc: 0.962 | Targets: 0.8138 | Entropy: -1.8609
# Epoch [359] 📊 acc: 0.963 | Targets: 0.8131 | Entropy: -1.8614
# New ref model saved
# Epoch [360] 📊 acc: 0.963 | Targets: 0.8143 | Entropy: -1.8616
#
# Evaluating at epoch 360 …
# Train Accuracy: 96.26%
# Train Average Loss: 0.8128
# Test Accuracy: 94.13%
# Test Average Loss: 0.8508
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-05
# New best model saved with test accuracy: 94.13%
# Epoch [361] 📊 acc: 0.962 | Targets: 0.8141 | Entropy: -1.8612
# Epoch [362] 📊 acc: 0.962 | Targets: 0.8155 | Entropy: -1.8616
# Epoch [363] 📊 acc: 0.961 | Targets: 0.8149 | Entropy: -1.8612
# Epoch [364] 📊 acc: 0.962 | Targets: 0.8142 | Entropy: -1.8616
# Epoch [365] 📊 acc: 0.963 | Targets: 0.8133 | Entropy: -1.8611
# Epoch [366] 📊 acc: 0.963 | Targets: 0.8132 | Entropy: -1.8610
# Epoch [367] 📊 acc: 0.963 | Targets: 0.8133 | Entropy: -1.8608
# Epoch [368] 📊 acc: 0.963 | Targets: 0.8143 | Entropy: -1.8617
# New ref model saved
# Epoch [369] 📊 acc: 0.962 | Targets: 0.8146 | Entropy: -1.8618
# Epoch [370] 📊 acc: 0.961 | Targets: 0.8154 | Entropy: -1.8611
#
# Evaluating at epoch 370 …
# Train Accuracy: 96.18%
# Train Average Loss: 0.8150
# Test Accuracy: 94.23%
# Test Average Loss: 0.8504
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.48e-05
# New best model saved with test accuracy: 94.23%
# Epoch [371] 📊 acc: 0.961 | Targets: 0.8155 | Entropy: -1.8617
# Epoch [372] 📊 acc: 0.963 | Targets: 0.8130 | Entropy: -1.8612
# Epoch [373] 📊 acc: 0.963 | Targets: 0.8120 | Entropy: -1.8607
# New ref model saved
# Epoch [374] 📊 acc: 0.962 | Targets: 0.8141 | Entropy: -1.8614
# Epoch [375] 📊 acc: 0.964 | Targets: 0.8115 | Entropy: -1.8608
# New ref model saved
# Epoch [376] 📊 acc: 0.963 | Targets: 0.8118 | Entropy: -1.8603
# Epoch [377] 📊 acc: 0.960 | Targets: 0.8169 | Entropy: -1.8619
# Epoch [378] 📊 acc: 0.963 | Targets: 0.8123 | Entropy: -1.8611
# Epoch [379] 📊 acc: 0.962 | Targets: 0.8132 | Entropy: -1.8605
# Epoch [380] 📊 acc: 0.964 | Targets: 0.8117 | Entropy: -1.8604
#
# Evaluating at epoch 380 …
# Train Accuracy: 96.25%
# Train Average Loss: 0.8121
# Test Accuracy: 94.25%
# Test Average Loss: 0.8496
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.15e-06
# New best model saved with test accuracy: 94.25%
# Epoch [381] 📊 acc: 0.963 | Targets: 0.8128 | Entropy: -1.8611
# Epoch [382] 📊 acc: 0.964 | Targets: 0.8108 | Entropy: -1.8606
# Epoch [383] 📊 acc: 0.963 | Targets: 0.8132 | Entropy: -1.8609
# Epoch [384] 📊 acc: 0.964 | Targets: 0.8116 | Entropy: -1.8610
# Epoch [385] 📊 acc: 0.963 | Targets: 0.8116 | Entropy: -1.8606
# Epoch [386] 📊 acc: 0.963 | Targets: 0.8125 | Entropy: -1.8611
# Epoch [387] 📊 acc: 0.963 | Targets: 0.8109 | Entropy: -1.8601
# Epoch [388] 📊 acc: 0.963 | Targets: 0.8122 | Entropy: -1.8607
# Epoch [389] 📊 acc: 0.964 | Targets: 0.8110 | Entropy: -1.8603
# Epoch [390] 📊 acc: 0.962 | Targets: 0.8124 | Entropy: -1.8606
#
# Evaluating at epoch 390 …
# Train Accuracy: 96.32%
# Train Average Loss: 0.8111
# Test Accuracy: 94.19%
# Test Average Loss: 0.8503
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-06
# Epoch [391] 📊 acc: 0.964 | Targets: 0.8110 | Entropy: -1.8603
# Epoch [392] 📊 acc: 0.963 | Targets: 0.8117 | Entropy: -1.8608
# Epoch [393] 📊 acc: 0.963 | Targets: 0.8136 | Entropy: -1.8609
# Epoch [394] 📊 acc: 0.963 | Targets: 0.8114 | Entropy: -1.8605
# Epoch [395] 📊 acc: 0.962 | Targets: 0.8142 | Entropy: -1.8612
# Epoch [396] 📊 acc: 0.963 | Targets: 0.8126 | Entropy: -1.8613
# Epoch [397] 📊 acc: 0.963 | Targets: 0.8128 | Entropy: -1.8608
# Epoch [398] 📊 acc: 0.964 | Targets: 0.8117 | Entropy: -1.8608
# Epoch [399] 📊 acc: 0.964 | Targets: 0.8111 | Entropy: -1.8603
# Epoch [400] 📊 acc: 0.964 | Targets: 0.8112 | Entropy: -1.8608
#
# Evaluating at epoch 400 …
# Train Accuracy: 96.37%
# Train Average Loss: 0.8104
# Test Accuracy: 94.31%
# Test Average Loss: 0.8497
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-06
# New best model saved with test accuracy: 94.31%
# Finished Training
# Best test accuracy achieved: 94.31%
# Total Trainable Parameters: 515,754
# Epoch [176] 📊 acc: 0.774 | Targets: 1.3655 | Entropy: -2.0883
# Epoch [177] 📊 acc: 0.774 | Targets: 1.3323 | Entropy: -2.0678
# Epoch [178] 📊 acc: 0.770 | Targets: 1.5458 | Entropy: -2.1848
# Epoch [179] 📊 acc: 0.775 | Targets: 1.1216 | Entropy: -1.8690
# Epoch [180] 📊 acc: 0.775 | Targets: 1.1022 | Entropy: -1.8514
#
# Evaluating at epoch 180 …
# Train Accuracy: 77.23%
# Train Average Loss: 1.1225
# Test Accuracy: 81.82%
# Test Average Loss: 1.0367
# Total Trainable Parameters: 38,322
#
# Current learning rate: 6.20e-04
# Epoch [181] 📊 acc: 0.775 | Targets: 1.3994 | Entropy: -2.1115
# Epoch [182] 📊 acc: 0.778 | Targets: 1.2781 | Entropy: -2.0291
# New ref model saved
# Epoch [183] 📊 acc: 0.776 | Targets: 0.7942 | Entropy: -1.2579
# Epoch [184] 📊 acc: 0.776 | Targets: 1.2646 | Entropy: -2.0089
# Epoch [185] 📊 acc: 0.775 | Targets: 0.7817 | Entropy: -1.2292
# Epoch [186] 📊 acc: 0.778 | Targets: 1.2205 | Entropy: -1.9701
# Epoch [187] 📊 acc: 0.779 | Targets: 0.8365 | Entropy: -1.4001
# New ref model saved
# Epoch [188] 📊 acc: 0.779 | Targets: 0.9146 | Entropy: -1.5686
# Epoch [189] 📊 acc: 0.777 | Targets: 1.2894 | Entropy: -2.0339
# Epoch [190] 📊 acc: 0.782 | Targets: 1.1018 | Entropy: -1.8540
# New ref model saved
#
# Evaluating at epoch 190 …
# Train Accuracy: 78.48%
# Train Average Loss: 1.0911
# Test Accuracy: 82.38%
# Test Average Loss: 1.0174
# Total Trainable Parameters: 38,322
#
# Current learning rate: 5.85e-04
# Epoch [191] 📊 acc: 0.772 | Targets: 1.6126 | Entropy: -2.2082
# Epoch [192] 📊 acc: 0.782 | Targets: 1.1619 | Entropy: -1.9199
# New ref model saved
# Epoch [193] 📊 acc: 0.777 | Targets: 1.2663 | Entropy: -2.0199
# Epoch [194] 📊 acc: 0.778 | Targets: 1.4278 | Entropy: -2.1298
# Epoch [195] 📊 acc: 0.779 | Targets: 1.0243 | Entropy: -1.7480
# Epoch [196] 📊 acc: 0.782 | Targets: 1.1106 | Entropy: -1.8699
# Epoch [197] 📊 acc: 0.781 | Targets: 1.2077 | Entropy: -1.9692
# Epoch [198] 📊 acc: 0.780 | Targets: 0.7444 | Entropy: -1.1470
# Epoch [199] 📊 acc: 0.785 | Targets: 0.9972 | Entropy: -1.7141
# New ref model saved
# Epoch [200] 📊 acc: 0.767 | Targets: 1.6957 | Entropy: -2.2312
#
# Evaluating at epoch 200 …
# Train Accuracy: 77.36%
# Train Average Loss: 1.7080
# Test Accuracy: 81.20%
# Test Average Loss: 1.6667
# Total Trainable Parameters: 38,322
#
# Current learning rate: 5.50e-04
# Epoch [201] 📊 acc: 0.778 | Targets: 1.4629 | Entropy: -2.1496
# Epoch [202] 📊 acc: 0.780 | Targets: 0.9533 | Entropy: -1.6312
# Epoch [203] 📊 acc: 0.750 | Targets: 1.8868 | Entropy: -2.2657
# Epoch [204] 📊 acc: 0.778 | Targets: 1.1710 | Entropy: -1.9209
# Epoch [205] 📊 acc: 0.782 | Targets: 0.9320 | Entropy: -1.6058
# Epoch [206] 📊 acc: 0.784 | Targets: 1.0105 | Entropy: -1.7378
# Epoch [207] 📊 acc: 0.783 | Targets: 0.7928 | Entropy: -1.3140
# Epoch [208] 📊 acc: 0.783 | Targets: 0.7260 | Entropy: -1.1197
# Epoch [209] 📊 acc: 0.785 | Targets: 0.9708 | Entropy: -1.6768
# New ref model saved
# Epoch [210] 📊 acc: 0.786 | Targets: 0.8802 | Entropy: -1.5239
# New ref model saved
#
# Evaluating at epoch 210 …
# Train Accuracy: 78.52%
# Train Average Loss: 0.8662
# Test Accuracy: 82.65%
# Test Average Loss: 0.7564
# Total Trainable Parameters: 38,322
#
# Current learning rate: 5.15e-04
# Epoch [211] 📊 acc: 0.784 | Targets: 0.6800 | Entropy: -0.9544
# Epoch [212] 📊 acc: 0.788 | Targets: 0.6353 | Entropy: -0.7861
# New ref model saved
# Epoch [213] 📊 acc: 0.786 | Targets: 0.6377 | Entropy: -0.7687
# Epoch [214] 📊 acc: 0.784 | Targets: 1.0792 | Entropy: -1.8094
# Epoch [215] 📊 acc: 0.790 | Targets: 0.9800 | Entropy: -1.7031
# New ref model saved
# Epoch [216] 📊 acc: 0.787 | Targets: 0.8914 | Entropy: -1.5482
# Epoch [217] 📊 acc: 0.788 | Targets: 1.0848 | Entropy: -1.8423
# Epoch [218] 📊 acc: 0.787 | Targets: 1.2454 | Entropy: -2.0086
# Epoch [219] 📊 acc: 0.790 | Targets: 1.0529 | Entropy: -1.8082
# Epoch [220] 📊 acc: 0.790 | Targets: 1.1631 | Entropy: -1.9351
# New ref model saved
#
# Evaluating at epoch 220 …
# Train Accuracy: 79.09%
# Train Average Loss: 1.1712
# Test Accuracy: 83.12%
# Test Average Loss: 1.0964
# Total Trainable Parameters: 38,322
#
# Current learning rate: 4.80e-04
# New best model saved with test accuracy: 83.12%
# Epoch [221] 📊 acc: 0.788 | Targets: 0.8977 | Entropy: -1.5640
# Epoch [222] 📊 acc: 0.782 | Targets: 1.4831 | Entropy: -2.1548
# Epoch [223] 📊 acc: 0.787 | Targets: 1.0460 | Entropy: -1.7918
# Epoch [224] 📊 acc: 0.791 | Targets: 0.9290 | Entropy: -1.6270
# New ref model saved
# Epoch [225] 📊 acc: 0.791 | Targets: 1.1800 | Entropy: -1.9522
# Epoch [226] 📊 acc: 0.788 | Targets: 1.3229 | Entropy: -2.0696
# Epoch [227] 📊 acc: 0.783 | Targets: 1.5506 | Entropy: -2.1908
# Epoch [228] 📊 acc: 0.788 | Targets: 1.2069 | Entropy: -1.9777
# Epoch [229] 📊 acc: 0.790 | Targets: 0.9447 | Entropy: -1.6480
# Epoch [230] 📊 acc: 0.787 | Targets: 1.3742 | Entropy: -2.1011
#
# Evaluating at epoch 230 …
# Train Accuracy: 78.67%
# Train Average Loss: 1.3743
# Test Accuracy: 83.31%
# Test Average Loss: 1.3107
# Total Trainable Parameters: 38,322
#
# Current learning rate: 4.45e-04
# New best model saved with test accuracy: 83.31%
# Epoch [231] 📊 acc: 0.789 | Targets: 1.1776 | Entropy: -1.9517
# Epoch [232] 📊 acc: 0.788 | Targets: 0.8835 | Entropy: -1.5358
# Epoch [233] 📊 acc: 0.781 | Targets: 1.5690 | Entropy: -2.1897
# Epoch [234] 📊 acc: 0.786 | Targets: 1.3095 | Entropy: -2.0602
# Epoch [235] 📊 acc: 0.790 | Targets: 1.0344 | Entropy: -1.7865
# Epoch [236] 📊 acc: 0.784 | Targets: 1.5055 | Entropy: -2.1703
# Epoch [237] 📊 acc: 0.790 | Targets: 1.1297 | Entropy: -1.9014
# Epoch [238] 📊 acc: 0.786 | Targets: 1.5225 | Entropy: -2.1793
# Epoch [239] 📊 acc: 0.787 | Targets: 1.4376 | Entropy: -2.1425
# Epoch [240] 📊 acc: 0.789 | Targets: 1.2393 | Entropy: -2.0086
#
# Evaluating at epoch 240 …
# Train Accuracy: 78.78%
# Train Average Loss: 1.2254
# Test Accuracy: 82.30%
# Test Average Loss: 1.1571
# Total Trainable Parameters: 38,322
#
# Current learning rate: 4.11e-04
# Epoch [241] 📊 acc: 0.786 | Targets: 0.7382 | Entropy: -1.1516
# Epoch [242] 📊 acc: 0.790 | Targets: 0.8190 | Entropy: -1.4090
# Epoch [243] 📊 acc: 0.795 | Targets: 1.0093 | Entropy: -1.7603
# New ref model saved
# Epoch [244] 📊 acc: 0.762 | Targets: 1.8565 | Entropy: -2.2643
# Epoch [245] 📊 acc: 0.786 | Targets: 1.1567 | Entropy: -1.9186
# Epoch [246] 📊 acc: 0.790 | Targets: 0.7898 | Entropy: -1.3372
# Epoch [247] 📊 acc: 0.789 | Targets: 1.2456 | Entropy: -2.0078
# Epoch [248] 📊 acc: 0.793 | Targets: 0.9709 | Entropy: -1.6984
# Epoch [249] 📊 acc: 0.786 | Targets: 1.5750 | Entropy: -2.1962
# Epoch [250] 📊 acc: 0.792 | Targets: 1.3318 | Entropy: -2.0809
#
# Evaluating at epoch 250 …
# Train Accuracy: 78.80%
# Train Average Loss: 1.3255
# Test Accuracy: 83.29%
# Test Average Loss: 1.2561
# Total Trainable Parameters: 38,322
#
# Current learning rate: 3.78e-04
# Epoch [251] 📊 acc: 0.786 | Targets: 1.5307 | Entropy: -2.1846
# Epoch [252] 📊 acc: 0.785 | Targets: 1.6637 | Entropy: -2.2313
# Epoch [253] 📊 acc: 0.791 | Targets: 1.0351 | Entropy: -1.7807
# Epoch [254] 📊 acc: 0.793 | Targets: 0.8498 | Entropy: -1.4845
# Epoch [255] 📊 acc: 0.790 | Targets: 1.0545 | Entropy: -1.8180
# Epoch [256] 📊 acc: 0.794 | Targets: 1.2578 | Entropy: -2.0269
# Epoch [257] 📊 acc: 0.790 | Targets: 0.7725 | Entropy: -1.2910
# Epoch [258] 📊 acc: 0.788 | Targets: 1.3282 | Entropy: -2.0673
# Epoch [259] 📊 acc: 0.796 | Targets: 1.2577 | Entropy: -2.0287
# New ref model saved
# Epoch [260] 📊 acc: 0.795 | Targets: 1.3087 | Entropy: -2.0673
#
# Evaluating at epoch 260 …
# Train Accuracy: 79.53%
# Train Average Loss: 1.3078
# Test Accuracy: 83.34%
# Test Average Loss: 1.2528
# Total Trainable Parameters: 38,322
#
# Current learning rate: 3.46e-04
# New best model saved with test accuracy: 83.34%
# Epoch [261] 📊 acc: 0.791 | Targets: 0.7482 | Entropy: -1.2097
# Epoch [262] 📊 acc: 0.797 | Targets: 0.7813 | Entropy: -1.3479
# New ref model saved
# Epoch [263] 📊 acc: 0.788 | Targets: 1.4959 | Entropy: -2.1582
# Epoch [264] 📊 acc: 0.793 | Targets: 1.1768 | Entropy: -1.9561
# Epoch [265] 📊 acc: 0.790 | Targets: 1.5612 | Entropy: -2.1967
# Epoch [266] 📊 acc: 0.794 | Targets: 1.5771 | Entropy: -2.2052
# Epoch [267] 📊 acc: 0.791 | Targets: 0.9467 | Entropy: -1.6468
# Epoch [268] 📊 acc: 0.791 | Targets: 0.6828 | Entropy: -1.0372
# Epoch [269] 📊 acc: 0.795 | Targets: 1.0767 | Entropy: -1.8425
# Epoch [270] 📊 acc: 0.792 | Targets: 1.4804 | Entropy: -2.1628
#
# Evaluating at epoch 270 …
# Train Accuracy: 79.29%
# Train Average Loss: 1.4738
# Test Accuracy: 83.26%
# Test Average Loss: 1.4223
# Total Trainable Parameters: 38,322
#
# Current learning rate: 3.15e-04
# Epoch [271] 📊 acc: 0.796 | Targets: 0.8388 | Entropy: -1.4508
# Epoch [272] 📊 acc: 0.794 | Targets: 1.1967 | Entropy: -1.9722
# Epoch [273] 📊 acc: 0.796 | Targets: 1.0460 | Entropy: -1.8167
# Epoch [274] 📊 acc: 0.797 | Targets: 1.3053 | Entropy: -2.0665
# New ref model saved
# Epoch [275] 📊 acc: 0.796 | Targets: 0.8205 | Entropy: -1.4223
# Epoch [276] 📊 acc: 0.799 | Targets: 0.9167 | Entropy: -1.6269
# New ref model saved
# Epoch [277] 📊 acc: 0.792 | Targets: 1.4679 | Entropy: -2.1535
# Epoch [278] 📊 acc: 0.797 | Targets: 1.2423 | Entropy: -2.0183
# Epoch [279] 📊 acc: 0.795 | Targets: 0.9829 | Entropy: -1.7286
# Epoch [280] 📊 acc: 0.798 | Targets: 0.7185 | Entropy: -1.1903
#
# Evaluating at epoch 280 …
# Train Accuracy: 80.20%
# Train Average Loss: 0.7011
# Test Accuracy: 84.19%
# Test Average Loss: 0.5901
# Total Trainable Parameters: 38,322
#
# Current learning rate: 2.85e-04
# New best model saved with test accuracy: 84.19%
# Epoch [281] 📊 acc: 0.798 | Targets: 0.7409 | Entropy: -1.2575
# Epoch [282] 📊 acc: 0.799 | Targets: 1.1380 | Entropy: -1.9188
# New ref model saved
# Epoch [283] 📊 acc: 0.799 | Targets: 0.8089 | Entropy: -1.4153
# New ref model saved
# Epoch [284] 📊 acc: 0.799 | Targets: 0.9995 | Entropy: -1.7572
# Epoch [285] 📊 acc: 0.801 | Targets: 1.0234 | Entropy: -1.7930
# New ref model saved
# Epoch [286] 📊 acc: 0.799 | Targets: 1.0408 | Entropy: -1.8162
# Epoch [287] 📊 acc: 0.800 | Targets: 1.2225 | Entropy: -2.0053
# Epoch [288] 📊 acc: 0.797 | Targets: 1.3710 | Entropy: -2.1087
# Epoch [289] 📊 acc: 0.796 | Targets: 1.2952 | Entropy: -2.0592
# Epoch [290] 📊 acc: 0.804 | Targets: 1.1430 | Entropy: -1.9359
# New ref model saved
#
# Evaluating at epoch 290 …
# Train Accuracy: 80.00%
# Train Average Loss: 1.1440
# Test Accuracy: 83.79%
# Test Average Loss: 1.0698
# Total Trainable Parameters: 38,322
#
# Current learning rate: 2.58e-04
# Epoch [291] 📊 acc: 0.768 | Targets: 1.8974 | Entropy: -2.2726
# Epoch [292] 📊 acc: 0.787 | Targets: 1.7615 | Entropy: -2.2560
# Epoch [293] 📊 acc: 0.796 | Targets: 1.1345 | Entropy: -1.9071
# Epoch [294] 📊 acc: 0.797 | Targets: 1.2258 | Entropy: -2.0074
# Epoch [295] 📊 acc: 0.800 | Targets: 1.1797 | Entropy: -1.9676
# Epoch [296] 📊 acc: 0.799 | Targets: 0.8561 | Entropy: -1.5122
# Epoch [297] 📊 acc: 0.794 | Targets: 1.4456 | Entropy: -2.1411
# Epoch [298] 📊 acc: 0.799 | Targets: 1.0295 | Entropy: -1.7970
# Epoch [299] 📊 acc: 0.802 | Targets: 0.9239 | Entropy: -1.6503
# Epoch [300] 📊 acc: 0.801 | Targets: 1.0720 | Entropy: -1.8580
#
# Evaluating at epoch 300 …
# Train Accuracy: 80.59%
# Train Average Loss: 1.0799
# Test Accuracy: 84.24%
# Test Average Loss: 1.0041
# Total Trainable Parameters: 38,322
#
# Current learning rate: 2.32e-04
# New best model saved with test accuracy: 84.24%
# Epoch [301] 📊 acc: 0.798 | Targets: 1.4273 | Entropy: -2.1406
# Epoch [302] 📊 acc: 0.802 | Targets: 1.2229 | Entropy: -2.0078
# Epoch [303] 📊 acc: 0.802 | Targets: 1.2926 | Entropy: -2.0625
# Epoch [304] 📊 acc: 0.802 | Targets: 1.0956 | Entropy: -1.8851
# Epoch [305] 📊 acc: 0.798 | Targets: 1.3817 | Entropy: -2.1168
# Epoch [306] 📊 acc: 0.801 | Targets: 1.0964 | Entropy: -1.8822
# Epoch [307] 📊 acc: 0.802 | Targets: 1.0193 | Entropy: -1.7941
# Epoch [308] 📊 acc: 0.800 | Targets: 1.3777 | Entropy: -2.1130
# Epoch [309] 📊 acc: 0.799 | Targets: 0.7312 | Entropy: -1.1879
# Epoch [310] 📊 acc: 0.801 | Targets: 0.9535 | Entropy: -1.6924
#
# Evaluating at epoch 310 …
# Train Accuracy: 80.46%
# Train Average Loss: 0.9683
# Test Accuracy: 83.74%
# Test Average Loss: 0.8816
# Total Trainable Parameters: 38,322
#
# Current learning rate: 2.08e-04
# Epoch [311] 📊 acc: 0.804 | Targets: 1.0100 | Entropy: -1.7835
# New ref model saved
# Epoch [312] 📊 acc: 0.798 | Targets: 1.4368 | Entropy: -2.1440
# Epoch [313] 📊 acc: 0.805 | Targets: 1.2238 | Entropy: -2.0108
# New ref model saved
# Epoch [314] 📊 acc: 0.800 | Targets: 1.5646 | Entropy: -2.2005
# Epoch [315] 📊 acc: 0.802 | Targets: 1.2899 | Entropy: -2.0589
# Epoch [316] 📊 acc: 0.804 | Targets: 1.1637 | Entropy: -1.9589
# Epoch [317] 📊 acc: 0.800 | Targets: 1.4239 | Entropy: -2.1406
# Epoch [318] 📊 acc: 0.807 | Targets: 0.9226 | Entropy: -1.6438
# New ref model saved
# Epoch [319] 📊 acc: 0.801 | Targets: 1.2165 | Entropy: -2.0012
# Epoch [320] 📊 acc: 0.806 | Targets: 0.8885 | Entropy: -1.5963
#
# Evaluating at epoch 320 …
# Train Accuracy: 80.47%
# Train Average Loss: 0.8637
# Test Accuracy: 84.26%
# Test Average Loss: 0.7780
# Total Trainable Parameters: 38,322
#
# Current learning rate: 1.86e-04
# New best model saved with test accuracy: 84.26%
# Epoch [321] 📊 acc: 0.802 | Targets: 1.1175 | Entropy: -1.9101
# Epoch [322] 📊 acc: 0.806 | Targets: 0.9600 | Entropy: -1.7184
# Epoch [323] 📊 acc: 0.807 | Targets: 1.0255 | Entropy: -1.8084
# New ref model saved
# Epoch [324] 📊 acc: 0.807 | Targets: 0.9020 | Entropy: -1.6235
# New ref model saved
# Epoch [325] 📊 acc: 0.791 | Targets: 1.5918 | Entropy: -2.1997
# Epoch [326] 📊 acc: 0.797 | Targets: 0.7592 | Entropy: -1.2245
# Epoch [327] 📊 acc: 0.804 | Targets: 1.1680 | Entropy: -1.9465
# Epoch [328] 📊 acc: 0.805 | Targets: 1.0055 | Entropy: -1.7809
# Epoch [329] 📊 acc: 0.804 | Targets: 0.9049 | Entropy: -1.6277
# Epoch [330] 📊 acc: 0.806 | Targets: 0.8115 | Entropy: -1.4574
#
# Evaluating at epoch 330 …
# Train Accuracy: 80.54%
# Train Average Loss: 0.8170
# Test Accuracy: 84.12%
# Test Average Loss: 0.7268
# Total Trainable Parameters: 38,322
#
# Current learning rate: 1.66e-04
# Epoch [331] 📊 acc: 0.805 | Targets: 0.9779 | Entropy: -1.7426
# Epoch [332] 📊 acc: 0.806 | Targets: 1.2042 | Entropy: -1.9943
# Epoch [333] 📊 acc: 0.804 | Targets: 0.6392 | Entropy: -0.8898
# Epoch [334] 📊 acc: 0.805 | Targets: 0.8924 | Entropy: -1.5823
# Epoch [335] 📊 acc: 0.803 | Targets: 1.1968 | Entropy: -1.9838
# Epoch [336] 📊 acc: 0.806 | Targets: 0.9767 | Entropy: -1.7415
# Epoch [337] 📊 acc: 0.806 | Targets: 0.7306 | Entropy: -1.2580
# Epoch [338] 📊 acc: 0.750 | Targets: 1.8617 | Entropy: -2.2354
# Epoch [339] 📊 acc: 0.801 | Targets: 0.9045 | Entropy: -1.5475
# Epoch [340] 📊 acc: 0.805 | Targets: 1.1565 | Entropy: -1.9454
#
# Evaluating at epoch 340 …
# Train Accuracy: 80.36%
# Train Average Loss: 1.1683
# Test Accuracy: 83.47%
# Test Average Loss: 1.1039
# Total Trainable Parameters: 38,322
#
# Current learning rate: 1.49e-04
# Epoch [341] 📊 acc: 0.804 | Targets: 0.6673 | Entropy: -1.0280
# Epoch [342] 📊 acc: 0.805 | Targets: 1.1345 | Entropy: -1.9085
# Epoch [343] 📊 acc: 0.808 | Targets: 0.9314 | Entropy: -1.6748
# New ref model saved
# Epoch [344] 📊 acc: 0.802 | Targets: 1.3743 | Entropy: -2.1098
# Epoch [345] 📊 acc: 0.807 | Targets: 1.1411 | Entropy: -1.9366
# Epoch [346] 📊 acc: 0.804 | Targets: 1.3283 | Entropy: -2.0880
# Epoch [347] 📊 acc: 0.809 | Targets: 1.1377 | Entropy: -1.9368
# New ref model saved
# Epoch [348] 📊 acc: 0.809 | Targets: 0.8602 | Entropy: -1.5560
# Epoch [349] 📊 acc: 0.804 | Targets: 0.6269 | Entropy: -0.9017
# Epoch [350] 📊 acc: 0.807 | Targets: 0.8473 | Entropy: -1.5100
#
# Evaluating at epoch 350 …
# Train Accuracy: 81.12%
# Train Average Loss: 0.8755
# Test Accuracy: 84.59%
# Test Average Loss: 0.7818
# Total Trainable Parameters: 38,322
#
# Current learning rate: 1.34e-04
# New best model saved with test accuracy: 84.59%
# Epoch [351] 📊 acc: 0.777 | Targets: 1.7567 | Entropy: -2.2372
# Epoch [352] 📊 acc: 0.806 | Targets: 1.2363 | Entropy: -2.0144
# Epoch [353] 📊 acc: 0.806 | Targets: 0.6964 | Entropy: -1.1307
# Epoch [354] 📊 acc: 0.807 | Targets: 1.0211 | Entropy: -1.7922
# Epoch [355] 📊 acc: 0.804 | Targets: 1.2023 | Entropy: -1.9934
# Epoch [356] 📊 acc: 0.805 | Targets: 0.6889 | Entropy: -1.1184
# Epoch [357] 📊 acc: 0.811 | Targets: 0.6187 | Entropy: -0.9364
# New ref model saved
# Epoch [358] 📊 acc: 0.808 | Targets: 1.0052 | Entropy: -1.7673
# Epoch [359] 📊 acc: 0.804 | Targets: 1.3687 | Entropy: -2.1092
# Epoch [360] 📊 acc: 0.807 | Targets: 0.8860 | Entropy: -1.5877
#
# Evaluating at epoch 360 …
# Train Accuracy: 81.05%
# Train Average Loss: 0.8665
# Test Accuracy: 84.46%
# Test Average Loss: 0.7792
# Total Trainable Parameters: 38,322
#
# Current learning rate: 1.22e-04
# Epoch [361] 📊 acc: 0.809 | Targets: 1.1828 | Entropy: -1.9764
# Epoch [362] 📊 acc: 0.809 | Targets: 0.7290 | Entropy: -1.2481
# Epoch [363] 📊 acc: 0.771 | Targets: 1.7762 | Entropy: -2.2191
# Epoch [364] 📊 acc: 0.802 | Targets: 1.5124 | Entropy: -2.1813
# Epoch [365] 📊 acc: 0.803 | Targets: 0.6842 | Entropy: -1.0049
# Epoch [366] 📊 acc: 0.806 | Targets: 1.0542 | Entropy: -1.8113
# Epoch [367] 📊 acc: 0.807 | Targets: 1.1731 | Entropy: -1.9685
# Epoch [368] 📊 acc: 0.808 | Targets: 1.1914 | Entropy: -1.9874
# Epoch [369] 📊 acc: 0.807 | Targets: 1.0791 | Entropy: -1.8744
# Epoch [370] 📊 acc: 0.798 | Targets: 1.6135 | Entropy: -2.2130
#
# Evaluating at epoch 370 …
# Train Accuracy: 80.22%
# Train Average Loss: 1.6420
# Test Accuracy: 83.33%
# Test Average Loss: 1.5963
# Total Trainable Parameters: 38,322
#
# Current learning rate: 1.12e-04
# Epoch [371] 📊 acc: 0.805 | Targets: 0.7205 | Entropy: -1.1192
# Epoch [372] 📊 acc: 0.808 | Targets: 0.5987 | Entropy: -0.8198
# Epoch [373] 📊 acc: 0.811 | Targets: 0.7630 | Entropy: -1.3453
# Epoch [374] 📊 acc: 0.805 | Targets: 1.2616 | Entropy: -2.0339
# Epoch [375] 📊 acc: 0.801 | Targets: 1.4518 | Entropy: -2.1553
# Epoch [376] 📊 acc: 0.809 | Targets: 1.1203 | Entropy: -1.9163
# Epoch [377] 📊 acc: 0.803 | Targets: 1.4322 | Entropy: -2.1452
# Epoch [378] 📊 acc: 0.812 | Targets: 1.1570 | Entropy: -1.9569
# New ref model saved
# Epoch [379] 📊 acc: 0.807 | Targets: 0.6677 | Entropy: -1.0388
# Epoch [380] 📊 acc: 0.806 | Targets: 1.1402 | Entropy: -1.9133
#
# Evaluating at epoch 380 …
# Train Accuracy: 80.98%
# Train Average Loss: 1.1750
# Test Accuracy: 84.61%
# Test Average Loss: 1.1016
# Total Trainable Parameters: 38,322
#
# Current learning rate: 1.06e-04
# New best model saved with test accuracy: 84.61%
# Epoch [381] 📊 acc: 0.809 | Targets: 1.0865 | Entropy: -1.8840
# Epoch [382] 📊 acc: 0.808 | Targets: 1.2437 | Entropy: -2.0295
# Epoch [383] 📊 acc: 0.809 | Targets: 1.0255 | Entropy: -1.8109
# Epoch [384] 📊 acc: 0.811 | Targets: 0.9510 | Entropy: -1.7148
# Epoch [385] 📊 acc: 0.804 | Targets: 1.4087 | Entropy: -2.1296
# Epoch [386] 📊 acc: 0.806 | Targets: 1.0825 | Entropy: -1.8745
