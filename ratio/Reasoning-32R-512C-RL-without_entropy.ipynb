# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth):
        out = self.conv[depth // (self.max_depth // self.num_module)](x, depth)
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            x = checkpoint(self.step_forward, x, x_prev, d, use_reentrant=False)

        return x

# %%
class RecursionAmplifyConv(nn.Module):
    def __init__(self, channels, height, width):
        super(RecursionAmplifyConv, self).__init__()
        
        self.conv0 = nn.Conv2d(3, channels, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(channels, max_depth=32, num_module=1)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))


    def forward(self, x):
        
        x = self.conv0(x)

        x = self.amconv(x)

        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.reamconv= RecursionAmplifyConv(512, 32, 32)

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.reamconv(x)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        return x

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (1 - correct)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)

        rewards, correct = self.compute_positive_reward(outputs, targets)
        pre_rewards, _ = self.compute_positive_reward(pre_outputs, targets)
        ref_rewards, _ = self.compute_positive_reward(ref_outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)
    
    ref_count = 32
    
    ratio = nn.Parameter(torch.randn(1, device=device))
    
    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()
    all_params = list(net.parameters()) + [
        ratio,
    ]
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    rl_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=epochs, eta_min=1e-6
            )
        
        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs = net(inputs)
                ref_outputs = ref_net(inputs)
                pre_outputs = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_delta = F.sigmoid(ratio) * F.sigmoid(select_delta) + (1 - F.sigmoid(ratio)) * F.sigmoid(pre_select_delta)
                select_delta = select_delta - F.sigmoid(ref_select_delta)
                
                select_loss = select_delta.mean()
                
                loss = select_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Ratio: {torch.sigmoid(ratio).detach().item():.4f}")

        if running_cor > rl_accuracy:
            rl_accuracy = running_cor
            ref = copy.deepcopy(net).cpu()
            prev_ref.append(ref)
            prev_ref = prev_ref[-ref_count//2:]
            print(f"New ref model saved")
            
        r = ((epoch % (len(prev_ref) * 2) + 1) - ((epoch % (len(prev_ref) * 2) + 1) & -(epoch % (len(prev_ref) * 2) + 1))) // 2
        ref_net = copy.deepcopy(prev_ref[r]).to(device)
        print(f"New ref model: {r}")
              
        pre_net = copy.deepcopy(prev_ref[-1]).to(device)
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
                    if use_bf16 else contextlib.nullcontext())

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = net(images)  
            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum    += batch_loss.item() * bs
            total_seen  += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 515,754

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
#
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.330 | Targets: 1.8557 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [2] 📊 acc: 0.490 | Targets: 1.4246 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [3] 📊 acc: 0.561 | Targets: 1.2371 | Ratio: 0.4560
# New ref model saved
# New ref model: 1
# Epoch [4] 📊 acc: 0.607 | Targets: 1.1167 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [5] 📊 acc: 0.647 | Targets: 1.0171 | Ratio: 0.4560
# New ref model saved
# New ref model: 2
# Epoch [6] 📊 acc: 0.670 | Targets: 0.9479 | Ratio: 0.4560
# New ref model saved
# New ref model: 2
# Epoch [7] 📊 acc: 0.690 | Targets: 0.8927 | Ratio: 0.4560
# New ref model saved
# New ref model: 3
# Epoch [8] 📊 acc: 0.705 | Targets: 0.8508 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [9] 📊 acc: 0.722 | Targets: 0.8023 | Ratio: 0.4560
# New ref model saved
# New ref model: 4
# Epoch [10] 📊 acc: 0.730 | Targets: 0.7799 | Ratio: 0.4560
# New ref model saved
# New ref model: 4
#
# Evaluating at epoch 10 …
# Train Accuracy: 71.94%
# Train Average Loss: 0.8171
# Test Accuracy: 78.17%
# Test Average Loss: 0.6349
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 78.17%
# Epoch [11] 📊 acc: 0.739 | Targets: 0.7515 | Ratio: 0.4560
# New ref model saved
# New ref model: 5
# Epoch [12] 📊 acc: 0.751 | Targets: 0.7206 | Ratio: 0.4560
# New ref model saved
# New ref model: 4
# Epoch [13] 📊 acc: 0.760 | Targets: 0.6944 | Ratio: 0.4560
# New ref model saved
# New ref model: 6
# Epoch [14] 📊 acc: 0.763 | Targets: 0.6819 | Ratio: 0.4560
# New ref model saved
# New ref model: 6
# Epoch [15] 📊 acc: 0.773 | Targets: 0.6554 | Ratio: 0.4560
# New ref model saved
# New ref model: 7
# Epoch [16] 📊 acc: 0.780 | Targets: 0.6369 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [17] 📊 acc: 0.786 | Targets: 0.6221 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [18] 📊 acc: 0.791 | Targets: 0.6045 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [19] 📊 acc: 0.793 | Targets: 0.5984 | Ratio: 0.4560
# New ref model saved
# New ref model: 9
# Epoch [20] 📊 acc: 0.799 | Targets: 0.5766 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 20 …
# Train Accuracy: 78.80%
# Train Average Loss: 0.6188
# Test Accuracy: 83.06%
# Test Average Loss: 0.5022
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 83.06%
# Epoch [21] 📊 acc: 0.800 | Targets: 0.5742 | Ratio: 0.4560
# New ref model saved
# New ref model: 10
# Epoch [22] 📊 acc: 0.807 | Targets: 0.5575 | Ratio: 0.4560
# New ref model saved
# New ref model: 10
# Epoch [23] 📊 acc: 0.808 | Targets: 0.5533 | Ratio: 0.4560
# New ref model saved
# New ref model: 11
# Epoch [24] 📊 acc: 0.812 | Targets: 0.5384 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [25] 📊 acc: 0.820 | Targets: 0.5217 | Ratio: 0.4560
# New ref model saved
# New ref model: 12
# Epoch [26] 📊 acc: 0.821 | Targets: 0.5191 | Ratio: 0.4560
# New ref model saved
# New ref model: 12
# Epoch [27] 📊 acc: 0.822 | Targets: 0.5162 | Ratio: 0.4560
# New ref model saved
# New ref model: 13
# Epoch [28] 📊 acc: 0.825 | Targets: 0.5042 | Ratio: 0.4560
# New ref model saved
# New ref model: 12
# Epoch [29] 📊 acc: 0.829 | Targets: 0.4954 | Ratio: 0.4560
# New ref model saved
# New ref model: 14
# Epoch [30] 📊 acc: 0.830 | Targets: 0.4876 | Ratio: 0.4560
# New ref model saved
# New ref model: 14
#
# Evaluating at epoch 30 …
# Train Accuracy: 82.90%
# Train Average Loss: 0.4913
# Test Accuracy: 87.44%
# Test Average Loss: 0.3776
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 87.44%
# Epoch [31] 📊 acc: 0.834 | Targets: 0.4771 | Ratio: 0.4560
# New ref model saved
# New ref model: 15
# Epoch [32] 📊 acc: 0.835 | Targets: 0.4768 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [33] 📊 acc: 0.838 | Targets: 0.4650 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [34] 📊 acc: 0.839 | Targets: 0.4601 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [35] 📊 acc: 0.842 | Targets: 0.4538 | Ratio: 0.4560
# New ref model saved
# New ref model: 1
# Epoch [36] 📊 acc: 0.847 | Targets: 0.4438 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [37] 📊 acc: 0.846 | Targets: 0.4411 | Ratio: 0.4560
# New ref model: 2
# Epoch [38] 📊 acc: 0.846 | Targets: 0.4373 | Ratio: 0.4560
# New ref model: 2
# Epoch [39] 📊 acc: 0.851 | Targets: 0.4338 | Ratio: 0.4560
# New ref model saved
# New ref model: 3
# Epoch [40] 📊 acc: 0.851 | Targets: 0.4267 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 40 …
# Train Accuracy: 86.89%
# Train Average Loss: 0.3753
# Test Accuracy: 89.39%
# Test Average Loss: 0.3049
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 89.39%
# Epoch [41] 📊 acc: 0.853 | Targets: 0.4226 | Ratio: 0.4560
# New ref model saved
# New ref model: 4
# Epoch [42] 📊 acc: 0.853 | Targets: 0.4165 | Ratio: 0.4560
# New ref model: 4
# Epoch [43] 📊 acc: 0.856 | Targets: 0.4101 | Ratio: 0.4560
# New ref model saved
# New ref model: 5
# Epoch [44] 📊 acc: 0.861 | Targets: 0.4021 | Ratio: 0.4560
# New ref model saved
# New ref model: 4
# Epoch [45] 📊 acc: 0.861 | Targets: 0.3972 | Ratio: 0.4560
# New ref model: 6
# Epoch [46] 📊 acc: 0.862 | Targets: 0.4001 | Ratio: 0.4560
# New ref model saved
# New ref model: 6
# Epoch [47] 📊 acc: 0.863 | Targets: 0.3911 | Ratio: 0.4560
# New ref model saved
# New ref model: 7
# Epoch [48] 📊 acc: 0.864 | Targets: 0.3901 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [49] 📊 acc: 0.867 | Targets: 0.3837 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [50] 📊 acc: 0.869 | Targets: 0.3767 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 50 …
# Train Accuracy: 86.33%
# Train Average Loss: 0.3943
# Test Accuracy: 88.90%
# Test Average Loss: 0.3411
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.33e-04
# Epoch [51] 📊 acc: 0.872 | Targets: 0.3717 | Ratio: 0.4560
# New ref model saved
# New ref model: 9
# Epoch [52] 📊 acc: 0.868 | Targets: 0.3782 | Ratio: 0.4560
# New ref model: 8
# Epoch [53] 📊 acc: 0.872 | Targets: 0.3707 | Ratio: 0.4560
# New ref model saved
# New ref model: 10
# Epoch [54] 📊 acc: 0.873 | Targets: 0.3618 | Ratio: 0.4560
# New ref model saved
# New ref model: 10
# Epoch [55] 📊 acc: 0.874 | Targets: 0.3563 | Ratio: 0.4560
# New ref model saved
# New ref model: 11
# Epoch [56] 📊 acc: 0.877 | Targets: 0.3563 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [57] 📊 acc: 0.876 | Targets: 0.3569 | Ratio: 0.4560
# New ref model: 12
# Epoch [58] 📊 acc: 0.878 | Targets: 0.3547 | Ratio: 0.4560
# New ref model saved
# New ref model: 12
# Epoch [59] 📊 acc: 0.879 | Targets: 0.3445 | Ratio: 0.4560
# New ref model saved
# New ref model: 13
# Epoch [60] 📊 acc: 0.881 | Targets: 0.3445 | Ratio: 0.4560
# New ref model saved
# New ref model: 12
#
# Evaluating at epoch 60 …
# Train Accuracy: 86.98%
# Train Average Loss: 0.3773
# Test Accuracy: 89.52%
# Test Average Loss: 0.3159
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 89.52%
# Epoch [61] 📊 acc: 0.881 | Targets: 0.3433 | Ratio: 0.4560
# New ref model saved
# New ref model: 14
# Epoch [62] 📊 acc: 0.881 | Targets: 0.3413 | Ratio: 0.4560
# New ref model: 14
# Epoch [63] 📊 acc: 0.884 | Targets: 0.3324 | Ratio: 0.4560
# New ref model saved
# New ref model: 15
# Epoch [64] 📊 acc: 0.883 | Targets: 0.3348 | Ratio: 0.4560
# New ref model: 0
# Epoch [65] 📊 acc: 0.884 | Targets: 0.3321 | Ratio: 0.4560
# New ref model: 0
# Epoch [66] 📊 acc: 0.882 | Targets: 0.3351 | Ratio: 0.4560
# New ref model: 0
# Epoch [67] 📊 acc: 0.886 | Targets: 0.3300 | Ratio: 0.4560
# New ref model saved
# New ref model: 1
# Epoch [68] 📊 acc: 0.890 | Targets: 0.3194 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [69] 📊 acc: 0.889 | Targets: 0.3161 | Ratio: 0.4560
# New ref model: 2
# Epoch [70] 📊 acc: 0.890 | Targets: 0.3159 | Ratio: 0.4560
# New ref model saved
# New ref model: 2
#
# Evaluating at epoch 70 …
# Train Accuracy: 89.72%
# Train Average Loss: 0.2922
# Test Accuracy: 91.68%
# Test Average Loss: 0.2592
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.72e-04
# New best model saved with test accuracy: 91.68%
# Epoch [71] 📊 acc: 0.893 | Targets: 0.3116 | Ratio: 0.4560
# New ref model saved
# New ref model: 3
# Epoch [72] 📊 acc: 0.892 | Targets: 0.3066 | Ratio: 0.4560
# New ref model: 0
# Epoch [73] 📊 acc: 0.891 | Targets: 0.3133 | Ratio: 0.4560
# New ref model: 4
# Epoch [74] 📊 acc: 0.895 | Targets: 0.2995 | Ratio: 0.4560
# New ref model saved
# New ref model: 4
# Epoch [75] 📊 acc: 0.894 | Targets: 0.3016 | Ratio: 0.4560
# New ref model: 5
# Epoch [76] 📊 acc: 0.896 | Targets: 0.2954 | Ratio: 0.4560
# New ref model saved
# New ref model: 4
# Epoch [77] 📊 acc: 0.894 | Targets: 0.3026 | Ratio: 0.4560
# New ref model: 6
# Epoch [78] 📊 acc: 0.899 | Targets: 0.2934 | Ratio: 0.4560
# New ref model saved
# New ref model: 6
# Epoch [79] 📊 acc: 0.897 | Targets: 0.2938 | Ratio: 0.4560
# New ref model: 7
# Epoch [80] 📊 acc: 0.898 | Targets: 0.2936 | Ratio: 0.4560
# New ref model: 0
#
# Evaluating at epoch 80 …
# Train Accuracy: 90.11%
# Train Average Loss: 0.2827
# Test Accuracy: 91.56%
# Test Average Loss: 0.2622
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.35e-04
# Epoch [81] 📊 acc: 0.900 | Targets: 0.2914 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [82] 📊 acc: 0.898 | Targets: 0.2906 | Ratio: 0.4560
# New ref model: 8
# Epoch [83] 📊 acc: 0.901 | Targets: 0.2859 | Ratio: 0.4560
# New ref model saved
# New ref model: 9
# Epoch [84] 📊 acc: 0.902 | Targets: 0.2782 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [85] 📊 acc: 0.901 | Targets: 0.2842 | Ratio: 0.4560
# New ref model: 10
# Epoch [86] 📊 acc: 0.903 | Targets: 0.2801 | Ratio: 0.4560
# New ref model saved
# New ref model: 10
# Epoch [87] 📊 acc: 0.906 | Targets: 0.2728 | Ratio: 0.4560
# New ref model saved
# New ref model: 11
# Epoch [88] 📊 acc: 0.905 | Targets: 0.2752 | Ratio: 0.4560
# New ref model: 8
# Epoch [89] 📊 acc: 0.905 | Targets: 0.2731 | Ratio: 0.4560
# New ref model: 12
# Epoch [90] 📊 acc: 0.905 | Targets: 0.2737 | Ratio: 0.4560
# New ref model: 12
#
# Evaluating at epoch 90 …
# Train Accuracy: 90.96%
# Train Average Loss: 0.2620
# Test Accuracy: 91.57%
# Test Average Loss: 0.2658
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.94e-04
# Epoch [91] 📊 acc: 0.906 | Targets: 0.2693 | Ratio: 0.4560
# New ref model saved
# New ref model: 13
# Epoch [92] 📊 acc: 0.907 | Targets: 0.2677 | Ratio: 0.4560
# New ref model saved
# New ref model: 12
# Epoch [93] 📊 acc: 0.908 | Targets: 0.2644 | Ratio: 0.4560
# New ref model saved
# New ref model: 14
# Epoch [94] 📊 acc: 0.908 | Targets: 0.2658 | Ratio: 0.4560
# New ref model: 14
# Epoch [95] 📊 acc: 0.909 | Targets: 0.2599 | Ratio: 0.4560
# New ref model saved
# New ref model: 15
# Epoch [96] 📊 acc: 0.911 | Targets: 0.2583 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [97] 📊 acc: 0.911 | Targets: 0.2582 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [98] 📊 acc: 0.911 | Targets: 0.2551 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [99] 📊 acc: 0.914 | Targets: 0.2498 | Ratio: 0.4560
# New ref model saved
# New ref model: 1
# Epoch [100] 📊 acc: 0.914 | Targets: 0.2507 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 100 …
# Train Accuracy: 92.07%
# Train Average Loss: 0.2308
# Test Accuracy: 92.53%
# Test Average Loss: 0.2385
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.50e-04
# New best model saved with test accuracy: 92.53%
# Epoch [101] 📊 acc: 0.913 | Targets: 0.2506 | Ratio: 0.4560
# New ref model: 2
# Epoch [102] 📊 acc: 0.910 | Targets: 0.2535 | Ratio: 0.4560
# New ref model: 2
# Epoch [103] 📊 acc: 0.915 | Targets: 0.2421 | Ratio: 0.4560
# New ref model saved
# New ref model: 3
# Epoch [104] 📊 acc: 0.917 | Targets: 0.2425 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [105] 📊 acc: 0.914 | Targets: 0.2422 | Ratio: 0.4560
# New ref model: 4
# Epoch [106] 📊 acc: 0.916 | Targets: 0.2415 | Ratio: 0.4560
# New ref model: 4
# Epoch [107] 📊 acc: 0.914 | Targets: 0.2413 | Ratio: 0.4560
# New ref model: 5
# Epoch [108] 📊 acc: 0.916 | Targets: 0.2429 | Ratio: 0.4560
# New ref model: 4
# Epoch [109] 📊 acc: 0.918 | Targets: 0.2370 | Ratio: 0.4560
# New ref model saved
# New ref model: 6
# Epoch [110] 📊 acc: 0.916 | Targets: 0.2409 | Ratio: 0.4560
# New ref model: 6
#
# Evaluating at epoch 110 …
# Train Accuracy: 92.06%
# Train Average Loss: 0.2261
# Test Accuracy: 92.32%
# Test Average Loss: 0.2489
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.04e-04
# Epoch [111] 📊 acc: 0.917 | Targets: 0.2389 | Ratio: 0.4560
# New ref model: 7
# Epoch [112] 📊 acc: 0.918 | Targets: 0.2287 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [113] 📊 acc: 0.920 | Targets: 0.2312 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [114] 📊 acc: 0.921 | Targets: 0.2283 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [115] 📊 acc: 0.921 | Targets: 0.2270 | Ratio: 0.4560
# New ref model saved
# New ref model: 9
# Epoch [116] 📊 acc: 0.922 | Targets: 0.2249 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [117] 📊 acc: 0.922 | Targets: 0.2248 | Ratio: 0.4560
# New ref model: 10
# Epoch [118] 📊 acc: 0.922 | Targets: 0.2255 | Ratio: 0.4560
# New ref model saved
# New ref model: 10
# Epoch [119] 📊 acc: 0.922 | Targets: 0.2223 | Ratio: 0.4560
# New ref model saved
# New ref model: 11
# Epoch [120] 📊 acc: 0.924 | Targets: 0.2177 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 120 …
# Train Accuracy: 91.70%
# Train Average Loss: 0.2353
# Test Accuracy: 91.76%
# Test Average Loss: 0.2789
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.55e-04
# Epoch [121] 📊 acc: 0.923 | Targets: 0.2194 | Ratio: 0.4560
# New ref model: 12
# Epoch [122] 📊 acc: 0.924 | Targets: 0.2214 | Ratio: 0.4560
# New ref model: 12
# Epoch [123] 📊 acc: 0.925 | Targets: 0.2174 | Ratio: 0.4560
# New ref model saved
# New ref model: 13
# Epoch [124] 📊 acc: 0.925 | Targets: 0.2146 | Ratio: 0.4560
# New ref model: 12
# Epoch [125] 📊 acc: 0.926 | Targets: 0.2145 | Ratio: 0.4560
# New ref model saved
# New ref model: 14
# Epoch [126] 📊 acc: 0.923 | Targets: 0.2184 | Ratio: 0.4560
# New ref model: 14
# Epoch [127] 📊 acc: 0.927 | Targets: 0.2089 | Ratio: 0.4560
# New ref model saved
# New ref model: 15
# Epoch [128] 📊 acc: 0.927 | Targets: 0.2097 | Ratio: 0.4560
# New ref model: 0
# Epoch [129] 📊 acc: 0.928 | Targets: 0.2082 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [130] 📊 acc: 0.927 | Targets: 0.2094 | Ratio: 0.4560
# New ref model: 0
#
# Evaluating at epoch 130 …
# Train Accuracy: 93.13%
# Train Average Loss: 0.1998
# Test Accuracy: 92.83%
# Test Average Loss: 0.2335
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.04e-04
# New best model saved with test accuracy: 92.83%
# Epoch [131] 📊 acc: 0.928 | Targets: 0.2072 | Ratio: 0.4560
# New ref model saved
# New ref model: 1
# Epoch [132] 📊 acc: 0.930 | Targets: 0.2037 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [133] 📊 acc: 0.930 | Targets: 0.2004 | Ratio: 0.4560
# New ref model saved
# New ref model: 2
# Epoch [134] 📊 acc: 0.930 | Targets: 0.2038 | Ratio: 0.4560
# New ref model: 2
# Epoch [135] 📊 acc: 0.931 | Targets: 0.1980 | Ratio: 0.4560
# New ref model saved
# New ref model: 3
# Epoch [136] 📊 acc: 0.930 | Targets: 0.1989 | Ratio: 0.4560
# New ref model: 0
# Epoch [137] 📊 acc: 0.931 | Targets: 0.1996 | Ratio: 0.4560
# New ref model saved
# New ref model: 4
# Epoch [138] 📊 acc: 0.930 | Targets: 0.1979 | Ratio: 0.4560
# New ref model: 4
# Epoch [139] 📊 acc: 0.931 | Targets: 0.1965 | Ratio: 0.4560
# New ref model saved
# New ref model: 5
# Epoch [140] 📊 acc: 0.931 | Targets: 0.1946 | Ratio: 0.4560
# New ref model: 4
#
# Evaluating at epoch 140 …
# Train Accuracy: 93.20%
# Train Average Loss: 0.1989
# Test Accuracy: 92.91%
# Test Average Loss: 0.2368
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.53e-04
# New best model saved with test accuracy: 92.91%
# Epoch [141] 📊 acc: 0.934 | Targets: 0.1920 | Ratio: 0.4560
# New ref model saved
# New ref model: 6
# Epoch [142] 📊 acc: 0.933 | Targets: 0.1947 | Ratio: 0.4560
# New ref model: 6
# Epoch [143] 📊 acc: 0.932 | Targets: 0.1948 | Ratio: 0.4560
# New ref model: 7
# Epoch [144] 📊 acc: 0.934 | Targets: 0.1899 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [145] 📊 acc: 0.936 | Targets: 0.1886 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [146] 📊 acc: 0.936 | Targets: 0.1866 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [147] 📊 acc: 0.935 | Targets: 0.1862 | Ratio: 0.4560
# New ref model: 9
# Epoch [148] 📊 acc: 0.935 | Targets: 0.1885 | Ratio: 0.4560
# New ref model: 8
# Epoch [149] 📊 acc: 0.935 | Targets: 0.1875 | Ratio: 0.4560
# New ref model: 10
# Epoch [150] 📊 acc: 0.937 | Targets: 0.1831 | Ratio: 0.4560
# New ref model saved
# New ref model: 10
#
# Evaluating at epoch 150 …
# Train Accuracy: 94.14%
# Train Average Loss: 0.1684
# Test Accuracy: 93.47%
# Test Average Loss: 0.2182
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.00e-04
# New best model saved with test accuracy: 93.47%
# Epoch [151] 📊 acc: 0.937 | Targets: 0.1827 | Ratio: 0.4560
# New ref model saved
# New ref model: 11
# Epoch [152] 📊 acc: 0.938 | Targets: 0.1787 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [153] 📊 acc: 0.937 | Targets: 0.1812 | Ratio: 0.4560
# New ref model: 12
# Epoch [154] 📊 acc: 0.941 | Targets: 0.1744 | Ratio: 0.4560
# New ref model saved
# New ref model: 12
# Epoch [155] 📊 acc: 0.937 | Targets: 0.1801 | Ratio: 0.4560
# New ref model: 13
# Epoch [156] 📊 acc: 0.940 | Targets: 0.1750 | Ratio: 0.4560
# New ref model: 12
# Epoch [157] 📊 acc: 0.940 | Targets: 0.1748 | Ratio: 0.4560
# New ref model: 14
# Epoch [158] 📊 acc: 0.938 | Targets: 0.1788 | Ratio: 0.4560
# New ref model: 14
# Epoch [159] 📊 acc: 0.941 | Targets: 0.1694 | Ratio: 0.4560
# New ref model saved
# New ref model: 15
# Epoch [160] 📊 acc: 0.941 | Targets: 0.1704 | Ratio: 0.4560
# New ref model: 0
#
# Evaluating at epoch 160 …
# Train Accuracy: 94.30%
# Train Average Loss: 0.1659
# Test Accuracy: 93.65%
# Test Average Loss: 0.2246
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.48e-04
# New best model saved with test accuracy: 93.65%
# Epoch [161] 📊 acc: 0.940 | Targets: 0.1750 | Ratio: 0.4560
# New ref model: 0
# Epoch [162] 📊 acc: 0.941 | Targets: 0.1686 | Ratio: 0.4560
# New ref model: 0
# Epoch [163] 📊 acc: 0.940 | Targets: 0.1749 | Ratio: 0.4560
# New ref model: 1
# Epoch [164] 📊 acc: 0.943 | Targets: 0.1657 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [165] 📊 acc: 0.943 | Targets: 0.1685 | Ratio: 0.4560
# New ref model: 2
# Epoch [166] 📊 acc: 0.942 | Targets: 0.1651 | Ratio: 0.4560
# New ref model: 2
# Epoch [167] 📊 acc: 0.943 | Targets: 0.1664 | Ratio: 0.4560
# New ref model saved
# New ref model: 3
# Epoch [168] 📊 acc: 0.943 | Targets: 0.1658 | Ratio: 0.4560
# New ref model: 0
# Epoch [169] 📊 acc: 0.944 | Targets: 0.1633 | Ratio: 0.4560
# New ref model saved
# New ref model: 4
# Epoch [170] 📊 acc: 0.943 | Targets: 0.1655 | Ratio: 0.4560
# New ref model: 4
#
# Evaluating at epoch 170 …
# Train Accuracy: 94.55%
# Train Average Loss: 0.1593
# Test Accuracy: 93.23%
# Test Average Loss: 0.2354
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.97e-04
# Epoch [171] 📊 acc: 0.945 | Targets: 0.1581 | Ratio: 0.4560
# New ref model saved
# New ref model: 5
# Epoch [172] 📊 acc: 0.944 | Targets: 0.1611 | Ratio: 0.4560
# New ref model: 4
# Epoch [173] 📊 acc: 0.946 | Targets: 0.1586 | Ratio: 0.4560
# New ref model saved
# New ref model: 6
# Epoch [174] 📊 acc: 0.944 | Targets: 0.1599 | Ratio: 0.4560
# New ref model: 6
# Epoch [175] 📊 acc: 0.944 | Targets: 0.1601 | Ratio: 0.4560
# New ref model: 7
# Epoch [176] 📊 acc: 0.946 | Targets: 0.1565 | Ratio: 0.4560
# New ref model: 0
# Epoch [177] 📊 acc: 0.944 | Targets: 0.1603 | Ratio: 0.4560
# New ref model: 8
# Epoch [178] 📊 acc: 0.947 | Targets: 0.1551 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [179] 📊 acc: 0.946 | Targets: 0.1561 | Ratio: 0.4560
# New ref model: 9
# Epoch [180] 📊 acc: 0.946 | Targets: 0.1546 | Ratio: 0.4560
# New ref model: 8
#
# Evaluating at epoch 180 …
# Train Accuracy: 95.11%
# Train Average Loss: 0.1427
# Test Accuracy: 93.72%
# Test Average Loss: 0.2303
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.46e-04
# New best model saved with test accuracy: 93.72%
# Epoch [181] 📊 acc: 0.947 | Targets: 0.1530 | Ratio: 0.4560
# New ref model: 10
# Epoch [182] 📊 acc: 0.947 | Targets: 0.1515 | Ratio: 0.4560
# New ref model: 10
# Epoch [183] 📊 acc: 0.949 | Targets: 0.1468 | Ratio: 0.4560
# New ref model saved
# New ref model: 11
# Epoch [184] 📊 acc: 0.949 | Targets: 0.1487 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [185] 📊 acc: 0.949 | Targets: 0.1495 | Ratio: 0.4560
# New ref model: 12
# Epoch [186] 📊 acc: 0.949 | Targets: 0.1500 | Ratio: 0.4560
# New ref model: 12
# Epoch [187] 📊 acc: 0.949 | Targets: 0.1475 | Ratio: 0.4560
# New ref model: 13
# Epoch [188] 📊 acc: 0.950 | Targets: 0.1470 | Ratio: 0.4560
# New ref model saved
# New ref model: 12
# Epoch [189] 📊 acc: 0.948 | Targets: 0.1479 | Ratio: 0.4560
# New ref model: 14
# Epoch [190] 📊 acc: 0.951 | Targets: 0.1405 | Ratio: 0.4560
# New ref model saved
# New ref model: 14
#
# Evaluating at epoch 190 …
# Train Accuracy: 95.07%
# Train Average Loss: 0.1430
# Test Accuracy: 93.69%
# Test Average Loss: 0.2357
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.97e-04
# Epoch [191] 📊 acc: 0.951 | Targets: 0.1420 | Ratio: 0.4560
# New ref model saved
# New ref model: 15
# Epoch [192] 📊 acc: 0.951 | Targets: 0.1435 | Ratio: 0.4560
# New ref model: 0
# Epoch [193] 📊 acc: 0.951 | Targets: 0.1442 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [194] 📊 acc: 0.952 | Targets: 0.1404 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [195] 📊 acc: 0.953 | Targets: 0.1371 | Ratio: 0.4560
# New ref model saved
# New ref model: 1
# Epoch [196] 📊 acc: 0.952 | Targets: 0.1387 | Ratio: 0.4560
# New ref model: 0
# Epoch [197] 📊 acc: 0.952 | Targets: 0.1422 | Ratio: 0.4560
# New ref model: 2
# Epoch [198] 📊 acc: 0.952 | Targets: 0.1383 | Ratio: 0.4560
# New ref model: 2
# Epoch [199] 📊 acc: 0.950 | Targets: 0.1441 | Ratio: 0.4560
# New ref model: 3
# Epoch [200] 📊 acc: 0.953 | Targets: 0.1382 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 200 …
# Train Accuracy: 95.48%
# Train Average Loss: 0.1304
# Test Accuracy: 93.63%
# Test Average Loss: 0.2355
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.51e-04
# Epoch [201] 📊 acc: 0.954 | Targets: 0.1364 | Ratio: 0.4560
# New ref model saved
# New ref model: 4
# Epoch [202] 📊 acc: 0.954 | Targets: 0.1371 | Ratio: 0.4560
# New ref model: 4
# Epoch [203] 📊 acc: 0.954 | Targets: 0.1328 | Ratio: 0.4560
# New ref model: 5
# Epoch [204] 📊 acc: 0.953 | Targets: 0.1368 | Ratio: 0.4560
# New ref model: 4
# Epoch [205] 📊 acc: 0.955 | Targets: 0.1311 | Ratio: 0.4560
# New ref model saved
# New ref model: 6
# Epoch [206] 📊 acc: 0.953 | Targets: 0.1342 | Ratio: 0.4560
# New ref model: 6
# Epoch [207] 📊 acc: 0.956 | Targets: 0.1289 | Ratio: 0.4560
# New ref model saved
# New ref model: 7
# Epoch [208] 📊 acc: 0.953 | Targets: 0.1349 | Ratio: 0.4560
# New ref model: 0
# Epoch [209] 📊 acc: 0.954 | Targets: 0.1343 | Ratio: 0.4560
# New ref model: 8
# Epoch [210] 📊 acc: 0.955 | Targets: 0.1316 | Ratio: 0.4560
# New ref model: 8
#
# Evaluating at epoch 210 …
# Train Accuracy: 95.60%
# Train Average Loss: 0.1279
# Test Accuracy: 93.89%
# Test Average Loss: 0.2280
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.07e-04
# New best model saved with test accuracy: 93.89%
# Epoch [211] 📊 acc: 0.955 | Targets: 0.1292 | Ratio: 0.4560
# New ref model: 9
# Epoch [212] 📊 acc: 0.956 | Targets: 0.1301 | Ratio: 0.4560
# New ref model: 8
# Epoch [213] 📊 acc: 0.954 | Targets: 0.1327 | Ratio: 0.4560
# New ref model: 10
# Epoch [214] 📊 acc: 0.955 | Targets: 0.1307 | Ratio: 0.4560
# New ref model: 10
# Epoch [215] 📊 acc: 0.955 | Targets: 0.1298 | Ratio: 0.4560
# New ref model: 11
# Epoch [216] 📊 acc: 0.958 | Targets: 0.1238 | Ratio: 0.4560
# New ref model saved
# New ref model: 8
# Epoch [217] 📊 acc: 0.958 | Targets: 0.1231 | Ratio: 0.4560
# New ref model: 12
# Epoch [218] 📊 acc: 0.956 | Targets: 0.1260 | Ratio: 0.4560
# New ref model: 12
# Epoch [219] 📊 acc: 0.957 | Targets: 0.1251 | Ratio: 0.4560
# New ref model: 13
# Epoch [220] 📊 acc: 0.958 | Targets: 0.1238 | Ratio: 0.4560
# New ref model saved
# New ref model: 12
#
# Evaluating at epoch 220 …
# Train Accuracy: 95.90%
# Train Average Loss: 0.1207
# Test Accuracy: 93.89%
# Test Average Loss: 0.2394
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.66e-04
# Epoch [221] 📊 acc: 0.956 | Targets: 0.1261 | Ratio: 0.4560
# New ref model: 14
# Epoch [222] 📊 acc: 0.957 | Targets: 0.1254 | Ratio: 0.4560
# New ref model: 14
# Epoch [223] 📊 acc: 0.958 | Targets: 0.1212 | Ratio: 0.4560
# New ref model saved
# New ref model: 15
# Epoch [224] 📊 acc: 0.957 | Targets: 0.1241 | Ratio: 0.4560
# New ref model: 0
# Epoch [225] 📊 acc: 0.958 | Targets: 0.1228 | Ratio: 0.4560
# New ref model: 0
# Epoch [226] 📊 acc: 0.958 | Targets: 0.1239 | Ratio: 0.4560
# New ref model: 0
# Epoch [227] 📊 acc: 0.959 | Targets: 0.1195 | Ratio: 0.4560
# New ref model saved
# New ref model: 1
# Epoch [228] 📊 acc: 0.959 | Targets: 0.1187 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [229] 📊 acc: 0.960 | Targets: 0.1171 | Ratio: 0.4560
# New ref model saved
# New ref model: 2
# Epoch [230] 📊 acc: 0.959 | Targets: 0.1192 | Ratio: 0.4560
# New ref model: 2
#
# Evaluating at epoch 230 …
# Train Accuracy: 96.08%
# Train Average Loss: 0.1129
# Test Accuracy: 94.05%
# Test Average Loss: 0.2399
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.29e-04
# New best model saved with test accuracy: 94.05%
# Epoch [231] 📊 acc: 0.958 | Targets: 0.1204 | Ratio: 0.4560
# New ref model: 3
# Epoch [232] 📊 acc: 0.961 | Targets: 0.1153 | Ratio: 0.4560
# New ref model saved
# New ref model: 0
# Epoch [233] 📊 acc: 0.960 | Targets: 0.1178 | Ratio: 0.4560
# New ref model: 4
# Epoch [234] 📊 acc: 0.959 | Targets: 0.1172 | Ratio: 0.4560
# New ref model: 4
# Epoch [235] 📊 acc: 0.959 | Targets: 0.1211 | Ratio: 0.4560
# New ref model: 5
# Epoch [236] 📊 acc: 0.961 | Targets: 0.1131 | Ratio: 0.4560
# New ref model saved
# New ref model: 4
# Epoch [237] 📊 acc: 0.960 | Targets: 0.1164 | Ratio: 0.4560
# New ref model: 6
# Epoch [238] 📊 acc: 0.961 | Targets: 0.1140 | Ratio: 0.4560
# New ref model saved
# New ref model: 6
# Epoch [239] 📊 acc: 0.959 | Targets: 0.1201 | Ratio: 0.4560
# New ref model: 7
# Epoch [240] 📊 acc: 0.960 | Targets: 0.1140 | Ratio: 0.4560
# New ref model: 0
#
# Evaluating at epoch 240 …
# Train Accuracy: 96.04%
# Train Average Loss: 0.1144
# Test Accuracy: 94.19%
# Test Average Loss: 0.2339
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.64e-05
# New best model saved with test accuracy: 94.19%
# Epoch [241] 📊 acc: 0.960 | Targets: 0.1160 | Ratio: 0.4560
# New ref model: 8
# Epoch [242] 📊 acc: 0.961 | Targets: 0.1123 | Ratio: 0.4560
# New ref model: 8
# Epoch [243] 📊 acc: 0.960 | Targets: 0.1150 | Ratio: 0.4560
# New ref model: 9
# Epoch [244] 📊 acc: 0.961 | Targets: 0.1149 | Ratio: 0.4560
# New ref model: 8
# Epoch [245] 📊 acc: 0.962 | Targets: 0.1136 | Ratio: 0.4560
# New ref model saved
# New ref model: 10
# Epoch [246] 📊 acc: 0.963 | Targets: 0.1088 | Ratio: 0.4560
# New ref model saved
# New ref model: 10
# Epoch [247] 📊 acc: 0.961 | Targets: 0.1130 | Ratio: 0.4560
# New ref model: 11
# Epoch [248] 📊 acc: 0.962 | Targets: 0.1100 | Ratio: 0.4560
# New ref model: 8
# Epoch [249] 📊 acc: 0.961 | Targets: 0.1143 | Ratio: 0.4560
# New ref model: 12
# Epoch [250] 📊 acc: 0.962 | Targets: 0.1107 | Ratio: 0.4560
# New ref model: 12
#
# Evaluating at epoch 250 …
# Train Accuracy: 96.01%
# Train Average Loss: 0.1122
# Test Accuracy: 94.06%
# Test Average Loss: 0.2295
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.79e-05
# Epoch [251] 📊 acc: 0.964 | Targets: 0.1072 | Ratio: 0.4560
# New ref model saved
# New ref model: 13
# Epoch [252] 📊 acc: 0.964 | Targets: 0.1076 | Ratio: 0.4560
# New ref model saved
# New ref model: 12
# Epoch [253] 📊 acc: 0.961 | Targets: 0.1120 | Ratio: 0.4560
# New ref model: 14
# Epoch [254] 📊 acc: 0.962 | Targets: 0.1120 | Ratio: 0.4560
# New ref model: 14
# Epoch [255] 📊 acc: 0.963 | Targets: 0.1091 | Ratio: 0.4560
# New ref model: 15
# Epoch [256] 📊 acc: 0.964 | Targets: 0.1077 | Ratio: 0.4560
# New ref model: 0
# Epoch [257] 📊 acc: 0.961 | Targets: 0.1094 | Ratio: 0.4560
# New ref model: 0
# Epoch [258] 📊 acc: 0.962 | Targets: 0.1084 | Ratio: 0.4560
# New ref model: 0
# Epoch [259] 📊 acc: 0.962 | Targets: 0.1106 | Ratio: 0.4560
# New ref model: 1
# Epoch [260] 📊 acc: 0.963 | Targets: 0.1076 | Ratio: 0.4560
# New ref model: 0
#
# Evaluating at epoch 260 …
# Train Accuracy: 96.27%
# Train Average Loss: 0.1079
# Test Accuracy: 94.22%
# Test Average Loss: 0.2310
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.42e-05
# New best model saved with test accuracy: 94.22%
# Epoch [261] 📊 acc: 0.963 | Targets: 0.1060 | Ratio: 0.4560
# New ref model: 2
# Epoch [262] 📊 acc: 0.965 | Targets: 0.1012 | Ratio: 0.4560
# New ref model saved
# New ref model: 2
# Epoch [263] 📊 acc: 0.963 | Targets: 0.1073 | Ratio: 0.4560
# New ref model: 3
# Epoch [264] 📊 acc: 0.964 | Targets: 0.1065 | Ratio: 0.4560
# New ref model: 0
# Epoch [265] 📊 acc: 0.964 | Targets: 0.1052 | Ratio: 0.4560
# New ref model: 4
# Epoch [266] 📊 acc: 0.964 | Targets: 0.1072 | Ratio: 0.4560
# New ref model: 4
# Epoch [267] 📊 acc: 0.965 | Targets: 0.1023 | Ratio: 0.4560
# New ref model: 5
# Epoch [268] 📊 acc: 0.963 | Targets: 0.1079 | Ratio: 0.4560
# New ref model: 4
# Epoch [269] 📊 acc: 0.963 | Targets: 0.1070 | Ratio: 0.4560
# New ref model: 6
# Epoch [270] 📊 acc: 0.964 | Targets: 0.1074 | Ratio: 0.4560
# New ref model: 6
#
# Evaluating at epoch 270 …
# Train Accuracy: 96.37%
# Train Average Loss: 0.1067
# Test Accuracy: 94.33%
# Test Average Loss: 0.2276
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-05
# New best model saved with test accuracy: 94.33%
# Epoch [271] 📊 acc: 0.963 | Targets: 0.1062 | Ratio: 0.4560
# New ref model: 7
# Epoch [272] 📊 acc: 0.963 | Targets: 0.1055 | Ratio: 0.4560
# New ref model: 0
# Epoch [273] 📊 acc: 0.963 | Targets: 0.1087 | Ratio: 0.4560
# New ref model: 8
# Epoch [274] 📊 acc: 0.964 | Targets: 0.1029 | Ratio: 0.4560
# New ref model: 8
# Epoch [275] 📊 acc: 0.965 | Targets: 0.1045 | Ratio: 0.4560
# New ref model: 9
# Epoch [276] 📊 acc: 0.964 | Targets: 0.1047 | Ratio: 0.4560
# New ref model: 8
# Epoch [277] 📊 acc: 0.966 | Targets: 0.1003 | Ratio: 0.4560
# New ref model saved
# New ref model: 10
# Epoch [278] 📊 acc: 0.962 | Targets: 0.1086 | Ratio: 0.4560
# New ref model: 10
# Epoch [279] 📊 acc: 0.964 | Targets: 0.1051 | Ratio: 0.4560
# New ref model: 11
# Epoch [280] 📊 acc: 0.966 | Targets: 0.1007 | Ratio: 0.4560
# New ref model: 8
#
# Evaluating at epoch 280 …
# Train Accuracy: 96.48%
# Train Average Loss: 0.1017
# Test Accuracy: 94.35%
# Test Average Loss: 0.2276
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.19e-05
# New best model saved with test accuracy: 94.35%
# Epoch [281] 📊 acc: 0.965 | Targets: 0.1017 | Ratio: 0.4560
# New ref model: 12
# Epoch [282] 📊 acc: 0.964 | Targets: 0.1026 | Ratio: 0.4560
# New ref model: 12
# Epoch [283] 📊 acc: 0.964 | Targets: 0.1027 | Ratio: 0.4560
# New ref model: 13
# Epoch [284] 📊 acc: 0.964 | Targets: 0.1051 | Ratio: 0.4560
# New ref model: 12
# Epoch [285] 📊 acc: 0.964 | Targets: 0.1047 | Ratio: 0.4560
# New ref model: 14
# Epoch [286] 📊 acc: 0.964 | Targets: 0.1042 | Ratio: 0.4560
# New ref model: 14
# Epoch [287] 📊 acc: 0.965 | Targets: 0.1039 | Ratio: 0.4560
# New ref model: 15
# Epoch [288] 📊 acc: 0.965 | Targets: 0.1021 | Ratio: 0.4560
# New ref model: 0
# Epoch [289] 📊 acc: 0.964 | Targets: 0.1036 | Ratio: 0.4560
# New ref model: 0
# Epoch [290] 📊 acc: 0.964 | Targets: 0.1054 | Ratio: 0.4560
# New ref model: 0
#
# Evaluating at epoch 290 …
# Train Accuracy: 96.64%
# Train Average Loss: 0.0991
# Test Accuracy: 94.33%
# Test Average Loss: 0.2291
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.74e-06
# Epoch [291] 📊 acc: 0.965 | Targets: 0.1013 | Ratio: 0.4560
# New ref model: 1
# Epoch [292] 📊 acc: 0.965 | Targets: 0.1022 | Ratio: 0.4560
# New ref model: 0
# Epoch [293] 📊 acc: 0.966 | Targets: 0.1001 | Ratio: 0.4560
# New ref model: 2
# Epoch [294] 📊 acc: 0.963 | Targets: 0.1053 | Ratio: 0.4560
# New ref model: 2
# Epoch [295] 📊 acc: 0.965 | Targets: 0.1018 | Ratio: 0.4560
# New ref model: 3
# Epoch [296] 📊 acc: 0.964 | Targets: 0.1048 | Ratio: 0.4560
# New ref model: 0
# Epoch [297] 📊 acc: 0.965 | Targets: 0.1039 | Ratio: 0.4560
# New ref model: 4
# Epoch [298] 📊 acc: 0.964 | Targets: 0.1040 | Ratio: 0.4560
# New ref model: 4
# Epoch [299] 📊 acc: 0.966 | Targets: 0.0988 | Ratio: 0.4560
# New ref model: 5
# Epoch [300] 📊 acc: 0.965 | Targets: 0.1030 | Ratio: 0.4560
# New ref model: 4
#
# Evaluating at epoch 300 …
# Train Accuracy: 96.46%
# Train Average Loss: 0.1033
# Test Accuracy: 94.36%
# Test Average Loss: 0.2278
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-06
# New best model saved with test accuracy: 94.36%
# Finished Training
# Best test accuracy achieved: 94.36%
# Total Trainable Parameters: 515,754
