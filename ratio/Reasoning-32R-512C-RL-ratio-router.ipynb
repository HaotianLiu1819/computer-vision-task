# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class Router(nn.Module):
    def __init__(self, channels, num_module, tau=1.0, reduction_factor=4):
        super().__init__()
        self.num_module = num_module
        self.tau = tau
        reduced_channels = channels // reduction_factor
        self.conv = nn.Sequential(
            nn.ReLU(),
            nn.GroupNorm(1, channels),
            nn.Conv2d(channels, reduced_channels, kernel_size=1, bias=False),
            nn.ReLU(),
            nn.GroupNorm(1, reduced_channels),
            nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels),
            nn.ReLU(),
            nn.GroupNorm(1, reduced_channels),
            nn.Conv2d(reduced_channels, channels, kernel_size=1, bias=False),
            nn.AdaptiveAvgPool2d((1, 1)),
        )
        self.fc = nn.Linear(channels, num_module)

    def forward(self, x):
        h = self.conv(x).flatten(1)
        logits = self.fc(h)
        r = F.gumbel_softmax(logits, tau=self.tau, hard=True, dim=1)
        return r, logits

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)
        self.router = Router(channels, num_module)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth, group_ids):
        out = torch.empty_like(x)

        for i in range(self.num_module):
            idx = (group_ids == i).nonzero(as_tuple=True)[0]
            if idx.numel() == 0:
                continue
            out_i = self.conv[i](x[idx], depth).to(x.dtype)
            out[idx] = out_i
        
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        usage_per_depth = []
        
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            
            r, logits = self.router(x)
            group_ids = torch.argmax(r, dim=1)
            usage = torch.bincount(group_ids, minlength=self.num_module).detach()
            usage_per_depth.append(usage)
            
            x = checkpoint(self.step_forward, x, x_prev, d, group_ids, use_reentrant=False)

        return x, usage_per_depth

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv0 = nn.Conv2d(3, 512, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(512, max_depth=32, num_module=4)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.conv0(x)
        x, usage_per_depth = self.amconv(x)
        
        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        
        return x, usage_per_depth

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (1 - correct)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        pre_entropy = torch.sum(pre_probs * torch.log(pre_probs), dim=1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_pre_entropy = torch.sum(old_pre_probs * torch.log(old_pre_probs), dim=1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        ref_entropy = torch.sum(ref_probs * torch.log(ref_probs), dim=1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_ref_entropy = torch.sum(old_ref_probs * torch.log(old_ref_probs), dim=1)

        rewards, correct = self.compute_positive_reward(outputs, targets)
        pre_rewards, _ = self.compute_positive_reward(pre_outputs, targets)
        ref_rewards, _ = self.compute_positive_reward(ref_outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        entropy_delta = (entropy - old_entropy)
        pre_entropy_delta = (pre_entropy - old_pre_entropy)
        ref_entropy_delta = (ref_entropy - old_ref_entropy)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
                'entropy': entropy.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)
    
    ref_count = 32
    
    ratio = nn.Parameter(torch.randn(1, device=device))
    
    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()
    all_params = list(net.parameters()) + [
        ratio,
    ]
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    rl_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=epochs, eta_min=1e-6
            )
        
        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs, _ = net(inputs)
                ref_outputs, _ = ref_net(inputs)
                pre_outputs, _ = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_delta = F.sigmoid(ratio) * F.sigmoid(select_delta) + (1 - F.sigmoid(ratio)) * F.sigmoid(pre_select_delta)
                select_delta = select_delta - F.sigmoid(ref_select_delta)
                
                select_loss = select_delta.mean()
                
                entropy_delta = F.sigmoid(ratio) * F.sigmoid(entropy_delta) + (1 - F.sigmoid(ratio)) * F.sigmoid(pre_entropy_delta)         
                entropy_delta = entropy_delta - F.sigmoid(ref_entropy_delta) 

                entropy_loss = entropy_delta.mean()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f} | Ratio: {torch.sigmoid(ratio).detach().item():.4f}")

        if running_cor > rl_accuracy:
            rl_accuracy = running_cor
            ref = copy.deepcopy(net).cpu()
            prev_ref.append(ref)
            prev_ref = prev_ref[-ref_count//2:]
            print(f"New ref model saved")
            
        r = ((epoch % (len(prev_ref) * 2) + 1) - ((epoch % (len(prev_ref) * 2) + 1) & -(epoch % (len(prev_ref) * 2) + 1))) // 2
        ref_net = copy.deepcopy(prev_ref[r]).to(device)
        print(f"New ref model: {r}")
              
        pre_net = copy.deepcopy(prev_ref[-1]).to(device)
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (
        torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
        if use_bf16 else contextlib.nullcontext()
    )

    total_usage_per_depth = None

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

        
            outputs, usage_per_depth = net(images)

            if total_usage_per_depth is None:
                total_usage_per_depth = [
                    u.clone().to(torch.long) for u in usage_per_depth
                ]
            else:
                for d in range(len(usage_per_depth)):
                    total_usage_per_depth[d] += usage_per_depth[d].to(torch.long)

            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum += batch_loss.item() * bs
            total_seen += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if total_usage_per_depth is not None:

        max_depth_to_sum = min(16, len(total_usage_per_depth))
        summed_usage = sum(total_usage_per_depth[:max_depth_to_sum])
        summed_usage = summed_usage.cpu()

        total = summed_usage.sum().item()
        print(f"{dataset_name} Module Usage Summed Over Depth 0 to {max_depth_to_sum - 1}:")

        if total > 0:
            ratio = summed_usage.float() / total
            for i in range(len(summed_usage)):
                print(f"  module{i}: {summed_usage[i].item()} ({ratio[i].item() * 100:.2f}%)")
        else:
            for i in range(len(summed_usage)):
                print(f"  module{i}: 0 (0.00%)")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 1,942,286

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.272 | Targets: 2.0669 | Entropy: -2.1516 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [2] 📊 acc: 0.431 | Targets: 1.7531 | Entropy: -2.0815 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [3] 📊 acc: 0.513 | Targets: 1.6220 | Entropy: -2.0416 | Ratio: 0.3146
# New ref model saved
# New ref model: 1
# Epoch [4] 📊 acc: 0.562 | Targets: 1.5347 | Entropy: -2.0171 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [5] 📊 acc: 0.600 | Targets: 1.4751 | Entropy: -2.0031 | Ratio: 0.3146
# New ref model saved
# New ref model: 2
# Epoch [6] 📊 acc: 0.639 | Targets: 1.4159 | Entropy: -1.9902 | Ratio: 0.3146
# New ref model saved
# New ref model: 2
# Epoch [7] 📊 acc: 0.657 | Targets: 1.3771 | Entropy: -1.9778 | Ratio: 0.3146
# New ref model saved
# New ref model: 3
# Epoch [8] 📊 acc: 0.677 | Targets: 1.3445 | Entropy: -1.9711 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [9] 📊 acc: 0.687 | Targets: 1.3250 | Entropy: -1.9681 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
# Epoch [10] 📊 acc: 0.708 | Targets: 1.2926 | Entropy: -1.9605 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
#
# Evaluating at epoch 10 …
# Train Accuracy: 69.90%
# Train Average Loss: 1.2928
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 240640 (30.09%)
#   module1: 198534 (24.82%)
#   module2: 171303 (21.42%)
#   module3: 189267 (23.67%)
# Test Accuracy: 74.76%
# Test Average Loss: 1.2290
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 47664 (29.79%)
#   module1: 39677 (24.80%)
#   module2: 34277 (21.42%)
#   module3: 38382 (23.99%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 74.76%
# Epoch [11] 📊 acc: 0.715 | Targets: 1.2780 | Entropy: -1.9586 | Ratio: 0.3146
# New ref model saved
# New ref model: 5
# Epoch [12] 📊 acc: 0.726 | Targets: 1.2581 | Entropy: -1.9548 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
# Epoch [13] 📊 acc: 0.735 | Targets: 1.2402 | Entropy: -1.9516 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [14] 📊 acc: 0.741 | Targets: 1.2285 | Entropy: -1.9488 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [15] 📊 acc: 0.752 | Targets: 1.2117 | Entropy: -1.9459 | Ratio: 0.3146
# New ref model saved
# New ref model: 7
# Epoch [16] 📊 acc: 0.756 | Targets: 1.2038 | Entropy: -1.9451 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [17] 📊 acc: 0.762 | Targets: 1.1926 | Entropy: -1.9426 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
# Epoch [18] 📊 acc: 0.766 | Targets: 1.1810 | Entropy: -1.9406 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
# Epoch [19] 📊 acc: 0.773 | Targets: 1.1728 | Entropy: -1.9394 | Ratio: 0.3146
# New ref model saved
# New ref model: 9
# Epoch [20] 📊 acc: 0.776 | Targets: 1.1633 | Entropy: -1.9378 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 20 …
# Train Accuracy: 78.73%
# Train Average Loss: 1.1565
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 250642 (31.34%)
#   module1: 201692 (25.22%)
#   module2: 162611 (20.33%)
#   module3: 184799 (23.11%)
# Test Accuracy: 82.98%
# Test Average Loss: 1.0796
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 50196 (31.37%)
#   module1: 39758 (24.85%)
#   module2: 32567 (20.35%)
#   module3: 37479 (23.42%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 82.98%
# Epoch [21] 📊 acc: 0.781 | Targets: 1.1593 | Entropy: -1.9368 | Ratio: 0.3146
# New ref model saved
# New ref model: 10
# Epoch [22] 📊 acc: 0.786 | Targets: 1.1475 | Entropy: -1.9339 | Ratio: 0.3146
# New ref model saved
# New ref model: 10
# Epoch [23] 📊 acc: 0.791 | Targets: 1.1391 | Entropy: -1.9337 | Ratio: 0.3146
# New ref model saved
# New ref model: 11
# Epoch [24] 📊 acc: 0.793 | Targets: 1.1322 | Entropy: -1.9316 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
# Epoch [25] 📊 acc: 0.797 | Targets: 1.1278 | Entropy: -1.9316 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
# Epoch [26] 📊 acc: 0.800 | Targets: 1.1211 | Entropy: -1.9298 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
# Epoch [27] 📊 acc: 0.804 | Targets: 1.1137 | Entropy: -1.9288 | Ratio: 0.3146
# New ref model saved
# New ref model: 13
# Epoch [28] 📊 acc: 0.807 | Targets: 1.1082 | Entropy: -1.9278 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
# Epoch [29] 📊 acc: 0.806 | Targets: 1.1071 | Entropy: -1.9279 | Ratio: 0.3146
# New ref model: 14
# Epoch [30] 📊 acc: 0.813 | Targets: 1.0967 | Entropy: -1.9255 | Ratio: 0.3146
# New ref model saved
# New ref model: 14
#
# Evaluating at epoch 30 …
# Train Accuracy: 82.32%
# Train Average Loss: 1.1048
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 249005 (31.14%)
#   module1: 200509 (25.07%)
#   module2: 162315 (20.30%)
#   module3: 187915 (23.50%)
# Test Accuracy: 85.63%
# Test Average Loss: 1.0506
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 50050 (31.28%)
#   module1: 39334 (24.58%)
#   module2: 32510 (20.32%)
#   module3: 38106 (23.82%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 85.63%
# Epoch [31] 📊 acc: 0.814 | Targets: 1.0922 | Entropy: -1.9250 | Ratio: 0.3146
# New ref model saved
# New ref model: 15
# Epoch [32] 📊 acc: 0.817 | Targets: 1.0894 | Entropy: -1.9240 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [33] 📊 acc: 0.822 | Targets: 1.0829 | Entropy: -1.9238 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [34] 📊 acc: 0.824 | Targets: 1.0789 | Entropy: -1.9229 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [35] 📊 acc: 0.822 | Targets: 1.0792 | Entropy: -1.9234 | Ratio: 0.3146
# New ref model: 1
# Epoch [36] 📊 acc: 0.830 | Targets: 1.0685 | Entropy: -1.9207 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [37] 📊 acc: 0.829 | Targets: 1.0677 | Entropy: -1.9212 | Ratio: 0.3146
# New ref model: 2
# Epoch [38] 📊 acc: 0.827 | Targets: 1.0687 | Entropy: -1.9218 | Ratio: 0.3146
# New ref model: 2
# Epoch [39] 📊 acc: 0.831 | Targets: 1.0600 | Entropy: -1.9197 | Ratio: 0.3146
# New ref model saved
# New ref model: 3
# Epoch [40] 📊 acc: 0.834 | Targets: 1.0589 | Entropy: -1.9195 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 40 …
# Train Accuracy: 84.00%
# Train Average Loss: 1.0545
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 244239 (30.54%)
#   module1: 196025 (24.51%)
#   module2: 162764 (20.35%)
#   module3: 196716 (24.60%)
# Test Accuracy: 87.53%
# Test Average Loss: 0.9940
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 49545 (30.97%)
#   module1: 39028 (24.39%)
#   module2: 32739 (20.46%)
#   module3: 38688 (24.18%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 87.53%
# Epoch [41] 📊 acc: 0.837 | Targets: 1.0531 | Entropy: -1.9180 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
# Epoch [42] 📊 acc: 0.837 | Targets: 1.0515 | Entropy: -1.9183 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
# Epoch [43] 📊 acc: 0.839 | Targets: 1.0453 | Entropy: -1.9162 | Ratio: 0.3146
# New ref model saved
# New ref model: 5
# Epoch [44] 📊 acc: 0.841 | Targets: 1.0429 | Entropy: -1.9162 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
# Epoch [45] 📊 acc: 0.842 | Targets: 1.0426 | Entropy: -1.9167 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [46] 📊 acc: 0.844 | Targets: 1.0378 | Entropy: -1.9150 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [47] 📊 acc: 0.847 | Targets: 1.0337 | Entropy: -1.9141 | Ratio: 0.3146
# New ref model saved
# New ref model: 7
# Epoch [48] 📊 acc: 0.850 | Targets: 1.0304 | Entropy: -1.9133 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [49] 📊 acc: 0.849 | Targets: 1.0275 | Entropy: -1.9129 | Ratio: 0.3146
# New ref model: 8
# Epoch [50] 📊 acc: 0.850 | Targets: 1.0262 | Entropy: -1.9127 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 50 …
# Train Accuracy: 85.50%
# Train Average Loss: 1.0086
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 247286 (30.92%)
#   module1: 192728 (24.10%)
#   module2: 162452 (20.31%)
#   module3: 197278 (24.67%)
# Test Accuracy: 88.38%
# Test Average Loss: 0.9632
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 49739 (31.09%)
#   module1: 37893 (23.68%)
#   module2: 32969 (20.61%)
#   module3: 39399 (24.62%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.33e-04
# New best model saved with test accuracy: 88.38%
# Epoch [51] 📊 acc: 0.852 | Targets: 1.0234 | Entropy: -1.9124 | Ratio: 0.3146
# New ref model saved
# New ref model: 9
# Epoch [52] 📊 acc: 0.849 | Targets: 1.0281 | Entropy: -1.9136 | Ratio: 0.3146
# New ref model: 8
# Epoch [53] 📊 acc: 0.855 | Targets: 1.0171 | Entropy: -1.9107 | Ratio: 0.3146
# New ref model saved
# New ref model: 10
# Epoch [54] 📊 acc: 0.856 | Targets: 1.0166 | Entropy: -1.9102 | Ratio: 0.3146
# New ref model saved
# New ref model: 10
# Epoch [55] 📊 acc: 0.858 | Targets: 1.0148 | Entropy: -1.9104 | Ratio: 0.3146
# New ref model saved
# New ref model: 11
# Epoch [56] 📊 acc: 0.858 | Targets: 1.0116 | Entropy: -1.9094 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
# Epoch [57] 📊 acc: 0.860 | Targets: 1.0087 | Entropy: -1.9087 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
# Epoch [58] 📊 acc: 0.862 | Targets: 1.0054 | Entropy: -1.9081 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
# Epoch [59] 📊 acc: 0.862 | Targets: 1.0059 | Entropy: -1.9082 | Ratio: 0.3146
# New ref model: 13
# Epoch [60] 📊 acc: 0.864 | Targets: 1.0000 | Entropy: -1.9066 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
#
# Evaluating at epoch 60 …
# Train Accuracy: 86.84%
# Train Average Loss: 0.9894
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 248880 (31.12%)
#   module1: 194787 (24.36%)
#   module2: 163908 (20.50%)
#   module3: 192169 (24.03%)
# Test Accuracy: 89.65%
# Test Average Loss: 0.9465
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 49832 (31.15%)
#   module1: 38186 (23.87%)
#   module2: 33264 (20.79%)
#   module3: 38718 (24.20%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 89.65%
# Epoch [61] 📊 acc: 0.862 | Targets: 1.0035 | Entropy: -1.9080 | Ratio: 0.3146
# New ref model: 14
# Epoch [62] 📊 acc: 0.864 | Targets: 0.9992 | Entropy: -1.9069 | Ratio: 0.3146
# New ref model saved
# New ref model: 14
# Epoch [63] 📊 acc: 0.867 | Targets: 0.9959 | Entropy: -1.9058 | Ratio: 0.3146
# New ref model saved
# New ref model: 15
# Epoch [64] 📊 acc: 0.868 | Targets: 0.9935 | Entropy: -1.9053 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [65] 📊 acc: 0.871 | Targets: 0.9900 | Entropy: -1.9047 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [66] 📊 acc: 0.869 | Targets: 0.9910 | Entropy: -1.9047 | Ratio: 0.3146
# New ref model: 0
# Epoch [67] 📊 acc: 0.871 | Targets: 0.9885 | Entropy: -1.9047 | Ratio: 0.3146
# New ref model saved
# New ref model: 1
# Epoch [68] 📊 acc: 0.871 | Targets: 0.9875 | Entropy: -1.9042 | Ratio: 0.3146
# New ref model: 0
# Epoch [69] 📊 acc: 0.873 | Targets: 0.9827 | Entropy: -1.9028 | Ratio: 0.3146
# New ref model saved
# New ref model: 2
# Epoch [70] 📊 acc: 0.874 | Targets: 0.9809 | Entropy: -1.9025 | Ratio: 0.3146
# New ref model saved
# New ref model: 2
#
# Evaluating at epoch 70 …
# Train Accuracy: 87.75%
# Train Average Loss: 0.9829
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 246894 (30.87%)
#   module1: 196149 (24.53%)
#   module2: 161796 (20.23%)
#   module3: 194905 (24.37%)
# Test Accuracy: 90.25%
# Test Average Loss: 0.9403
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 49000 (30.63%)
#   module1: 38702 (24.19%)
#   module2: 33109 (20.69%)
#   module3: 39189 (24.49%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 8.72e-04
# New best model saved with test accuracy: 90.25%
# Epoch [71] 📊 acc: 0.876 | Targets: 0.9785 | Entropy: -1.9022 | Ratio: 0.3146
# New ref model saved
# New ref model: 3
# Epoch [72] 📊 acc: 0.877 | Targets: 0.9786 | Entropy: -1.9020 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [73] 📊 acc: 0.878 | Targets: 0.9750 | Entropy: -1.9010 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
# Epoch [74] 📊 acc: 0.877 | Targets: 0.9768 | Entropy: -1.9017 | Ratio: 0.3146
# New ref model: 4
# Epoch [75] 📊 acc: 0.880 | Targets: 0.9732 | Entropy: -1.9007 | Ratio: 0.3146
# New ref model saved
# New ref model: 5
# Epoch [76] 📊 acc: 0.878 | Targets: 0.9752 | Entropy: -1.9013 | Ratio: 0.3146
# New ref model: 4
# Epoch [77] 📊 acc: 0.880 | Targets: 0.9710 | Entropy: -1.9005 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [78] 📊 acc: 0.880 | Targets: 0.9714 | Entropy: -1.9007 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [79] 📊 acc: 0.883 | Targets: 0.9657 | Entropy: -1.8988 | Ratio: 0.3146
# New ref model saved
# New ref model: 7
# Epoch [80] 📊 acc: 0.881 | Targets: 0.9687 | Entropy: -1.9000 | Ratio: 0.3146
# New ref model: 0
#
# Evaluating at epoch 80 …
# Train Accuracy: 89.00%
# Train Average Loss: 0.9549
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 250858 (31.37%)
#   module1: 194798 (24.36%)
#   module2: 163219 (20.41%)
#   module3: 190869 (23.87%)
# Test Accuracy: 90.90%
# Test Average Loss: 0.9226
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 50059 (31.29%)
#   module1: 38563 (24.10%)
#   module2: 32850 (20.53%)
#   module3: 38528 (24.08%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 8.35e-04
# New best model saved with test accuracy: 90.90%
# Epoch [81] 📊 acc: 0.884 | Targets: 0.9649 | Entropy: -1.8988 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
# Epoch [82] 📊 acc: 0.885 | Targets: 0.9616 | Entropy: -1.8982 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
# Epoch [83] 📊 acc: 0.883 | Targets: 0.9619 | Entropy: -1.8979 | Ratio: 0.3146
# New ref model: 9
# Epoch [84] 📊 acc: 0.887 | Targets: 0.9595 | Entropy: -1.8978 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
# Epoch [85] 📊 acc: 0.886 | Targets: 0.9591 | Entropy: -1.8974 | Ratio: 0.3146
# New ref model: 10
# Epoch [86] 📊 acc: 0.887 | Targets: 0.9592 | Entropy: -1.8977 | Ratio: 0.3146
# New ref model: 10
# Epoch [87] 📊 acc: 0.887 | Targets: 0.9580 | Entropy: -1.8973 | Ratio: 0.3146
# New ref model saved
# New ref model: 11
# Epoch [88] 📊 acc: 0.891 | Targets: 0.9511 | Entropy: -1.8954 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
# Epoch [89] 📊 acc: 0.888 | Targets: 0.9545 | Entropy: -1.8965 | Ratio: 0.3146
# New ref model: 12
# Epoch [90] 📊 acc: 0.891 | Targets: 0.9496 | Entropy: -1.8949 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
#
# Evaluating at epoch 90 …
# Train Accuracy: 89.41%
# Train Average Loss: 0.9438
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 252782 (31.61%)
#   module1: 193067 (24.14%)
#   module2: 161890 (20.24%)
#   module3: 192005 (24.01%)
# Test Accuracy: 91.07%
# Test Average Loss: 0.9196
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 50407 (31.50%)
#   module1: 38208 (23.88%)
#   module2: 32743 (20.46%)
#   module3: 38642 (24.15%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 7.94e-04
# New best model saved with test accuracy: 91.07%
# Epoch [91] 📊 acc: 0.891 | Targets: 0.9516 | Entropy: -1.8957 | Ratio: 0.3146
# New ref model: 13
# Epoch [92] 📊 acc: 0.894 | Targets: 0.9468 | Entropy: -1.8943 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
# Epoch [93] 📊 acc: 0.893 | Targets: 0.9468 | Entropy: -1.8943 | Ratio: 0.3146
# New ref model: 14
# Epoch [94] 📊 acc: 0.891 | Targets: 0.9497 | Entropy: -1.8952 | Ratio: 0.3146
# New ref model: 14
# Epoch [95] 📊 acc: 0.893 | Targets: 0.9450 | Entropy: -1.8940 | Ratio: 0.3146
# New ref model: 15
# Epoch [96] 📊 acc: 0.893 | Targets: 0.9449 | Entropy: -1.8938 | Ratio: 0.3146
# New ref model: 0
# Epoch [97] 📊 acc: 0.895 | Targets: 0.9410 | Entropy: -1.8929 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [98] 📊 acc: 0.896 | Targets: 0.9418 | Entropy: -1.8934 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [99] 📊 acc: 0.897 | Targets: 0.9393 | Entropy: -1.8926 | Ratio: 0.3146
# New ref model saved
# New ref model: 1
# Epoch [100] 📊 acc: 0.897 | Targets: 0.9379 | Entropy: -1.8921 | Ratio: 0.3146
# New ref model: 0
#
# Evaluating at epoch 100 …
# Train Accuracy: 90.41%
# Train Average Loss: 0.9200
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 250014 (31.26%)
#   module1: 196303 (24.55%)
#   module2: 163434 (20.44%)
#   module3: 189993 (23.76%)
# Test Accuracy: 91.75%
# Test Average Loss: 0.9030
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 49883 (31.18%)
#   module1: 38996 (24.37%)
#   module2: 32682 (20.43%)
#   module3: 38439 (24.02%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 7.50e-04
# New best model saved with test accuracy: 91.75%
# Epoch [101] 📊 acc: 0.896 | Targets: 0.9398 | Entropy: -1.8928 | Ratio: 0.3146
# New ref model: 2
# Epoch [102] 📊 acc: 0.899 | Targets: 0.9352 | Entropy: -1.8919 | Ratio: 0.3146
# New ref model saved
# New ref model: 2
# Epoch [103] 📊 acc: 0.900 | Targets: 0.9352 | Entropy: -1.8917 | Ratio: 0.3146
# New ref model saved
# New ref model: 3
# Epoch [104] 📊 acc: 0.900 | Targets: 0.9330 | Entropy: -1.8915 | Ratio: 0.3146
# New ref model: 0
# Epoch [105] 📊 acc: 0.900 | Targets: 0.9326 | Entropy: -1.8910 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
# Epoch [106] 📊 acc: 0.900 | Targets: 0.9324 | Entropy: -1.8909 | Ratio: 0.3146
# New ref model: 4
# Epoch [107] 📊 acc: 0.900 | Targets: 0.9306 | Entropy: -1.8909 | Ratio: 0.3146
# New ref model: 5
# Epoch [108] 📊 acc: 0.902 | Targets: 0.9289 | Entropy: -1.8903 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
# Epoch [109] 📊 acc: 0.903 | Targets: 0.9248 | Entropy: -1.8892 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [110] 📊 acc: 0.903 | Targets: 0.9275 | Entropy: -1.8900 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
#
# Evaluating at epoch 110 …
# Train Accuracy: 90.50%
# Train Average Loss: 0.9303
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 254530 (31.83%)
#   module1: 194333 (24.30%)
#   module2: 161098 (20.14%)
#   module3: 189783 (23.73%)
# Test Accuracy: 91.54%
# Test Average Loss: 0.9141
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 50775 (31.73%)
#   module1: 38507 (24.07%)
#   module2: 32559 (20.35%)
#   module3: 38159 (23.85%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 7.04e-04
# Epoch [111] 📊 acc: 0.904 | Targets: 0.9279 | Entropy: -1.8901 | Ratio: 0.3146
# New ref model saved
# New ref model: 7
# Epoch [112] 📊 acc: 0.907 | Targets: 0.9214 | Entropy: -1.8885 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [113] 📊 acc: 0.906 | Targets: 0.9226 | Entropy: -1.8888 | Ratio: 0.3146
# New ref model: 8
# Epoch [114] 📊 acc: 0.905 | Targets: 0.9240 | Entropy: -1.8894 | Ratio: 0.3146
# New ref model: 8
# Epoch [115] 📊 acc: 0.909 | Targets: 0.9160 | Entropy: -1.8869 | Ratio: 0.3146
# New ref model saved
# New ref model: 9
# Epoch [116] 📊 acc: 0.909 | Targets: 0.9182 | Entropy: -1.8875 | Ratio: 0.3146
# New ref model: 8
# Epoch [117] 📊 acc: 0.907 | Targets: 0.9169 | Entropy: -1.8872 | Ratio: 0.3146
# New ref model: 10
# Epoch [118] 📊 acc: 0.906 | Targets: 0.9200 | Entropy: -1.8881 | Ratio: 0.3146
# New ref model: 10
# Epoch [119] 📊 acc: 0.913 | Targets: 0.9101 | Entropy: -1.8854 | Ratio: 0.3146
# New ref model saved
# New ref model: 11
# Epoch [120] 📊 acc: 0.907 | Targets: 0.9174 | Entropy: -1.8874 | Ratio: 0.3146
# New ref model: 8
#
# Evaluating at epoch 120 …
# Train Accuracy: 90.99%
# Train Average Loss: 0.9107
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 250487 (31.32%)
#   module1: 195663 (24.47%)
#   module2: 162766 (20.35%)
#   module3: 190828 (23.86%)
# Test Accuracy: 92.07%
# Test Average Loss: 0.8927
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 49335 (30.83%)
#   module1: 39225 (24.52%)
#   module2: 33469 (20.92%)
#   module3: 37971 (23.73%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 6.55e-04
# New best model saved with test accuracy: 92.07%
# Epoch [121] 📊 acc: 0.909 | Targets: 0.9156 | Entropy: -1.8871 | Ratio: 0.3146
# New ref model: 12
# Epoch [122] 📊 acc: 0.911 | Targets: 0.9139 | Entropy: -1.8869 | Ratio: 0.3146
# New ref model: 12
# Epoch [123] 📊 acc: 0.911 | Targets: 0.9106 | Entropy: -1.8859 | Ratio: 0.3146
# New ref model: 13
# Epoch [124] 📊 acc: 0.913 | Targets: 0.9104 | Entropy: -1.8857 | Ratio: 0.3146
# New ref model: 12
# Epoch [125] 📊 acc: 0.913 | Targets: 0.9102 | Entropy: -1.8857 | Ratio: 0.3146
# New ref model: 14
# Epoch [126] 📊 acc: 0.911 | Targets: 0.9119 | Entropy: -1.8863 | Ratio: 0.3146
# New ref model: 14
# Epoch [127] 📊 acc: 0.912 | Targets: 0.9100 | Entropy: -1.8855 | Ratio: 0.3146
# New ref model: 15
# Epoch [128] 📊 acc: 0.914 | Targets: 0.9057 | Entropy: -1.8847 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [129] 📊 acc: 0.912 | Targets: 0.9080 | Entropy: -1.8852 | Ratio: 0.3146
# New ref model: 0
# Epoch [130] 📊 acc: 0.915 | Targets: 0.9049 | Entropy: -1.8845 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 130 …
# Train Accuracy: 91.75%
# Train Average Loss: 0.9048
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 251858 (31.49%)
#   module1: 197449 (24.69%)
#   module2: 160180 (20.03%)
#   module3: 190257 (23.79%)
# Test Accuracy: 92.36%
# Test Average Loss: 0.8950
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 50172 (31.36%)
#   module1: 38722 (24.20%)
#   module2: 32893 (20.56%)
#   module3: 38213 (23.88%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 6.04e-04
# New best model saved with test accuracy: 92.36%
# Epoch [131] 📊 acc: 0.914 | Targets: 0.9065 | Entropy: -1.8852 | Ratio: 0.3146
# New ref model: 1
# Epoch [132] 📊 acc: 0.918 | Targets: 0.9009 | Entropy: -1.8835 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [133] 📊 acc: 0.916 | Targets: 0.9025 | Entropy: -1.8836 | Ratio: 0.3146
# New ref model: 2
# Epoch [134] 📊 acc: 0.917 | Targets: 0.9013 | Entropy: -1.8836 | Ratio: 0.3146
# New ref model: 2
# Epoch [135] 📊 acc: 0.915 | Targets: 0.9041 | Entropy: -1.8845 | Ratio: 0.3146
# New ref model: 3
# Epoch [136] 📊 acc: 0.917 | Targets: 0.9012 | Entropy: -1.8835 | Ratio: 0.3146
# New ref model: 0
# Epoch [137] 📊 acc: 0.918 | Targets: 0.8991 | Entropy: -1.8831 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
# Epoch [138] 📊 acc: 0.918 | Targets: 0.9009 | Entropy: -1.8836 | Ratio: 0.3146
# New ref model: 4
# Epoch [139] 📊 acc: 0.919 | Targets: 0.8964 | Entropy: -1.8825 | Ratio: 0.3146
# New ref model saved
# New ref model: 5
# Epoch [140] 📊 acc: 0.917 | Targets: 0.8999 | Entropy: -1.8834 | Ratio: 0.3146
# New ref model: 4
#
# Evaluating at epoch 140 …
# Train Accuracy: 91.96%
# Train Average Loss: 0.8971
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 257650 (32.22%)
#   module1: 196831 (24.61%)
#   module2: 159119 (19.90%)
#   module3: 186144 (23.28%)
# Test Accuracy: 92.36%
# Test Average Loss: 0.8860
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51047 (31.90%)
#   module1: 38897 (24.31%)
#   module2: 32403 (20.25%)
#   module3: 37653 (23.53%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 5.53e-04
# Epoch [141] 📊 acc: 0.921 | Targets: 0.8949 | Entropy: -1.8822 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [142] 📊 acc: 0.918 | Targets: 0.8976 | Entropy: -1.8826 | Ratio: 0.3146
# New ref model: 6
# Epoch [143] 📊 acc: 0.922 | Targets: 0.8920 | Entropy: -1.8811 | Ratio: 0.3146
# New ref model saved
# New ref model: 7
# Epoch [144] 📊 acc: 0.922 | Targets: 0.8929 | Entropy: -1.8818 | Ratio: 0.3146
# New ref model: 0
# Epoch [145] 📊 acc: 0.920 | Targets: 0.8937 | Entropy: -1.8816 | Ratio: 0.3146
# New ref model: 8
# Epoch [146] 📊 acc: 0.922 | Targets: 0.8930 | Entropy: -1.8817 | Ratio: 0.3146
# New ref model: 8
# Epoch [147] 📊 acc: 0.922 | Targets: 0.8918 | Entropy: -1.8813 | Ratio: 0.3146
# New ref model: 9
# Epoch [148] 📊 acc: 0.921 | Targets: 0.8911 | Entropy: -1.8809 | Ratio: 0.3146
# New ref model: 8
# Epoch [149] 📊 acc: 0.923 | Targets: 0.8883 | Entropy: -1.8806 | Ratio: 0.3146
# New ref model saved
# New ref model: 10
# Epoch [150] 📊 acc: 0.925 | Targets: 0.8855 | Entropy: -1.8796 | Ratio: 0.3146
# New ref model saved
# New ref model: 10
#
# Evaluating at epoch 150 …
# Train Accuracy: 92.19%
# Train Average Loss: 0.8892
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 257484 (32.20%)
#   module1: 193410 (24.18%)
#   module2: 159340 (19.92%)
#   module3: 189510 (23.70%)
# Test Accuracy: 92.45%
# Test Average Loss: 0.8836
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51406 (32.13%)
#   module1: 38370 (23.98%)
#   module2: 32446 (20.28%)
#   module3: 37778 (23.61%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 5.00e-04
# New best model saved with test accuracy: 92.45%
# Epoch [151] 📊 acc: 0.923 | Targets: 0.8883 | Entropy: -1.8805 | Ratio: 0.3146
# New ref model: 11
# Epoch [152] 📊 acc: 0.926 | Targets: 0.8848 | Entropy: -1.8797 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
# Epoch [153] 📊 acc: 0.926 | Targets: 0.8842 | Entropy: -1.8796 | Ratio: 0.3146
# New ref model: 12
# Epoch [154] 📊 acc: 0.926 | Targets: 0.8843 | Entropy: -1.8791 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
# Epoch [155] 📊 acc: 0.926 | Targets: 0.8839 | Entropy: -1.8795 | Ratio: 0.3146
# New ref model: 13
# Epoch [156] 📊 acc: 0.927 | Targets: 0.8824 | Entropy: -1.8791 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
# Epoch [157] 📊 acc: 0.925 | Targets: 0.8840 | Entropy: -1.8793 | Ratio: 0.3146
# New ref model: 14
# Epoch [158] 📊 acc: 0.926 | Targets: 0.8832 | Entropy: -1.8791 | Ratio: 0.3146
# New ref model: 14
# Epoch [159] 📊 acc: 0.929 | Targets: 0.8805 | Entropy: -1.8789 | Ratio: 0.3146
# New ref model saved
# New ref model: 15
# Epoch [160] 📊 acc: 0.929 | Targets: 0.8798 | Entropy: -1.8782 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 160 …
# Train Accuracy: 92.90%
# Train Average Loss: 0.8819
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 257229 (32.16%)
#   module1: 197834 (24.74%)
#   module2: 157496 (19.69%)
#   module3: 187185 (23.41%)
# Test Accuracy: 92.96%
# Test Average Loss: 0.8794
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51858 (32.41%)
#   module1: 38812 (24.26%)
#   module2: 31823 (19.89%)
#   module3: 37507 (23.44%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 4.48e-04
# New best model saved with test accuracy: 92.96%
# Epoch [161] 📊 acc: 0.926 | Targets: 0.8835 | Entropy: -1.8793 | Ratio: 0.3146
# New ref model: 0
# Epoch [162] 📊 acc: 0.931 | Targets: 0.8744 | Entropy: -1.8768 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [163] 📊 acc: 0.928 | Targets: 0.8792 | Entropy: -1.8784 | Ratio: 0.3146
# New ref model: 1
# Epoch [164] 📊 acc: 0.930 | Targets: 0.8760 | Entropy: -1.8773 | Ratio: 0.3146
# New ref model: 0
# Epoch [165] 📊 acc: 0.929 | Targets: 0.8773 | Entropy: -1.8777 | Ratio: 0.3146
# New ref model: 2
# Epoch [166] 📊 acc: 0.930 | Targets: 0.8770 | Entropy: -1.8775 | Ratio: 0.3146
# New ref model: 2
# Epoch [167] 📊 acc: 0.931 | Targets: 0.8735 | Entropy: -1.8768 | Ratio: 0.3146
# New ref model saved
# New ref model: 3
# Epoch [168] 📊 acc: 0.931 | Targets: 0.8756 | Entropy: -1.8773 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [169] 📊 acc: 0.933 | Targets: 0.8701 | Entropy: -1.8759 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
# Epoch [170] 📊 acc: 0.930 | Targets: 0.8738 | Entropy: -1.8770 | Ratio: 0.3146
# New ref model: 4
#
# Evaluating at epoch 170 …
# Train Accuracy: 93.35%
# Train Average Loss: 0.8726
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 256759 (32.11%)
#   module1: 197535 (24.70%)
#   module2: 157677 (19.72%)
#   module3: 187773 (23.48%)
# Test Accuracy: 93.52%
# Test Average Loss: 0.8697
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51346 (32.09%)
#   module1: 38592 (24.12%)
#   module2: 32399 (20.25%)
#   module3: 37663 (23.54%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 3.97e-04
# New best model saved with test accuracy: 93.52%
# Epoch [171] 📊 acc: 0.932 | Targets: 0.8742 | Entropy: -1.8769 | Ratio: 0.3146
# New ref model: 5
# Epoch [172] 📊 acc: 0.932 | Targets: 0.8727 | Entropy: -1.8770 | Ratio: 0.3146
# New ref model: 4
# Epoch [173] 📊 acc: 0.931 | Targets: 0.8737 | Entropy: -1.8769 | Ratio: 0.3146
# New ref model: 6
# Epoch [174] 📊 acc: 0.935 | Targets: 0.8677 | Entropy: -1.8753 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [175] 📊 acc: 0.934 | Targets: 0.8671 | Entropy: -1.8750 | Ratio: 0.3146
# New ref model: 7
# Epoch [176] 📊 acc: 0.935 | Targets: 0.8676 | Entropy: -1.8754 | Ratio: 0.3146
# New ref model: 0
# Epoch [177] 📊 acc: 0.934 | Targets: 0.8660 | Entropy: -1.8747 | Ratio: 0.3146
# New ref model: 8
# Epoch [178] 📊 acc: 0.934 | Targets: 0.8677 | Entropy: -1.8755 | Ratio: 0.3146
# New ref model: 8
# Epoch [179] 📊 acc: 0.936 | Targets: 0.8648 | Entropy: -1.8748 | Ratio: 0.3146
# New ref model saved
# New ref model: 9
# Epoch [180] 📊 acc: 0.936 | Targets: 0.8653 | Entropy: -1.8746 | Ratio: 0.3146
# New ref model: 8
#
# Evaluating at epoch 180 …
# Train Accuracy: 93.73%
# Train Average Loss: 0.8628
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 256911 (32.12%)
#   module1: 195729 (24.47%)
#   module2: 159331 (19.92%)
#   module3: 187773 (23.48%)
# Test Accuracy: 93.46%
# Test Average Loss: 0.8646
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51563 (32.23%)
#   module1: 38243 (23.90%)
#   module2: 32466 (20.29%)
#   module3: 37728 (23.58%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 3.46e-04
# Epoch [181] 📊 acc: 0.937 | Targets: 0.8642 | Entropy: -1.8746 | Ratio: 0.3146
# New ref model saved
# New ref model: 10
# Epoch [182] 📊 acc: 0.936 | Targets: 0.8644 | Entropy: -1.8746 | Ratio: 0.3146
# New ref model: 10
# Epoch [183] 📊 acc: 0.936 | Targets: 0.8646 | Entropy: -1.8749 | Ratio: 0.3146
# New ref model: 11
# Epoch [184] 📊 acc: 0.937 | Targets: 0.8634 | Entropy: -1.8745 | Ratio: 0.3146
# New ref model: 8
# Epoch [185] 📊 acc: 0.938 | Targets: 0.8618 | Entropy: -1.8741 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
# Epoch [186] 📊 acc: 0.938 | Targets: 0.8612 | Entropy: -1.8737 | Ratio: 0.3146
# New ref model: 12
# Epoch [187] 📊 acc: 0.939 | Targets: 0.8604 | Entropy: -1.8736 | Ratio: 0.3146
# New ref model saved
# New ref model: 13
# Epoch [188] 📊 acc: 0.939 | Targets: 0.8601 | Entropy: -1.8735 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
# Epoch [189] 📊 acc: 0.940 | Targets: 0.8598 | Entropy: -1.8733 | Ratio: 0.3146
# New ref model saved
# New ref model: 14
# Epoch [190] 📊 acc: 0.940 | Targets: 0.8577 | Entropy: -1.8727 | Ratio: 0.3146
# New ref model: 14
#
# Evaluating at epoch 190 …
# Train Accuracy: 93.80%
# Train Average Loss: 0.8591
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 255226 (31.91%)
#   module1: 195918 (24.50%)
#   module2: 158807 (19.86%)
#   module3: 189793 (23.73%)
# Test Accuracy: 93.09%
# Test Average Loss: 0.8682
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51527 (32.20%)
#   module1: 38544 (24.09%)
#   module2: 32417 (20.26%)
#   module3: 37512 (23.44%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 2.97e-04
# Epoch [191] 📊 acc: 0.939 | Targets: 0.8583 | Entropy: -1.8732 | Ratio: 0.3146
# New ref model: 15
# Epoch [192] 📊 acc: 0.939 | Targets: 0.8590 | Entropy: -1.8732 | Ratio: 0.3146
# New ref model: 0
# Epoch [193] 📊 acc: 0.940 | Targets: 0.8579 | Entropy: -1.8729 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [194] 📊 acc: 0.940 | Targets: 0.8571 | Entropy: -1.8726 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [195] 📊 acc: 0.940 | Targets: 0.8576 | Entropy: -1.8732 | Ratio: 0.3146
# New ref model saved
# New ref model: 1
# Epoch [196] 📊 acc: 0.940 | Targets: 0.8554 | Entropy: -1.8722 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [197] 📊 acc: 0.943 | Targets: 0.8522 | Entropy: -1.8714 | Ratio: 0.3146
# New ref model saved
# New ref model: 2
# Epoch [198] 📊 acc: 0.942 | Targets: 0.8533 | Entropy: -1.8718 | Ratio: 0.3146
# New ref model: 2
# Epoch [199] 📊 acc: 0.942 | Targets: 0.8513 | Entropy: -1.8713 | Ratio: 0.3146
# New ref model: 3
# Epoch [200] 📊 acc: 0.941 | Targets: 0.8533 | Entropy: -1.8718 | Ratio: 0.3146
# New ref model: 0
#
# Evaluating at epoch 200 …
# Train Accuracy: 94.43%
# Train Average Loss: 0.8481
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 255630 (31.96%)
#   module1: 194746 (24.35%)
#   module2: 158677 (19.84%)
#   module3: 190691 (23.84%)
# Test Accuracy: 93.37%
# Test Average Loss: 0.8550
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51546 (32.22%)
#   module1: 38451 (24.03%)
#   module2: 32086 (20.05%)
#   module3: 37917 (23.70%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 2.51e-04
# Epoch [201] 📊 acc: 0.943 | Targets: 0.8525 | Entropy: -1.8716 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
# Epoch [202] 📊 acc: 0.942 | Targets: 0.8532 | Entropy: -1.8720 | Ratio: 0.3146
# New ref model: 4
# Epoch [203] 📊 acc: 0.943 | Targets: 0.8520 | Entropy: -1.8716 | Ratio: 0.3146
# New ref model: 5
# Epoch [204] 📊 acc: 0.942 | Targets: 0.8523 | Entropy: -1.8717 | Ratio: 0.3146
# New ref model: 4
# Epoch [205] 📊 acc: 0.944 | Targets: 0.8503 | Entropy: -1.8712 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [206] 📊 acc: 0.944 | Targets: 0.8496 | Entropy: -1.8711 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [207] 📊 acc: 0.945 | Targets: 0.8482 | Entropy: -1.8705 | Ratio: 0.3146
# New ref model saved
# New ref model: 7
# Epoch [208] 📊 acc: 0.944 | Targets: 0.8498 | Entropy: -1.8708 | Ratio: 0.3146
# New ref model: 0
# Epoch [209] 📊 acc: 0.943 | Targets: 0.8496 | Entropy: -1.8710 | Ratio: 0.3146
# New ref model: 8
# Epoch [210] 📊 acc: 0.946 | Targets: 0.8462 | Entropy: -1.8699 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 210 …
# Train Accuracy: 94.42%
# Train Average Loss: 0.8476
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 255611 (31.96%)
#   module1: 194845 (24.36%)
#   module2: 158932 (19.87%)
#   module3: 190356 (23.80%)
# Test Accuracy: 93.84%
# Test Average Loss: 0.8544
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51799 (32.37%)
#   module1: 38199 (23.87%)
#   module2: 32254 (20.16%)
#   module3: 37748 (23.59%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 2.07e-04
# New best model saved with test accuracy: 93.84%
# Epoch [211] 📊 acc: 0.946 | Targets: 0.8461 | Entropy: -1.8700 | Ratio: 0.3146
# New ref model: 9
# Epoch [212] 📊 acc: 0.944 | Targets: 0.8487 | Entropy: -1.8711 | Ratio: 0.3146
# New ref model: 8
# Epoch [213] 📊 acc: 0.945 | Targets: 0.8471 | Entropy: -1.8702 | Ratio: 0.3146
# New ref model: 10
# Epoch [214] 📊 acc: 0.945 | Targets: 0.8472 | Entropy: -1.8707 | Ratio: 0.3146
# New ref model: 10
# Epoch [215] 📊 acc: 0.945 | Targets: 0.8468 | Entropy: -1.8702 | Ratio: 0.3146
# New ref model: 11
# Epoch [216] 📊 acc: 0.947 | Targets: 0.8451 | Entropy: -1.8699 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
# Epoch [217] 📊 acc: 0.946 | Targets: 0.8455 | Entropy: -1.8702 | Ratio: 0.3146
# New ref model: 12
# Epoch [218] 📊 acc: 0.948 | Targets: 0.8434 | Entropy: -1.8694 | Ratio: 0.3146
# New ref model saved
# New ref model: 12
# Epoch [219] 📊 acc: 0.947 | Targets: 0.8430 | Entropy: -1.8693 | Ratio: 0.3146
# New ref model: 13
# Epoch [220] 📊 acc: 0.946 | Targets: 0.8447 | Entropy: -1.8697 | Ratio: 0.3146
# New ref model: 12
#
# Evaluating at epoch 220 …
# Train Accuracy: 94.68%
# Train Average Loss: 0.8411
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 255274 (31.92%)
#   module1: 195278 (24.42%)
#   module2: 159369 (19.93%)
#   module3: 189823 (23.74%)
# Test Accuracy: 93.99%
# Test Average Loss: 0.8497
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51288 (32.05%)
#   module1: 38177 (23.86%)
#   module2: 32641 (20.40%)
#   module3: 37894 (23.68%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 1.66e-04
# New best model saved with test accuracy: 93.99%
# Epoch [221] 📊 acc: 0.947 | Targets: 0.8437 | Entropy: -1.8696 | Ratio: 0.3146
# New ref model: 14
# Epoch [222] 📊 acc: 0.949 | Targets: 0.8402 | Entropy: -1.8685 | Ratio: 0.3146
# New ref model saved
# New ref model: 14
# Epoch [223] 📊 acc: 0.947 | Targets: 0.8426 | Entropy: -1.8692 | Ratio: 0.3146
# New ref model: 15
# Epoch [224] 📊 acc: 0.947 | Targets: 0.8437 | Entropy: -1.8694 | Ratio: 0.3146
# New ref model: 0
# Epoch [225] 📊 acc: 0.949 | Targets: 0.8401 | Entropy: -1.8687 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [226] 📊 acc: 0.948 | Targets: 0.8419 | Entropy: -1.8690 | Ratio: 0.3146
# New ref model: 0
# Epoch [227] 📊 acc: 0.949 | Targets: 0.8398 | Entropy: -1.8682 | Ratio: 0.3146
# New ref model saved
# New ref model: 1
# Epoch [228] 📊 acc: 0.949 | Targets: 0.8403 | Entropy: -1.8686 | Ratio: 0.3146
# New ref model: 0
# Epoch [229] 📊 acc: 0.950 | Targets: 0.8378 | Entropy: -1.8680 | Ratio: 0.3146
# New ref model saved
# New ref model: 2
# Epoch [230] 📊 acc: 0.949 | Targets: 0.8402 | Entropy: -1.8690 | Ratio: 0.3146
# New ref model: 2
#
# Evaluating at epoch 230 …
# Train Accuracy: 94.98%
# Train Average Loss: 0.8391
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 257508 (32.20%)
#   module1: 195914 (24.50%)
#   module2: 158356 (19.80%)
#   module3: 187966 (23.50%)
# Test Accuracy: 94.05%
# Test Average Loss: 0.8501
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51590 (32.24%)
#   module1: 38264 (23.92%)
#   module2: 32441 (20.28%)
#   module3: 37705 (23.57%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 1.29e-04
# New best model saved with test accuracy: 94.05%
# Epoch [231] 📊 acc: 0.949 | Targets: 0.8393 | Entropy: -1.8685 | Ratio: 0.3146
# New ref model: 3
# Epoch [232] 📊 acc: 0.949 | Targets: 0.8396 | Entropy: -1.8688 | Ratio: 0.3146
# New ref model: 0
# Epoch [233] 📊 acc: 0.949 | Targets: 0.8400 | Entropy: -1.8688 | Ratio: 0.3146
# New ref model: 4
# Epoch [234] 📊 acc: 0.950 | Targets: 0.8387 | Entropy: -1.8682 | Ratio: 0.3146
# New ref model: 4
# Epoch [235] 📊 acc: 0.950 | Targets: 0.8369 | Entropy: -1.8678 | Ratio: 0.3146
# New ref model saved
# New ref model: 5
# Epoch [236] 📊 acc: 0.950 | Targets: 0.8386 | Entropy: -1.8685 | Ratio: 0.3146
# New ref model: 4
# Epoch [237] 📊 acc: 0.953 | Targets: 0.8347 | Entropy: -1.8674 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [238] 📊 acc: 0.952 | Targets: 0.8341 | Entropy: -1.8670 | Ratio: 0.3146
# New ref model: 6
# Epoch [239] 📊 acc: 0.952 | Targets: 0.8344 | Entropy: -1.8673 | Ratio: 0.3146
# New ref model: 7
# Epoch [240] 📊 acc: 0.952 | Targets: 0.8348 | Entropy: -1.8671 | Ratio: 0.3146
# New ref model: 0
#
# Evaluating at epoch 240 …
# Train Accuracy: 95.06%
# Train Average Loss: 0.8389
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 256462 (32.07%)
#   module1: 195058 (24.39%)
#   module2: 158556 (19.83%)
#   module3: 189668 (23.72%)
# Test Accuracy: 94.01%
# Test Average Loss: 0.8541
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51387 (32.12%)
#   module1: 38585 (24.12%)
#   module2: 32319 (20.20%)
#   module3: 37709 (23.57%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.64e-05
# Epoch [241] 📊 acc: 0.951 | Targets: 0.8361 | Entropy: -1.8678 | Ratio: 0.3146
# New ref model: 8
# Epoch [242] 📊 acc: 0.952 | Targets: 0.8355 | Entropy: -1.8675 | Ratio: 0.3146
# New ref model: 8
# Epoch [243] 📊 acc: 0.952 | Targets: 0.8351 | Entropy: -1.8676 | Ratio: 0.3146
# New ref model: 9
# Epoch [244] 📊 acc: 0.952 | Targets: 0.8352 | Entropy: -1.8674 | Ratio: 0.3146
# New ref model: 8
# Epoch [245] 📊 acc: 0.953 | Targets: 0.8343 | Entropy: -1.8672 | Ratio: 0.3146
# New ref model saved
# New ref model: 10
# Epoch [246] 📊 acc: 0.953 | Targets: 0.8317 | Entropy: -1.8663 | Ratio: 0.3146
# New ref model: 10
# Epoch [247] 📊 acc: 0.952 | Targets: 0.8342 | Entropy: -1.8672 | Ratio: 0.3146
# New ref model: 11
# Epoch [248] 📊 acc: 0.954 | Targets: 0.8309 | Entropy: -1.8663 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
# Epoch [249] 📊 acc: 0.953 | Targets: 0.8330 | Entropy: -1.8670 | Ratio: 0.3146
# New ref model: 12
# Epoch [250] 📊 acc: 0.952 | Targets: 0.8344 | Entropy: -1.8674 | Ratio: 0.3146
# New ref model: 12
#
# Evaluating at epoch 250 …
# Train Accuracy: 95.36%
# Train Average Loss: 0.8310
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 256425 (32.06%)
#   module1: 196546 (24.58%)
#   module2: 157791 (19.73%)
#   module3: 188982 (23.63%)
# Test Accuracy: 94.14%
# Test Average Loss: 0.8513
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51310 (32.07%)
#   module1: 38643 (24.15%)
#   module2: 32125 (20.08%)
#   module3: 37922 (23.70%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 6.79e-05
# New best model saved with test accuracy: 94.14%
# Epoch [251] 📊 acc: 0.952 | Targets: 0.8325 | Entropy: -1.8667 | Ratio: 0.3146
# New ref model: 13
# Epoch [252] 📊 acc: 0.953 | Targets: 0.8331 | Entropy: -1.8671 | Ratio: 0.3146
# New ref model: 12
# Epoch [253] 📊 acc: 0.954 | Targets: 0.8316 | Entropy: -1.8665 | Ratio: 0.3146
# New ref model saved
# New ref model: 14
# Epoch [254] 📊 acc: 0.954 | Targets: 0.8314 | Entropy: -1.8666 | Ratio: 0.3146
# New ref model: 14
# Epoch [255] 📊 acc: 0.954 | Targets: 0.8305 | Entropy: -1.8660 | Ratio: 0.3146
# New ref model: 15
# Epoch [256] 📊 acc: 0.954 | Targets: 0.8309 | Entropy: -1.8661 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [257] 📊 acc: 0.953 | Targets: 0.8326 | Entropy: -1.8668 | Ratio: 0.3146
# New ref model: 0
# Epoch [258] 📊 acc: 0.955 | Targets: 0.8300 | Entropy: -1.8661 | Ratio: 0.3146
# New ref model saved
# New ref model: 0
# Epoch [259] 📊 acc: 0.955 | Targets: 0.8282 | Entropy: -1.8656 | Ratio: 0.3146
# New ref model saved
# New ref model: 1
# Epoch [260] 📊 acc: 0.955 | Targets: 0.8297 | Entropy: -1.8659 | Ratio: 0.3146
# New ref model: 0
#
# Evaluating at epoch 260 …
# Train Accuracy: 95.57%
# Train Average Loss: 0.8287
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 257544 (32.20%)
#   module1: 195806 (24.48%)
#   module2: 158126 (19.77%)
#   module3: 188268 (23.54%)
# Test Accuracy: 94.25%
# Test Average Loss: 0.8479
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51889 (32.43%)
#   module1: 38713 (24.20%)
#   module2: 31924 (19.95%)
#   module3: 37474 (23.42%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 4.42e-05
# New best model saved with test accuracy: 94.25%
# Epoch [261] 📊 acc: 0.953 | Targets: 0.8322 | Entropy: -1.8668 | Ratio: 0.3146
# New ref model: 2
# Epoch [262] 📊 acc: 0.953 | Targets: 0.8308 | Entropy: -1.8663 | Ratio: 0.3146
# New ref model: 2
# Epoch [263] 📊 acc: 0.955 | Targets: 0.8281 | Entropy: -1.8656 | Ratio: 0.3146
# New ref model: 3
# Epoch [264] 📊 acc: 0.955 | Targets: 0.8298 | Entropy: -1.8663 | Ratio: 0.3146
# New ref model: 0
# Epoch [265] 📊 acc: 0.955 | Targets: 0.8290 | Entropy: -1.8656 | Ratio: 0.3146
# New ref model: 4
# Epoch [266] 📊 acc: 0.955 | Targets: 0.8295 | Entropy: -1.8661 | Ratio: 0.3146
# New ref model: 4
# Epoch [267] 📊 acc: 0.955 | Targets: 0.8286 | Entropy: -1.8659 | Ratio: 0.3146
# New ref model: 5
# Epoch [268] 📊 acc: 0.954 | Targets: 0.8308 | Entropy: -1.8665 | Ratio: 0.3146
# New ref model: 4
# Epoch [269] 📊 acc: 0.956 | Targets: 0.8275 | Entropy: -1.8654 | Ratio: 0.3146
# New ref model saved
# New ref model: 6
# Epoch [270] 📊 acc: 0.955 | Targets: 0.8289 | Entropy: -1.8659 | Ratio: 0.3146
# New ref model: 6
#
# Evaluating at epoch 270 …
# Train Accuracy: 95.44%
# Train Average Loss: 0.8298
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 257125 (32.15%)
#   module1: 196096 (24.52%)
#   module2: 158635 (19.84%)
#   module3: 187888 (23.49%)
# Test Accuracy: 94.14%
# Test Average Loss: 0.8479
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51592 (32.25%)
#   module1: 38725 (24.20%)
#   module2: 32275 (20.17%)
#   module3: 37408 (23.38%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 2.54e-05
# Epoch [271] 📊 acc: 0.956 | Targets: 0.8270 | Entropy: -1.8655 | Ratio: 0.3146
# New ref model saved
# New ref model: 7
# Epoch [272] 📊 acc: 0.955 | Targets: 0.8288 | Entropy: -1.8657 | Ratio: 0.3146
# New ref model: 0
# Epoch [273] 📊 acc: 0.956 | Targets: 0.8276 | Entropy: -1.8657 | Ratio: 0.3146
# New ref model saved
# New ref model: 8
# Epoch [274] 📊 acc: 0.956 | Targets: 0.8279 | Entropy: -1.8655 | Ratio: 0.3146
# New ref model: 8
# Epoch [275] 📊 acc: 0.956 | Targets: 0.8284 | Entropy: -1.8659 | Ratio: 0.3146
# New ref model saved
# New ref model: 9
# Epoch [276] 📊 acc: 0.956 | Targets: 0.8256 | Entropy: -1.8648 | Ratio: 0.3146
# New ref model: 8
# Epoch [277] 📊 acc: 0.955 | Targets: 0.8290 | Entropy: -1.8659 | Ratio: 0.3146
# New ref model: 10
# Epoch [278] 📊 acc: 0.956 | Targets: 0.8267 | Entropy: -1.8652 | Ratio: 0.3146
# New ref model: 10
# Epoch [279] 📊 acc: 0.957 | Targets: 0.8271 | Entropy: -1.8655 | Ratio: 0.3146
# New ref model saved
# New ref model: 11
# Epoch [280] 📊 acc: 0.956 | Targets: 0.8274 | Entropy: -1.8655 | Ratio: 0.3146
# New ref model: 8
#
# Evaluating at epoch 280 …
# Train Accuracy: 95.72%
# Train Average Loss: 0.8262
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 256901 (32.12%)
#   module1: 195355 (24.43%)
#   module2: 158976 (19.88%)
#   module3: 188512 (23.57%)
# Test Accuracy: 94.47%
# Test Average Loss: 0.8445
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51661 (32.29%)
#   module1: 38917 (24.32%)
#   module2: 32246 (20.15%)
#   module3: 37176 (23.24%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 1.19e-05
# New best model saved with test accuracy: 94.47%
# Epoch [281] 📊 acc: 0.954 | Targets: 0.8298 | Entropy: -1.8662 | Ratio: 0.3146
# New ref model: 12
# Epoch [282] 📊 acc: 0.955 | Targets: 0.8284 | Entropy: -1.8659 | Ratio: 0.3146
# New ref model: 12
# Epoch [283] 📊 acc: 0.957 | Targets: 0.8263 | Entropy: -1.8656 | Ratio: 0.3146
# New ref model saved
# New ref model: 13
# Epoch [284] 📊 acc: 0.956 | Targets: 0.8265 | Entropy: -1.8652 | Ratio: 0.3146
# New ref model: 12
# Epoch [285] 📊 acc: 0.956 | Targets: 0.8284 | Entropy: -1.8655 | Ratio: 0.3146
# New ref model: 14
# Epoch [286] 📊 acc: 0.957 | Targets: 0.8268 | Entropy: -1.8656 | Ratio: 0.3146
# New ref model: 14
# Epoch [287] 📊 acc: 0.955 | Targets: 0.8290 | Entropy: -1.8656 | Ratio: 0.3146
# New ref model: 15
# Epoch [288] 📊 acc: 0.956 | Targets: 0.8279 | Entropy: -1.8657 | Ratio: 0.3146
# New ref model: 0
# Epoch [289] 📊 acc: 0.955 | Targets: 0.8279 | Entropy: -1.8656 | Ratio: 0.3146
# New ref model: 0
# Epoch [290] 📊 acc: 0.956 | Targets: 0.8280 | Entropy: -1.8662 | Ratio: 0.3146
# New ref model: 0
#
# Evaluating at epoch 290 …
# Train Accuracy: 95.69%
# Train Average Loss: 0.8261
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 256921 (32.13%)
#   module1: 195366 (24.43%)
#   module2: 159232 (19.91%)
#   module3: 188225 (23.54%)
# Test Accuracy: 94.38%
# Test Average Loss: 0.8451
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51684 (32.30%)
#   module1: 38622 (24.14%)
#   module2: 32263 (20.16%)
#   module3: 37431 (23.39%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 3.74e-06
# Epoch [291] 📊 acc: 0.955 | Targets: 0.8267 | Entropy: -1.8655 | Ratio: 0.3146
# New ref model: 1
# Epoch [292] 📊 acc: 0.957 | Targets: 0.8268 | Entropy: -1.8655 | Ratio: 0.3146
# New ref model: 0
# Epoch [293] 📊 acc: 0.957 | Targets: 0.8255 | Entropy: -1.8652 | Ratio: 0.3146
# New ref model: 2
# Epoch [294] 📊 acc: 0.956 | Targets: 0.8275 | Entropy: -1.8655 | Ratio: 0.3146
# New ref model: 2
# Epoch [295] 📊 acc: 0.956 | Targets: 0.8261 | Entropy: -1.8654 | Ratio: 0.3146
# New ref model: 3
# Epoch [296] 📊 acc: 0.957 | Targets: 0.8265 | Entropy: -1.8652 | Ratio: 0.3146
# New ref model: 0
# Epoch [297] 📊 acc: 0.955 | Targets: 0.8277 | Entropy: -1.8651 | Ratio: 0.3146
# New ref model: 4
# Epoch [298] 📊 acc: 0.956 | Targets: 0.8270 | Entropy: -1.8655 | Ratio: 0.3146
# New ref model: 4
# Epoch [299] 📊 acc: 0.956 | Targets: 0.8261 | Entropy: -1.8652 | Ratio: 0.3146
# New ref model: 5
# Epoch [300] 📊 acc: 0.957 | Targets: 0.8251 | Entropy: -1.8648 | Ratio: 0.3146
# New ref model saved
# New ref model: 4
#
# Evaluating at epoch 300 …
# Train Accuracy: 95.60%
# Train Average Loss: 0.8268
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 257035 (32.14%)
#   module1: 196852 (24.61%)
#   module2: 158798 (19.86%)
#   module3: 187059 (23.39%)
# Test Accuracy: 94.41%
# Test Average Loss: 0.8443
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 51479 (32.17%)
#   module1: 38515 (24.07%)
#   module2: 32289 (20.18%)
#   module3: 37717 (23.57%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 1.00e-06
# Finished Training
# Best test accuracy achieved: 94.47%
# Total Trainable Parameters: 1,942,286
