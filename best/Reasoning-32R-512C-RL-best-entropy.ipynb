# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth):
        out = self.conv[depth // (self.max_depth // self.num_module)](x, depth)
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            x = checkpoint(self.step_forward, x, x_prev, d, use_reentrant=False)

        return x

# %%
class RecursionAmplifyConv(nn.Module):
    def __init__(self, channels, height, width):
        super(RecursionAmplifyConv, self).__init__()
        
        self.conv0 = nn.Conv2d(3, channels, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(channels, max_depth=32, num_module=1)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))


    def forward(self, x):
        
        x = self.conv0(x)

        x = self.amconv(x)

        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.reamconv= RecursionAmplifyConv(512, 32, 32)

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.reamconv(x)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        return x

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (1 - correct)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        pre_entropy = torch.sum(pre_probs * torch.log(pre_probs), dim=1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_pre_entropy = torch.sum(old_pre_probs * torch.log(old_pre_probs), dim=1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        ref_entropy = torch.sum(ref_probs * torch.log(ref_probs), dim=1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_ref_entropy = torch.sum(old_ref_probs * torch.log(old_ref_probs), dim=1)

        rewards, correct = self.compute_positive_reward(outputs, targets)
        pre_rewards, _ = self.compute_positive_reward(pre_outputs, targets)
        ref_rewards, _ = self.compute_positive_reward(ref_outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        entropy_delta = (entropy - old_entropy)
        pre_entropy_delta = (pre_entropy - old_pre_entropy)
        ref_entropy_delta = (ref_entropy - old_ref_entropy)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
                'entropy': entropy.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)
    
    ref_count = 32
    
    select_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    select_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))

    entropy_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    entropy_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    
    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()
    all_params = list(net.parameters()) + [
        select_embeddings1, select_embeddings2,
        entropy_embeddings1, entropy_embeddings2,
    ]
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    rl_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=300, eta_min=1e-6
            )
        
        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs = net(inputs)
                ref_outputs = ref_net(inputs)
                pre_outputs = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_delta = F.tanh(select_delta) - 2 * F.sigmoid(select_embeddings1[epoch % ref_count]) * F.relu(F.tanh(pre_select_delta))
                select_delta = F.tanh(select_delta)
                select_delta = select_delta - 2 * F.sigmoid(select_embeddings2[epoch % ref_count]) * F.relu(F.tanh(ref_select_delta))
                
                select_loss = select_delta.mean()
                
                entropy_delta = F.tanh(entropy_delta) - 2 * F.sigmoid(entropy_embeddings1[epoch % ref_count]) * F.relu(F.tanh(pre_entropy_delta))
                entropy_delta = F.tanh(entropy_delta)           
                entropy_delta = entropy_delta - 2 * F.sigmoid(entropy_embeddings2[epoch % ref_count]) * F.relu(F.tanh(ref_entropy_delta))  

                entropy_loss = entropy_delta.mean()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f}")

        if running_cor > rl_accuracy:
            rl_accuracy = running_cor
            ref = copy.deepcopy(net).cpu()
            prev_ref.append(ref)
            prev_ref = prev_ref[-ref_count//2:]
            print(f"New ref model saved")
            
        r = ((epoch % (len(prev_ref) * 2) + 1) - ((epoch % (len(prev_ref) * 2) + 1) & -(epoch % (len(prev_ref) * 2) + 1))) // 2
        ref_net = copy.deepcopy(prev_ref[r]).to(device)
        pre_net = copy.deepcopy(prev_ref[0]).to(device)
        print(f"New ref model: {r}")
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
                    if use_bf16 else contextlib.nullcontext())

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = net(images)  
            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum    += batch_loss.item() * bs
            total_seen  += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 515,754

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.292 | Targets: 2.0426 | Entropy: -2.1400
# New ref model saved
# New ref model: 0
# Epoch [2] 📊 acc: 0.467 | Targets: 1.6987 | Entropy: -2.0660
# New ref model saved
# New ref model: 0
# Epoch [3] 📊 acc: 0.546 | Targets: 1.5587 | Entropy: -2.0245
# New ref model saved
# New ref model: 1
# Epoch [4] 📊 acc: 0.604 | Targets: 1.4660 | Entropy: -1.9990
# New ref model saved
# New ref model: 0
# Epoch [5] 📊 acc: 0.638 | Targets: 1.4069 | Entropy: -1.9834
# New ref model saved
# New ref model: 2
# Epoch [6] 📊 acc: 0.664 | Targets: 1.3648 | Entropy: -1.9735
# New ref model saved
# New ref model: 2
# Epoch [7] 📊 acc: 0.685 | Targets: 1.3218 | Entropy: -1.9640
# New ref model saved
# New ref model: 3
# Epoch [8] 📊 acc: 0.702 | Targets: 1.2971 | Entropy: -1.9592
# New ref model saved
# New ref model: 0
# Epoch [9] 📊 acc: 0.714 | Targets: 1.2742 | Entropy: -1.9546
# New ref model saved
# New ref model: 4
# Epoch [10] 📊 acc: 0.724 | Targets: 1.2555 | Entropy: -1.9511
# New ref model saved
# New ref model: 4
#
# Evaluating at epoch 10 …
# Train Accuracy: 73.32%
# Train Average Loss: 1.2156
# Test Accuracy: 78.77%
# Test Average Loss: 1.1095
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 78.77%
# Epoch [11] 📊 acc: 0.733 | Targets: 1.2409 | Entropy: -1.9485
# New ref model saved
# New ref model: 5
# Epoch [12] 📊 acc: 0.743 | Targets: 1.2231 | Entropy: -1.9449
# New ref model saved
# New ref model: 4
# Epoch [13] 📊 acc: 0.752 | Targets: 1.2042 | Entropy: -1.9412
# New ref model saved
# New ref model: 6
# Epoch [14] 📊 acc: 0.760 | Targets: 1.1934 | Entropy: -1.9403
# New ref model saved
# New ref model: 6
# Epoch [15] 📊 acc: 0.764 | Targets: 1.1828 | Entropy: -1.9391
# New ref model saved
# New ref model: 7
# Epoch [16] 📊 acc: 0.769 | Targets: 1.1705 | Entropy: -1.9364
# New ref model saved
# New ref model: 0
# Epoch [17] 📊 acc: 0.775 | Targets: 1.1631 | Entropy: -1.9349
# New ref model saved
# New ref model: 8
# Epoch [18] 📊 acc: 0.781 | Targets: 1.1555 | Entropy: -1.9334
# New ref model saved
# New ref model: 8
# Epoch [19] 📊 acc: 0.786 | Targets: 1.1453 | Entropy: -1.9325
# New ref model saved
# New ref model: 9
# Epoch [20] 📊 acc: 0.787 | Targets: 1.1402 | Entropy: -1.9312
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 20 …
# Train Accuracy: 79.37%
# Train Average Loss: 1.1290
# Test Accuracy: 84.68%
# Test Average Loss: 1.0248
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 84.68%
# Epoch [21] 📊 acc: 0.793 | Targets: 1.1323 | Entropy: -1.9307
# New ref model saved
# New ref model: 10
# Epoch [22] 📊 acc: 0.796 | Targets: 1.1236 | Entropy: -1.9281
# New ref model saved
# New ref model: 10
# Epoch [23] 📊 acc: 0.801 | Targets: 1.1164 | Entropy: -1.9273
# New ref model saved
# New ref model: 11
# Epoch [24] 📊 acc: 0.802 | Targets: 1.1113 | Entropy: -1.9266
# New ref model saved
# New ref model: 8
# Epoch [25] 📊 acc: 0.808 | Targets: 1.1046 | Entropy: -1.9258
# New ref model saved
# New ref model: 12
# Epoch [26] 📊 acc: 0.812 | Targets: 1.0956 | Entropy: -1.9238
# New ref model saved
# New ref model: 12
# Epoch [27] 📊 acc: 0.814 | Targets: 1.0923 | Entropy: -1.9232
# New ref model saved
# New ref model: 13
# Epoch [28] 📊 acc: 0.816 | Targets: 1.0899 | Entropy: -1.9224
# New ref model saved
# New ref model: 12
# Epoch [29] 📊 acc: 0.820 | Targets: 1.0824 | Entropy: -1.9209
# New ref model saved
# New ref model: 14
# Epoch [30] 📊 acc: 0.820 | Targets: 1.0782 | Entropy: -1.9203
# New ref model: 14
#
# Evaluating at epoch 30 …
# Train Accuracy: 82.75%
# Train Average Loss: 1.0733
# Test Accuracy: 87.09%
# Test Average Loss: 0.9878
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 87.09%
# Epoch [31] 📊 acc: 0.822 | Targets: 1.0760 | Entropy: -1.9196
# New ref model saved
# New ref model: 15
# Epoch [32] 📊 acc: 0.826 | Targets: 1.0701 | Entropy: -1.9189
# New ref model saved
# New ref model: 0
# Epoch [33] 📊 acc: 0.826 | Targets: 1.0687 | Entropy: -1.9188
# New ref model saved
# New ref model: 0
# Epoch [34] 📊 acc: 0.830 | Targets: 1.0607 | Entropy: -1.9171
# New ref model saved
# New ref model: 0
# Epoch [35] 📊 acc: 0.833 | Targets: 1.0559 | Entropy: -1.9151
# New ref model saved
# New ref model: 1
# Epoch [36] 📊 acc: 0.834 | Targets: 1.0566 | Entropy: -1.9172
# New ref model saved
# New ref model: 0
# Epoch [37] 📊 acc: 0.836 | Targets: 1.0480 | Entropy: -1.9140
# New ref model saved
# New ref model: 2
# Epoch [38] 📊 acc: 0.838 | Targets: 1.0483 | Entropy: -1.9141
# New ref model saved
# New ref model: 2
# Epoch [39] 📊 acc: 0.838 | Targets: 1.0463 | Entropy: -1.9140
# New ref model saved
# New ref model: 3
# Epoch [40] 📊 acc: 0.840 | Targets: 1.0439 | Entropy: -1.9138
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 40 …
# Train Accuracy: 85.34%
# Train Average Loss: 1.0137
# Test Accuracy: 88.78%
# Test Average Loss: 0.9433
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 88.78%
# Epoch [41] 📊 acc: 0.842 | Targets: 1.0392 | Entropy: -1.9127
# New ref model saved
# New ref model: 4
# Epoch [42] 📊 acc: 0.844 | Targets: 1.0344 | Entropy: -1.9116
# New ref model saved
# New ref model: 4
# Epoch [43] 📊 acc: 0.844 | Targets: 1.0345 | Entropy: -1.9118
# New ref model: 5
# Epoch [44] 📊 acc: 0.845 | Targets: 1.0343 | Entropy: -1.9122
# New ref model saved
# New ref model: 4
# Epoch [45] 📊 acc: 0.852 | Targets: 1.0236 | Entropy: -1.9096
# New ref model saved
# New ref model: 6
# Epoch [46] 📊 acc: 0.851 | Targets: 1.0254 | Entropy: -1.9106
# New ref model: 6
# Epoch [47] 📊 acc: 0.851 | Targets: 1.0232 | Entropy: -1.9096
# New ref model: 7
# Epoch [48] 📊 acc: 0.849 | Targets: 1.0241 | Entropy: -1.9100
# New ref model: 0
# Epoch [49] 📊 acc: 0.853 | Targets: 1.0181 | Entropy: -1.9087
# New ref model saved
# New ref model: 8
# Epoch [50] 📊 acc: 0.855 | Targets: 1.0159 | Entropy: -1.9080
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 50 …
# Train Accuracy: 85.48%
# Train Average Loss: 1.0221
# Test Accuracy: 89.26%
# Test Average Loss: 0.9577
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.33e-04
# New best model saved with test accuracy: 89.26%
# Epoch [51] 📊 acc: 0.856 | Targets: 1.0124 | Entropy: -1.9071
# New ref model saved
# New ref model: 9
# Epoch [52] 📊 acc: 0.857 | Targets: 1.0102 | Entropy: -1.9067
# New ref model saved
# New ref model: 8
# Epoch [53] 📊 acc: 0.858 | Targets: 1.0092 | Entropy: -1.9066
# New ref model saved
# New ref model: 10
# Epoch [54] 📊 acc: 0.860 | Targets: 1.0089 | Entropy: -1.9068
# New ref model saved
# New ref model: 10
# Epoch [55] 📊 acc: 0.863 | Targets: 1.0033 | Entropy: -1.9055
# New ref model saved
# New ref model: 11
# Epoch [56] 📊 acc: 0.862 | Targets: 1.0022 | Entropy: -1.9053
# New ref model: 8
# Epoch [57] 📊 acc: 0.862 | Targets: 1.0027 | Entropy: -1.9057
# New ref model: 12
# Epoch [58] 📊 acc: 0.863 | Targets: 1.0010 | Entropy: -1.9053
# New ref model saved
# New ref model: 12
# Epoch [59] 📊 acc: 0.866 | Targets: 0.9952 | Entropy: -1.9036
# New ref model saved
# New ref model: 13
# Epoch [60] 📊 acc: 0.866 | Targets: 0.9954 | Entropy: -1.9039
# New ref model saved
# New ref model: 12
#
# Evaluating at epoch 60 …
# Train Accuracy: 86.38%
# Train Average Loss: 1.0025
# Test Accuracy: 89.31%
# Test Average Loss: 0.9364
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 89.31%
# Epoch [61] 📊 acc: 0.867 | Targets: 0.9920 | Entropy: -1.9035
# New ref model saved
# New ref model: 14
# Epoch [62] 📊 acc: 0.869 | Targets: 0.9894 | Entropy: -1.9025
# New ref model saved
# New ref model: 14
# Epoch [63] 📊 acc: 0.870 | Targets: 0.9889 | Entropy: -1.9026
# New ref model saved
# New ref model: 15
# Epoch [64] 📊 acc: 0.870 | Targets: 0.9865 | Entropy: -1.9020
# New ref model: 0
# Epoch [65] 📊 acc: 0.872 | Targets: 0.9842 | Entropy: -1.9012
# New ref model saved
# New ref model: 0
# Epoch [66] 📊 acc: 0.873 | Targets: 0.9826 | Entropy: -1.9012
# New ref model saved
# New ref model: 0
# Epoch [67] 📊 acc: 0.877 | Targets: 0.9796 | Entropy: -1.9005
# New ref model saved
# New ref model: 1
# Epoch [68] 📊 acc: 0.875 | Targets: 0.9802 | Entropy: -1.9008
# New ref model: 0
# Epoch [69] 📊 acc: 0.876 | Targets: 0.9776 | Entropy: -1.9002
# New ref model: 2
# Epoch [70] 📊 acc: 0.876 | Targets: 0.9770 | Entropy: -1.8999
# New ref model: 2
#
# Evaluating at epoch 70 …
# Train Accuracy: 88.52%
# Train Average Loss: 0.9719
# Test Accuracy: 90.43%
# Test Average Loss: 0.9228
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.72e-04
# New best model saved with test accuracy: 90.43%
# Epoch [71] 📊 acc: 0.876 | Targets: 0.9768 | Entropy: -1.9000
# New ref model: 3
# Epoch [72] 📊 acc: 0.877 | Targets: 0.9736 | Entropy: -1.8991
# New ref model: 0
# Epoch [73] 📊 acc: 0.877 | Targets: 0.9715 | Entropy: -1.8986
# New ref model saved
# New ref model: 4
# Epoch [74] 📊 acc: 0.880 | Targets: 0.9699 | Entropy: -1.8982
# New ref model saved
# New ref model: 4
# Epoch [75] 📊 acc: 0.881 | Targets: 0.9678 | Entropy: -1.8978
# New ref model saved
# New ref model: 5
# Epoch [76] 📊 acc: 0.880 | Targets: 0.9682 | Entropy: -1.8978
# New ref model: 4
# Epoch [77] 📊 acc: 0.882 | Targets: 0.9655 | Entropy: -1.8978
# New ref model saved
# New ref model: 6
# Epoch [78] 📊 acc: 0.884 | Targets: 0.9615 | Entropy: -1.8962
# New ref model saved
# New ref model: 6
# Epoch [79] 📊 acc: 0.885 | Targets: 0.9606 | Entropy: -1.8963
# New ref model saved
# New ref model: 7
# Epoch [80] 📊 acc: 0.885 | Targets: 0.9604 | Entropy: -1.8965
# New ref model: 0
#
# Evaluating at epoch 80 …
# Train Accuracy: 89.44%
# Train Average Loss: 0.9557
# Test Accuracy: 91.04%
# Test Average Loss: 0.9125
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.35e-04
# New best model saved with test accuracy: 91.04%
# Epoch [81] 📊 acc: 0.885 | Targets: 0.9595 | Entropy: -1.8960
# New ref model saved
# New ref model: 8
# Epoch [82] 📊 acc: 0.887 | Targets: 0.9561 | Entropy: -1.8956
# New ref model saved
# New ref model: 8
# Epoch [83] 📊 acc: 0.888 | Targets: 0.9541 | Entropy: -1.8943
# New ref model saved
# New ref model: 9
# Epoch [84] 📊 acc: 0.888 | Targets: 0.9559 | Entropy: -1.8954
# New ref model: 8
# Epoch [85] 📊 acc: 0.889 | Targets: 0.9520 | Entropy: -1.8946
# New ref model saved
# New ref model: 10
# Epoch [86] 📊 acc: 0.889 | Targets: 0.9496 | Entropy: -1.8936
# New ref model saved
# New ref model: 10
# Epoch [87] 📊 acc: 0.888 | Targets: 0.9526 | Entropy: -1.8948
# New ref model: 11
# Epoch [88] 📊 acc: 0.893 | Targets: 0.9452 | Entropy: -1.8926
# New ref model saved
# New ref model: 8
# Epoch [89] 📊 acc: 0.892 | Targets: 0.9462 | Entropy: -1.8930
# New ref model: 12
# Epoch [90] 📊 acc: 0.891 | Targets: 0.9491 | Entropy: -1.8939
# New ref model: 12
#
# Evaluating at epoch 90 …
# Train Accuracy: 89.88%
# Train Average Loss: 0.9258
# Test Accuracy: 91.90%
# Test Average Loss: 0.8792
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.94e-04
# New best model saved with test accuracy: 91.90%
# Epoch [91] 📊 acc: 0.893 | Targets: 0.9443 | Entropy: -1.8931
# New ref model saved
# New ref model: 13
# Epoch [92] 📊 acc: 0.896 | Targets: 0.9418 | Entropy: -1.8921
# New ref model saved
# New ref model: 12
# Epoch [93] 📊 acc: 0.895 | Targets: 0.9420 | Entropy: -1.8921
# New ref model: 14
# Epoch [94] 📊 acc: 0.893 | Targets: 0.9436 | Entropy: -1.8928
# New ref model: 14
# Epoch [95] 📊 acc: 0.895 | Targets: 0.9386 | Entropy: -1.8913
# New ref model: 15
# Epoch [96] 📊 acc: 0.897 | Targets: 0.9394 | Entropy: -1.8915
# New ref model saved
# New ref model: 0
# Epoch [97] 📊 acc: 0.897 | Targets: 0.9371 | Entropy: -1.8912
# New ref model saved
# New ref model: 0
# Epoch [98] 📊 acc: 0.899 | Targets: 0.9331 | Entropy: -1.8904
# New ref model saved
# New ref model: 0
# Epoch [99] 📊 acc: 0.898 | Targets: 0.9369 | Entropy: -1.8912
# New ref model: 1
# Epoch [100] 📊 acc: 0.897 | Targets: 0.9378 | Entropy: -1.8915
# New ref model: 0
#
# Evaluating at epoch 100 …
# Train Accuracy: 89.91%
# Train Average Loss: 0.9306
# Test Accuracy: 91.87%
# Test Average Loss: 0.8883
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.50e-04
# Epoch [101] 📊 acc: 0.899 | Targets: 0.9355 | Entropy: -1.8909
# New ref model: 2
# Epoch [102] 📊 acc: 0.901 | Targets: 0.9313 | Entropy: -1.8902
# New ref model saved
# New ref model: 2
# Epoch [103] 📊 acc: 0.901 | Targets: 0.9296 | Entropy: -1.8897
# New ref model saved
# New ref model: 3
# Epoch [104] 📊 acc: 0.901 | Targets: 0.9303 | Entropy: -1.8903
# New ref model saved
# New ref model: 0
# Epoch [105] 📊 acc: 0.903 | Targets: 0.9276 | Entropy: -1.8892
# New ref model saved
# New ref model: 4
# Epoch [106] 📊 acc: 0.901 | Targets: 0.9277 | Entropy: -1.8889
# New ref model: 4
# Epoch [107] 📊 acc: 0.904 | Targets: 0.9258 | Entropy: -1.8888
# New ref model saved
# New ref model: 5
# Epoch [108] 📊 acc: 0.904 | Targets: 0.9254 | Entropy: -1.8888
# New ref model saved
# New ref model: 4
# Epoch [109] 📊 acc: 0.903 | Targets: 0.9236 | Entropy: -1.8881
# New ref model: 6
# Epoch [110] 📊 acc: 0.904 | Targets: 0.9232 | Entropy: -1.8881
# New ref model: 6
#
# Evaluating at epoch 110 …
# Train Accuracy: 91.03%
# Train Average Loss: 0.9147
# Test Accuracy: 92.14%
# Test Average Loss: 0.8865
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.04e-04
# New best model saved with test accuracy: 92.14%
# Epoch [111] 📊 acc: 0.905 | Targets: 0.9223 | Entropy: -1.8878
# New ref model saved
# New ref model: 7
# Epoch [112] 📊 acc: 0.906 | Targets: 0.9196 | Entropy: -1.8872
# New ref model saved
# New ref model: 0
# Epoch [113] 📊 acc: 0.907 | Targets: 0.9185 | Entropy: -1.8869
# New ref model saved
# New ref model: 8
# Epoch [114] 📊 acc: 0.907 | Targets: 0.9174 | Entropy: -1.8867
# New ref model saved
# New ref model: 8
# Epoch [115] 📊 acc: 0.908 | Targets: 0.9146 | Entropy: -1.8859
# New ref model saved
# New ref model: 9
# Epoch [116] 📊 acc: 0.909 | Targets: 0.9158 | Entropy: -1.8863
# New ref model saved
# New ref model: 8
# Epoch [117] 📊 acc: 0.909 | Targets: 0.9160 | Entropy: -1.8865
# New ref model saved
# New ref model: 10
# Epoch [118] 📊 acc: 0.910 | Targets: 0.9139 | Entropy: -1.8862
# New ref model saved
# New ref model: 10
# Epoch [119] 📊 acc: 0.910 | Targets: 0.9132 | Entropy: -1.8860
# New ref model saved
# New ref model: 11
# Epoch [120] 📊 acc: 0.912 | Targets: 0.9108 | Entropy: -1.8850
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 120 …
# Train Accuracy: 91.57%
# Train Average Loss: 0.9042
# Test Accuracy: 92.48%
# Test Average Loss: 0.8771
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.55e-04
# New best model saved with test accuracy: 92.48%
# Epoch [121] 📊 acc: 0.910 | Targets: 0.9125 | Entropy: -1.8859
# New ref model: 12
# Epoch [122] 📊 acc: 0.910 | Targets: 0.9126 | Entropy: -1.8857
# New ref model: 12
# Epoch [123] 📊 acc: 0.914 | Targets: 0.9053 | Entropy: -1.8840
# New ref model saved
# New ref model: 13
# Epoch [124] 📊 acc: 0.912 | Targets: 0.9083 | Entropy: -1.8846
# New ref model: 12
# Epoch [125] 📊 acc: 0.912 | Targets: 0.9073 | Entropy: -1.8844
# New ref model: 14
# Epoch [126] 📊 acc: 0.913 | Targets: 0.9070 | Entropy: -1.8845
# New ref model: 14
# Epoch [127] 📊 acc: 0.916 | Targets: 0.9031 | Entropy: -1.8831
# New ref model saved
# New ref model: 15
# Epoch [128] 📊 acc: 0.916 | Targets: 0.9025 | Entropy: -1.8835
# New ref model saved
# New ref model: 0
# Epoch [129] 📊 acc: 0.916 | Targets: 0.9029 | Entropy: -1.8831
# New ref model: 0
# Epoch [130] 📊 acc: 0.915 | Targets: 0.9058 | Entropy: -1.8844
# New ref model: 0
#
# Evaluating at epoch 130 …
# Train Accuracy: 91.99%
# Train Average Loss: 0.8963
# Test Accuracy: 92.51%
# Test Average Loss: 0.8771
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.04e-04
# New best model saved with test accuracy: 92.51%
# Epoch [131] 📊 acc: 0.917 | Targets: 0.9005 | Entropy: -1.8830
# New ref model saved
# New ref model: 1
# Epoch [132] 📊 acc: 0.916 | Targets: 0.9002 | Entropy: -1.8825
# New ref model: 0
# Epoch [133] 📊 acc: 0.919 | Targets: 0.8980 | Entropy: -1.8821
# New ref model saved
# New ref model: 2
# Epoch [134] 📊 acc: 0.918 | Targets: 0.9003 | Entropy: -1.8830
# New ref model: 2
# Epoch [135] 📊 acc: 0.917 | Targets: 0.8989 | Entropy: -1.8825
# New ref model: 3
# Epoch [136] 📊 acc: 0.918 | Targets: 0.8970 | Entropy: -1.8822
# New ref model: 0
# Epoch [137] 📊 acc: 0.919 | Targets: 0.8962 | Entropy: -1.8819
# New ref model: 4
# Epoch [138] 📊 acc: 0.920 | Targets: 0.8948 | Entropy: -1.8815
# New ref model saved
# New ref model: 4
# Epoch [139] 📊 acc: 0.921 | Targets: 0.8921 | Entropy: -1.8811
# New ref model saved
# New ref model: 5
# Epoch [140] 📊 acc: 0.919 | Targets: 0.8966 | Entropy: -1.8820
# New ref model: 4
#
# Evaluating at epoch 140 …
# Train Accuracy: 91.45%
# Train Average Loss: 0.9051
# Test Accuracy: 92.02%
# Test Average Loss: 0.8893
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.53e-04
# Epoch [141] 📊 acc: 0.920 | Targets: 0.8938 | Entropy: -1.8814
# New ref model: 6
# Epoch [142] 📊 acc: 0.921 | Targets: 0.8914 | Entropy: -1.8804
# New ref model saved
# New ref model: 6
# Epoch [143] 📊 acc: 0.921 | Targets: 0.8935 | Entropy: -1.8813
# New ref model: 7
# Epoch [144] 📊 acc: 0.922 | Targets: 0.8921 | Entropy: -1.8810
# New ref model saved
# New ref model: 0
# Epoch [145] 📊 acc: 0.923 | Targets: 0.8889 | Entropy: -1.8802
# New ref model saved
# New ref model: 8
# Epoch [146] 📊 acc: 0.923 | Targets: 0.8884 | Entropy: -1.8799
# New ref model: 8
# Epoch [147] 📊 acc: 0.924 | Targets: 0.8852 | Entropy: -1.8789
# New ref model saved
# New ref model: 9
# Epoch [148] 📊 acc: 0.923 | Targets: 0.8880 | Entropy: -1.8798
# New ref model: 8
# Epoch [149] 📊 acc: 0.924 | Targets: 0.8860 | Entropy: -1.8789
# New ref model: 10
# Epoch [150] 📊 acc: 0.924 | Targets: 0.8870 | Entropy: -1.8799
# New ref model: 10
#
# Evaluating at epoch 150 …
# Train Accuracy: 92.54%
# Train Average Loss: 0.8810
# Test Accuracy: 92.78%
# Test Average Loss: 0.8657
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.00e-04
# New best model saved with test accuracy: 92.78%
# Epoch [151] 📊 acc: 0.924 | Targets: 0.8866 | Entropy: -1.8796
# New ref model: 11
# Epoch [152] 📊 acc: 0.926 | Targets: 0.8834 | Entropy: -1.8787
# New ref model saved
# New ref model: 8
# Epoch [153] 📊 acc: 0.927 | Targets: 0.8818 | Entropy: -1.8783
# New ref model saved
# New ref model: 12
# Epoch [154] 📊 acc: 0.926 | Targets: 0.8822 | Entropy: -1.8785
# New ref model: 12
# Epoch [155] 📊 acc: 0.925 | Targets: 0.8842 | Entropy: -1.8792
# New ref model: 13
# Epoch [156] 📊 acc: 0.926 | Targets: 0.8822 | Entropy: -1.8784
# New ref model: 12
# Epoch [157] 📊 acc: 0.926 | Targets: 0.8830 | Entropy: -1.8784
# New ref model: 14
# Epoch [158] 📊 acc: 0.929 | Targets: 0.8770 | Entropy: -1.8771
# New ref model saved
# New ref model: 14
# Epoch [159] 📊 acc: 0.929 | Targets: 0.8790 | Entropy: -1.8778
# New ref model: 15
# Epoch [160] 📊 acc: 0.929 | Targets: 0.8782 | Entropy: -1.8776
# New ref model: 0
#
# Evaluating at epoch 160 …
# Train Accuracy: 93.22%
# Train Average Loss: 0.8657
# Test Accuracy: 93.24%
# Test Average Loss: 0.8577
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.48e-04
# New best model saved with test accuracy: 93.24%
# Epoch [161] 📊 acc: 0.929 | Targets: 0.8775 | Entropy: -1.8773
# New ref model saved
# New ref model: 0
# Epoch [162] 📊 acc: 0.931 | Targets: 0.8745 | Entropy: -1.8767
# New ref model saved
# New ref model: 0
# Epoch [163] 📊 acc: 0.931 | Targets: 0.8760 | Entropy: -1.8775
# New ref model saved
# New ref model: 1
# Epoch [164] 📊 acc: 0.932 | Targets: 0.8730 | Entropy: -1.8763
# New ref model saved
# New ref model: 0
# Epoch [165] 📊 acc: 0.930 | Targets: 0.8758 | Entropy: -1.8770
# New ref model: 2
# Epoch [166] 📊 acc: 0.932 | Targets: 0.8735 | Entropy: -1.8763
# New ref model: 2
# Epoch [167] 📊 acc: 0.932 | Targets: 0.8716 | Entropy: -1.8761
# New ref model: 3
# Epoch [168] 📊 acc: 0.930 | Targets: 0.8753 | Entropy: -1.8772
# New ref model: 0
# Epoch [169] 📊 acc: 0.931 | Targets: 0.8736 | Entropy: -1.8768
# New ref model: 4
# Epoch [170] 📊 acc: 0.934 | Targets: 0.8685 | Entropy: -1.8749
# New ref model saved
# New ref model: 4
#
# Evaluating at epoch 170 …
# Train Accuracy: 93.52%
# Train Average Loss: 0.8663
# Test Accuracy: 93.07%
# Test Average Loss: 0.8656
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.97e-04
# Epoch [171] 📊 acc: 0.934 | Targets: 0.8690 | Entropy: -1.8753
# New ref model saved
# New ref model: 5
# Epoch [172] 📊 acc: 0.934 | Targets: 0.8698 | Entropy: -1.8759
# New ref model: 4
# Epoch [173] 📊 acc: 0.934 | Targets: 0.8683 | Entropy: -1.8751
# New ref model saved
# New ref model: 6
# Epoch [174] 📊 acc: 0.935 | Targets: 0.8670 | Entropy: -1.8748
# New ref model saved
# New ref model: 6
# Epoch [175] 📊 acc: 0.936 | Targets: 0.8639 | Entropy: -1.8740
# New ref model saved
# New ref model: 7
# Epoch [176] 📊 acc: 0.935 | Targets: 0.8662 | Entropy: -1.8748
# New ref model: 0
# Epoch [177] 📊 acc: 0.936 | Targets: 0.8638 | Entropy: -1.8736
# New ref model: 8
# Epoch [178] 📊 acc: 0.936 | Targets: 0.8647 | Entropy: -1.8745
# New ref model saved
# New ref model: 8
# Epoch [179] 📊 acc: 0.937 | Targets: 0.8624 | Entropy: -1.8736
# New ref model saved
# New ref model: 9
# Epoch [180] 📊 acc: 0.935 | Targets: 0.8638 | Entropy: -1.8740
# New ref model: 8
#
# Evaluating at epoch 180 …
# Train Accuracy: 93.89%
# Train Average Loss: 0.8610
# Test Accuracy: 93.50%
# Test Average Loss: 0.8581
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.46e-04
# New best model saved with test accuracy: 93.50%
# Epoch [181] 📊 acc: 0.936 | Targets: 0.8628 | Entropy: -1.8737
# New ref model: 10
# Epoch [182] 📊 acc: 0.938 | Targets: 0.8621 | Entropy: -1.8738
# New ref model saved
# New ref model: 10
# Epoch [183] 📊 acc: 0.939 | Targets: 0.8599 | Entropy: -1.8730
# New ref model saved
# New ref model: 11
# Epoch [184] 📊 acc: 0.939 | Targets: 0.8605 | Entropy: -1.8735
# New ref model: 8
# Epoch [185] 📊 acc: 0.938 | Targets: 0.8604 | Entropy: -1.8735
# New ref model: 12
# Epoch [186] 📊 acc: 0.937 | Targets: 0.8620 | Entropy: -1.8738
# New ref model: 12
# Epoch [187] 📊 acc: 0.938 | Targets: 0.8585 | Entropy: -1.8726
# New ref model: 13
# Epoch [188] 📊 acc: 0.939 | Targets: 0.8576 | Entropy: -1.8725
# New ref model saved
# New ref model: 12
# Epoch [189] 📊 acc: 0.939 | Targets: 0.8561 | Entropy: -1.8722
# New ref model: 14
# Epoch [190] 📊 acc: 0.940 | Targets: 0.8559 | Entropy: -1.8721
# New ref model saved
# New ref model: 14
#
# Evaluating at epoch 190 …
# Train Accuracy: 93.99%
# Train Average Loss: 0.8536
# Test Accuracy: 93.66%
# Test Average Loss: 0.8522
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.97e-04
# New best model saved with test accuracy: 93.66%
# Epoch [191] 📊 acc: 0.940 | Targets: 0.8570 | Entropy: -1.8726
# New ref model: 15
# Epoch [192] 📊 acc: 0.940 | Targets: 0.8559 | Entropy: -1.8720
# New ref model: 0
# Epoch [193] 📊 acc: 0.941 | Targets: 0.8547 | Entropy: -1.8720
# New ref model saved
# New ref model: 0
# Epoch [194] 📊 acc: 0.941 | Targets: 0.8555 | Entropy: -1.8721
# New ref model saved
# New ref model: 0
# Epoch [195] 📊 acc: 0.942 | Targets: 0.8532 | Entropy: -1.8716
# New ref model saved
# New ref model: 1
# Epoch [196] 📊 acc: 0.943 | Targets: 0.8517 | Entropy: -1.8713
# New ref model saved
# New ref model: 0
# Epoch [197] 📊 acc: 0.943 | Targets: 0.8503 | Entropy: -1.8705
# New ref model: 2
# Epoch [198] 📊 acc: 0.942 | Targets: 0.8529 | Entropy: -1.8717
# New ref model: 2
# Epoch [199] 📊 acc: 0.943 | Targets: 0.8521 | Entropy: -1.8715
# New ref model: 3
# Epoch [200] 📊 acc: 0.943 | Targets: 0.8510 | Entropy: -1.8708
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 200 …
# Train Accuracy: 94.19%
# Train Average Loss: 0.8539
# Test Accuracy: 93.13%
# Test Average Loss: 0.8635
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.51e-04
# Epoch [201] 📊 acc: 0.942 | Targets: 0.8516 | Entropy: -1.8710
# New ref model: 4
# Epoch [202] 📊 acc: 0.944 | Targets: 0.8495 | Entropy: -1.8705
# New ref model saved
# New ref model: 4
# Epoch [203] 📊 acc: 0.944 | Targets: 0.8479 | Entropy: -1.8702
# New ref model saved
# New ref model: 5
# Epoch [204] 📊 acc: 0.945 | Targets: 0.8470 | Entropy: -1.8699
# New ref model saved
# New ref model: 4
# Epoch [205] 📊 acc: 0.947 | Targets: 0.8459 | Entropy: -1.8698
# New ref model saved
# New ref model: 6
# Epoch [206] 📊 acc: 0.946 | Targets: 0.8446 | Entropy: -1.8693
# New ref model: 6
# Epoch [207] 📊 acc: 0.946 | Targets: 0.8466 | Entropy: -1.8700
# New ref model: 7
# Epoch [208] 📊 acc: 0.944 | Targets: 0.8479 | Entropy: -1.8702
# New ref model: 0
# Epoch [209] 📊 acc: 0.947 | Targets: 0.8454 | Entropy: -1.8695
# New ref model saved
# New ref model: 8
# Epoch [210] 📊 acc: 0.947 | Targets: 0.8448 | Entropy: -1.8694
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 210 …
# Train Accuracy: 94.82%
# Train Average Loss: 0.8418
# Test Accuracy: 93.77%
# Test Average Loss: 0.8515
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.07e-04
# New best model saved with test accuracy: 93.77%
# Epoch [211] 📊 acc: 0.946 | Targets: 0.8450 | Entropy: -1.8696
# New ref model: 9
# Epoch [212] 📊 acc: 0.948 | Targets: 0.8445 | Entropy: -1.8697
# New ref model saved
# New ref model: 8
# Epoch [213] 📊 acc: 0.946 | Targets: 0.8439 | Entropy: -1.8693
# New ref model: 10
# Epoch [214] 📊 acc: 0.947 | Targets: 0.8430 | Entropy: -1.8692
# New ref model: 10
# Epoch [215] 📊 acc: 0.948 | Targets: 0.8406 | Entropy: -1.8683
# New ref model saved
# New ref model: 11
# Epoch [216] 📊 acc: 0.947 | Targets: 0.8436 | Entropy: -1.8689
# New ref model: 8
# Epoch [217] 📊 acc: 0.950 | Targets: 0.8401 | Entropy: -1.8688
# New ref model saved
# New ref model: 12
# Epoch [218] 📊 acc: 0.947 | Targets: 0.8438 | Entropy: -1.8693
# New ref model: 12
# Epoch [219] 📊 acc: 0.950 | Targets: 0.8371 | Entropy: -1.8674
# New ref model saved
# New ref model: 13
# Epoch [220] 📊 acc: 0.948 | Targets: 0.8418 | Entropy: -1.8689
# New ref model: 12
#
# Evaluating at epoch 220 …
# Train Accuracy: 94.82%
# Train Average Loss: 0.8419
# Test Accuracy: 93.68%
# Test Average Loss: 0.8531
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.66e-04
# Epoch [221] 📊 acc: 0.950 | Targets: 0.8381 | Entropy: -1.8679
# New ref model saved
# New ref model: 14
# Epoch [222] 📊 acc: 0.947 | Targets: 0.8428 | Entropy: -1.8692
# New ref model: 14
# Epoch [223] 📊 acc: 0.948 | Targets: 0.8405 | Entropy: -1.8687
# New ref model: 15
# Epoch [224] 📊 acc: 0.949 | Targets: 0.8396 | Entropy: -1.8686
# New ref model: 0
# Epoch [225] 📊 acc: 0.949 | Targets: 0.8389 | Entropy: -1.8679
# New ref model: 0
# Epoch [226] 📊 acc: 0.950 | Targets: 0.8372 | Entropy: -1.8680
# New ref model: 0
# Epoch [227] 📊 acc: 0.952 | Targets: 0.8338 | Entropy: -1.8667
# New ref model saved
# New ref model: 1
# Epoch [228] 📊 acc: 0.950 | Targets: 0.8391 | Entropy: -1.8684
# New ref model: 0
# Epoch [229] 📊 acc: 0.950 | Targets: 0.8390 | Entropy: -1.8682
# New ref model: 2
# Epoch [230] 📊 acc: 0.950 | Targets: 0.8368 | Entropy: -1.8674
# New ref model: 2
#
# Evaluating at epoch 230 …
# Train Accuracy: 95.12%
# Train Average Loss: 0.8320
# Test Accuracy: 93.67%
# Test Average Loss: 0.8487
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.29e-04
# Epoch [231] 📊 acc: 0.951 | Targets: 0.8354 | Entropy: -1.8670
# New ref model: 3
# Epoch [232] 📊 acc: 0.950 | Targets: 0.8377 | Entropy: -1.8679
# New ref model: 0
# Epoch [233] 📊 acc: 0.952 | Targets: 0.8337 | Entropy: -1.8668
# New ref model saved
# New ref model: 4
# Epoch [234] 📊 acc: 0.955 | Targets: 0.8313 | Entropy: -1.8660
# New ref model saved
# New ref model: 4
# Epoch [235] 📊 acc: 0.953 | Targets: 0.8341 | Entropy: -1.8669
# New ref model: 5
# Epoch [236] 📊 acc: 0.953 | Targets: 0.8327 | Entropy: -1.8666
# New ref model: 4
# Epoch [237] 📊 acc: 0.951 | Targets: 0.8358 | Entropy: -1.8676
# New ref model: 6
# Epoch [238] 📊 acc: 0.953 | Targets: 0.8310 | Entropy: -1.8660
# New ref model: 6
# Epoch [239] 📊 acc: 0.952 | Targets: 0.8351 | Entropy: -1.8672
# New ref model: 7
# Epoch [240] 📊 acc: 0.954 | Targets: 0.8307 | Entropy: -1.8658
# New ref model: 0
#
# Evaluating at epoch 240 …
# Train Accuracy: 95.40%
# Train Average Loss: 0.8308
# Test Accuracy: 93.94%
# Test Average Loss: 0.8500
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.64e-05
# New best model saved with test accuracy: 93.94%
# Epoch [241] 📊 acc: 0.952 | Targets: 0.8324 | Entropy: -1.8665
# New ref model: 8
# Epoch [242] 📊 acc: 0.953 | Targets: 0.8321 | Entropy: -1.8665
# New ref model: 8
# Epoch [243] 📊 acc: 0.954 | Targets: 0.8290 | Entropy: -1.8656
# New ref model: 9
# Epoch [244] 📊 acc: 0.954 | Targets: 0.8304 | Entropy: -1.8659
# New ref model: 8
# Epoch [245] 📊 acc: 0.955 | Targets: 0.8294 | Entropy: -1.8657
# New ref model saved
# New ref model: 10
# Epoch [246] 📊 acc: 0.954 | Targets: 0.8321 | Entropy: -1.8663
# New ref model: 10
# Epoch [247] 📊 acc: 0.955 | Targets: 0.8299 | Entropy: -1.8660
# New ref model: 11
# Epoch [248] 📊 acc: 0.954 | Targets: 0.8307 | Entropy: -1.8662
# New ref model: 8
# Epoch [249] 📊 acc: 0.955 | Targets: 0.8292 | Entropy: -1.8658
# New ref model: 12
# Epoch [250] 📊 acc: 0.953 | Targets: 0.8320 | Entropy: -1.8663
# New ref model: 12
#
# Evaluating at epoch 250 …
# Train Accuracy: 95.47%
# Train Average Loss: 0.8293
# Test Accuracy: 94.03%
# Test Average Loss: 0.8488
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.79e-05
# New best model saved with test accuracy: 94.03%
# Epoch [251] 📊 acc: 0.955 | Targets: 0.8292 | Entropy: -1.8657
# New ref model saved
# New ref model: 13
# Epoch [252] 📊 acc: 0.955 | Targets: 0.8291 | Entropy: -1.8655
# New ref model: 12
# Epoch [253] 📊 acc: 0.954 | Targets: 0.8309 | Entropy: -1.8663
# New ref model: 14
# Epoch [254] 📊 acc: 0.955 | Targets: 0.8288 | Entropy: -1.8656
# New ref model saved
# New ref model: 14
# Epoch [255] 📊 acc: 0.955 | Targets: 0.8300 | Entropy: -1.8659
# New ref model: 15
# Epoch [256] 📊 acc: 0.954 | Targets: 0.8283 | Entropy: -1.8656
# New ref model: 0
# Epoch [257] 📊 acc: 0.954 | Targets: 0.8296 | Entropy: -1.8657
# New ref model: 0
# Epoch [258] 📊 acc: 0.955 | Targets: 0.8289 | Entropy: -1.8658
# New ref model saved
# New ref model: 0
# Epoch [259] 📊 acc: 0.957 | Targets: 0.8243 | Entropy: -1.8646
# New ref model saved
# New ref model: 1
# Epoch [260] 📊 acc: 0.956 | Targets: 0.8260 | Entropy: -1.8650
# New ref model: 0
#
# Evaluating at epoch 260 …
# Train Accuracy: 95.71%
# Train Average Loss: 0.8266
# Test Accuracy: 93.86%
# Test Average Loss: 0.8494
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.42e-05
# Epoch [261] 📊 acc: 0.956 | Targets: 0.8282 | Entropy: -1.8656
# New ref model: 2
# Epoch [262] 📊 acc: 0.955 | Targets: 0.8275 | Entropy: -1.8655
# New ref model: 2
# Epoch [263] 📊 acc: 0.957 | Targets: 0.8264 | Entropy: -1.8650
# New ref model: 3
# Epoch [264] 📊 acc: 0.954 | Targets: 0.8306 | Entropy: -1.8662
# New ref model: 0
# Epoch [265] 📊 acc: 0.957 | Targets: 0.8251 | Entropy: -1.8647
# New ref model saved
# New ref model: 4
# Epoch [266] 📊 acc: 0.957 | Targets: 0.8267 | Entropy: -1.8653
# New ref model: 4
# Epoch [267] 📊 acc: 0.957 | Targets: 0.8245 | Entropy: -1.8643
# New ref model saved
# New ref model: 5
# Epoch [268] 📊 acc: 0.957 | Targets: 0.8250 | Entropy: -1.8648
# New ref model: 4
# Epoch [269] 📊 acc: 0.958 | Targets: 0.8239 | Entropy: -1.8643
# New ref model saved
# New ref model: 6
# Epoch [270] 📊 acc: 0.957 | Targets: 0.8253 | Entropy: -1.8645
# New ref model: 6
#
# Evaluating at epoch 270 …
# Train Accuracy: 95.71%
# Train Average Loss: 0.8245
# Test Accuracy: 94.21%
# Test Average Loss: 0.8469
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-05
# New best model saved with test accuracy: 94.21%
# Epoch [271] 📊 acc: 0.956 | Targets: 0.8258 | Entropy: -1.8646
# New ref model: 7
# Epoch [272] 📊 acc: 0.958 | Targets: 0.8235 | Entropy: -1.8640
# New ref model saved
# New ref model: 0
# Epoch [273] 📊 acc: 0.957 | Targets: 0.8242 | Entropy: -1.8643
# New ref model: 8
# Epoch [274] 📊 acc: 0.957 | Targets: 0.8251 | Entropy: -1.8646
# New ref model: 8
# Epoch [275] 📊 acc: 0.955 | Targets: 0.8272 | Entropy: -1.8653
# New ref model: 9
# Epoch [276] 📊 acc: 0.956 | Targets: 0.8267 | Entropy: -1.8651
# New ref model: 8
# Epoch [277] 📊 acc: 0.958 | Targets: 0.8225 | Entropy: -1.8639
# New ref model saved
# New ref model: 10
# Epoch [278] 📊 acc: 0.959 | Targets: 0.8209 | Entropy: -1.8636
# New ref model saved
# New ref model: 10
# Epoch [279] 📊 acc: 0.958 | Targets: 0.8224 | Entropy: -1.8639
# New ref model: 11
# Epoch [280] 📊 acc: 0.959 | Targets: 0.8223 | Entropy: -1.8637
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 280 …
# Train Accuracy: 95.88%
# Train Average Loss: 0.8226
# Test Accuracy: 94.22%
# Test Average Loss: 0.8466
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.19e-05
# New best model saved with test accuracy: 94.22%
# Epoch [281] 📊 acc: 0.957 | Targets: 0.8234 | Entropy: -1.8641
# New ref model: 12
# Epoch [282] 📊 acc: 0.958 | Targets: 0.8222 | Entropy: -1.8638
# New ref model: 12
# Epoch [283] 📊 acc: 0.957 | Targets: 0.8232 | Entropy: -1.8639
# New ref model: 13
# Epoch [284] 📊 acc: 0.957 | Targets: 0.8252 | Entropy: -1.8651
# New ref model: 12
# Epoch [285] 📊 acc: 0.957 | Targets: 0.8244 | Entropy: -1.8641
# New ref model: 14
# Epoch [286] 📊 acc: 0.958 | Targets: 0.8233 | Entropy: -1.8639
# New ref model: 14
# Epoch [287] 📊 acc: 0.957 | Targets: 0.8243 | Entropy: -1.8643
# New ref model: 15
# Epoch [288] 📊 acc: 0.958 | Targets: 0.8239 | Entropy: -1.8645
# New ref model: 0
# Epoch [289] 📊 acc: 0.957 | Targets: 0.8240 | Entropy: -1.8646
# New ref model: 0
# Epoch [290] 📊 acc: 0.958 | Targets: 0.8240 | Entropy: -1.8643
# New ref model: 0
#
# Evaluating at epoch 290 …
# Train Accuracy: 95.75%
# Train Average Loss: 0.8233
# Test Accuracy: 94.30%
# Test Average Loss: 0.8457
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.74e-06
# New best model saved with test accuracy: 94.30%
# Epoch [291] 📊 acc: 0.957 | Targets: 0.8243 | Entropy: -1.8640
# New ref model: 1
# Epoch [292] 📊 acc: 0.958 | Targets: 0.8244 | Entropy: -1.8648
# New ref model: 0
# Epoch [293] 📊 acc: 0.957 | Targets: 0.8240 | Entropy: -1.8645
# New ref model: 2
# Epoch [294] 📊 acc: 0.959 | Targets: 0.8226 | Entropy: -1.8643
# New ref model saved
# New ref model: 2
# Epoch [295] 📊 acc: 0.959 | Targets: 0.8221 | Entropy: -1.8644
# New ref model: 3
# Epoch [296] 📊 acc: 0.958 | Targets: 0.8229 | Entropy: -1.8641
# New ref model: 0
# Epoch [297] 📊 acc: 0.957 | Targets: 0.8259 | Entropy: -1.8647
# New ref model: 4
# Epoch [298] 📊 acc: 0.956 | Targets: 0.8250 | Entropy: -1.8646
# New ref model: 4
# Epoch [299] 📊 acc: 0.958 | Targets: 0.8236 | Entropy: -1.8642
# New ref model: 5
# Epoch [300] 📊 acc: 0.959 | Targets: 0.8216 | Entropy: -1.8641
# New ref model: 4
#
# Evaluating at epoch 300 …
# Train Accuracy: 95.81%
# Train Average Loss: 0.8232
# Test Accuracy: 94.28%
# Test Average Loss: 0.8458
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-06
# Finished Training
# Best test accuracy achieved: 94.30%
# Total Trainable Parameters: 515,754
