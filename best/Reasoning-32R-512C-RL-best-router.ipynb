# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class Router(nn.Module):
    def __init__(self, channels, num_module, tau=1.0, reduction_factor=4):
        super().__init__()
        self.num_module = num_module
        self.tau = tau
        reduced_channels = channels // reduction_factor
        self.conv = nn.Sequential(
            nn.ReLU(),
            nn.GroupNorm(1, channels),
            nn.Conv2d(channels, reduced_channels, kernel_size=1, bias=False),
            nn.ReLU(),
            nn.GroupNorm(1, reduced_channels),
            nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels),
            nn.ReLU(),
            nn.GroupNorm(1, reduced_channels),
            nn.Conv2d(reduced_channels, channels, kernel_size=1, bias=False),
            nn.AdaptiveAvgPool2d((1, 1)),
        )
        self.fc = nn.Linear(channels, num_module)

    def forward(self, x):
        h = self.conv(x).flatten(1)
        logits = self.fc(h)
        r = F.gumbel_softmax(logits, tau=self.tau, hard=True, dim=1)
        return r, logits

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)
        self.router = Router(channels, num_module)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth, group_ids):
        out = torch.empty_like(x)

        for i in range(self.num_module):
            idx = (group_ids == i).nonzero(as_tuple=True)[0]
            if idx.numel() == 0:
                continue
            out_i = self.conv[i](x[idx], depth).to(x.dtype)
            out[idx] = out_i
        
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        usage_per_depth = []
        
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            
            r, logits = self.router(x)
            group_ids = torch.argmax(r, dim=1)
            usage = torch.bincount(group_ids, minlength=self.num_module).detach()
            usage_per_depth.append(usage)
            
            x = checkpoint(self.step_forward, x, x_prev, d, group_ids, use_reentrant=False)

        return x, usage_per_depth

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv0 = nn.Conv2d(3, 512, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(512, max_depth=32, num_module=4)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.conv0(x)
        x, usage_per_depth = self.amconv(x)
        
        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        
        return x, usage_per_depth

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (1 - correct)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        entropy = torch.sum(probs * torch.log(probs), dim=1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_entropy = torch.sum(old_probs * torch.log(old_probs), dim=1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        pre_entropy = torch.sum(pre_probs * torch.log(pre_probs), dim=1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_pre_entropy = torch.sum(old_pre_probs * torch.log(old_pre_probs), dim=1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        ref_entropy = torch.sum(ref_probs * torch.log(ref_probs), dim=1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
            old_ref_entropy = torch.sum(old_ref_probs * torch.log(old_ref_probs), dim=1)

        rewards, correct = self.compute_positive_reward(outputs, targets)
        pre_rewards, _ = self.compute_positive_reward(pre_outputs, targets)
        ref_rewards, _ = self.compute_positive_reward(ref_outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)

        entropy_delta = (entropy - old_entropy)
        pre_entropy_delta = (pre_entropy - old_pre_entropy)
        ref_entropy_delta = (ref_entropy - old_ref_entropy)

        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
                'entropy': entropy.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL_router.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)
    
    ref_count = 16
    
    select_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    select_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))

    entropy_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    entropy_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    
    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()
    all_params = list(net.parameters()) + [
        select_embeddings1, select_embeddings2,
        entropy_embeddings1, entropy_embeddings2,
    ]
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    rl_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=epochs, eta_min=1e-6
            )
        
        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0, 'entropy': 0.0,
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs, _ = net(inputs)
                ref_outputs, _ = ref_net(inputs)
                pre_outputs, _ = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, entropy_delta, pre_entropy_delta, ref_entropy_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_delta = F.tanh(select_delta) - 2 * F.sigmoid(select_embeddings1[epoch % ref_count]) * F.relu(F.tanh(pre_select_delta))
                select_delta = F.tanh(select_delta)
                select_delta = select_delta - 2 * F.sigmoid(select_embeddings2[epoch % ref_count]) * F.relu(F.tanh(ref_select_delta))
                
                select_loss = select_delta.mean()
                
                entropy_delta = F.tanh(entropy_delta) - 2 * F.sigmoid(entropy_embeddings1[epoch % ref_count]) * F.relu(F.tanh(pre_entropy_delta))
                entropy_delta = F.tanh(entropy_delta)           
                entropy_delta = entropy_delta - 2 * F.sigmoid(entropy_embeddings2[epoch % ref_count]) * F.relu(F.tanh(ref_entropy_delta))  

                entropy_loss = entropy_delta.mean()
                
                loss = select_loss + entropy_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f} | Entropy: {avg_metrics['entropy']:.4f}")

        if running_cor > rl_accuracy:
            rl_accuracy = running_cor
            ref = copy.deepcopy(net).cpu()
            prev_ref.append(ref)
            prev_ref = prev_ref[-ref_count//2:]
            print(f"New ref model saved")
            
        r = ((epoch % (len(prev_ref) * 2) + 1) - ((epoch % (len(prev_ref) * 2) + 1) & -(epoch % (len(prev_ref) * 2) + 1))) // 2
        ref_net = copy.deepcopy(prev_ref[r]).to(device)
        pre_net = copy.deepcopy(prev_ref[0]).to(device)
        print(f"New ref model: {r}")
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (
        torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
        if use_bf16 else contextlib.nullcontext()
    )

    total_usage_per_depth = None

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

        
            outputs, usage_per_depth = net(images)

            if total_usage_per_depth is None:
                total_usage_per_depth = [
                    u.clone().to(torch.long) for u in usage_per_depth
                ]
            else:
                for d in range(len(usage_per_depth)):
                    total_usage_per_depth[d] += usage_per_depth[d].to(torch.long)

            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum += batch_loss.item() * bs
            total_seen += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if total_usage_per_depth is not None:

        max_depth_to_sum = min(16, len(total_usage_per_depth))
        summed_usage = sum(total_usage_per_depth[:max_depth_to_sum])
        summed_usage = summed_usage.cpu()

        total = summed_usage.sum().item()
        print(f"{dataset_name} Module Usage Summed Over Depth 0 to {max_depth_to_sum - 1}:")

        if total > 0:
            ratio = summed_usage.float() / total
            for i in range(len(summed_usage)):
                print(f"  module{i}: {summed_usage[i].item()} ({ratio[i].item() * 100:.2f}%)")
        else:
            for i in range(len(summed_usage)):
                print(f"  module{i}: 0 (0.00%)")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 1,942,286

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.272 | Targets: 2.0772 | Entropy: -2.1514
# New ref model saved
# New ref model: 0
# Epoch [2] 📊 acc: 0.429 | Targets: 1.7601 | Entropy: -2.0840
# New ref model saved
# New ref model: 0
# Epoch [3] 📊 acc: 0.507 | Targets: 1.6299 | Entropy: -2.0429
# New ref model saved
# New ref model: 1
# Epoch [4] 📊 acc: 0.557 | Targets: 1.5465 | Entropy: -2.0199
# New ref model saved
# New ref model: 0
# Epoch [5] 📊 acc: 0.592 | Targets: 1.4867 | Entropy: -2.0037
# New ref model saved
# New ref model: 2
# Epoch [6] 📊 acc: 0.623 | Targets: 1.4352 | Entropy: -1.9907
# New ref model saved
# New ref model: 2
# Epoch [7] 📊 acc: 0.650 | Targets: 1.3907 | Entropy: -1.9801
# New ref model saved
# New ref model: 3
# Epoch [8] 📊 acc: 0.669 | Targets: 1.3568 | Entropy: -1.9710
# New ref model saved
# New ref model: 0
# Epoch [9] 📊 acc: 0.689 | Targets: 1.3227 | Entropy: -1.9639
# New ref model saved
# New ref model: 4
# Epoch [10] 📊 acc: 0.696 | Targets: 1.3075 | Entropy: -1.9618
# New ref model saved
# New ref model: 4
#
# Evaluating at epoch 10 …
# Train Accuracy: 70.47%
# Train Average Loss: 1.3056
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 174087 (21.77%)
#   module1: 207295 (25.92%)
#   module2: 231858 (28.99%)
#   module3: 186504 (23.32%)
# Test Accuracy: 75.92%
# Test Average Loss: 1.2302
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 36188 (22.62%)
#   module1: 38914 (24.32%)
#   module2: 45277 (28.30%)
#   module3: 39621 (24.76%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 75.92%
# Epoch [11] 📊 acc: 0.708 | Targets: 1.2865 | Entropy: -1.9573
# New ref model saved
# New ref model: 5
# Epoch [12] 📊 acc: 0.718 | Targets: 1.2679 | Entropy: -1.9534
# New ref model saved
# New ref model: 4
# Epoch [13] 📊 acc: 0.728 | Targets: 1.2514 | Entropy: -1.9507
# New ref model saved
# New ref model: 6
# Epoch [14] 📊 acc: 0.738 | Targets: 1.2340 | Entropy: -1.9477
# New ref model saved
# New ref model: 6
# Epoch [15] 📊 acc: 0.746 | Targets: 1.2211 | Entropy: -1.9449
# New ref model saved
# New ref model: 7
# Epoch [16] 📊 acc: 0.751 | Targets: 1.2112 | Entropy: -1.9441
# New ref model saved
# New ref model: 0
# Epoch [17] 📊 acc: 0.756 | Targets: 1.2030 | Entropy: -1.9430
# New ref model saved
# New ref model: 0
# Epoch [18] 📊 acc: 0.760 | Targets: 1.1919 | Entropy: -1.9401
# New ref model saved
# New ref model: 0
# Epoch [19] 📊 acc: 0.768 | Targets: 1.1815 | Entropy: -1.9390
# New ref model saved
# New ref model: 1
# Epoch [20] 📊 acc: 0.772 | Targets: 1.1717 | Entropy: -1.9373
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 20 …
# Train Accuracy: 77.46%
# Train Average Loss: 1.1582
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 173097 (21.64%)
#   module1: 209907 (26.25%)
#   module2: 233658 (29.22%)
#   module3: 183082 (22.89%)
# Test Accuracy: 82.55%
# Test Average Loss: 1.0789
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 35910 (22.44%)
#   module1: 38997 (24.37%)
#   module2: 45717 (28.57%)
#   module3: 39376 (24.61%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 82.55%
# Epoch [21] 📊 acc: 0.776 | Targets: 1.1665 | Entropy: -1.9360
# New ref model saved
# New ref model: 2
# Epoch [22] 📊 acc: 0.782 | Targets: 1.1545 | Entropy: -1.9331
# New ref model saved
# New ref model: 2
# Epoch [23] 📊 acc: 0.784 | Targets: 1.1492 | Entropy: -1.9329
# New ref model saved
# New ref model: 3
# Epoch [24] 📊 acc: 0.789 | Targets: 1.1414 | Entropy: -1.9309
# New ref model saved
# New ref model: 0
# Epoch [25] 📊 acc: 0.790 | Targets: 1.1360 | Entropy: -1.9301
# New ref model saved
# New ref model: 4
# Epoch [26] 📊 acc: 0.795 | Targets: 1.1293 | Entropy: -1.9295
# New ref model saved
# New ref model: 4
# Epoch [27] 📊 acc: 0.800 | Targets: 1.1211 | Entropy: -1.9276
# New ref model saved
# New ref model: 5
# Epoch [28] 📊 acc: 0.802 | Targets: 1.1175 | Entropy: -1.9278
# New ref model saved
# New ref model: 4
# Epoch [29] 📊 acc: 0.802 | Targets: 1.1119 | Entropy: -1.9261
# New ref model saved
# New ref model: 6
# Epoch [30] 📊 acc: 0.806 | Targets: 1.1087 | Entropy: -1.9261
# New ref model saved
# New ref model: 6
#
# Evaluating at epoch 30 …
# Train Accuracy: 80.82%
# Train Average Loss: 1.1096
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 171826 (21.49%)
#   module1: 208166 (26.03%)
#   module2: 232502 (29.07%)
#   module3: 187250 (23.41%)
# Test Accuracy: 84.27%
# Test Average Loss: 1.0408
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 35638 (22.27%)
#   module1: 39009 (24.38%)
#   module2: 45554 (28.47%)
#   module3: 39799 (24.87%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 84.27%
# Epoch [31] 📊 acc: 0.809 | Targets: 1.1037 | Entropy: -1.9251
# New ref model saved
# New ref model: 7
# Epoch [32] 📊 acc: 0.812 | Targets: 1.0963 | Entropy: -1.9237
# New ref model saved
# New ref model: 0
# Epoch [33] 📊 acc: 0.813 | Targets: 1.0960 | Entropy: -1.9234
# New ref model saved
# New ref model: 0
# Epoch [34] 📊 acc: 0.819 | Targets: 1.0846 | Entropy: -1.9206
# New ref model saved
# New ref model: 0
# Epoch [35] 📊 acc: 0.817 | Targets: 1.0860 | Entropy: -1.9221
# New ref model: 1
# Epoch [36] 📊 acc: 0.821 | Targets: 1.0811 | Entropy: -1.9206
# New ref model saved
# New ref model: 0
# Epoch [37] 📊 acc: 0.820 | Targets: 1.0781 | Entropy: -1.9207
# New ref model: 2
# Epoch [38] 📊 acc: 0.825 | Targets: 1.0709 | Entropy: -1.9187
# New ref model saved
# New ref model: 2
# Epoch [39] 📊 acc: 0.828 | Targets: 1.0693 | Entropy: -1.9186
# New ref model saved
# New ref model: 3
# Epoch [40] 📊 acc: 0.830 | Targets: 1.0639 | Entropy: -1.9173
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 40 …
# Train Accuracy: 83.06%
# Train Average Loss: 1.0574
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 170671 (21.34%)
#   module1: 209480 (26.19%)
#   module2: 238230 (29.79%)
#   module3: 181363 (22.68%)
# Test Accuracy: 86.14%
# Test Average Loss: 0.9902
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 34625 (21.64%)
#   module1: 39297 (24.56%)
#   module2: 46486 (29.05%)
#   module3: 39592 (24.74%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 86.14%
# Epoch [41] 📊 acc: 0.830 | Targets: 1.0621 | Entropy: -1.9167
# New ref model: 4
# Epoch [42] 📊 acc: 0.833 | Targets: 1.0570 | Entropy: -1.9150
# New ref model saved
# New ref model: 4
# Epoch [43] 📊 acc: 0.836 | Targets: 1.0511 | Entropy: -1.9147
# New ref model saved
# New ref model: 5
# Epoch [44] 📊 acc: 0.835 | Targets: 1.0517 | Entropy: -1.9157
# New ref model: 4
# Epoch [45] 📊 acc: 0.837 | Targets: 1.0474 | Entropy: -1.9137
# New ref model saved
# New ref model: 6
# Epoch [46] 📊 acc: 0.838 | Targets: 1.0485 | Entropy: -1.9148
# New ref model saved
# New ref model: 6
# Epoch [47] 📊 acc: 0.842 | Targets: 1.0409 | Entropy: -1.9126
# New ref model saved
# New ref model: 7
# Epoch [48] 📊 acc: 0.843 | Targets: 1.0379 | Entropy: -1.9116
# New ref model saved
# New ref model: 0
# Epoch [49] 📊 acc: 0.843 | Targets: 1.0395 | Entropy: -1.9127
# New ref model saved
# New ref model: 0
# Epoch [50] 📊 acc: 0.845 | Targets: 1.0338 | Entropy: -1.9113
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 50 …
# Train Accuracy: 84.27%
# Train Average Loss: 1.0472
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 169477 (21.19%)
#   module1: 208093 (26.02%)
#   module2: 238471 (29.82%)
#   module3: 183703 (22.97%)
# Test Accuracy: 87.89%
# Test Average Loss: 0.9866
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 34964 (21.85%)
#   module1: 38510 (24.07%)
#   module2: 47363 (29.60%)
#   module3: 39163 (24.48%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.33e-04
# New best model saved with test accuracy: 87.89%
# Epoch [51] 📊 acc: 0.847 | Targets: 1.0320 | Entropy: -1.9112
# New ref model saved
# New ref model: 1
# Epoch [52] 📊 acc: 0.849 | Targets: 1.0272 | Entropy: -1.9101
# New ref model saved
# New ref model: 0
# Epoch [53] 📊 acc: 0.850 | Targets: 1.0250 | Entropy: -1.9095
# New ref model saved
# New ref model: 2
# Epoch [54] 📊 acc: 0.850 | Targets: 1.0255 | Entropy: -1.9098
# New ref model: 2
# Epoch [55] 📊 acc: 0.852 | Targets: 1.0217 | Entropy: -1.9086
# New ref model saved
# New ref model: 3
# Epoch [56] 📊 acc: 0.853 | Targets: 1.0215 | Entropy: -1.9088
# New ref model saved
# New ref model: 0
# Epoch [57] 📊 acc: 0.853 | Targets: 1.0207 | Entropy: -1.9096
# New ref model saved
# New ref model: 4
# Epoch [58] 📊 acc: 0.855 | Targets: 1.0166 | Entropy: -1.9084
# New ref model saved
# New ref model: 4
# Epoch [59] 📊 acc: 0.854 | Targets: 1.0152 | Entropy: -1.9080
# New ref model: 5
# Epoch [60] 📊 acc: 0.858 | Targets: 1.0110 | Entropy: -1.9069
# New ref model saved
# New ref model: 4
#
# Evaluating at epoch 60 …
# Train Accuracy: 86.51%
# Train Average Loss: 0.9892
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 164012 (20.51%)
#   module1: 211559 (26.45%)
#   module2: 242375 (30.31%)
#   module3: 181798 (22.73%)
# Test Accuracy: 89.49%
# Test Average Loss: 0.9215
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 33588 (20.99%)
#   module1: 39459 (24.66%)
#   module2: 47560 (29.73%)
#   module3: 39393 (24.62%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 89.49%
# Epoch [61] 📊 acc: 0.857 | Targets: 1.0113 | Entropy: -1.9076
# New ref model: 6
# Epoch [62] 📊 acc: 0.860 | Targets: 1.0074 | Entropy: -1.9061
# New ref model saved
# New ref model: 6
# Epoch [63] 📊 acc: 0.859 | Targets: 1.0072 | Entropy: -1.9064
# New ref model: 7
# Epoch [64] 📊 acc: 0.862 | Targets: 1.0020 | Entropy: -1.9053
# New ref model saved
# New ref model: 0
# Epoch [65] 📊 acc: 0.864 | Targets: 1.0009 | Entropy: -1.9049
# New ref model saved
# New ref model: 0
# Epoch [66] 📊 acc: 0.864 | Targets: 0.9992 | Entropy: -1.9044
# New ref model: 0
# Epoch [67] 📊 acc: 0.863 | Targets: 1.0012 | Entropy: -1.9050
# New ref model: 1
# Epoch [68] 📊 acc: 0.866 | Targets: 0.9969 | Entropy: -1.9042
# New ref model saved
# New ref model: 0
# Epoch [69] 📊 acc: 0.867 | Targets: 0.9928 | Entropy: -1.9030
# New ref model saved
# New ref model: 2
# Epoch [70] 📊 acc: 0.866 | Targets: 0.9958 | Entropy: -1.9042
# New ref model: 2
#
# Evaluating at epoch 70 …
# Train Accuracy: 87.12%
# Train Average Loss: 0.9849
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 168681 (21.09%)
#   module1: 210390 (26.31%)
#   module2: 241514 (30.20%)
#   module3: 179159 (22.40%)
# Test Accuracy: 89.78%
# Test Average Loss: 0.9264
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 34021 (21.26%)
#   module1: 38983 (24.36%)
#   module2: 48041 (30.03%)
#   module3: 38955 (24.35%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 8.72e-04
# New best model saved with test accuracy: 89.78%
# Epoch [71] 📊 acc: 0.868 | Targets: 0.9913 | Entropy: -1.9026
# New ref model saved
# New ref model: 3
# Epoch [72] 📊 acc: 0.870 | Targets: 0.9904 | Entropy: -1.9031
# New ref model saved
# New ref model: 0
# Epoch [73] 📊 acc: 0.870 | Targets: 0.9881 | Entropy: -1.9021
# New ref model saved
# New ref model: 4
# Epoch [74] 📊 acc: 0.871 | Targets: 0.9869 | Entropy: -1.9022
# New ref model saved
# New ref model: 4
# Epoch [75] 📊 acc: 0.872 | Targets: 0.9865 | Entropy: -1.9025
# New ref model saved
# New ref model: 5
# Epoch [76] 📊 acc: 0.873 | Targets: 0.9814 | Entropy: -1.9007
# New ref model saved
# New ref model: 4
# Epoch [77] 📊 acc: 0.876 | Targets: 0.9782 | Entropy: -1.9003
# New ref model saved
# New ref model: 6
# Epoch [78] 📊 acc: 0.875 | Targets: 0.9780 | Entropy: -1.9002
# New ref model: 6
# Epoch [79] 📊 acc: 0.875 | Targets: 0.9796 | Entropy: -1.9007
# New ref model: 7
# Epoch [80] 📊 acc: 0.879 | Targets: 0.9726 | Entropy: -1.8990
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 80 …
# Train Accuracy: 88.45%
# Train Average Loss: 0.9576
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 164848 (20.61%)
#   module1: 208941 (26.13%)
#   module2: 245311 (30.67%)
#   module3: 180644 (22.59%)
# Test Accuracy: 90.93%
# Test Average Loss: 0.9050
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 33692 (21.06%)
#   module1: 39169 (24.48%)
#   module2: 48083 (30.05%)
#   module3: 39056 (24.41%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 8.35e-04
# New best model saved with test accuracy: 90.93%
# Epoch [81] 📊 acc: 0.878 | Targets: 0.9720 | Entropy: -1.8988
# New ref model: 0
# Epoch [82] 📊 acc: 0.879 | Targets: 0.9707 | Entropy: -1.8986
# New ref model: 0
# Epoch [83] 📊 acc: 0.881 | Targets: 0.9680 | Entropy: -1.8980
# New ref model saved
# New ref model: 1
# Epoch [84] 📊 acc: 0.880 | Targets: 0.9704 | Entropy: -1.8987
# New ref model: 0
# Epoch [85] 📊 acc: 0.882 | Targets: 0.9686 | Entropy: -1.8986
# New ref model saved
# New ref model: 2
# Epoch [86] 📊 acc: 0.882 | Targets: 0.9643 | Entropy: -1.8970
# New ref model saved
# New ref model: 2
# Epoch [87] 📊 acc: 0.882 | Targets: 0.9663 | Entropy: -1.8983
# New ref model saved
# New ref model: 3
# Epoch [88] 📊 acc: 0.883 | Targets: 0.9645 | Entropy: -1.8973
# New ref model saved
# New ref model: 0
# Epoch [89] 📊 acc: 0.886 | Targets: 0.9594 | Entropy: -1.8963
# New ref model saved
# New ref model: 4
# Epoch [90] 📊 acc: 0.884 | Targets: 0.9599 | Entropy: -1.8963
# New ref model: 4
#
# Evaluating at epoch 90 …
# Train Accuracy: 88.55%
# Train Average Loss: 0.9581
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 162012 (20.26%)
#   module1: 215002 (26.88%)
#   module2: 245460 (30.69%)
#   module3: 177270 (22.17%)
# Test Accuracy: 91.34%
# Test Average Loss: 0.9066
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 33209 (20.76%)
#   module1: 40224 (25.14%)
#   module2: 48176 (30.11%)
#   module3: 38391 (23.99%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 7.94e-04
# New best model saved with test accuracy: 91.34%
# Epoch [91] 📊 acc: 0.888 | Targets: 0.9558 | Entropy: -1.8953
# New ref model saved
# New ref model: 5
# Epoch [92] 📊 acc: 0.885 | Targets: 0.9597 | Entropy: -1.8966
# New ref model: 4
# Epoch [93] 📊 acc: 0.885 | Targets: 0.9586 | Entropy: -1.8960
# New ref model: 6
# Epoch [94] 📊 acc: 0.887 | Targets: 0.9569 | Entropy: -1.8962
# New ref model: 6
# Epoch [95] 📊 acc: 0.888 | Targets: 0.9550 | Entropy: -1.8957
# New ref model: 7
# Epoch [96] 📊 acc: 0.889 | Targets: 0.9521 | Entropy: -1.8952
# New ref model saved
# New ref model: 0
# Epoch [97] 📊 acc: 0.891 | Targets: 0.9498 | Entropy: -1.8940
# New ref model saved
# New ref model: 0
# Epoch [98] 📊 acc: 0.891 | Targets: 0.9498 | Entropy: -1.8944
# New ref model: 0
# Epoch [99] 📊 acc: 0.893 | Targets: 0.9461 | Entropy: -1.8931
# New ref model saved
# New ref model: 1
# Epoch [100] 📊 acc: 0.893 | Targets: 0.9451 | Entropy: -1.8931
# New ref model: 0
#
# Evaluating at epoch 100 …
# Train Accuracy: 89.38%
# Train Average Loss: 0.9464
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 161438 (20.19%)
#   module1: 212573 (26.58%)
#   module2: 248531 (31.08%)
#   module3: 177202 (22.16%)
# Test Accuracy: 91.80%
# Test Average Loss: 0.9014
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 32892 (20.56%)
#   module1: 40098 (25.06%)
#   module2: 48654 (30.41%)
#   module3: 38356 (23.97%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 7.50e-04
# New best model saved with test accuracy: 91.80%
# Epoch [101] 📊 acc: 0.892 | Targets: 0.9473 | Entropy: -1.8938
# New ref model: 2
# Epoch [102] 📊 acc: 0.895 | Targets: 0.9426 | Entropy: -1.8926
# New ref model saved
# New ref model: 2
# Epoch [103] 📊 acc: 0.894 | Targets: 0.9439 | Entropy: -1.8931
# New ref model: 3
# Epoch [104] 📊 acc: 0.894 | Targets: 0.9440 | Entropy: -1.8932
# New ref model: 0
# Epoch [105] 📊 acc: 0.894 | Targets: 0.9419 | Entropy: -1.8925
# New ref model: 4
# Epoch [106] 📊 acc: 0.895 | Targets: 0.9407 | Entropy: -1.8924
# New ref model saved
# New ref model: 4
# Epoch [107] 📊 acc: 0.897 | Targets: 0.9400 | Entropy: -1.8922
# New ref model saved
# New ref model: 5
# Epoch [108] 📊 acc: 0.897 | Targets: 0.9371 | Entropy: -1.8916
# New ref model: 4
# Epoch [109] 📊 acc: 0.898 | Targets: 0.9353 | Entropy: -1.8910
# New ref model saved
# New ref model: 6
# Epoch [110] 📊 acc: 0.900 | Targets: 0.9335 | Entropy: -1.8904
# New ref model saved
# New ref model: 6
#
# Evaluating at epoch 110 …
# Train Accuracy: 89.98%
# Train Average Loss: 0.9366
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 156509 (19.57%)
#   module1: 214888 (26.87%)
#   module2: 252933 (31.63%)
#   module3: 175414 (21.93%)
# Test Accuracy: 91.67%
# Test Average Loss: 0.8962
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 32222 (20.14%)
#   module1: 40130 (25.08%)
#   module2: 49825 (31.14%)
#   module3: 37823 (23.64%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 7.04e-04
# Epoch [111] 📊 acc: 0.899 | Targets: 0.9343 | Entropy: -1.8908
# New ref model: 7
# Epoch [112] 📊 acc: 0.903 | Targets: 0.9290 | Entropy: -1.8896
# New ref model saved
# New ref model: 0
# Epoch [113] 📊 acc: 0.899 | Targets: 0.9333 | Entropy: -1.8907
# New ref model: 0
# Epoch [114] 📊 acc: 0.902 | Targets: 0.9296 | Entropy: -1.8893
# New ref model: 0
# Epoch [115] 📊 acc: 0.903 | Targets: 0.9287 | Entropy: -1.8897
# New ref model: 1
# Epoch [116] 📊 acc: 0.902 | Targets: 0.9279 | Entropy: -1.8894
# New ref model: 0
# Epoch [117] 📊 acc: 0.904 | Targets: 0.9260 | Entropy: -1.8891
# New ref model saved
# New ref model: 2
# Epoch [118] 📊 acc: 0.903 | Targets: 0.9252 | Entropy: -1.8884
# New ref model: 2
# Epoch [119] 📊 acc: 0.905 | Targets: 0.9243 | Entropy: -1.8886
# New ref model saved
# New ref model: 3
# Epoch [120] 📊 acc: 0.905 | Targets: 0.9226 | Entropy: -1.8878
# New ref model: 0
#
# Evaluating at epoch 120 …
# Train Accuracy: 90.17%
# Train Average Loss: 0.9285
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 155732 (19.47%)
#   module1: 211685 (26.47%)
#   module2: 248381 (31.06%)
#   module3: 183946 (23.00%)
# Test Accuracy: 91.94%
# Test Average Loss: 0.8922
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31564 (19.73%)
#   module1: 39771 (24.86%)
#   module2: 49427 (30.89%)
#   module3: 39238 (24.52%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 6.55e-04
# New best model saved with test accuracy: 91.94%
# Epoch [121] 📊 acc: 0.907 | Targets: 0.9188 | Entropy: -1.8873
# New ref model saved
# New ref model: 4
# Epoch [122] 📊 acc: 0.905 | Targets: 0.9217 | Entropy: -1.8877
# New ref model: 4
# Epoch [123] 📊 acc: 0.906 | Targets: 0.9207 | Entropy: -1.8876
# New ref model: 5
# Epoch [124] 📊 acc: 0.906 | Targets: 0.9229 | Entropy: -1.8885
# New ref model: 4
# Epoch [125] 📊 acc: 0.908 | Targets: 0.9155 | Entropy: -1.8861
# New ref model saved
# New ref model: 6
# Epoch [126] 📊 acc: 0.908 | Targets: 0.9157 | Entropy: -1.8861
# New ref model saved
# New ref model: 6
# Epoch [127] 📊 acc: 0.910 | Targets: 0.9136 | Entropy: -1.8859
# New ref model saved
# New ref model: 7
# Epoch [128] 📊 acc: 0.912 | Targets: 0.9128 | Entropy: -1.8854
# New ref model saved
# New ref model: 0
# Epoch [129] 📊 acc: 0.908 | Targets: 0.9156 | Entropy: -1.8862
# New ref model: 0
# Epoch [130] 📊 acc: 0.910 | Targets: 0.9142 | Entropy: -1.8860
# New ref model: 0
#
# Evaluating at epoch 130 …
# Train Accuracy: 91.58%
# Train Average Loss: 0.9059
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 158530 (19.82%)
#   module1: 213955 (26.75%)
#   module2: 244931 (30.63%)
#   module3: 182328 (22.80%)
# Test Accuracy: 92.45%
# Test Average Loss: 0.8806
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 32063 (20.04%)
#   module1: 40693 (25.43%)
#   module2: 49183 (30.74%)
#   module3: 38061 (23.79%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 6.04e-04
# New best model saved with test accuracy: 92.45%
# Epoch [131] 📊 acc: 0.909 | Targets: 0.9143 | Entropy: -1.8861
# New ref model: 1
# Epoch [132] 📊 acc: 0.911 | Targets: 0.9145 | Entropy: -1.8865
# New ref model: 0
# Epoch [133] 📊 acc: 0.912 | Targets: 0.9106 | Entropy: -1.8855
# New ref model saved
# New ref model: 2
# Epoch [134] 📊 acc: 0.912 | Targets: 0.9099 | Entropy: -1.8854
# New ref model: 2
# Epoch [135] 📊 acc: 0.912 | Targets: 0.9098 | Entropy: -1.8851
# New ref model saved
# New ref model: 3
# Epoch [136] 📊 acc: 0.914 | Targets: 0.9060 | Entropy: -1.8843
# New ref model saved
# New ref model: 0
# Epoch [137] 📊 acc: 0.914 | Targets: 0.9071 | Entropy: -1.8845
# New ref model saved
# New ref model: 4
# Epoch [138] 📊 acc: 0.913 | Targets: 0.9067 | Entropy: -1.8844
# New ref model: 4
# Epoch [139] 📊 acc: 0.913 | Targets: 0.9058 | Entropy: -1.8840
# New ref model: 5
# Epoch [140] 📊 acc: 0.914 | Targets: 0.9076 | Entropy: -1.8848
# New ref model: 4
#
# Evaluating at epoch 140 …
# Train Accuracy: 91.83%
# Train Average Loss: 0.8989
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 157308 (19.67%)
#   module1: 215189 (26.91%)
#   module2: 250716 (31.35%)
#   module3: 176531 (22.07%)
# Test Accuracy: 92.49%
# Test Average Loss: 0.8828
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31655 (19.78%)
#   module1: 40311 (25.19%)
#   module2: 50125 (31.33%)
#   module3: 37909 (23.69%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 5.53e-04
# New best model saved with test accuracy: 92.49%
# Epoch [141] 📊 acc: 0.916 | Targets: 0.9009 | Entropy: -1.8827
# New ref model saved
# New ref model: 6
# Epoch [142] 📊 acc: 0.917 | Targets: 0.9019 | Entropy: -1.8834
# New ref model saved
# New ref model: 6
# Epoch [143] 📊 acc: 0.917 | Targets: 0.8988 | Entropy: -1.8823
# New ref model saved
# New ref model: 7
# Epoch [144] 📊 acc: 0.916 | Targets: 0.9022 | Entropy: -1.8837
# New ref model: 0
# Epoch [145] 📊 acc: 0.916 | Targets: 0.9011 | Entropy: -1.8833
# New ref model: 0
# Epoch [146] 📊 acc: 0.917 | Targets: 0.9002 | Entropy: -1.8829
# New ref model: 0
# Epoch [147] 📊 acc: 0.919 | Targets: 0.8958 | Entropy: -1.8812
# New ref model saved
# New ref model: 1
# Epoch [148] 📊 acc: 0.921 | Targets: 0.8964 | Entropy: -1.8823
# New ref model saved
# New ref model: 0
# Epoch [149] 📊 acc: 0.919 | Targets: 0.8959 | Entropy: -1.8816
# New ref model: 2
# Epoch [150] 📊 acc: 0.919 | Targets: 0.8952 | Entropy: -1.8814
# New ref model: 2
#
# Evaluating at epoch 150 …
# Train Accuracy: 91.89%
# Train Average Loss: 0.8917
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 154547 (19.32%)
#   module1: 213438 (26.69%)
#   module2: 252043 (31.52%)
#   module3: 179716 (22.47%)
# Test Accuracy: 93.05%
# Test Average Loss: 0.8696
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31632 (19.77%)
#   module1: 40098 (25.06%)
#   module2: 49945 (31.22%)
#   module3: 38325 (23.95%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 5.00e-04
# New best model saved with test accuracy: 93.05%
# Epoch [151] 📊 acc: 0.921 | Targets: 0.8941 | Entropy: -1.8813
# New ref model: 3
# Epoch [152] 📊 acc: 0.919 | Targets: 0.8944 | Entropy: -1.8813
# New ref model: 0
# Epoch [153] 📊 acc: 0.923 | Targets: 0.8902 | Entropy: -1.8803
# New ref model saved
# New ref model: 4
# Epoch [154] 📊 acc: 0.922 | Targets: 0.8912 | Entropy: -1.8810
# New ref model: 4
# Epoch [155] 📊 acc: 0.923 | Targets: 0.8896 | Entropy: -1.8802
# New ref model saved
# New ref model: 5
# Epoch [156] 📊 acc: 0.921 | Targets: 0.8915 | Entropy: -1.8812
# New ref model: 4
# Epoch [157] 📊 acc: 0.923 | Targets: 0.8893 | Entropy: -1.8799
# New ref model: 6
# Epoch [158] 📊 acc: 0.924 | Targets: 0.8866 | Entropy: -1.8797
# New ref model saved
# New ref model: 6
# Epoch [159] 📊 acc: 0.925 | Targets: 0.8861 | Entropy: -1.8794
# New ref model saved
# New ref model: 7
# Epoch [160] 📊 acc: 0.923 | Targets: 0.8875 | Entropy: -1.8799
# New ref model: 0
#
# Evaluating at epoch 160 …
# Train Accuracy: 92.63%
# Train Average Loss: 0.8822
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 159724 (19.97%)
#   module1: 211954 (26.50%)
#   module2: 251346 (31.43%)
#   module3: 176720 (22.10%)
# Test Accuracy: 92.57%
# Test Average Loss: 0.8774
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 32277 (20.17%)
#   module1: 39798 (24.87%)
#   module2: 49938 (31.21%)
#   module3: 37987 (23.74%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 4.48e-04
# Epoch [161] 📊 acc: 0.924 | Targets: 0.8859 | Entropy: -1.8792
# New ref model: 0
# Epoch [162] 📊 acc: 0.924 | Targets: 0.8863 | Entropy: -1.8795
# New ref model: 0
# Epoch [163] 📊 acc: 0.926 | Targets: 0.8851 | Entropy: -1.8791
# New ref model saved
# New ref model: 1
# Epoch [164] 📊 acc: 0.926 | Targets: 0.8836 | Entropy: -1.8790
# New ref model saved
# New ref model: 0
# Epoch [165] 📊 acc: 0.926 | Targets: 0.8829 | Entropy: -1.8788
# New ref model: 2
# Epoch [166] 📊 acc: 0.926 | Targets: 0.8824 | Entropy: -1.8787
# New ref model: 2
# Epoch [167] 📊 acc: 0.926 | Targets: 0.8831 | Entropy: -1.8787
# New ref model: 3
# Epoch [168] 📊 acc: 0.927 | Targets: 0.8797 | Entropy: -1.8775
# New ref model saved
# New ref model: 0
# Epoch [169] 📊 acc: 0.929 | Targets: 0.8796 | Entropy: -1.8780
# New ref model saved
# New ref model: 4
# Epoch [170] 📊 acc: 0.928 | Targets: 0.8815 | Entropy: -1.8787
# New ref model: 4
#
# Evaluating at epoch 170 …
# Train Accuracy: 93.24%
# Train Average Loss: 0.8759
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 158540 (19.82%)
#   module1: 214515 (26.82%)
#   module2: 251267 (31.42%)
#   module3: 175422 (21.93%)
# Test Accuracy: 93.57%
# Test Average Loss: 0.8642
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31884 (19.93%)
#   module1: 40844 (25.53%)
#   module2: 49855 (31.16%)
#   module3: 37417 (23.39%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 3.97e-04
# New best model saved with test accuracy: 93.57%
# Epoch [171] 📊 acc: 0.929 | Targets: 0.8793 | Entropy: -1.8778
# New ref model saved
# New ref model: 5
# Epoch [172] 📊 acc: 0.928 | Targets: 0.8789 | Entropy: -1.8776
# New ref model: 4
# Epoch [173] 📊 acc: 0.930 | Targets: 0.8767 | Entropy: -1.8771
# New ref model saved
# New ref model: 6
# Epoch [174] 📊 acc: 0.930 | Targets: 0.8783 | Entropy: -1.8781
# New ref model: 6
# Epoch [175] 📊 acc: 0.932 | Targets: 0.8730 | Entropy: -1.8765
# New ref model saved
# New ref model: 7
# Epoch [176] 📊 acc: 0.929 | Targets: 0.8770 | Entropy: -1.8772
# New ref model: 0
# Epoch [177] 📊 acc: 0.929 | Targets: 0.8760 | Entropy: -1.8774
# New ref model: 0
# Epoch [178] 📊 acc: 0.931 | Targets: 0.8735 | Entropy: -1.8765
# New ref model: 0
# Epoch [179] 📊 acc: 0.931 | Targets: 0.8742 | Entropy: -1.8766
# New ref model: 1
# Epoch [180] 📊 acc: 0.932 | Targets: 0.8720 | Entropy: -1.8761
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 180 …
# Train Accuracy: 93.04%
# Train Average Loss: 0.8705
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 157912 (19.75%)
#   module1: 214033 (26.76%)
#   module2: 250034 (31.26%)
#   module3: 177765 (22.23%)
# Test Accuracy: 93.18%
# Test Average Loss: 0.8634
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31959 (19.97%)
#   module1: 40043 (25.03%)
#   module2: 50058 (31.29%)
#   module3: 37940 (23.71%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 3.46e-04
# Epoch [181] 📊 acc: 0.933 | Targets: 0.8710 | Entropy: -1.8760
# New ref model saved
# New ref model: 2
# Epoch [182] 📊 acc: 0.933 | Targets: 0.8727 | Entropy: -1.8763
# New ref model: 2
# Epoch [183] 📊 acc: 0.934 | Targets: 0.8681 | Entropy: -1.8751
# New ref model saved
# New ref model: 3
# Epoch [184] 📊 acc: 0.933 | Targets: 0.8712 | Entropy: -1.8759
# New ref model: 0
# Epoch [185] 📊 acc: 0.935 | Targets: 0.8674 | Entropy: -1.8747
# New ref model saved
# New ref model: 4
# Epoch [186] 📊 acc: 0.932 | Targets: 0.8697 | Entropy: -1.8757
# New ref model: 4
# Epoch [187] 📊 acc: 0.935 | Targets: 0.8659 | Entropy: -1.8742
# New ref model saved
# New ref model: 5
# Epoch [188] 📊 acc: 0.936 | Targets: 0.8663 | Entropy: -1.8749
# New ref model saved
# New ref model: 4
# Epoch [189] 📊 acc: 0.936 | Targets: 0.8634 | Entropy: -1.8741
# New ref model saved
# New ref model: 6
# Epoch [190] 📊 acc: 0.936 | Targets: 0.8634 | Entropy: -1.8740
# New ref model saved
# New ref model: 6
#
# Evaluating at epoch 190 …
# Train Accuracy: 93.17%
# Train Average Loss: 0.8708
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 156522 (19.57%)
#   module1: 216153 (27.03%)
#   module2: 250502 (31.32%)
#   module3: 176567 (22.08%)
# Test Accuracy: 93.38%
# Test Average Loss: 0.8625
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 32150 (20.09%)
#   module1: 40811 (25.51%)
#   module2: 49177 (30.74%)
#   module3: 37862 (23.66%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 2.97e-04
# Epoch [191] 📊 acc: 0.935 | Targets: 0.8663 | Entropy: -1.8750
# New ref model: 7
# Epoch [192] 📊 acc: 0.937 | Targets: 0.8637 | Entropy: -1.8744
# New ref model saved
# New ref model: 0
# Epoch [193] 📊 acc: 0.936 | Targets: 0.8629 | Entropy: -1.8735
# New ref model: 0
# Epoch [194] 📊 acc: 0.936 | Targets: 0.8632 | Entropy: -1.8741
# New ref model: 0
# Epoch [195] 📊 acc: 0.937 | Targets: 0.8630 | Entropy: -1.8738
# New ref model: 1
# Epoch [196] 📊 acc: 0.938 | Targets: 0.8594 | Entropy: -1.8727
# New ref model saved
# New ref model: 0
# Epoch [197] 📊 acc: 0.937 | Targets: 0.8626 | Entropy: -1.8741
# New ref model: 2
# Epoch [198] 📊 acc: 0.939 | Targets: 0.8577 | Entropy: -1.8725
# New ref model saved
# New ref model: 2
# Epoch [199] 📊 acc: 0.937 | Targets: 0.8617 | Entropy: -1.8739
# New ref model: 3
# Epoch [200] 📊 acc: 0.937 | Targets: 0.8616 | Entropy: -1.8737
# New ref model: 0
#
# Evaluating at epoch 200 …
# Train Accuracy: 93.99%
# Train Average Loss: 0.8589
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 155785 (19.48%)
#   module1: 213246 (26.66%)
#   module2: 252377 (31.56%)
#   module3: 178336 (22.30%)
# Test Accuracy: 93.83%
# Test Average Loss: 0.8610
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31490 (19.68%)
#   module1: 39776 (24.86%)
#   module2: 50536 (31.58%)
#   module3: 38198 (23.87%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 2.51e-04
# New best model saved with test accuracy: 93.83%
# Epoch [201] 📊 acc: 0.938 | Targets: 0.8608 | Entropy: -1.8736
# New ref model: 4
# Epoch [202] 📊 acc: 0.940 | Targets: 0.8558 | Entropy: -1.8720
# New ref model saved
# New ref model: 4
# Epoch [203] 📊 acc: 0.939 | Targets: 0.8573 | Entropy: -1.8721
# New ref model: 5
# Epoch [204] 📊 acc: 0.941 | Targets: 0.8552 | Entropy: -1.8723
# New ref model saved
# New ref model: 4
# Epoch [205] 📊 acc: 0.941 | Targets: 0.8549 | Entropy: -1.8719
# New ref model saved
# New ref model: 6
# Epoch [206] 📊 acc: 0.941 | Targets: 0.8534 | Entropy: -1.8715
# New ref model: 6
# Epoch [207] 📊 acc: 0.943 | Targets: 0.8524 | Entropy: -1.8712
# New ref model saved
# New ref model: 7
# Epoch [208] 📊 acc: 0.941 | Targets: 0.8545 | Entropy: -1.8719
# New ref model: 0
# Epoch [209] 📊 acc: 0.942 | Targets: 0.8530 | Entropy: -1.8713
# New ref model: 0
# Epoch [210] 📊 acc: 0.942 | Targets: 0.8534 | Entropy: -1.8718
# New ref model: 0
#
# Evaluating at epoch 210 …
# Train Accuracy: 94.31%
# Train Average Loss: 0.8479
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 156542 (19.57%)
#   module1: 213539 (26.70%)
#   module2: 251655 (31.47%)
#   module3: 178008 (22.26%)
# Test Accuracy: 93.72%
# Test Average Loss: 0.8526
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31623 (19.76%)
#   module1: 40027 (25.02%)
#   module2: 50464 (31.54%)
#   module3: 37886 (23.68%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 2.07e-04
# Epoch [211] 📊 acc: 0.941 | Targets: 0.8540 | Entropy: -1.8715
# New ref model: 1
# Epoch [212] 📊 acc: 0.941 | Targets: 0.8547 | Entropy: -1.8721
# New ref model: 0
# Epoch [213] 📊 acc: 0.942 | Targets: 0.8533 | Entropy: -1.8716
# New ref model: 2
# Epoch [214] 📊 acc: 0.943 | Targets: 0.8519 | Entropy: -1.8708
# New ref model: 2
# Epoch [215] 📊 acc: 0.942 | Targets: 0.8534 | Entropy: -1.8717
# New ref model: 3
# Epoch [216] 📊 acc: 0.944 | Targets: 0.8492 | Entropy: -1.8705
# New ref model saved
# New ref model: 0
# Epoch [217] 📊 acc: 0.943 | Targets: 0.8503 | Entropy: -1.8712
# New ref model: 4
# Epoch [218] 📊 acc: 0.944 | Targets: 0.8491 | Entropy: -1.8704
# New ref model saved
# New ref model: 4
# Epoch [219] 📊 acc: 0.943 | Targets: 0.8498 | Entropy: -1.8707
# New ref model: 5
# Epoch [220] 📊 acc: 0.944 | Targets: 0.8484 | Entropy: -1.8702
# New ref model saved
# New ref model: 4
#
# Evaluating at epoch 220 …
# Train Accuracy: 94.29%
# Train Average Loss: 0.8460
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 157674 (19.72%)
#   module1: 210001 (26.26%)
#   module2: 252647 (31.59%)
#   module3: 179422 (22.43%)
# Test Accuracy: 93.66%
# Test Average Loss: 0.8525
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31915 (19.95%)
#   module1: 39520 (24.70%)
#   module2: 50366 (31.48%)
#   module3: 38199 (23.87%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 1.66e-04
# Epoch [221] 📊 acc: 0.944 | Targets: 0.8491 | Entropy: -1.8704
# New ref model: 6
# Epoch [222] 📊 acc: 0.945 | Targets: 0.8489 | Entropy: -1.8708
# New ref model saved
# New ref model: 6
# Epoch [223] 📊 acc: 0.945 | Targets: 0.8460 | Entropy: -1.8693
# New ref model saved
# New ref model: 7
# Epoch [224] 📊 acc: 0.945 | Targets: 0.8483 | Entropy: -1.8706
# New ref model: 0
# Epoch [225] 📊 acc: 0.945 | Targets: 0.8446 | Entropy: -1.8693
# New ref model saved
# New ref model: 0
# Epoch [226] 📊 acc: 0.945 | Targets: 0.8476 | Entropy: -1.8702
# New ref model: 0
# Epoch [227] 📊 acc: 0.946 | Targets: 0.8455 | Entropy: -1.8697
# New ref model saved
# New ref model: 1
# Epoch [228] 📊 acc: 0.945 | Targets: 0.8480 | Entropy: -1.8705
# New ref model: 0
# Epoch [229] 📊 acc: 0.947 | Targets: 0.8443 | Entropy: -1.8693
# New ref model saved
# New ref model: 2
# Epoch [230] 📊 acc: 0.946 | Targets: 0.8442 | Entropy: -1.8695
# New ref model: 2
#
# Evaluating at epoch 230 …
# Train Accuracy: 94.74%
# Train Average Loss: 0.8388
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 156834 (19.61%)
#   module1: 212711 (26.60%)
#   module2: 251572 (31.46%)
#   module3: 178627 (22.34%)
# Test Accuracy: 94.02%
# Test Average Loss: 0.8478
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31789 (19.87%)
#   module1: 39964 (24.98%)
#   module2: 50288 (31.43%)
#   module3: 37959 (23.72%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 1.29e-04
# New best model saved with test accuracy: 94.02%
# Epoch [231] 📊 acc: 0.947 | Targets: 0.8453 | Entropy: -1.8696
# New ref model: 3
# Epoch [232] 📊 acc: 0.945 | Targets: 0.8464 | Entropy: -1.8699
# New ref model: 0
# Epoch [233] 📊 acc: 0.946 | Targets: 0.8460 | Entropy: -1.8699
# New ref model: 4
# Epoch [234] 📊 acc: 0.947 | Targets: 0.8440 | Entropy: -1.8696
# New ref model saved
# New ref model: 4
# Epoch [235] 📊 acc: 0.947 | Targets: 0.8445 | Entropy: -1.8694
# New ref model: 5
# Epoch [236] 📊 acc: 0.949 | Targets: 0.8415 | Entropy: -1.8689
# New ref model saved
# New ref model: 4
# Epoch [237] 📊 acc: 0.948 | Targets: 0.8410 | Entropy: -1.8686
# New ref model: 6
# Epoch [238] 📊 acc: 0.946 | Targets: 0.8443 | Entropy: -1.8696
# New ref model: 6
# Epoch [239] 📊 acc: 0.947 | Targets: 0.8444 | Entropy: -1.8694
# New ref model: 7
# Epoch [240] 📊 acc: 0.948 | Targets: 0.8415 | Entropy: -1.8689
# New ref model: 0
#
# Evaluating at epoch 240 …
# Train Accuracy: 94.92%
# Train Average Loss: 0.8413
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 156369 (19.55%)
#   module1: 212307 (26.55%)
#   module2: 251808 (31.49%)
#   module3: 179260 (22.41%)
# Test Accuracy: 94.14%
# Test Average Loss: 0.8485
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31671 (19.79%)
#   module1: 40199 (25.12%)
#   module2: 49901 (31.19%)
#   module3: 38229 (23.89%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 9.64e-05
# New best model saved with test accuracy: 94.14%
# Epoch [241] 📊 acc: 0.949 | Targets: 0.8393 | Entropy: -1.8680
# New ref model saved
# New ref model: 0
# Epoch [242] 📊 acc: 0.949 | Targets: 0.8408 | Entropy: -1.8686
# New ref model: 0
# Epoch [243] 📊 acc: 0.947 | Targets: 0.8415 | Entropy: -1.8688
# New ref model: 1
# Epoch [244] 📊 acc: 0.950 | Targets: 0.8390 | Entropy: -1.8682
# New ref model saved
# New ref model: 0
# Epoch [245] 📊 acc: 0.949 | Targets: 0.8388 | Entropy: -1.8679
# New ref model: 2
# Epoch [246] 📊 acc: 0.950 | Targets: 0.8384 | Entropy: -1.8677
# New ref model saved
# New ref model: 2
# Epoch [247] 📊 acc: 0.949 | Targets: 0.8404 | Entropy: -1.8686
# New ref model: 3
# Epoch [248] 📊 acc: 0.951 | Targets: 0.8362 | Entropy: -1.8673
# New ref model saved
# New ref model: 0
# Epoch [249] 📊 acc: 0.950 | Targets: 0.8396 | Entropy: -1.8687
# New ref model: 4
# Epoch [250] 📊 acc: 0.949 | Targets: 0.8394 | Entropy: -1.8681
# New ref model: 4
#
# Evaluating at epoch 250 …
# Train Accuracy: 95.03%
# Train Average Loss: 0.8378
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 156559 (19.58%)
#   module1: 210295 (26.30%)
#   module2: 252604 (31.59%)
#   module3: 180286 (22.54%)
# Test Accuracy: 94.17%
# Test Average Loss: 0.8502
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31915 (19.95%)
#   module1: 39801 (24.88%)
#   module2: 50373 (31.48%)
#   module3: 37911 (23.69%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 6.79e-05
# New best model saved with test accuracy: 94.17%
# Epoch [251] 📊 acc: 0.952 | Targets: 0.8345 | Entropy: -1.8668
# New ref model saved
# New ref model: 5
# Epoch [252] 📊 acc: 0.950 | Targets: 0.8379 | Entropy: -1.8678
# New ref model: 4
# Epoch [253] 📊 acc: 0.951 | Targets: 0.8369 | Entropy: -1.8677
# New ref model: 6
# Epoch [254] 📊 acc: 0.951 | Targets: 0.8379 | Entropy: -1.8679
# New ref model: 6
# Epoch [255] 📊 acc: 0.950 | Targets: 0.8367 | Entropy: -1.8673
# New ref model: 7
# Epoch [256] 📊 acc: 0.951 | Targets: 0.8373 | Entropy: -1.8677
# New ref model: 0
# Epoch [257] 📊 acc: 0.952 | Targets: 0.8349 | Entropy: -1.8668
# New ref model: 0
# Epoch [258] 📊 acc: 0.951 | Targets: 0.8355 | Entropy: -1.8672
# New ref model: 0
# Epoch [259] 📊 acc: 0.951 | Targets: 0.8353 | Entropy: -1.8672
# New ref model: 1
# Epoch [260] 📊 acc: 0.952 | Targets: 0.8347 | Entropy: -1.8667
# New ref model: 0
#
# Evaluating at epoch 260 …
# Train Accuracy: 95.10%
# Train Average Loss: 0.8348
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 157319 (19.67%)
#   module1: 211691 (26.47%)
#   module2: 251890 (31.50%)
#   module3: 178844 (22.36%)
# Test Accuracy: 94.31%
# Test Average Loss: 0.8463
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31660 (19.79%)
#   module1: 39706 (24.82%)
#   module2: 50680 (31.67%)
#   module3: 37954 (23.72%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 4.42e-05
# New best model saved with test accuracy: 94.31%
# Epoch [261] 📊 acc: 0.952 | Targets: 0.8355 | Entropy: -1.8673
# New ref model: 2
# Epoch [262] 📊 acc: 0.953 | Targets: 0.8331 | Entropy: -1.8664
# New ref model saved
# New ref model: 2
# Epoch [263] 📊 acc: 0.953 | Targets: 0.8325 | Entropy: -1.8664
# New ref model saved
# New ref model: 3
# Epoch [264] 📊 acc: 0.950 | Targets: 0.8376 | Entropy: -1.8681
# New ref model: 0
# Epoch [265] 📊 acc: 0.950 | Targets: 0.8360 | Entropy: -1.8673
# New ref model: 4
# Epoch [266] 📊 acc: 0.951 | Targets: 0.8358 | Entropy: -1.8674
# New ref model: 4
# Epoch [267] 📊 acc: 0.952 | Targets: 0.8348 | Entropy: -1.8672
# New ref model: 5
# Epoch [268] 📊 acc: 0.952 | Targets: 0.8331 | Entropy: -1.8666
# New ref model: 4
# Epoch [269] 📊 acc: 0.951 | Targets: 0.8355 | Entropy: -1.8674
# New ref model: 6
# Epoch [270] 📊 acc: 0.952 | Targets: 0.8335 | Entropy: -1.8667
# New ref model: 6
#
# Evaluating at epoch 270 …
# Train Accuracy: 95.08%
# Train Average Loss: 0.8350
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 157984 (19.75%)
#   module1: 211211 (26.41%)
#   module2: 251859 (31.49%)
#   module3: 178690 (22.34%)
# Test Accuracy: 94.17%
# Test Average Loss: 0.8480
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 32058 (20.04%)
#   module1: 39718 (24.82%)
#   module2: 50508 (31.57%)
#   module3: 37716 (23.57%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 2.54e-05
# Epoch [271] 📊 acc: 0.951 | Targets: 0.8353 | Entropy: -1.8673
# New ref model: 7
# Epoch [272] 📊 acc: 0.952 | Targets: 0.8353 | Entropy: -1.8674
# New ref model: 0
# Epoch [273] 📊 acc: 0.953 | Targets: 0.8342 | Entropy: -1.8672
# New ref model: 0
# Epoch [274] 📊 acc: 0.952 | Targets: 0.8343 | Entropy: -1.8668
# New ref model: 0
# Epoch [275] 📊 acc: 0.952 | Targets: 0.8327 | Entropy: -1.8666
# New ref model: 1
# Epoch [276] 📊 acc: 0.953 | Targets: 0.8328 | Entropy: -1.8667
# New ref model saved
# New ref model: 0
# Epoch [277] 📊 acc: 0.953 | Targets: 0.8324 | Entropy: -1.8664
# New ref model saved
# New ref model: 2
# Epoch [278] 📊 acc: 0.952 | Targets: 0.8334 | Entropy: -1.8667
# New ref model: 2
# Epoch [279] 📊 acc: 0.954 | Targets: 0.8324 | Entropy: -1.8668
# New ref model saved
# New ref model: 3
# Epoch [280] 📊 acc: 0.954 | Targets: 0.8317 | Entropy: -1.8664
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 280 …
# Train Accuracy: 95.42%
# Train Average Loss: 0.8306
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 157352 (19.68%)
#   module1: 211628 (26.46%)
#   module2: 251518 (31.45%)
#   module3: 179246 (22.41%)
# Test Accuracy: 94.20%
# Test Average Loss: 0.8454
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 32148 (20.09%)
#   module1: 39613 (24.76%)
#   module2: 50454 (31.53%)
#   module3: 37785 (23.62%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 1.19e-05
# Epoch [281] 📊 acc: 0.953 | Targets: 0.8320 | Entropy: -1.8664
# New ref model: 4
# Epoch [282] 📊 acc: 0.953 | Targets: 0.8318 | Entropy: -1.8663
# New ref model: 4
# Epoch [283] 📊 acc: 0.955 | Targets: 0.8298 | Entropy: -1.8655
# New ref model saved
# New ref model: 5
# Epoch [284] 📊 acc: 0.953 | Targets: 0.8318 | Entropy: -1.8661
# New ref model: 4
# Epoch [285] 📊 acc: 0.953 | Targets: 0.8325 | Entropy: -1.8668
# New ref model: 6
# Epoch [286] 📊 acc: 0.953 | Targets: 0.8329 | Entropy: -1.8666
# New ref model: 6
# Epoch [287] 📊 acc: 0.952 | Targets: 0.8331 | Entropy: -1.8664
# New ref model: 7
# Epoch [288] 📊 acc: 0.952 | Targets: 0.8343 | Entropy: -1.8670
# New ref model: 0
# Epoch [289] 📊 acc: 0.954 | Targets: 0.8307 | Entropy: -1.8660
# New ref model: 0
# Epoch [290] 📊 acc: 0.954 | Targets: 0.8304 | Entropy: -1.8656
# New ref model: 0
#
# Evaluating at epoch 290 …
# Train Accuracy: 95.33%
# Train Average Loss: 0.8290
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 157696 (19.72%)
#   module1: 211606 (26.46%)
#   module2: 251532 (31.45%)
#   module3: 178910 (22.37%)
# Test Accuracy: 94.30%
# Test Average Loss: 0.8453
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31688 (19.81%)
#   module1: 39797 (24.87%)
#   module2: 50285 (31.43%)
#   module3: 38230 (23.89%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 3.74e-06
# Epoch [291] 📊 acc: 0.953 | Targets: 0.8317 | Entropy: -1.8661
# New ref model: 1
# Epoch [292] 📊 acc: 0.953 | Targets: 0.8324 | Entropy: -1.8662
# New ref model: 0
# Epoch [293] 📊 acc: 0.953 | Targets: 0.8331 | Entropy: -1.8666
# New ref model: 2
# Epoch [294] 📊 acc: 0.953 | Targets: 0.8327 | Entropy: -1.8666
# New ref model: 2
# Epoch [295] 📊 acc: 0.954 | Targets: 0.8322 | Entropy: -1.8667
# New ref model: 3
# Epoch [296] 📊 acc: 0.953 | Targets: 0.8310 | Entropy: -1.8661
# New ref model: 0
# Epoch [297] 📊 acc: 0.955 | Targets: 0.8298 | Entropy: -1.8658
# New ref model saved
# New ref model: 4
# Epoch [298] 📊 acc: 0.954 | Targets: 0.8324 | Entropy: -1.8666
# New ref model: 4
# Epoch [299] 📊 acc: 0.954 | Targets: 0.8297 | Entropy: -1.8660
# New ref model: 5
# Epoch [300] 📊 acc: 0.953 | Targets: 0.8331 | Entropy: -1.8663
# New ref model: 4
#
# Evaluating at epoch 300 …
# Train Accuracy: 95.29%
# Train Average Loss: 0.8329
# Train Module Usage Summed Over Depth 0 to 15:
#   module0: 157611 (19.71%)
#   module1: 211110 (26.40%)
#   module2: 251763 (31.48%)
#   module3: 179260 (22.41%)
# Test Accuracy: 94.22%
# Test Average Loss: 0.8442
# Test Module Usage Summed Over Depth 0 to 15:
#   module0: 31998 (20.00%)
#   module1: 39558 (24.72%)
#   module2: 50497 (31.56%)
#   module3: 37947 (23.72%)
# Total Trainable Parameters: 1,942,286
#
# Current learning rate: 1.00e-06
# Finished Training
# Best test accuracy achieved: 94.31%
# Total Trainable Parameters: 1,942,286
