# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision
import torchvision.transforms as transforms
from torchvision.transforms import autoaugment
from torch.utils.checkpoint import checkpoint
import torch.optim as optim
import copy
import contextlib
import numpy as np

# %%
def get_cifar10_loaders(
    batch_size: int         = 256, 
    num_workers: int        = 8,  
    pin_memory: bool        = True,
    persistent_workers: bool = True, 
):
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(p=0.5),
        autoaugment.AutoAugment(autoaugment.AutoAugmentPolicy.CIFAR10),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),
                             (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
        drop_last=True,              
    )

    testset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )
    testloader = torch.utils.data.DataLoader(
        testset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=persistent_workers,
    )

    return trainloader, testloader

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(channels // reduction, channels, kernel_size=1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        w = self.global_avg_pool(x)
        w = self.relu(self.fc1(w))
        w = 2 * self.sigmoid(self.fc2(w))
        return x * w

# %%
class BottleneckBlock(nn.Module):
    def __init__(self, in_channels, out_channels, max_depth=3, reduction_factor=4):
        super(BottleneckBlock, self).__init__()

        reduced_channels = in_channels // reduction_factor

        self.conv1 = nn.Conv2d(in_channels, reduced_channels, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, in_channels)

        self.conv2 = nn.Conv2d(reduced_channels, reduced_channels, kernel_size=3, stride=1, padding=1, bias=False, groups=reduced_channels)
        self.bn2 = nn.GroupNorm(1, reduced_channels)
        
        self.conv3 = nn.Conv2d(reduced_channels, out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, reduced_channels)

        self.relu = nn.ReLU()

        self.skip_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.skip_bn = nn.GroupNorm(1, in_channels)

        self.se = SEBlock(out_channels)

    def forward(self, x, depth):
        identity = x

        out = self.relu(x)
        out = self.bn1(out)
        out = self.conv1(out)

        out = self.relu(out)
        out = self.bn2(out)
        out = self.conv2(out)

        out = self.relu(out)
        out = self.bn3(out)
        out = self.conv3(out)

        out = self.se(out)

        skip = self.relu(identity)
        skip = self.skip_bn(skip)
        skip = self.skip_conv(skip)

        out += skip
        return out

# %%
class AmplifyConv(nn.Module):
    def __init__(self, channels, max_depth=3, num_module=2):
        super(AmplifyConv, self).__init__()
        self.max_depth = max_depth
        self.num_module = num_module

        self.conv = nn.ModuleList([
            BottleneckBlock(channels, channels, max_depth) for _ in range(num_module)
        ])
        self.bn = nn.GroupNorm(1, channels)

        self.step_embeddings = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings1 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))
        self.step_embeddings2 = nn.Parameter(torch.randn(max_depth, channels, 1, 1))

    def step_forward(self, x, x_prev, depth):
        out = self.conv[depth // (self.max_depth // self.num_module)](x, depth)
        x = 2 * F.sigmoid(self.step_embeddings1[depth]) * F.relu(x) + (1 + self.step_embeddings[depth]) * out
        x = self.bn(x)

        x = x + 2 * F.sigmoid(self.step_embeddings2[depth]) * F.relu(x_prev)
        return x

    def forward(self, x):
        prev = []
        for d in range(self.max_depth):
            if d % 2 == 0:
                prev.append(x)
                
            x_prev = prev[((d + 1) - ((d + 1) & -(d + 1))) // 2]
            x = checkpoint(self.step_forward, x, x_prev, d, use_reentrant=False)

        return x

# %%
class RecursionAmplifyConv(nn.Module):
    def __init__(self, channels, height, width):
        super(RecursionAmplifyConv, self).__init__()
        
        self.conv0 = nn.Conv2d(3, channels, kernel_size=4, stride=2, padding=1)
        self.amconv = AmplifyConv(channels, max_depth=32, num_module=1)
        
        self.max_pool = nn.AdaptiveMaxPool2d((1, 1))
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))


    def forward(self, x):
        
        x = self.conv0(x)

        x = self.amconv(x)

        x = torch.cat([self.max_pool(x), self.avg_pool(x)], dim=1)
        
        return x

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.reamconv= RecursionAmplifyConv(512, 32, 32)

        self.fc1 = nn.Linear(1024, 10)

    def forward(self, x):
        
        x = self.reamconv(x)
        
        x = x.contiguous().view(-1, 1024)
        x = F.relu(x)
        x = self.fc1(x)
        return x

# %%
class RL_fine_tune:
    def __init__(self, device):
        self.device = device


    def compute_reconstruct_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (correct - 0.5)
    
        return rewards, correct.sum().item()

    def compute_positive_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = correct
    
        return rewards, correct.sum().item()

    def compute_negative_reward(self, outputs, targets):
        predictions = torch.argmax(outputs, dim=1)
        correct = (predictions == targets).float()
        
        rewards = (1 - correct)
    
        return rewards, correct.sum().item()

    
    def emergency_policy_loss(self, ref_outputs, pre_outputs, outputs, targets):
        
        probs = F.softmax(outputs, dim=1)
        select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)

        with torch.no_grad():
            old_probs = F.softmax(outputs, dim=1)
            old_select = - F.log_softmax(outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)

        pre_probs = F.softmax(pre_outputs, dim=1)
        pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)

        with torch.no_grad():
            old_pre_probs = F.softmax(pre_outputs, dim=1)
            old_pre_select = - F.log_softmax(pre_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)
        
        ref_probs = F.softmax(ref_outputs, dim=1)
        ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)

        with torch.no_grad():
            old_ref_probs = F.softmax(ref_outputs, dim=1)
            old_ref_select = - F.log_softmax(ref_outputs, dim=1).gather(1, targets.unsqueeze(1)).squeeze(1)

        rewards, correct = self.compute_positive_reward(outputs, targets)
        pre_rewards, _ = self.compute_positive_reward(pre_outputs, targets)
        ref_rewards, _ = self.compute_positive_reward(ref_outputs, targets)

        ce_loss = F.cross_entropy(outputs, targets)

        select_delta = (select - old_select)
        pre_select_delta = (pre_select - old_pre_select)
        ref_select_delta = (ref_select - old_ref_select)


        with torch.no_grad():

            metrics = {
                'ce_loss': ce_loss.item(),
                'targets': select.sum().item(),
            }
    
        return select_delta, pre_select_delta, ref_select_delta, correct, metrics

# %%
def train_model(
    net: torch.nn.Module,
    get_cifar10_loaders,
    evaluate_model,
    batch_size: int = 64,
    epochs: int = 300,
    eval_interval: int = 10,
    lr: float = 1e-3,
    checkpoint_path: str = "Reasoning_32R_512C_RL.pth",
):
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    net = net.to(device)
    ref_net = copy.deepcopy(net).to(device)
    pre_net = copy.deepcopy(net).to(device)
    
    ref_count = 32
    
    select_embeddings1 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    select_embeddings2 = nn.Parameter(torch.randn(ref_count, 1, device=device))
    
    trainloader, testloader = get_cifar10_loaders(
        batch_size=batch_size,
        num_workers=8,
        pin_memory=True,
        persistent_workers=True,
    )
    
    criterion = torch.nn.CrossEntropyLoss()
    all_params = list(net.parameters()) + [
        select_embeddings1, select_embeddings2,
    ]
    optimizer = torch.optim.Adam(all_params, lr=lr)
    scaler = torch.amp.GradScaler(enabled=device.type == "cuda")
    best_test_acc = 0.0
    rl_accuracy = 0.0
    
    rl_trainer = RL_fine_tune(device)
    rl_metrics_accumulator = {}
    prev_ref = []
    
    for epoch in range(epochs):
        net.train()
        batch_count = 0
        running_cor = 0.0
            
        if (epoch == 0):
            print("\n💫 starting supervised training and RL fine-tuning with 1e-3 learning rate\n")

            for param_group in optimizer.param_groups:
                param_group['lr'] = lr
            
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, T_max=300, eta_min=1e-6
            )
        
        rl_metrics_accumulator = {
            'ce_loss': 0.0, 'targets': 0.0,
        }
        
        for batch_idx, (inputs, targets) in enumerate(trainloader):
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type="cuda"):
                outputs = net(inputs)
                ref_outputs = ref_net(inputs)
                pre_outputs = pre_net(inputs)
                
                select_delta, pre_select_delta, ref_select_delta, cor, metrics = rl_trainer.emergency_policy_loss(ref_outputs, pre_outputs, outputs, targets)

                select_delta = F.tanh(select_delta) - 2 * F.sigmoid(select_embeddings1[epoch % ref_count]) * F.relu(F.tanh(pre_select_delta))
                select_delta = F.tanh(select_delta)
                select_delta = select_delta - 2 * F.sigmoid(select_embeddings2[epoch % ref_count]) * F.relu(F.tanh(ref_select_delta))
                
                select_loss = select_delta.mean()
                
                
                loss = select_loss
                    
                for key, value in metrics.items():
                    rl_metrics_accumulator[key] += value

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=0.5)
            scaler.step(optimizer)
            scaler.update()
            
            running_cor += cor
            batch_count += inputs.shape[0]

        scheduler.step()
        
        avg_acc = running_cor / batch_count
        avg_metrics = {k: v / batch_count for k, v in rl_metrics_accumulator.items()}
            
        print(f"Epoch [{epoch + 1}] 📊 acc: {avg_acc:.3f} | Targets: {avg_metrics['targets']:.4f}")

        if running_cor > rl_accuracy:
            rl_accuracy = running_cor
            ref = copy.deepcopy(net).cpu()
            prev_ref.append(ref)
            prev_ref = prev_ref[-ref_count//2:]
            print(f"New ref model saved")
            
        r = ((epoch % (len(prev_ref) * 2) + 1) - ((epoch % (len(prev_ref) * 2) + 1) & -(epoch % (len(prev_ref) * 2) + 1))) // 2
        ref_net = copy.deepcopy(prev_ref[r]).to(device)
        pre_net = copy.deepcopy(prev_ref[0]).to(device)
        print(f"New ref model: {r}")
            
        if (epoch + 1) % eval_interval == 0 or epoch == epochs - 1:
            print(f"\nEvaluating at epoch {epoch + 1} …")
            train_acc = evaluate_model(net, trainloader, criterion, "Train", device)
            test_acc  = evaluate_model(net, testloader,  criterion, "Test",  device)
            print(f"Total Trainable Parameters: {count_parameters(net):,}\n")
            print(f"Current learning rate: {optimizer.param_groups[0]['lr']:.2e}")
            
            if test_acc > best_test_acc:
                best_test_acc = test_acc
                torch.save(net.state_dict(), checkpoint_path)
                print(f"New best model saved with test accuracy: {test_acc:.2f}%")
    
    print("Finished Training")
    print(f"Best test accuracy achieved: {best_test_acc:.2f}%")

# %%
def evaluate_model(
    net: torch.nn.Module,
    dataloader,
    criterion,
    dataset_name: str = "",
    device=None,
):
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    was_training = net.training
    net.eval()

    total_correct = 0
    total_seen = 0
    loss_sum = 0.0

    use_bf16 = torch.cuda.is_available() and torch.cuda.is_bf16_supported()
    autocast_ctx = (torch.amp.autocast(device_type="cuda", dtype=torch.bfloat16)
                    if use_bf16 else contextlib.nullcontext())

    with torch.no_grad(), autocast_ctx:
        for images, labels in dataloader:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            outputs = net(images)  
            batch_loss = criterion(outputs.float(), labels)

            if not torch.isfinite(batch_loss):
                print("[eval/warn] non-finite loss",
                      "logits_minmax=", float(outputs.min()), float(outputs.max()))
                continue

            bs = labels.size(0)
            loss_sum    += batch_loss.item() * bs
            total_seen  += bs

            preds = outputs.argmax(dim=1)
            total_correct += (preds == labels).sum().item()

    if total_seen == 0:
        avg_loss = float("nan")
        acc = 0.0
    else:
        avg_loss = loss_sum / total_seen
        acc = 100.0 * total_correct / total_seen

    print(f"{dataset_name} Accuracy: {acc:.2f}%")
    print(f"{dataset_name} Average Loss: {avg_loss:.4f}")

    if was_training:
        net.train()

    return acc

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Example usage:
model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# Total Trainable Parameters: 515,754

# %%
torch.backends.cudnn.benchmark = True
net = Net()
train_model(net, get_cifar10_loaders, evaluate_model)

model = Net()
print(f"Total Trainable Parameters: {count_parameters(model):,}")
# Out:
# 💫 starting supervised training and RL fine-tuning with 1e-3 learning rate
#
# Epoch [1] 📊 acc: 0.323 | Targets: 1.8748
# New ref model saved
# New ref model: 0
# Epoch [2] 📊 acc: 0.483 | Targets: 1.4437
# New ref model saved
# New ref model: 0
# Epoch [3] 📊 acc: 0.554 | Targets: 1.2506
# New ref model saved
# New ref model: 1
# Epoch [4] 📊 acc: 0.611 | Targets: 1.1083
# New ref model saved
# New ref model: 0
# Epoch [5] 📊 acc: 0.647 | Targets: 1.0158
# New ref model saved
# New ref model: 2
# Epoch [6] 📊 acc: 0.671 | Targets: 0.9443
# New ref model saved
# New ref model: 2
# Epoch [7] 📊 acc: 0.693 | Targets: 0.8882
# New ref model saved
# New ref model: 3
# Epoch [8] 📊 acc: 0.704 | Targets: 0.8525
# New ref model saved
# New ref model: 0
# Epoch [9] 📊 acc: 0.722 | Targets: 0.8031
# New ref model saved
# New ref model: 4
# Epoch [10] 📊 acc: 0.733 | Targets: 0.7721
# New ref model saved
# New ref model: 4
#
# Evaluating at epoch 10 …
# Train Accuracy: 74.34%
# Train Average Loss: 0.7372
# Test Accuracy: 80.25%
# Test Average Loss: 0.5721
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.97e-04
# New best model saved with test accuracy: 80.25%
# Epoch [11] 📊 acc: 0.740 | Targets: 0.7515
# New ref model saved
# New ref model: 5
# Epoch [12] 📊 acc: 0.751 | Targets: 0.7178
# New ref model saved
# New ref model: 4
# Epoch [13] 📊 acc: 0.759 | Targets: 0.6967
# New ref model saved
# New ref model: 6
# Epoch [14] 📊 acc: 0.764 | Targets: 0.6825
# New ref model saved
# New ref model: 6
# Epoch [15] 📊 acc: 0.772 | Targets: 0.6595
# New ref model saved
# New ref model: 7
# Epoch [16] 📊 acc: 0.777 | Targets: 0.6461
# New ref model saved
# New ref model: 0
# Epoch [17] 📊 acc: 0.784 | Targets: 0.6302
# New ref model saved
# New ref model: 8
# Epoch [18] 📊 acc: 0.785 | Targets: 0.6180
# New ref model saved
# New ref model: 8
# Epoch [19] 📊 acc: 0.791 | Targets: 0.6028
# New ref model saved
# New ref model: 9
# Epoch [20] 📊 acc: 0.795 | Targets: 0.5912
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 20 …
# Train Accuracy: 80.41%
# Train Average Loss: 0.5675
# Test Accuracy: 85.75%
# Test Average Loss: 0.4161
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.89e-04
# New best model saved with test accuracy: 85.75%
# Epoch [21] 📊 acc: 0.800 | Targets: 0.5787
# New ref model saved
# New ref model: 10
# Epoch [22] 📊 acc: 0.801 | Targets: 0.5735
# New ref model saved
# New ref model: 10
# Epoch [23] 📊 acc: 0.811 | Targets: 0.5522
# New ref model saved
# New ref model: 11
# Epoch [24] 📊 acc: 0.811 | Targets: 0.5495
# New ref model saved
# New ref model: 8
# Epoch [25] 📊 acc: 0.814 | Targets: 0.5415
# New ref model saved
# New ref model: 12
# Epoch [26] 📊 acc: 0.816 | Targets: 0.5305
# New ref model saved
# New ref model: 12
# Epoch [27] 📊 acc: 0.818 | Targets: 0.5266
# New ref model saved
# New ref model: 13
# Epoch [28] 📊 acc: 0.822 | Targets: 0.5160
# New ref model saved
# New ref model: 12
# Epoch [29] 📊 acc: 0.824 | Targets: 0.5085
# New ref model saved
# New ref model: 14
# Epoch [30] 📊 acc: 0.829 | Targets: 0.4950
# New ref model saved
# New ref model: 14
#
# Evaluating at epoch 30 …
# Train Accuracy: 82.75%
# Train Average Loss: 0.4984
# Test Accuracy: 86.38%
# Test Average Loss: 0.3978
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.76e-04
# New best model saved with test accuracy: 86.38%
# Epoch [31] 📊 acc: 0.830 | Targets: 0.4916
# New ref model saved
# New ref model: 15
# Epoch [32] 📊 acc: 0.833 | Targets: 0.4828
# New ref model saved
# New ref model: 0
# Epoch [33] 📊 acc: 0.835 | Targets: 0.4770
# New ref model saved
# New ref model: 0
# Epoch [34] 📊 acc: 0.837 | Targets: 0.4707
# New ref model saved
# New ref model: 0
# Epoch [35] 📊 acc: 0.840 | Targets: 0.4628
# New ref model saved
# New ref model: 1
# Epoch [36] 📊 acc: 0.842 | Targets: 0.4582
# New ref model saved
# New ref model: 0
# Epoch [37] 📊 acc: 0.844 | Targets: 0.4518
# New ref model saved
# New ref model: 2
# Epoch [38] 📊 acc: 0.844 | Targets: 0.4480
# New ref model saved
# New ref model: 2
# Epoch [39] 📊 acc: 0.847 | Targets: 0.4415
# New ref model saved
# New ref model: 3
# Epoch [40] 📊 acc: 0.849 | Targets: 0.4380
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 40 …
# Train Accuracy: 84.46%
# Train Average Loss: 0.4528
# Test Accuracy: 88.52%
# Test Average Loss: 0.3511
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.57e-04
# New best model saved with test accuracy: 88.52%
# Epoch [41] 📊 acc: 0.853 | Targets: 0.4317
# New ref model saved
# New ref model: 4
# Epoch [42] 📊 acc: 0.853 | Targets: 0.4240
# New ref model saved
# New ref model: 4
# Epoch [43] 📊 acc: 0.854 | Targets: 0.4259
# New ref model saved
# New ref model: 5
# Epoch [44] 📊 acc: 0.855 | Targets: 0.4180
# New ref model saved
# New ref model: 4
# Epoch [45] 📊 acc: 0.854 | Targets: 0.4165
# New ref model: 6
# Epoch [46] 📊 acc: 0.859 | Targets: 0.4078
# New ref model saved
# New ref model: 6
# Epoch [47] 📊 acc: 0.862 | Targets: 0.3994
# New ref model saved
# New ref model: 7
# Epoch [48] 📊 acc: 0.864 | Targets: 0.3958
# New ref model saved
# New ref model: 0
# Epoch [49] 📊 acc: 0.862 | Targets: 0.3952
# New ref model: 8
# Epoch [50] 📊 acc: 0.866 | Targets: 0.3911
# New ref model saved
# New ref model: 8
#
# Evaluating at epoch 50 …
# Train Accuracy: 86.75%
# Train Average Loss: 0.3836
# Test Accuracy: 89.50%
# Test Average Loss: 0.3204
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.33e-04
# New best model saved with test accuracy: 89.50%
# Epoch [51] 📊 acc: 0.863 | Targets: 0.3904
# New ref model: 9
# Epoch [52] 📊 acc: 0.870 | Targets: 0.3783
# New ref model saved
# New ref model: 8
# Epoch [53] 📊 acc: 0.870 | Targets: 0.3725
# New ref model: 10
# Epoch [54] 📊 acc: 0.871 | Targets: 0.3698
# New ref model saved
# New ref model: 10
# Epoch [55] 📊 acc: 0.871 | Targets: 0.3687
# New ref model saved
# New ref model: 11
# Epoch [56] 📊 acc: 0.873 | Targets: 0.3636
# New ref model saved
# New ref model: 8
# Epoch [57] 📊 acc: 0.873 | Targets: 0.3641
# New ref model saved
# New ref model: 12
# Epoch [58] 📊 acc: 0.876 | Targets: 0.3596
# New ref model saved
# New ref model: 12
# Epoch [59] 📊 acc: 0.876 | Targets: 0.3589
# New ref model: 13
# Epoch [60] 📊 acc: 0.876 | Targets: 0.3566
# New ref model saved
# New ref model: 12
#
# Evaluating at epoch 60 …
# Train Accuracy: 87.49%
# Train Average Loss: 0.3556
# Test Accuracy: 89.52%
# Test Average Loss: 0.3102
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.05e-04
# New best model saved with test accuracy: 89.52%
# Epoch [61] 📊 acc: 0.880 | Targets: 0.3454
# New ref model saved
# New ref model: 14
# Epoch [62] 📊 acc: 0.880 | Targets: 0.3451
# New ref model: 14
# Epoch [63] 📊 acc: 0.880 | Targets: 0.3514
# New ref model: 15
# Epoch [64] 📊 acc: 0.883 | Targets: 0.3361
# New ref model saved
# New ref model: 0
# Epoch [65] 📊 acc: 0.882 | Targets: 0.3402
# New ref model: 0
# Epoch [66] 📊 acc: 0.882 | Targets: 0.3391
# New ref model: 0
# Epoch [67] 📊 acc: 0.884 | Targets: 0.3337
# New ref model saved
# New ref model: 1
# Epoch [68] 📊 acc: 0.883 | Targets: 0.3355
# New ref model: 0
# Epoch [69] 📊 acc: 0.886 | Targets: 0.3276
# New ref model saved
# New ref model: 2
# Epoch [70] 📊 acc: 0.889 | Targets: 0.3206
# New ref model saved
# New ref model: 2
#
# Evaluating at epoch 70 …
# Train Accuracy: 89.38%
# Train Average Loss: 0.3101
# Test Accuracy: 91.32%
# Test Average Loss: 0.2751
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.72e-04
# New best model saved with test accuracy: 91.32%
# Epoch [71] 📊 acc: 0.887 | Targets: 0.3231
# New ref model: 3
# Epoch [72] 📊 acc: 0.889 | Targets: 0.3221
# New ref model saved
# New ref model: 0
# Epoch [73] 📊 acc: 0.892 | Targets: 0.3139
# New ref model saved
# New ref model: 4
# Epoch [74] 📊 acc: 0.891 | Targets: 0.3158
# New ref model: 4
# Epoch [75] 📊 acc: 0.890 | Targets: 0.3138
# New ref model: 5
# Epoch [76] 📊 acc: 0.894 | Targets: 0.3071
# New ref model saved
# New ref model: 4
# Epoch [77] 📊 acc: 0.894 | Targets: 0.3027
# New ref model saved
# New ref model: 6
# Epoch [78] 📊 acc: 0.893 | Targets: 0.3055
# New ref model: 6
# Epoch [79] 📊 acc: 0.896 | Targets: 0.3019
# New ref model saved
# New ref model: 7
# Epoch [80] 📊 acc: 0.896 | Targets: 0.3003
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 80 …
# Train Accuracy: 90.26%
# Train Average Loss: 0.2805
# Test Accuracy: 91.70%
# Test Average Loss: 0.2557
# Total Trainable Parameters: 515,754
#
# Current learning rate: 8.35e-04
# New best model saved with test accuracy: 91.70%
# Epoch [81] 📊 acc: 0.896 | Targets: 0.3006
# New ref model: 8
# Epoch [82] 📊 acc: 0.898 | Targets: 0.2950
# New ref model saved
# New ref model: 8
# Epoch [83] 📊 acc: 0.899 | Targets: 0.2945
# New ref model saved
# New ref model: 9
# Epoch [84] 📊 acc: 0.900 | Targets: 0.2862
# New ref model saved
# New ref model: 8
# Epoch [85] 📊 acc: 0.901 | Targets: 0.2864
# New ref model saved
# New ref model: 10
# Epoch [86] 📊 acc: 0.900 | Targets: 0.2884
# New ref model: 10
# Epoch [87] 📊 acc: 0.901 | Targets: 0.2865
# New ref model saved
# New ref model: 11
# Epoch [88] 📊 acc: 0.901 | Targets: 0.2865
# New ref model saved
# New ref model: 8
# Epoch [89] 📊 acc: 0.901 | Targets: 0.2825
# New ref model: 12
# Epoch [90] 📊 acc: 0.905 | Targets: 0.2754
# New ref model saved
# New ref model: 12
#
# Evaluating at epoch 90 …
# Train Accuracy: 90.61%
# Train Average Loss: 0.2672
# Test Accuracy: 91.77%
# Test Average Loss: 0.2556
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.94e-04
# New best model saved with test accuracy: 91.77%
# Epoch [91] 📊 acc: 0.904 | Targets: 0.2782
# New ref model: 13
# Epoch [92] 📊 acc: 0.904 | Targets: 0.2770
# New ref model: 12
# Epoch [93] 📊 acc: 0.904 | Targets: 0.2734
# New ref model: 14
# Epoch [94] 📊 acc: 0.905 | Targets: 0.2724
# New ref model saved
# New ref model: 14
# Epoch [95] 📊 acc: 0.906 | Targets: 0.2702
# New ref model saved
# New ref model: 15
# Epoch [96] 📊 acc: 0.907 | Targets: 0.2684
# New ref model saved
# New ref model: 0
# Epoch [97] 📊 acc: 0.908 | Targets: 0.2662
# New ref model saved
# New ref model: 0
# Epoch [98] 📊 acc: 0.908 | Targets: 0.2641
# New ref model: 0
# Epoch [99] 📊 acc: 0.907 | Targets: 0.2661
# New ref model: 1
# Epoch [100] 📊 acc: 0.909 | Targets: 0.2579
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 100 …
# Train Accuracy: 91.31%
# Train Average Loss: 0.2522
# Test Accuracy: 92.11%
# Test Average Loss: 0.2555
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.50e-04
# New best model saved with test accuracy: 92.11%
# Epoch [101] 📊 acc: 0.912 | Targets: 0.2535
# New ref model saved
# New ref model: 2
# Epoch [102] 📊 acc: 0.910 | Targets: 0.2575
# New ref model: 2
# Epoch [103] 📊 acc: 0.910 | Targets: 0.2571
# New ref model: 3
# Epoch [104] 📊 acc: 0.913 | Targets: 0.2494
# New ref model saved
# New ref model: 0
# Epoch [105] 📊 acc: 0.913 | Targets: 0.2529
# New ref model: 4
# Epoch [106] 📊 acc: 0.913 | Targets: 0.2522
# New ref model saved
# New ref model: 4
# Epoch [107] 📊 acc: 0.916 | Targets: 0.2462
# New ref model saved
# New ref model: 5
# Epoch [108] 📊 acc: 0.915 | Targets: 0.2455
# New ref model: 4
# Epoch [109] 📊 acc: 0.913 | Targets: 0.2489
# New ref model: 6
# Epoch [110] 📊 acc: 0.916 | Targets: 0.2417
# New ref model saved
# New ref model: 6
#
# Evaluating at epoch 110 …
# Train Accuracy: 91.80%
# Train Average Loss: 0.2359
# Test Accuracy: 92.30%
# Test Average Loss: 0.2584
# Total Trainable Parameters: 515,754
#
# Current learning rate: 7.04e-04
# New best model saved with test accuracy: 92.30%
# Epoch [111] 📊 acc: 0.915 | Targets: 0.2435
# New ref model: 7
# Epoch [112] 📊 acc: 0.917 | Targets: 0.2405
# New ref model saved
# New ref model: 0
# Epoch [113] 📊 acc: 0.918 | Targets: 0.2392
# New ref model saved
# New ref model: 8
# Epoch [114] 📊 acc: 0.918 | Targets: 0.2392
# New ref model: 8
# Epoch [115] 📊 acc: 0.918 | Targets: 0.2351
# New ref model saved
# New ref model: 9
# Epoch [116] 📊 acc: 0.919 | Targets: 0.2337
# New ref model saved
# New ref model: 8
# Epoch [117] 📊 acc: 0.919 | Targets: 0.2329
# New ref model saved
# New ref model: 10
# Epoch [118] 📊 acc: 0.920 | Targets: 0.2334
# New ref model saved
# New ref model: 10
# Epoch [119] 📊 acc: 0.919 | Targets: 0.2331
# New ref model: 11
# Epoch [120] 📊 acc: 0.918 | Targets: 0.2319
# New ref model: 8
#
# Evaluating at epoch 120 …
# Train Accuracy: 92.17%
# Train Average Loss: 0.2226
# Test Accuracy: 92.26%
# Test Average Loss: 0.2613
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.55e-04
# Epoch [121] 📊 acc: 0.920 | Targets: 0.2313
# New ref model saved
# New ref model: 12
# Epoch [122] 📊 acc: 0.923 | Targets: 0.2229
# New ref model saved
# New ref model: 12
# Epoch [123] 📊 acc: 0.921 | Targets: 0.2287
# New ref model: 13
# Epoch [124] 📊 acc: 0.922 | Targets: 0.2253
# New ref model: 12
# Epoch [125] 📊 acc: 0.923 | Targets: 0.2217
# New ref model saved
# New ref model: 14
# Epoch [126] 📊 acc: 0.923 | Targets: 0.2203
# New ref model: 14
# Epoch [127] 📊 acc: 0.923 | Targets: 0.2220
# New ref model: 15
# Epoch [128] 📊 acc: 0.925 | Targets: 0.2184
# New ref model saved
# New ref model: 0
# Epoch [129] 📊 acc: 0.925 | Targets: 0.2153
# New ref model: 0
# Epoch [130] 📊 acc: 0.925 | Targets: 0.2171
# New ref model: 0
#
# Evaluating at epoch 130 …
# Train Accuracy: 92.19%
# Train Average Loss: 0.2249
# Test Accuracy: 92.29%
# Test Average Loss: 0.2675
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.04e-04
# Epoch [131] 📊 acc: 0.925 | Targets: 0.2140
# New ref model: 1
# Epoch [132] 📊 acc: 0.928 | Targets: 0.2103
# New ref model saved
# New ref model: 0
# Epoch [133] 📊 acc: 0.927 | Targets: 0.2096
# New ref model: 2
# Epoch [134] 📊 acc: 0.927 | Targets: 0.2106
# New ref model: 2
# Epoch [135] 📊 acc: 0.928 | Targets: 0.2091
# New ref model saved
# New ref model: 3
# Epoch [136] 📊 acc: 0.928 | Targets: 0.2051
# New ref model: 0
# Epoch [137] 📊 acc: 0.930 | Targets: 0.2055
# New ref model saved
# New ref model: 4
# Epoch [138] 📊 acc: 0.931 | Targets: 0.2012
# New ref model saved
# New ref model: 4
# Epoch [139] 📊 acc: 0.929 | Targets: 0.2043
# New ref model: 5
# Epoch [140] 📊 acc: 0.928 | Targets: 0.2076
# New ref model: 4
#
# Evaluating at epoch 140 …
# Train Accuracy: 93.13%
# Train Average Loss: 0.2023
# Test Accuracy: 93.07%
# Test Average Loss: 0.2666
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.53e-04
# New best model saved with test accuracy: 93.07%
# Epoch [141] 📊 acc: 0.931 | Targets: 0.2018
# New ref model saved
# New ref model: 6
# Epoch [142] 📊 acc: 0.928 | Targets: 0.2035
# New ref model: 6
# Epoch [143] 📊 acc: 0.932 | Targets: 0.1989
# New ref model saved
# New ref model: 7
# Epoch [144] 📊 acc: 0.931 | Targets: 0.1971
# New ref model: 0
# Epoch [145] 📊 acc: 0.932 | Targets: 0.1966
# New ref model saved
# New ref model: 8
# Epoch [146] 📊 acc: 0.934 | Targets: 0.1903
# New ref model saved
# New ref model: 8
# Epoch [147] 📊 acc: 0.934 | Targets: 0.1911
# New ref model: 9
# Epoch [148] 📊 acc: 0.932 | Targets: 0.1942
# New ref model: 8
# Epoch [149] 📊 acc: 0.936 | Targets: 0.1892
# New ref model saved
# New ref model: 10
# Epoch [150] 📊 acc: 0.934 | Targets: 0.1874
# New ref model: 10
#
# Evaluating at epoch 150 …
# Train Accuracy: 93.10%
# Train Average Loss: 0.1984
# Test Accuracy: 92.64%
# Test Average Loss: 0.2774
# Total Trainable Parameters: 515,754
#
# Current learning rate: 5.00e-04
# Epoch [151] 📊 acc: 0.937 | Targets: 0.1861
# New ref model saved
# New ref model: 11
# Epoch [152] 📊 acc: 0.935 | Targets: 0.1872
# New ref model: 8
# Epoch [153] 📊 acc: 0.936 | Targets: 0.1844
# New ref model: 12
# Epoch [154] 📊 acc: 0.937 | Targets: 0.1835
# New ref model saved
# New ref model: 12
# Epoch [155] 📊 acc: 0.938 | Targets: 0.1843
# New ref model saved
# New ref model: 13
# Epoch [156] 📊 acc: 0.937 | Targets: 0.1797
# New ref model: 12
# Epoch [157] 📊 acc: 0.937 | Targets: 0.1839
# New ref model: 14
# Epoch [158] 📊 acc: 0.937 | Targets: 0.1837
# New ref model: 14
# Epoch [159] 📊 acc: 0.937 | Targets: 0.1831
# New ref model: 15
# Epoch [160] 📊 acc: 0.940 | Targets: 0.1764
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 160 …
# Train Accuracy: 94.16%
# Train Average Loss: 0.1711
# Test Accuracy: 93.16%
# Test Average Loss: 0.2569
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.48e-04
# New best model saved with test accuracy: 93.16%
# Epoch [161] 📊 acc: 0.939 | Targets: 0.1800
# New ref model: 0
# Epoch [162] 📊 acc: 0.939 | Targets: 0.1740
# New ref model: 0
# Epoch [163] 📊 acc: 0.940 | Targets: 0.1764
# New ref model: 1
# Epoch [164] 📊 acc: 0.938 | Targets: 0.1770
# New ref model: 0
# Epoch [165] 📊 acc: 0.938 | Targets: 0.1782
# New ref model: 2
# Epoch [166] 📊 acc: 0.940 | Targets: 0.1719
# New ref model saved
# New ref model: 2
# Epoch [167] 📊 acc: 0.941 | Targets: 0.1695
# New ref model saved
# New ref model: 3
# Epoch [168] 📊 acc: 0.942 | Targets: 0.1700
# New ref model saved
# New ref model: 0
# Epoch [169] 📊 acc: 0.942 | Targets: 0.1708
# New ref model: 4
# Epoch [170] 📊 acc: 0.942 | Targets: 0.1651
# New ref model saved
# New ref model: 4
#
# Evaluating at epoch 170 …
# Train Accuracy: 94.36%
# Train Average Loss: 0.1654
# Test Accuracy: 93.26%
# Test Average Loss: 0.2724
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.97e-04
# New best model saved with test accuracy: 93.26%
# Epoch [171] 📊 acc: 0.943 | Targets: 0.1667
# New ref model saved
# New ref model: 5
# Epoch [172] 📊 acc: 0.943 | Targets: 0.1642
# New ref model saved
# New ref model: 4
# Epoch [173] 📊 acc: 0.944 | Targets: 0.1652
# New ref model saved
# New ref model: 6
# Epoch [174] 📊 acc: 0.943 | Targets: 0.1664
# New ref model: 6
# Epoch [175] 📊 acc: 0.944 | Targets: 0.1603
# New ref model saved
# New ref model: 7
# Epoch [176] 📊 acc: 0.943 | Targets: 0.1642
# New ref model: 0
# Epoch [177] 📊 acc: 0.944 | Targets: 0.1639
# New ref model: 8
# Epoch [178] 📊 acc: 0.944 | Targets: 0.1640
# New ref model: 8
# Epoch [179] 📊 acc: 0.944 | Targets: 0.1603
# New ref model saved
# New ref model: 9
# Epoch [180] 📊 acc: 0.944 | Targets: 0.1632
# New ref model: 8
#
# Evaluating at epoch 180 …
# Train Accuracy: 94.40%
# Train Average Loss: 0.1594
# Test Accuracy: 93.42%
# Test Average Loss: 0.2680
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.46e-04
# New best model saved with test accuracy: 93.42%
# Epoch [181] 📊 acc: 0.945 | Targets: 0.1610
# New ref model saved
# New ref model: 10
# Epoch [182] 📊 acc: 0.946 | Targets: 0.1555
# New ref model saved
# New ref model: 10
# Epoch [183] 📊 acc: 0.947 | Targets: 0.1528
# New ref model saved
# New ref model: 11
# Epoch [184] 📊 acc: 0.946 | Targets: 0.1578
# New ref model: 8
# Epoch [185] 📊 acc: 0.947 | Targets: 0.1540
# New ref model: 12
# Epoch [186] 📊 acc: 0.947 | Targets: 0.1544
# New ref model saved
# New ref model: 12
# Epoch [187] 📊 acc: 0.948 | Targets: 0.1507
# New ref model saved
# New ref model: 13
# Epoch [188] 📊 acc: 0.948 | Targets: 0.1519
# New ref model saved
# New ref model: 12
# Epoch [189] 📊 acc: 0.947 | Targets: 0.1547
# New ref model: 14
# Epoch [190] 📊 acc: 0.947 | Targets: 0.1516
# New ref model: 14
#
# Evaluating at epoch 190 …
# Train Accuracy: 95.08%
# Train Average Loss: 0.1447
# Test Accuracy: 93.54%
# Test Average Loss: 0.2545
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.97e-04
# New best model saved with test accuracy: 93.54%
# Epoch [191] 📊 acc: 0.950 | Targets: 0.1471
# New ref model saved
# New ref model: 15
# Epoch [192] 📊 acc: 0.949 | Targets: 0.1497
# New ref model: 0
# Epoch [193] 📊 acc: 0.949 | Targets: 0.1456
# New ref model: 0
# Epoch [194] 📊 acc: 0.949 | Targets: 0.1466
# New ref model: 0
# Epoch [195] 📊 acc: 0.949 | Targets: 0.1484
# New ref model: 1
# Epoch [196] 📊 acc: 0.949 | Targets: 0.1483
# New ref model: 0
# Epoch [197] 📊 acc: 0.950 | Targets: 0.1458
# New ref model: 2
# Epoch [198] 📊 acc: 0.952 | Targets: 0.1410
# New ref model saved
# New ref model: 2
# Epoch [199] 📊 acc: 0.952 | Targets: 0.1396
# New ref model saved
# New ref model: 3
# Epoch [200] 📊 acc: 0.950 | Targets: 0.1433
# New ref model: 0
#
# Evaluating at epoch 200 …
# Train Accuracy: 95.18%
# Train Average Loss: 0.1403
# Test Accuracy: 93.64%
# Test Average Loss: 0.2612
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.51e-04
# New best model saved with test accuracy: 93.64%
# Epoch [201] 📊 acc: 0.951 | Targets: 0.1416
# New ref model: 4
# Epoch [202] 📊 acc: 0.952 | Targets: 0.1408
# New ref model: 4
# Epoch [203] 📊 acc: 0.951 | Targets: 0.1369
# New ref model: 5
# Epoch [204] 📊 acc: 0.951 | Targets: 0.1424
# New ref model: 4
# Epoch [205] 📊 acc: 0.953 | Targets: 0.1390
# New ref model saved
# New ref model: 6
# Epoch [206] 📊 acc: 0.954 | Targets: 0.1344
# New ref model saved
# New ref model: 6
# Epoch [207] 📊 acc: 0.953 | Targets: 0.1397
# New ref model: 7
# Epoch [208] 📊 acc: 0.954 | Targets: 0.1392
# New ref model: 0
# Epoch [209] 📊 acc: 0.953 | Targets: 0.1384
# New ref model: 8
# Epoch [210] 📊 acc: 0.953 | Targets: 0.1341
# New ref model: 8
#
# Evaluating at epoch 210 …
# Train Accuracy: 95.44%
# Train Average Loss: 0.1345
# Test Accuracy: 93.79%
# Test Average Loss: 0.2694
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.07e-04
# New best model saved with test accuracy: 93.79%
# Epoch [211] 📊 acc: 0.954 | Targets: 0.1345
# New ref model saved
# New ref model: 9
# Epoch [212] 📊 acc: 0.954 | Targets: 0.1351
# New ref model: 8
# Epoch [213] 📊 acc: 0.953 | Targets: 0.1358
# New ref model: 10
# Epoch [214] 📊 acc: 0.954 | Targets: 0.1357
# New ref model: 10
# Epoch [215] 📊 acc: 0.953 | Targets: 0.1364
# New ref model: 11
# Epoch [216] 📊 acc: 0.954 | Targets: 0.1367
# New ref model: 8
# Epoch [217] 📊 acc: 0.954 | Targets: 0.1316
# New ref model: 12
# Epoch [218] 📊 acc: 0.955 | Targets: 0.1336
# New ref model saved
# New ref model: 12
# Epoch [219] 📊 acc: 0.954 | Targets: 0.1353
# New ref model: 13
# Epoch [220] 📊 acc: 0.957 | Targets: 0.1263
# New ref model saved
# New ref model: 12
#
# Evaluating at epoch 220 …
# Train Accuracy: 95.69%
# Train Average Loss: 0.1267
# Test Accuracy: 93.48%
# Test Average Loss: 0.2791
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.66e-04
# Epoch [221] 📊 acc: 0.956 | Targets: 0.1280
# New ref model: 14
# Epoch [222] 📊 acc: 0.956 | Targets: 0.1293
# New ref model: 14
# Epoch [223] 📊 acc: 0.957 | Targets: 0.1258
# New ref model saved
# New ref model: 15
# Epoch [224] 📊 acc: 0.955 | Targets: 0.1298
# New ref model: 0
# Epoch [225] 📊 acc: 0.957 | Targets: 0.1263
# New ref model: 0
# Epoch [226] 📊 acc: 0.956 | Targets: 0.1267
# New ref model: 0
# Epoch [227] 📊 acc: 0.956 | Targets: 0.1279
# New ref model: 1
# Epoch [228] 📊 acc: 0.958 | Targets: 0.1241
# New ref model saved
# New ref model: 0
# Epoch [229] 📊 acc: 0.955 | Targets: 0.1322
# New ref model: 2
# Epoch [230] 📊 acc: 0.957 | Targets: 0.1250
# New ref model: 2
#
# Evaluating at epoch 230 …
# Train Accuracy: 95.75%
# Train Average Loss: 0.1249
# Test Accuracy: 93.83%
# Test Average Loss: 0.2745
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.29e-04
# New best model saved with test accuracy: 93.83%
# Epoch [231] 📊 acc: 0.959 | Targets: 0.1217
# New ref model saved
# New ref model: 3
# Epoch [232] 📊 acc: 0.958 | Targets: 0.1247
# New ref model: 0
# Epoch [233] 📊 acc: 0.957 | Targets: 0.1250
# New ref model: 4
# Epoch [234] 📊 acc: 0.956 | Targets: 0.1248
# New ref model: 4
# Epoch [235] 📊 acc: 0.957 | Targets: 0.1256
# New ref model: 5
# Epoch [236] 📊 acc: 0.958 | Targets: 0.1219
# New ref model: 4
# Epoch [237] 📊 acc: 0.959 | Targets: 0.1195
# New ref model saved
# New ref model: 6
# Epoch [238] 📊 acc: 0.959 | Targets: 0.1190
# New ref model: 6
# Epoch [239] 📊 acc: 0.958 | Targets: 0.1241
# New ref model: 7
# Epoch [240] 📊 acc: 0.960 | Targets: 0.1161
# New ref model saved
# New ref model: 0
#
# Evaluating at epoch 240 …
# Train Accuracy: 96.01%
# Train Average Loss: 0.1167
# Test Accuracy: 93.91%
# Test Average Loss: 0.2645
# Total Trainable Parameters: 515,754
#
# Current learning rate: 9.64e-05
# New best model saved with test accuracy: 93.91%
# Epoch [241] 📊 acc: 0.960 | Targets: 0.1172
# New ref model: 8
# Epoch [242] 📊 acc: 0.959 | Targets: 0.1211
# New ref model: 8
# Epoch [243] 📊 acc: 0.960 | Targets: 0.1169
# New ref model saved
# New ref model: 9
# Epoch [244] 📊 acc: 0.958 | Targets: 0.1186
# New ref model: 8
# Epoch [245] 📊 acc: 0.961 | Targets: 0.1123
# New ref model saved
# New ref model: 10
# Epoch [246] 📊 acc: 0.960 | Targets: 0.1179
# New ref model: 10
# Epoch [247] 📊 acc: 0.961 | Targets: 0.1118
# New ref model saved
# New ref model: 11
# Epoch [248] 📊 acc: 0.960 | Targets: 0.1171
# New ref model: 8
# Epoch [249] 📊 acc: 0.960 | Targets: 0.1149
# New ref model: 12
# Epoch [250] 📊 acc: 0.960 | Targets: 0.1168
# New ref model: 12
#
# Evaluating at epoch 250 …
# Train Accuracy: 96.05%
# Train Average Loss: 0.1139
# Test Accuracy: 94.03%
# Test Average Loss: 0.2667
# Total Trainable Parameters: 515,754
#
# Current learning rate: 6.79e-05
# New best model saved with test accuracy: 94.03%
# Epoch [251] 📊 acc: 0.959 | Targets: 0.1159
# New ref model: 13
# Epoch [252] 📊 acc: 0.961 | Targets: 0.1146
# New ref model: 12
# Epoch [253] 📊 acc: 0.961 | Targets: 0.1144
# New ref model: 14
# Epoch [254] 📊 acc: 0.961 | Targets: 0.1143
# New ref model: 14
# Epoch [255] 📊 acc: 0.961 | Targets: 0.1152
# New ref model: 15
# Epoch [256] 📊 acc: 0.963 | Targets: 0.1094
# New ref model saved
# New ref model: 0
# Epoch [257] 📊 acc: 0.961 | Targets: 0.1138
# New ref model: 0
# Epoch [258] 📊 acc: 0.961 | Targets: 0.1166
# New ref model: 0
# Epoch [259] 📊 acc: 0.961 | Targets: 0.1125
# New ref model: 1
# Epoch [260] 📊 acc: 0.962 | Targets: 0.1123
# New ref model: 0
#
# Evaluating at epoch 260 …
# Train Accuracy: 96.18%
# Train Average Loss: 0.1148
# Test Accuracy: 93.93%
# Test Average Loss: 0.2756
# Total Trainable Parameters: 515,754
#
# Current learning rate: 4.42e-05
# Epoch [261] 📊 acc: 0.961 | Targets: 0.1177
# New ref model: 2
# Epoch [262] 📊 acc: 0.962 | Targets: 0.1119
# New ref model: 2
# Epoch [263] 📊 acc: 0.963 | Targets: 0.1102
# New ref model: 3
# Epoch [264] 📊 acc: 0.962 | Targets: 0.1110
# New ref model: 0
# Epoch [265] 📊 acc: 0.963 | Targets: 0.1097
# New ref model saved
# New ref model: 4
# Epoch [266] 📊 acc: 0.960 | Targets: 0.1147
# New ref model: 4
# Epoch [267] 📊 acc: 0.962 | Targets: 0.1104
# New ref model: 5
# Epoch [268] 📊 acc: 0.962 | Targets: 0.1105
# New ref model: 4
# Epoch [269] 📊 acc: 0.961 | Targets: 0.1149
# New ref model: 6
# Epoch [270] 📊 acc: 0.962 | Targets: 0.1107
# New ref model: 6
#
# Evaluating at epoch 270 …
# Train Accuracy: 96.39%
# Train Average Loss: 0.1066
# Test Accuracy: 94.03%
# Test Average Loss: 0.2728
# Total Trainable Parameters: 515,754
#
# Current learning rate: 2.54e-05
# Epoch [271] 📊 acc: 0.962 | Targets: 0.1092
# New ref model: 7
# Epoch [272] 📊 acc: 0.963 | Targets: 0.1118
# New ref model: 0
# Epoch [273] 📊 acc: 0.962 | Targets: 0.1129
# New ref model: 8
# Epoch [274] 📊 acc: 0.961 | Targets: 0.1136
# New ref model: 8
# Epoch [275] 📊 acc: 0.963 | Targets: 0.1108
# New ref model: 9
# Epoch [276] 📊 acc: 0.962 | Targets: 0.1115
# New ref model: 8
# Epoch [277] 📊 acc: 0.962 | Targets: 0.1110
# New ref model: 10
# Epoch [278] 📊 acc: 0.963 | Targets: 0.1098
# New ref model: 10
# Epoch [279] 📊 acc: 0.964 | Targets: 0.1039
# New ref model saved
# New ref model: 11
# Epoch [280] 📊 acc: 0.964 | Targets: 0.1048
# New ref model: 8
#
# Evaluating at epoch 280 …
# Train Accuracy: 96.41%
# Train Average Loss: 0.1055
# Test Accuracy: 94.00%
# Test Average Loss: 0.2773
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.19e-05
# Epoch [281] 📊 acc: 0.962 | Targets: 0.1120
# New ref model: 12
# Epoch [282] 📊 acc: 0.963 | Targets: 0.1086
# New ref model: 12
# Epoch [283] 📊 acc: 0.963 | Targets: 0.1084
# New ref model: 13
# Epoch [284] 📊 acc: 0.963 | Targets: 0.1096
# New ref model: 12
# Epoch [285] 📊 acc: 0.963 | Targets: 0.1053
# New ref model: 14
# Epoch [286] 📊 acc: 0.963 | Targets: 0.1089
# New ref model: 14
# Epoch [287] 📊 acc: 0.963 | Targets: 0.1094
# New ref model: 15
# Epoch [288] 📊 acc: 0.963 | Targets: 0.1087
# New ref model: 0
# Epoch [289] 📊 acc: 0.962 | Targets: 0.1097
# New ref model: 0
# Epoch [290] 📊 acc: 0.963 | Targets: 0.1070
# New ref model: 0
#
# Evaluating at epoch 290 …
# Train Accuracy: 96.34%
# Train Average Loss: 0.1079
# Test Accuracy: 94.03%
# Test Average Loss: 0.2736
# Total Trainable Parameters: 515,754
#
# Current learning rate: 3.74e-06
# Epoch [291] 📊 acc: 0.964 | Targets: 0.1085
# New ref model: 1
# Epoch [292] 📊 acc: 0.961 | Targets: 0.1130
# New ref model: 0
# Epoch [293] 📊 acc: 0.964 | Targets: 0.1065
# New ref model saved
# New ref model: 2
# Epoch [294] 📊 acc: 0.962 | Targets: 0.1112
# New ref model: 2
# Epoch [295] 📊 acc: 0.963 | Targets: 0.1079
# New ref model: 3
# Epoch [296] 📊 acc: 0.963 | Targets: 0.1069
# New ref model: 0
# Epoch [297] 📊 acc: 0.963 | Targets: 0.1086
# New ref model: 4
# Epoch [298] 📊 acc: 0.964 | Targets: 0.1039
# New ref model saved
# New ref model: 4
# Epoch [299] 📊 acc: 0.962 | Targets: 0.1101
# New ref model: 5
# Epoch [300] 📊 acc: 0.963 | Targets: 0.1083
# New ref model: 4
#
# Evaluating at epoch 300 …
# Train Accuracy: 96.30%
# Train Average Loss: 0.1116
# Test Accuracy: 94.09%
# Test Average Loss: 0.2730
# Total Trainable Parameters: 515,754
#
# Current learning rate: 1.00e-06
# New best model saved with test accuracy: 94.09%
# Finished Training
# Best test accuracy achieved: 94.09%
# Total Trainable Parameters: 515,754
